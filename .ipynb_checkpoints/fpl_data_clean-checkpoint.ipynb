# %%
from fastai.tabular import *
import requests
import lxml.html as lh

# %%
path = Path('/home/jupyter/fpl_prediction/data')

# %%
season_paths = [path/'2016-17', path/'2017-18', path/'2018-19', path/'2019-20']
season_names = ['1617', '1718', '1819', '1920']
season_players = []

for season_path in season_paths:
    players = pd.read_csv(season_path/'players_raw.csv', 
                           usecols=['first_name', 'second_name', 'id', 'team_code', 'element_type'])
    season_players.append(players)
    
teams = pd.read_csv(path/'teams.csv')

# two danny wards in 1819, rename the new one
season_players[2].loc[143, 'second_name'] = 'Ward_2'

for players in season_players:
    players['full_name'] = players['first_name'] + '_' + players['second_name']
    players.drop(['first_name', 'second_name'], axis=1, inplace=True)
    
all_players = pd.concat(season_players, axis=0, ignore_index=True, sort=False)
all_players = pd.DataFrame(all_players['full_name'].drop_duplicates())

for players, season in zip(season_players, season_names):
    all_players = all_players.merge(players, on='full_name', how='left')
    all_players.rename(index=str,
                       columns={'id':'id_' + season,
                                'team_code':'team_' + season,
                                'element_type': 'position_' + season},
                       inplace=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-e0e06e34afe0> in <module>
#       5 for season_path in season_paths:
#       6     players = pd.read_csv(season_path/'players_raw.csv',
# ----> 7                            usecols=['first_name', 'second_name', 'id', 'team_code', 'element_type'])
#       8     season_players.append(players)
#       9
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'/home/jupyter/fpl_prediction/data/2016-17/players_raw.csv' does not exist: b'/home/jupyter/fpl_prediction/data/2016-17/players_raw.csv'

# %%
all_players.head(20)
# Out:
#                    full_name  position_1617  id_1617  team_1617  \
# 0               David_Ospina            1.0      1.0        3.0
# 1                  Petr_Cech            1.0      2.0        3.0
# 2          Laurent_Koscielny            2.0      3.0        3.0
# 3            Per_Mertesacker            2.0      4.0        3.0
# 4   Gabriel Armando_de Abreu            2.0      5.0        3.0
# 5            Héctor_Bellerín            2.0      6.0        3.0
# 6               Kieran_Gibbs            2.0      7.0        3.0
# 7            Mathieu_Debuchy            2.0      8.0        3.0
# 8             Carl_Jenkinson            2.0      9.0        3.0
# 9              Nacho_Monreal            2.0     10.0        3.0
# 10            Calum_Chambers            2.0     11.0       25.0
# 11            Alexis_Sánchez            3.0     12.0        3.0
# 12              Theo_Walcott            3.0     13.0        3.0
# 13                Mesut_Özil            3.0     14.0        3.0
# 14          Santiago_Cazorla            3.0     15.0        3.0
# 15              Aaron_Ramsey            3.0     16.0        3.0
# 16             Jack_Wilshere            3.0     17.0       91.0
# 17   Alex_Oxlade-Chamberlain            3.0     18.0        3.0
# 18              Serge_Gnabry            3.0     19.0        3.0
# 19          Francis_Coquelin            3.0     20.0        3.0
#
#     position_1718  id_1718  team_1718  position_1819  id_1819  team_1819  \
# 0             1.0      1.0        3.0            NaN      NaN        NaN
# 1             1.0      2.0        3.0            1.0      1.0        3.0
# 2             2.0      4.0        3.0            2.0      3.0        3.0
# 3             2.0      5.0        3.0            NaN      NaN        NaN
# 4             2.0      6.0        3.0            NaN      NaN        NaN
# 5             2.0      7.0        3.0            2.0      4.0        3.0
# 6             2.0      8.0       35.0            NaN      NaN        NaN
# 7             2.0    564.0        3.0            NaN      NaN        NaN
# 8             2.0      9.0        3.0            2.0    581.0        3.0
# 9             2.0     10.0        3.0            2.0      5.0        3.0
# 10            2.0    480.0        3.0            2.0      9.0       54.0
# 11            3.0     14.0        1.0            3.0    295.0        1.0
# 12            3.0     15.0       11.0            3.0    164.0       11.0
# 13            3.0     16.0        3.0            3.0     13.0        3.0
# 14            3.0     17.0        3.0            NaN      NaN        NaN
# 15            3.0     18.0        3.0            3.0     14.0        3.0
# 16            3.0     24.0        3.0            3.0    447.0       21.0
# 17            3.0     19.0       14.0            3.0    248.0       14.0
# 18            NaN      NaN        NaN            NaN      NaN        NaN
# 19            3.0     20.0        3.0            NaN      NaN        NaN
#
#     position_1920  id_1920  team_1920
# 0             NaN      NaN        NaN
# 1             NaN      NaN        NaN
# 2             2.0      7.0        3.0
# 3             NaN      NaN        NaN
# 4             NaN      NaN        NaN
# 5             2.0      2.0        3.0
# 6             NaN      NaN        NaN
# 7             NaN      NaN        NaN
# 8             2.0      9.0        3.0
# 9             2.0      6.0        3.0
# 10            NaN      NaN        NaN
# 11            3.0    240.0        1.0
# 12            3.0    153.0       11.0
# 13            3.0     15.0        3.0
# 14            NaN      NaN        NaN
# 15            NaN      NaN        NaN
# 16            3.0    394.0       21.0
# 17            3.0    193.0       14.0
# 18            NaN      NaN        NaN
# 19            NaN      NaN        NaN

# %%
type(all_players.loc[:,'id_1617']) #& (all_players['full_name'] == '1')
# Out:
# pandas.core.series.Series

# %%
all_players.shape
# Out:
# (1139, 13)

# %%
teams
# Out:
#                         team  team_code  team_1617  team_1718  team_1819  \
# 0                    Arsenal          3        1.0        1.0        1.0
# 1                Bournemouth         91        2.0        2.0        2.0
# 2                    Burnley         90        3.0        4.0        4.0
# 3                    Chelsea          8        4.0        5.0        6.0
# 4             Crystal Palace         31        5.0        6.0        7.0
# 5                    Everton         11        6.0        7.0        8.0
# 6                  Hull City         88        7.0        NaN        NaN
# 7             Leicester City         13        8.0        9.0       11.0
# 8                  Liverpool         14        9.0       10.0       12.0
# 9            Manchester City         43       10.0       11.0       13.0
# 10         Manchester United          1       11.0       12.0       14.0
# 11             Middlesbrough         25       12.0        NaN        NaN
# 12               Southampton         20       13.0       14.0       16.0
# 13                Stoke City        110       14.0       15.0        NaN
# 14                Sunderland         56       15.0        NaN        NaN
# 15              Swansea City         80       16.0       16.0        NaN
# 16         Tottenham Hotspur          6       17.0       17.0       17.0
# 17                   Watford         57       18.0       18.0       18.0
# 18      West Bromwich Albion         35       19.0       19.0        NaN
# 19           West Ham United         21       20.0       20.0       19.0
# 20  Brighton and Hove Albion         36        NaN        3.0        3.0
# 21         Huddersfield Town         38        NaN        8.0       10.0
# 22          Newcastle United          4        NaN       13.0       15.0
# 23              Cardiff City         97        NaN        NaN        5.0
# 24                    Fulham         54        NaN        NaN        9.0
# 25   Wolverhampton Wanderers         39        NaN        NaN       20.0
# 26               Aston Villa          7        NaN        NaN        NaN
# 27                   Norwich         45        NaN        NaN        NaN
# 28          Sheffield United         49        NaN        NaN        NaN
#
#     team_1920
# 0         1.0
# 1         3.0
# 2         5.0
# 3         6.0
# 4         7.0
# 5         8.0
# 6         NaN
# 7         9.0
# 8        10.0
# 9        11.0
# 10       12.0
# 11        NaN
# 12       16.0
# 13        NaN
# 14        NaN
# 15        NaN
# 16       17.0
# 17       18.0
# 18        NaN
# 19       19.0
# 20        4.0
# 21        NaN
# 22       13.0
# 23        NaN
# 24        NaN
# 25       20.0
# 26        2.0
# 27       14.0
# 28       15.0

# %%
def build_season_mv(season, header_row, team_rows):
    
    #previous_season = str(int(season[2:4]) - 1)
    url=r'https://www.transfermarkt.com/premier-league/startseite/wettbewerb/GB1/plus/?saison_id=' + '20' + season[0:2]
    
    #Create a handle, page, to handle the contents of the website
    page = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})
    
    #Store the contents of the website under doc
    doc = lh.fromstring(page.content)
    
    #Parse data that are stored between <tr>..</tr> of HTML
    tr_elements = doc.xpath('//tr')
    
    #Create empty list
    col=[]
    i=0

    #For each row, store each first element (header) and an empty list
    for t in tr_elements[header_row]:
        i+=1
        name=t.text_content()
        col.append((name,[]))
        
    #data is stored on the second row onwards
    for j in team_rows:
        #T is our j'th row
        T=tr_elements[j]

        #If row is not of size 10, the //tr data is not from our table 
        if len(T)!=10:
            break

        #i is the index of our column
        i=0

        #Iterate through each element of the row
        for t in T.iterchildren():
            data=t.text_content() 
            #Check if row is empty
            if i>0:
            #Convert any numerical value to integers
                try:
                    data=int(data)
                except:
                    pass
            #Append the data to the empty list of the i'th column
            col[i][1].append(data)
            #Increment i for the next column
            i+=1
        
    Dict={title:column for (title,column) in col}
    df=pd.DataFrame(Dict)
    
    values = [float(item[0].replace(',', '.')) for item in df['Total MV'].str.split(" ", 1)]
    values = [item*10**3 if item < 3 else item for item in values]
    values = values/np.mean(values)
    
    df = df[['name']]
    df.replace(team_names, inplace=True)
    df['relative_market_value'] = values
    df['season'] = season
    
    return df

# %%
team_names = {'Man City': 'Manchester City',
              'Spurs': 'Tottenham Hotspur',
              'Man Utd': 'Manchester United',
              'Leicester': 'Leicester City',
              'West Ham': 'West Ham United',
              'Wolves': 'Wolverhampton Wanderers',
              'Brighton': 'Brighton and Hove Albion',
              'Newcastle': 'Newcastle United',
              'Sheffield Utd.': 'Sheffield United',
              'West Brom': 'West Bromwich Albion',
              'Swansea': 'Swansea City',
              'Huddersfield': 'Huddersfield Town',
              'Cardiff': 'Cardiff City'}

# %%
teams_mv = pd.concat([build_season_mv('1617', 10, range(12,32)),
                      build_season_mv('1718', 10, range(12,32)),
                      build_season_mv('1819', 10, range(12,32)),
                      build_season_mv('1920', 11, range(13,33))], axis=0, ignore_index=True, sort=False)

# %%
teams_mv[teams_mv['season'] == '1819']
# Out:
#                         name  relative_market_value season
# 40           Manchester City               2.540586   1819
# 41                   Chelsea               2.540586   1819
# 42                 Liverpool               2.177887   1819
# 43         Manchester United               2.015531   1819
# 44         Tottenham Hotspur               1.983109   1819
# 45                   Arsenal               1.435552   1819
# 46                   Everton               1.039221   1819
# 47            Leicester City               0.796050   1819
# 48           West Ham United               0.749352   1819
# 49               Southampton               0.654624   1819
# 50            Crystal Palace               0.634856   1819
# 51          Newcastle United               0.483921   1819
# 52                   Burnley               0.449442   1819
# 53               Bournemouth               0.418108   1819
# 54  Brighton and Hove Albion               0.417745   1819
# 55                   Watford               0.412301   1819
# 56                    Fulham               0.405284   1819
# 57   Wolverhampton Wanderers               0.388177   1819
# 58         Huddersfield Town               0.273778   1819
# 59              Cardiff City               0.183890   1819

# %%
def build_season(path, season):
    df_season = []
    id_season = 'id_' + season
    id_team = 'team_' + season
    id_position = 'position_' + season
    
    for i in range(1, 39):
        gw = 'gws/gw' + str(i) + '.csv'
        gw_df = pd.read_csv(path/gw, encoding='latin')
        gw_df['gw'] = i
        df_season.append(gw_df)
    
    df_season = pd.concat(df_season, axis=0)
    df_season = df_season.merge(all_players, left_on='element', right_on=id_season, how='left')
    df_season = df_season.merge(teams, left_on='opponent_team', right_on=id_team, how='left')
    df_season = df_season.merge(teams, left_on=id_team + '_x', right_on='team_code', how='left')
    df_season = df_season.merge(teams_mv[teams_mv['season'] == season], left_on='team_y', right_on='name', how='left')
    df_season = df_season[['full_name', 'gw', 
                           id_position, 'minutes', 'team_y', 
                           'team_x', 'relative_market_value', 'was_home', 'total_points']]
    df_season.columns = ['player', 'gw', 
                          'position', 'minutes', 'team', 
                          'opponent_team', 'relative_market_value', 'was_home', 'total_points']
    df_season['season'] = season
    df_season['position'] = df_season['position'].astype(int)
    
    return df_season

# %%
df_1617 = build_season(season_paths[0], season_names[0])
df_1718 = build_season(season_paths[1], season_names[1])
df_1819 = build_season(season_paths[2], season_names[2])

# %%
type(df_1617['minutes'])
# Out:
# pandas.core.series.Series

# %%
[x.shape for x in [df_1617, df_1718, df_1819]]
# Out:
# [(23679, 10), (22467, 10), (21790, 10)]

# %%
#df_all = pd.concat([df_1617, df_1718, df_1819], ignore_index=True, axis=0)

# %%
df_all = df_1617.append(df_1718).append(df_1819).reset_index(drop=True)

# %%
len(df_all)
# Out:
# 67936

# %%
df_all.tail(10)
# Out:
#                       player  gw  position  minutes                      team  \
# 67926             Yerry_Mina  38         2       90                   Everton
# 67927       Yohan_Benalouane  38         2        0            Leicester City
# 67928         Yoshinori_Muto  38         4       24          Newcastle United
# 67929          Younes_Kaboul  38         2        0                   Watford
# 67930        Youri_Tielemans  38         3       90            Leicester City
# 67931          Yves_Bissouma  38         3       90  Brighton and Hove Albion
# 67932            Zech_Medley  38         2        0                   Arsenal
# 67933  Zeze Steven_Sessegnon  38         2        0                    Fulham
# 67934          Álvaro_Morata  38         4        0                   Chelsea
# 67935         Çaglar_Söyüncü  38         2        0            Leicester City
#
#            opponent_team  relative_market_value  was_home  total_points season
# 67926  Tottenham Hotspur               1.039221     False             1   1819
# 67927            Chelsea               0.796050      True             0   1819
# 67928             Fulham               0.483921     False             1   1819
# 67929    West Ham United               0.412301      True             0   1819
# 67930            Chelsea               0.796050      True             3   1819
# 67931    Manchester City               0.417745      True             2   1819
# 67932            Burnley               1.435552     False             0   1819
# 67933   Newcastle United               0.405284      True             0   1819
# 67934     Leicester City               2.540586     False             0   1819
# 67935            Chelsea               0.796050      True             0   1819

# %%
# find validation cut point - index for 18-19 season second half (gw 19)
valid_start = df_all[(df_all['gw'] > 18) & (df_all['season'] == '1819')].index.min()
#valid_start = df_all[(df_all['season'] == '1819')].index.min()
valid_end = df_all.index.max()

# %%
df_all.shape
# Out:
# (67936, 10)

# %%
df_all.dtypes
# Out:
# player                    object
# gw                         int64
# position                   int64
# minutes                    int64
# team                      object
# opponent_team             object
# relative_market_value    float64
# was_home                    bool
# total_points               int64
# season                    object
# dtype: object

# %%
cat_vars = ['player', 'gw', 'position', 'team', 'opponent_team', 'was_home', 'season']
cont_vars = ['minutes']
#cont_vars = ['relative_market_value', 'minutes']

# %%
dep_var = 'total_points'

# %%
valid_idx = range(valid_start, valid_end)

# %%
procs=[Categorify, Normalize]

# %%
data = (TabularList.from_df(df_all, path=path, cat_names=cat_vars, cont_names=cont_vars, procs=procs,)
                .split_by_idx(valid_idx)
                .label_from_df(cols=dep_var, label_cls=FloatList)
                .databunch())

# %%
max_y = np.max(df_all['total_points'])*1.1
y_range = torch.tensor([0, max_y], device=defaults.device)

# %%
learn = tabular_learner(data, layers=[1000,500], ps=[0.001,0.01], emb_drop=0.04, 
                        y_range=y_range, metrics=rmse)

# %%
learn.model
# Out:
# TabularModel(
#   (embeds): ModuleList(
#     (0): Embedding(1055, 79)
#     (1): Embedding(39, 12)
#     (2): Embedding(5, 4)
#     (3): Embedding(27, 10)
#     (4): Embedding(27, 10)
#     (5): Embedding(3, 3)
#     (6): Embedding(4, 3)
#   )
#   (emb_drop): Dropout(p=0.04)
#   (bn_cont): BatchNorm1d(2, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layers): Sequential(
#     (0): Linear(in_features=123, out_features=1000, bias=True)
#     (1): ReLU(inplace)
#     (2): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.001)
#     (4): Linear(in_features=1000, out_features=500, bias=True)
#     (5): ReLU(inplace)
#     (6): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.01)
#     (8): Linear(in_features=500, out_features=1, bias=True)
#   )
# )

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
# old one without market value
learn.fit_one_cycle(7, 1.1e-2, wd=0.2)
# Out:
# Total time: 00:40 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.671103</td>
#       <td>4.058165</td>
#       <td>1.975258</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.023581</td>
#       <td>4.245531</td>
#       <td>1.991781</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.069503</td>
#       <td>4.208030</td>
#       <td>1.985547</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.735965</td>
#       <td>4.595274</td>
#       <td>2.119409</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.585393</td>
#       <td>3.877654</td>
#       <td>1.932921</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.206583</td>
#       <td>3.711629</td>
#       <td>1.876884</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.050195</td>
#       <td>3.812535</td>
#       <td>1.910187</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
# no market value, new season validation
learn.fit_one_cycle(7, 1.1e-2, wd=0.2)
# Out:
# Total time: 00:38 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.190550</td>
#       <td>6.135087</td>
#       <td>2.440161</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.857543</td>
#       <td>3.978027</td>
#       <td>1.933421</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.710502</td>
#       <td>3.876259</td>
#       <td>1.927505</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.443164</td>
#       <td>3.826964</td>
#       <td>1.915945</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.446122</td>
#       <td>3.713155</td>
#       <td>1.877538</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.098882</td>
#       <td>3.761742</td>
#       <td>1.897482</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.939469</td>
#       <td>3.802439</td>
#       <td>1.905856</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
# market value, new season validation
learn.fit_one_cycle(7, 1.1e-2, wd=0.2)
# Out:
# Total time: 00:38 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.974407</td>
#       <td>3.883185</td>
#       <td>1.914001</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.753403</td>
#       <td>4.662024</td>
#       <td>2.126512</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.625479</td>
#       <td>3.772259</td>
#       <td>1.889259</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.840882</td>
#       <td>3.775510</td>
#       <td>1.897972</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.616885</td>
#       <td>3.812484</td>
#       <td>1.901750</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.309392</td>
#       <td>3.734806</td>
#       <td>1.886369</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.903124</td>
#       <td>3.771559</td>
#       <td>1.897273</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.get_preds()[0]
# Out:
# tensor([[3.0839],
#         [0.1953],
#         [0.3003],
#         ...,
#         [0.1794],
#         [0.1215],
#         [0.3482]])

# %%
df_valid = df_all.loc[valid_idx]
df_valid['predicted_points'] = learn.get_preds()[0].data.numpy().T[0]

# %%
df_valid.dtypes
# Out:
# player                    object
# gw                         int64
# position                   int64
# minutes                    int64
# team                      object
# opponent_team             object
# relative_market_value    float64
# was_home                    bool
# total_points               int64
# season                    object
# predicted_points         float32
# dtype: object

# %%
df_valid[(df_valid['team'] == 'Cardiff City') & (df_valid['opponent_team'] == 'Chelsea')]
# Out:
#                            player  gw  position  minutes          team  \
# 48293               Alex_Smithies   5         1        0  Cardiff City
# 48314          Anthony_Pilkington   5         3        0  Cardiff City
# 48318             Aron_Gunnarsson   5         3        0  Cardiff City
# 48321  Ashley Darel Jazz_Richards   5         2       45  Cardiff City
# 48345                  Bobby_Reid   5         4       70  Cardiff City
# 48348                Brian_Murphy   5         1        0  Cardiff City
# 48350          Bruno_Ecuele Manga   5         2       90  Cardiff City
# 48354             Callum_Paterson   5         3       19  Cardiff City
# 48394                Danny_Ward_2   5         3       76  Cardiff City
# 48400        David Junior_Hoilett   5         3       90  Cardiff City
# 48456                 Gary_Madine   5         4       13  Cardiff City
# 48463            Greg_Cunninghamm   5         2        0  Cardiff City
# 48464                Greg_Halford   5         2        0  Cardiff City
# 48468                 Harry_Arter   5         3       45  Cardiff City
# 48519                 Joe_Bennett   5         2       90  Cardiff City
# 48522                   Joe_Ralls   5         3       90  Cardiff City
# 48544                 Josh_Murphy   5         3        0  Cardiff City
# 48554               Kadeem_Harris   5         3        0  Cardiff City
# 48558              Kenneth_Zohore   5         4        0  Cardiff City
# 48576                 Lee_Peltier   5         2        0  Cardiff City
# 48583                 Loïc_Damour   5         3        0  Cardiff City
# 48621            Matthew_Connolly   5         2        0  Cardiff City
# 48651      Nathaniel_Mendez-Laing   5         3        0  Cardiff City
# 48655              Neil_Etheridge   5         1       90  Cardiff City
# 48662                  Omar_Bogle   5         4        0  Cardiff City
# 48730               Sean_Morrison   5         2       90  Cardiff City
# 48745                   Sol_Bamba   5         2       90  Cardiff City
# 48783             Víctor_Camarasa   5         3       90  Cardiff City
# 52476                Oumar_Niasse  12         4        0  Cardiff City
# 63316               Alex_Smithies  32         1        0  Cardiff City
# 63354          Anthony_Pilkington  32         3        0  Cardiff City
# 63363             Aron_Gunnarsson  32         3       90  Cardiff City
# 63367  Ashley Darel Jazz_Richards  32         2        0  Cardiff City
# 63408                  Bobby_Reid  32         4        0  Cardiff City
# 63414                Brian_Murphy  32         1        0  Cardiff City
# 63418          Bruno_Ecuele Manga  32         2       90  Cardiff City
# 63425             Callum_Paterson  32         3        0  Cardiff City
# 63493                Danny_Ward_2  32         3        0  Cardiff City
# 63503        David Junior_Hoilett  32         3       90  Cardiff City
# 63596                 Gary_Madine  32         4        0  Cardiff City
# 63611            Greg_Cunninghamm  32         2        0  Cardiff City
# 63613                Greg_Halford  32         2        0  Cardiff City
# 63618                 Harry_Arter  32         3       79  Cardiff City
# 63697                 Joe_Bennett  32         2       90  Cardiff City
# 63703                   Joe_Ralls  32         3       10  Cardiff City
# 63736                 Josh_Murphy  32         3       89  Cardiff City
# 63756               Kadeem_Harris  32         3        0  Cardiff City
# 63765              Kenneth_Zohore  32         4        5  Cardiff City
# 63795              Leandro_Bacuna  32         2        0  Cardiff City
# 63799                 Lee_Peltier  32         2       90  Cardiff City
# 63810                 Loïc_Damour  32         3        0  Cardiff City
# 63872            Matthew_Connolly  32         2        0  Cardiff City
# 63922      Nathaniel_Mendez-Laing  32         3        1  Cardiff City
# 63928              Neil_Etheridge  32         1       90  Cardiff City
# 63942                  Omar_Bogle  32         4        0  Cardiff City
# 63945                Oumar_Niasse  32         4       84  Cardiff City
# 63990                 Rhys_Healey  32         4        0  Cardiff City
# 64053               Sean_Morrison  32         2       90  Cardiff City
# 64076                   Sol_Bamba  32         2        0  Cardiff City
# 64140             Víctor_Camarasa  32         3       90  Cardiff City
#
#       opponent_team  relative_market_value  was_home  total_points season  \
# 48293       Chelsea                0.18389     False             0   1819
# 48314       Chelsea                0.18389     False             0   1819
# 48318       Chelsea                0.18389     False             0   1819
# 48321       Chelsea                0.18389     False             0   1819
# 48345       Chelsea                0.18389     False             2   1819
# 48348       Chelsea                0.18389     False             0   1819
# 48350       Chelsea                0.18389     False             0   1819
# 48354       Chelsea                0.18389     False             1   1819
# 48394       Chelsea                0.18389     False             2   1819
# 48400       Chelsea                0.18389     False             2   1819
# 48456       Chelsea                0.18389     False             1   1819
# 48463       Chelsea                0.18389     False             0   1819
# 48464       Chelsea                0.18389     False             0   1819
# 48468       Chelsea                0.18389     False             1   1819
# 48519       Chelsea                0.18389     False             0   1819
# 48522       Chelsea                0.18389     False             2   1819
# 48544       Chelsea                0.18389     False             0   1819
# 48554       Chelsea                0.18389     False             0   1819
# 48558       Chelsea                0.18389     False             0   1819
# 48576       Chelsea                0.18389     False             0   1819
# 48583       Chelsea                0.18389     False             0   1819
# 48621       Chelsea                0.18389     False             0   1819
# 48651       Chelsea                0.18389     False             0   1819
# 48655       Chelsea                0.18389     False             1   1819
# 48662       Chelsea                0.18389     False             0   1819
# 48730       Chelsea                0.18389     False             3   1819
# 48745       Chelsea                0.18389     False             6   1819
# 48783       Chelsea                0.18389     False             2   1819
# 52476       Chelsea                0.18389     False             0   1819
# 63316       Chelsea                0.18389      True             0   1819
# 63354       Chelsea                0.18389      True             0   1819
# 63363       Chelsea                0.18389      True             1   1819
# 63367       Chelsea                0.18389      True             0   1819
# 63408       Chelsea                0.18389      True             0   1819
# 63414       Chelsea                0.18389      True             0   1819
# 63418       Chelsea                0.18389      True             1   1819
# 63425       Chelsea                0.18389      True             0   1819
# 63493       Chelsea                0.18389      True             0   1819
# 63503       Chelsea                0.18389      True             2   1819
# 63596       Chelsea                0.18389      True             0   1819
# 63611       Chelsea                0.18389      True             0   1819
# 63613       Chelsea                0.18389      True             0   1819
# 63618       Chelsea                0.18389      True             5   1819
# 63697       Chelsea                0.18389      True             1   1819
# 63703       Chelsea                0.18389      True             1   1819
# 63736       Chelsea                0.18389      True             2   1819
# 63756       Chelsea                0.18389      True             0   1819
# 63765       Chelsea                0.18389      True             1   1819
# 63795       Chelsea                0.18389      True             0   1819
# 63799       Chelsea                0.18389      True             1   1819
# 63810       Chelsea                0.18389      True             0   1819
# 63872       Chelsea                0.18389      True             0   1819
# 63922       Chelsea                0.18389      True             1   1819
# 63928       Chelsea                0.18389      True             1   1819
# 63942       Chelsea                0.18389      True             0   1819
# 63945       Chelsea                0.18389      True             2   1819
# 63990       Chelsea                0.18389      True             0   1819
# 64053       Chelsea                0.18389      True             1   1819
# 64076       Chelsea                0.18389      True             0   1819
# 64140       Chelsea                0.18389      True             8   1819
#
#        predicted_points
# 48293          0.208214
# 48314          0.240774
# 48318          0.240774
# 48321          1.164150
# 48345          3.228093
# 48348          0.208214
# 48350          2.327248
# 48354          1.039282
# 48394          3.232011
# 48400          3.712587
# 48456          0.958701
# 48463          0.197794
# 48464          0.197794
# 48468          1.503152
# 48519          2.327248
# 48522          3.712587
# 48544          0.240774
# 48554          0.240774
# 48558          0.301839
# 48576          0.197794
# 48583          0.240774
# 48621          0.197794
# 48651          0.240774
# 48655          3.411342
# 48662          0.301839
# 48730          2.327248
# 48745          2.327248
# 48783          3.712587
# 52476          0.244217
# 63316          0.162259
# 63354          0.182687
# 63363          4.077508
# 63367          0.178417
# 63408          0.231195
# 63414          0.162259
# 63418          2.679641
# 63425          0.182687
# 63493          0.182687
# 63503          4.077508
# 63596          0.231195
# 63611          0.178417
# 63613          0.178417
# 63618          2.109879
# 63697          2.679641
# 63703          0.673166
# 63736          4.041504
# 63756          0.182687
# 63765          0.473594
# 63795          0.178417
# 63799          2.679641
# 63810          0.182687
# 63872          0.178417
# 63922          0.218463
# 63928          3.682704
# 63942          0.231195
# 63945          4.476368
# 63990          0.231195
# 64053          2.679641
# 64076          0.178417
# 64140          4.077508

# %%
fixtures = pd.read_csv(path/'fixtures.csv')

# %%
fixtures.head(10)
# Out:
#            home_team                 away_team  gw
# 0          Liverpool                   Norwich   1
# 1    West Ham United           Manchester City   1
# 2        Bournemouth          Sheffield United   1
# 3            Burnley               Southampton   1
# 4     Crystal Palace                   Everton   1
# 5            Watford  Brighton and Hove Albion   1
# 6  Tottenham Hotspur               Aston Villa   1
# 7     Leicester City   Wolverhampton Wanderers   1
# 8   Newcastle United                   Arsenal   1
# 9  Manchester United                   Chelsea   1

# %%
fixtures = fixtures.merge(teams, left_on='home_team', right_on='team', how='left')
fixtures = fixtures.merge(teams, left_on='away_team', right_on='team', how='left')
fixtures = fixtures[['gw', 'home_team', 'away_team', 'team_code_x', 'team_code_y']]
fixtures.rename(index=str,
                columns={'team_code_x':'home_team_code',
                         'team_code_y':'away_team_code'},
                inplace=True)

# %%
fixtures
# Out:
#      gw                 home_team                 away_team  home_team_code  \
# 0     1                 Liverpool                   Norwich              14
# 1     1           West Ham United           Manchester City              21
# 2     1               Bournemouth          Sheffield United              91
# 3     1                   Burnley               Southampton              90
# 4     1            Crystal Palace                   Everton              31
# 5     1                   Watford  Brighton and Hove Albion              57
# 6     1         Tottenham Hotspur               Aston Villa               6
# 7     1            Leicester City   Wolverhampton Wanderers              13
# 8     1          Newcastle United                   Arsenal               4
# 9     1         Manchester United                   Chelsea               1
# 10    2                   Arsenal                   Burnley               3
# 11    2               Aston Villa               Bournemouth               7
# 12    2  Brighton and Hove Albion           West Ham United              36
# 13    2                   Everton                   Watford              11
# 14    2                   Norwich          Newcastle United              45
# 15    2               Southampton                 Liverpool              20
# 16    2           Manchester City         Tottenham Hotspur              43
# 17    2          Sheffield United            Crystal Palace              49
# 18    2                   Chelsea            Leicester City               8
# 19    2   Wolverhampton Wanderers         Manchester United              39
# 20    3               Aston Villa                   Everton               7
# 21    3                   Norwich                   Chelsea              45
# 22    3  Brighton and Hove Albion               Southampton              36
# 23    3         Manchester United            Crystal Palace               1
# 24    3          Sheffield United            Leicester City              49
# 25    3                   Watford           West Ham United              57
# 26    3   Wolverhampton Wanderers                   Burnley              39
# 27    3                 Liverpool                   Arsenal              14
# 28    3               Bournemouth           Manchester City              91
# 29    3         Tottenham Hotspur          Newcastle United               6
# ..   ..                       ...                       ...             ...
# 350  36                   Arsenal                 Liverpool               3
# 351  36                   Burnley   Wolverhampton Wanderers              90
# 352  36                   Chelsea                   Norwich               8
# 353  36            Crystal Palace         Manchester United              31
# 354  36                   Everton               Aston Villa              11
# 355  36            Leicester City          Sheffield United              13
# 356  36           Manchester City               Bournemouth              43
# 357  36          Newcastle United         Tottenham Hotspur               4
# 358  36               Southampton  Brighton and Hove Albion              20
# 359  36           West Ham United                   Watford              21
# 360  37               Aston Villa                   Arsenal               7
# 361  37               Bournemouth               Southampton              91
# 362  37  Brighton and Hove Albion          Newcastle United              36
# 363  37                 Liverpool                   Chelsea              14
# 364  37         Manchester United           West Ham United               1
# 365  37                   Norwich                   Burnley              45
# 366  37          Sheffield United                   Everton              49
# 367  37         Tottenham Hotspur            Leicester City               6
# 368  37                   Watford           Manchester City              57
# 369  37   Wolverhampton Wanderers            Crystal Palace              39
# 370  38                   Arsenal                   Watford               3
# 371  38                   Burnley  Brighton and Hove Albion              90
# 372  38                   Chelsea   Wolverhampton Wanderers               8
# 373  38            Crystal Palace         Tottenham Hotspur              31
# 374  38                   Everton               Bournemouth              11
# 375  38            Leicester City         Manchester United              13
# 376  38           Manchester City                   Norwich              43
# 377  38          Newcastle United                 Liverpool               4
# 378  38               Southampton          Sheffield United              20
# 379  38           West Ham United               Aston Villa              21
#
#      away_team_code
# 0                45
# 1                43
# 2                49
# 3                20
# 4                11
# 5                36
# 6                 7
# 7                39
# 8                 3
# 9                 8
# 10               90
# 11               91
# 12               21
# 13               57
# 14                4
# 15               14
# 16                6
# 17               31
# 18               13
# 19                1
# 20               11
# 21                8
# 22               20
# 23               31
# 24               13
# 25               21
# 26               90
# 27                3
# 28               43
# 29                4
# ..              ...
# 350              14
# 351              39
# 352              45
# 353               1
# 354               7
# 355              49
# 356              91
# 357               6
# 358              36
# 359              57
# 360               3
# 361              20
# 362               4
# 363               8
# 364              21
# 365              90
# 366              11
# 367              13
# 368              43
# 369              31
# 370              57
# 371              36
# 372              39
# 373               6
# 374              91
# 375               1
# 376              45
# 377              14
# 378              49
# 379               7
#
# [380 rows x 5 columns]

# %%
home_df = fixtures.merge(all_players, 
               left_on='home_team_code', 
               right_on='team_1920', 
               how='left')

home_df = home_df[['gw', 'home_team', 'away_team', 'full_name', 'position_1920']]
home_df.rename(index=str, 
               columns={'home_team':'team',
                        'away_team':'opponent_team',
                        'full_name':'player',
                        'position_1920':'position'},
              inplace=True)
home_df['was_home'] = True
home_df['season'] = '1920'
home_df['minutes'] = 90
home_df['position'] = home_df['position'].astype(int)

# %%
away_df = fixtures.merge(all_players, 
               left_on='away_team_code', 
               right_on='team_1920', 
               how='left')

away_df = away_df[['gw',  'away_team', 'home_team', 'full_name', 'position_1920']]
away_df.rename(index=str, 
               columns={'away_team':'team',
                        'home_team':'opponent_team',
                        'full_name':'player',
                        'position_1920':'position'},
              inplace=True)
away_df['was_home'] = False
away_df['season'] = '1920'
away_df['minutes'] = 90
away_df['position'] = away_df['position'].astype(int)

# %%
away_df.head()
# Out:
#    gw     team opponent_team              player  position  was_home season  \
# 0   1  Norwich     Liverpool            Tim_Krul         1     False   1920
# 1   1  Norwich     Liverpool        Grant_Hanley         2     False   1920
# 2   1  Norwich     Liverpool          Timm_Klose         2     False   1920
# 3   1  Norwich     Liverpool         Ben_Godfrey         2     False   1920
# 4   1  Norwich     Liverpool  Maximillian_Aarons         2     False   1920
#
#    minutes
# 0       90
# 1       90
# 2       90
# 3       90
# 4       90

# %%
home_df.head()
# Out:
#    gw       team opponent_team                   player  position  was_home  \
# 0   1  Liverpool       Norwich  Alex_Oxlade-Chamberlain         3      True
# 1   1  Liverpool       Norwich         Andrew_Robertson         2      True
# 2   1  Liverpool       Norwich           Simon_Mignolet         1      True
# 3   1  Liverpool       Norwich             Dejan_Lovren         2      True
# 4   1  Liverpool       Norwich             Joseph_Gomez         2      True
#
#   season  minutes
# 0   1920       90
# 1   1920       90
# 2   1920       90
# 3   1920       90
# 4   1920       90

# %%
test_df = home_df.append(away_df).reset_index(drop=True)

# %%
test_df.head()
# Out:
#    gw       team opponent_team                   player  position  was_home  \
# 0   1  Liverpool       Norwich  Alex_Oxlade-Chamberlain         3      True
# 1   1  Liverpool       Norwich         Andrew_Robertson         2      True
# 2   1  Liverpool       Norwich           Simon_Mignolet         1      True
# 3   1  Liverpool       Norwich             Dejan_Lovren         2      True
# 4   1  Liverpool       Norwich             Joseph_Gomez         2      True
#
#   season  minutes
# 0   1920       90
# 1   1920       90
# 2   1920       90
# 3   1920       90
# 4   1920       90

# %%
data = (TabularList.from_df(df_all, path=path, cat_names=cat_vars, cont_names=cont_vars, procs=procs,)
                .split_by_idx(valid_idx)
                .label_from_df(cols=dep_var, label_cls=FloatList)
                .add_test(TabularList.from_df(test_df, path=path, cat_names=cat_vars, cont_names=cont_vars))
                .databunch())

# %%
learn = tabular_learner(data, layers=[1000,500], ps=[0.001,0.01], emb_drop=0.04, 
                        y_range=y_range, metrics=rmse)

# %%
learn.fit_one_cycle(7, 1.1e-2, wd=0.2)
# Out:
# Total time: 00:50 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.869320</td>
#       <td>3.674817</td>
#       <td>1.861629</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.825601</td>
#       <td>3.724636</td>
#       <td>1.880392</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.172987</td>
#       <td>4.042958</td>
#       <td>1.946726</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.748235</td>
#       <td>3.719925</td>
#       <td>1.867813</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.572295</td>
#       <td>3.554706</td>
#       <td>1.834649</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.289519</td>
#       <td>3.505348</td>
#       <td>1.821876</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.164142</td>
#       <td>3.507097</td>
#       <td>1.822886</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>

# %%
test_preds=learn.get_preds(DatasetType.Test)
test_df['predicted_points'] = test_preds[0].data.numpy().T[0]

# %%
test_df.shape
# Out:
# (16074, 9)

# %%
test_df.head(20)
#.sort_values(by='predicted_points', ascending=False)
# Out:
#     gw       team opponent_team                   player  position  was_home  \
# 0    1  Liverpool       Norwich  Alex_Oxlade-Chamberlain         3      True
# 1    1  Liverpool       Norwich         Andrew_Robertson         2      True
# 2    1  Liverpool       Norwich           Simon_Mignolet         1      True
# 3    1  Liverpool       Norwich             Dejan_Lovren         2      True
# 4    1  Liverpool       Norwich             Joseph_Gomez         2      True
# 5    1  Liverpool       Norwich               Joel_Matip         2      True
# 6    1  Liverpool       Norwich         Jordan_Henderson         3      True
# 7    1  Liverpool       Norwich             Adam_Lallana         3      True
# 8    1  Liverpool       Norwich             James_Milner         3      True
# 9    1  Liverpool       Norwich          Roberto_Firmino         4      True
# 10   1  Liverpool       Norwich               Sadio_Mané         3      True
# 11   1  Liverpool       Norwich             Divock_Origi         4      True
# 12   1  Liverpool       Norwich          Virgil_van Dijk         2      True
# 13   1  Liverpool       Norwich          Xherdan_Shaqiri         3      True
# 14   1  Liverpool       Norwich      Georginio_Wijnaldum         3      True
# 15   1  Liverpool       Norwich   Trent_Alexander-Arnold         2      True
# 16   1  Liverpool       Norwich            Mohamed_Salah         3      True
# 17   1  Liverpool       Norwich           Rafael_Camacho         3      True
# 18   1  Liverpool       Norwich   Fabio Henrique_Tavares         3      True
# 19   1  Liverpool       Norwich               Naby_Keita         3      True
#
#    season  minutes  predicted_points
# 0    1920       90          4.399515
# 1    1920       90          5.503911
# 2    1920       90          4.016280
# 3    1920       90          4.712327
# 4    1920       90          5.045530
# 5    1920       90          4.627059
# 6    1920       90          2.718491
# 7    1920       90          5.031825
# 8    1920       90          4.030863
# 9    1920       90          5.379467
# 10   1920       90          6.055552
# 11   1920       90          5.471268
# 12   1920       90          4.693638
# 13   1920       90          5.745436
# 14   1920       90          3.950357
# 15   1920       90          5.166481
# 16   1920       90          7.755748
# 17   1920       90          5.145797
# 18   1920       90          3.364471
# 19   1920       90          3.336928

# %%
test_df.to_csv('predictions.csv', encoding='latin')
