# %%
import pandas as pd
import numpy as np
from pathlib import Path
import math

# %%
# path to project directory
path = Path('./')

# %%
# read in training dataset
train_df = pd.read_csv(path/'data/train_v4.csv', index_col=0, dtype={'season':str})

# %%
# add all lag points scored to training set
train_df = player_lag_features(train_df, ['total_points'], ['all'])

# %%
train_df['season'].iloc[-1]
# Out:
# '1920'

# %%
idx = (78390, 78973, 80156, 82053)

# %%
# train_idx = 
train_df.iloc[list(range(valid_start))]
# Out:
#                            player  gw  position  minutes  \
# 0                 Aaron_Cresswell   1         2        0
# 1                    Aaron_Lennon   1         3       15
# 2                    Aaron_Ramsey   1         3       60
# 3              Abdoulaye_Doucouré   1         3        0
# 4               Abdul Rahman_Baba   1         2        0
# ...                           ...  ..       ...      ...
# 78385                Grant_Hanley  19         2       90
# 78386             Roberto_Pereyra  19         3       45
# 78387              Sead_Kolasinac  19         2        0
# 78388            Stuart_Armstrong  19         3       85
# 78389  Rúben Diogo_da Silva Neves  19         3       90
#
#                           team      opponent_team  relative_market_value_team  \
# 0              West Ham United            Chelsea                         NaN
# 1                      Everton  Tottenham Hotspur                         NaN
# 2                      Arsenal          Liverpool                         NaN
# 3                      Watford        Southampton                         NaN
# 4                      Chelsea    West Ham United                         NaN
# ...                        ...                ...                         ...
# 78385                  Norwich        Aston Villa                    0.295212
# 78386                  Watford   Sheffield United                    0.433797
# 78387                  Arsenal        Bournemouth                    1.413491
# 78388              Southampton            Chelsea                    0.469252
# 78389  Wolverhampton Wanderers    Manchester City                    0.746215
#
#        relative_market_value_opponent_team  was_home  total_points  ...  \
# 0                                      NaN     False             0  ...
# 1                                      NaN      True             1  ...
# 2                                      NaN      True             2  ...
# 3                                      NaN     False             0  ...
# 4                                      NaN      True             0  ...
# ...                                    ...       ...           ...  ...
# 78385                             0.522434     False             2  ...
# 78386                             0.242030     False             1  ...
# 78387                             0.713784     False             0  ...
# 78388                             1.757609     False             3  ...
# 78389                             2.711234      True             5  ...
#
#        transfers_out  yellow_cards          kickoff_time  season  play_proba  \
# 0                  0             0  2016-08-15T19:00:00Z    1617         NaN
# 1                  0             0  2016-08-13T14:00:00Z    1617         NaN
# 2                  0             0  2016-08-14T15:00:00Z    1617         NaN
# 3                  0             0  2016-08-13T14:00:00Z    1617         NaN
# 4                  0             0  2016-08-15T19:00:00Z    1617         NaN
# ...              ...           ...                   ...     ...         ...
# 78385           2441             0  2019-12-26T15:00:00Z    1920         1.0
# 78386            592             0  2019-12-26T15:00:00Z    1920         1.0
# 78387           2566             0  2019-12-26T15:00:00Z    1920         0.0
# 78388             67             0  2019-12-26T15:00:00Z    1920         1.0
# 78389          10811             0  2019-12-27T19:45:00Z    1920         1.0
#
#        relative_market_value_team_season  \
# 0                               0.895471
# 1                               1.057509
# 2                               1.944129
# 3                               0.704200
# 4                               2.243698
# ...                                  ...
# 78385                           0.198300
# 78386                           0.555819
# 78387                           1.448866
# 78388                           0.624210
# 78389                           0.673382
#
#        relative_market_value_opponent_team_season  minutes_last_all  \
# 0                                        2.243698                 0
# 1                                        1.433690                 0
# 2                                        1.465860                 0
# 3                                        0.796805                 0
# 4                                        0.895471                 0
# ...                                           ...               ...
# 78385                                    0.338194               360
# 78386                                    0.150631              6289
# 78387                                    0.687124              4960
# 78388                                    1.798870              1852
# 78389                                    2.727025              4415
#
#        total_points_last_all  total_points_pg_last_all
# 0                          0                       NaN
# 1                          0                       NaN
# 2                          0                       NaN
# 3                          0                       NaN
# 4                          0                       NaN
# ...                      ...                       ...
# 78385                      1                  0.250000
# 78386                    272                  3.892511
# 78387                    216                  3.919355
# 78388                     93                  4.519438
# 78389                    151                  3.078143
#
# [78390 rows x 40 columns]

# %%
def simple_model(df, idx):
    valid_start, valid_end_gw1, valid_end_gw3, valid_end_gw6 = idx
    
    train_idx = range(valid_start)
    valid_idx = range(valid_start, valid_end_gw6)    
    
    train = df.iloc[train_idx]
    valid = df[['player', 'gw', 'season', 'minutes', 'total_points']].iloc[valid_idx]
    
    season_point = valid['season'].iloc[0]
    gw_point = valid['gw'].iloc[0]
    
    # get player total per game average at validation point
    player_points_pg = train_df[(train_df['season'] == season_point) & 
                                (train_df['gw'] == gw_point)][['player', 'total_points_pg_last_all']]
    
    pred_df = valid.merge(player_points_pg, on='player', how='left')   
    pred_df.fillna(0, inplace=True)
    preds = pred_df['total_points_pg_last_all'] * pred_df['minutes'] / 90
    targs = pred_df['total_points']
    
    return preds, targs

# %%
preds, targs = simple_model(train_df, idx)

# %%
# get player total per game average at validation point
player_points_pg = train_df[(train_df['season'] == '1920') & 
                            (train_df['gw'] == 20)][['player', 'total_points_pg_last_all']]

# %%
valid_df = train_df[(train_df['season'] == '1920') 
                    & (train_df['gw'] > 19)
                    & (train_df['gw'] < 26)][['player', 'minutes', 'total_points']]

# %%
pred_df = valid_df.merge(player_points_pg, on='player', how='left')

# %%
pred_df['pred'] = pred_df['total_points_pg_last_all'] * pred_df['minutes'] / 90

# %%
pred_df.fillna(0, inplace=True)

# %%
r_mse(pred_df['pred'], pred_df['total_points'])
# Out:
# 1.904038

# %%
r_mse(preds, targs)
# Out:
# 1.904298

# %%
def r_mse(pred,y): return round(math.sqrt(((pred-y)**2).mean()), 6)

# %%
# player level lag features
def player_lag_features(df, features, lags):    
    df_new = df.copy()
    
    # need minutes for per game stats, add to front of list
    features.insert(0, 'minutes')

    # calculate totals for each lag period
    for feature in features:
        for lag in lags:
            feature_name = feature + '_last_' + str(lag)
            
            if lag == 'all':
                df_new[feature_name] = df_new.groupby(['player'])[feature].apply(lambda x: x.cumsum() - x)
            else: 
                df_new[feature_name] = df_new.groupby(['player'])[feature].apply(lambda x: x.rolling(min_periods=1, 
                                                                                            window=lag+1).sum() - x)
            if feature != 'minutes':
                minute_name = 'minutes_last_' + str(lag)
                pg_feature_name = feature + '_pg_last_' + str(lag)
                
                df_new[pg_feature_name] = 90 * df_new[feature_name] / df_new[minute_name] 
#                 df_new[pg_feature_name] = df_new[pg_feature_name].fillna(0)
                
    return df_new
