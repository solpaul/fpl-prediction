# %%
# import required packages
from fastai.tabular import *

# %%
# path to project directory
path = Path('/home/jupyter/fpl-prediction')

# %%
# read in training dataset
# created using fpl_data_clean notebook
train_df = pd.read_csv(path/'data/train_v3.csv', index_col=0, dtype={'season':str})

# %%
train_df.tail()
# Out:
#                 player  gw  position  minutes               team  \
# 87133      Tommy_Doyle  33         3        0    Manchester City
# 87134     Joseph_Anang  33         1        0    West Ham United
# 87135     Erik_Pieters  33         2       90            Burnley
# 87136  Japhet_Tanganga  33         2        0  Tottenham Hotspur
# 87137   Ravel_Morrison  33         3        0   Sheffield United
#
#           opponent_team  relative_market_value_team  \
# 87133       Southampton                    2.614702
# 87134  Newcastle United                    0.711519
# 87135  Sheffield United                    0.357745
# 87136           Everton                    1.729156
# 87137           Burnley                    0.296744
#
#        relative_market_value_opponent_team  was_home  total_points  \
# 87133                             0.470400     False             0
# 87134                             0.598668     False             0
# 87135                             0.296744      True             2
# 87136                             1.016527      True             0
# 87137                             0.357745     False             0
#
#           ...      team_a_score  team_h_score  threat  transfers_balance  \
# 87133     ...                 0             1     0.0                 27
# 87134     ...                 2             2     0.0                -19
# 87135     ...                 1             1     5.0               9164
# 87136     ...                 0             1     0.0              -8539
# 87137     ...                 1             1     0.0                -14
#
#        transfers_in  transfers_out  yellow_cards          kickoff_time  \
# 87133            35              8             0  2020-07-05T18:00:00Z
# 87134           150            169             0  2020-07-05T13:15:00Z
# 87135         11623           2459             0  2020-07-05T11:00:00Z
# 87136           228           8767             0  2020-07-06T19:00:00Z
# 87137            11             25             0  2020-07-05T11:00:00Z
#
#        season  play_proba
# 87133    1920         1.0
# 87134    1920         1.0
# 87135    1920         1.0
# 87136    1920         0.0
# 87137    1920         0.0
#
# [5 rows x 35 columns]

# %%
# exclude zero minute rows
#train_df = train_df[train_df['minutes'] != 0].reset_index()

# %%
train_df.shape
# Out:
# (87138, 35)

# %%
# find the latest gameweek
last_gw = train_df['gw'][train_df['season'] == '1920'].max()

if np.isnan(last_gw): 
    next_gw = 1 
else: 
    next_gw = last_gw + 1
    
next_gw
# Out:
# 34

# %%
# find validation cut point - index for 18-19 season second half (gw 19)
#valid_start = train_df[(train_df['gw'] > 18) & (train_df['season'] == '1819')].index.min()
# or take validation as same as current prediction set
valid_start = train_df[(train_df['season'] == '1819') & (train_df['gw'] == next_gw)].index.min()
valid_end = train_df[(train_df['season'] == '1920') & (train_df['gw'] == 1)].index.min()
#valid_end = train_df.index.max()

# %%
# check data types
train_df.dtypes
# Out:
# player                                  object
# gw                                       int64
# position                                 int64
# minutes                                  int64
# team                                    object
# opponent_team                           object
# relative_market_value_team             float64
# relative_market_value_opponent_team    float64
# was_home                                  bool
# total_points                             int64
# assists                                  int64
# bonus                                    int64
# bps                                      int64
# clean_sheets                             int64
# creativity                             float64
# goals_conceded                           int64
# goals_scored                             int64
# ict_index                              float64
# influence                              float64
# own_goals                                int64
# penalties_missed                         int64
# penalties_saved                          int64
# red_cards                                int64
# saves                                    int64
# selected                                 int64
# team_a_score                             int64
# team_h_score                             int64
# threat                                 float64
# transfers_balance                        int64
# transfers_in                             int64
# transfers_out                            int64
# yellow_cards                             int64
# kickoff_time                            object
# season                                  object
# play_proba                             float64
# dtype: object

# %%
# set categorical and continuous variables for tabular learner
cat_vars = ['player', 'gw', 'position', 'team', 'opponent_team', 'was_home', 'season']
cont_vars = ['minutes', 'relative_market_value_team', 'relative_market_value_opponent_team']#, 'ppg_total', 'points_last_5']

# %%
# set dependent variable
dep_var = 'total_points'

# %%
# set validation dataset based on indexes calculated earlier
valid_idx = range(valid_start, valid_end)

# %%
# processors - categorify categorical variables and normalize continuous variables
# fill missing not used because new teams are almost certainly well below the league average
procs=[Categorify, Normalize]

# %%
# create databunch
data = (TabularList.from_df(train_df, path=path, cat_names=cat_vars, cont_names=cont_vars, procs=procs,)
                .split_by_idx(valid_idx)
                .label_from_df(cols=dep_var, label_cls=FloatList)
                .databunch())

# %%
# set range of predictions - minimum to current max
max_y = np.max(train_df['total_points'])
min_y = np.min(train_df['total_points'])
y_range = torch.tensor([-1, max_y], device=defaults.device)

# %%
# instatiate tabular learner
learn = tabular_learner(data, layers=[1000,500], ps=[0.001,0.01], emb_drop=0.04, 
                        y_range=y_range, metrics=rmse)

# %%
# take a look at the nueral net architecture
# note that categorical variables all have embeddings (used default embedding sizes)
learn.model
# Out:
# TabularModel(
#   (embeds): ModuleList(
#     (0): Embedding(1270, 88)
#     (1): Embedding(39, 12)
#     (2): Embedding(5, 4)
#     (3): Embedding(30, 11)
#     (4): Embedding(30, 11)
#     (5): Embedding(3, 3)
#     (6): Embedding(5, 4)
#   )
#   (emb_drop): Dropout(p=0.04)
#   (bn_cont): BatchNorm1d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layers): Sequential(
#     (0): Linear(in_features=136, out_features=1000, bias=True)
#     (1): ReLU(inplace)
#     (2): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.001)
#     (4): Linear(in_features=1000, out_features=500, bias=True)
#     (5): ReLU(inplace)
#     (6): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.01)
#     (8): Linear(in_features=500, out_features=1, bias=True)
#   )
# )

# %%
learn.lr_find()

# %%
learn.recorder.plot()

# %%
# no market value, latest half season validation
# learn.fit_one_cycle(3, 1.1e-2, wd=0.2)

# %%
# market value, latest half season validation
# learn.fit_one_cycle(3, 1.5e-3, wd=0.2)
# Out:
# Total time: 00:08 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>10.148968</td>
#       <td>8.108212</td>
#       <td>2.815272</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>7.744442</td>
#       <td>7.921211</td>
#       <td>2.780680</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>6.750823</td>
#       <td>7.586754</td>
#       <td>2.719187</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>

# %%
# no market value, new season validation
# learn.fit_one_cycle(4, 1e-2, wd=0.2)
# Out:
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>8.286838</td>
#       <td>8.456475</td>
#       <td>2.861300</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>7.342739</td>
#       <td>7.591846</td>
#       <td>2.721933</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>7.386149</td>
#       <td>7.513053</td>
#       <td>2.702131</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>6.645412</td>
#       <td>7.562900</td>
#       <td>2.718028</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>

# %%
# CURRENT APPROACH
# market value, new season validation
learn.fit_one_cycle(2, 1e-2, wd=0.2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.137546</td>
#       <td>4.397381</td>
#       <td>2.068236</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.644954</td>
#       <td>3.482495</td>
#       <td>1.807508</td>
#       <td>00:08</td>
#     </tr>
#   </tbody>
# </table>

# %%
# second training run with lower LR
learn.fit_one_cycle(1, 1e-3, wd=0.2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.135233</td>
#       <td>3.473020</td>
#       <td>1.805526</td>
#       <td>00:08</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
# add predictions to the validations set
df_valid = train_df.loc[valid_idx]
df_valid['predicted_points'] = learn.get_preds()[0].data.numpy().T[0]

# %%
# look at one team/gameweek
df_valid[(df_valid['team'] == 'Cardiff City') & (df_valid['opponent_team'] == 'Chelsea')].head(10)
# Out:
# Empty DataFrame
# Columns: [player, gw, position, minutes, team, opponent_team, relative_market_value_team, relative_market_value_opponent_team, was_home, total_points, assists, bonus, bps, clean_sheets, creativity, goals_conceded, goals_scored, ict_index, influence, own_goals, penalties_missed, penalties_saved, red_cards, saves, selected, team_a_score, team_h_score, threat, transfers_balance, transfers_in, transfers_out, yellow_cards, kickoff_time, season, play_proba, predicted_points]
# Index: []
#
# [0 rows x 36 columns]

# %%
# look at top predictions
df_valid.sort_values('predicted_points', ascending=False).head(20)
# Out:
#                        player  gw  position  minutes                     team  \
# 66509           Mohamed_Salah  36         3       90                Liverpool
# 66596              Sadio_Mané  36         3       90                Liverpool
# 65818           Mohamed_Salah  35         3       90                Liverpool
# 66657  Trent_Alexander-Arnold  36         2       87                Liverpool
# 66122        Andrew_Robertson  36         2       90                Liverpool
# 67748           Mohamed_Salah  38         3       90                Liverpool
# 66875             Eden_Hazard  37         3       90                  Chelsea
# 66320           Heung-Min_Son  36         3       90        Tottenham Hotspur
# 65942              Sadio_Mané  35         3       90                Liverpool
# 67457              Danny_Ings  38         4       75              Southampton
# 66154           Bamidele_Alli  36         3       84        Tottenham Hotspur
# 67715         Mason_Greenwood  38         4       90        Manchester United
# 67856           Sergio_Agüero  38         4       90          Manchester City
# 65470             Eden_Hazard  35         3       90                  Chelsea
# 65023           Mohamed_Salah  34         3       89                Liverpool
# 66670         Virgil_van Dijk  36         2       90                Liverpool
# 67836              Sadio_Mané  38         3       90                Liverpool
# 67125           Mohamed_Salah  37         3       72                Liverpool
# 67181            Raúl_Jiménez  37         4       90  Wolverhampton Wanderers
# 66198       Christian_Eriksen  36         3       90        Tottenham Hotspur
#
#                   opponent_team  relative_market_value_team  \
# 66509         Huddersfield Town                    2.177887
# 66596         Huddersfield Town                    2.177887
# 65818              Cardiff City                    2.177887
# 66657         Huddersfield Town                    2.177887
# 66122         Huddersfield Town                    2.177887
# 67748   Wolverhampton Wanderers                    2.177887
# 66875                   Watford                    2.540586
# 66320           West Ham United                    1.983109
# 65942              Cardiff City                    2.177887
# 67457         Huddersfield Town                    0.654624
# 66154           West Ham United                    1.983109
# 67715              Cardiff City                    2.015531
# 67856  Brighton and Hove Albion                    2.540586
# 65470                   Burnley                    2.540586
# 65023                   Chelsea                    2.177887
# 66670         Huddersfield Town                    2.177887
# 67836   Wolverhampton Wanderers                    2.177887
# 67125          Newcastle United                    2.177887
# 67181                    Fulham                    0.388177
# 66198           West Ham United                    1.983109
#
#        relative_market_value_opponent_team  was_home  total_points  \
# 66509                             0.273778      True            19
# 66596                             0.273778      True            13
# 65818                             0.183890     False             6
# 66657                             0.273778      True            10
# 66122                             0.273778      True            14
# 67748                             0.388177      True             3
# 66875                             0.412301      True            11
# 66320                             0.749352      True             2
# 65942                             0.183890     False             3
# 67457                             0.273778      True             5
# 66154                             0.749352      True             2
# 67715                             0.183890      True             2
# 67856                             0.417745     False             6
# 65470                             0.449442      True             7
# 65023                             2.540586      True             8
# 66670                             0.273778      True             6
# 67836                             0.388177      True            15
# 67125                             0.483921     False             7
# 67181                             0.405284      True             2
# 66198                             0.749352      True             2
#
#              ...         team_h_score  threat  transfers_balance  \
# 66509        ...                    5    97.0              71136
# 66596        ...                    5    49.0             168266
# 65818        ...                    0    55.0             -23964
# 66657        ...                    5     0.0             131164
# 66122        ...                    5     6.0              15389
# 67748        ...                    2    63.0            -123436
# 66875        ...                    3    62.0              31623
# 66320        ...                    0    73.0              61077
# 65942        ...                    0    29.0             -18269
# 67457        ...                    1    79.0               8701
# 66154        ...                    0    22.0               1384
# 67715        ...                    0    88.0               5258
# 67856        ...                    1    59.0              93769
# 65470        ...                    2    49.0            -249962
# 65023        ...                    2    89.0            -113549
# 66670        ...                    5     4.0              44242
# 67836        ...                    2    36.0             133596
# 67125        ...                    2    45.0              29206
# 67181        ...                    1    23.0              91026
# 66198        ...                    0    47.0              -6853
#
#        transfers_in  transfers_out  yellow_cards          kickoff_time  \
# 66509         83818          12682             0  2019-04-26T19:00:00Z
# 66596        187216          18950             0  2019-04-26T19:00:00Z
# 65818         33993          57957             0  2019-04-21T15:00:00Z
# 66657        137713           6549             0  2019-04-26T19:00:00Z
# 66122         32054          16665             0  2019-04-26T19:00:00Z
# 67748         35332         158768             0  2019-05-12T14:00:00Z
# 66875         64057          32434             0  2019-05-05T13:00:00Z
# 66320        103969          42892             0  2019-04-27T11:30:00Z
# 65942         64263          82532             0  2019-04-21T15:00:00Z
# 67457         16556           7855             0  2019-05-12T14:00:00Z
# 66154          2667           1283             0  2019-04-27T11:30:00Z
# 67715          6034            776             0  2019-05-12T14:00:00Z
# 67856        112643          18874             0  2019-05-12T14:00:00Z
# 65470         22030         271992             0  2019-04-22T19:00:00Z
# 65023         25100         138649             0  2019-04-14T15:30:00Z
# 66670         51854           7612             0  2019-04-26T19:00:00Z
# 67836        158060          24464             0  2019-05-12T14:00:00Z
# 67125         47369          18163             0  2019-05-04T18:45:00Z
# 67181        108285          17259             0  2019-05-04T14:00:00Z
# 66198         36339          43192             0  2019-04-27T11:30:00Z
#
#        season  play_proba  predicted_points
# 66509    1819         NaN         11.015843
# 66596    1819         NaN          9.414276
# 65818    1819         NaN          8.976044
# 66657    1819         NaN          8.302423
# 66122    1819         NaN          8.169272
# 67748    1819         NaN          8.140009
# 66875    1819         NaN          7.960456
# 66320    1819         NaN          7.594182
# 65942    1819         NaN          7.487764
# 67457    1819         NaN          7.468188
# 66154    1819         NaN          7.308445
# 67715    1819         NaN          7.293280
# 67856    1819         NaN          7.220876
# 65470    1819         NaN          7.217916
# 65023    1819         NaN          7.126965
# 66670    1819         NaN          7.108407
# 67836    1819         NaN          6.920625
# 67125    1819         NaN          6.823535
# 67181    1819         NaN          6.781802
# 66198    1819         NaN          6.738838
#
# [20 rows x 36 columns]

# %%
np.mean(df_valid.sort_values('predicted_points', ascending=False).head(1000)['predicted_points'])
# Out:
# 3.7062597274780273

# %%
prev_pt_mean = np.mean(df_valid.sort_values('predicted_points', ascending=False).head(1000)['total_points'])
prev_pt_mean
# Out:
# 3.755

# %%
## now we have decided training approach, need to apply to remainder of season
# read in remaining_season.csv
remaining_season_df = pd.read_csv(path/'data/remaining_season.csv', index_col=0)

# %%
remaining_season_df.head(50)
#remaining_season_df[remaining_season_df.player == 'Trent_Alexander-Arnold']
# Out:
#     gw         team      opponent_team                            player  \
# 0   34      Arsenal     Leicester City                  Shkodran_Mustafi
# 1   34      Arsenal     Leicester City                   Héctor_Bellerín
# 2   34      Arsenal     Leicester City                    Sead_Kolasinac
# 3   34      Arsenal     Leicester City            Ainsley_Maitland-Niles
# 4   34      Arsenal     Leicester City         Sokratis_Papastathopoulos
# 5   34      Arsenal     Leicester City                     Nacho_Monreal
# 6   34      Arsenal     Leicester City                 Laurent_Koscielny
# 7   34      Arsenal     Leicester City           Konstantinos_Mavropanos
# 8   34      Arsenal     Leicester City                    Carl_Jenkinson
# 9   34      Arsenal     Leicester City                       Rob_Holding
# 10  34      Arsenal     Leicester City         Pierre-Emerick_Aubameyang
# 11  34      Arsenal     Leicester City               Alexandre_Lacazette
# 12  34      Arsenal     Leicester City                    Edward_Nketiah
# 13  34      Arsenal     Leicester City                        Bernd_Leno
# 14  34      Arsenal     Leicester City                        Mesut_Özil
# 15  34      Arsenal     Leicester City                Henrikh_Mkhitaryan
# 16  34      Arsenal     Leicester City                      Granit_Xhaka
# 17  34      Arsenal     Leicester City                    Lucas_Torreira
# 18  34      Arsenal     Leicester City                    Mohamed_Elneny
# 19  34      Arsenal     Leicester City                  Matteo_Guendouzi
# 20  34      Arsenal     Leicester City        David_Luiz Moreira Marinho
# 21  34      Arsenal     Leicester City                 Emiliano_Martínez
# 22  34      Arsenal     Leicester City                    Calum_Chambers
# 23  34      Arsenal     Leicester City         Daniel_Ceballos Fernández
# 24  34      Arsenal     Leicester City                     Cédric_Soares
# 25  34      Arsenal     Leicester City                      Nicolas_Pépé
# 26  34      Arsenal     Leicester City                      Reiss_Nelson
# 27  34      Arsenal     Leicester City                    Joseph_Willock
# 28  34      Arsenal     Leicester City  Gabriel Teodoro_Martinelli Silva
# 29  34      Arsenal     Leicester City                    Kieran_Tierney
# 30  34      Arsenal     Leicester City                       Bukayo_Saka
# 31  34      Arsenal     Leicester City                  Emile_Smith Rowe
# 32  34      Arsenal     Leicester City                Tyreece_John-Jules
# 33  34      Arsenal     Leicester City                        Pablo_Marí
# 34  34      Arsenal     Leicester City                       Zech_Medley
# 35  34      Arsenal     Leicester City                        Matt_Macey
# 36  34      Arsenal     Leicester City                     Matthew_Smith
# 37  34  Aston Villa  Manchester United                 Ahmed_El Mohamady
# 38  34  Aston Villa  Manchester United                     James_Chester
# 39  34  Aston Villa  Manchester United                       Neil_Taylor
# 40  34  Aston Villa  Manchester United                     Kortney_Hause
# 41  34  Aston Villa  Manchester United                   Jonathan_Kodjia
# 42  34  Aston Villa  Manchester United                      Ørjan_Nyland
# 43  34  Aston Villa  Manchester United                   Conor_Hourihane
# 44  34  Aston Villa  Manchester United                     Jack_Grealish
# 45  34  Aston Villa  Manchester United                    Anwar_El Ghazi
# 46  34  Aston Villa  Manchester United                       John_McGinn
# 47  34  Aston Villa  Manchester United                       Andre_Green
# 48  34  Aston Villa  Manchester United                  Birkir_Bjarnason
# 49  34  Aston Villa  Manchester United                      Keinan_Davis
#
#     position  price  play_proba  was_home  relative_market_value_team  \
# 0          2    5.1        1.00      True                    1.484583
# 1          2    5.3        1.00      True                    1.484583
# 2          2    5.2        1.00      True                    1.484583
# 3          2    4.5        1.00      True                    1.484583
# 4          2    4.8        1.00      True                    1.484583
# 5          2    5.0        0.00      True                    1.484583
# 6          2    5.0        0.00      True                    1.484583
# 7          2    4.3        0.00      True                    1.484583
# 8          2    4.5        0.00      True                    1.484583
# 9          2    4.4        1.00      True                    1.484583
# 10         4   10.9        1.00      True                    1.484583
# 11         4    9.2        1.00      True                    1.484583
# 12         4    4.4        1.00      True                    1.484583
# 13         1    4.8        0.00      True                    1.484583
# 14         3    7.0        0.75      True                    1.484583
# 15         3    6.7        0.00      True                    1.484583
# 16         3    5.1        1.00      True                    1.484583
# 17         3    4.7        1.00      True                    1.484583
# 18         3    4.2        0.00      True                    1.484583
# 19         3    4.2        1.00      True                    1.484583
# 20         2    5.7        1.00      True                    1.484583
# 21         1    4.3        1.00      True                    1.484583
# 22         2    4.3        0.00      True                    1.484583
# 23         3    5.2        1.00      True                    1.484583
# 24         2    4.8        1.00      True                    1.484583
# 25         3    9.0        1.00      True                    1.484583
# 26         3    5.3        1.00      True                    1.484583
# 27         3    4.7        1.00      True                    1.484583
# 28         4    4.3        0.00      True                    1.484583
# 29         2    5.3        1.00      True                    1.484583
# 30         3    4.7        1.00      True                    1.484583
# 31         3    4.3        0.00      True                    1.484583
# 32         4    4.4        0.00      True                    1.484583
# 33         2    4.5        0.00      True                    1.484583
# 34         2    4.0        1.00      True                    1.484583
# 35         1    4.0        1.00      True                    1.484583
# 36         2    4.0        1.00      True                    1.484583
# 37         2    4.1        1.00      True                    0.528490
# 38         2    4.2        0.00      True                    0.528490
# 39         2    4.2        1.00      True                    0.528490
# 40         2    4.4        1.00      True                    0.528490
# 41         4    5.4        0.00      True                    0.528490
# 42         1    4.3        1.00      True                    0.528490
# 43         3    5.7        1.00      True                    0.528490
# 44         3    6.0        1.00      True                    0.528490
# 45         3    5.3        1.00      True                    0.528490
# 46         3    5.3        1.00      True                    0.528490
# 47         3    4.8        0.00      True                    0.528490
# 48         3    4.5        0.00      True                    0.528490
# 49         3    4.3        1.00      True                    0.528490
#
#     relative_market_value_opponent_team  season    minutes
# 0                              1.036260    1920  81.000000
# 1                              1.036260    1920  60.166667
# 2                              1.036260    1920  58.000000
# 3                              1.036260    1920  11.166667
# 4                              1.036260    1920  18.000000
# 5                              1.036260    1920   0.000000
# 6                              1.036260    1920   0.000000
# 7                              1.036260    1920   0.000000
# 8                              1.036260    1920   0.000000
# 9                              1.036260    1920  37.500000
# 10                             1.036260    1920  88.500000
# 11                             1.036260    1920  37.333333
# 12                             1.036260    1920  51.666667
# 13                             1.036260    1920   0.000000
# 14                             1.036260    1920  13.200000
# 15                             1.036260    1920   0.000000
# 16                             1.036260    1920  55.400000
# 17                             1.036260    1920   2.333333
# 18                             1.036260    1920   0.000000
# 19                             1.036260    1920  26.000000
# 20                             1.036260    1920  59.000000
# 21                             1.036260    1920  53.333333
# 22                             1.036260    1920   0.000000
# 23                             1.036260    1920  84.833333
# 24                             1.036260    1920  25.000000
# 25                             1.036260    1920  37.500000
# 26                             1.036260    1920  17.333333
# 27                             1.036260    1920  23.500000
# 28                             1.036260    1920   0.000000
# 29                             1.036260    1920  61.400000
# 30                             1.036260    1920  71.833333
# 31                             1.036260    1920   0.000000
# 32                             1.036260    1920   0.000000
# 33                             1.036260    1920   0.000000
# 34                             1.036260    1920   0.000000
# 35                             1.036260    1920   0.000000
# 36                             1.036260    1920   0.000000
# 37                             1.627232    1920  19.833333
# 38                             1.627232    1920   0.000000
# 39                             1.627232    1920  28.166667
# 40                             1.627232    1920  75.000000
# 41                             1.627232    1920   0.000000
# 42                             1.627232    1920  60.000000
# 43                             1.627232    1920  50.666667
# 44                             1.627232    1920  90.000000
# 45                             1.627232    1920  52.333333
# 46                             1.627232    1920  71.400000
# 47                             1.627232    1920   0.000000
# 48                             1.627232    1920   0.000000
# 49                             1.627232    1920  53.500000

# %%
# create new databunch, with remaining season as test set
# and using all available data i.e. no validation
data = (TabularList.from_df(train_df, path=path, cat_names=cat_vars, cont_names=cont_vars, procs=procs,)
                .split_none()
                .label_from_df(cols=dep_var, label_cls=FloatList)
                .add_test(TabularList.from_df(remaining_season_df, path=path, cat_names=cat_vars, cont_names=cont_vars))
                .databunch())

# %%
# instatiate new tabular learner
# learn = tabular_learner(data, layers=[1000,500], ps=[0.001,0.01], emb_drop=0.04, 
#                         y_range=y_range, metrics=rmse)

# %%
# train as before
# learn.fit_one_cycle(2, 1e-2, wd=0.2)

# %%
# learn.fit_one_cycle(1, 1e-3, wd=0.2)

# %%
# get predictions
# test_preds=learn.get_preds(DatasetType.Test)
# remaining_season_df['predicted_points'] = test_preds[0].data.numpy().T[0]

# %%
# check mean of top predictions to see if it's reasonably close to previous season's actuals
# re-run if not - not ideal but at the moment the training often over-predicts top players
# pred_pt_mean = np.mean(remaining_season_df.sort_values('predicted_points', ascending=False).head(1000)['predicted_points'])
# pred_pt_mean

# %%
while True:
    # instatiate new tabular learner
    learn = tabular_learner(data, layers=[1000,500], ps=[0.001,0.01], emb_drop=0.04, 
                            y_range=y_range, metrics=rmse)
    
    # train as before
    learn.fit_one_cycle(2, 1e-2, wd=0.2)
    learn.fit_one_cycle(1, 1e-3, wd=0.2)

    # get predictions
    test_preds=learn.get_preds(DatasetType.Test)
    remaining_season_df['predicted_points'] = test_preds[0].data.numpy().T[0]
    
    # check mean of top predictions to see if it's reasonably close to previous season's actuals
    # re-run if not - not ideal but at the moment the training often over-predicts top players
    pred_pt_mean = np.mean(remaining_season_df.sort_values('predicted_points', ascending=False).head(1000)['predicted_points'])
    
    if abs((prev_pt_mean - pred_pt_mean) / prev_pt_mean) < 0.15:
        print("Mean of top 1000 predictions: {:.4}".format(pred_pt_mean))
        break
    else:
        print("{:.4}...retraining...".format(pred_pt_mean))
# Out:
# Mean of top 1000 predictions: 3.26

# %%
remaining_season_df.shape
# Out:
# (3260, 13)

# %%
# quick look
remaining_season_df.sort_values(by='predicted_points', ascending=False).head(20)
# Out:
#       gw               team             opponent_team  \
# 1309  38            Arsenal                   Watford
# 432   35          Liverpool                   Burnley
# 1500  38    Manchester City                   Norwich
# 1136  37  Manchester United           West Ham United
# 431   35          Liverpool                   Burnley
# 3177  38          Liverpool          Newcastle United
# 1501  38    Manchester City                   Norwich
# 2618  37            Arsenal               Aston Villa
# 1737  34          Liverpool  Brighton and Hove Albion
# 3176  38          Liverpool          Newcastle United
# 1689  34  Manchester United               Aston Villa
# 1084  37          Liverpool                   Chelsea
# 1736  34          Liverpool  Brighton and Hove Albion
# 484   35  Manchester United               Southampton
# 778   36            Everton               Aston Villa
# 1083  37          Liverpool                   Chelsea
# 2297  36          Liverpool                   Arsenal
# 733   36            Chelsea                   Norwich
# 848   36    Manchester City               Bournemouth
# 10    34            Arsenal            Leicester City
#
#                              player  position  price  play_proba  was_home  \
# 1309      Pierre-Emerick_Aubameyang         4   10.9         1.0      True
# 432                      Sadio_Mané         3   12.4         1.0      True
# 1500                Raheem_Sterling         3   11.7         1.0      True
# 1136  Bruno Miguel_Borges Fernandes         3    8.9         1.0      True
# 431                   Mohamed_Salah         3   12.6         1.0      True
# 3177                     Sadio_Mané         3   12.4         1.0     False
# 1501                Kevin_De Bruyne         3   10.8         1.0      True
# 2618      Pierre-Emerick_Aubameyang         4   10.9         1.0     False
# 1737                     Sadio_Mané         3   12.4         1.0     False
# 3176                  Mohamed_Salah         3   12.6         1.0     False
# 1689  Bruno Miguel_Borges Fernandes         3    8.9         1.0     False
# 1084                     Sadio_Mané         3   12.4         1.0      True
# 1736                  Mohamed_Salah         3   12.6         1.0     False
# 484   Bruno Miguel_Borges Fernandes         3    8.9         1.0      True
# 778                     Lucas_Digne         2    5.7         1.0      True
# 1083                  Mohamed_Salah         3   12.6         1.0      True
# 2297                     Sadio_Mané         3   12.4         1.0     False
# 733               Christian_Pulisic         3    7.2         1.0      True
# 848                 Raheem_Sterling         3   11.7         1.0      True
# 10        Pierre-Emerick_Aubameyang         4   10.9         1.0      True
#
#       relative_market_value_team  relative_market_value_opponent_team  season  \
# 1309                    1.484583                             0.476394    1920
# 432                     2.432042                             0.357745    1920
# 1500                    2.614702                             0.332832    1920
# 1136                    1.627232                             0.711519    1920
# 431                     2.432042                             0.357745    1920
# 3177                    2.432042                             0.598668    1920
# 1501                    2.614702                             0.332832    1920
# 2618                    1.484583                             0.528490    1920
# 1737                    2.432042                             0.478786    1920
# 3176                    2.432042                             0.598668    1920
# 1689                    1.627232                             0.528490    1920
# 1084                    2.432042                             2.047361    1920
# 1736                    2.432042                             0.478786    1920
# 484                     1.627232                             0.470400    1920
# 778                     1.016527                             0.528490    1920
# 1083                    2.432042                             2.047361    1920
# 2297                    2.432042                             1.484583    1920
# 733                     2.047361                             0.332832    1920
# 848                     2.614702                             0.608362    1920
# 10                      1.484583                             1.036260    1920
#
#         minutes  predicted_points
# 1309  88.500000          8.112929
# 432   87.400000          7.689050
# 1500  67.666667          7.637456
# 1136  81.800000          7.399767
# 431   72.000000          7.247955
# 3177  87.400000          7.171623
# 1501  61.800000          7.053588
# 2618  88.500000          6.949062
# 1737  87.400000          6.944948
# 3176  72.000000          6.877630
# 1689  81.800000          6.782131
# 1084  87.400000          6.687973
# 1736  72.000000          6.610323
# 484   81.800000          6.575152
# 778   90.000000          6.437805
# 1083  72.000000          6.418960
# 2297  87.400000          6.408188
# 733   76.250000          6.347435
# 848   67.666667          6.326332
# 10    88.500000          6.223283

# %%
# rename previous week's predictions file
# generate previous week's filename
last_gw = next_gw - 1
filename = 'predictions_gw' + str(last_gw) + '.csv'
! mv predictions.csv $filename

# %%
# write to predictions.csv
## RENAME PREVIOUS WEEK FIRST
predictions = remaining_season_df[['gw', 'player', 'team', 'position', 'price', 'play_proba', 'predicted_points']]
predictions.to_csv('predictions.csv')
