# %%
# import required packages
from fastai.tabular import *

# %%
# path to project directory
path = Path('/home/jupyter/fpl-prediction')

# %%
# read in training dataset
# created using fpl_data_clean notebook
train_df = pd.read_csv(path/'data/train.csv', index_col=0, dtype={'season':str})

# %%
train_df.head(10)
# Out:
#                player  gw  position  minutes             team  \
# 0     Aaron_Cresswell   1         2        0  West Ham United
# 1        Aaron_Lennon   1         3       15          Everton
# 2        Aaron_Ramsey   1         3       60          Arsenal
# 3  Abdoulaye_Doucouré   1         3        0          Watford
# 4   Abdul Rahman_Baba   1         2        0          Chelsea
# 5      Abel_Hernández   1         4       90        Hull City
# 6      Adama_Diomande   1         4       90        Hull City
# 7        Adam_Clayton   1         3       90    Middlesbrough
# 8       Adam_Federici   1         1        0      Bournemouth
# 9        Adam_Forshaw   1         3       69    Middlesbrough
#
#        opponent_team  relative_market_value_team  \
# 0            Chelsea                    0.895471
# 1  Tottenham Hotspur                    1.057509
# 2          Liverpool                    1.944129
# 3        Southampton                    0.704200
# 4    West Ham United                    2.243698
# 5     Leicester City                    0.494447
# 6     Leicester City                    0.494447
# 7         Stoke City                    0.452793
# 8  Manchester United                    0.384921
# 9         Stoke City                    0.452793
#
#    relative_market_value_opponent_team  was_home  total_points season
# 0                             2.243698     False             0   1617
# 1                             1.433690      True             1   1617
# 2                             1.465860      True             2   1617
# 3                             0.796805     False             0   1617
# 4                             0.895471      True             0   1617
# 5                             0.650832      True             5   1617
# 6                             0.650832      True             8   1617
# 7                             0.718705      True             2   1617
# 8                             1.983179      True             0   1617
# 9                             0.718705      True             1   1617

# %%
train_df.shape
# Out:
# (67936, 11)

# %%
# find validation cut point - index for 18-19 season second half (gw 19)
valid_start = train_df[(train_df['gw'] > 18) & (train_df['season'] == '1819')].index.min()
#valid_start = train_df[(train_df['season'] == '1819')].index.min()
valid_end = train_df.index.max()

# %%
# check data types
train_df.dtypes
# Out:
# player                                  object
# gw                                       int64
# position                                 int64
# minutes                                  int64
# team                                    object
# opponent_team                           object
# relative_market_value_team             float64
# relative_market_value_opponent_team    float64
# was_home                                  bool
# total_points                             int64
# season                                  object
# dtype: object

# %%
# set categorical and continuous variables for tabular learner
cat_vars = ['player', 'gw', 'position', 'team', 'opponent_team', 'was_home', 'season']
cont_vars = ['minutes', 'relative_market_value_team', 'relative_market_value_opponent_team']

# %%
# set dependent variable
dep_var = 'total_points'

# %%
# set validation dataset based on indexes calculated earlier
valid_idx = range(valid_start, valid_end)

# %%
# processors - categorify categorical variables and normalize continuous variables
# fill missing not used because new teams are almost certainly well below the league average
procs=[Categorify, Normalize]

# %%
# create databunch
data = (TabularList.from_df(train_df, path=path, cat_names=cat_vars, cont_names=cont_vars, procs=procs,)
                .split_by_idx(valid_idx)
                .label_from_df(cols=dep_var, label_cls=FloatList)
                .databunch())

# %%
# set range of predictions - 0 to current 1.1 times current max
max_y = np.max(train_df['total_points'])*1.1
y_range = torch.tensor([0, max_y], device=defaults.device)

# %%
# instatiate tabular learner
learn = tabular_learner(data, layers=[1000,500], ps=[0.001,0.01], emb_drop=0.04, 
                        y_range=y_range, metrics=rmse)

# %%
# take a look at the nueral net architecture
# note that categorical variables all have embeddings (used default embedding sizes)
learn.model
# Out:
# TabularModel(
#   (embeds): ModuleList(
#     (0): Embedding(1055, 79)
#     (1): Embedding(39, 12)
#     (2): Embedding(5, 4)
#     (3): Embedding(27, 10)
#     (4): Embedding(27, 10)
#     (5): Embedding(3, 3)
#     (6): Embedding(4, 3)
#   )
#   (emb_drop): Dropout(p=0.04)
#   (bn_cont): BatchNorm1d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layers): Sequential(
#     (0): Linear(in_features=124, out_features=1000, bias=True)
#     (1): ReLU(inplace)
#     (2): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.001)
#     (4): Linear(in_features=1000, out_features=500, bias=True)
#     (5): ReLU(inplace)
#     (6): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.01)
#     (8): Linear(in_features=500, out_features=1, bias=True)
#   )
# )

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
# no market value, latest half season validation
learn.fit_one_cycle(7, 1.1e-2, wd=0.2)
# Out:
# Total time: 00:40 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.671103</td>
#       <td>4.058165</td>
#       <td>1.975258</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.023581</td>
#       <td>4.245531</td>
#       <td>1.991781</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.069503</td>
#       <td>4.208030</td>
#       <td>1.985547</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.735965</td>
#       <td>4.595274</td>
#       <td>2.119409</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.585393</td>
#       <td>3.877654</td>
#       <td>1.932921</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.206583</td>
#       <td>3.711629</td>
#       <td>1.876884</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.050195</td>
#       <td>3.812535</td>
#       <td>1.910187</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
# market value, latest half season validation
learn.fit_one_cycle(4, 1e-2, wd=0.2)
# Out:
# Total time: 00:25 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.032480</td>
#       <td>4.725388</td>
#       <td>2.104817</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.830288</td>
#       <td>3.971875</td>
#       <td>1.929598</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.588023</td>
#       <td>3.556929</td>
#       <td>1.833755</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.255609</td>
#       <td>3.519153</td>
#       <td>1.826030</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>

# %%
# no market value, new season validation
learn.fit_one_cycle(7, 1.1e-2, wd=0.2)
# Out:
# Total time: 00:38 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.190550</td>
#       <td>6.135087</td>
#       <td>2.440161</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.857543</td>
#       <td>3.978027</td>
#       <td>1.933421</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.710502</td>
#       <td>3.876259</td>
#       <td>1.927505</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.443164</td>
#       <td>3.826964</td>
#       <td>1.915945</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.446122</td>
#       <td>3.713155</td>
#       <td>1.877538</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.098882</td>
#       <td>3.761742</td>
#       <td>1.897482</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.939469</td>
#       <td>3.802439</td>
#       <td>1.905856</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
# market value, new season validation
learn.fit_one_cycle(7, 1.1e-2, wd=0.2)
# Out:
# Total time: 00:38 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.974407</td>
#       <td>3.883185</td>
#       <td>1.914001</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.753403</td>
#       <td>4.662024</td>
#       <td>2.126512</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.625479</td>
#       <td>3.772259</td>
#       <td>1.889259</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.840882</td>
#       <td>3.775510</td>
#       <td>1.897972</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.616885</td>
#       <td>3.812484</td>
#       <td>1.901750</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.309392</td>
#       <td>3.734806</td>
#       <td>1.886369</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.903124</td>
#       <td>3.771559</td>
#       <td>1.897273</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
# add predictions to the validations set
df_valid = train_df.loc[valid_idx]
df_valid['predicted_points'] = learn.get_preds()[0].data.numpy().T[0]

# %%
# look at one team/gameweek
df_valid[(df_valid['team'] == 'Cardiff City') & (df_valid['opponent_team'] == 'Chelsea')].head(10)
# Out:
#                            player  gw  position  minutes          team  \
# 63316               Alex_Smithies  32         1        0  Cardiff City
# 63354          Anthony_Pilkington  32         3        0  Cardiff City
# 63363             Aron_Gunnarsson  32         3       90  Cardiff City
# 63367  Ashley Darel Jazz_Richards  32         2        0  Cardiff City
# 63408                  Bobby_Reid  32         4        0  Cardiff City
# 63414                Brian_Murphy  32         1        0  Cardiff City
# 63418          Bruno_Ecuele Manga  32         2       90  Cardiff City
# 63425             Callum_Paterson  32         3        0  Cardiff City
# 63493                Danny_Ward_2  32         3        0  Cardiff City
# 63503        David Junior_Hoilett  32         3       90  Cardiff City
#
#       opponent_team  relative_market_value_team  \
# 63316       Chelsea                     0.18389
# 63354       Chelsea                     0.18389
# 63363       Chelsea                     0.18389
# 63367       Chelsea                     0.18389
# 63408       Chelsea                     0.18389
# 63414       Chelsea                     0.18389
# 63418       Chelsea                     0.18389
# 63425       Chelsea                     0.18389
# 63493       Chelsea                     0.18389
# 63503       Chelsea                     0.18389
#
#        relative_market_value_opponent_team  was_home  total_points season  \
# 63316                             2.540586      True             0   1819
# 63354                             2.540586      True             0   1819
# 63363                             2.540586      True             1   1819
# 63367                             2.540586      True             0   1819
# 63408                             2.540586      True             0   1819
# 63414                             2.540586      True             0   1819
# 63418                             2.540586      True             1   1819
# 63425                             2.540586      True             0   1819
# 63493                             2.540586      True             0   1819
# 63503                             2.540586      True             2   1819
#
#        predicted_points
# 63316          0.148682
# 63354          0.122390
# 63363          2.570295
# 63367          0.146987
# 63408          0.228783
# 63414          0.164977
# 63418          1.362040
# 63425          0.226511
# 63493          0.149529
# 63503          3.274357

# %%
# look at top predictions
df_valid.sort_values('predicted_points', ascending=False).head(20)
# Out:
#                           player  gw  position  minutes               team  \
# 66509              Mohamed_Salah  36         3       90          Liverpool
# 63182              Mohamed_Salah  31         3       90          Liverpool
# 63593  Gabriel Fernando_de Jesus  32         4       90    Manchester City
# 58652              Mohamed_Salah  23         3       90          Liverpool
# 61572              Mohamed_Salah  28         3       90          Liverpool
# 60486              Mohamed_Salah  26         3       90          Liverpool
# 56366              Mohamed_Salah  19         3       90          Liverpool
# 63982            Raheem_Sterling  32         3       87    Manchester City
# 63486       Danilo Luiz_da Silva  32         2       90    Manchester City
# 59235              Mohamed_Salah  24         3       90          Liverpool
# 63995               Riyad_Mahrez  32         3       90    Manchester City
# 62786              Mohamed_Salah  30         3       90          Liverpool
# 58753              Sergio_Agüero  23         4       90    Manchester City
# 61676              Sergio_Agüero  28         4       84    Manchester City
# 63628              Heung-Min_Son  32         3       90  Tottenham Hotspur
# 56934              Mohamed_Salah  20         3       90          Liverpool
# 63621                 Harry_Kane  32         4       90  Tottenham Hotspur
# 57545  Pierre-Emerick_Aubameyang  21         4       90            Arsenal
# 63772            Kevin_De Bruyne  32         3       90    Manchester City
# 58701            Raheem_Sterling  23         3       90    Manchester City
#
#            opponent_team  relative_market_value_team  \
# 66509  Huddersfield Town                    2.177887
# 63182             Fulham                    2.177887
# 63593       Cardiff City                    2.540586
# 58652     Crystal Palace                    2.177887
# 61572            Watford                    2.177887
# 60486        Bournemouth                    2.177887
# 56366   Newcastle United                    2.177887
# 63982             Fulham                    2.540586
# 63486       Cardiff City                    2.540586
# 59235     Leicester City                    2.177887
# 63995       Cardiff City                    2.540586
# 62786            Burnley                    2.177887
# 58753  Huddersfield Town                    2.540586
# 61676    West Ham United                    2.540586
# 63628     Crystal Palace                    1.983109
# 56934            Arsenal                    2.177887
# 63621     Crystal Palace                    1.983109
# 57545             Fulham                    1.435552
# 63772       Cardiff City                    2.540586
# 58701  Huddersfield Town                    2.540586
#
#        relative_market_value_opponent_team  was_home  total_points season  \
# 66509                             0.273778      True            19   1819
# 63182                             0.405284     False             2   1819
# 63593                             0.183890      True             5   1819
# 58652                             0.634856      True            15   1819
# 61572                             0.412301      True             3   1819
# 60486                             0.418108      True             8   1819
# 56366                             0.483921      True            12   1819
# 63982                             0.405284     False             3   1819
# 63486                             0.183890      True             8   1819
# 59235                             0.796050      True             2   1819
# 63995                             0.183890      True             3   1819
# 62786                             0.449442      True             5   1819
# 58753                             0.273778     False             5   1819
# 61676                             0.749352      True             9   1819
# 63628                             0.634856      True            10   1819
# 56934                             1.435552      True            12   1819
# 63621                             0.634856      True             2   1819
# 57545                             0.405284      True             9   1819
# 63772                             0.183890      True            11   1819
# 58701                             0.273778     False            10   1819
#
#        predicted_points
# 66509          9.141500
# 63182          8.932616
# 63593          8.788439
# 58652          8.704599
# 61572          8.572733
# 60486          8.548874
# 56366          8.417863
# 63982          8.373673
# 63486          8.250161
# 59235          8.202671
# 63995          8.169096
# 62786          8.131118
# 58753          8.125011
# 61676          8.056474
# 63628          8.048368
# 56934          8.013070
# 63621          7.993508
# 57545          7.953502
# 63772          7.896030
# 58701          7.855867

# %%
np.mean(df_valid.sort_values('predicted_points', ascending=False).head(100)['predicted_points'])
# Out:
# 7.420433521270752

# %%
np.mean(df_valid.sort_values('predicted_points', ascending=False).head(100)['total_points'])
# Out:
# 6.92

# %%
## now we have decided training approach, need to apply to remainder of season
# read in remaining_season.csv
remaining_season_df = pd.read_csv(path/'data/remaining_season.csv', index_col=0)

# %%
remaining_season_df.head(10)
# Out:
#    gw       team opponent_team                   player  position  price  \
# 0   1  Liverpool       Norwich  Alex_Oxlade-Chamberlain         3    6.5
# 1   1  Liverpool       Norwich         Andrew_Robertson         2    7.0
# 2   1  Liverpool       Norwich           Simon_Mignolet         1    4.5
# 3   1  Liverpool       Norwich             Dejan_Lovren         2    5.5
# 4   1  Liverpool       Norwich             Joseph_Gomez         2    5.5
# 5   1  Liverpool       Norwich               Joel_Matip         2    5.5
# 6   1  Liverpool       Norwich         Jordan_Henderson         3    5.5
# 7   1  Liverpool       Norwich             Adam_Lallana         3    6.0
# 8   1  Liverpool       Norwich             James_Milner         3    5.5
# 9   1  Liverpool       Norwich          Roberto_Firmino         4    9.5
#
#    was_home  relative_market_value_team  relative_market_value_opponent_team  \
# 0      True                    2.430207                             0.190403
# 1      True                    2.430207                             0.190403
# 2      True                    2.430207                             0.190403
# 3      True                    2.430207                             0.190403
# 4      True                    2.430207                             0.190403
# 5      True                    2.430207                             0.190403
# 6      True                    2.430207                             0.190403
# 7      True                    2.430207                             0.190403
# 8      True                    2.430207                             0.190403
# 9      True                    2.430207                             0.190403
#
#    season  minutes
# 0    1920       90
# 1    1920       90
# 2    1920       90
# 3    1920       90
# 4    1920       90
# 5    1920       90
# 6    1920       90
# 7    1920       90
# 8    1920       90
# 9    1920       90

# %%
# create new databunch, including remaining season as test set
data = (TabularList.from_df(train_df, path=path, cat_names=cat_vars, cont_names=cont_vars, procs=procs,)
                .split_by_idx(valid_idx)
                .label_from_df(cols=dep_var, label_cls=FloatList)
                .add_test(TabularList.from_df(remaining_season_df, path=path, cat_names=cat_vars, cont_names=cont_vars))
                .databunch())

# %%
# instatiate new tabular learner
learn = tabular_learner(data, layers=[1000,500], ps=[0.001,0.01], emb_drop=0.04, 
                        y_range=y_range, metrics=rmse)

# %%
# train as before
learn.fit_one_cycle(4, 1e-2, wd=0.2)
# Out:
# Total time: 00:26 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.129379</td>
#       <td>4.133836</td>
#       <td>1.967832</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.327464</td>
#       <td>3.715800</td>
#       <td>1.878311</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.510802</td>
#       <td>3.564620</td>
#       <td>1.834917</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.290228</td>
#       <td>3.495810</td>
#       <td>1.816640</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>

# %%
# get predictions
test_preds=learn.get_preds(DatasetType.Test)
remaining_season_df['predicted_points'] = test_preds[0].data.numpy().T[0]

# %%
remaining_season_df.shape
# Out:
# (16074, 12)

# %%
# quick look
remaining_season_df.head(20)
#.sort_values(by='predicted_points', ascending=False)
# Out:
#     gw       team opponent_team                   player  position  price  \
# 0    1  Liverpool       Norwich  Alex_Oxlade-Chamberlain         3    6.5
# 1    1  Liverpool       Norwich         Andrew_Robertson         2    7.0
# 2    1  Liverpool       Norwich           Simon_Mignolet         1    4.5
# 3    1  Liverpool       Norwich             Dejan_Lovren         2    5.5
# 4    1  Liverpool       Norwich             Joseph_Gomez         2    5.5
# 5    1  Liverpool       Norwich               Joel_Matip         2    5.5
# 6    1  Liverpool       Norwich         Jordan_Henderson         3    5.5
# 7    1  Liverpool       Norwich             Adam_Lallana         3    6.0
# 8    1  Liverpool       Norwich             James_Milner         3    5.5
# 9    1  Liverpool       Norwich          Roberto_Firmino         4    9.5
# 10   1  Liverpool       Norwich               Sadio_Mané         3   11.5
# 11   1  Liverpool       Norwich             Divock_Origi         4    5.5
# 12   1  Liverpool       Norwich          Virgil_van Dijk         2    6.5
# 13   1  Liverpool       Norwich          Xherdan_Shaqiri         3    6.5
# 14   1  Liverpool       Norwich      Georginio_Wijnaldum         3    5.5
# 15   1  Liverpool       Norwich   Trent_Alexander-Arnold         2    7.0
# 16   1  Liverpool       Norwich            Mohamed_Salah         3   12.5
# 17   1  Liverpool       Norwich           Rafael_Camacho         3    4.5
# 18   1  Liverpool       Norwich   Fabio Henrique_Tavares         3    5.5
# 19   1  Liverpool       Norwich               Naby_Keita         3    6.0
#
#     was_home  relative_market_value_team  relative_market_value_opponent_team  \
# 0       True                    2.430207                             0.190403
# 1       True                    2.430207                             0.190403
# 2       True                    2.430207                             0.190403
# 3       True                    2.430207                             0.190403
# 4       True                    2.430207                             0.190403
# 5       True                    2.430207                             0.190403
# 6       True                    2.430207                             0.190403
# 7       True                    2.430207                             0.190403
# 8       True                    2.430207                             0.190403
# 9       True                    2.430207                             0.190403
# 10      True                    2.430207                             0.190403
# 11      True                    2.430207                             0.190403
# 12      True                    2.430207                             0.190403
# 13      True                    2.430207                             0.190403
# 14      True                    2.430207                             0.190403
# 15      True                    2.430207                             0.190403
# 16      True                    2.430207                             0.190403
# 17      True                    2.430207                             0.190403
# 18      True                    2.430207                             0.190403
# 19      True                    2.430207                             0.190403
#
#     season  minutes  predicted_points
# 0     1920       90          4.572116
# 1     1920       90          6.481074
# 2     1920       90          4.449578
# 3     1920       90          5.288513
# 4     1920       90          5.319177
# 5     1920       90          4.661710
# 6     1920       90          2.981629
# 7     1920       90          5.033906
# 8     1920       90          4.684102
# 9     1920       90          5.963749
# 10    1920       90          7.300383
# 11    1920       90          5.799222
# 12    1920       90          4.794802
# 13    1920       90          6.578553
# 14    1920       90          4.065099
# 15    1920       90          5.413446
# 16    1920       90          8.992106
# 17    1920       90          5.262002
# 18    1920       90          4.266851
# 19    1920       90          3.813422

# %%
# write to predictions.csv
predictions = remaining_season_df[['gw', 'player', 'team', 'position', 'price', 'predicted_points']]
predictions.to_csv('predictions.csv')
