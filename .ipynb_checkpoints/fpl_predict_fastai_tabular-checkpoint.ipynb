# %%
# import required packages
from fastai.tabular import *

# %%
# path to project directory
path = Path('/home/jupyter/fpl-prediction')

# %%
# read in training dataset
# created using fpl_data_clean notebook
train_df = pd.read_csv(path/'data/train.csv', index_col=0, dtype={'season':str})

# %%
train_df.head(10)
# Out:
#                player  gw  position  minutes             team  \
# 0     Aaron_Cresswell   1         2        0  West Ham United
# 1        Aaron_Lennon   1         3       15          Everton
# 2        Aaron_Ramsey   1         3       60          Arsenal
# 3  Abdoulaye_Doucouré   1         3        0          Watford
# 4   Abdul Rahman_Baba   1         2        0          Chelsea
# 5      Abel_Hernández   1         4       90        Hull City
# 6      Adama_Diomande   1         4       90        Hull City
# 7        Adam_Clayton   1         3       90    Middlesbrough
# 8       Adam_Federici   1         1        0      Bournemouth
# 9        Adam_Forshaw   1         3       69    Middlesbrough
#
#        opponent_team  relative_market_value_team  \
# 0            Chelsea                    0.895471
# 1  Tottenham Hotspur                    1.057509
# 2          Liverpool                    1.944129
# 3        Southampton                    0.704200
# 4    West Ham United                    2.243698
# 5     Leicester City                    0.494447
# 6     Leicester City                    0.494447
# 7         Stoke City                    0.452793
# 8  Manchester United                    0.384921
# 9         Stoke City                    0.452793
#
#    relative_market_value_opponent_team  was_home  total_points season
# 0                             2.243698     False             0   1617
# 1                             1.433690      True             1   1617
# 2                             1.465860      True             2   1617
# 3                             0.796805     False             0   1617
# 4                             0.895471      True             0   1617
# 5                             0.650832      True             5   1617
# 6                             0.650832      True             8   1617
# 7                             0.718705      True             2   1617
# 8                             1.983179      True             0   1617
# 9                             0.718705      True             1   1617

# %%
train_df.shape
# Out:
# (67936, 11)

# %%
# find validation cut point - index for 18-19 season second half (gw 19)
valid_start = train_df[(train_df['gw'] > 18) & (train_df['season'] == '1819')].index.min()
#valid_start = train_df[(train_df['season'] == '1819')].index.min()
valid_end = train_df.index.max()

# %%
# check data types
train_df.dtypes
# Out:
# player                                  object
# gw                                       int64
# position                                 int64
# minutes                                  int64
# team                                    object
# opponent_team                           object
# relative_market_value_team             float64
# relative_market_value_opponent_team    float64
# was_home                                  bool
# total_points                             int64
# season                                  object
# dtype: object

# %%
# set categorical and continuous variables for tabular learner
cat_vars = ['player', 'gw', 'position', 'team', 'opponent_team', 'was_home', 'season']
cont_vars = ['minutes', 'relative_market_value_team', 'relative_market_value_opponent_team']

# %%
# set dependent variable
dep_var = 'total_points'

# %%
# set validation dataset based on indexes calculated earlier
valid_idx = range(valid_start, valid_end)

# %%
# processors - categorify categorical variables and normalize continuous variables
# fill missing not used because new teams are almost certainly well below the league average
procs=[Categorify, Normalize]

# %%
# create databunch
data = (TabularList.from_df(train_df, path=path, cat_names=cat_vars, cont_names=cont_vars, procs=procs,)
                .split_by_idx(valid_idx)
                .label_from_df(cols=dep_var, label_cls=FloatList)
                .databunch())

# %%
# set range of predictions - 0 to current 1.1 times current max
max_y = np.max(train_df['total_points'])*1.1
y_range = torch.tensor([0, max_y], device=defaults.device)

# %%
# instatiate tabular learner
learn = tabular_learner(data, layers=[1000,500], ps=[0.001,0.01], emb_drop=0.04, 
                        y_range=y_range, metrics=rmse)

# %%
# take a look at the nueral net architecture
# note that categorical variables all have embeddings (used default embedding sizes)
learn.model
# Out:
# TabularModel(
#   (embeds): ModuleList(
#     (0): Embedding(1055, 79)
#     (1): Embedding(39, 12)
#     (2): Embedding(5, 4)
#     (3): Embedding(27, 10)
#     (4): Embedding(27, 10)
#     (5): Embedding(3, 3)
#     (6): Embedding(4, 3)
#   )
#   (emb_drop): Dropout(p=0.04)
#   (bn_cont): BatchNorm1d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layers): Sequential(
#     (0): Linear(in_features=124, out_features=1000, bias=True)
#     (1): ReLU(inplace)
#     (2): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.001)
#     (4): Linear(in_features=1000, out_features=500, bias=True)
#     (5): ReLU(inplace)
#     (6): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.01)
#     (8): Linear(in_features=500, out_features=1, bias=True)
#   )
# )

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
# no market value, latest half season validation
learn.fit_one_cycle(7, 1.1e-2, wd=0.2)
# Out:
# Total time: 00:40 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.671103</td>
#       <td>4.058165</td>
#       <td>1.975258</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.023581</td>
#       <td>4.245531</td>
#       <td>1.991781</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.069503</td>
#       <td>4.208030</td>
#       <td>1.985547</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.735965</td>
#       <td>4.595274</td>
#       <td>2.119409</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.585393</td>
#       <td>3.877654</td>
#       <td>1.932921</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.206583</td>
#       <td>3.711629</td>
#       <td>1.876884</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.050195</td>
#       <td>3.812535</td>
#       <td>1.910187</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
# market value, latest half season validation
learn.fit_one_cycle(4, 1e-2, wd=0.2)
# Out:
# Total time: 00:24 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.931848</td>
#       <td>4.204875</td>
#       <td>1.988563</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.888279</td>
#       <td>3.608261</td>
#       <td>1.850430</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.780805</td>
#       <td>3.683231</td>
#       <td>1.860200</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.377957</td>
#       <td>3.498230</td>
#       <td>1.816319</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
# no market value, new season validation
learn.fit_one_cycle(7, 1.1e-2, wd=0.2)
# Out:
# Total time: 00:38 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.190550</td>
#       <td>6.135087</td>
#       <td>2.440161</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.857543</td>
#       <td>3.978027</td>
#       <td>1.933421</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.710502</td>
#       <td>3.876259</td>
#       <td>1.927505</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.443164</td>
#       <td>3.826964</td>
#       <td>1.915945</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.446122</td>
#       <td>3.713155</td>
#       <td>1.877538</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.098882</td>
#       <td>3.761742</td>
#       <td>1.897482</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.939469</td>
#       <td>3.802439</td>
#       <td>1.905856</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
# market value, new season validation
learn.fit_one_cycle(7, 1.1e-2, wd=0.2)
# Out:
# Total time: 00:38 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.974407</td>
#       <td>3.883185</td>
#       <td>1.914001</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.753403</td>
#       <td>4.662024</td>
#       <td>2.126512</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.625479</td>
#       <td>3.772259</td>
#       <td>1.889259</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.840882</td>
#       <td>3.775510</td>
#       <td>1.897972</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.616885</td>
#       <td>3.812484</td>
#       <td>1.901750</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.309392</td>
#       <td>3.734806</td>
#       <td>1.886369</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.903124</td>
#       <td>3.771559</td>
#       <td>1.897273</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
# add predictions to the validations set
df_valid = train_df.loc[valid_idx]
df_valid['predicted_points'] = learn.get_preds()[0].data.numpy().T[0]

# %%
# look at one team/gameweek
df_valid[(df_valid['team'] == 'Cardiff City') & (df_valid['opponent_team'] == 'Chelsea')].head(10)
# Out:
#                            player  gw  position  minutes          team  \
# 63316               Alex_Smithies  32         1        0  Cardiff City
# 63354          Anthony_Pilkington  32         3        0  Cardiff City
# 63363             Aron_Gunnarsson  32         3       90  Cardiff City
# 63367  Ashley Darel Jazz_Richards  32         2        0  Cardiff City
# 63408                  Bobby_Reid  32         4        0  Cardiff City
# 63414                Brian_Murphy  32         1        0  Cardiff City
# 63418          Bruno_Ecuele Manga  32         2       90  Cardiff City
# 63425             Callum_Paterson  32         3        0  Cardiff City
# 63493                Danny_Ward_2  32         3        0  Cardiff City
# 63503        David Junior_Hoilett  32         3       90  Cardiff City
#
#       opponent_team  relative_market_value_team  \
# 63316       Chelsea                     0.18389
# 63354       Chelsea                     0.18389
# 63363       Chelsea                     0.18389
# 63367       Chelsea                     0.18389
# 63408       Chelsea                     0.18389
# 63414       Chelsea                     0.18389
# 63418       Chelsea                     0.18389
# 63425       Chelsea                     0.18389
# 63493       Chelsea                     0.18389
# 63503       Chelsea                     0.18389
#
#        relative_market_value_opponent_team  was_home  total_points season  \
# 63316                             2.540586      True             0   1819
# 63354                             2.540586      True             0   1819
# 63363                             2.540586      True             1   1819
# 63367                             2.540586      True             0   1819
# 63408                             2.540586      True             0   1819
# 63414                             2.540586      True             0   1819
# 63418                             2.540586      True             1   1819
# 63425                             2.540586      True             0   1819
# 63493                             2.540586      True             0   1819
# 63503                             2.540586      True             2   1819
#
#        predicted_points
# 63316          0.190831
# 63354          0.223532
# 63363          2.200396
# 63367          0.094203
# 63408          0.243515
# 63414          0.215196
# 63418          1.231089
# 63425          0.281070
# 63493          0.162828
# 63503          2.855926

# %%
# look at top predictions
df_valid.sort_values('predicted_points', ascending=False).head(20)
# Out:
#                      player  gw  position  minutes               team  \
# 63182         Mohamed_Salah  31         3       90          Liverpool
# 66509         Mohamed_Salah  36         3       90          Liverpool
# 61572         Mohamed_Salah  28         3       90          Liverpool
# 56366         Mohamed_Salah  19         3       90          Liverpool
# 65818         Mohamed_Salah  35         3       90          Liverpool
# 60486         Mohamed_Salah  26         3       90          Liverpool
# 59235         Mohamed_Salah  24         3       90          Liverpool
# 63982       Raheem_Sterling  32         3       87    Manchester City
# 58652         Mohamed_Salah  23         3       90          Liverpool
# 64436         Mohamed_Salah  33         3       90          Liverpool
# 58075         Mohamed_Salah  22         3       90          Liverpool
# 57274           Eden_Hazard  21         3       90            Chelsea
# 63486  Danilo Luiz_da Silva  32         2       90    Manchester City
# 56934         Mohamed_Salah  20         3       90          Liverpool
# 62786         Mohamed_Salah  30         3       90          Liverpool
# 64284           Eden_Hazard  33         3       90            Chelsea
# 57326            Harry_Kane  21         4       90  Tottenham Hotspur
# 63995          Riyad_Mahrez  32         3       90    Manchester City
# 63621            Harry_Kane  32         4       90  Tottenham Hotspur
# 67802       Raheem_Sterling  38         3       90    Manchester City
#
#                   opponent_team  relative_market_value_team  \
# 63182                    Fulham                    2.177887
# 66509         Huddersfield Town                    2.177887
# 61572                   Watford                    2.177887
# 56366          Newcastle United                    2.177887
# 65818              Cardiff City                    2.177887
# 60486               Bournemouth                    2.177887
# 59235            Leicester City                    2.177887
# 63982                    Fulham                    2.540586
# 58652            Crystal Palace                    2.177887
# 64436               Southampton                    2.177887
# 58075  Brighton and Hove Albion                    2.177887
# 57274               Southampton                    2.540586
# 63486              Cardiff City                    2.540586
# 56934                   Arsenal                    2.177887
# 62786                   Burnley                    2.177887
# 64284           West Ham United                    2.540586
# 57326              Cardiff City                    1.983109
# 63995              Cardiff City                    2.540586
# 63621            Crystal Palace                    1.983109
# 67802  Brighton and Hove Albion                    2.540586
#
#        relative_market_value_opponent_team  was_home  total_points season  \
# 63182                             0.405284     False             2   1819
# 66509                             0.273778      True            19   1819
# 61572                             0.412301      True             3   1819
# 56366                             0.483921      True            12   1819
# 65818                             0.183890     False             6   1819
# 60486                             0.418108      True             8   1819
# 59235                             0.796050      True             2   1819
# 63982                             0.405284     False             3   1819
# 58652                             0.634856      True            15   1819
# 64436                             0.654624     False             6   1819
# 58075                             0.417745     False            11   1819
# 57274                             0.654624      True             3   1819
# 63486                             0.183890      True             8   1819
# 56934                             1.435552      True            12   1819
# 62786                             0.449442      True             5   1819
# 64284                             0.749352      True            16   1819
# 57326                             0.183890     False            12   1819
# 63995                             0.183890      True             3   1819
# 63621                             0.634856      True             2   1819
# 67802                             0.417745     False             5   1819
#
#        predicted_points
# 63182          9.611014
# 66509          9.445539
# 61572          8.963617
# 56366          8.824974
# 65818          8.790278
# 60486          8.767662
# 59235          8.607562
# 63982          8.486714
# 58652          8.280928
# 64436          8.190902
# 58075          8.103573
# 57274          7.974944
# 63486          7.940959
# 56934          7.818070
# 62786          7.810671
# 64284          7.810327
# 57326          7.748004
# 63995          7.727018
# 63621          7.724406
# 67802          7.699733

# %%
np.mean(df_valid.sort_values('predicted_points', ascending=False).head(1000)['predicted_points'])
# Out:
# 5.028342247009277

# %%
np.mean(df_valid.sort_values('predicted_points', ascending=False).head(1000)['total_points'])
# Out:
# 4.917

# %%
## now we have decided training approach, need to apply to remainder of season
# read in remaining_season.csv
remaining_season_df = pd.read_csv(path/'data/remaining_season.csv')

# %%
remaining_season_df.head(10)
# Out:
#    Unnamed: 0  gw       team opponent_team                   player  position  \
# 0           0   1  Liverpool       Norwich  Alex_Oxlade-Chamberlain         3
# 1           1   1  Liverpool       Norwich         Andrew_Robertson         2
# 2           2   1  Liverpool       Norwich           Simon_Mignolet         1
# 3           3   1  Liverpool       Norwich             Dejan_Lovren         2
# 4           4   1  Liverpool       Norwich             Joseph_Gomez         2
# 5           5   1  Liverpool       Norwich               Joel_Matip         2
# 6           6   1  Liverpool       Norwich         Jordan_Henderson         3
# 7           7   1  Liverpool       Norwich             Adam_Lallana         3
# 8           8   1  Liverpool       Norwich             James_Milner         3
# 9           9   1  Liverpool       Norwich          Roberto_Firmino         4
#
#    was_home  relative_market_value_team  relative_market_value_opponent_team  \
# 0      True                    2.428907                              0.19253
# 1      True                    2.428907                              0.19253
# 2      True                    2.428907                              0.19253
# 3      True                    2.428907                              0.19253
# 4      True                    2.428907                              0.19253
# 5      True                    2.428907                              0.19253
# 6      True                    2.428907                              0.19253
# 7      True                    2.428907                              0.19253
# 8      True                    2.428907                              0.19253
# 9      True                    2.428907                              0.19253
#
#    season  minutes
# 0    1920       90
# 1    1920       90
# 2    1920       90
# 3    1920       90
# 4    1920       90
# 5    1920       90
# 6    1920       90
# 7    1920       90
# 8    1920       90
# 9    1920       90

# %%
# create new databunch, including remaining season as test set
data = (TabularList.from_df(train_df, path=path, cat_names=cat_vars, cont_names=cont_vars, procs=procs,)
                .split_by_idx(valid_idx)
                .label_from_df(cols=dep_var, label_cls=FloatList)
                .add_test(TabularList.from_df(remaining_season_df, path=path, cat_names=cat_vars, cont_names=cont_vars))
                .databunch())

# %%
# instatiate new tabular learner
learn = tabular_learner(data, layers=[1000,500], ps=[0.001,0.01], emb_drop=0.04, 
                        y_range=y_range, metrics=rmse)

# %%
# train as before
learn.fit_one_cycle(4, 1e-2, wd=0.2)
# Out:
# Total time: 00:24 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.610872</td>
#       <td>4.684419</td>
#       <td>2.097926</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.809728</td>
#       <td>3.666731</td>
#       <td>1.863704</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.543875</td>
#       <td>3.583972</td>
#       <td>1.843783</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.173853</td>
#       <td>3.502098</td>
#       <td>1.821280</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>

# %%
# get predictions
test_preds=learn.get_preds(DatasetType.Test)
remaining_season_df['predicted_points'] = test_preds[0].data.numpy().T[0]

# %%
remaining_season_df.shape
# Out:
# (16074, 12)

# %%
# quick look
remaining_season_df.head(20)
#.sort_values(by='predicted_points', ascending=False)
# Out:
#     Unnamed: 0  gw       team opponent_team                   player  \
# 0            0   1  Liverpool       Norwich  Alex_Oxlade-Chamberlain
# 1            1   1  Liverpool       Norwich         Andrew_Robertson
# 2            2   1  Liverpool       Norwich           Simon_Mignolet
# 3            3   1  Liverpool       Norwich             Dejan_Lovren
# 4            4   1  Liverpool       Norwich             Joseph_Gomez
# 5            5   1  Liverpool       Norwich               Joel_Matip
# 6            6   1  Liverpool       Norwich         Jordan_Henderson
# 7            7   1  Liverpool       Norwich             Adam_Lallana
# 8            8   1  Liverpool       Norwich             James_Milner
# 9            9   1  Liverpool       Norwich          Roberto_Firmino
# 10          10   1  Liverpool       Norwich               Sadio_Mané
# 11          11   1  Liverpool       Norwich             Divock_Origi
# 12          12   1  Liverpool       Norwich          Virgil_van Dijk
# 13          13   1  Liverpool       Norwich          Xherdan_Shaqiri
# 14          14   1  Liverpool       Norwich      Georginio_Wijnaldum
# 15          15   1  Liverpool       Norwich   Trent_Alexander-Arnold
# 16          16   1  Liverpool       Norwich            Mohamed_Salah
# 17          17   1  Liverpool       Norwich           Rafael_Camacho
# 18          18   1  Liverpool       Norwich   Fabio Henrique_Tavares
# 19          19   1  Liverpool       Norwich               Naby_Keita
#
#     position  was_home  relative_market_value_team  \
# 0          3      True                    2.428907
# 1          2      True                    2.428907
# 2          1      True                    2.428907
# 3          2      True                    2.428907
# 4          2      True                    2.428907
# 5          2      True                    2.428907
# 6          3      True                    2.428907
# 7          3      True                    2.428907
# 8          3      True                    2.428907
# 9          4      True                    2.428907
# 10         3      True                    2.428907
# 11         4      True                    2.428907
# 12         2      True                    2.428907
# 13         3      True                    2.428907
# 14         3      True                    2.428907
# 15         2      True                    2.428907
# 16         3      True                    2.428907
# 17         3      True                    2.428907
# 18         3      True                    2.428907
# 19         3      True                    2.428907
#
#     relative_market_value_opponent_team  season  minutes  predicted_points
# 0                               0.19253    1920       90          4.705704
# 1                               0.19253    1920       90          6.874360
# 2                               0.19253    1920       90          5.105846
# 3                               0.19253    1920       90          5.216479
# 4                               0.19253    1920       90          4.586348
# 5                               0.19253    1920       90          5.064442
# 6                               0.19253    1920       90          3.632555
# 7                               0.19253    1920       90          6.032600
# 8                               0.19253    1920       90          4.397369
# 9                               0.19253    1920       90          5.629373
# 10                              0.19253    1920       90          7.738614
# 11                              0.19253    1920       90          6.116557
# 12                              0.19253    1920       90          5.787560
# 13                              0.19253    1920       90          6.763589
# 14                              0.19253    1920       90          4.148347
# 15                              0.19253    1920       90          6.790408
# 16                              0.19253    1920       90          9.137580
# 17                              0.19253    1920       90          5.381402
# 18                              0.19253    1920       90          4.415897
# 19                              0.19253    1920       90          3.845847

# %%
# write to predictions.csv
remaining_season_df.to_csv('predictions.csv')
