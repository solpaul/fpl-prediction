# %%
# import required packages
from fastai.tabular import *

# %%
# path to project directory
path = Path('/home/jupyter/fpl-prediction')

# %%
# read in training dataset
# created using fpl_data_clean notebook
train_df = pd.read_csv(path/'data/train.csv', index_col=0, dtype={'season':str})

# %%
train_df.tail()
# Out:
#                 player  gw  position  minutes                      team  \
# 70047   Yoshinori_Muto   4         4        8          Newcastle United
# 70048  Youri_Tielemans   4         3       90            Leicester City
# 70049    Yves_Bissouma   4         3        0  Brighton and Hove Albion
# 70050   Çaglar_Söyüncü   4         2       90            Leicester City
# 70051     Ørjan_Nyland   4         1        0               Aston Villa
#
#          opponent_team  relative_market_value_team  \
# 70047          Watford                    0.587436
# 70048      Bournemouth                    0.880896
# 70049  Manchester City                    0.466161
# 70050      Bournemouth                    0.880896
# 70051   Crystal Palace                    0.410119
#
#        relative_market_value_opponent_team  was_home  total_points season  \
# 70047                             0.507495      True             1   1920
# 70048                             0.717707      True            12   1920
# 70049                             2.748438     False             0   1920
# 70050                             0.717707      True             2   1920
# 70051                             0.507924     False             0   1920
#
#        play_proba
# 70047         1.0
# 70048         1.0
# 70049         0.0
# 70050         1.0
# 70051         1.0

# %%
train_df.shape
# Out:
# (70052, 12)

# %%
# exclude zero minute rows
#train_df = train_df[train_df['minutes'] != 0].reset_index()

# %%
train_df.shape
# Out:
# (70052, 12)

# %%
# find validation cut point - index for 18-19 season second half (gw 19)
#valid_start = train_df[(train_df['gw'] > 18) & (train_df['season'] == '1819')].index.min()
# or take validation as same as current prediction set
valid_start = train_df[(train_df['season'] == '1819') & (train_df['gw'] == 5)].index.min()
valid_end = train_df.index.max()

# %%
# check data types
train_df.dtypes
# Out:
# player                                  object
# gw                                       int64
# position                                 int64
# minutes                                  int64
# team                                    object
# opponent_team                           object
# relative_market_value_team             float64
# relative_market_value_opponent_team    float64
# was_home                                  bool
# total_points                             int64
# season                                  object
# play_proba                             float64
# dtype: object

# %%
# set categorical and continuous variables for tabular learner
cat_vars = ['player', 'gw', 'position', 'team', 'opponent_team', 'was_home', 'season']
cont_vars = ['minutes', 'relative_market_value_team', 'relative_market_value_opponent_team']

# %%
# set dependent variable
dep_var = 'total_points'

# %%
# set validation dataset based on indexes calculated earlier
valid_idx = range(valid_start, valid_end)

# %%
# processors - categorify categorical variables and normalize continuous variables
# fill missing not used because new teams are almost certainly well below the league average
procs=[Categorify, Normalize]

# %%
# create databunch
data = (TabularList.from_df(train_df, path=path, cat_names=cat_vars, cont_names=cont_vars, procs=procs,)
                .split_by_idx(valid_idx)
                .label_from_df(cols=dep_var, label_cls=FloatList)
                .databunch())

# %%
# set range of predictions - minimum to current max
max_y = np.max(train_df['total_points'])
min_y = np.min(train_df['total_points'])
y_range = torch.tensor([-1, max_y], device=defaults.device)

# %%
# instatiate tabular learner
learn = tabular_learner(data, layers=[1000,500], ps=[0.001,0.01], emb_drop=0.04, 
                        y_range=y_range, metrics=rmse)

# %%
# take a look at the nueral net architecture
# note that categorical variables all have embeddings (used default embedding sizes)
learn.model
# Out:
# TabularModel(
#   (embeds): ModuleList(
#     (0): Embedding(1035, 78)
#     (1): Embedding(39, 12)
#     (2): Embedding(5, 4)
#     (3): Embedding(28, 10)
#     (4): Embedding(27, 10)
#     (5): Embedding(3, 3)
#     (6): Embedding(5, 4)
#   )
#   (emb_drop): Dropout(p=0.04)
#   (bn_cont): BatchNorm1d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layers): Sequential(
#     (0): Linear(in_features=124, out_features=1000, bias=True)
#     (1): ReLU(inplace)
#     (2): BatchNorm1d(1000, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.001)
#     (4): Linear(in_features=1000, out_features=500, bias=True)
#     (5): ReLU(inplace)
#     (6): BatchNorm1d(500, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.01)
#     (8): Linear(in_features=500, out_features=1, bias=True)
#   )
# )

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
# no market value, latest half season validation
learn.fit_one_cycle(3, 1.1e-2, wd=0.2)
# Out:
# Total time: 00:08 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>8.501507</td>
#       <td>7.926478</td>
#       <td>2.782442</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>7.460577</td>
#       <td>8.293941</td>
#       <td>2.840935</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>6.654506</td>
#       <td>7.472949</td>
#       <td>2.700373</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>

# %%
# market value, latest half season validation
learn.fit_one_cycle(3, 1.5e-3, wd=0.2)
# Out:
# Total time: 00:08 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>10.148968</td>
#       <td>8.108212</td>
#       <td>2.815272</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>7.744442</td>
#       <td>7.921211</td>
#       <td>2.780680</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>6.750823</td>
#       <td>7.586754</td>
#       <td>2.719187</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>

# %%
# no market value, new season validation
learn.fit_one_cycle(4, 1e-2, wd=0.2)
# Out:
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>8.286838</td>
#       <td>8.456475</td>
#       <td>2.861300</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>7.342739</td>
#       <td>7.591846</td>
#       <td>2.721933</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>7.386149</td>
#       <td>7.513053</td>
#       <td>2.702131</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>6.645412</td>
#       <td>7.562900</td>
#       <td>2.718028</td>
#       <td>00:02</td>
#     </tr>
#   </tbody>
# </table>

# %%
# CURRENT APPROACH
# market value, new season validation
learn.fit_one_cycle(2, 1e-2, wd=0.2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.671412</td>
#       <td>3.953879</td>
#       <td>1.948558</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.264624</td>
#       <td>3.637542</td>
#       <td>1.866212</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>

# %%
# second training run with lower LR
learn.fit_one_cycle(1, 1e-3, wd=0.2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.126489</td>
#       <td>3.625573</td>
#       <td>1.861412</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
# add predictions to the validations set
df_valid = train_df.loc[valid_idx]
df_valid['predicted_points'] = learn.get_preds()[0].data.numpy().T[0]

# %%
# look at one team/gameweek
df_valid[(df_valid['team'] == 'Cardiff City') & (df_valid['opponent_team'] == 'Chelsea')].head(10)
# Out:
#                            player  gw  position  minutes          team  \
# 48293               Alex_Smithies   5         1        0  Cardiff City
# 48314          Anthony_Pilkington   5         3        0  Cardiff City
# 48318             Aron_Gunnarsson   5         3        0  Cardiff City
# 48321  Ashley Darel Jazz_Richards   5         2       45  Cardiff City
# 48345                  Bobby_Reid   5         4       70  Cardiff City
# 48348                Brian_Murphy   5         1        0  Cardiff City
# 48350          Bruno_Ecuele Manga   5         2       90  Cardiff City
# 48354             Callum_Paterson   5         3       19  Cardiff City
# 48394                Danny_Ward_2   5         3       76  Cardiff City
# 48400        David Junior_Hoilett   5         3       90  Cardiff City
#
#       opponent_team  relative_market_value_team  \
# 48293       Chelsea                     0.18389
# 48314       Chelsea                     0.18389
# 48318       Chelsea                     0.18389
# 48321       Chelsea                     0.18389
# 48345       Chelsea                     0.18389
# 48348       Chelsea                     0.18389
# 48350       Chelsea                     0.18389
# 48354       Chelsea                     0.18389
# 48394       Chelsea                     0.18389
# 48400       Chelsea                     0.18389
#
#        relative_market_value_opponent_team  was_home  total_points season  \
# 48293                             2.540586     False             0   1819
# 48314                             2.540586     False             0   1819
# 48318                             2.540586     False             0   1819
# 48321                             2.540586     False             0   1819
# 48345                             2.540586     False             2   1819
# 48348                             2.540586     False             0   1819
# 48350                             2.540586     False             0   1819
# 48354                             2.540586     False             1   1819
# 48394                             2.540586     False             2   1819
# 48400                             2.540586     False             2   1819
#
#        play_proba  predicted_points
# 48293         NaN          0.162879
# 48314         NaN          0.286753
# 48318         NaN          0.245408
# 48321         NaN          1.093436
# 48345         NaN          1.955034
# 48348         NaN          0.162391
# 48350         NaN          1.481189
# 48354         NaN          1.008169
# 48394         NaN          1.853666
# 48400         NaN          2.043683

# %%
# look at top predictions
df_valid.sort_values('predicted_points', ascending=False).head(20)
# Out:
#                           player  gw  position  minutes               team  \
# 51349              Mohamed_Salah  10         3       90          Liverpool
# 66509              Mohamed_Salah  36         3       90          Liverpool
# 68308              Mohamed_Salah   1         3       90          Liverpool
# 61572              Mohamed_Salah  28         3       90          Liverpool
# 63772            Kevin_De Bruyne  32         3       90    Manchester City
# 49177              Mohamed_Salah   6         3       90          Liverpool
# 67748              Mohamed_Salah  38         3       90          Liverpool
# 52450              Mohamed_Salah  12         3       90          Liverpool
# 60486              Mohamed_Salah  26         3       90          Liverpool
# 63593  Gabriel Fernando_de Jesus  32         4       90    Manchester City
# 58652              Mohamed_Salah  23         3       90          Liverpool
# 62786              Mohamed_Salah  30         3       90          Liverpool
# 56366              Mohamed_Salah  19         3       90          Liverpool
# 69992              Sergio_Agüero   4         4       90    Manchester City
# 50801              Mohamed_Salah   9         3       90          Liverpool
# 59235              Mohamed_Salah  24         3       90          Liverpool
# 50086                 Harry_Kane   8         4       90  Tottenham Hotspur
# 65818              Mohamed_Salah  35         3       90          Liverpool
# 68126                 Harry_Kane   1         4       90  Tottenham Hotspur
# 63805                 Leroy_Sané  32         3       90    Manchester City
#
#                   opponent_team  relative_market_value_team  \
# 51349              Cardiff City                    2.177887
# 66509         Huddersfield Town                    2.177887
# 68308                   Norwich                    2.297572
# 61572                   Watford                    2.177887
# 63772              Cardiff City                    2.540586
# 49177               Southampton                    2.177887
# 67748   Wolverhampton Wanderers                    2.177887
# 52450                    Fulham                    2.177887
# 60486               Bournemouth                    2.177887
# 63593              Cardiff City                    2.540586
# 58652            Crystal Palace                    2.177887
# 62786                   Burnley                    2.177887
# 56366          Newcastle United                    2.177887
# 69992  Brighton and Hove Albion                    2.748438
# 50801         Huddersfield Town                    2.177887
# 59235            Leicester City                    2.177887
# 50086              Cardiff City                    1.983109
# 65818              Cardiff City                    2.177887
# 68126               Aston Villa                    2.113981
# 63805              Cardiff City                    2.540586
#
#        relative_market_value_opponent_team  was_home  total_points season  \
# 51349                             0.183890      True            15   1819
# 66509                             0.273778      True            19   1819
# 68308                             0.198300      True            12   1920
# 61572                             0.412301      True             3   1819
# 63772                             0.183890      True            11   1819
# 49177                             0.654624      True             8   1819
# 67748                             0.388177      True             3   1819
# 52450                             0.405284      True             8   1819
# 60486                             0.418108      True             8   1819
# 63593                             0.183890      True             5   1819
# 58652                             0.634856      True            15   1819
# 62786                             0.449442      True             5   1819
# 56366                             0.483921      True            12   1819
# 69992                             0.466161      True            16   1920
# 50801                             0.273778     False             8   1819
# 59235                             0.796050      True             2   1819
# 50086                             0.183890      True             1   1819
# 65818                             0.183890     False             6   1819
# 68126                             0.338194      True            13   1920
# 63805                             0.183890      True             8   1819
#
#        play_proba  predicted_points
# 51349         NaN          9.129925
# 66509         NaN          9.046007
# 68308         1.0          8.887022
# 61572         NaN          8.742349
# 63772         NaN          8.599860
# 49177         NaN          8.589981
# 67748         NaN          8.520441
# 52450         NaN          8.461168
# 60486         NaN          8.364565
# 63593         NaN          8.339113
# 58652         NaN          8.332688
# 62786         NaN          8.268920
# 56366         NaN          8.250589
# 69992         1.0          8.173490
# 50801         NaN          8.151920
# 59235         NaN          8.109383
# 50086         NaN          8.038466
# 65818         NaN          8.008201
# 68126         1.0          7.969539
# 63805         NaN          7.959956

# %%
np.mean(df_valid.sort_values('predicted_points', ascending=False).head(1000)['predicted_points'])
# Out:
# 5.757300853729248

# %%
np.mean(df_valid.sort_values('predicted_points', ascending=False).head(1000)['total_points'])
# Out:
# 5.44

# %%
## now we have decided training approach, need to apply to remainder of season
# read in remaining_season.csv
remaining_season_df = pd.read_csv(path/'data/remaining_season.csv', index_col=0)

# %%
remaining_season_df.head(50)
# Out:
#     gw                      team     opponent_team  \
# 0    5                 Liverpool  Newcastle United
# 1    5                 Liverpool  Newcastle United
# 2    5                 Liverpool  Newcastle United
# 3    5                 Liverpool  Newcastle United
# 4    5                 Liverpool  Newcastle United
# 5    5                 Liverpool  Newcastle United
# 6    5                 Liverpool  Newcastle United
# 7    5                 Liverpool  Newcastle United
# 8    5                 Liverpool  Newcastle United
# 9    5                 Liverpool  Newcastle United
# 10   5                 Liverpool  Newcastle United
# 11   5                 Liverpool  Newcastle United
# 12   5                 Liverpool  Newcastle United
# 13   5                 Liverpool  Newcastle United
# 14   5                 Liverpool  Newcastle United
# 15   5                 Liverpool  Newcastle United
# 16   5                 Liverpool  Newcastle United
# 17   5                 Liverpool  Newcastle United
# 18   5                 Liverpool  Newcastle United
# 19   5                 Liverpool  Newcastle United
# 20   5                 Liverpool  Newcastle United
# 21   5                 Liverpool  Newcastle United
# 22   5                 Liverpool  Newcastle United
# 23   5                 Liverpool  Newcastle United
# 24   5                 Liverpool  Newcastle United
# 25   5  Brighton and Hove Albion           Burnley
# 26   5  Brighton and Hove Albion           Burnley
# 27   5  Brighton and Hove Albion           Burnley
# 28   5  Brighton and Hove Albion           Burnley
# 29   5  Brighton and Hove Albion           Burnley
# 30   5  Brighton and Hove Albion           Burnley
# 31   5  Brighton and Hove Albion           Burnley
# 32   5  Brighton and Hove Albion           Burnley
# 33   5  Brighton and Hove Albion           Burnley
# 34   5  Brighton and Hove Albion           Burnley
# 35   5  Brighton and Hove Albion           Burnley
# 36   5  Brighton and Hove Albion           Burnley
# 37   5  Brighton and Hove Albion           Burnley
# 38   5  Brighton and Hove Albion           Burnley
# 39   5  Brighton and Hove Albion           Burnley
# 40   5  Brighton and Hove Albion           Burnley
# 41   5  Brighton and Hove Albion           Burnley
# 42   5  Brighton and Hove Albion           Burnley
# 43   5  Brighton and Hove Albion           Burnley
# 44   5  Brighton and Hove Albion           Burnley
# 45   5  Brighton and Hove Albion           Burnley
# 46   5  Brighton and Hove Albion           Burnley
# 47   5  Brighton and Hove Albion           Burnley
# 48   5  Brighton and Hove Albion           Burnley
# 49   5  Brighton and Hove Albion           Burnley
#
#                                 player  position  price  play_proba  was_home  \
# 0                     Andrew_Robertson         2    6.9         1.0      True
# 1               Trent_Alexander-Arnold         2    7.0         1.0      True
# 2                      Virgil_van Dijk         2    6.5         1.0      True
# 3                         Joseph_Gomez         2    5.4         1.0      True
# 4                           Joel_Matip         2    5.4         1.0      True
# 5                         Dejan_Lovren         2    5.4         1.0      True
# 6                      Roberto_Firmino         4    9.5         1.0      True
# 7                         Divock_Origi         4    5.5         1.0      True
# 8                Alisson_Ramses Becker         1    5.8         0.0      True
# 9                       Simon_Mignolet         1    4.5         0.0      True
# 10                       Mohamed_Salah         3   12.5         1.0      True
# 11                          Sadio_Mané         3   11.5         1.0      True
# 12             Alex_Oxlade-Chamberlain         3    6.4         1.0      True
# 13                     Xherdan_Shaqiri         3    6.3         1.0      True
# 14                        Adam_Lallana         3    5.9         1.0      True
# 15                          Naby_Keita         3    5.9         0.0      True
# 16              Fabio Henrique_Tavares         3    5.5         1.0      True
# 17                    Jordan_Henderson         3    5.5         1.0      True
# 18                 Georginio_Wijnaldum         3    5.5         1.0      True
# 19                        James_Milner         3    5.5         1.0      True
# 20                      Rafael_Camacho         3    4.5         0.0      True
# 21                      Rhian_Brewster         4    4.5         1.0      True
# 22      Adrián_San Miguel del Castillo         1    4.6         1.0      True
# 23                       Andy_Lonergan         1    4.5         1.0      True
# 24                   Caoimhin_Kelleher         1    4.5         1.0      True
# 25                         Shane_Duffy         2    5.0         1.0      True
# 26                      Martín_Montoya         2    4.5         1.0      True
# 27  Bernardo_Fernandes da Silva Junior         2    4.5         1.0      True
# 28                        Leon_Balogun         2    4.4         1.0      True
# 29                         Gaëtan_Bong         2    4.4         1.0      True
# 30                          Lewis_Dunk         2    4.6         1.0      True
# 31                      Matthew_Clarke         2    4.4         0.0      True
# 32                        Glenn_Murray         4    5.9         1.0      True
# 33                      Jürgen_Locadia         4    5.4         0.0      True
# 34                       Florin_Andone         4    5.0         0.0      True
# 35                         Mathew_Ryan         1    4.6         1.0      True
# 36                        David_Button         1    4.0         1.0      True
# 37                         Pascal_Groß         3    6.5         1.0      True
# 38                 Alireza_Jahanbakhsh         3    5.9         1.0      True
# 39       José Heriberto_Izquierdo Mena         3    5.5         0.0      True
# 40                   Anthony_Knockaert         3    5.4         0.0      True
# 41                       Yves_Bissouma         3    5.0         0.5      True
# 42                        Davy_Pröpper         3    5.0         1.0      True
# 43                       Solomon_March         3    4.9         1.0      True
# 44                         Beram_Kayal         3    4.4         0.0      True
# 45                       Dale_Stephens         3    4.5         1.0      True
# 46                    Leandro_Trossard         3    6.0         1.0      True
# 47                            Dan_Burn         2    4.5         1.0      True
# 48                        Adam_Webster         2    4.4         1.0      True
# 49                         Neal_Maupay         4    6.0         1.0      True
#
#     relative_market_value_team  relative_market_value_opponent_team  season  \
# 0                     2.297523                             0.587436    1920
# 1                     2.297523                             0.587436    1920
# 2                     2.297523                             0.587436    1920
# 3                     2.297523                             0.587436    1920
# 4                     2.297523                             0.587436    1920
# 5                     2.297523                             0.587436    1920
# 6                     2.297523                             0.587436    1920
# 7                     2.297523                             0.587436    1920
# 8                     2.297523                             0.587436    1920
# 9                     2.297523                             0.587436    1920
# 10                    2.297523                             0.587436    1920
# 11                    2.297523                             0.587436    1920
# 12                    2.297523                             0.587436    1920
# 13                    2.297523                             0.587436    1920
# 14                    2.297523                             0.587436    1920
# 15                    2.297523                             0.587436    1920
# 16                    2.297523                             0.587436    1920
# 17                    2.297523                             0.587436    1920
# 18                    2.297523                             0.587436    1920
# 19                    2.297523                             0.587436    1920
# 20                    2.297523                             0.587436    1920
# 21                    2.297523                             0.587436    1920
# 22                    2.297523                             0.587436    1920
# 23                    2.297523                             0.587436    1920
# 24                    2.297523                             0.587436    1920
# 25                    0.466161                             0.426759    1920
# 26                    0.466161                             0.426759    1920
# 27                    0.466161                             0.426759    1920
# 28                    0.466161                             0.426759    1920
# 29                    0.466161                             0.426759    1920
# 30                    0.466161                             0.426759    1920
# 31                    0.466161                             0.426759    1920
# 32                    0.466161                             0.426759    1920
# 33                    0.466161                             0.426759    1920
# 34                    0.466161                             0.426759    1920
# 35                    0.466161                             0.426759    1920
# 36                    0.466161                             0.426759    1920
# 37                    0.466161                             0.426759    1920
# 38                    0.466161                             0.426759    1920
# 39                    0.466161                             0.426759    1920
# 40                    0.466161                             0.426759    1920
# 41                    0.466161                             0.426759    1920
# 42                    0.466161                             0.426759    1920
# 43                    0.466161                             0.426759    1920
# 44                    0.466161                             0.426759    1920
# 45                    0.466161                             0.426759    1920
# 46                    0.466161                             0.426759    1920
# 47                    0.466161                             0.426759    1920
# 48                    0.466161                             0.426759    1920
# 49                    0.466161                             0.426759    1920
#
#       minutes
# 0   90.000000
# 1   90.000000
# 2   90.000000
# 3    0.000000
# 4   90.000000
# 5    0.000000
# 6   86.333333
# 7    5.333333
# 8    0.000000
# 9    0.000000
# 10  86.000000
# 11  83.333333
# 12  40.000000
# 13   1.666667
# 14   1.333333
# 15   0.000000
# 16  65.333333
# 17  53.666667
# 18  82.666667
# 19  31.333333
# 20   0.000000
# 21   0.000000
# 22  90.000000
# 23   0.000000
# 24   0.000000
# 25  60.000000
# 26  90.000000
# 27  22.000000
# 28   0.000000
# 29   0.000000
# 30  90.000000
# 31   0.000000
# 32  37.333333
# 33   0.000000
# 34   0.000000
# 35  90.000000
# 36   0.000000
# 37  31.333333
# 38   0.000000
# 39   0.000000
# 40   0.000000
# 41   0.000000
# 42  90.000000
# 43  82.333333
# 44   0.000000
# 45  85.666667
# 46  82.333333
# 47  90.000000
# 48  30.000000
# 49  54.000000

# %%
# create new databunch, with remaining season as test set
# and using all available data i.e. no validation
data = (TabularList.from_df(train_df, path=path, cat_names=cat_vars, cont_names=cont_vars, procs=procs,)
                .split_none()
                .label_from_df(cols=dep_var, label_cls=FloatList)
                .add_test(TabularList.from_df(remaining_season_df, path=path, cat_names=cat_vars, cont_names=cont_vars))
                .databunch())

# %%
# instatiate new tabular learner
learn = tabular_learner(data, layers=[1000,500], ps=[0.001,0.01], emb_drop=0.04, 
                        y_range=y_range, metrics=rmse)

# %%
# train as before
learn.fit_one_cycle(2, 1e-2, wd=0.2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.886206</td>
#       <td>#na#</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.507227</td>
#       <td>#na#</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(1, 1e-3, wd=0.2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>root_mean_squared_error</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.327767</td>
#       <td>#na#</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>

# %%
# get predictions
test_preds=learn.get_preds(DatasetType.Test)
remaining_season_df['predicted_points'] = test_preds[0].data.numpy().T[0]

# %%
# check mean of top predictions to see if it's reasonably close to previous season's actuals
# re-run if not - not ideal but at the moment the training often over-predicts top players
np.mean(remaining_season_df.sort_values('predicted_points', ascending=False).head(1000)['predicted_points'])
# Out:
# 5.37995719909668

# %%
remaining_season_df.shape
# Out:
# (18088, 13)

# %%
# quick look
remaining_season_df.head(20)
#.sort_values(by='predicted_points', ascending=False)
# Out:
#     gw       team     opponent_team                   player  position  price  \
# 0    5  Liverpool  Newcastle United         Andrew_Robertson         2    6.9
# 1    5  Liverpool  Newcastle United   Trent_Alexander-Arnold         2    7.0
# 2    5  Liverpool  Newcastle United          Virgil_van Dijk         2    6.5
# 3    5  Liverpool  Newcastle United             Joseph_Gomez         2    5.4
# 4    5  Liverpool  Newcastle United               Joel_Matip         2    5.4
# 5    5  Liverpool  Newcastle United             Dejan_Lovren         2    5.4
# 6    5  Liverpool  Newcastle United          Roberto_Firmino         4    9.5
# 7    5  Liverpool  Newcastle United             Divock_Origi         4    5.5
# 8    5  Liverpool  Newcastle United    Alisson_Ramses Becker         1    5.8
# 9    5  Liverpool  Newcastle United           Simon_Mignolet         1    4.5
# 10   5  Liverpool  Newcastle United            Mohamed_Salah         3   12.5
# 11   5  Liverpool  Newcastle United               Sadio_Mané         3   11.5
# 12   5  Liverpool  Newcastle United  Alex_Oxlade-Chamberlain         3    6.4
# 13   5  Liverpool  Newcastle United          Xherdan_Shaqiri         3    6.3
# 14   5  Liverpool  Newcastle United             Adam_Lallana         3    5.9
# 15   5  Liverpool  Newcastle United               Naby_Keita         3    5.9
# 16   5  Liverpool  Newcastle United   Fabio Henrique_Tavares         3    5.5
# 17   5  Liverpool  Newcastle United         Jordan_Henderson         3    5.5
# 18   5  Liverpool  Newcastle United      Georginio_Wijnaldum         3    5.5
# 19   5  Liverpool  Newcastle United             James_Milner         3    5.5
#
#     play_proba  was_home  relative_market_value_team  \
# 0          1.0      True                    2.297523
# 1          1.0      True                    2.297523
# 2          1.0      True                    2.297523
# 3          1.0      True                    2.297523
# 4          1.0      True                    2.297523
# 5          1.0      True                    2.297523
# 6          1.0      True                    2.297523
# 7          1.0      True                    2.297523
# 8          0.0      True                    2.297523
# 9          0.0      True                    2.297523
# 10         1.0      True                    2.297523
# 11         1.0      True                    2.297523
# 12         1.0      True                    2.297523
# 13         1.0      True                    2.297523
# 14         1.0      True                    2.297523
# 15         0.0      True                    2.297523
# 16         1.0      True                    2.297523
# 17         1.0      True                    2.297523
# 18         1.0      True                    2.297523
# 19         1.0      True                    2.297523
#
#     relative_market_value_opponent_team  season    minutes  predicted_points
# 0                              0.587436    1920  90.000000          6.161880
# 1                              0.587436    1920  90.000000          5.862887
# 2                              0.587436    1920  90.000000          5.191683
# 3                              0.587436    1920   0.000000         -0.021872
# 4                              0.587436    1920  90.000000          4.603323
# 5                              0.587436    1920   0.000000          0.014344
# 6                              0.587436    1920  86.333333          5.880629
# 7                              0.587436    1920   5.333333          0.451412
# 8                              0.587436    1920   0.000000          0.056432
# 9                              0.587436    1920   0.000000         -0.013736
# 10                             0.587436    1920  86.000000          8.371880
# 11                             0.587436    1920  83.333333          6.760961
# 12                             0.587436    1920  40.000000          2.647433
# 13                             0.587436    1920   1.666667          0.167849
# 14                             0.587436    1920   1.333333          0.045028
# 15                             0.587436    1920   0.000000          0.114555
# 16                             0.587436    1920  65.333333          2.512932
# 17                             0.587436    1920  53.666667          1.975794
# 18                             0.587436    1920  82.666667          3.517064
# 19                             0.587436    1920  31.333333          2.172060

# %%
# write to predictions.csv
## RENAME PREVIOUS WEEK FIRST
predictions = remaining_season_df[['gw', 'player', 'team', 'position', 'price', 'play_proba', 'predicted_points']]
predictions.to_csv('predictions.csv')
