# %%
# import required packages
# from fastai2.tabular.all import *
import xgboost as xgb
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.feature_extraction import DictVectorizer
from helpers import *

pd.options.display.max_columns = None

# %%
# path to project directory
path = Path('./')

# %%
# read in training dataset
train_df = pd.read_csv(path/'data/train_v5.csv', index_col=0, dtype={'season':str})

# %%
train_df.shape
# Out:
# (98458, 37)

# %%
# features for model
season = '2021'
cat_vars = ['season', 'position', 'was_home']
cont_vars = ['gw', 'minutes']
dep_var = ['total_points']

# find the latest gameweek
last_gw = train_df['gw'][train_df['season'] == season].max()

if np.isnan(last_gw): 
    next_gw = 1 
else: 
    next_gw = last_gw + 1
    
next_gw
# Out:
# 15

# %%
# read in remaining_season.csv and sort
remaining_season_df = pd.read_csv(path/'data/remaining_season.csv', 
                                  index_col=0).sort_values(by=['gw', 'team'])

remaining_season_df['season'] = season
remaining_season_df['total_points'] = 0
remaining_season_df['kickoff_time'] = '9999-99-99'

# append remaining season to end of training set
train_df = train_df.append(remaining_season_df, sort=False).reset_index(drop=True)

# %%
# add player lag features
lag_train_df, team_lag_vars = team_lag_features(train_df, ['total_points'], ['all', 1, 2, 3, 4, 5, 10])
lag_train_df, player_lag_vars = player_lag_features(lag_train_df, ['total_points'], 
                                                    ['all', 1, 2, 3, 4, 5, 10])

# %%
# we want to set gw and season as ordered categorical variables
# need lists with ordered categories
ordered_gws = list(range(1,39))
ordered_seasons = ['1617', '1718', '1819', '1920', '2021']

# set as categories with correct order 
lag_train_df['gw'] = lag_train_df['gw'].astype('category')
lag_train_df['season'] = lag_train_df['season'].astype('category')

lag_train_df['gw'].cat.set_categories(ordered_gws, ordered=True, inplace=True)
lag_train_df['season'].cat.set_categories(ordered_seasons, ordered=True, inplace=True)

# %%
# create dataset with latest lag numbers for all future gameweeks
valid_season = '2021'
valid_gw = next_gw
valid_len = 38 - next_gw + 1

train_predict_df, train_idx, valid_idx = create_lag_train(lag_train_df, 
                                                      cat_vars, cont_vars, 
                                                      player_lag_vars, team_lag_vars, dep_var,
                                                      valid_season, valid_gw, valid_len)

# %%
# take a look at the dataframe
train_predict_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113313 entries, 0 to 113312
# Data columns (total 37 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   gw                                      113313 non-null  category
#  1   minutes                                 113313 non-null  float64
#  2   minutes_last_1                          113313 non-null  float64
#  3   minutes_last_10                         113313 non-null  float64
#  4   minutes_last_2                          113313 non-null  float64
#  5   minutes_last_3                          113313 non-null  float64
#  6   minutes_last_4                          113313 non-null  float64
#  7   minutes_last_5                          113313 non-null  float64
#  8   minutes_last_all                        113313 non-null  float64
#  9   opponent_team                           113313 non-null  object
#  10  player                                  113313 non-null  object
#  11  position                                113313 non-null  int64
#  12  season                                  113313 non-null  category
#  13  team                                    113313 non-null  object
#  14  total_points                            113313 non-null  int64
#  15  total_points_pg_last_1                  52360 non-null   float64
#  16  total_points_pg_last_10                 79662 non-null   float64
#  17  total_points_pg_last_2                  61311 non-null   float64
#  18  total_points_pg_last_3                  65829 non-null   float64
#  19  total_points_pg_last_4                  69305 non-null   float64
#  20  total_points_pg_last_5                  71878 non-null   float64
#  21  total_points_pg_last_all                96582 non-null   float64
#  22  total_points_team_pg_last_1             112531 non-null  float64
#  23  total_points_team_pg_last_10            112531 non-null  float64
#  24  total_points_team_pg_last_10_opponent   112527 non-null  float64
#  25  total_points_team_pg_last_1_opponent    112527 non-null  float64
#  26  total_points_team_pg_last_2             112531 non-null  float64
#  27  total_points_team_pg_last_2_opponent    112527 non-null  float64
#  28  total_points_team_pg_last_3             112531 non-null  float64
#  29  total_points_team_pg_last_3_opponent    112527 non-null  float64
#  30  total_points_team_pg_last_4             112531 non-null  float64
#  31  total_points_team_pg_last_4_opponent    112527 non-null  float64
#  32  total_points_team_pg_last_5             112531 non-null  float64
#  33  total_points_team_pg_last_5_opponent    112527 non-null  float64
#  34  total_points_team_pg_last_all           112531 non-null  float64
#  35  total_points_team_pg_last_all_opponent  112527 non-null  float64
#  36  was_home                                113313 non-null  bool
# dtypes: bool(1), category(2), float64(29), int64(2), object(3)
# memory usage: 29.7+ MB

# %%
# split out dependent variable
X, y = train_predict_df[cat_vars + cont_vars + player_lag_vars + team_lag_vars].copy(), train_predict_df[dep_var].copy()

# %%
# since position is categorical, it should be a string
X['position'] = X['position'].apply(str)

# need to transform season
enc = LabelEncoder()
X['season'] = enc.fit_transform(X['season'])
X_dict = X.to_dict("records")

# Create the DictVectorizer object: dv
dv = DictVectorizer(sparse=False, separator='_')

# Apply dv on df: df_encoded
X_encoded = dv.fit_transform(X_dict)

X_df = pd.DataFrame(X_encoded, columns=dv.feature_names_)

# %%
# split out training and prediction sets
X_train = X_df.iloc[train_idx]
y_train = y.iloc[train_idx]
X_test = X_df.iloc[valid_idx]
y_test = y.iloc[valid_idx]

# %%
# instatiate and train XGB Regressor
xg_reg = xgb.XGBRegressor(objective="reg:squarederror",
                          gamma=0.42, learning_rate=0.047, max_depth=4, n_estimators=171, subsample=0.6)

xg_reg.fit(X_train, y_train)
preds = xg_reg.predict(X_test)

# %%
preds
# Out:
# array([0.02676913, 0.01692116, 1.9646041 , ..., 1.1928705 , 0.01639271,
#        0.01639271], dtype=float32)

# %%
remaining_season_df['predicted_points'] = preds

# %%
remaining_season_df
# Out:
#       gw                     team      opponent_team  \
# 91    15                  Arsenal            Chelsea
# 92    15                  Arsenal            Chelsea
# 93    15                  Arsenal            Chelsea
# 94    15                  Arsenal            Chelsea
# 95    15                  Arsenal            Chelsea
# ...   ..                      ...                ...
# 7418  38  Wolverhampton Wanderers  Manchester United
# 7419  38  Wolverhampton Wanderers  Manchester United
# 7420  38  Wolverhampton Wanderers  Manchester United
# 7421  38  Wolverhampton Wanderers  Manchester United
# 7422  38  Wolverhampton Wanderers  Manchester United
#
#                           player  position  price  play_proba  short_name  \
# 91                    Mesut_Özil         3    6.8        0.00        Özil
# 92     Sokratis_Papastathopoulos         2    4.8        0.00    Sokratis
# 93    David_Luiz Moreira Marinho         2    5.4        1.00  David Luiz
# 94     Pierre-Emerick_Aubameyang         3   11.4        0.75  Aubameyang
# 95                 Cédric_Soares         2    4.6        1.00      Cédric
# ...                          ...       ...    ...         ...         ...
# 7418             Meritan_Shabani         3    4.5        1.00     Shabani
# 7419             Rayan_Ait Nouri         2    5.0        1.00   Ait Nouri
# 7420               Owen_Otasowie         3    4.5        1.00    Otasowie
# 7421               Theo_Corbeanu         3    4.5        1.00    Corbeanu
# 7422                Taylor_Perry         3    4.5        1.00       Perry
#
#       was_home  relative_market_value_team  \
# 91        True                    1.317380
# 92        True                    1.317380
# 93        True                    1.317380
# 94        True                    1.317380
# 95        True                    1.317380
# ...        ...                         ...
# 7418      True                    0.910778
# 7419      True                    0.910778
# 7420      True                    0.910778
# 7421      True                    0.910778
# 7422      True                    0.910778
#
#       relative_market_value_opponent_team season  minutes  total_points  \
# 91                                1.85944   2021      0.0             0
# 92                                1.85944   2021      0.0             0
# 93                                1.85944   2021     67.5             0
# 94                                1.85944   2021     54.0             0
# 95                                1.85944   2021      1.0             0
# ...                                   ...    ...      ...           ...
# 7418                              1.69599   2021      0.0             0
# 7419                              1.69599   2021     15.6             0
# 7420                              1.69599   2021     20.8             0
# 7421                              1.69599   2021      0.0             0
# 7422                              1.69599   2021      0.0             0
#
#      kickoff_time  predicted_points
# 91     9999-99-99          0.026769
# 92     9999-99-99          0.016921
# 93     9999-99-99          1.964604
# 94     9999-99-99          1.745235
# 95     9999-99-99          0.870770
# ...           ...               ...
# 7418   9999-99-99          0.016393
# 7419   9999-99-99          1.168844
# 7420   9999-99-99          1.192870
# 7421   9999-99-99          0.016393
# 7422   9999-99-99          0.016393
#
# [14855 rows x 16 columns]

# %%
remaining_season_df[remaining_season_df['gw'] == next_gw].sort_values(by='predicted_points', ascending=False).head(50)
# Out:
#       gw                     team             opponent_team  \
# 261   15                Liverpool      West Bromwich Albion
# 285   15          Manchester City          Newcastle United
# 7802  15        Tottenham Hotspur   Wolverhampton Wanderers
# 256   15                Liverpool      West Bromwich Albion
# 289   15          Manchester City          Newcastle United
# 7804  15        Tottenham Hotspur   Wolverhampton Wanderers
# 227   15           Leicester City         Manchester United
# 258   15                Liverpool      West Bromwich Albion
# 7597  15              Southampton                    Fulham
# 198   15                    Leeds                   Burnley
# 7651  15        Manchester United            Leicester City
# 266   15                Liverpool      West Bromwich Albion
# 7536  15                  Chelsea                   Arsenal
# 7744  15                  Everton          Sheffield United
# 262   15                Liverpool      West Bromwich Albion
# 7581  15              Southampton                    Fulham
# 7751  15                  Everton          Sheffield United
# 152   15              Aston Villa            Crystal Palace
# 341   15          West Ham United  Brighton and Hove Albion
# 7797  15        Tottenham Hotspur   Wolverhampton Wanderers
# 291   15          Manchester City          Newcastle United
# 134   15              Aston Villa            Crystal Palace
# 351   15          West Ham United  Brighton and Hove Albion
# 7655  15        Manchester United            Leicester City
# 284   15          Manchester City          Newcastle United
# 306   15          Manchester City          Newcastle United
# 7567  15           Crystal Palace               Aston Villa
# 355   15          West Ham United  Brighton and Hove Albion
# 7591  15              Southampton                    Fulham
# 384   15  Wolverhampton Wanderers         Tottenham Hotspur
# 7545  15                  Chelsea                   Arsenal
# 362   15          West Ham United  Brighton and Hove Albion
# 124   15              Aston Villa            Crystal Palace
# 7620  15                  Burnley                     Leeds
# 355                              0.534079   2021  81.000000             0
# 7591                             0.486303   2021  90.000000             0
# 384                              1.669460   2021  87.600000             0
# 7545                             1.317380   2021  90.000000             0
# 362                              0.534079   2021  88.800000             0
# 124                              0.474342   2021  90.000000             0
# 7620                             0.439606   2021  79.200000             0
# 7547                             1.317380   2021  90.000000             0
# 7595                             0.486303   2021  90.000000             0
# 217                              0.341918   2021  88.800000             0
# 234                              1.695990   2021  86.800000             0
# 194                              0.341918   2021  80.600000             0
# 184                              0.535315   2021  89.200000             0
# 250                              0.255967   2021  85.600000             0
# 251                              0.255967   2021  87.500000             0
# 7583                             0.486303   2021  90.000000             0
# 7584                             0.486303   2021  90.000000             0
# 259                              0.255967   2021  67.500000             0
# 199                              0.341918   2021  78.250000             0
# 379                              1.669460   2021  81.600000             0
# 151                              0.474342   2021  89.000000             0
# 7575                             0.733614   2021  82.200000             0
# 7803                             0.910778   2021  83.250000             0
#
#      kickoff_time  predicted_points
# 261    9999-99-99          6.822416
# 285    9999-99-99          6.604663
# 7802   9999-99-99          6.585641
# 256    9999-99-99          6.289239
# 289    9999-99-99          6.164451
# 7804   9999-99-99          6.141796
# 227    9999-99-99          6.096792
# 258    9999-99-99          6.069838
# 7597   9999-99-99          5.876266
# 198    9999-99-99          5.747579
# 7651   9999-99-99          5.689777
# 266    9999-99-99          5.598053
# 7536   9999-99-99          5.326263
# 7744   9999-99-99          5.133226
# 262    9999-99-99          5.001408
# 7581   9999-99-99          4.863936
# 7751   9999-99-99          4.813278
# 152    9999-99-99          4.782923
# 341    9999-99-99          4.775355
# 7797   9999-99-99          4.710246
# 291    9999-99-99          4.702661
# 134    9999-99-99          4.641900
# 351    9999-99-99          4.612205
# 7655   9999-99-99          4.570212
# 284    9999-99-99          4.569495
# 306    9999-99-99          4.562300
# 7567   9999-99-99          4.561530
# 355    9999-99-99          4.546058
# 7591   9999-99-99          4.470782
# 384    9999-99-99          4.428493
# 7545   9999-99-99          4.395183
# 362    9999-99-99          4.386338
# 124    9999-99-99          4.383878
# 7620   9999-99-99          4.318917
# 7547   9999-99-99          4.265738
# 7595   9999-99-99          4.210851
# 217    9999-99-99          4.195327
# 234    9999-99-99          4.189656
# 194    9999-99-99          4.186702
# 184    9999-99-99          4.181923
# 250    9999-99-99          4.179337
# 251    9999-99-99          4.169359
# 7583   9999-99-99          4.162642
# 7584   9999-99-99          4.123225
# 259    9999-99-99          4.112514
# 199    9999-99-99          4.102761
# 379    9999-99-99          4.061003
# 151    9999-99-99          4.017305
# 7575   9999-99-99          3.997034
# 7803   9999-99-99          3.996788

# %%
# rename previous week's predictions file
# generate previous week's filename
last_gw = next_gw - 1
filename = 'history/2020-21/predictions_gw' + str(last_gw) + '.csv'
# windows
! move predictions.csv $filename
# linux
# ! mv predictions.csv $filename
# Out:
#         1 file(s) moved.

# %%
# write to predictions.csv
## RENAME PREVIOUS WEEK FIRST
predictions = remaining_season_df[['gw', 'player', 'team', 'opponent_team', 
                                   'position', 'price', 'play_proba', 'short_name',
                                   'was_home', 'predicted_points', 'minutes']]
predictions.to_csv('predictions.csv')
