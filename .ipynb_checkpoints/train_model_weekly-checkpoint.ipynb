# %%
# import required packages
# from fastai2.tabular.all import *
import xgboost as xgb
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.feature_extraction import DictVectorizer
from helpers import *

pd.options.display.max_columns = None

# %%
# path to project directory
path = Path('./')

# %%
# read in training dataset
train_df = pd.read_csv(path/'data/train_v7.csv', index_col=0, dtype={'season':str,
                                                                     'squad':str,
                                                                     'comp':str})

# %%
train_df.shape
# Out:
# (99563, 60)

# %%
# features for model
season = '2021'
cat_vars = ['season', 'position', 'was_home']
cont_vars = ['gw', 'minutes']
dep_var = ['total_points']

# find the latest gameweek
last_gw = train_df['gw'][train_df['season'] == season].max()

if np.isnan(last_gw): 
    next_gw = 1 
else: 
    next_gw = last_gw + 1
    
next_gw
# Out:
# 17

# %%
# read in remaining_season.csv and sort
remaining_season_df = pd.read_csv(path/'data/remaining_season.csv', 
                                  index_col=0).sort_values(by=['gw', 'team'])

remaining_season_df['season'] = season
remaining_season_df['total_points'] = 0
remaining_season_df['kickoff_time'] = '9999-99-99'

# append remaining season to end of training set
train_df = train_df.append(remaining_season_df, sort=False).reset_index(drop=True)

# %%
# add player lag features
# lag_train_df, team_lag_vars = team_lag_features(train_df, ['total_points'], ['all', 1, 2, 3, 4, 5, 10])
# lag_train_df, player_lag_vars = player_lag_features(lag_train_df, ['total_points'], 
#                                                     ['all', 1, 2, 3, 4, 5, 10])

lag_train_df, team_lag_vars = team_lag_features(train_df, ['total_points', 'xg'], [5, 10, 20])
lag_train_df, player_lag_vars = player_lag_features(lag_train_df, ['total_points'], 
                                                    ['all', 3, 5, 10, 20, 38])

# %%
# manually add team pg conceded fields for xg 
team_lag_vars += [x.replace('team', 'team_conceded') for x in team_lag_vars if 'xg' in x]

# %%
# we want to set gw and season as ordered categorical variables
# need lists with ordered categories
ordered_gws = list(range(1,39))
ordered_seasons = ['1617', '1718', '1819', '1920', '2021']

# set as categories with correct order 
lag_train_df['gw'] = lag_train_df['gw'].astype('category')
lag_train_df['season'] = lag_train_df['season'].astype('category')

lag_train_df['gw'].cat.set_categories(ordered_gws, ordered=True, inplace=True)
lag_train_df['season'].cat.set_categories(ordered_seasons, ordered=True, inplace=True)

# %%
# create dataset with latest lag numbers for all future gameweeks
valid_season = '2021'
valid_gw = next_gw
valid_len = 38 - next_gw + 1

train_predict_df, train_idx, valid_idx = create_lag_train(lag_train_df, 
                                                      cat_vars, cont_vars, 
                                                      player_lag_vars, team_lag_vars, dep_var,
                                                      valid_season, valid_gw, valid_len)

# %%
# take a look at the dataframe
train_predict_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113433 entries, 0 to 113432
# Data columns (total 39 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   gw                                     113433 non-null  category
#  1   minutes                                113433 non-null  float64
#  2   minutes_last_10                        113433 non-null  float64
#  3   minutes_last_20                        113433 non-null  float64
#  4   minutes_last_3                         113433 non-null  float64
#  5   minutes_last_38                        113433 non-null  float64
#  6   minutes_last_5                         113433 non-null  float64
#  7   minutes_last_all                       113433 non-null  float64
#  8   opponent_team                          113433 non-null  object
#  9   player                                 113433 non-null  object
#  10  position                               113433 non-null  int64
#  11  season                                 113433 non-null  category
#  12  team                                   113433 non-null  object
#  13  total_points                           113433 non-null  int64
#  14  total_points_pg_last_10                79657 non-null   float64
#  15  total_points_pg_last_20                87873 non-null   float64
#  16  total_points_pg_last_3                 66218 non-null   float64
#  17  total_points_pg_last_38                94014 non-null   float64
#  18  total_points_pg_last_5                 71891 non-null   float64
#  19  total_points_pg_last_all               96582 non-null   float64
#  20  total_points_team_pg_last_10           112651 non-null  float64
#  21  total_points_team_pg_last_10_opponent  112647 non-null  float64
#  22  total_points_team_pg_last_20           112651 non-null  float64
#  23  total_points_team_pg_last_20_opponent  112647 non-null  float64
#  24  total_points_team_pg_last_5            112651 non-null  float64
#  25  total_points_team_pg_last_5_opponent   112647 non-null  float64
#  26  was_home                               113433 non-null  bool
#  27  xg_team_conceded_pg_last_10            112649 non-null  float64
#  28  xg_team_conceded_pg_last_10_opponent   112647 non-null  float64
#  29  xg_team_conceded_pg_last_20            112649 non-null  float64
#  30  xg_team_conceded_pg_last_20_opponent   112647 non-null  float64
#  31  xg_team_conceded_pg_last_5             112649 non-null  float64
#  32  xg_team_conceded_pg_last_5_opponent    112647 non-null  float64
#  33  xg_team_pg_last_10                     112651 non-null  float64
#  34  xg_team_pg_last_10_opponent            112647 non-null  float64
#  35  xg_team_pg_last_20                     112651 non-null  float64
#  36  xg_team_pg_last_20_opponent            112647 non-null  float64
#  37  xg_team_pg_last_5                      112651 non-null  float64
#  38  xg_team_pg_last_5_opponent             112647 non-null  float64
# dtypes: bool(1), category(2), float64(31), int64(2), object(3)
# memory usage: 31.5+ MB

# %%
# split out dependent variable
X, y = train_predict_df[cat_vars + cont_vars + player_lag_vars + team_lag_vars].copy(), train_predict_df[dep_var].copy()

# %%
# since position is categorical, it should be a string
X['position'] = X['position'].apply(str)

# need to transform season
enc = LabelEncoder()
X['season'] = enc.fit_transform(X['season'])
X_dict = X.to_dict("records")

# Create the DictVectorizer object: dv
dv = DictVectorizer(sparse=False, separator='_')

# Apply dv on df: df_encoded
X_encoded = dv.fit_transform(X_dict)

X_df = pd.DataFrame(X_encoded, columns=dv.feature_names_)

# %%
# split out training and prediction sets
X_train = X_df.iloc[train_idx]
y_train = y.iloc[train_idx]
X_test = X_df.iloc[valid_idx]
y_test = y.iloc[valid_idx]

# %%
# instatiate and train XGB Regressor
# xg_reg = xgb.XGBRegressor(objective="reg:squarederror",
#                           gamma=0.42, learning_rate=0.047, max_depth=4, n_estimators=171, subsample=0.6)

xg_reg = xgb.XGBRegressor(objective="reg:squarederror",
                                  gamma=0.34, learning_rate=0.088, max_depth=5, n_estimators=55, subsample=0.78)

xg_reg.fit(X_train, y_train)
preds = xg_reg.predict(X_test)

# %%
preds
# Out:
# array([ 5.8003366e-03,  1.0671347e-02,  1.0525670e+00, ...,
#        -5.3465366e-04, -5.3465366e-04, -5.3465366e-04], dtype=float32)

# %%
remaining_season_df['predicted_points'] = preds

# %%
remaining_season_df
# Out:
#       gw                     team         opponent_team  \
# 7370  17                  Arsenal  West Bromwich Albion
# 7371  17                  Arsenal  West Bromwich Albion
# 7372  17                  Arsenal  West Bromwich Albion
# 7373  17                  Arsenal  West Bromwich Albion
# 7374  17                  Arsenal  West Bromwich Albion
# ...   ..                      ...                   ...
# 6924  38  Wolverhampton Wanderers     Manchester United
# 6925  38  Wolverhampton Wanderers     Manchester United
# 6926  38  Wolverhampton Wanderers     Manchester United
# 6927  38  Wolverhampton Wanderers     Manchester United
# 6928  38  Wolverhampton Wanderers     Manchester United
#
#                           player  position  price  play_proba  short_name  \
# 7370                  Mesut Özil         3    6.8        0.00        Özil
# 7371   Sokratis Papastathopoulos         2    4.8        0.00    Sokratis
# 7372  David Luiz Moreira Marinho         2    5.4        0.75  David Luiz
# 7373   Pierre-Emerick Aubameyang         3   11.4        1.00  Aubameyang
# 7374               Cédric Soares         2    4.6        1.00      Cédric
# ...                          ...       ...    ...         ...         ...
# 6924               Theo Corbeanu         3    4.5        1.00    Corbeanu
# 6925                Taylor Perry         3    4.5        1.00       Perry
# 6926                 Luke Cundle         3    4.5        1.00      Cundle
# 6927              Lewis Richards         2    4.0        1.00    Richards
# 6928           Christian Marques         2    4.0        1.00     Marques
#
#       was_home  relative_market_value_team  \
# 7370     False                    1.316625
# 7371     False                    1.316625
# 7372     False                    1.316625
# 7373     False                    1.316625
# 7374     False                    1.316625
# ...        ...                         ...
# 6924      True                    0.910256
# 6925      True                    0.910256
# 6926      True                    0.910256
# 6927      True                    0.910256
# 6928      True                    0.910256
#
#       relative_market_value_opponent_team season  minutes  total_points  \
# 7370                             0.255820   2021     0.00             0
# 7371                             0.255820   2021     0.00             0
# 7372                             0.255820   2021    33.75             0
# 7373                             0.255820   2021    67.50             0
# 7374                             0.255820   2021     1.00             0
# ...                                   ...    ...      ...           ...
# 6924                             1.695018   2021     0.00             0
# 6925                             1.695018   2021     0.00             0
# 6926                             1.695018   2021     0.00             0
# 6927                             1.695018   2021     0.00             0
# 6928                             1.695018   2021     0.00             0
#
#      kickoff_time  predicted_points
# 7370   9999-99-99          0.005800
# 7371   9999-99-99          0.010671
# 7372   9999-99-99          1.052567
# 7373   9999-99-99          4.255922
# 7374   9999-99-99          0.931585
# ...           ...               ...
# 6924   9999-99-99         -0.000535
# 6925   9999-99-99         -0.000535
# 6926   9999-99-99         -0.000535
# 6927   9999-99-99         -0.000535
# 6928   9999-99-99         -0.000535
#
# [13870 rows x 16 columns]

# %%
remaining_season_df[remaining_season_df['gw'] == next_gw].sort_values(by='predicted_points', ascending=False).head(50)

# %%
remaining_season_df[remaining_season_df['gw'] == next_gw].sort_values(by='predicted_points', ascending=False).head(50)
# Out:
#       gw                      team             opponent_team  \
# 7288  17            Leicester City          Newcastle United
# 7322  17                 Liverpool               Southampton
# 7319  17                 Liverpool               Southampton
# 407   17         Tottenham Hotspur                     Leeds
# 7327  17                 Liverpool               Southampton
# 196   17                   Burnley                    Fulham
# 7173  17           Manchester City                   Chelsea
# 251   17            Crystal Palace          Sheffield United
# 282   17                   Everton           West Ham United
# 7169  17           Manchester City                   Chelsea
# 405   17         Tottenham Hotspur                     Leeds
# 275   17                   Everton           West Ham United
# 7317  17                 Liverpool               Southampton
# 7349  17                     Leeds         Tottenham Hotspur
# 7323  17                 Liverpool               Southampton
# 305   17         Manchester United               Aston Villa
# 316   17         Manchester United               Aston Villa
# 260   17            Crystal Palace          Sheffield United
# 7113  17   Wolverhampton Wanderers  Brighton and Hove Albion
# 193   17                   Burnley                    Fulham
# 252   17            Crystal Palace          Sheffield United
# 7298  17            Leicester City          Newcastle United
# 320   17         Manchester United               Aston Villa
# 7392                             0.255820   2021  88.000000             0
# 281                              0.666121   2021  83.750000             0
# 200                              0.486024   2021  82.666667             0
# 7235                             1.144393   2021  87.200000             0
# 284                              0.666121   2021  86.750000             0
# 289                              0.666121   2021  89.750000             0
# 247                              0.386932   2021  90.000000             0
# 291                              0.666121   2021  89.666667             0
# 7373                             0.255820   2021  67.500000             0
# 317                              0.733193   2021  69.750000             0
# 7368                             1.668504   2021  83.800000             0
# 257                              0.386932   2021  82.000000             0
# 7320                             0.535009   2021  90.000000             0
# 7281                             0.602306   2021  90.000000             0
# 7377                             0.255820   2021  90.000000             0
# 7158                             0.341722   2021  89.000000             0
# 7108                             0.541862   2021  78.800000             0
# 400                              0.439354   2021  90.000000             0
# 7259                             1.695018   2021  90.000000             0
# 226                              2.381811   2021  86.600000             0
# 7350                             1.668504   2021  81.000000             0
# 388                              2.471691   2021  80.200000             0
# 7175                             1.858374   2021  90.000000             0
# 174                              0.910256   2021  86.200000             0
# 231                              2.381811   2021  70.600000             0
# 7302                             0.602306   2021  90.000000             0
#
#      kickoff_time  predicted_points
# 7288   9999-99-99          8.645499
# 7322   9999-99-99          6.898355
# 7319   9999-99-99          6.638753
# 407    9999-99-99          5.716894
# 7327   9999-99-99          5.636406
# 196    9999-99-99          5.481269
# 7173   9999-99-99          5.403155
# 251    9999-99-99          5.393681
# 282    9999-99-99          5.348070
# 7169   9999-99-99          5.316530
# 405    9999-99-99          5.282135
# 275    9999-99-99          5.272251
# 7317   9999-99-99          5.198937
# 7349   9999-99-99          5.145641
# 7323   9999-99-99          5.135022
# 305    9999-99-99          5.090796
# 316    9999-99-99          5.068451
# 260    9999-99-99          4.996060
# 7113   9999-99-99          4.956099
# 193    9999-99-99          4.857845
# 252    9999-99-99          4.821811
# 7298   9999-99-99          4.817049
# 320    9999-99-99          4.692509
# 201    9999-99-99          4.676000
# 7392   9999-99-99          4.671886
# 281    9999-99-99          4.537294
# 200    9999-99-99          4.514257
# 7235   9999-99-99          4.374178
# 284    9999-99-99          4.359985
# 289    9999-99-99          4.289923
# 247    9999-99-99          4.276633
# 291    9999-99-99          4.258698
# 7373   9999-99-99          4.255922
# 317    9999-99-99          4.221545
# 7368   9999-99-99          4.175535
# 257    9999-99-99          4.131444
# 7320   9999-99-99          4.107435
# 7281   9999-99-99          3.965441
# 7377   9999-99-99          3.965334
# 7158   9999-99-99          3.962997
# 7108   9999-99-99          3.946606
# 400    9999-99-99          3.945618
# 7259   9999-99-99          3.908726
# 226    9999-99-99          3.889549
# 7350   9999-99-99          3.854422
# 388    9999-99-99          3.815252
# 7175   9999-99-99          3.755591
# 174    9999-99-99          3.734435
# 231    9999-99-99          3.712193
# 7302   9999-99-99          3.687920

# %%
# rename previous week's predictions file
# generate previous week's filename
last_gw = next_gw - 1
filename = 'history/2020-21/predictions_gw' + str(last_gw) + '.csv'
# windows
! move predictions.csv $filename
# linux
# ! mv predictions.csv $filename
# Out:
#         1 file(s) moved.

# %%
# write to predictions.csv
## RENAME PREVIOUS WEEK FIRST
predictions = remaining_season_df[['gw', 'player', 'team', 'opponent_team', 
                                   'position', 'price', 'play_proba', 'short_name',
                                   'was_home', 'predicted_points', 'minutes']]
predictions.to_csv('predictions.csv')
