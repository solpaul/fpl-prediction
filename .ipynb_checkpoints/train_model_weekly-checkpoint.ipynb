# %%
# import required packages
# from fastai2.tabular.all import *
import xgboost as xgb
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.feature_extraction import DictVectorizer
from helpers import *

pd.options.display.max_columns = None

# %%
# path to project directory
path = Path('./')

# %%
# read in training dataset
train_df = pd.read_csv(path/'data/train_v5.csv', index_col=0, dtype={'season':str})

# %%
train_df.shape
# Out:
# (94888, 37)

# %%
# features for model
season = '2021'
cat_vars = ['season', 'position', 'was_home']
cont_vars = ['gw', 'minutes']
dep_var = ['total_points']

# find the latest gameweek
last_gw = train_df['gw'][train_df['season'] == season].max()

if np.isnan(last_gw): 
    next_gw = 1 
else: 
    next_gw = last_gw + 1
    
next_gw
# Out:
# 9

# %%
# read in remaining_season.csv and sort
remaining_season_df = pd.read_csv(path/'data/remaining_season.csv', 
                                  index_col=0).sort_values(by=['gw', 'team'])

remaining_season_df['season'] = season
remaining_season_df['total_points'] = 0
remaining_season_df['kickoff_time'] = '9999-99-99'

# append remaining season to end of training set
train_df = train_df.append(remaining_season_df, sort=False).reset_index(drop=True)

# %%
# add player lag features
lag_train_df, team_lag_vars = team_lag_features(train_df, ['total_points'], ['all', 1, 2, 3, 4, 5, 10])
lag_train_df, player_lag_vars = player_lag_features(lag_train_df, ['total_points'], 
                                                    ['all', 1, 2, 3, 4, 5, 10])

# %%
# we want to set gw and season as ordered categorical variables
# need lists with ordered categories
ordered_gws = list(range(1,39))
ordered_seasons = ['1617', '1718', '1819', '1920', '2021']

# set as categories with correct order 
lag_train_df['gw'] = lag_train_df['gw'].astype('category')
lag_train_df['season'] = lag_train_df['season'].astype('category')

lag_train_df['gw'].cat.set_categories(ordered_gws, ordered=True, inplace=True)
lag_train_df['season'].cat.set_categories(ordered_seasons, ordered=True, inplace=True)

# %%
# create dataset with latest lag numbers for all future gameweeks
valid_season = '2021'
valid_gw = next_gw
valid_len = 38 - next_gw + 1

train_predict_df, train_idx, valid_idx = create_lag_train(lag_train_df, 
                                                      cat_vars, cont_vars, 
                                                      player_lag_vars, team_lag_vars, dep_var,
                                                      valid_season, valid_gw, valid_len)

# %%
# take a look at the dataframe
train_predict_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113012 entries, 0 to 113011
# Data columns (total 37 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   gw                                      113012 non-null  category
#  1   minutes                                 113012 non-null  float64
#  2   minutes_last_1                          113012 non-null  float64
#  3   minutes_last_10                         113012 non-null  float64
#  4   minutes_last_2                          113012 non-null  float64
#  5   minutes_last_3                          113012 non-null  float64
#  6   minutes_last_4                          113012 non-null  float64
#  7   minutes_last_5                          113012 non-null  float64
#  8   minutes_last_all                        113012 non-null  float64
#  9   opponent_team                           113012 non-null  object
#  10  player                                  113012 non-null  object
#  11  position                                113012 non-null  int64
#  12  season                                  113012 non-null  category
#  13  team                                    113012 non-null  object
#  14  total_points                            113012 non-null  int64
#  15  total_points_pg_last_1                  51841 non-null   float64
#  16  total_points_pg_last_10                 80562 non-null   float64
#  17  total_points_pg_last_2                  60657 non-null   float64
#  18  total_points_pg_last_3                  65510 non-null   float64
#  19  total_points_pg_last_4                  69241 non-null   float64
#  20  total_points_pg_last_5                  71952 non-null   float64
#  21  total_points_pg_last_all                96229 non-null   float64
#  22  total_points_team_pg_last_1             112230 non-null  float64
#  23  total_points_team_pg_last_10            112230 non-null  float64
#  24  total_points_team_pg_last_10_opponent   112226 non-null  float64
#  25  total_points_team_pg_last_1_opponent    112226 non-null  float64
#  26  total_points_team_pg_last_2             112230 non-null  float64
#  27  total_points_team_pg_last_2_opponent    112226 non-null  float64
#  28  total_points_team_pg_last_3             112230 non-null  float64
#  29  total_points_team_pg_last_3_opponent    112226 non-null  float64
#  30  total_points_team_pg_last_4             112230 non-null  float64
#  31  total_points_team_pg_last_4_opponent    112226 non-null  float64
#  32  total_points_team_pg_last_5             112230 non-null  float64
#  33  total_points_team_pg_last_5_opponent    112226 non-null  float64
#  34  total_points_team_pg_last_all           112230 non-null  float64
#  35  total_points_team_pg_last_all_opponent  112226 non-null  float64
#  36  was_home                                113012 non-null  bool
# dtypes: bool(1), category(2), float64(29), int64(2), object(3)
# memory usage: 29.6+ MB

# %%
# split out dependent variable
X, y = train_predict_df[cat_vars + cont_vars + player_lag_vars + team_lag_vars].copy(), train_predict_df[dep_var].copy()

# %%
# since position is categorical, it should be a string
X['position'] = X['position'].apply(str)

# need to transform season
enc = LabelEncoder()
X['season'] = enc.fit_transform(X['season'])
X_dict = X.to_dict("records")

# Create the DictVectorizer object: dv
dv = DictVectorizer(sparse=False, separator='_')

# Apply dv on df: df_encoded
X_encoded = dv.fit_transform(X_dict)

X_df = pd.DataFrame(X_encoded, columns=dv.feature_names_)

# %%
# split out training and prediction sets
X_train = X_df.iloc[train_idx]
y_train = y.iloc[train_idx]
X_test = X_df.iloc[valid_idx]
y_test = y.iloc[valid_idx]

# %%
# instatiate and train XGB Regressor
xg_reg = xgb.XGBRegressor(objective="reg:squarederror",
                          gamma=0.42, learning_rate=0.047, max_depth=4, n_estimators=171, subsample=0.6)

xg_reg.fit(X_train, y_train)
preds = xg_reg.predict(X_test)

# %%
preds
# Out:
# array([-5.0364733e-03,  4.9656630e-04,  8.8962215e-01, ...,
#        -1.0004401e-02,  1.4355645e+00, -1.0004401e-02], dtype=float32)

# %%
remaining_season_df['predicted_points'] = preds

# %%
remaining_season_df
# Out:
#       gw                     team      opponent_team  \
# 9216   9                  Arsenal              Leeds
# 9217   9                  Arsenal              Leeds
# 9218   9                  Arsenal              Leeds
# 9219   9                  Arsenal              Leeds
# 9220   9                  Arsenal              Leeds
# ...   ..                      ...                ...
# 9053  38  Wolverhampton Wanderers  Manchester United
# 9054  38  Wolverhampton Wanderers  Manchester United
# 9055  38  Wolverhampton Wanderers  Manchester United
# 9056  38  Wolverhampton Wanderers  Manchester United
# 9057  38  Wolverhampton Wanderers  Manchester United
#
#                           player  position  price  play_proba  short_name  \
# 9216                  Mesut_Özil         3    6.8         0.0        Özil
# 9217   Sokratis_Papastathopoulos         2    4.9         0.0    Sokratis
# 9218  David_Luiz Moreira Marinho         2    5.5         1.0  David Luiz
# 9219   Pierre-Emerick_Aubameyang         3   11.7         1.0  Aubameyang
# 9220               Cédric_Soares         2    4.7         1.0      Cédric
# ...                          ...       ...    ...         ...         ...
# 9053              Ki-Jana_Hoever         2    4.5         1.0      Hoever
# 9054        Nélson_Cabral Semedo         2    5.5         1.0      Semedo
# 9055             Meritan_Shabani         3    4.5         1.0     Shabani
# 9056             Rayan_Ait Nouri         2    5.0         1.0   Ait Nouri
# 9057               Owen_Otasowie         3    4.5         1.0    Otasowie
#
#       was_home  relative_market_value_team  \
# 9216     False                    1.417772
# 9217     False                    1.417772
# 9218     False                    1.417772
# 9219     False                    1.417772
# 9220     False                    1.417772
# ...        ...                         ...
# 9053      True                    0.870249
# 9054      True                    0.870249
# 9055      True                    0.870249
# 9056      True                    0.870249
# 9057      True                    0.870249
#
#       relative_market_value_opponent_team season  minutes  total_points  \
# 9216                             0.406812   2021     0.00             0
# 9217                             0.406812   2021     0.00             0
# 9218                             0.406812   2021    57.00             0
# 9219                             0.406812   2021    90.00             0
# 9220                             0.406812   2021     0.00             0
# ...                                   ...    ...      ...           ...
# 9053                             1.794454   2021     3.00             0
# 9054                             1.794454   2021    86.75             0
# 9055                             1.794454   2021     0.00             0
# 9056                             1.794454   2021    25.00             0
# 9057                             1.794454   2021     0.00             0
#
#      kickoff_time  predicted_points
# 9216   9999-99-99         -0.005036
# 9217   9999-99-99          0.000497
# 9218   9999-99-99          0.889622
# 9219   9999-99-99          5.271476
# 9220   9999-99-99         -0.005036
# ...           ...               ...
# 9053   9999-99-99          1.120619
# 9054   9999-99-99          3.925999
# 9055   9999-99-99         -0.010004
# 9056   9999-99-99          1.435565
# 9057   9999-99-99         -0.010004
#
# [18124 rows x 16 columns]

# %%
remaining_season_df[remaining_season_df['gw'] == next_gw].sort_values(by='predicted_points', ascending=False).head(50)
# Out:
#       gw                      team             opponent_team  \
# 195    9                 Liverpool            Leicester City
# 224    9         Manchester United      West Bromwich Albion
# 310    9         Tottenham Hotspur           Manchester City
# 9320   9                   Chelsea          Newcastle United
# 9219   9                   Arsenal                     Leeds
# 100    9                   Burnley            Crystal Palace
# 161    9                     Leeds                   Arsenal
# 9371   9           Manchester City         Tottenham Hotspur
# 9210   9                   Everton                    Fulham
# 9194   9                   Everton                    Fulham
# 9202   9                   Everton                    Fulham
# 308    9         Tottenham Hotspur           Manchester City
# 190    9                 Liverpool            Leicester City
# 9195   9                   Everton                    Fulham
# 9367   9           Manchester City         Tottenham Hotspur
# 340    9   Wolverhampton Wanderers               Southampton
# 9377   9           Manchester City         Tottenham Hotspur
# 86     9               Aston Villa  Brighton and Hove Albion
# 9406   9               Southampton   Wolverhampton Wanderers
# 9329   9                   Chelsea          Newcastle United
# 68     9               Aston Villa  Brighton and Hove Albion
# 192    9                 Liverpool            Leicester City
# 9331   9                   Chelsea          Newcastle United
# 84     9               Aston Villa  Brighton and Hove Albion
# 290    9          Sheffield United           West Ham United
# 353    9   Wolverhampton Wanderers               Southampton
# 196    9                 Liverpool            Leicester City
# 58     9               Aston Villa  Brighton and Hove Albion
# 213    9         Manchester United      West Bromwich Albion
# 157    9                     Leeds                   Arsenal
# 9257   9            Leicester City                 Liverpool
# 9193   9                   Everton                    Fulham
# 360    9   Wolverhampton Wanderers               Southampton
# 58                               0.517797   2021  90.000000             0
# 213                              0.239044   2021  90.000000             0
# 157                              1.417772   2021  86.500000             0
# 9257                             2.422967   2021  90.000000             0
# 9193                             0.490763   2021  85.250000             0
# 360                              0.491548   2021  86.750000             0
# 9173                             0.341190   2021  90.000000             0
# 9137                             0.699520   2021  90.000000             0
# 148                              1.140365   2021  90.000000             0
# 9355                             0.394966   2021  81.750000             0
# 9242                             0.406812   2021  74.000000             0
# 9328                             0.608770   2021  90.000000             0
# 9305                             1.794454   2021  83.000000             0
# 162                              1.417772   2021  87.000000             0
# 96                               0.503618   2021  77.666667             0
# 105                              0.503618   2021  90.000000             0
# 71                               0.517797   2021  79.500000             0
# 99                               0.503618   2021  83.000000             0
# 85                               0.517797   2021  87.250000             0
# 349                              0.491548   2021  90.000000             0
# 9398                             0.870249   2021  90.000000             0
# 147                              1.140365   2021  90.000000             0
# 220                              0.239044   2021  90.000000             0
#
#      kickoff_time  predicted_points
# 195    9999-99-99          6.128925
# 224    9999-99-99          5.639880
# 310    9999-99-99          5.296147
# 9320   9999-99-99          5.286140
# 9219   9999-99-99          5.271476
# 100    9999-99-99          5.256185
# 161    9999-99-99          5.242399
# 9371   9999-99-99          5.241838
# 9210   9999-99-99          5.231502
# 9194   9999-99-99          5.110126
# 9202   9999-99-99          5.104550
# 308    9999-99-99          5.077491
# 190    9999-99-99          4.953465
# 9195   9999-99-99          4.951359
# 9367   9999-99-99          4.919289
# 340    9999-99-99          4.860633
# 9377   9999-99-99          4.816848
# 86     9999-99-99          4.813831
# 9406   9999-99-99          4.793883
# 9329   9999-99-99          4.750076
# 68     9999-99-99          4.722956
# 192    9999-99-99          4.709712
# 9331   9999-99-99          4.696722
# 84     9999-99-99          4.585966
# 290    9999-99-99          4.566820
# 353    9999-99-99          4.551738
# 196    9999-99-99          4.440389
# 58     9999-99-99          4.419641
# 213    9999-99-99          4.396953
# 157    9999-99-99          4.389310
# 9257   9999-99-99          4.379572
# 9193   9999-99-99          4.378499
# 360    9999-99-99          4.358035
# 9173   9999-99-99          4.344415
# 9137   9999-99-99          4.312791
# 148    9999-99-99          4.295464
# 9355   9999-99-99          4.200824
# 9242   9999-99-99          4.185832
# 9328   9999-99-99          4.177835
# 9305   9999-99-99          4.172611
# 162    9999-99-99          4.151237
# 96     9999-99-99          4.150495
# 105    9999-99-99          4.117789
# 71     9999-99-99          4.111851
# 99     9999-99-99          4.108154
# 85     9999-99-99          4.107718
# 349    9999-99-99          4.091141
# 9398   9999-99-99          4.071821
# 147    9999-99-99          4.071543
# 220    9999-99-99          4.058678

# %%
# rename previous week's predictions file
# generate previous week's filename
last_gw = next_gw - 1
filename = 'history/2020-21/predictions_gw' + str(last_gw) + '.csv'
# windows
! move predictions.csv $filename
# linux
# ! mv predictions.csv $filename
# Out:
#         1 file(s) moved.

# %%
# write to predictions.csv
## RENAME PREVIOUS WEEK FIRST
predictions = remaining_season_df[['gw', 'player', 'team', 'opponent_team', 
                                   'position', 'price', 'play_proba', 'short_name',
                                   'was_home', 'predicted_points', 'minutes']]
predictions.to_csv('predictions.csv')
