# %%
# import required packages
from fastai2.tabular.all import *
from helpers import *

# %%
# path to project directory
path = Path('./')

# %%
# read in training dataset
train_df = pd.read_csv(path/'data/train_v4.csv', index_col=0, dtype={'season':str})

# %%
train_df.tail()
# Out:
#                 player  gw  position  minutes               team  \
# 90432      Tommy_Doyle  38         3        0    Manchester City
# 90433     Joseph_Anang  38         1        0    West Ham United
# 90434     Erik_Pieters  38         2       90            Burnley
# 90435  Japhet_Tanganga  38         2        0  Tottenham Hotspur
# 90436   Ravel_Morrison  38         3        0   Sheffield United
#
#                   opponent_team  relative_market_value_team  \
# 90432                   Norwich                    2.430397
# 90433               Aston Villa                    0.709989
# 90434  Brighton and Hove Albion                    0.370648
# 90435            Crystal Palace                    1.604904
# 90436               Southampton                    0.348678
#
#        relative_market_value_opponent_team  was_home  total_points  ...  \
# 90432                             0.327574      True             0  ...
# 90433                             0.553818      True             0  ...
# 90434                             0.541184      True             3  ...
# 90435                             0.430493     False             0  ...
# 90436                             0.526987     False             0  ...
#
#        threat  transfers_balance  transfers_in  transfers_out  yellow_cards  \
# 90432     0.0                 -2            22             24             0
# 90433     0.0                 70           270            200             0
# 90434     2.0             139816        144388           4572             1
# 90435     0.0               7999         14840           6841             0
# 90436     0.0                -23             7             30             0
#
#                kickoff_time  season  play_proba  \
# 90432  2020-07-26T15:00:00Z    1920         1.0
# 90433  2020-07-26T15:00:00Z    1920         1.0
# 90434  2020-07-26T15:00:00Z    1920         1.0
# 90435  2020-07-26T15:00:00Z    1920         1.0
# 90436  2020-07-26T15:00:00Z    1920         0.0
#
#        relative_market_value_team_season  \
# 90432                           2.727025
# 90433                           0.739196
# 90434                           0.441799
# 90435                           2.113981
# 90436                           0.150631
#
#        relative_market_value_opponent_team_season
# 90432                                    0.198300
# 90433                                    0.338194
# 90434                                    0.476156
# 90435                                    0.495374
# 90436                                    0.624210
#
# [5 rows x 37 columns]

# %%
train_df.shape
# Out:
# (90437, 37)

# %%
# parameters for model
season = '2021'
cat_vars = ['gw', 'season', 'position', 'team', 'opponent_team', 'was_home']
cont_vars = ['minutes', 'relative_market_value_team_season', 'relative_market_value_opponent_team_season']
dep_var = ['total_points']

# %%
# we want to set gw and season as ordered categorical variables
# need lists with ordered categories
ordered_gws = list(range(1,39))
ordered_seasons = ['1617', '1718', '1819', '1920']

# %%
# set as categories with correct order 
lag_train_df['gw'] = lag_train_df['gw'].astype('category')
lag_train_df['season'] = lag_train_df['season'].astype('category')

lag_train_df['gw'].cat.set_categories(ordered_gws, ordered=True, inplace=True)
lag_train_df['season'].cat.set_categories(ordered_seasons, ordered=True, inplace=True)

# %%
# dependent variable needs to be float
lag_train_df['total_points'] = lag_train_df['total_points'].astype('float64')

# %%
# find the latest gameweek
last_gw = train_df['gw'][train_df['season'] == season].max()

if np.isnan(last_gw): 
    next_gw = 1 
else: 
    next_gw = last_gw + 1
    
next_gw
# Out:
# 1

# %%
# read in remaining_season.csv
remaining_season_df = pd.read_csv(path/'data/remaining_season.csv', index_col=0)

# %%
remaining_season_df.head(10)
# Out:
#    gw    team opponent_team                   player  position  price  \
# 0   1  Fulham       Arsenal  Fabricio_Agosto Ramírez         1    4.0
# 1   1  Fulham       Arsenal           Kevin_McDonald         3    5.0
# 2   1  Fulham       Arsenal       Maxime_Le Marchand         2    4.5
# 3   1  Fulham       Arsenal          Stefan_Johansen         3    5.0
# 4   1  Fulham       Arsenal              Tom_Cairney         3    5.5
# 5   1  Fulham       Arsenal                 Tim_Ream         2    4.5
# 6   1  Fulham       Arsenal        Anthony_Knockaert         3    5.5
# 7   1  Fulham       Arsenal           Michael_Hector         2    4.5
# 8   1  Fulham       Arsenal           Cyrus_Christie         2    4.5
# 9   1  Fulham       Arsenal          Neeskens_Kebano         3    5.0
#
#    play_proba  was_home  relative_market_value_team  \
# 0         1.0      True                    0.318038
# 1         1.0      True                    0.318038
# 2         1.0      True                    0.318038
# 3         1.0      True                    0.318038
# 4         1.0      True                    0.318038
# 5         1.0      True                    0.318038
# 6         1.0      True                    0.318038
# 7         1.0      True                    0.318038
# 8         1.0      True                    0.318038
# 9         1.0      True                    0.318038
#
#    relative_market_value_opponent_team  season  minutes
# 0                             1.535042    1920     90.0
# 1                             1.535042    1920     90.0
# 2                             1.535042    1920     90.0
# 3                             1.535042    1920     90.0
# 4                             1.535042    1920     90.0
# 5                             1.535042    1920     90.0
# 6                             1.535042    1920     90.0
# 7                             1.535042    1920     90.0
# 8                             1.535042    1920     90.0
# 9                             1.535042    1920     90.0

# %%
# processors - categorify categorical variables and normalize continuous variables
# fill missing not used because new teams are almost certainly well below the league average
procs=[Categorify, Normalize]
to_nn = TabularPandas(lag_train_df, procs, cat_vars + ['player'], cont_vars, #+ player_lag_vars + team_lag_vars,
                      #splits=splits, 
                      y_names=dep_var)

# %%
dls = to_nn.dataloaders()

# %%
dls.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>gw</th>
#       <th>season</th>
#       <th>position</th>
#       <th>team</th>
#       <th>opponent_team</th>
#       <th>was_home</th>
#       <th>player</th>
#       <th>minutes</th>
#       <th>relative_market_value_team</th>
#       <th>relative_market_value_opponent_team</th>
#       <th>total_points</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>21</td>
#       <td>1617</td>
#       <td>3</td>
#       <td>Manchester United</td>
#       <td>Liverpool</td>
#       <td>True</td>
#       <td>Juan_Mata</td>
#       <td>2.600000e+01</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>25</td>
#       <td>1920</td>
#       <td>3</td>
#       <td>West Ham United</td>
#       <td>Brighton and Hove Albion</td>
#       <td>True</td>
#       <td>Manuel_Lanzini</td>
#       <td>4.999999e+00</td>
#       <td>0.740968</td>
#       <td>0.462137</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>24</td>
#       <td>1819</td>
#       <td>1</td>
#       <td>Southampton</td>
#       <td>Crystal Palace</td>
#       <td>True</td>
#       <td>Fraser_Forster</td>
#       <td>5.823472e-08</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>38</td>
#       <td>1920</td>
#       <td>2</td>
#       <td>Arsenal</td>
#       <td>Watford</td>
#       <td>True</td>
#       <td>Calum_Chambers</td>
#       <td>5.823472e-08</td>
#       <td>1.452343</td>
#       <td>0.472917</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>20</td>
#       <td>1718</td>
#       <td>2</td>
#       <td>Everton</td>
#       <td>West Bromwich Albion</td>
#       <td>False</td>
#       <td>Michael_Keane</td>
#       <td>9.000000e+01</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>8.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>18</td>
#       <td>1819</td>
#       <td>3</td>
#       <td>Brighton and Hove Albion</td>
#       <td>Bournemouth</td>
#       <td>False</td>
#       <td>Solomon_March</td>
#       <td>9.000000e+01</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>2.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>1</td>
#       <td>1819</td>
#       <td>4</td>
#       <td>Brighton and Hove Albion</td>
#       <td>Watford</td>
#       <td>False</td>
#       <td>Florin_Andone</td>
#       <td>5.823472e-08</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>27</td>
#       <td>1718</td>
#       <td>3</td>
#       <td>Manchester United</td>
#       <td>Newcastle United</td>
#       <td>False</td>
#       <td>Juan_Mata</td>
#       <td>2.400000e+01</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>22</td>
#       <td>1718</td>
#       <td>3</td>
#       <td>Leicester City</td>
#       <td>Huddersfield Town</td>
#       <td>True</td>
#       <td>Adrien Sebastian_Perruchet Silva</td>
#       <td>4.000000e+00</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>1.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>31</td>
#       <td>1617</td>
#       <td>4</td>
#       <td>Bournemouth</td>
#       <td>Liverpool</td>
#       <td>False</td>
#       <td>Callum_Wilson</td>
#       <td>5.823472e-08</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0.0</td>
#     </tr>
#   </tbody>
# </table>

# %%
# set range of predictions - minimum to current max
max_y = np.max(lag_train_df['total_points'])
min_y = np.min(lag_train_df['total_points'])
y_range = (-1, max_y)

# %%
learn = tabular_learner(dls, y_range=y_range, layers=[1000,500], ps=[0.001,0.01], emb_drop=0.04,
                        n_out=1, loss_func=F.mse_loss, metrics=rmse)

# %%
learn.fit_one_cycle(7, 1e-2, wd=0.2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>_rmse</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.036372</td>
#       <td>None</td>
#       <td>None</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.492450</td>
#       <td>None</td>
#       <td>None</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.812050</td>
#       <td>None</td>
#       <td>None</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.534576</td>
#       <td>None</td>
#       <td>None</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.763046</td>
#       <td>None</td>
#       <td>None</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.230725</td>
#       <td>None</td>
#       <td>None</td>
#       <td>00:18</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.044583</td>
#       <td>None</td>
#       <td>None</td>
#       <td>00:18</td>
#     </tr>
#   </tbody>
# </table>
# /opt/conda/envs/fastai/lib/python3.7/site-packages/fastprogress/fastprogress.py:74: UserWarning: Your generator is empty.
#   warn("Your generator is empty.")

# %%
cont_vars = ['minutes', 'relative_market_value_team', 'relative_market_value_opponent_team']

# %%
to_test = TabularPandas(remaining_season_df, procs, cat_vars + ['player'], cont_vars)#, y_names=dep_var)

# %%
test_dl = dls.test_dl(remaining_season_df)

# %%
preds = learn.get_preds(dl=test_dl)

# %%
preds
# Out:
# (tensor([[3.4369],
#          [2.2753],
#          [2.0237],
#          ...,
#          [2.9834],
#          [2.7172],
#          [4.2082]]),
#  None)

# %%
remaining_season_df['predicted_points'] = preds[0].data.numpy().T[0]

# %%
remaining_season_df.sort_values(by='predicted_points', ascending=False).head(20)
# Out:
#        gw               team             opponent_team  \
# 6684   27          Liverpool                    Fulham
# 6679   27          Liverpool                    Fulham
# 3679   15          Liverpool      West Bromwich Albion
# 6676   27          Liverpool                    Fulham
# 9490   38          Liverpool            Crystal Palace
# 88      1          Liverpool                     Leeds
# 1624    7          Liverpool           West Ham United
# 3676   15          Liverpool      West Bromwich Albion
# 12447  12          Liverpool                    Fulham
# 7686   31          Liverpool               Aston Villa
# 5543   22          Liverpool  Brighton and Hove Albion
# 2661   11    Manchester City                    Fulham
# 9227   37  Manchester United                    Fulham
# 8729   35          Liverpool               Southampton
# 4510   18          Liverpool                   Burnley
# 8224   33          Liverpool          Newcastle United
# 9487   38          Liverpool            Crystal Palace
# 1399    6          Liverpool          Sheffield United
# 2653   11    Manchester City                    Fulham
# 3416   14  Manchester United                     Leeds
#
#                               player  position  price  play_proba  was_home  \
# 6684          Trent_Alexander-Arnold         2    7.5         1.0      True
# 6679                   Mohamed_Salah         3   12.0         1.0      True
# 3679                   Mohamed_Salah         3   12.0         1.0      True
# 6676                      Sadio_Mané         3   12.0         1.0      True
# 9490                   Mohamed_Salah         3   12.0         1.0      True
# 88                     Mohamed_Salah         3   12.0         1.0      True
# 1624                   Mohamed_Salah         3   12.0         1.0      True
# 3676                      Sadio_Mané         3   12.0         1.0      True
# 12447                  Mohamed_Salah         3   12.0         1.0     False
# 7686                   Mohamed_Salah         3   12.0         1.0      True
# 5543                   Mohamed_Salah         3   12.0         1.0      True
# 2661                 Raheem_Sterling         3   11.5         1.0      True
# 9227   Bruno Miguel_Borges Fernandes         3   10.5         1.0      True
# 8729                   Mohamed_Salah         3   12.0         1.0      True
# 4510                   Mohamed_Salah         3   12.0         1.0      True
# 8224                   Mohamed_Salah         3   12.0         1.0      True
# 9487                      Sadio_Mané         3   12.0         1.0      True
# 1399                   Mohamed_Salah         3   12.0         1.0      True
# 2653                   Sergio_Agüero         4   10.5         1.0      True
# 3416   Bruno Miguel_Borges Fernandes         3   10.5         1.0      True
#
#        relative_market_value_team  relative_market_value_opponent_team  \
# 6684                     2.403843                             0.318038
# 6679                     2.403843                             0.318038
# 3679                     2.403843                             0.179463
# 6676                     2.403843                             0.318038
# 9490                     2.403843                             0.444240
# 88                       2.403843                             0.301777
# 1624                     2.403843                             0.684978
# 3676                     2.403843                             0.179463
# 12447                    2.403843                             0.318038
# 7686                     2.403843                             0.556890
# 5543                     2.403843                             0.463683
# 2661                     2.498112                             0.318038
# 9227                     1.890316                             0.318038
# 8729                     2.403843                             0.497737
# 4510                     2.403843                             0.354166
# 8224                     2.403843                             0.626767
# 9487                     2.403843                             0.444240
# 1399                     2.403843                             0.365007
# 2653                     2.498112                             0.318038
# 3416                     1.890316                             0.301777
#
#        season  minutes  predicted_points
# 6684     1920     90.0          9.126164
# 6679     1920     90.0          8.965622
# 3679     1920     90.0          8.675791
# 6676     1920     90.0          8.618359
# 9490     1920     90.0          8.484838
# 88       1920     90.0          8.404057
# 1624     1920     90.0          8.356295
# 3676     1920     90.0          8.333290
# 12447    1920     90.0          8.274717
# 7686     1920     90.0          8.247001
# 5543     1920     90.0          8.245965
# 2661     1920     90.0          8.211056
# 9227     1920     90.0          8.169088
# 8729     1920     90.0          8.161670
# 4510     1920     90.0          8.142046
# 8224     1920     90.0          8.106710
# 9487     1920     90.0          8.090015
# 1399     1920     90.0          8.085204
# 2653     1920     90.0          8.081870
# 3416     1920     90.0          7.976591

# %%
# write to predictions.csv
## RENAME PREVIOUS WEEK FIRST
predictions = remaining_season_df[['gw', 'player', 'team', 'position', 'price', 'play_proba', 'predicted_points']]
predictions.to_csv('predictions.csv')
