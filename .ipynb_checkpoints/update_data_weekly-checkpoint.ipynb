# %%
# import required libriaries
from pathlib import Path
import json

from fpl_predictor.util import *

# %%
# path to data directory
#path = Path('/home/jupyter/fpl-prediction/data')
path = Path('./fpl_predictor/data')

# %%
# read in latest training set
df_train = pd.read_csv(path/'train_v8.csv', index_col=0, 
                       dtype={'season':str,
                              'comp':str,
                              'squad':str})

# path to current season
season_paths = [path/'2021-22']

# name for current season
season_names = ['2122']

# team codes
teams = pd.read_csv(path/'teams.csv')

# latest remaining season dataset, for latest week's play_proba values
remaining_season = pd.read_csv(path/'remaining_season.csv', index_col=0)

# create players dataset
all_players = build_players(path, season_paths, season_names, teams)

# 2019-20 market value
# table was in slightly different position for 2019-20 season
# should check that 2019-20 season values remain the same once season starts
teams_mv = build_season_mv('2122', 11, range(13,33))

# %%
# all_players#[all_players['full_name'] == 'Ben Davies']

# %%
# df_train = df_train.iloc[:-686]

# %%
# find the latest gameweek
last_gw = df_train['gw'][df_train['season'] == season_names[0]].max()

if np.isnan(last_gw): 
    last_gw = 1 
else: 
    last_gw = last_gw + 1
    
last_gw
# Out:
# 23

# %%
# build training set for latest gameweek
df_latest = build_season(season_paths[0], season_names[0], all_players, teams, teams_mv, [last_gw])

# %%
df_latest.drop_duplicates(inplace=True)

# %%
# df_latest[df_latest['player'] == 'Chris Wood']
# lucas digne
# chris wood

# %%
last_play_proba = remaining_season[remaining_season['gw'] == last_gw][['player', 'team', 'play_proba']]

# %%
last_play_proba.head()
# Out:
#            player     team  play_proba
# 0  Moussa Sissoko  Watford         1.0
# 1      Ben Foster  Watford         1.0
# 2      Danny Rose  Watford         1.0
# 3     Dan Gosling  Watford         1.0
# 4  Craig Cathcart  Watford         1.0

# %%
# add latest week's play_proba for each player
df_latest = df_latest.merge(last_play_proba, on=['player', 'team'], how='left')

# %%
df_latest.drop_duplicates(inplace=True)

# %%
df_train.drop_duplicates(inplace=True)

# %%
if last_gw==1:
    df_latest['relative_market_value_team_season'] = df_latest['relative_market_value_team']
    df_latest['relative_market_value_opponent_team_season'] = df_latest['relative_market_value_opponent_team']

# %%
# for when you're doing the season value properly
# relative_market_value_season = train_df[train_df['season'] == '2021'][['team', 'relative_market_value_team']].groupby(['team']).first()
# relative_market_value_season = relative_market_value_season.rename(columns={'relative_market_value_team': 'season_value'})
# relative_market_value_season

# %%
# now get futher stats from fbref
# standard stats
features = ['squad', 'comp', 'round', 'shots_total', 'shots_on_target', 'touches', 'pressures',
            'tackles', 'interceptions', 'blocks', 'xg', 'npxg', 'xa', 'sca', 
            'gca', 'passes_completed', 'passes', 'passes_pct',  'carries', 
            'dribbles_completed', 'dribbles']

# %%
# url for the premier league
url_base = 'https://fbref.com'
pl_history_page = '/en/comps/9/history/Premier-League-Seasons'
url = url_base + pl_history_page

# scrape the history table to get latest season
pl_history_table = get_table(url)
pl_history_urls = get_urls(['season'], 'season', pl_history_table, url_base)
season_urls = pl_history_urls[0:1]

df_enhanced = get_stats(features, season_urls, url_base)
# Out:
# 2021-2022
# https://fbref.com/en/comps/9/Premier-League-Stats
# Manchester City
# https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats
# Ederson
# João Cancelo
# Bernardo Silva
# Rúben Dias
# Rodri
# Aymeric Laporte
# Gabriel Jesus
# Jack Grealish
# Kyle Walker
# Raheem Sterling
# Phil Foden
# Kevin De Bruyne
# İlkay Gündoğan
# Riyad Mahrez
# Nathan Aké
# Fernandinho
# Oleksandr Zinchenko
# John Stones
# Ferrán Torres
# Cole Palmer
# Zack Steffen
# Benjamin Mendy
# James Mcatee
# Liverpool
# https://fbref.com/en/squads/822bd0ba/Liverpool-Stats
# Alisson
# Virgil van Dijk
# Mohamed Salah
# Trent Alexander-Arnold
# Sadio Mané
# Jordan Henderson
# Diogo Jota
# Joël Matip
# Andrew Robertson
# Fabinho
# Alex Oxlade-Chamberlain
# Thiago Alcántara
# Ibrahima Konaté
# James Milner
# Roberto Firmino
# Kostas Tsimikas
# Naby Keïta
# Curtis Jones
# Harvey Elliott
# Caoimhín Kelleher
# Tyler Morton
# Takumi Minamino
# Divock Origi
# Joe Gomez
# Kaide Gordon
# Neco Williams
# Chelsea
# https://fbref.com/en/squads/cff3d9bb/Chelsea-Stats
# Antonio Rüdiger
# Edouard Mendy
# Thiago Silva
# Jorginho
# Mason Mount
# Marcos Alonso
# César Azpilicueta
# Reece James
# Mateo Kovačić
# Kai Havertz
# Romelu Lukaku
# Andreas Christensen
# Callum Hudson-Odoi
# N'Golo Kanté
# Trevoh Chalobah
# Hakim Ziyech
# Christian Pulisic
# Ruben Loftus-Cheek
# Timo Werner
# Ben Chilwell
# Kepa Arrizabalaga
# Malang Sarr
# Saúl Ñíguez
# Ross Barkley
# Emerson Palmieri
# Manchester Utd
# https://fbref.com/en/squads/19538871/Manchester-United-Stats
# David de Gea
# Bruno Fernandes
# Harry Maguire
# Scott McTominay
# Fred
# Cristiano Ronaldo
# Mason Greenwood
# Aaron Wan-Bissaka
# Victor Lindelöf
# Luke Shaw
# Raphaël Varane
# Jadon Sancho
# Nemanja Matić
# Alex Telles
# Diogo Dalot
# Marcus Rashford
# Paul Pogba
# Edinson Cavani
# Anthony Elanga
# Eric Bailly
# Anthony Martial
# Daniel James
# Phil Jones
# Jesse Lingard
# Donny van de Beek
# West Ham
# https://fbref.com/en/squads/7c21e445/West-Ham-United-Stats
# Łukasz Fabiański
# Declan Rice
# Jarrod Bowen
# Michail Antonio
# Tomáš Souček
# Pablo Fornals
# Saïd Benrahma
# Vladimír Coufal
# Craig Dawson
# Aaron Cresswell
# Kurt Zouma
# Angelo Ogbonna
# Ben Johnson
# Manuel Lanzini
# Issa Diop
# Arthur Masuaku
# Nikola Vlašić
# Mark Noble
# Alphonse Areola
# Andriy Yarmolenko
# Ryan Fredericks
# Harrison Ashby
# Sonny Perkins
# Alex Král
# Arsenal
# https://fbref.com/en/squads/18bb7c10/Arsenal-Stats
# Ben White
# Bukayo Saka
# Aaron Ramsdale
# Gabriel Dos Santos
# Takehiro Tomiyasu
# Thomas Partey
# Martin Ødegaard
# Kieran Tierney
# Emile Smith Rowe
# Pierre-Emerick Aubameyang
# Alexandre Lacazette
# Albert Sambi Lokonga
# Martinelli
# Granit Xhaka
# Nuno Tavares
# Nicolas Pépé
# Rob Holding
# Bernd Leno
# Ainsley Maitland-Niles
# Cédric Soares
# Pablo Marí
# Calum Chambers
# Mohamed Elneny
# Sead Kolašinac
# Folarin Balogun
# Eddie Nketiah
# Reiss Nelson
# Tottenham
# https://fbref.com/en/squads/361ca564/Tottenham-Hotspur-Stats
# Hugo Lloris
# Pierre Højbjerg
# Eric Dier
# Harry Kane
# Son Heung-min
# Sergio Reguilón
# Lucas Moura
# Oliver Skipp
# Emerson
# Davinson Sánchez
# Ben Davies
# Japhet Tanganga
# Dele Alli
# Cristian Romero
# Harry Winks
# Tanguy Ndombele
# Steven Bergwijn
# Giovani Lo Celso
# Ryan Sessegnon
# Matt Doherty
# Bryan
# Joe Rodon
# Wolves
# https://fbref.com/en/squads/8cec06e1/Wolverhampton-Wanderers-Stats
# José Sá
# Max Kilman
# Conor Coady
# João Moutinho
# Nélson Semedo
# Romain Saïss
# Raúl Jiménez
# Rúben Neves
# Francisco Trincão
# Hwang Hee-chan
# Fernando Marçal
# Adama Traoré
# Rayan Aït Nouri
# Leander Dendoncker
# Daniel Podence
# Ki-Jana Hoever
# Toti Gomes
# Fábio Silva
# Morgan Gibbs-White
# Luke Cundle
# Brighton
# https://fbref.com/en/squads/d07537b9/Brighton-and-Hove-Albion-Stats
# Robert Sánchez
# Leandro Trossard
# Marc Cucurella
# Neal Maupay
# Joël Veltman
# Adam Lallana
# Jakub Moder
# Lewis Dunk
# Yves Bissouma
# Pascal Groß
# Shane Duffy
# Dan Burn
# Adam Webster
# Solly March
# Alexis Mac Allister
# Tariq Lamptey
# Enock Mwepu
# Danny Welbeck
# Steven Alzate
# Aaron Connolly
# Jason Steele
# Jeremy Sarmiento
# Taylor Richards
# Jürgen Locadia
# Leicester City
# https://fbref.com/en/squads/a2d435b3/Leicester-City-Stats
# Kasper Schmeichel
# Çağlar Söyüncü
# James Maddison
# Youri Tielemans
# Jamie Vardy
# Harvey Barnes
# Wilfred Ndidi
# Timothy Castagne
# Luke Thomas
# Boubakary Soumaré
# Ademola Lookman
# Daniel Amartey
# Jonny Evans
# Ricardo Pereira
# Kiernan Dewsbury Hall
# Kelechi Iheanacho
# Jannik Vestergaard
# Marc Albrighton
# Patson Daka
# Ryan Bertrand
# Hamza Choudhury
# Ayoze Pérez
# James Justin
# Kasey McAteer
# Aston Villa
# https://fbref.com/en/squads/8602292d/Aston-Villa-Stats
# Matty Cash
# Emiliano Martínez
# Ezri Konsa
# Tyrone Mings
# John McGinn
# Ollie Watkins
# Matt Targett
# Douglas Luiz
# Jacob Ramsey
# Emi Buendía
# Danny Ings
# Marvelous Nakamba
# Ashley Young
# Axel Tuanzebe
# Leon Bailey
# Kortney Hause
# Anwar El Ghazi
# Morgan Sanson
# Lucas Digne
# Carney Chukwuemeka
# Bertrand Traoré
# Philippe Coutinho
# Jed Steer
# Cameron Archer
# Keinan Davis
# Trézéguet
# Jaden Philogene Bidace
# Wesley Moraes
# Southampton
# https://fbref.com/en/squads/33c895d4/Southampton-Stats
# Mohammed Salisu
# James Ward-Prowse
# Oriol Romeu
# Valentino Livramento
# Jan Bednarek
# Alex McCarthy
# Nathan Redmond
# Kyle Walker-Peters
# Adam Armstrong
# Che Adams
# Armando Broja
# Mohamed Elyounoussi
# Romain Perraud
# Ibrahima Diallo
# Nathan Tella
# Jack Stephens
# Lyanco
# Fraser Forster
# Moussa Djenepo
# Theo Walcott
# Stuart Armstrong
# Willy Caballero
# Shane Long
# Yan Valery
# William Smallbone
# Crystal Palace
# https://fbref.com/en/squads/47c64c55/Crystal-Palace-Stats
# Tyrick Mitchell
# Marc Guéhi
# Joel Ward
# Vicente Guaita
# Conor Gallagher
# Joachim Andersen
# Wilfried Zaha
# Jordan Ayew
# Cheikhou Kouyaté
# Odsonne Édouard
# Christian Benteke
# James McArthur
# Jeffrey Schlupp
# Will Hughes
# Luka Milivojević
# James Tomkins
# Michael Olise
# Jean-Philippe Mateta
# Jack Butland
# Eberechi Eze
# Jaïro Riedewald
# Nathaniel Clyne
# Jesuran Rak Sakyi
# Nathan Ferguson
# Brentford
# https://fbref.com/en/squads/cd051869/Brentford-Stats
# Pontus Jansson
# Christian Nørgaard
# Ethan Pinnock
# Ivan Toney
# Bryan Mbeumo
# Sergi Canós
# Rico Henry
# Vitaly Janelt
# Álvaro Fernández
# Frank Onyeka
# Mathias Jensen
# Kristoffer Ajer
# Shandon Baptiste
# David Raya
# Mads Roerslev
# Mathias Jørgensen
# Charlie Goode
# Mads Bech Sørensen
# Yoane Wissa
# Saman Ghoddos
# Jonas Lössl
# Dominic Thompson
# Marcus Forss
# Mads Bidstrup
# Finley Stevens
# Leeds United
# https://fbref.com/en/squads/5bfb9659/Leeds-United-Stats
# Illan Meslier
# Stuart Dallas
# Raphael Dias Belloli
# Jack Harrison
# Liam Cooper
# Diego Llorente
# Daniel James
# Mateusz Klich
# Luke Ayling
# Rodrigo
# Kalvin Phillips
# Pascal Struijk
# Junior Firpo
# Adam Forshaw
# Tyler Roberts
# Jamie Shackleton
# Patrick Bamford
# Robin Koch
# Joe Gelhardt
# Cody Drameh
# Charlie Cresswell
# Crysencio Summerville
# Leo Fuhr Hjelde
# Lewis Bate
# Hélder Costa
# Sam Greenwood
# Liam McCarron
# Stuart McKinstry
# Everton
# https://fbref.com/en/squads/d3fd31cc/Everton-Stats
# Michael Keane
# Jordan Pickford
# Demarai Gray
# Ben Godfrey
# Allan
# Abdoulaye Doucouré
# Andros Townsend
# Séamus Coleman
# Lucas Digne
# Richarlison
# Anthony Gordon
# Salomón Rondón
# Alex Iwobi
# Mason Holgate
# Yerry Mina
# Dominic Calvert-Lewin
# André Gomes
# Jonjoe Kenny
# Fabian Delph
# Tom Davies
# Asmir Begović
# Jarrad Branthwaite
# Vitaliy Mykolenko
# Jean-Philippe Gbamin
# Ellis Simms
# Lewis Dobbin
# Tyler Onyango
# Cenk Tosun
# Moise Kean
# Norwich City
# https://fbref.com/en/squads/1c781004/Norwich-City-Stats
# Max Aarons
# Teemu Pukki
# Tim Krul
# Kenny McLean
# Ben Gibson
# Grant Hanley
# Brandon Williams
# Pierre Lees-Melou
# Josh Sargent
# Billy Gilmour
# Milot Rashica
# Ozan Kabak
# Mathias Normann
# Dimitris Giannoulis
# Adam Idah
# Lukas Rupp
# Todd Cantwell
# Przemysław Płacheta
# Andrew Omobamidele
# Jakob Sørensen
# Kieran Dowell
# Christos Tzolis
# Angus Gunn
# Sam Byram
# Bali Mumba
# Jon Rowe
# Watford
# https://fbref.com/en/squads/2abfe087/Watford-Stats
# Moussa Sissoko
# Craig Cathcart
# Joshua King
# Emmanuel Dennis
# William Troost-Ekong
# Juraj Kucka
# Kiko Femenía
# Ismaila Sarr
# Daniel Bachmann
# Adam Masina
# Ben Foster
# Tom Cleverley
# Danny Rose
# João Pedro
# Cucho
# Imran Louza
# Jeremy Ngakia
# Francisco Sierralta
# Ken Sema
# Oghenekaro Etebo
# Ozan Tufan
# Christian Kabasele
# Samir Santos
# Hassane Kamara
# Edo Kayembe
# Nicolas Nkoulou
# Ashley Fletcher
# Troy Deeney
# Dan Gosling
# Newcastle Utd
# https://fbref.com/en/squads/b2b47a98/Newcastle-United-Stats
# Allan Saint-Maximin
# Jamaal Lascelles
# Joelinton
# Matt Ritchie
# Callum Wilson
# Joe Willock
# Javier Manquillo
# Ciaran Clark
# Isaac Hayden
# Jonjo Shelvey
# Miguel Almirón
# Fabian Schär
# Sean Longstaff
# Martin Dúbravka
# Ryan Fraser
# Karl Darlow
# Jacob Murphy
# Emil Krafth
# Federico Fernández
# Freddie Woodman
# Jamal Lewis
# Kieran Trippier
# Chris Wood
# Paul Dummett
# Jeff Hendrick
# Dwight Gayle
# Burnley
# https://fbref.com/en/squads/943e8050/Burnley-Stats
# Dwight McNeil
# James Tarkowski
# Nick Pope
# Matthew Lowton
# Ashley Westwood
# Chris Wood
# Charlie Taylor
# Ben Mee
# Josh Brownhill
# Jóhann Berg Guðmundsson
# Maxwel Cornet
# Jack Cork
# Nathan Collins
# Aaron Lennon
# Ashley Barnes
# Jay Rodriguez
# Matěj Vydra
# Erik Pieters
# Connor Roberts
# Wayne Hennessey
# Dale Stephens
# Wout Weghorst

# %%
# get the player name matching dictionary
with open(path/'match_list.json') as f:
  match_list = json.load(f)

match_list
# Out:
# {'Fabinho': 'Fabio Henrique Tavares',
#  'Alisson': 'Alisson Ramses Becker',
#  'Joël Matip': 'Joel Matip',
#  'Joe Gomez': 'Joseph Gomez',
#  'Naby Keïta': 'Naby Keita',
#  'Adrián': 'Adrián San Miguel del Castillo',
#  'Thiago Alcántara': 'Thiago Alcántara do Nascimento',
#  'Allan': 'Allan Marques Loureiro',
#  'Richarlison': 'Richarlison de Andrade',
#  'Gylfi Sigurðsson': 'Gylfi Sigurdsson',
#  'Séamus Coleman': 'Seamus Coleman',
#  'André Gomes': 'André Filipe Tavares Gomes',
#  'Bernard': 'Bernard Anício Caldeira Duarte',
#  'Çağlar Söyüncü': 'Çaglar Söyüncü',
#  'Bruno Fernandes': 'Bruno Miguel Borges Fernandes',
#  'Fred': 'Frederico Rodrigues de Paula Santos',
#  'Nemanja Matić': 'Nemanja Matic',
#  'Alex Telles': 'Alex Nicolao Telles',
#  'Pierre Højbjerg': 'Pierre-Emile Højbjerg',
#  'Son Heung-min': 'Heung-Min Son',
#  'Lucas Moura': 'Lucas Rodrigues Moura da Silva',
#  'Érik Lamela': 'Erik Lamela',
#  'Dele Alli': 'Bamidele Alli',
#  'Carlos Vinícius': 'Carlos Vinicius Alves Morais',
#  'Ederson': 'Ederson Santana de Moraes',
#  'Rodri': 'Rodrigo Hernandez',
#  'Rúben Dias': 'Rúben Santos Gato Alves Dias',
#  'João Cancelo': 'João Pedro Cavaco Cancelo',
#  'İlkay Gündoğan': 'Ilkay Gündogan',
#  'Gabriel Jesus': 'Gabriel Fernando de Jesus',
#  'Ferrán Torres': 'Ferran Torres',
#  'Bernardo Silva': 'Bernardo Mota Veiga de Carvalho e Silva',
#  'Fernandinho': 'Fernando Luiz Rosa',
#  'Eric García': 'Eric Garcia',
#  'Matty Cash': 'Matthew Cash',
#  'Douglas Luiz': 'Douglas Luiz Soares de Paulo',
#  'Ezri Konsa': 'Ezri Konsa Ngoyo',
#  'Trézéguet': 'Mahmoud Ahmed Ibrahim Hassan',
#  'Ben Chilwell': 'Benjamin Chilwell',
#  'Thiago Silva': 'Thiago Emiliano da Silva',
#  'Mateo Kovačić': 'Mateo Kovacic',
#  'Jorginho': 'Jorge Luiz Frello Filho',
#  'Emerson Palmieri': 'Emerson Palmieri dos Santos',
#  'Oriol Romeu': 'Oriol Romeu Vidal',
#  'Dan Nlundulu': "Daniel N'Lundulu",
#  'Łukasz Fabiański': 'Lukasz Fabianski',
#  'Tomáš Souček': 'Tomas Soucek',
#  'Vladimír Coufal': 'Vladimir Coufal',
#  'Felipe Anderson': 'Felipe Anderson Pereira Gomes',
#  'Rui Patrício': 'Rui Pedro dos Santos Patrício',
#  'Pedro Neto': 'Pedro Lomba Neto',
#  'Daniel Podence': 'Daniel Castelo Podence',
#  'Nélson Semedo': 'Nélson Cabral Semedo',
#  'Rúben Neves': 'Rúben Diogo da Silva Neves',
#  'João Moutinho': 'João Filipe Iria Santos Moutinho',
#  'Rayan Aït Nouri': 'Rayan Ait Nouri',
#  'Fábio Silva': 'Fabio Silva',
#  'Rúben Vinagre': 'Rúben Gonçalo Silva Nascimento Vinagre',
#  'Vitinha': 'Vitor Ferreira',
#  'Rodrigo': 'Rodrigo Moreno',
#  'Pablo Hernández': 'Pablo Hernández Domínguez',
#  'Ian Carlo Poveda': 'Ian Carlo Poveda-Ocampo',
#  'Joelinton': 'Joelinton Cássio Apolinário de Lira',
#  'Luka Milivojević': 'Luka Milivojevic',
#  'Jaïro Riedewald': 'Jairo Riedewald',
#  'Gabriel Dos Santos': 'Gabriel Magalhães',
#  'Willian': 'Willian Borges Da Silva',
#  'Dani Ceballos': 'Daniel Ceballos Fernández',
#  'David Luiz': 'David Luiz Moreira Marinho',
#  'Eddie Nketiah': 'Edward Nketiah',
#  'Joe Willock': 'Joseph Willock',
#  'Sead Kolašinac': 'Sead Kolasinac',
#  'Martinelli': 'Gabriel Teodoro Martinelli Silva',
#  'Solly March': 'Solomon March',
#  'Bernardo': 'Bernardo Fernandes da Silva Junior',
#  'Jóhann Berg Guðmundsson': 'Johann Berg Gudmundsson',
#  'Matěj Vydra': 'Matej Vydra',
#  'Andre-Frank Zambo Anguissa': 'André-Frank Zambo Anguissa',
#  'Semi Ajayi': 'Oluwasemilogo Adesewo Ibidapo Ajayi',
#  'Branislav Ivanović': 'Branislav Ivanovic',
#  'Filip Krovinović': 'Filip Krovinovic',
#  'Ahmed Hegazi': 'Ahmed El-Sayed Hegazi',
#  'Harvey Elliot': 'Harvey Elliott',
#  'Angeliño': 'Angelo Ogbonna',
#  'Thomas Doyle': 'Tommy Doyle',
#  'Diogo Dalot': 'José Diogo Dalot Teixeira',
#  'Pedro': 'Pedro Rodríguez Ledesma',
#  'Ricardo Pereira': 'Ricardo Domingos Barbosa Pereira',
#  'Gedson Fernandes': 'Gedson Carvalho Fernandes',
#  "Georges-Kévin N'Koudou": 'Georges-Kévin Nkoudou',
#  'Jonny Castro': 'Jonathan Castro Otto',
#  'Jesús Vallejo': 'Jesús Vallejo Lázaro',
#  'Bruno Jordão': 'Bruno André Cavaco Jordao',
#  'Mattéo Guendouzi': 'Matteo Guendouzi',
#  'Richairo Živković': 'Richairo Zivkovic',
#  'Danny Drinkwater': 'Daniel Drinkwater',
#  'Martin Dúbravka': 'Martin Dubravka',
#  'Yoshinori Mutō': 'Yoshinori Muto',
#  'Ki Sung-yueng': 'Sung-yueng Ki',
#  'Roberto': 'Roberto Jimenez Gago',
#  'Javier Hernández': 'Javier Hernández Balcázar',
#  'Frederic Guilbert': 'Frédéric Guilbert',
#  'Björn Engels': 'Bjorn Engels',
#  'Pepe Reina': 'José Reina',
#  'Jota': 'José Ignacio Peleteiro Romallo',
#  'Arnaut Groeneveld': 'Arnaut Danjuma Groeneveld',
#  'Étienne Capoue': 'Etienne Capoue',
#  'Kiko Femenía': 'Francisco Femenía Far',
#  'Ismaila Sarr': 'Ismaila Sarr',
#  'João Pedro': 'João Pedro Junqueira de Jesus',
#  'Max Aarons': 'Max Aarons',
#  'Emi Buendía': 'Emiliano Buendía Stati',
#  'Mario Vrančić': 'Mario Vrancic',
#  'Josip Drmić': 'Josip Drmic',
#  'Ralf Fährmann': 'Ralf Fahrmann',
#  'Danilo': 'Danilo Luiz da Silva',
#  'Petr Čech': 'Petr Cech',
#  'Idrissa Gana Gueye': 'Idrissa Gueye',
#  'Marko Arnautović': 'Marko Arnautovic',
#  'Xande Silva': 'Alexandre Nascimento Costa Silva',
#  'Julián Speroni': 'Julian Speroni',
#  'Kenedy': 'Robert Kenedy Nunes do Nascimento',
#  'Joselu': 'Jose Luis Mato Sanmartín',
#  'Asmir Begović': 'Asmir Begović',
#  'Kayne Ramsey': 'Kayne Ramsay',
#  'Bruno': 'Bruno Saltor Grau',
#  'Junior Hoilett': 'David Junior Hoilett',
#  'Greg Cunningham': 'Greg Cunninghamm',
#  'Jazz Richards': 'Ashley Darel Jazz Richards',
#  'Jean Seri': 'Jean Michael Seri',
#  'Fabricio': 'Fabricio Agosto Ramírez',
#  'Lazar Marković': 'Lazar Markovic',
#  'Mathias Jørgensen': 'Mathias Jorgensen',
#  'Steve Mounié': 'Steve Mounie',
#  'Jon Gorenc Stanković': 'Jon Gorenc Stankovic',
#  'Matty Daly': 'Matthew Daly',
#  'Yaya Touré': 'Gnegneri Yaya Touré',
#  'Brahim Díaz': 'Brahim Diaz',
#  'Zlatan Ibrahimović': 'Zlatan Ibrahimovic',
#  'Marko Grujić': 'Marko Grujic',
#  'Charly Musonda Jr.': 'Charly Musonda',
#  'Nikola Vlašić': 'Nikola Vlasic',
#  'Aleksandar Dragović': 'Aleksandar Dragovic',
#  'Eldin Jakupović': 'Eldin Jakupovic',
#  'Rob Elliot': 'Robert Elliot',
#  'Jesús Gámez': 'Jesús Gámez Duarte',
#  'Massadio Haïdara': 'Massadio Haidara',
#  'Lee Chung-yong': 'Chung-yong Lee',
#  'Freddie Ladapo': 'Olayinka Fredrick Oladotun Ladapo',
#  'João Mário': 'João Mário Naval Costa Eduardo',
#  'José Fonte': 'Jose Fonte',
#  'Younès Kaboul': 'Younes Kaboul',
#  'Izzy Brown': 'Isaiah Brown',
#  'Dušan Tadić': 'Dusan Tadic',
#  'Àngel Rangel': 'Angel Rangel',
#  'Badou Ndiaye': 'Papa Alioune Ndiaye',
#  'Jesé': 'Jesé Rodríguez Ruiz',
#  'Tom Edwards': 'Thomas Edwards',
#  'Kostas Stafylidis': 'Konstantinos Stafylidis',
#  'Lasse Sørensen': 'Lasse Sorenson',
#  'Bojan Krkić': 'Bojan Krkic',
#  'Allan Nyom': 'Allan-Roméo Nyom',
#  'Ahmed Elmohamady': 'Ahmed El Mohamady',
#  'Hélder Costa': 'Hélder Wander Sousa de Azevedo e Costa',
#  'Mohamed Elneny': 'Mohamed Naser El Sayed Elneny',
#  'Emile Smith-Rowe': 'Emile Smith Rowe',
#  'Ivan Cavaleiro': 'Ivan Ricardo Neves Abreu Cavaleiro',
#  'Bobby Reid': 'Bobby Decordova-Reid',
#  'Ahmed El-Sayed Hegazi': 'Ahmed El-Sayed Hegazy',
#  'Kiko Casilla': 'Francisco Casilla Cortés',
#  'Willian José': 'Willian José Da Silva',
#  'Kostas Tsimikas': 'Konstantinos Tsimikas',
#  'Okay Yokuşlu': 'Okay Yokuslu',
#  'Khanya Leshabela': 'Thakgalo Leshabela',
#  'Jaden Philogene Bidace': 'Jaden Philogene-Bidace',
#  'William Thomas Fish': 'William Fish',
#  'David Raya': 'David Raya Martin',
#  'Oghenekaro Etebo': 'Oghenekaro Peter Etebo',
#  'Ismaïla Sarr': 'Ismaila Sarr',
#  'Cucho': 'Juan Camilo Hernández Suárez',
#  'Enoch Mwepu': 'Enock Mwepu',
#  'Emiliano Buendía': 'Emiliano Buendía StatiJosé Malheiro de Sá',
#  'José Sá': 'José Malheiro de Sá',
#  'Francisco Trincão': 'Francisco Machado Mota de Castro Trincão',
#  'Valentino Livramento': 'Tino Livramento',
#  'Nuno Tavares': 'Nuno Varela Tavares',
#  'Jesuran Rak Sakyi': 'Jesurun Rak-Sakyi',
#  'Maximillian Aarons': 'Max Aarons',
#  'Josh Sargent': 'Joshua Sargent',
#  'Junior Firpo': 'Héctor Junior Firpo Adames',
#  'Imran Louza': 'Imrân Louza',
#  'Bryan': 'Bryan Gil Salvatierra',
#  'Kiernan Dewsbury Hall': 'Kiernan Dewsbury-Hall',
#  'Cristiano Ronaldo': 'Cristiano Ronaldo dos Santos Aveiro',
#  'Emerson': 'Emerson Aparecido Leite de Souza Junior',
#  'Mads Roerslev': 'Mads Roerslev Rasmussen',
#  'Odsonne Édouard': 'Odsonne Edouard',
#  'Hwang Hee-chan': 'Hee-Chan Hwang',
#  'Asmir Begovic': 'Asmir Begović',
#  'Caoimhín Kelleher': 'Caoimhin Kelleher',
#  'Lyanco': 'Lyanco Evangelista Silveira Neves Vojnovic',
#  'Przemysław Płacheta': 'Przemyslaw Placheta',
#  'James Mcatee': 'James McAtee',
#  'Jakob Sørensen': 'Jacob Sørensen',
#  'Alex Král': 'Alex Kral',
#  'Jon Rowe': 'Jonathan Rowe',
#  'Toti Gomes': 'Toti António Gomes',
#  'Philippe Coutinho': 'Philippe Coutinho Correia',
#  'Vitaliy Mykolenko': 'Vitalii Mykolenko',
#  'Samir Santos': 'Samir Caetano de Souza Santos'}

# %%
team_list = {}
team_list['Brighton'] = 'Brighton and Hove Albion'
team_list['Leeds United'] = 'Leeds'
team_list['Manchester Utd'] = 'Manchester United'
team_list['Newcastle Utd'] = 'Newcastle United'
team_list['Norwich City'] = 'Norwich'
team_list['Sheffield Utd'] = 'Sheffield United'
team_list['Tottenham'] = 'Tottenham Hotspur'
team_list['West Brom'] = 'West Bromwich Albion'
team_list['West Ham'] = 'West Ham United'
team_list['Wolves'] = 'Wolverhampton Wanderers'

# %%
df_enhanced = df_enhanced.loc[df_enhanced[df_enhanced['round'].str[-2:] != 'on'].index]

# %%
# replace non-matching names/teams and extract gw as integer
df_enhanced['alt_name'] = df_enhanced['player'].replace(match_list)
df_enhanced['squad'] = df_enhanced['squad'].replace(team_list)
df_enhanced['round'] = df_enhanced['round'].str[-2:].astype('int')

# %%
# remove duplicated (happens when players transferred within season)
df_enhanced = df_enhanced.drop_duplicates()

# %%
df_enhanced
# Out:
#          season           player        date            squad            comp  \
# 0     2021-2022          Ederson  2021-08-15  Manchester City  Premier League
# 1     2021-2022          Ederson  2021-08-21  Manchester City  Premier League
# 2     2021-2022          Ederson  2021-08-28  Manchester City  Premier League
# 3     2021-2022          Ederson  2021-09-11  Manchester City  Premier League
# 4     2021-2022          Ederson  2021-09-18  Manchester City  Premier League
# ...         ...              ...         ...              ...             ...
# 6002  2021-2022  Wayne Hennessey  2021-12-30          Burnley  Premier League
# 6003  2021-2022  Wayne Hennessey  2022-01-02          Burnley  Premier League
# 6004  2021-2022    Dale Stephens  2021-12-30          Burnley  Premier League
# 6005  2021-2022    Dale Stephens  2022-02-05          Burnley  Premier League
# 6006  2021-2022    Wout Weghorst  2022-02-05          Burnley  Premier League
#
#       round shots_total shots_on_target touches pressures  ...   xa sca gca  \
# 0         1           0               0      22         0  ...  0.0   2   0
# 1         2           0               0      14         0  ...  0.0   0   0
# 2         3           0               0      37         0  ...  0.0   0   0
# 3         4           0               0      26         0  ...  0.0   0   0
# 4         5           0               0      40         0  ...  0.0   0   0
# ...     ...         ...             ...     ...       ...  ...  ...  ..  ..
# 6002     20           0               0      36         0  ...  0.1   3   0
# 6003     21           0               0      51         1  ...  0.0   0   0
# 6004     20           0               0      20         9  ...  0.0   0   0
# 6005     17           1               0      55        33  ...  0.0   2   0
# 6006     17           2               0      41        36  ...  0.0   2   0
#
#      passes_completed passes passes_pct carries dribbles_completed dribbles  \
# 0                  20     22       90.9      10                  0        0
# 1                  12     12      100.0       6                  0        0
# 2                  31     37       83.8      25                  0        0
# 3                  22     24       91.7      10                  0        0
# 4                  39     39      100.0      28                  0        0
# ...               ...    ...        ...     ...                ...      ...
# 6002               18     32       56.3      11                  0        0
# 6003               22     48       45.8      15                  0        0
# 6004               12     16       75.0       9                  0        0
# 6005               32     42       76.2      25                  0        0
# 6006               15     26       57.7      17                  1        3
#
#                        alt_name
# 0     Ederson Santana de Moraes
# 1     Ederson Santana de Moraes
# 2     Ederson Santana de Moraes
# 3     Ederson Santana de Moraes
# 4     Ederson Santana de Moraes
# ...                         ...
# 6002            Wayne Hennessey
# 6003            Wayne Hennessey
# 6004              Dale Stephens
# 6005              Dale Stephens
# 6006              Wout Weghorst
#
# [5939 rows x 25 columns]

# %%
# create date field in same format as enhanced data
df_latest['date'] = df_latest['kickoff_time'].str[:10]

# %%
# check if any names aren't matching
enhanced_players = df_enhanced[df_enhanced['date'].isin(df_latest['date'].unique())]['alt_name'].unique().tolist()
standard_players = df_latest['player'].unique().tolist()

unmatched_players = [x for x in enhanced_players if x not in standard_players]
unmatched_players
# Out:
# []

# %%
# check if any teams aren't matching
enhanced_teams = df_enhanced[df_enhanced['date'].isin(df_latest['date'].unique())]['squad'].unique().tolist()
standard_teams = df_latest['team'].unique().tolist()

unmatched_teams = [x for x in enhanced_teams if x not in standard_teams]
unmatched_teams
# Out:
# []

# %%
# any additional corrections
# match_list['Toti Gomes'] = 'Toti António Gomes'
# match_list['Philippe Coutinho'] = 'Philippe Coutinho Correia'
# match_list['Vitaliy Mykolenko'] = 'Vitalii Mykolenko'
# match_list['Samir Santos'] = 'Samir Caetano de Souza Santos'
# match_list['Hwang Hee-chan'] = 'Hee-Chan Hwang'

# %%
# replace additional non-matching names
# df_enhanced['alt_name'] = df_enhanced['player'].replace(match_list)

# %%
# make sure there are no non matches after update
# enhanced_players =  df_enhanced[df_enhanced['round'] == last_gw]['alt_name'].unique().tolist()
# standard_players = df_latest['player'].unique().tolist()

# unmatched_players = [x for x in enhanced_players if x not in standard_players]
# unmatched_players

# %%
# if match list was updated then update the file
# json_file = json.dumps(match_list)
# f = open(path/"match_list.json","w")
# f.write(json_file)
# f.close()

# %%
# check there are no duplicates in the join fields for the enhanced data
assert(len(df_enhanced[df_enhanced.duplicated(subset=['alt_name', 'date'], keep=False)]) == 0)

# %%
df_latest[df_latest.duplicated(subset=['date','player','team'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [player, gw, position, minutes, team, opponent_team, relative_market_value_team, relative_market_value_opponent_team, was_home, total_points, assists, bonus, bps, clean_sheets, creativity, goals_conceded, goals_scored, ict_index, influence, own_goals, penalties_missed, penalties_saved, red_cards, saves, selected, team_a_score, team_h_score, threat, transfers_balance, transfers_in, transfers_out, yellow_cards, kickoff_time, season, play_proba, date]
# Index: []
#
# [0 rows x 36 columns]

# %%
# check there are no duplicates in the join fields for the standard data
assert(len(df_train[df_train.duplicated(subset=['date','player','team'])]) == 0)

# %%
# df_train[df_train.duplicated(subset=['date','player','team'])]

# %%
# join standard and enhanced dataframes
df_latest_further = df_latest.merge(df_enhanced.drop(['player', 'season', 'round'], axis=1), 
                                   left_on=['date', 'player', 'team'], 
                                   right_on=['date', 'alt_name', 'squad'], how='left')

# %%
# drop the alt name field and check the length of the standard
# dataframe has not increased
df_latest_further = df_latest_further.drop(['alt_name'], axis=1)
assert(len(df_latest_further) == len(df_latest_further))

# %%
# add crowds field
df_latest_further['crowds'] = 1

# %%
assert(sum(df_latest_further[df_latest_further['minutes'] > 0]['xg'].isnull()) == 0)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3768/2444589764.py in <module>
# ----> 1 assert(sum(df_latest_further[df_latest_further['minutes'] > 0]['xg'].isnull()) == 0)
#
# AssertionError:

# %%
df_latest_further[df_latest_further['minutes'] > 0][df_latest_further[df_latest_further['minutes'] > 0]['xg'].isnull()]
# Out:
#        player  gw  position  minutes              team   opponent_team  \
# 170  Dan Burn  23         2       90  Newcastle United  Leicester City
#
#      relative_market_value_team  relative_market_value_opponent_team  \
# 170                         NaN                                  NaN
#
#      was_home  total_points  ...   xa  sca  gca  passes_completed  passes  \
# 170     False             1  ...  NaN  NaN  NaN               NaN     NaN
#
#      passes_pct  carries  dribbles_completed  dribbles  crowds
# 170         NaN      NaN                 NaN       NaN       1
#
# [1 rows x 57 columns]

# %%
df_enhanced
# Out:
#          season           player        date            squad            comp  \
# 0     2021-2022          Ederson  2021-08-15  Manchester City  Premier League
# 1     2021-2022          Ederson  2021-08-21  Manchester City  Premier League
# 2     2021-2022          Ederson  2021-08-28  Manchester City  Premier League
# 3     2021-2022          Ederson  2021-09-11  Manchester City  Premier League
# 4     2021-2022          Ederson  2021-09-18  Manchester City  Premier League
# ...         ...              ...         ...              ...             ...
# 6002  2021-2022  Wayne Hennessey  2021-12-30          Burnley  Premier League
# 6003  2021-2022  Wayne Hennessey  2022-01-02          Burnley  Premier League
# 6004  2021-2022    Dale Stephens  2021-12-30          Burnley  Premier League
# 6005  2021-2022    Dale Stephens  2022-02-05          Burnley  Premier League
# 6006  2021-2022    Wout Weghorst  2022-02-05          Burnley  Premier League
#
#       round shots_total shots_on_target touches pressures  ...   xa sca gca  \
# 0         1           0               0      22         0  ...  0.0   2   0
# 1         2           0               0      14         0  ...  0.0   0   0
# 2         3           0               0      37         0  ...  0.0   0   0
# 3         4           0               0      26         0  ...  0.0   0   0
# 4         5           0               0      40         0  ...  0.0   0   0
# ...     ...         ...             ...     ...       ...  ...  ...  ..  ..
# 6002     20           0               0      36         0  ...  0.1   3   0
# 6003     21           0               0      51         1  ...  0.0   0   0
# 6004     20           0               0      20         9  ...  0.0   0   0
# 6005     17           1               0      55        33  ...  0.0   2   0
# 6006     17           2               0      41        36  ...  0.0   2   0
#
#      passes_completed passes passes_pct carries dribbles_completed dribbles  \
# 0                  20     22       90.9      10                  0        0
# 1                  12     12      100.0       6                  0        0
# 2                  31     37       83.8      25                  0        0
# 3                  22     24       91.7      10                  0        0
# 4                  39     39      100.0      28                  0        0
# ...               ...    ...        ...     ...                ...      ...
# 6002               18     32       56.3      11                  0        0
# 6003               22     48       45.8      15                  0        0
# 6004               12     16       75.0       9                  0        0
# 6005               32     42       76.2      25                  0        0
# 6006               15     26       57.7      17                  1        3
#
#                        alt_name
# 0     Ederson Santana de Moraes
# 1     Ederson Santana de Moraes
# 2     Ederson Santana de Moraes
# 3     Ederson Santana de Moraes
# 4     Ederson Santana de Moraes
# ...                         ...
# 6002            Wayne Hennessey
# 6003            Wayne Hennessey
# 6004              Dale Stephens
# 6005              Dale Stephens
# 6006              Wout Weghorst
#
# [5939 rows x 25 columns]

# %%
df_train_new = pd.concat([df_train, df_latest_further], ignore_index=True, axis=0, sort=False)

# %%
df_train_new[df_train_new['player'] == 'Harry Kane'].tail()
# Out:
#             player  gw  position  minutes               team   opponent_team  \
# 125561  Harry Kane  19         4       63  Tottenham Hotspur  Crystal Palace
# 125801  Harry Kane  20         4       90  Tottenham Hotspur     Southampton
# 126346  Harry Kane  21         4       90  Tottenham Hotspur         Watford
# 127048  Harry Kane  22         4       90  Tottenham Hotspur  Leicester City
# 127815  Harry Kane  23         4       90  Tottenham Hotspur         Chelsea
#
#         relative_market_value_team  relative_market_value_opponent_team  \
# 125561                    1.463462                             0.545912
# 125801                    1.463462                             0.563202
# 126346                    1.467118                             0.338504
# 127048                    1.466032                             1.169548
# 127815                         NaN                                  NaN
#
#         was_home  total_points  ...   xa   sca  gca  passes_completed  passes  \
# 125561      True             6  ...  0.0   1.0  1.0              17.0    19.0
# 125801     False             6  ...  0.1   3.0  0.0              17.0    24.0
# 126346     False             2  ...  0.0   3.0  0.0              24.0    33.0
# 127048     False            11  ...  0.4  11.0  2.0              25.0    36.0
# 127815     False             2  ...  0.2     2    0                13      21
#
#         passes_pct  carries  dribbles_completed  dribbles  crowds
# 125561        89.5     23.0                 1.0       1.0       1
# 125801        70.8     34.0                 2.0       2.0       1
# 126346        72.7     38.0                 0.0       1.0       1
# 127048        69.4     49.0                 4.0       4.0       1
# 127815        61.9       25                   2         2       1
#
# [5 rows x 59 columns]

# %%
df_train_new.tail(10)
# Out:
#                             player  gw  position  minutes  \
# 128314             Xherdan Shaqiri  23         3        0
# 128315                  Yan Valery  23         2        0
# 128316                  Yerry Mina  23         2       90
# 128317  Yerson Mosquera Valdelamar  23         2        0
# 128318                 Yoane Wissa  23         3       32
# 128319             Youri Tielemans  23         3       90
# 128320               Yves Bissouma  23         3        0
# 128321                Zack Steffen  23         1        0
# 128322            Álvaro Fernández  23         1        0
# 128323              Çaglar Söyüncü  23         2       90
#
#                             team             opponent_team  \
# 128314                 Liverpool            Crystal Palace
# 128315               Southampton           Manchester City
# 128316                   Everton               Aston Villa
# 128317   Wolverhampton Wanderers                 Brentford
# 128318                 Brentford   Wolverhampton Wanderers
# 128319            Leicester City  Brighton and Hove Albion
# 128320  Brighton and Hove Albion            Leicester City
# 128321           Manchester City               Southampton
# 128322                 Brentford   Wolverhampton Wanderers
# 128323            Leicester City  Brighton and Hove Albion
#
#         relative_market_value_team  relative_market_value_opponent_team  \
# 128314                         NaN                                  NaN
# 128315                         NaN                                  NaN
# 128316                         NaN                                  NaN
# 128317                         NaN                                  NaN
# 128318                         NaN                                  NaN
# 128319                         NaN                                  NaN
# 128320                         NaN                                  NaN
# 128321                         NaN                                  NaN
# 128322                         NaN                                  NaN
# 128323                         NaN                                  NaN
#
#         was_home  total_points  ...   xa  sca  gca  passes_completed  passes  \
# 128314     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 128315      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 128316      True             1  ...  0.0    2    0                42      49
# 128317     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 128318      True             1  ...  0.0    0    0                 3       6
# 128319      True             2  ...  0.1    4    0                49      62
# 128320     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 128321     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 128322      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 128323      True             2  ...  0.0    0    0                53      67
#
#         passes_pct  carries  dribbles_completed  dribbles  crowds
# 128314         NaN      NaN                 NaN       NaN       1
# 128315         NaN      NaN                 NaN       NaN       1
# 128316        85.7       31                   0         0       1
# 128317         NaN      NaN                 NaN       NaN       1
# 128318        50.0        6                   0         0       1
# 128319        79.0       39                   0         0       1
# 128320         NaN      NaN                 NaN       NaN       1
# 128321         NaN      NaN                 NaN       NaN       1
# 128322         NaN      NaN                 NaN       NaN       1
# 128323        79.1       42                   0         0       1
#
# [10 rows x 59 columns]

# %%
df_latest_further.shape
# Out:
# (773, 57)

# %%
df_train_new.shape
# Out:
# (128324, 59)

# %%
# save latest training set to csv
# overwrite existing one
df_train_new.to_csv(path/'train_v8.csv')

# %%
# get fixtures
fixtures = pd.read_csv(path/'2021-22/fixtures.csv')
team_dict = teams[['team_2122', 'team']].dropna().set_index('team_2122').to_dict()['team']

fixtures['home_team'] = fixtures['team_h'].replace(team_dict)
fixtures['away_team'] = fixtures['team_a'].replace(team_dict)
fixtures = fixtures[['home_team', 'away_team', 'kickoff_time', 'event']]
fixtures = fixtures.rename(columns={'event':'gw'})


# use these two lines if updating play_proba later in week
# current_gw = last_gw
# df_train_new = pd.read_csv(path/'train_v7.csv', index_col=0, dtype={'season':str,
#                                                                     'comp':str,
#                                                                     'squad':str})

# set starting gameweek (where are we right now in the season)
current_gw = last_gw + 1
fixtures = fixtures[fixtures['gw'] >= current_gw].sort_values(by=['gw'])
fixtures['match_no'] = np.arange(fixtures.shape[0])

# %%
fixtures.head(50)
# Out:
#                     home_team                 away_team          kickoff_time  \
# 229          Newcastle United                   Everton  2022-02-08T19:45:00Z
# 230           West Ham United                   Watford  2022-02-08T19:45:00Z
# 231                   Burnley         Manchester United  2022-02-08T20:00:00Z
# 232           Manchester City                 Brentford  2022-02-09T19:45:00Z
# 233                   Norwich            Crystal Palace  2022-02-09T19:45:00Z
# 234         Tottenham Hotspur               Southampton  2022-02-09T19:45:00Z
# 235               Aston Villa                     Leeds  2022-02-09T20:00:00Z
# 236                 Liverpool            Leicester City  2022-02-10T19:45:00Z
# 237   Wolverhampton Wanderers                   Arsenal  2022-02-10T19:45:00Z
# 247         Manchester United  Brighton and Hove Albion  2022-02-15T20:15:00Z
# 245         Tottenham Hotspur   Wolverhampton Wanderers  2022-02-13T14:00:00Z
# 244          Newcastle United               Aston Villa  2022-02-13T14:00:00Z
# 243                   Burnley                 Liverpool  2022-02-13T14:00:00Z
# 246            Leicester City           West Ham United  2022-02-13T16:30:00Z
# 241                   Watford  Brighton and Hove Albion  2022-02-12T15:00:00Z
# 240                   Everton                     Leeds  2022-02-12T15:00:00Z
# 239                 Brentford            Crystal Palace  2022-02-12T15:00:00Z
# 238         Manchester United               Southampton  2022-02-12T12:30:00Z
# 242                   Norwich           Manchester City  2022-02-12T17:30:00Z
# 261                   Arsenal   Wolverhampton Wanderers  2022-02-24T19:45:00Z
# 260                 Liverpool                     Leeds  2022-02-23T19:45:00Z
# 259                   Watford            Crystal Palace  2022-02-23T19:30:00Z
# 258                   Burnley         Tottenham Hotspur  2022-02-23T19:30:00Z
# 257   Wolverhampton Wanderers            Leicester City  2022-02-20T16:30:00Z
# 256                     Leeds         Manchester United  2022-02-20T14:00:00Z
# 255           Manchester City         Tottenham Hotspur  2022-02-19T17:30:00Z
# 253                 Liverpool                   Norwich  2022-02-19T15:00:00Z
# 252            Crystal Palace                   Chelsea  2022-02-19T15:00:00Z
# 251  Brighton and Hove Albion                   Burnley  2022-02-19T15:00:00Z
# 250               Aston Villa                   Watford  2022-02-19T15:00:00Z
# 249                   Arsenal                 Brentford  2022-02-19T15:00:00Z
# 248           West Ham United          Newcastle United  2022-02-19T12:30:00Z
# 254               Southampton                   Everton  2022-02-19T15:00:00Z
# 268                   Everton           Manchester City  2022-02-26T17:30:00Z
# 269           West Ham United   Wolverhampton Wanderers  2022-02-27T14:00:00Z
# 267         Manchester United                   Watford  2022-02-26T15:00:00Z
# 266            Crystal Palace                   Burnley  2022-02-26T15:00:00Z
# 265  Brighton and Hove Albion               Aston Villa  2022-02-26T15:00:00Z
# 264                 Brentford          Newcastle United  2022-02-26T15:00:00Z
# 263                     Leeds         Tottenham Hotspur  2022-02-26T12:30:00Z
# 262               Southampton                   Norwich  2022-02-25T20:00:00Z
# 279         Tottenham Hotspur                   Everton  2022-03-07T20:00:00Z
# 278           Manchester City         Manchester United  2022-03-06T16:30:00Z
# 277                   Watford                   Arsenal  2022-03-06T14:00:00Z
# 276                 Liverpool           West Ham United  2022-03-05T17:30:00Z
# 275   Wolverhampton Wanderers            Crystal Palace  2022-03-05T15:00:00Z
# 273          Newcastle United  Brighton and Hove Albion  2022-03-05T15:00:00Z
# 272                   Burnley                   Chelsea  2022-03-05T15:00:00Z
# 271               Aston Villa               Southampton  2022-03-05T15:00:00Z
# 270            Leicester City                     Leeds  2022-03-05T12:30:00Z
#
#        gw  match_no
# 229  24.0         0
# 230  24.0         1
# 231  24.0         2
# 232  24.0         3
# 233  24.0         4
# 234  24.0         5
# 235  24.0         6
# 236  24.0         7
# 237  24.0         8
# 247  25.0         9
# 245  25.0        10
# 244  25.0        11
# 243  25.0        12
# 246  25.0        13
# 241  25.0        14
# 240  25.0        15
# 239  25.0        16
# 238  25.0        17
# 242  25.0        18
# 261  26.0        19
# 260  26.0        20
# 259  26.0        21
# 258  26.0        22
# 257  26.0        23
# 256  26.0        24
# 255  26.0        25
# 253  26.0        26
# 252  26.0        27
# 251  26.0        28
# 250  26.0        29
# 249  26.0        30
# 248  26.0        31
# 254  26.0        32
# 268  27.0        33
# 269  27.0        34
# 267  27.0        35
# 266  27.0        36
# 265  27.0        37
# 264  27.0        38
# 263  27.0        39
# 262  27.0        40
# 279  28.0        41
# 278  28.0        42
# 277  28.0        43
# 276  28.0        44
# 275  28.0        45
# 273  28.0        46
# 272  28.0        47
# 271  28.0        48
# 270  28.0        49

# %%
# add universal team codes for home and away teams
fixtures = fixtures.merge(teams, left_on='home_team', right_on='team', how='left')
fixtures = fixtures.merge(teams, left_on='away_team', right_on='team', how='left')
fixtures = fixtures[['gw', 'match_no', 'home_team', 'away_team', 'kickoff_time', 'team_code_x', 'team_code_y']]
fixtures.rename(index=str,
                columns={'team_code_x':'home_team_code',
                         'team_code_y':'away_team_code'},
                inplace=True)

# %%
fixtures.head()
# Out:
#      gw  match_no         home_team          away_team          kickoff_time  \
# 0  24.0         0  Newcastle United            Everton  2022-02-08T19:45:00Z
# 1  24.0         1   West Ham United            Watford  2022-02-08T19:45:00Z
# 2  24.0         2           Burnley  Manchester United  2022-02-08T20:00:00Z
# 3  24.0         3   Manchester City          Brentford  2022-02-09T19:45:00Z
# 4  24.0         4           Norwich     Crystal Palace  2022-02-09T19:45:00Z
#
#    home_team_code  away_team_code
# 0               4              11
# 1              21              57
# 2              90               1
# 3              43              94
# 4              45              31

# %%
# all_players.replace(to_replace='None', value=1, inplace=True)

# %%
all_players[all_players['play_proba_2122'] == '0']
# Out:
#                      full_name play_proba_2122  position_2122  id_2122  \
# 1         Rúnar Alex Rúnarsson               0              1        2
# 2      Willian Borges Da Silva               0              3        3
# 3    Pierre-Emerick Aubameyang               0              4        4
# 7                   Pablo Marí               0              2        8
# 8              Héctor Bellerín               0              2        9
# ..                         ...             ...            ...      ...
# 693             Hee-Chan Hwang               0              4      583
# 694              Louie Moulden               0              1      611
# 697  Bruno André Cavaco Jordão               0              3      661
# 699             Dion Sanderson               0              2      686
# 700                 Ryan Giles               0              3      687
#
#      cost_2122  team_2122 web_name_2122
# 1           40          3     Rúnarsson
# 2           63          3       Willian
# 3           96          3    Aubameyang
# 7           42          3          Marí
# 8           48          3      Bellerín
# ..         ...        ...           ...
# 693         54         39         Hwang
# 694         40         39       Moulden
# 697         45         39        Jordão
# 699         40         39     Sanderson
# 700         45         39         Giles
#
# [180 rows x 7 columns]

# %%
# join home team to all players for current season
home_df = fixtures.merge(all_players, 
               left_on='home_team_code', 
               right_on='team_2122', 
               how='left')

# pull out the required fields and rename columns
home_df = home_df[['gw', 'match_no', 'home_team', 'away_team', 'kickoff_time', 
                   'full_name', 'position_2122', 'cost_2122', 'play_proba_2122', 
                   'web_name_2122']]
home_df.rename(index=str, 
               columns={'home_team':'team',
                        'away_team':'opponent_team',
                        'full_name':'player',
                        'position_2122':'position',
                        'cost_2122':'price',
                        'play_proba_2122':'play_proba',
                        'web_name_2122':'short_name'},
              inplace=True)

# add home flag
home_df['was_home'] = True

# %%
# join away team to all players for current season
away_df = fixtures.merge(all_players, 
               left_on='away_team_code', 
               right_on='team_2122', 
               how='left')

# pull out the required fields and rename columns
away_df = away_df[['gw',  'match_no', 'away_team', 'home_team', 'kickoff_time', 
                   'full_name', 'position_2122', 'cost_2122', 'play_proba_2122', 
                   'web_name_2122']]
away_df.rename(index=str, 
               columns={'away_team':'team',
                        'home_team':'opponent_team',
                        'full_name':'player',
                        'position_2122':'position',
                        'cost_2122':'price',
                        'play_proba_2122':'play_proba',
                        'web_name_2122':'short_name'},
              inplace=True)

# add home flag
away_df['was_home'] = False

# %%
# look at away players
away_df.head()
# Out:
#      gw  match_no     team     opponent_team          kickoff_time  \
# 0  24.0         0  Everton  Newcastle United  2022-02-08T19:45:00Z
# 1  24.0         0  Everton  Newcastle United  2022-02-08T19:45:00Z
# 2  24.0         0  Everton  Newcastle United  2022-02-08T19:45:00Z
# 3  24.0         0  Everton  Newcastle United  2022-02-08T19:45:00Z
# 4  24.0         0  Everton  Newcastle United  2022-02-08T19:45:00Z
#
#              player  position  price play_proba  short_name  was_home
# 0    Anwar El Ghazi         3     56        100    El Ghazi     False
# 1      Fabian Delph         3     43          0       Delph     False
# 2  Gylfi Sigurdsson         3     67          0  Sigurdsson     False
# 3    Seamus Coleman         2     49        100     Coleman     False
# 4   James Rodríguez         3     69          0       James     False

# %%
# look at home players
home_df.head()
# Out:
#      gw  match_no              team opponent_team          kickoff_time  \
# 0  24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 1  24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 2  24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 3  24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 4  24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
#
#            player  position  price play_proba short_name  was_home
# 0  Joseph Willock         3     57        100    Willock      True
# 1    Matt Targett         2     47        100    Targett      True
# 2        Dan Burn         2     44         75       Burn      True
# 3      Chris Wood         4     67        100       Wood      True
# 4   Jonjo Shelvey         3     53        100    Shelvey      True

# %%
# # calculate average minutes over last 5 gameweeks
# # first get last 5 gameweeks in current season
# recent_mins = df_train_new[(df_train_new['gw'] >= current_gw - 5) & 
#                            (df_train_new['season'] == season_names[0])][['player', 'minutes', 'play_proba']]

# # recent_mins = df_train_new[((df_train_new['gw'] >= 40 - 5) & 
# #                            (df_train_new['season'] == '1920')) | 
# #                            ((df_train_new['gw'] >= 1) & 
# #                            (df_train_new['season'] == '2021'))][['player', 'minutes', 'play_proba']]

# # exclude weeks where the player had an injury designation (i.e. keep where play_proba is 1)
# recent_mins = recent_mins[recent_mins['play_proba'] == 1]

# len(recent_mins)

# # average for each player
# recent_mins = recent_mins.groupby(['player'])['minutes'].mean().to_dict()

# recent_mins

# %%
# concatenate home and away players
remaining_season_df = home_df.append(away_df).reset_index(drop=True)

# add home and away team market values
remaining_season_df = remaining_season_df.merge(teams_mv[teams_mv['season'] == '2122'],
                                                left_on='team', 
                                                right_on='name', 
                                                how='left').drop(['name', 'season'], axis=1)

remaining_season_df = remaining_season_df.merge(teams_mv[teams_mv['season'] == '2122'],
                                                left_on='opponent_team', 
                                                right_on='name', 
                                                how='left').drop(['name', 'season'], axis=1)

remaining_season_df.rename(index=str, 
                           columns={'relative_market_value_x':'relative_market_value_team',
                                    'relative_market_value_y':'relative_market_value_opponent_team'},
                           inplace=True)

# add season name
remaining_season_df['season'] = season_names[0]

# divide cost by 10 for actual cost
remaining_season_df['price'] = remaining_season_df['price']/10

# set availability probability
# 0 = 0% chance, 25 = 25% chance, etc
# 'None' or '100' = 100% chance
remaining_season_df.loc[remaining_season_df['play_proba'] == 'None', 'play_proba'] = 100
remaining_season_df['play_proba'] = remaining_season_df['play_proba'].astype('float') / 100

# cast position to integer
remaining_season_df['position'] = remaining_season_df['position'].astype(int)

# # add minutes based on last five fixtures
# remaining_season_df['minutes'] = remaining_season_df['player'].map(recent_mins)
# remaining_season_df['minutes'].fillna(0, inplace=True)

# # multiply minutes by play probability
# remaining_season_df['minutes'] = remaining_season_df['minutes'] * remaining_season_df['play_proba']

# %%
remaining_season_df.head(50)
# Out:
#       gw  match_no              team opponent_team          kickoff_time  \
# 0   24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 1   24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 2   24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 3   24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 4   24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 5   24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 6   24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 7   24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 8   24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 9   24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 10  24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 11  24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 12  24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 13  24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 14  24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 15  24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 16  24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 17  24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 18  24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 19  24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 20  24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 21  24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 22  24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 23  24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 24  24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 25  24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 26  24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 27  24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 28  24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 29  24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 30  24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 31  24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 32  24.0         0  Newcastle United       Everton  2022-02-08T19:45:00Z
# 33  24.0         1   West Ham United       Watford  2022-02-08T19:45:00Z
# 34  24.0         1   West Ham United       Watford  2022-02-08T19:45:00Z
# 35  24.0         1   West Ham United       Watford  2022-02-08T19:45:00Z
# 36  24.0         1   West Ham United       Watford  2022-02-08T19:45:00Z
# 37  24.0         1   West Ham United       Watford  2022-02-08T19:45:00Z
# 38  24.0         1   West Ham United       Watford  2022-02-08T19:45:00Z
# 39  24.0         1   West Ham United       Watford  2022-02-08T19:45:00Z
# 40  24.0         1   West Ham United       Watford  2022-02-08T19:45:00Z
# 41  24.0         1   West Ham United       Watford  2022-02-08T19:45:00Z
# 42  24.0         1   West Ham United       Watford  2022-02-08T19:45:00Z
# 43  24.0         1   West Ham United       Watford  2022-02-08T19:45:00Z
# 44  24.0         1   West Ham United       Watford  2022-02-08T19:45:00Z
# 45  24.0         1   West Ham United       Watford  2022-02-08T19:45:00Z
# 46  24.0         1   West Ham United       Watford  2022-02-08T19:45:00Z
# 47  24.0         1   West Ham United       Watford  2022-02-08T19:45:00Z
# 48  24.0         1   West Ham United       Watford  2022-02-08T19:45:00Z
# 49  24.0         1   West Ham United       Watford  2022-02-08T19:45:00Z
#
#                                  player  position  price  play_proba  \
# 0                        Joseph Willock         3    5.7        1.00
# 1                          Matt Targett         2    4.7        1.00
# 2                              Dan Burn         2    4.4        0.75
# 3                            Chris Wood         4    6.7        1.00
# 4                         Jonjo Shelvey         3    5.3        1.00
# 5                          Matt Ritchie         2    4.9        0.00
# 6                          Ciaran Clark         2    4.4        0.00
# 7                           Karl Darlow         1    4.5        1.00
# 8                       Martin Dubravka         1    4.4        1.00
# 9                         Callum Wilson         4    7.2        0.00
# 10                        Jeff Hendrick         3    4.8        0.00
# 11                          Ryan Fraser         3    5.3        1.00
# 12                     Jamaal Lascelles         2    4.4        1.00
# 13                         Dwight Gayle         4    5.2        1.00
# 14                         Paul Dummett         2    4.5        0.25
# 15                     Javier Manquillo         2    3.9        1.00
# 16                          Emil Krafth         2    4.3        1.00
# 17                         Jacob Murphy         3    4.7        1.00
# 18                         Fabian Schär         2    4.3        1.00
# 19                         Isaac Hayden         3    4.5        0.00
# 20                  Allan Saint-Maximin         4    6.8        1.00
# 21                       Miguel Almirón         3    5.1        1.00
# 22                       Sean Longstaff         3    4.4        1.00
# 23  Joelinton Cássio Apolinário de Lira         4    5.8        0.75
# 24                          Jamal Lewis         2    4.2        0.00
# 25                    Matthew Longstaff         3    4.5        0.00
# 26                   Federico Fernández         2    4.3        0.00
# 27                      Freddie Woodman         1    4.3        0.00
# 28                       Mark Gillespie         1    4.0        1.00
# 29                            Joe White         3    4.4        0.00
# 30                      Elliot Anderson         3    4.5        0.00
# 31                      Kieran Trippier         2    5.0        1.00
# 32      Bruno Guimarães Rodriguez Moura         3    5.0        1.00
# 33                           Kurt Zouma         2    5.4        1.00
# 34                           Mark Noble         3    4.4        1.00
# 35                      Darren Randolph         1    4.3        1.00
# 36                     Lukasz Fabianski         1    5.0        0.75
# 37                       Angelo Ogbonna         2    4.9        0.00
# 38                         Winston Reid         2    3.9        0.00
# 39                      Aaron Cresswell         2    5.3        1.00
# 40                    Andriy Yarmolenko         3    5.1        1.00
# 41                      Michail Antonio         4    7.9        0.75
# 42                         Craig Dawson         2    4.9        1.00
# 43                      Ryan Fredericks         2    4.4        1.00
# 44                       Manuel Lanzini         3    5.8        0.50
# 45                       Arthur Masuaku         2    4.4        0.25
# 46                      Vladimir Coufal         2    4.7        1.00
# 47                        Saïd Benrahma         3    5.9        1.00
# 48                         Jarrod Bowen         3    6.9        1.00
# 49                          Declan Rice         3    5.1        1.00
#
#          short_name  was_home  relative_market_value_team  \
# 0           Willock      True                         NaN
# 1           Targett      True                         NaN
# 2              Burn      True                         NaN
# 3              Wood      True                         NaN
# 4           Shelvey      True                         NaN
# 5           Ritchie      True                         NaN
# 6             Clark      True                         NaN
# 7            Darlow      True                         NaN
# 8          Dubravka      True                         NaN
# 9            Wilson      True                         NaN
# 10         Hendrick      True                         NaN
# 11           Fraser      True                         NaN
# 12        Lascelles      True                         NaN
# 13            Gayle      True                         NaN
# 14          Dummett      True                         NaN
# 15        Manquillo      True                         NaN
# 16           Krafth      True                         NaN
# 17           Murphy      True                         NaN
# 18            Schär      True                         NaN
# 19           Hayden      True                         NaN
# 20    Saint-Maximin      True                         NaN
# 21          Almirón      True                         NaN
# 22      S.Longstaff      True                         NaN
# 23        Joelinton      True                         NaN
# 24            Lewis      True                         NaN
# 25      M.Longstaff      True                         NaN
# 26        Fernández      True                         NaN
# 27          Woodman      True                         NaN
# 28        Gillespie      True                         NaN
# 29            White      True                         NaN
# 30         Anderson      True                         NaN
# 31         Trippier      True                         NaN
# 32  Bruno Guimarães      True                         NaN
# 33            Zouma      True                         NaN
# 34            Noble      True                         NaN
# 35         Randolph      True                         NaN
# 36        Fabianski      True                         NaN
# 37          Ogbonna      True                         NaN
# 38             Reid      True                         NaN
# 39        Cresswell      True                         NaN
# 40       Yarmolenko      True                         NaN
# 41          Antonio      True                         NaN
# 42           Dawson      True                         NaN
# 43       Fredericks      True                         NaN
# 44          Lanzini      True                         NaN
# 45          Masuaku      True                         NaN
# 46           Coufal      True                         NaN
# 47         Benrahma      True                         NaN
# 48            Bowen      True                         NaN
# 49             Rice      True                         NaN
#
#     relative_market_value_opponent_team season
# 0                                   NaN   2122
# 1                                   NaN   2122
# 2                                   NaN   2122
# 3                                   NaN   2122
# 4                                   NaN   2122
# 5                                   NaN   2122
# 6                                   NaN   2122
# 7                                   NaN   2122
# 8                                   NaN   2122
# 9                                   NaN   2122
# 10                                  NaN   2122
# 11                                  NaN   2122
# 12                                  NaN   2122
# 13                                  NaN   2122
# 14                                  NaN   2122
# 15                                  NaN   2122
# 16                                  NaN   2122
# 17                                  NaN   2122
# 18                                  NaN   2122
# 19                                  NaN   2122
# 20                                  NaN   2122
# 21                                  NaN   2122
# 22                                  NaN   2122
# 23                                  NaN   2122
# 24                                  NaN   2122
# 25                                  NaN   2122
# 26                                  NaN   2122
# 27                                  NaN   2122
# 28                                  NaN   2122
# 29                                  NaN   2122
# 30                                  NaN   2122
# 31                                  NaN   2122
# 32                                  NaN   2122
# 33                                  NaN   2122
# 34                                  NaN   2122
# 35                                  NaN   2122
# 36                                  NaN   2122
# 37                                  NaN   2122
# 38                                  NaN   2122
# 39                                  NaN   2122
# 40                                  NaN   2122
# 41                                  NaN   2122
# 42                                  NaN   2122
# 43                                  NaN   2122
# 44                                  NaN   2122
# 45                                  NaN   2122
# 46                                  NaN   2122
# 47                                  NaN   2122
# 48                                  NaN   2122
# 49                                  NaN   2122

# %%
# save latest prediction set to csv
remaining_season_df.to_csv(path/'remaining_season.csv')
