# %%
# import required libriaries
from pathlib import Path
import json

from fpl_predictor.util import *

# %%
# path to data directory
#path = Path('/home/jupyter/fpl-prediction/data')
path = Path('./fpl_predictor/data')

# %%
# read in latest training set
df_train = pd.read_csv(path/'train_v8.csv', index_col=0, 
                       dtype={'season':str,
                              'comp':str,
                              'squad':str})

# path to current season
season_paths = [path/'2021-22']

# name for current season
season_names = ['2122']

# team codes
teams = pd.read_csv(path/'teams.csv')

# latest remaining season dataset, for latest week's play_proba values
remaining_season = pd.read_csv(path/'remaining_season.csv', index_col=0)

# create players dataset
all_players = build_players(path, season_paths, season_names, teams)

# 2019-20 market value
# table was in slightly different position for 2019-20 season
# should check that 2019-20 season values remain the same once season starts
teams_mv = build_season_mv('2122', 11, range(13,33))

# %%
# all_players#[all_players['full_name'] == 'Ben Davies']

# %%
df_train.tail(50)
# Out:
#                                 player  gw  position  minutes  \
# 115305                   Tariq Lamptey   1         2        0
# 115306                 Taylor Richards   1         3        0
# 115307                     Teemu Pukki   1         4       76
# 115308                    Theo Walcott   1         3       79
# 115309  Thiago Alcántara do Nascimento   1         3        0
# 115310        Thiago Emiliano da Silva   1         2        0
# 115311                   Thomas Partey   1         3        0
# 115312                Timothy Castagne   1         2        0
# 115313                     Timo Werner   1         4       90
# 115314                        Tim Krul   1         1       90
# 115315                 Tino Livramento   1         2       90
# 115316               Toby Alderweireld   1         2        0
# 115317                   Todd Cantwell   1         3       85
# 115318                    Tomas Soucek   1         3       90
# 115319                   Tom Cleverley   1         3       78
# 115320                      Tom Davies   1         3        0
# 115321                      Tom Heaton   1         1        0
# 115322          Trent Alexander-Arnold   1         2       90
# 115323                 Trevoh Chalobah   1         2       90
# 115324                     Troy Deeney   1         4       11
# 115325                   Tyler Roberts   1         3       13
# 115326                 Tyrick Mitchell   1         2       90
# 115327                    Tyrone Mings   1         2       90
# 115328                  Vicente Guaita   1         1       90
# 115329                 Victor Lindelöf   1         2       90
# 115330                 Virgil van Dijk   1         2       90
# 115331                   Vitaly Janelt   1         3       90
# 115332                 Vladimir Coufal   1         2       90
# 115333                 Wayne Hennessey   1         1        0
# 115334                   Wesley Fofana   1         2        0
# 115335                   Wesley Moraes   1         4        0
# 115336                   Wilfred Ndidi   1         3       90
# 115337                   Wilfried Zaha   1         3       90
# 115338                  William Saliba   1         2        0
# 115339               William Smallbone   1         3        0
# 115340            William Troost-Ekong   1         2       90
# 115341         Willian Borges Da Silva   1         3        0
# 115342                      Willy Boly   1         2        0
# 115343                     Will Hughes   1         3        0
# 115344                     Will Norris   1         1        0
# 115345                    Winston Reid   1         2        0
# 115346                 Xherdan Shaqiri   1         3        0
# 115347                      Yan Valery   1         2        0
# 115348                      Yerry Mina   1         2        7
# 115349      Yerson Mosquera Valdelamar   1         2        0
# 115350                     Yoane Wissa   1         3        0
# 115351                 Youri Tielemans   1         3       90
# 115352                   Yves Bissouma   1         3       90
# 115353                    Zack Steffen   1         1        0
# 115354                  Çaglar Söyüncü   1         2       90
#
#                             team             opponent_team  \
# 115336                    1.230500                             0.889458
# 115337                    0.477592                             2.083714
# 115338                    1.190377                             0.372963
# 115339                    0.532456                             1.098383
# 115340                    0.327077                             0.951637
# 115341                    1.190377                             0.372963
# 115342                    0.889458                             1.230500
# 115343                    0.327077                             0.951637
# 115344                    0.283075                             0.549968
# 115345                    0.628994                             0.546199
# 115346                    1.998371                             0.328739
# 115347                    0.532456                             1.098383
# 115348                    1.098383                             0.532456
# 115349                    0.889458                             1.230500
# 115350                    0.372963                             1.190377
# 115351                    1.230500                             0.889458
# 115352                    0.549968                             0.283075
# 115353                    2.349720                             1.560569
# 115354                    1.230500                             0.889458
#
#         was_home  total_points  ...   xa  sca  gca  passes_completed  passes  \
# 115305     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 115306     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 115307      True             2  ...  0.0  0.0  0.0              10.0    11.0
# 115308     False             2  ...  0.0  0.0  0.0              12.0    20.0
# 115309     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 115310      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 115311     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 115312      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 115313      True             2  ...  0.0  1.0  0.0              13.0    21.0
# 115314      True             2  ...  0.0  0.0  0.0              30.0    44.0
# 115315     False             1  ...  0.0  0.0  0.0              38.0    52.0
# 115316      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 115317      True             1  ...  0.2  3.0  0.0              23.0    27.0
# 115318     False             8  ...  0.0  1.0  0.0              32.0    37.0
# 115319      True             5  ...  0.0  2.0  1.0              18.0    29.0
# 115320      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 115321      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 115322     False             6  ...  0.2  5.0  1.0              44.0    58.0
# 115323      True            14  ...  0.0  0.0  0.0              73.0    80.0
# 115324      True             1  ...  0.0  0.0  0.0               1.0     1.0
# 115325     False             1  ...  0.3  1.0  0.0               3.0     3.0
# 115326     False             1  ...  0.0  0.0  0.0              29.0    33.0
# 115327     False             0  ...  0.0  0.0  0.0              74.0    81.0
# 115328     False             2  ...  0.0  0.0  0.0              34.0    41.0
# 115329      True             5  ...  0.2  2.0  1.0              44.0    52.0
# 115330     False             7  ...  0.0  1.0  0.0              79.0    85.0
# 115331      True             3  ...  0.0  1.0  0.0              22.0    30.0
# 115332     False             1  ...  0.6  1.0  0.0              42.0    61.0
# 115333      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 115334      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 115335     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 115336      True             3  ...  0.0  1.0  0.0              64.0    67.0
# 115337     False             2  ...  0.0  1.0  0.0              14.0    19.0
# 115338     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 115339     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 115340      True             1  ...  0.0  0.0  0.0              33.0    41.0
# 115341     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 115342     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 115343      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 115344      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 115345     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 115346     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 115347     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 115348      True             1  ...  0.0  0.0  0.0               1.0     2.0
# 115349     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 115350      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 115351      True             3  ...  0.1  2.0  0.0              72.0    86.0
# 115352     False             2  ...  0.0  1.0  1.0              42.0    45.0
# 115353     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 115354      True             6  ...  0.0  0.0  0.0              80.0    88.0
#
#         passes_pct  carries  dribbles_completed  dribbles  crowds
# 115305         NaN      NaN                 NaN       NaN       1
# 115306         NaN      NaN                 NaN       NaN       1
# 115307        90.9     12.0                 0.0       1.0       1
# 115308        60.0     12.0                 0.0       0.0       1
# 115309         NaN      NaN                 NaN       NaN       1
# 115310         NaN      NaN                 NaN       NaN       1
# 115311         NaN      NaN                 NaN       NaN       1
# 115312         NaN      NaN                 NaN       NaN       1
# 115313        61.9     17.0                 1.0       1.0       1
# 115314        68.2     24.0                 0.0       0.0       1
# 115315        73.1     39.0                 1.0       3.0       1
# 115316         NaN      NaN                 NaN       NaN       1
# 115317        85.2     37.0                 0.0       1.0       1
# 115318        86.5     29.0                 1.0       1.0       1
# 115319        62.1     19.0                 0.0       0.0       1
# 115320         NaN      NaN                 NaN       NaN       1
# 115321         NaN      NaN                 NaN       NaN       1
# 115322        75.9     37.0                 1.0       5.0       1
# 115323        91.3     69.0                 1.0       1.0       1
# 115324       100.0      0.0                 0.0       0.0       1
# 115325       100.0      6.0                 0.0       0.0       1
# 115326        87.9     26.0                 0.0       1.0       1
# 115327        91.4     60.0                 2.0       2.0       1
# 115328        82.9     26.0                 0.0       0.0       1
# 115329        84.6     40.0                 0.0       0.0       1
# 115330        92.9     66.0                 0.0       0.0       1
# 115331        73.3     25.0                 0.0       0.0       1
# 115332        68.9     42.0                 1.0       1.0       1
# 115333         NaN      NaN                 NaN       NaN       1
# 115334         NaN      NaN                 NaN       NaN       1
# 115335         NaN      NaN                 NaN       NaN       1
# 115336        95.5     53.0                 1.0       1.0       1
# 115337        73.7     28.0                 1.0       1.0       1
# 115338         NaN      NaN                 NaN       NaN       1
# 115339         NaN      NaN                 NaN       NaN       1
# 115340        80.5     23.0                 0.0       0.0       1
# 115341         NaN      NaN                 NaN       NaN       1
# 115342         NaN      NaN                 NaN       NaN       1
# 115343         NaN      NaN                 NaN       NaN       1
# 115344         NaN      NaN                 NaN       NaN       1
# 115345         NaN      NaN                 NaN       NaN       1
# 115346         NaN      NaN                 NaN       NaN       1
# 115347         NaN      NaN                 NaN       NaN       1
# 115348        50.0      0.0                 0.0       0.0       1
# 115349         NaN      NaN                 NaN       NaN       1
# 115350         NaN      NaN                 NaN       NaN       1
# 115351        83.7     63.0                 1.0       1.0       1
# 115352        93.3     38.0                 0.0       0.0       1
# 115353         NaN      NaN                 NaN       NaN       1
# 115354        90.9     76.0                 0.0       0.0       1
#
# [50 rows x 59 columns]

# %%
# find the latest gameweek
last_gw = df_train['gw'][df_train['season'] == season_names[0]].max()

if np.isnan(last_gw): 
    last_gw = 1 
else: 
    last_gw = last_gw + 1
    
last_gw
# Out:
# 2

# %%
# build training set for latest gameweek
df_latest = build_season(season_paths[0], season_names[0], all_players, teams, teams_mv, [last_gw])

# %%
df_latest.drop_duplicates(inplace=True)

# %%
df_latest.head(50)
# Out:
#                             player  gw  position  minutes  \
# 0                   Aaron Connolly   2         4       45
# 1                  Aaron Cresswell   2         2       90
# 2                   Aaron Ramsdale   2         1        0
# 3                     Aaron Ramsey   2         3        0
# 4                Aaron Wan-Bissaka   2         2       90
# 5               Abdoulaye Doucouré   2         3       90
# 6                     Adama Traoré   2         3       90
# 7                   Adam Armstrong   2         4       90
# 8                     Adam Forshaw   2         3        0
# 9                        Adam Idah   2         4        0
# 10                    Adam Lallana   2         3       79
# 11                     Adam Masina   2         2       90
# 12                    Adam Webster   2         2       90
# 41                   Everton                     Leeds
# 42         Manchester United               Southampton
# 43                   Chelsea                   Arsenal
# 44               Aston Villa          Newcastle United
# 45               Southampton         Manchester United
# 46           West Ham United            Leicester City
# 47                   Burnley                 Liverpool
# 48                   Watford  Brighton and Hove Albion
# 49                   Burnley                 Liverpool
#
#     relative_market_value_team  relative_market_value_opponent_team  was_home  \
# 0                     0.538249                             0.322706      True
# 1                     0.628252                             1.233477      True
# 2                     1.268682                             2.025905      True
# 3                     0.950515                             0.534485      True
# 4                     2.115023                             0.543120     False
# 5                     1.095428                             0.538581     False
# 6                     0.858519                             1.558729      True
# 7                     0.543120                             2.115023      True
# 8                     0.538581                             1.095428      True
# 9                     0.341636                             2.346950     False
# 10                    0.538249                             0.322706      True
# 11                    0.322706                             0.538249     False
# 12                    0.538249                             0.322706      True
# 13                    0.322706                             0.538249     False
# 14                    1.965017                             0.285177      True
# 15                    1.268682                             2.025905      True
# 16                    1.268682                             2.025905      True
# 17                    2.115023                             0.543120     False
# 18                    1.268682                             2.025905      True
# 19                    0.538249                             0.322706      True
# 20                    1.095428                             0.538581     False
# 21                    0.543120                             2.115023      True
# 22                    1.965017                             0.285177      True
# 23                    0.538249                             0.322706      True
# 24                    1.965017                             0.285177      True
# 25                    1.095428                             0.538581     False
# 26                    0.534485                             0.950515     False
# 27                    0.628252                             1.233477      True
# 28                    0.538249                             0.322706      True
# 29                    2.025905                             1.268682     False
# 30                    2.115023                             0.543120     False
# 31                    0.858519                             1.558729      True
# 32                    0.341636                             2.346950     False
# 33                    1.965017                             0.285177      True
# 34                    0.322706                             0.538249     False
# 35                    0.628252                             1.233477      True
# 36                    1.095428                             0.538581     False
# 37                    1.095428                             0.538581     False
# 38                    0.628252                             1.233477      True
# 39                    0.341636                             2.346950     False
# 40                    2.115023                             0.543120     False
# 41                    1.095428                             0.538581     False
# 42                    2.115023                             0.543120     False
# 43                    2.025905                             1.268682     False
# 44                    0.950515                             0.534485      True
# 45                    0.543120                             2.115023      True
# 46                    0.628252                             1.233477      True
# 47                    0.285177                             1.965017     False
# 48                    0.322706                             0.538249     False
# 49                    0.285177                             1.965017     False
#
#     total_points  ...  selected  team_a_score  team_h_score  threat  \
# 0              1  ...     15599             0             2     6.0
# 1              2  ...   1345295             1             4     6.0
# 2              0  ...      1432             2             0     0.0
# 3              0  ...     11767             0             2     0.0
# 4              2  ...    707386             1             1     2.0
# 5              4  ...     71179             2             2    16.0
# 6              2  ...     85215             1             0    65.0
# 7              2  ...    165181             1             1    26.0
# 8              0  ...       503             2             2     0.0
# 9              0  ...     36741             0             5     0.0
# 10             3  ...     18760             0             2     2.0
# 11             1  ...      9061             0             2     0.0
# 12             5  ...     43513             0             2     0.0
# 13             0  ...     16511             0             2     0.0
# 14             0  ...     19533             0             2     0.0
# 15             0  ...      6016             2             0     0.0
# 16             1  ...     16263             2             0     1.0
# 17             0  ...      1321             1             1     0.0
# 18             0  ...    108809             2             0     0.0
# 19             3  ...     43643             0             2    39.0
# 6   2021-08-22T13:00:00Z    2122
# 7   2021-08-22T13:00:00Z    2122
# 8   2021-08-21T14:00:00Z    2122
# 9   2021-08-21T14:00:00Z    2122
# 10  2021-08-21T16:30:00Z    2122
# 11  2021-08-21T16:30:00Z    2122
# 12  2021-08-21T16:30:00Z    2122
# 13  2021-08-21T16:30:00Z    2122
# 14  2021-08-21T11:30:00Z    2122
# 15  2021-08-22T15:30:00Z    2122
# 16  2021-08-22T15:30:00Z    2122
# 17  2021-08-22T13:00:00Z    2122
# 18  2021-08-22T15:30:00Z    2122
# 19  2021-08-21T16:30:00Z    2122
# 20  2021-08-21T14:00:00Z    2122
# 21  2021-08-22T13:00:00Z    2122
# 22  2021-08-21T11:30:00Z    2122
# 23  2021-08-21T16:30:00Z    2122
# 24  2021-08-21T11:30:00Z    2122
# 25  2021-08-21T14:00:00Z    2122
# 26  2021-08-21T14:00:00Z    2122
# 27  2021-08-23T19:00:00Z    2122
# 28  2021-08-21T16:30:00Z    2122
# 29  2021-08-22T15:30:00Z    2122
# 30  2021-08-22T13:00:00Z    2122
# 31  2021-08-22T13:00:00Z    2122
# 32  2021-08-21T14:00:00Z    2122
# 33  2021-08-21T11:30:00Z    2122
# 34  2021-08-21T16:30:00Z    2122
# 35  2021-08-23T19:00:00Z    2122
# 36  2021-08-21T14:00:00Z    2122
# 37  2021-08-21T14:00:00Z    2122
# 38  2021-08-23T19:00:00Z    2122
# 39  2021-08-21T14:00:00Z    2122
# 40  2021-08-22T13:00:00Z    2122
# 41  2021-08-21T14:00:00Z    2122
# 42  2021-08-22T13:00:00Z    2122
# 43  2021-08-22T15:30:00Z    2122
# 44  2021-08-21T14:00:00Z    2122
# 45  2021-08-22T13:00:00Z    2122
# 46  2021-08-23T19:00:00Z    2122
# 47  2021-08-21T11:30:00Z    2122
# 48  2021-08-21T16:30:00Z    2122
# 49  2021-08-21T11:30:00Z    2122
#
# [50 rows x 34 columns]

# %%
df_latest.shape
# Out:
# (566, 34)

# %%
last_play_proba = remaining_season[remaining_season['gw'] == last_gw][['player', 'team', 'play_proba']]

# %%
last_play_proba.head()
# Out:
#                            player       team  play_proba
# 0                    James Milner  Liverpool         1.0
# 1                Jordan Henderson  Liverpool         1.0
# 2  Adrián San Miguel del Castillo  Liverpool         1.0
# 3                      Joel Matip  Liverpool         1.0
# 4  Thiago Alcántara do Nascimento  Liverpool         1.0

# %%
# add latest week's play_proba for each player
df_latest = df_latest.merge(last_play_proba, on=['player', 'team'], how='left')

# %%
df_latest.drop_duplicates(inplace=True)

# %%
df_train.drop_duplicates(inplace=True)

# %%
if last_gw==1:
    df_latest['relative_market_value_team_season'] = df_latest['relative_market_value_team']
    df_latest['relative_market_value_opponent_team_season'] = df_latest['relative_market_value_opponent_team']

# %%
# for when you're doing the season value properly
# relative_market_value_season = train_df[train_df['season'] == '2021'][['team', 'relative_market_value_team']].groupby(['team']).first()
# relative_market_value_season = relative_market_value_season.rename(columns={'relative_market_value_team': 'season_value'})
# relative_market_value_season

# %%
# now get futher stats from fbref
# standard stats
features = ['squad', 'comp', 'round', 'shots_total', 'shots_on_target', 'touches', 'pressures',
            'tackles', 'interceptions', 'blocks', 'xg', 'npxg', 'xa', 'sca', 
            'gca', 'passes_completed', 'passes', 'passes_pct',  'carries', 
            'dribbles_completed', 'dribbles']

# %%
# url for the premier league
url_base = 'https://fbref.com'
pl_history_page = '/en/comps/9/history/Premier-League-Seasons'
url = url_base + pl_history_page

# scrape the history table to get latest season
pl_history_table = get_table(url)
pl_history_urls = get_urls(['season'], 'season', pl_history_table, url_base)
season_urls = pl_history_urls[0:1]

df_enhanced = get_stats(features, season_urls, url_base)
# Out:
# 2021-2022
# https://fbref.com/en/comps/9/Premier-League-Stats
# West Ham
# https://fbref.com/en/squads/7c21e445/West-Ham-United-Stats
# Vladimír Coufal
# Aaron Cresswell
# Craig Dawson
# Łukasz Fabiański
# Pablo Fornals
# Angelo Ogbonna
# Declan Rice
# Tomáš Souček
# Jarrod Bowen
# Michail Antonio
# Saïd Benrahma
# Ryan Fredericks
# Mark Noble
# Andriy Yarmolenko
# Ben Johnson
# Chelsea
# https://fbref.com/en/squads/cff3d9bb/Chelsea-Stats
# Andreas Christensen
# Jorginho
# Edouard Mendy
# Antonio Rüdiger
# Marcos Alonso
# Mason Mount
# Mateo Kovačić
# César Azpilicueta
# Reece James
# Kai Havertz
# Timo Werner
# Trevoh Chalobah
# Romelu Lukaku
# Christian Pulisic
# N'Golo Kanté
# Hakim Ziyech
# Emerson Palmieri
# Liverpool
# https://fbref.com/en/squads/822bd0ba/Liverpool-Stats
# Trent Alexander-Arnold
# Alisson
# Virgil van Dijk
# Sadio Mané
# Joël Matip
# Mohamed Salah
# Kostas Tsimikas
# Naby Keïta
# Diogo Jota
# Harvey Elliot
# Jordan Henderson
# James Milner
# Alex Oxlade-Chamberlain
# Roberto Firmino
# Fabinho
# Thiago Alcántara
# Joe Gomez
# Brighton
# https://fbref.com/en/squads/d07537b9/Brighton-and-Hove-Albion-Stats
# Yves Bissouma
# Shane Duffy
# Lewis Dunk
# Pascal Groß
# Solly March
# Robert Sánchez
# Adam Webster
# Leandro Trossard
# Neal Maupay
# Adam Lallana
# Alexis Mac Allister
# Steven Alzate
# Enoch Mwepu
# Aaron Connolly
# Jakub Moder
# Tottenham
# https://fbref.com/en/squads/361ca564/Tottenham-Hotspur-Stats
# Dele Alli
# Eric Dier
# Hugo Lloris
# Sergio Reguilón
# Davinson Sánchez
# Oliver Skipp
# Pierre Højbjerg
# Japhet Tanganga
# Steven Bergwijn
# Son Heung-min
# Lucas Moura
# Giovani Lo Celso
# Harry Kane
# Matt Doherty
# Cristian Romero
# Harry Winks
# Manchester Utd
# https://fbref.com/en/squads/19538871/Manchester-United-Stats
# Bruno Fernandes
# David de Gea
# Mason Greenwood
# Victor Lindelöf
# Harry Maguire
# Luke Shaw
# Aaron Wan-Bissaka
# Fred
# Paul Pogba
# Nemanja Matić
# Scott McTominay
# Daniel James
# Anthony Martial
# Jadon Sancho
# Jesse Lingard
# Everton
# https://fbref.com/en/squads/d3fd31cc/Everton-Stats
# Allan
# Séamus Coleman
# Lucas Digne
# Abdoulaye Doucouré
# Michael Keane
# Jordan Pickford
# Dominic Calvert-Lewin
# Richarlison
://fbref.com/en/squads/8cec06e1/Wolverhampton-Wanderers-Stats
# Conor Coady
# Raúl Jiménez
# Fernando Marçal
# Rúben Neves
# José Sá
# Adama Traoré
# Max Kilman
# Romain Saïss
# Francisco Trincão
# João Moutinho
# Ki-Jana Hoever
# Nélson Semedo
# Leander Dendoncker
# Fábio Silva
# Rayan Aït Nouri
# Morgan Gibbs-White
# Burnley
# https://fbref.com/en/squads/943e8050/Burnley-Stats
# Matthew Lowton
# Ben Mee
# Nick Pope
# James Tarkowski
# Charlie Taylor
# Jack Cork
# Jóhann Berg Guðmundsson
# Dwight McNeil
# Chris Wood
# Ashley Barnes
# Josh Brownhill
# Ashley Westwood
# Jay Rodriguez
# Erik Pieters
# Matěj Vydra
# Newcastle Utd
# https://fbref.com/en/squads/b2b47a98/Newcastle-United-Stats
# Miguel Almirón
# Jacob Murphy
# Matt Ritchie
# Allan Saint-Maximin
# Freddie Woodman
# Callum Wilson
# Federico Fernández
# Isaac Hayden
# Ciaran Clark
# Jamaal Lascelles
# Fabian Schär
# Joe Willock
# Emil Krafth
# Jonjo Shelvey
# Sean Longstaff
# Ryan Fraser
# Joelinton
# Arsenal
# https://fbref.com/en/squads/18bb7c10/Arsenal-Stats
# Bernd Leno
# Pablo Marí
# Nicolas Pépé
# Albert Sambi Lokonga
# Emile Smith-Rowe
# Granit Xhaka
# Kieran Tierney
# Martinelli
# Bukayo Saka
# Rob Holding
# Cédric Soares
# Ben White
# Calum Chambers
# Folarin Balogun
# Nuno Tavares
# Pierre-Emerick Aubameyang
# Reiss Nelson
# Norwich City
# https://fbref.com/en/squads/1c781004/Norwich-City-Stats
# Max Aarons
# Ben Gibson
# Billy Gilmour
# Grant Hanley
# Tim Krul
# Pierre Lees-Melou
# Todd Cantwell
# Milot Rashica
# Teemu Pukki
# Dimitris Giannoulis
# Lukas Rupp
# Kenny McLean
# Bali Mumba
# Josh Sargent
# Adam Idah
# Kieran Dowell

# %%
# get the player name matching dictionary
with open(path/'match_list.json') as f:
  match_list = json.load(f)

match_list
# Out:
# {'Fabinho': 'Fabio Henrique Tavares',
#  'Alisson': 'Alisson Ramses Becker',
#  'Joël Matip': 'Joel Matip',
#  'Joe Gomez': 'Joseph Gomez',
#  'Naby Keïta': 'Naby Keita',
#  'Adrián': 'Adrián San Miguel del Castillo',
#  'Thiago Alcántara': 'Thiago Alcántara do Nascimento',
#  'Allan': 'Allan Marques Loureiro',
#  'Richarlison': 'Richarlison de Andrade',
#  'Gylfi Sigurðsson': 'Gylfi Sigurdsson',
#  'Séamus Coleman': 'Seamus Coleman',
#  'André Gomes': 'André Filipe Tavares Gomes',
#  'Bernard': 'Bernard Anício Caldeira Duarte',
#  'Çağlar Söyüncü': 'Çaglar Söyüncü',
#  'Bruno Fernandes': 'Bruno Miguel Borges Fernandes',
#  'Fred': 'Frederico Rodrigues de Paula Santos',
#  'Nemanja Matić': 'Nemanja Matic',
#  'Alex Telles': 'Alex Nicolao Telles',
#  'Pierre Højbjerg': 'Pierre-Emile Højbjerg',
#  'Son Heung-min': 'Heung-Min Son',
#  'Lucas Moura': 'Lucas Rodrigues Moura da Silva',
#  'Érik Lamela': 'Erik Lamela',
#  'Dele Alli': 'Bamidele Alli',
#  'Carlos Vinícius': 'Carlos Vinicius Alves Morais',
#  'Ederson': 'Ederson Santana de Moraes',
#  'Rodri': 'Rodrigo Hernandez',
#  'Rúben Dias': 'Rúben Santos Gato Alves Dias',
#  'João Cancelo': 'João Pedro Cavaco Cancelo',
#  'İlkay Gündoğan': 'Ilkay Gündogan',
#  'Gabriel Jesus': 'Gabriel Fernando de Jesus',
#  'Ferrán Torres': 'Ferran Torres',
#  'Bernardo Silva': 'Bernardo Mota Veiga de Carvalho e Silva',
#  'Fernandinho': 'Fernando Luiz Rosa',
#  'Eric García': 'Eric Garcia',
#  'Matty Cash': 'Matthew Cash',
#  'Douglas Luiz': 'Douglas Luiz Soares de Paulo',
#  'Ezri Konsa': 'Ezri Konsa Ngoyo',
#  'Trézéguet': 'Mahmoud Ahmed Ibrahim Hassan',
#  'Ben Chilwell': 'Benjamin Chilwell',
#  'Thiago Silva': 'Thiago Thiago',
#  'Mateo Kovačić': 'Mateo Kovacic',
#  'Jorginho': 'Jorge Luiz Frello Filho',
#  'Emerson Palmieri': 'Emerson Palmieri dos Santos',
#  'Oriol Romeu': 'Oriol Romeu Vidal',
#  'Dan Nlundulu': "Daniel N'Lundulu",
#  'Łukasz Fabiański': 'Lukasz Fabianski',
#  'Tomáš Souček': 'Tomas Soucek',
#  'Vladimír Coufal': 'Vladimir Coufal',
#  'Felipe Anderson': 'Felipe Anderson Pereira Gomes',
#  'Rui Patrício': 'Rui Pedro dos Santos Patrício',
#  'Pedro Neto': 'Pedro Lomba Neto',
#  'Daniel Podence': 'Daniel Castelo Podence',
#  'Nélson Semedo': 'Nélson Cabral Semedo',
#  'Rúben Neves': 'Rúben Diogo da Silva Neves',
#  'João Moutinho': 'João Filipe Iria Santos Moutinho',
#  'Rayan Aït Nouri': 'Rayan Ait Nouri',
#  'Fábio Silva': 'Fabio Silva',
#  'Rúben Vinagre': 'Rúben Gonçalo Silva Nascimento Vinagre',
#  'Vitinha': 'Vitor Ferreira',
#  'Rodrigo': 'Rodrigo Moreno',
#  'Pablo Hernández': 'Pablo Hernández Domínguez',
#  'Ian Carlo Poveda': 'Ian Carlo Poveda-Ocampo',
#  'Joelinton': 'Joelinton Cássio Apolinário de Lira',
#  'Luka Milivojević': 'Luka Milivojevic',
#  'Jaïro Riedewald': 'Jairo Riedewald',
#  'Gabriel Dos Santos': 'Gabriel Magalhães',
#  'Willian': 'Willian Borges Da Silva',
#  'Dani Ceballos': 'Daniel Ceballos Fernández',
#  'David Luiz': 'David Luiz Moreira Marinho',
#  'Eddie Nketiah': 'Edward Nketiah',
#  'Joe Willock': 'Joseph Willock',
#  'Sead Kolašinac': 'Sead Kolasinac',
#  'Martinelli': 'Gabriel Teodoro Martinelli Silva',
#  'Solly March': 'Solomon March',
#  'Bernardo': 'Bernardo Fernandes da Silva Junior',
#  'Jóhann Berg Guðmundsson': 'Johann Berg Gudmundsson',
#  'Matěj Vydra': 'Matej Vydra',
#  'Andre-Frank Zambo Anguissa': 'André-Frank Zambo Anguissa',
#  'Semi Ajayi': 'Oluwasemilogo Adesewo Ibidapo Ajayi',
#  'Branislav Ivanović': 'Branislav Ivanovic',
#  'Filip Krovinović': 'Filip Krovinovic',
#  'Ahmed Hegazi': 'Ahmed El-Sayed Hegazi',
#  'Harvey Elliot': 'Harvey Elliott',
#  'Angeliño': 'Angelo Ogbonna',
#  'Thomas Doyle': 'Tommy Doyle',
#  'Diogo Dalot': 'José Diogo Dalot Teixeira',
#  'Pedro': 'Pedro Rodríguez Ledesma',
#  'Ricardo Pereira': 'Ricardo Domingos Barbosa Pereira',
#  'Gedson Fernandes': 'Gedson Carvalho Fernandes',
#  "Georges-Kévin N'Koudou": 'Georges-Kévin Nkoudou',
#  'Jonny Castro': 'Jonathan Castro Otto',
#  'Jesús Vallejo': 'Jesús Vallejo Lázaro',
#  'Bruno Jordão': 'Bruno André Cavaco Jordao',
#  'Mattéo Guendouzi': 'Matteo Guendouzi',
#  'Richairo Živković': 'Richairo Zivkovic',
#  'Danny Drinkwater': 'Daniel Drinkwater',
#  'Martin Dúbravka': 'Martin Dubravka',
#  'Yoshinori Mutō': 'Yoshinori Muto',
#  'Ki Sung-yueng': 'Sung-yueng Ki',
#  'Roberto': 'Roberto Jimenez Gago',
#  'Javier Hernández': 'Javier Hernández Balcázar',
#  'Frederic Guilbert': 'Frédéric Guilbert',
#  'Björn Engels': 'Bjorn Engels',
#  'Pepe Reina': 'José Reina',
#  'Jota': 'José Ignacio Peleteiro Romallo',
#  'Arnaut Groeneveld': 'Arnaut Danjuma Groeneveld',
#  'Étienne Capoue': 'Etienne Capoue',
#  'Kiko Femenía': 'Francisco Femenía Far',
#  'Ismaila Sarr': 'Ismaila Sarr',
#  'João Pedro': 'João Pedro Junqueira de Jesus',
#  'Max Aarons': 'Max Aarons',
#  'Emi Buendía': 'Emiliano Buendía Stati',
#  'Mario Vrančić': 'Mario Vrancic',
#  'Josip Drmić': 'Josip Drmic',
#  'Ralf Fährmann': 'Ralf Fahrmann',
#  'Danilo': 'Danilo Luiz da Silva',
#  'Petr Čech': 'Petr Cech',
#  'Idrissa Gana Gueye': 'Idrissa Gueye',
#  'Marko Arnautović': 'Marko Arnautovic',
#  'Xande Silva': 'Alexandre Nascimento Costa Silva',
#  'Julián Speroni': 'Julian Speroni',
#  'Kenedy': 'Robert Kenedy Nunes do Nascimento',
#  'Joselu': 'Jose Luis Mato Sanmartín',
#  'Asmir Begović': 'Asmir Begovic',
#  'Kayne Ramsey': 'Kayne Ramsay',
#  'Bruno': 'Bruno Saltor Grau',
#  'Junior Hoilett': 'David Junior Hoilett',
#  'Greg Cunningham': 'Greg Cunninghamm',
#  'Jazz Richards': 'Ashley Darel Jazz Richards',
#  'Jean Seri': 'Jean Michael Seri',
#  'Fabricio': 'Fabricio Agosto Ramírez',
#  'Lazar Marković': 'Lazar Markovic',
#  'Mathias Jørgensen': 'Mathias Jorgensen',
#  'Steve Mounié': 'Steve Mounie',
#  'Jon Gorenc Stanković': 'Jon Gorenc Stankovic',
#  'Matty Daly': 'Matthew Daly',
#  'Yaya Touré': 'Gnegneri Yaya Touré',
#  'Brahim Díaz': 'Brahim Diaz',
#  'Zlatan Ibrahimović': 'Zlatan Ibrahimovic',
#  'Marko Grujić': 'Marko Grujic',
#  'Charly Musonda Jr.': 'Charly Musonda',
#  'Nikola Vlašić': 'Nikola Vlasic',
#  'Aleksandar Dragović': 'Aleksandar Dragovic',
#  'Eldin Jakupović': 'Eldin Jakupovic',
#  'Rob Elliot': 'Robert Elliot',
#  'Jesús Gámez': 'Jesús Gámez Duarte',
#  'Massadio Haïdara': 'Massadio Haidara',
#  'Lee Chung-yong': 'Chung-yong Lee',
#  'Freddie Ladapo': 'Olayinka Fredrick Oladotun Ladapo',
#  'João Mário': 'João Mário Naval Costa Eduardo',
#  'José Fonte': 'Jose Fonte',
#  'Younès Kaboul': 'Younes Kaboul',
#  'Izzy Brown': 'Isaiah Brown',
#  'Dušan Tadić': 'Dusan Tadic',
#  'Àngel Rangel': 'Angel Rangel',
#  'Badou Ndiaye': 'Papa Alioune Ndiaye',
#  'Jesé': 'Jesé Rodríguez Ruiz',
#  'Tom Edwards': 'Thomas Edwards',
#  'Kostas Stafylidis': 'Konstantinos Stafylidis',
#  'Lasse Sørensen': 'Lasse Sorenson',
#  'Bojan Krkić': 'Bojan Krkic',
#  'Allan Nyom': 'Allan-Roméo Nyom',
#  'Ahmed Elmohamady': 'Ahmed El Mohamady',
#  'Hélder Costa': 'Hélder Wander Sousa de Azevedo e Costa',
#  'Mohamed Elneny': 'Mohamed Naser El Sayed Elneny',
#  'Emile Smith-Rowe': 'Emile Smith Rowe',
#  'Ivan Cavaleiro': 'Ivan Ricardo Neves Abreu Cavaleiro',
#  'Bobby Reid': 'Bobby Decordova-Reid',
#  'Ahmed El-Sayed Hegazi': 'Ahmed El-Sayed Hegazy',
#  'Kiko Casilla': 'Francisco Casilla Cortés',
#  'Willian José': 'Willian José Da Silva',
#  'Kostas Tsimikas': 'Konstantinos Tsimikas',
#  'Okay Yokuşlu': 'Okay Yokuslu',
#  'Khanya Leshabela': 'Thakgalo Leshabela',
#  'Jaden Philogene Bidace': 'Jaden Philogene-Bidace',
#  'William Thomas Fish': 'William Fish',
#  'David Raya': 'David Raya Martin',
#  'Oghenekaro Etebo': 'Oghenekaro Peter Etebo',
#  'Ismaïla Sarr': 'Ismaila Sarr',
#  'Cucho': 'Juan Camilo Hernández Suárez',
#  'Enoch Mwepu': 'Enock Mwepu',
#  'Emiliano Buendía': 'Emiliano Buendía StatiJosé Malheiro de Sá',
#  'José Sá': 'José Malheiro de Sá',
#  'Francisco Trincão': 'Francisco Machado Mota de Castro Trincão',
#  'Valentino Livramento': 'Tino Livramento',
#  'Nuno Tavares': 'Nuno Varela Tavares',
#  'Jesuran Rak Sakyi': 'Jesurun Rak-Sakyi',
#  'Maximillian Aarons': 'Max Aarons',
#  'Josh Sargent': 'Joshua Sargent',
#  'Junior Firpo': 'Héctor Junior Firpo Adames'}

# %%
team_list = {}
team_list['Brighton'] = 'Brighton and Hove Albion'
team_list['Leeds United'] = 'Leeds'
team_list['Manchester Utd'] = 'Manchester United'
team_list['Newcastle Utd'] = 'Newcastle United'
team_list['Norwich City'] = 'Norwich'
team_list['Sheffield Utd'] = 'Sheffield United'
team_list['Tottenham'] = 'Tottenham Hotspur'
team_list['West Brom'] = 'West Bromwich Albion'
team_list['West Ham'] = 'West Ham United'
team_list['Wolves'] = 'Wolverhampton Wanderers'

# %%
# replace non-matching names/teams and extract gw as integer
df_enhanced['alt_name'] = df_enhanced['player'].replace(match_list)
df_enhanced['squad'] = df_enhanced['squad'].replace(team_list)
df_enhanced['round'] = df_enhanced['round'].str[-2:].astype('int')

# %%
# remove duplicated (happens when players transferred within season)
df_enhanced = df_enhanced.drop_duplicates()

# %%
df_enhanced
# Out:
#         season           player        date            squad            comp  \
# 0    2021-2022  Vladimír Coufal  2021-08-15  West Ham United  Premier League
# 1    2021-2022  Vladimír Coufal  2021-08-23  West Ham United  Premier League
# 2    2021-2022  Aaron Cresswell  2021-08-15  West Ham United  Premier League
# 3    2021-2022  Aaron Cresswell  2021-08-23  West Ham United  Premier League
# 4    2021-2022     Craig Dawson  2021-08-15  West Ham United  Premier League
# ..         ...              ...         ...              ...             ...
# 550  2021-2022       Bali Mumba  2021-08-21          Norwich  Premier League
# 551  2021-2022     Josh Sargent  2021-08-14          Norwich  Premier League
# 552  2021-2022     Josh Sargent  2021-08-21          Norwich  Premier League
# 553  2021-2022        Adam Idah  2021-08-14          Norwich  Premier League
# 554  2021-2022    Kieran Dowell  2021-08-14          Norwich  Premier League
#
#      round shots_total shots_on_target touches pressures  ...   xa sca gca  \
# 0        1           0               0      67        11  ...  0.6   1   0
# 1        2           0               0      89        11  ...  0.6   5   1
# 2        1           2               1      90         9  ...  0.1   2   0
# 3        2           1               0      81         3  ...  0.0   1   1
# 4        1           1               0      59         8  ...  0.0   1   0
# ..     ...         ...             ...     ...       ...  ...  ...  ..  ..
# 550      2           0               0      19        12  ...  0.0   0   0
# 551      1           1               0      11         6  ...  0.0   0   0
# 552      2           0               0       7         2  ...  0.0   0   0
# 553      1           1               1       6         5  ...  0.0   0   0
# 554      1           0               0       6         0  ...  0.1   2   0
#
#     passes_completed passes passes_pct carries dribbles_completed dribbles  \
# 0                 42     61       68.9      42                  1        1
# 1                 63     83       75.9      51                  0        0
# 2                 67     79       84.8      54                  0        1
# 3                 65     76       85.5      50                  0        0
# 4                 45     48       93.8      37                  0        0
# ..               ...    ...        ...     ...                ...      ...
# 550                7     10       70.0       9                  0        1
# 551                4      4      100.0       4                  0        1
# 552                4      5       80.0       5                  1        1
# 553                3      5       60.0       2                  0        0
# 554                4      5       80.0       5                  0        0
#
#             alt_name
# 0    Vladimir Coufal
# 1    Vladimir Coufal
# 2    Aaron Cresswell
# 3    Aaron Cresswell
# 4       Craig Dawson
# ..               ...
# 550       Bali Mumba
# 551   Joshua Sargent
# 552   Joshua Sargent
# 553        Adam Idah
# 554    Kieran Dowell
#
# [555 rows x 25 columns]

# %%
# create date field in same format as enhanced data
df_latest['date'] = df_latest['kickoff_time'].str[:10]

# %%
# check if any names aren't matching
enhanced_players = df_enhanced[df_enhanced['date'].isin(df_latest['date'].unique())]['alt_name'].unique().tolist()
standard_players = df_latest['player'].unique().tolist()

unmatched_players = [x for x in enhanced_players if x not in standard_players]
unmatched_players
# Out:
# []

# %%
# check if any teams aren't matching
enhanced_teams = df_enhanced[df_enhanced['date'].isin(df_latest['date'].unique())]['squad'].unique().tolist()
standard_teams = df_latest['team'].unique().tolist()

unmatched_teams = [x for x in enhanced_teams if x not in standard_teams]
unmatched_teams
# Out:
# []

# %%
# any additional corrections
# match_list['Imran Louza'] = 'Imrân Louza'
# match_list['Oghenekaro Etebo'] = 'Oghenekaro Peter Etebo'
# match_list['Ismaila Sarr'] = 'Ismaila Sarr'
# match_list['Cucho'] = 'Juan Camilo Hernández Suárez'
# match_list['Enoch Mwepu'] = 'Enock Mwepu'
# match_list['Emi Buendía'] = 'Emiliano Buendía Stati'
# match_list['José Sá'] = 'José Malheiro de Sá'
# match_list['Francisco Trincão'] = 'Francisco Machado Mota de Castro Trincão'
# match_list['Valentino Livramento'] = 'Tino Livramento'
# match_list['Nuno Tavares'] = 'Nuno Varela Tavares'
# match_list['Jesuran Rak Sakyi'] = 'Jesurun Rak-Sakyi'
# match_list['Josh Sargent'] = 'Joshua Sargent'
# match_list['Junior Firpo'] = 'Héctor Junior Firpo Adames'

# %%
# replace additional non-matching names
# df_enhanced['alt_name'] = df_enhanced['player'].replace(match_list)

# %%
# make sure there are no non matches after update
# enhanced_players =  df_enhanced[df_enhanced['round'] == last_gw]['alt_name'].unique().tolist()
# standard_players = df_latest['player'].unique().tolist()

# unmatched_players = [x for x in enhanced_players if x not in standard_players]
# unmatched_players
# Out:
# []

# %%
# if match list was updated then update the file
# json_file = json.dumps(match_list)
# f = open(path/"match_list.json","w")
# f.write(json_file)
# f.close()

# %%
# check there are no duplicates in the join fields for the enhanced data
assert(len(df_enhanced[df_enhanced.duplicated(subset=['alt_name', 'date'], keep=False)]) == 0)

# %%
df_latest[df_latest.duplicated(subset=['date','player','team'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [player, gw, position, minutes, team, opponent_team, relative_market_value_team, relative_market_value_opponent_team, was_home, total_points, assists, bonus, bps, clean_sheets, creativity, goals_conceded, goals_scored, ict_index, influence, own_goals, penalties_missed, penalties_saved, red_cards, saves, selected, team_a_score, team_h_score, threat, transfers_balance, transfers_in, transfers_out, yellow_cards, kickoff_time, season, play_proba, date]
# Index: []
#
# [0 rows x 36 columns]

# %%
# check there are no duplicates in the join fields for the standard data
assert(len(df_train[df_train.duplicated(subset=['date','player','team'])]) == 0)

# %%
# df_train[df_train.duplicated(subset=['date','player','team'])]

# %%
# join standard and enhanced dataframes
df_latest_further = df_latest.merge(df_enhanced.drop(['player', 'season', 'round'], axis=1), 
                                   left_on=['date', 'player', 'team'], 
                                   right_on=['date', 'alt_name', 'squad'], how='left')

# %%
# drop the alt name field and check the length of the standard
# dataframe has not increased
df_latest_further = df_latest_further.drop(['alt_name'], axis=1)
assert(len(df_latest_further) == len(df_latest_further))

# %%
# add crowds field
df_latest_further['crowds'] = 1

# %%
assert(sum(df_latest_further[df_latest_further['minutes'] > 0]['xg'].isnull()) == 0)

# %%
df_train_new = pd.concat([df_train, df_latest_further], ignore_index=True, axis=0, sort=False)

# %%
df_train_new[df_train_new['player'] == 'Harry Kane'].tail()
# Out:
#             player  gw  position  minutes               team  \
# 113008  Harry Kane  36         4       90  Tottenham Hotspur
# 113629  Harry Kane  37         4       90  Tottenham Hotspur
# 114301  Harry Kane  38         4       90  Tottenham Hotspur
# 114999  Harry Kane   1         4        0  Tottenham Hotspur
# 115556  Harry Kane   2         4       18  Tottenham Hotspur
#
#                   opponent_team  relative_market_value_team  \
# 113008  Wolverhampton Wanderers                    1.586460
# 113629              Aston Villa                    1.586543
# 114301           Leicester City                    1.568259
# 114999          Manchester City                    1.560569
# 115556  Wolverhampton Wanderers                    1.558729
#
#         relative_market_value_opponent_team  was_home  total_points  ...   xa  \
# 113008                             0.960312      True             8  ...  0.1
# 113629                             0.884857      True             2  ...  0.2
# 114301                             1.165630     False            10  ...  0.1
# 114999                             2.349720      True             0  ...  NaN
# 115556                             0.858519     False             0  ...  0.1
#
#         sca  gca  passes_completed  passes  passes_pct  carries  \
# 113008    6    1                18      27        66.7       28
# 113629    1    0                11      24        45.8       21
# 114301    3    2                 8      16          50       28
# 114999  NaN  NaN               NaN     NaN         NaN      NaN
# 115556    2    0                 7      10        70.0        7
#
#         dribbles_completed  dribbles  crowds
# 113008                   3         5       0
# 113629                   1         1       1
# 114301                   6         7       1
# 114999                 NaN       NaN       1
# 115556                   0         0       1
#
# [5 rows x 59 columns]

# %%
df_train_new.tail(7)
# Out:
#                             player  gw  position  minutes  \
# 115914  Yerson Mosquera Valdelamar   2         2        0
# 115915                 Yoane Wissa   2         3       13
# 115916             Youri Tielemans   2         3       90
# 115917               Yves Bissouma   2         3       90
# 115918                Zack Steffen   2         1        0
# 115919            Álvaro Fernández   2         1        0
# 115920              Çaglar Söyüncü   2         2       90
#
#                             team      opponent_team  \
# 115914   Wolverhampton Wanderers  Tottenham Hotspur
# 115915                 Brentford     Crystal Palace
# 115916            Leicester City    West Ham United
# 115917  Brighton and Hove Albion            Watford
# 115918           Manchester City            Norwich
# 115919                 Brentford     Crystal Palace
# 115920            Leicester City    West Ham United
#
#         relative_market_value_team  relative_market_value_opponent_team  \
# 115914                    0.858519                             1.558729
# 115915                    0.372523                             0.477029
# 115916                    1.233477                             0.628252
# 115917                    0.538249                             0.322706
# 115918                    2.346950                             0.341636
# 115919                    0.372523                             0.477029
# 115920                    1.233477                             0.628252
#
#         was_home  total_points  ...   xa  sca  gca  passes_completed  passes  \
# 115914      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 115915     False             1  ...  0.0    0    0                 2       3
# 115916     False             7  ...  0.0    2    1                38      48
# 115917      True             8  ...  0.4    3    2                47      55
# 115918      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 115919     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 115920     False             0  ...  0.0    0    0                85      99
#
#         passes_pct  carries  dribbles_completed  dribbles  crowds
# 115914         NaN      NaN                 NaN       NaN       1
# 115915        66.7        4                   1         1       1
# 115916        79.2       48                   0         0       1
# 115917        85.5       44                   2         2       1
# 115918         NaN      NaN                 NaN       NaN       1
# 115919         NaN      NaN                 NaN       NaN       1
# 115920        85.9       80                   0         0       1
#
# [7 rows x 59 columns]

# %%
df_latest_further.shape
# Out:
# (566, 57)

# %%
df_train_new.shape
# Out:
# (115921, 59)

# %%
# save latest training set to csv
# overwrite existing one
df_train_new.to_csv(path/'train_v8.csv')

# %%
# get fixtures
fixtures = pd.read_csv(path/'2021-22/fixtures.csv')
team_dict = teams[['team_2122', 'team']].dropna().set_index('team_2122').to_dict()['team']

fixtures['home_team'] = fixtures['team_h'].replace(team_dict)
fixtures['away_team'] = fixtures['team_a'].replace(team_dict)
fixtures = fixtures[['home_team', 'away_team', 'kickoff_time', 'event']]
fixtures = fixtures.rename(columns={'event':'gw'})


# use these two lines if updating play_proba later in week
# current_gw = last_gw
# df_train_new = pd.read_csv(path/'train_v7.csv', index_col=0, dtype={'season':str,
#                                                                     'comp':str,
#                                                                     'squad':str})

# set starting gameweek (where are we right now in the season)
current_gw = last_gw + 1
fixtures = fixtures[fixtures['gw'] >= current_gw].sort_values(by=['gw'])
fixtures['match_no'] = np.arange(fixtures.shape[0])

# %%
fixtures.head(50)
# Out:
#                    home_team                 away_team          kickoff_time  \
# 20           Manchester City                   Arsenal  2021-08-28T11:30:00Z
# 21               Aston Villa                 Brentford  2021-08-28T14:00:00Z
# 22  Brighton and Hove Albion                   Everton  2021-08-28T14:00:00Z
# 23          Newcastle United               Southampton  2021-08-28T14:00:00Z
# 24                   Norwich            Leicester City  2021-08-28T14:00:00Z
# 25           West Ham United            Crystal Palace  2021-08-28T14:00:00Z
# 26                 Liverpool                   Chelsea  2021-08-28T16:30:00Z
# 27                   Burnley                     Leeds  2021-08-29T13:00:00Z
# 28         Tottenham Hotspur                   Watford  2021-08-29T13:00:00Z
# 29   Wolverhampton Wanderers         Manchester United  2021-08-29T15:30:00Z
# 39                   Everton                   Burnley  2021-09-13T19:00:00Z
# 38                     Leeds                 Liverpool  2021-09-12T15:30:00Z
# 37                   Chelsea               Aston Villa  2021-09-11T16:30:00Z
# 36                   Watford   Wolverhampton Wanderers  2021-09-11T14:00:00Z
# 35               Southampton           West Ham United  2021-09-11T14:00:00Z
# 32                 Brentford  Brighton and Hove Albion  2021-09-11T14:00:00Z
# 33            Leicester City           Manchester City  2021-09-11T14:00:00Z
# 31                   Arsenal                   Norwich  2021-09-11T14:00:00Z
# 30            Crystal Palace         Tottenham Hotspur  2021-09-11T11:30:00Z
# 34         Manchester United          Newcastle United  2021-09-11T14:00:00Z
# 46               Aston Villa                   Everton  2021-09-18T16:30:00Z
# 49         Tottenham Hotspur                   Chelsea  2021-09-19T15:30:00Z
# 48           West Ham United         Manchester United  2021-09-19T13:00:00Z
# 47  Brighton and Hove Albion            Leicester City  2021-09-19T13:00:00Z
# 45                   Norwich                   Watford  2021-09-18T14:00:00Z
# 42                   Burnley                   Arsenal  2021-09-18T14:00:00Z
# 43                 Liverpool            Crystal Palace  2021-09-18T14:00:00Z
# 41   Wolverhampton Wanderers                 Brentford  2021-09-18T11:30:00Z
# 40          Newcastle United                     Leeds  2021-09-17T19:00:00Z
# 44           Manchester City               Southampton  2021-09-18T14:00:00Z
# 59            Crystal Palace  Brighton and Hove Albion  2021-09-27T19:00:00Z
# 58                   Arsenal         Tottenham Hotspur  2021-09-26T15:30:00Z
# 57               Southampton   Wolverhampton Wanderers  2021-09-26T13:00:00Z
# 56                 Brentford                 Liverpool  2021-09-25T16:30:00Z
# 55                   Watford          Newcastle United  2021-09-25T14:00:00Z
# 53            Leicester City                   Burnley  2021-09-25T14:00:00Z
# 52                     Leeds           West Ham United  2021-09-25T14:00:00Z
# 51                   Everton                   Norwich  2021-09-25T14:00:00Z
# 50                   Chelsea           Manchester City  2021-09-25T11:30:00Z
# 54         Manchester United               Aston Villa  2021-09-25T14:00:00Z
# 66  Brighton and Hove Albion                   Arsenal  2021-10-02T16:30:00Z
# 69                 Liverpool           Manchester City  2021-10-03T15:30:00Z
# 68           West Ham United                 Brentford  2021-10-03T13:00:00Z
# 67            Crystal Palace            Leicester City  2021-10-03T13:00:00Z
# 65   Wolverhampton Wanderers          Newcastle United  2021-10-02T14:00:00Z
# 61                   Burnley                   Norwich  2021-10-02T14:00:00Z
# 63                     Leeds                   Watford  2021-10-02T14:00:00Z
# 60         Manchester United                   Everton  2021-10-02T11:30:00Z
# 64         Tottenham Hotspur               Aston Villa  2021-10-02T14:00:00Z
# 62                   Chelsea               Southampton  2021-10-02T14:00:00Z
#
#     gw  match_no
# 20   3         0
# 21   3         1
# 22   3         2
# 23   3         3
# 24   3         4
# 25   3         5
# 26   3         6
# 27   3         7
# 28   3         8
# 29   3         9
# 39   4        10
# 38   4        11
# 37   4        12
# 36   4        13
# 35   4        14
# 32   4        15
# 33   4        16
# 31   4        17
# 30   4        18
# 34   4        19
# 46   5        20
# 49   5        21
# 48   5        22
# 47   5        23
# 45   5        24
# 42   5        25
# 43   5        26
# 41   5        27
# 40   5        28
# 44   5        29
# 59   6        30
# 58   6        31
# 57   6        32
# 56   6        33
# 55   6        34
# 53   6        35
# 52   6        36
# 51   6        37
# 50   6        38
# 54   6        39
# 66   7        40
# 69   7        41
# 68   7        42
# 67   7        43
# 65   7        44
# 61   7        45
# 63   7        46
# 60   7        47
# 64   7        48
# 62   7        49

# %%
# add universal team codes for home and away teams
fixtures = fixtures.merge(teams, left_on='home_team', right_on='team', how='left')
fixtures = fixtures.merge(teams, left_on='away_team', right_on='team', how='left')
fixtures = fixtures[['gw', 'match_no', 'home_team', 'away_team', 'kickoff_time', 'team_code_x', 'team_code_y']]
fixtures.rename(index=str,
                columns={'team_code_x':'home_team_code',
                         'team_code_y':'away_team_code'},
                inplace=True)

# %%
fixtures.head()
# Out:
#    gw  match_no                 home_team       away_team  \
# 0   3         0           Manchester City         Arsenal
# 1   3         1               Aston Villa       Brentford
# 2   3         2  Brighton and Hove Albion         Everton
# 3   3         3          Newcastle United     Southampton
# 4   3         4                   Norwich  Leicester City
#
#            kickoff_time  home_team_code  away_team_code
# 0  2021-08-28T11:30:00Z              43               3
# 1  2021-08-28T14:00:00Z               7              94
# 2  2021-08-28T14:00:00Z              36              11
# 3  2021-08-28T14:00:00Z               4              20
# 4  2021-08-28T14:00:00Z              45              13

# %%
# all_players.replace(to_replace='None', value=1, inplace=True)

# %%
all_players[all_players['play_proba_2122'] == '0']
# Out:
#                          full_name play_proba_2122  position_2122  id_2122  \
# 14                   Thomas Partey               0              3       15
# 17                  Lucas Torreira               0              3       18
# 18                  Edward Nketiah               0              4       20
# 22         Konstantinos Mavropanos               0              2       24
# 23                Mattéo Guendouzi               0              3       25
# ..                             ...             ...            ...      ...
# 539  Rui Pedro dos Santos Patrício               0              1      427
# 545           Jonathan Castro Otto               0              2      433
# 553               Pedro Lomba Neto               0              3      441
# 554                  Owen Otasowie               0              3      442
# 563                Patrick Cutrone               0              4      523
#
#      cost_2122  team_2122 web_name_2122
# 14          50          3        Partey
# 17          45          3      Torreira
# 18          55          3       Nketiah
# 22          45          3    Mavropanos
# 23          45          3     Guendouzi
# ..         ...        ...           ...
# 539         50         39      Patrício
# 545         45         39         Jonny
# 553         65         39          Neto
# 554         45         39      Otasowie
# 563         50         39       Cutrone
#
# [94 rows x 7 columns]

# %%
# join home team to all players for current season
home_df = fixtures.merge(all_players, 
               left_on='home_team_code', 
               right_on='team_2122', 
               how='left')

# pull out the required fields and rename columns
home_df = home_df[['gw', 'match_no', 'home_team', 'away_team', 'kickoff_time', 
                   'full_name', 'position_2122', 'cost_2122', 'play_proba_2122', 
                   'web_name_2122']]
home_df.rename(index=str, 
               columns={'home_team':'team',
                        'away_team':'opponent_team',
                        'full_name':'player',
                        'position_2122':'position',
                        'cost_2122':'price',
                        'play_proba_2122':'play_proba',
                        'web_name_2122':'short_name'},
              inplace=True)

# add home flag
home_df['was_home'] = True

# %%
# join away team to all players for current season
away_df = fixtures.merge(all_players, 
               left_on='away_team_code', 
               right_on='team_2122', 
               how='left')

# pull out the required fields and rename columns
away_df = away_df[['gw',  'match_no', 'away_team', 'home_team', 'kickoff_time', 
                   'full_name', 'position_2122', 'cost_2122', 'play_proba_2122', 
                   'web_name_2122']]
away_df.rename(index=str, 
               columns={'away_team':'team',
                        'home_team':'opponent_team',
                        'full_name':'player',
                        'position_2122':'position',
                        'cost_2122':'price',
                        'play_proba_2122':'play_proba',
                        'web_name_2122':'short_name'},
              inplace=True)

# add home flag
away_df['was_home'] = False

# %%
# look at away players
away_df.head()
# Out:
#    gw  match_no     team    opponent_team          kickoff_time  \
# 0   3         0  Arsenal  Manchester City  2021-08-28T11:30:00Z
# 1   3         0  Arsenal  Manchester City  2021-08-28T11:30:00Z
# 2   3         0  Arsenal  Manchester City  2021-08-28T11:30:00Z
# 3   3         0  Arsenal  Manchester City  2021-08-28T11:30:00Z
# 4   3         0  Arsenal  Manchester City  2021-08-28T11:30:00Z
#
#                       player  position  price play_proba  short_name  was_home
# 0                 Bernd Leno         1     49       None        Leno     False
# 1       Rúnar Alex Rúnarsson         1     40        100   Rúnarsson     False
# 2    Willian Borges Da Silva         3     63         50     Willian     False
# 3  Pierre-Emerick Aubameyang         4     99        100  Aubameyang     False
# 4              Cédric Soares         2     45       None      Cédric     False

# %%
# look at home players
home_df.head()
# Out:
#    gw  match_no             team opponent_team          kickoff_time  \
# 0   3         0  Manchester City       Arsenal  2021-08-28T11:30:00Z
# 1   3         0  Manchester City       Arsenal  2021-08-28T11:30:00Z
# 2   3         0  Manchester City       Arsenal  2021-08-28T11:30:00Z
# 3   3         0  Manchester City       Arsenal  2021-08-28T11:30:00Z
# 4   3         0  Manchester City       Arsenal  2021-08-28T11:30:00Z
#
#             player  position  price play_proba short_name  was_home
# 0    Jack Grealish         3     80       None   Grealish      True
# 1      Kyle Walker         2     55       None     Walker      True
# 2   Ilkay Gündogan         3     74        100   Gündogan      True
# 3  Kevin De Bruyne         3    120          0  De Bruyne      True
# 4      John Stones         2     54       None     Stones      True

# %%
# # calculate average minutes over last 5 gameweeks
# # first get last 5 gameweeks in current season
# recent_mins = df_train_new[(df_train_new['gw'] >= current_gw - 5) & 
#                            (df_train_new['season'] == season_names[0])][['player', 'minutes', 'play_proba']]

# # recent_mins = df_train_new[((df_train_new['gw'] >= 40 - 5) & 
# #                            (df_train_new['season'] == '1920')) | 
# #                            ((df_train_new['gw'] >= 1) & 
# #                            (df_train_new['season'] == '2021'))][['player', 'minutes', 'play_proba']]

# # exclude weeks where the player had an injury designation (i.e. keep where play_proba is 1)
# recent_mins = recent_mins[recent_mins['play_proba'] == 1]

# len(recent_mins)

# # average for each player
# recent_mins = recent_mins.groupby(['player'])['minutes'].mean().to_dict()

# recent_mins

# %%
# concatenate home and away players
remaining_season_df = home_df.append(away_df).reset_index(drop=True)

# add home and away team market values
remaining_season_df = remaining_season_df.merge(teams_mv[teams_mv['season'] == '2122'],
                                                left_on='team', 
                                                right_on='name', 
                                                how='left').drop(['name', 'season'], axis=1)

remaining_season_df = remaining_season_df.merge(teams_mv[teams_mv['season'] == '2122'],
                                                left_on='opponent_team', 
                                                right_on='name', 
                                                how='left').drop(['name', 'season'], axis=1)

remaining_season_df.rename(index=str, 
                           columns={'relative_market_value_x':'relative_market_value_team',
                                    'relative_market_value_y':'relative_market_value_opponent_team'},
                           inplace=True)

# add season name
remaining_season_df['season'] = season_names[0]

# divide cost by 10 for actual cost
remaining_season_df['price'] = remaining_season_df['price']/10

# set availability probability
# 0 = 0% chance, 25 = 25% chance, etc
# 'None' or '100' = 100% chance
remaining_season_df.loc[remaining_season_df['play_proba'] == 'None', 'play_proba'] = 100
remaining_season_df['play_proba'] = remaining_season_df['play_proba'].astype('float') / 100

# cast position to integer
remaining_season_df['position'] = remaining_season_df['position'].astype(int)

# # add minutes based on last five fixtures
# remaining_season_df['minutes'] = remaining_season_df['player'].map(recent_mins)
# remaining_season_df['minutes'].fillna(0, inplace=True)

# # multiply minutes by play probability
# remaining_season_df['minutes'] = remaining_season_df['minutes'] * remaining_season_df['play_proba']

# %%
remaining_season_df.head(50)
# Out:
#     gw  match_no             team opponent_team          kickoff_time  \
# 0    3         0  Manchester City       Arsenal  2021-08-28T11:30:00Z
# 1    3         0  Manchester City       Arsenal  2021-08-28T11:30:00Z
# 2    3         0  Manchester City       Arsenal  2021-08-28T11:30:00Z
# 3    3         0  Manchester City       Arsenal  2021-08-28T11:30:00Z
# 4    3         0  Manchester City       Arsenal  2021-08-28T11:30:00Z
# 5    3         0  Manchester City       Arsenal  2021-08-28T11:30:00Z
# 6    3         0  Manchester City       Arsenal  2021-08-28T11:30:00Z
# 7    3         0  Manchester City       Arsenal  2021-08-28T11:30:00Z
# 8    3         0  Manchester City       Arsenal  2021-08-28T11:30:00Z
# 9    3         0  Manchester City       Arsenal  2021-08-28T11:30:00Z
# 10   3         0  Manchester City       Arsenal  2021-08-28T11:30:00Z
# 11   3         0  Manchester City       Arsenal  2021-08-28T11:30:00Z
# 12   3         0  Manchester City       Arsenal  2021-08-28T11:30:00Z
# 13   3         0  Manchester City       Arsenal  2021-08-28T11:30:00Z
# 14   3         0  Manchester City       Arsenal  2021-08-28T11:30:00Z
# 15   3         0  Manchester City       Arsenal  2021-08-28T11:30:00Z
# 16   3         0  Manchester City       Arsenal  2021-08-28T11:30:00Z
# 17   3         0  Manchester City       Arsenal  2021-08-28T11:30:00Z
# 18   3         0  Manchester City       Arsenal  2021-08-28T11:30:00Z
# 19   3         0  Manchester City       Arsenal  2021-08-28T11:30:00Z
# 20   3         0  Manchester City       Arsenal  2021-08-28T11:30:00Z
# 21   3         0  Manchester City       Arsenal  2021-08-28T11:30:00Z
# 22   3         0  Manchester City       Arsenal  2021-08-28T11:30:00Z
#
# 3      De Bruyne      True                    2.346950
# 4         Stones      True                    2.346950
# 5          Mendy      True                    2.346950
# 6         Mahrez      True                    2.346950
# 7       Sterling      True                    2.346950
# 8        Cancelo      True                    2.346950
# 9        Ederson      True                    2.346950
# 10           Aké      True                    2.346950
# 11       Laporte      True                    2.346950
# 12       Steffen      True                    2.346950
# 13      Bernardo      True                    2.346950
# 14          Dias      True                    2.346950
# 15         Jesus      True                    2.346950
# 16     Zinchenko      True                    2.346950
# 17         Foden      True                    2.346950
# 18       Rodrigo      True                    2.346950
# 19        Torres      True                    2.346950
# 20   Fernandinho      True                    2.346950
# 21        Palmer      True                    2.346950
# 22        Edozie      True                    2.346950
# 23         Doyle      True                    2.346950
# 24         Steer      True                    0.950515
# 25     Hourihane      True                    0.950515
# 26      Martínez      True                    0.950515
# 27        Engels      True                    0.950515
# 28        Traoré      True                    0.950515
# 29        Sanson      True                    0.950515
# 30        McGinn      True                    0.950515
# 31         Hause      True                    0.950515
# 32     Trézéguet      True                    0.950515
# 33         Mings      True                    0.950515
# 34       Targett      True                    0.950515
# 35       Watkins      True                    0.950515
# 36       Nakamba      True                    0.950515
# 37      El Ghazi      True                    0.950515
# 38       Buendía      True                    0.950515
# 39          Cash      True                    0.950515
# 40         Konsa      True                    0.950515
# 41      Guilbert      True                    0.950515
# 42        Wesley      True                    0.950515
# 43       Samatta      True                    0.950515
# 44         Davis      True                    0.950515
# 45  Douglas Luiz      True                    0.950515
# 46        Ramsey      True                    0.950515
# 47         Young      True                    0.950515
# 48      Tuanzebe      True                    0.950515
# 49          Ings      True                    0.950515
#
#     relative_market_value_opponent_team season
# 0                              1.268682   2122
# 1                              1.268682   2122
# 2                              1.268682   2122
# 3                              1.268682   2122
# 4                              1.268682   2122
# 5                              1.268682   2122
# 6                              1.268682   2122
# 7                              1.268682   2122
# 8                              1.268682   2122
# 9                              1.268682   2122
# 10                             1.268682   2122
# 11                             1.268682   2122
# 12                             1.268682   2122
# 13                             1.268682   2122
# 14                             1.268682   2122
# 15                             1.268682   2122
# 16                             1.268682   2122
# 17                             1.268682   2122
# 18                             1.268682   2122
# 19                             1.268682   2122
# 20                             1.268682   2122
# 21                             1.268682   2122
# 22                             1.268682   2122
# 23                             1.268682   2122
# 24                             0.372523   2122
# 25                             0.372523   2122
# 26                             0.372523   2122
# 27                             0.372523   2122
# 28                             0.372523   2122
# 29                             0.372523   2122
# 30                             0.372523   2122
# 31                             0.372523   2122
# 32                             0.372523   2122
# 33                             0.372523   2122
# 34                             0.372523   2122
# 35                             0.372523   2122
# 36                             0.372523   2122
# 37                             0.372523   2122
# 38                             0.372523   2122
# 39                             0.372523   2122
# 40                             0.372523   2122
# 41                             0.372523   2122
# 42                             0.372523   2122
# 43                             0.372523   2122
# 44                             0.372523   2122
# 45                             0.372523   2122
# 46                             0.372523   2122
# 47                             0.372523   2122
# 48                             0.372523   2122
# 49                             0.372523   2122

# %%
# save latest prediction set to csv
remaining_season_df.to_csv(path/'remaining_season.csv')
