# %%
# import required libriaries
from pathlib import Path
import json

from fpl_predictor.util import *

# %%
# path to data directory
#path = Path('/home/jupyter/fpl-prediction/data')
path = Path('./fpl_predictor/data')

# %%
# read in latest training set
df_train = pd.read_csv(path/'train_v8.csv', index_col=0, 
                       dtype={'season':str,
                              'comp':str,
                              'squad':str})

# path to current season
season_paths = [path/'2021-22']

# name for current season
season_names = ['2122']

# team codes
teams = pd.read_csv(path/'teams.csv')

# latest remaining season dataset, for latest week's play_proba values
remaining_season = pd.read_csv(path/'remaining_season.csv', index_col=0)

# create players dataset
all_players = build_players(path, season_paths, season_names, teams)

# 2019-20 market value
# table was in slightly different position for 2019-20 season
# should check that 2019-20 season values remain the same once season starts
teams_mv = build_season_mv('2122', 11, range(13,33))

# %%
# all_players#[all_players['full_name'] == 'Ben Davies']

# %%
# df_train = df_train.iloc[:-686]

# %%
# find the latest gameweek
last_gw = df_train['gw'][df_train['season'] == season_names[0]].max()

if np.isnan(last_gw): 
    last_gw = 1 
else: 
    last_gw = last_gw + 1
    
last_gw
# Out:
# 24

# %%
# build training set for latest gameweek
df_latest = build_season(season_paths[0], season_names[0], all_players, teams, teams_mv, [last_gw])

# %%
df_latest.drop_duplicates(inplace=True)

# %%
# df_latest[df_latest['player'] == 'Chris Wood']
# lucas digne
# chris wood

# %%
last_play_proba = remaining_season[remaining_season['gw'] == last_gw][['player', 'team', 'play_proba']]

# %%
last_play_proba.head()
# Out:
#            player              team  play_proba
# 0  Joseph Willock  Newcastle United        1.00
# 1    Matt Targett  Newcastle United        1.00
# 2        Dan Burn  Newcastle United        0.75
# 3      Chris Wood  Newcastle United        1.00
# 4   Jonjo Shelvey  Newcastle United        1.00

# %%
# add latest week's play_proba for each player
df_latest = df_latest.merge(last_play_proba, on=['player', 'team'], how='left')

# %%
df_latest.drop_duplicates(inplace=True)

# %%
df_train.drop_duplicates(inplace=True)

# %%
if last_gw==1:
    df_latest['relative_market_value_team_season'] = df_latest['relative_market_value_team']
    df_latest['relative_market_value_opponent_team_season'] = df_latest['relative_market_value_opponent_team']

# %%
# for when you're doing the season value properly
# relative_market_value_season = train_df[train_df['season'] == '2021'][['team', 'relative_market_value_team']].groupby(['team']).first()
# relative_market_value_season = relative_market_value_season.rename(columns={'relative_market_value_team': 'season_value'})
# relative_market_value_season

# %%
# now get futher stats from fbref
# standard stats
features = ['squad', 'comp', 'round', 'shots_total', 'shots_on_target', 'touches', 'pressures',
            'tackles', 'interceptions', 'blocks', 'xg', 'npxg', 'xa', 'sca', 
            'gca', 'passes_completed', 'passes', 'passes_pct',  'carries', 
            'dribbles_completed', 'dribbles']

# %%
# url for the premier league
url_base = 'https://fbref.com'
pl_history_page = '/en/comps/9/history/Premier-League-Seasons'
url = url_base + pl_history_page

# scrape the history table to get latest season
pl_history_table = get_table(url)
pl_history_urls = get_urls(['season'], 'season', pl_history_table, url_base)
season_urls = pl_history_urls[0:1]

df_enhanced = get_stats(features, season_urls, url_base)
# Out:
# 2021-2022
# https://fbref.com/en/comps/9/Premier-League-Stats
# Manchester City
# https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats
# Ederson
# João Cancelo
# Bernardo Silva
# Rúben Dias
# Rodri
# Aymeric Laporte
# Gabriel Jesus
# Jack Grealish
# Raheem Sterling
# Kyle Walker
# Backing off 1.0 seconds afters 1 tries calling function <function get_table at 0x000002263B98E8B8> with args ('https://fbref.com/en/players/86dd77d1/matchlogs/2021-2022/summary/Kyle-Walker-Match-Logs',) and kwargs {}
# Backing off 1.6 seconds afters 2 tries calling function <function get_table at 0x000002263B98E8B8> with args ('https://fbref.com/en/players/86dd77d1/matchlogs/2021-2022/summary/Kyle-Walker-Match-Logs',) and kwargs {}
# Backing off 2.3 seconds afters 3 tries calling function <function get_table at 0x000002263B98E8B8> with args ('https://fbref.com/en/players/86dd77d1/matchlogs/2021-2022/summary/Kyle-Walker-Match-Logs',) and kwargs {}
# Kevin De Bruyne
# Phil Foden
# İlkay Gündoğan
# Riyad Mahrez
# John Stones
# Nathan Aké
# Fernandinho
# Oleksandr Zinchenko
# Ferrán Torres
# Cole Palmer
# Zack Steffen
# Benjamin Mendy
# James Mcatee
# Liverpool
# https://fbref.com/en/squads/822bd0ba/Liverpool-Stats
# Alisson
# Virgil van Dijk
# Trent Alexander-Arnold
# Mohamed Salah
# Sadio Mané
# Diogo Jota
# Joël Matip
# Jordan Henderson
# Andrew Robertson
# Fabinho
# Thiago Alcántara
# Alex Oxlade-Chamberlain
# Roberto Firmino
# Ibrahima Konaté
# James Milner
# Kostas Tsimikas
# Curtis Jones
# Naby Keïta
# Harvey Elliott
# Caoimhín Kelleher
# Luis Díaz
# Tyler Morton
# Takumi Minamino
# Divock Origi
# Joe Gomez
# Kaide Gordon
# Neco Williams
# Chelsea
# https://fbref.com/en/squads/cff3d9bb/Chelsea-Stats
# Antonio Rüdiger
# Edouard Mendy
# Thiago Silva
# Jorginho
# Mason Mount
# Marcos Alonso
# César Azpilicueta
# Reece James
# Mateo Kovačić
# Kai Havertz
# Romelu Lukaku
# Andreas Christensen
# Callum Hudson-Odoi
# N'Golo Kanté
# Trevoh Chalobah
# Hakim Ziyech
# Christian Pulisic
# Ruben Loftus-Cheek
# Timo Werner
# Ben Chilwell
# Kepa Arrizabalaga
# Malang Sarr
# Saúl Ñíguez
# Ross Barkley
# Emerson Palmieri
# West Ham
# https://fbref.com/en/squads/7c21e445/West-Ham-United-Stats
# Łukasz Fabiański
# Declan Rice
# Jarrod Bowen
# Michail Antonio
# Tomáš Souček
# Pablo Fornals
# Saïd Benrahma
# Vladimír Coufal
# Craig Dawson
# Aaron Cresswell
# Kurt Zouma
# Angelo Ogbonna
# Ben Johnson
# Manuel Lanzini
# Issa Diop
# Arthur Masuaku
# Nikola Vlašić
# Mark Noble
# Alphonse Areola
# Andriy Yarmolenko
# Ryan Fredericks
# Harrison Ashby
# Sonny Perkins
# Alex Král
# Arsenal
# https://fbref.com/en/squads/18bb7c10/Arsenal-Stats
# Ben White
# Bukayo Saka
# Aaron Ramsdale
# Gabriel Dos Santos
# Thomas Partey
# Takehiro Tomiyasu
# Kieran Tierney
# Martin Ødegaard
# Emile Smith Rowe
# Pierre-Emerick Aubameyang
# Alexandre Lacazette
# Martinelli
# Granit Xhaka
# Albert Sambi Lokonga
# Nuno Tavares
# Nicolas Pépé
# Rob Holding
# Cédric Soares
# Bernd Leno
# Ainsley Maitland-Niles
# Pablo Marí
# Calum Chambers
# Mohamed Elneny
# Sead Kolašinac
# Folarin Balogun
# Eddie Nketiah
# Reiss Nelson
# Manchester Utd
# https://fbref.com/en/squads/19538871/Manchester-United-Stats
# David de Gea
# Bruno Fernandes
# Harry Maguire
# Scott McTominay
# Fred
# Cristiano Ronaldo
# Mason Greenwood
# Aaron Wan-Bissaka
# Luke Shaw
# Victor Lindelöf
# Raphaël Varane
# Jadon Sancho
# Diogo Dalot
# Nemanja Matić
# Alex Telles
# Marcus Rashford
# Paul Pogba
# Edinson Cavani
# Anthony Elanga
# Eric Bailly
# Anthony Martial
# Daniel James
# Phil Jones
# Jesse Lingard
# Donny van de Beek
# Tottenham
# https://fbref.com/en/squads/361ca564/Tottenham-Hotspur-Stats
# Hugo Lloris
# Pierre Højbjerg
# Harry Kane
# Eric Dier
# Son Heung-min
# Sergio Reguilón
# Lucas Moura
# Emerson
# Oliver Skipp
# Davinson Sánchez
# Ben Davies
# Japhet Tanganga
# Dele Alli
# Cristian Romero
# Harry Winks
# Tanguy Ndombele
# Steven Bergwijn
# Giovani Lo Celso
# Ryan Sessegnon
# Matt Doherty
# Bryan
# Joe Rodon
# Rodrigo Bentancur
# Dejan Kulusevski
# Wolves
# https://fbref.com/en/squads/8cec06e1/Wolverhampton-Wanderers-Stats
# José Sá
# Max Kilman
# Conor Coady
# João Moutinho
# Nélson Semedo
# Romain Saïss
# Raúl Jiménez
# Rúben Neves
# Francisco Trincão
# Fernando Marçal
# Hwang Hee-chan
# Adama Traoré
# Leander Dendoncker
# Rayan Aït Nouri
# Daniel Podence
# Ki-Jana Hoever
# Toti Gomes
# Fábio Silva
# Chiquinho
# Morgan Gibbs-White
# Luke Cundle
# Brighton
# https://fbref.com/en/squads/d07537b9/Brighton-and-Hove-Albion-Stats
# Robert Sánchez
# Leandro Trossard
# Marc Cucurella
# Neal Maupay
# Joël Veltman
# Adam Lallana
# Jakub Moder
# Lewis Dunk
# Yves Bissouma
# Pascal Groß
# Shane Duffy
# Dan Burn
# Adam Webster
# Solly March
# Alexis Mac Allister
# Tariq Lamptey
# Enock Mwepu
# Danny Welbeck
# Steven Alzate
# Aaron Connolly
# Jason Steele
# Jeremy Sarmiento
# Taylor Richards
# Jürgen Locadia
# Southampton
# https://fbref.com/en/squads/33c895d4/Southampton-Stats
# Mohammed Salisu
# James Ward-Prowse
# Oriol Romeu
# Valentino Livramento
# Jan Bednarek
# Alex McCarthy
# Kyle Walker-Peters
# Nathan Redmond
# Adam Armstrong
# Che Adams
# Armando Broja
# Mohamed Elyounoussi
# Romain Perraud
# Ibrahima Diallo
# Nathan Tella
# Fraser Forster
# Jack Stephens
# Lyanco
# Moussa Djenepo
# Theo Walcott
# Stuart Armstrong
# Willy Caballero
# Shane Long
# Yan Valery
# William Smallbone
# Aston Villa
# https://fbref.com/en/squads/8602292d/Aston-Villa-Stats
# Matty Cash
# Emiliano Martínez
# Ezri Konsa
# Tyrone Mings
# John McGinn
# Ollie Watkins
# Douglas Luiz
# Matt Targett
# Jacob Ramsey
# Emi Buendía
# Danny Ings
# Marvelous Nakamba
# Ashley Young
# Axel Tuanzebe
# Leon Bailey
# Kortney Hause
# Anwar El Ghazi
# Lucas Digne
# Morgan Sanson
# Philippe Coutinho
# Carney Chukwuemeka
# Bertrand Traoré
# Jed Steer
# Cameron Archer
# Keinan Davis
# Trézéguet
# Jaden Philogene Bidace
# Calum Chambers
# Wesley Moraes
# Leicester City
# https://fbref.com/en/squads/a2d435b3/Leicester-City-Stats
# Kasper Schmeichel
# Çağlar Söyüncü
# James Maddison
# Youri Tielemans
# Jamie Vardy
# Wilfred Ndidi
# Harvey Barnes
# Luke Thomas
# Timothy Castagne
# Boubakary Soumaré
# Daniel Amartey
# Ademola Lookman
# Jonny Evans
# Ricardo Pereira
# Kiernan Dewsbury Hall
# Marc Albrighton
# Kelechi Iheanacho
# Jannik Vestergaard
# Patson Daka
# Ryan Bertrand
# Hamza Choudhury
# Ayoze Pérez
# James Justin
# Kasey McAteer
# Crystal Palace
# https://fbref.com/en/squads/47c64c55/Crystal-Palace-Stats
# Tyrick Mitchell
# Marc Guéhi
# Joel Ward
# Vicente Guaita
# Conor Gallagher
# Joachim Andersen
# Wilfried Zaha
# Jordan Ayew
# Cheikhou Kouyaté
# Odsonne Édouard
# Christian Benteke
# James McArthur
# Jeffrey Schlupp
# Will Hughes
# Luka Milivojević
# James Tomkins
# Michael Olise
# Jean-Philippe Mateta
# Jack Butland
# Eberechi Eze
# Jaïro Riedewald
# Nathaniel Clyne
# Jesuran Rak Sakyi
# Nathan Ferguson
# Brentford
# https://fbref.com/en/squads/cd051869/Brentford-Stats
# Pontus Jansson
# Christian Nørgaard
# Ethan Pinnock
# Ivan Toney
# Sergi Canós
# Bryan Mbeumo
# Rico Henry
# Vitaly Janelt
# Álvaro Fernández
# Frank Onyeka
# Mathias Jensen
# Kristoffer Ajer
# David Raya
# Mads Roerslev
# Shandon Baptiste
# Mathias Jørgensen
# Charlie Goode
# Mads Bech Sørensen
# Yoane Wissa
# Saman Ghoddos
# Jonas Lössl
# Dominic Thompson
# Marcus Forss
# Mads Bidstrup
# Josh Dasilva
# Finley Stevens
# Leeds United
# https://fbref.com/en/squads/5bfb9659/Leeds-United-Stats
# Illan Meslier
# Stuart Dallas
# Raphael Dias Belloli
# Jack Harrison
# Diego Llorente
# Daniel James
# Liam Cooper
# Mateusz Klich
# Luke Ayling
# Rodrigo
# Pascal Struijk
# Kalvin Phillips
# Junior Firpo
# Adam Forshaw
# Tyler Roberts
# Jamie Shackleton
# Robin Koch
# Patrick Bamford
# Joe Gelhardt
# Cody Drameh
# Charlie Cresswell
# Crysencio Summerville
# Leo Fuhr Hjelde
# Lewis Bate
# Hélder Costa
# Sam Greenwood
# Liam McCarron
# Stuart McKinstry
# Everton
# https://fbref.com/en/squads/d3fd31cc/Everton-Stats
# Michael Keane
# Jordan Pickford
# Demarai Gray
# Allan
# Ben Godfrey
# Andros Townsend
# Abdoulaye Doucouré
# Séamus Coleman
# Lucas Digne
# Richarlison
# Anthony Gordon
# Mason Holgate
# Salomón Rondón
# Yerry Mina
# Alex Iwobi
# Dominic Calvert-Lewin
# André Gomes
# Jonjoe Kenny
# Fabian Delph
# Tom Davies
# Jarrad Branthwaite
# Asmir Begović
# Vitaliy Mykolenko
# Jean-Philippe Gbamin
# Ellis Simms
# Dele Alli
# Lewis Dobbin
# Donny van de Beek
# Tyler Onyango
# Cenk Tosun
# Moise Kean
# Newcastle Utd
# https://fbref.com/en/squads/b2b47a98/Newcastle-United-Stats
# Allan Saint-Maximin
# Jamaal Lascelles
# Joelinton
# Joe Willock
# Matt Ritchie
# Callum Wilson
# Jonjo Shelvey
# Javier Manquillo
# Fabian Schär
# Ciaran Clark
# Isaac Hayden
# Miguel Almirón
# Sean Longstaff
# Martin Dúbravka
# Ryan Fraser
# Karl Darlow
# Jacob Murphy
# Emil Krafth
# Federico Fernández
# Freddie Woodman
# Jamal Lewis
# Chris Wood
# Kieran Trippier
# Paul Dummett
# Matt Targett
# Jeff Hendrick
# Dwight Gayle
# Bruno Guimarães
# Norwich City
# https://fbref.com/en/squads/1c781004/Norwich-City-Stats
# Max Aarons
# Teemu Pukki
# Kenny McLean
# Tim Krul
# Ben Gibson
# Grant Hanley
# Brandon Williams
# Pierre Lees-Melou
# Milot Rashica
# Billy Gilmour
# Josh Sargent
# Ozan Kabak
# Mathias Normann
# Dimitris Giannoulis
# Adam Idah
# Przemysław Płacheta
# Lukas Rupp
# Todd Cantwell
# Andrew Omobamidele
# Jakob Sørensen
# Angus Gunn
# Kieran Dowell
# Christos Tzolis
# Sam Byram
# Jon Rowe
# Bali Mumba
# Watford
# https://fbref.com/en/squads/2abfe087/Watford-Stats
# Moussa Sissoko
# Craig Cathcart
# Joshua King
# Emmanuel Dennis
# Juraj Kucka
# William Troost-Ekong
# Kiko Femenía
# Ismaila Sarr
# Daniel Bachmann
# Ben Foster
# Tom Cleverley
# Adam Masina
# Danny Rose
# João Pedro
# Cucho
# Imran Louza
# Jeremy Ngakia
# Francisco Sierralta
# Ken Sema
# Oghenekaro Etebo
# Samir Santos
# Hassane Kamara
# Ozan Tufan
# Edo Kayembe
# Christian Kabasele
# Nicolas Nkoulou
# Ashley Fletcher
# Troy Deeney
# Dan Gosling
# Burnley
# https://fbref.com/en/squads/943e8050/Burnley-Stats
# Dwight McNeil
# James Tarkowski
# Nick Pope
# Ashley Westwood
# Matthew Lowton
# Chris Wood
# Ben Mee
# Charlie Taylor
# Josh Brownhill
# Jóhann Berg Guðmundsson
# Maxwel Cornet
# Jack Cork
# Nathan Collins
# Aaron Lennon
# Jay Rodriguez
# Ashley Barnes
# Erik Pieters
# Matěj Vydra
# Connor Roberts
# Wayne Hennessey
# Wout Weghorst
# Dale Stephens

# %%
# get the player name matching dictionary
with open(path/'match_list.json') as f:
  match_list = json.load(f)

match_list
# Out:
# {'Fabinho': 'Fabio Henrique Tavares',
#  'Alisson': 'Alisson Ramses Becker',
#  'Joël Matip': 'Joel Matip',
#  'Joe Gomez': 'Joseph Gomez',
#  'Naby Keïta': 'Naby Keita',
#  'Adrián': 'Adrián San Miguel del Castillo',
#  'Thiago Alcántara': 'Thiago Alcántara do Nascimento',
#  'Allan': 'Allan Marques Loureiro',
#  'Richarlison': 'Richarlison de Andrade',
#  'Gylfi Sigurðsson': 'Gylfi Sigurdsson',
#  'Séamus Coleman': 'Seamus Coleman',
#  'André Gomes': 'André Filipe Tavares Gomes',
#  'Bernard': 'Bernard Anício Caldeira Duarte',
#  'Çağlar Söyüncü': 'Çaglar Söyüncü',
#  'Bruno Fernandes': 'Bruno Miguel Borges Fernandes',
#  'Fred': 'Frederico Rodrigues de Paula Santos',
#  'Nemanja Matić': 'Nemanja Matic',
#  'Alex Telles': 'Alex Nicolao Telles',
#  'Pierre Højbjerg': 'Pierre-Emile Højbjerg',
#  'Son Heung-min': 'Heung-Min Son',
#  'Lucas Moura': 'Lucas Rodrigues Moura da Silva',
#  'Érik Lamela': 'Erik Lamela',
#  'Dele Alli': 'Bamidele Alli',
#  'Carlos Vinícius': 'Carlos Vinicius Alves Morais',
#  'Ederson': 'Ederson Santana de Moraes',
#  'Rodri': 'Rodrigo Hernandez',
#  'Rúben Dias': 'Rúben Santos Gato Alves Dias',
#  'João Cancelo': 'João Pedro Cavaco Cancelo',
#  'İlkay Gündoğan': 'Ilkay Gündogan',
#  'Gabriel Jesus': 'Gabriel Fernando de Jesus',
#  'Ferrán Torres': 'Ferran Torres',
#  'Bernardo Silva': 'Bernardo Mota Veiga de Carvalho e Silva',
#  'Fernandinho': 'Fernando Luiz Rosa',
#  'Eric García': 'Eric Garcia',
#  'Matty Cash': 'Matthew Cash',
#  'Douglas Luiz': 'Douglas Luiz Soares de Paulo',
#  'Ezri Konsa': 'Ezri Konsa Ngoyo',
#  'Trézéguet': 'Mahmoud Ahmed Ibrahim Hassan',
#  'Ben Chilwell': 'Benjamin Chilwell',
#  'Thiago Silva': 'Thiago Emiliano da Silva',
#  'Mateo Kovačić': 'Mateo Kovacic',
#  'Jorginho': 'Jorge Luiz Frello Filho',
#  'Emerson Palmieri': 'Emerson Palmieri dos Santos',
#  'Oriol Romeu': 'Oriol Romeu Vidal',
#  'Dan Nlundulu': "Daniel N'Lundulu",
#  'Łukasz Fabiański': 'Lukasz Fabianski',
#  'Tomáš Souček': 'Tomas Soucek',
#  'Vladimír Coufal': 'Vladimir Coufal',
#  'Felipe Anderson': 'Felipe Anderson Pereira Gomes',
#  'Rui Patrício': 'Rui Pedro dos Santos Patrício',
#  'Pedro Neto': 'Pedro Lomba Neto',
#  'Daniel Podence': 'Daniel Castelo Podence',
#  'Nélson Semedo': 'Nélson Cabral Semedo',
#  'Rúben Neves': 'Rúben Diogo da Silva Neves',
#  'João Moutinho': 'João Filipe Iria Santos Moutinho',
#  'Rayan Aït Nouri': 'Rayan Ait Nouri',
#  'Fábio Silva': 'Fabio Silva',
#  'Rúben Vinagre': 'Rúben Gonçalo Silva Nascimento Vinagre',
#  'Vitinha': 'Vitor Ferreira',
#  'Rodrigo': 'Rodrigo Moreno',
#  'Pablo Hernández': 'Pablo Hernández Domínguez',
#  'Ian Carlo Poveda': 'Ian Carlo Poveda-Ocampo',
#  'Joelinton': 'Joelinton Cássio Apolinário de Lira',
#  'Luka Milivojević': 'Luka Milivojevic',
#  'Jaïro Riedewald': 'Jairo Riedewald',
#  'Gabriel Dos Santos': 'Gabriel Magalhães',
#  'Willian': 'Willian Borges Da Silva',
#  'Dani Ceballos': 'Daniel Ceballos Fernández',
#  'David Luiz': 'David Luiz Moreira Marinho',
#  'Eddie Nketiah': 'Edward Nketiah',
#  'Joe Willock': 'Joseph Willock',
#  'Sead Kolašinac': 'Sead Kolasinac',
#  'Martinelli': 'Gabriel Teodoro Martinelli Silva',
#  'Solly March': 'Solomon March',
#  'Bernardo': 'Bernardo Fernandes da Silva Junior',
#  'Jóhann Berg Guðmundsson': 'Johann Berg Gudmundsson',
#  'Matěj Vydra': 'Matej Vydra',
#  'Andre-Frank Zambo Anguissa': 'André-Frank Zambo Anguissa',
#  'Semi Ajayi': 'Oluwasemilogo Adesewo Ibidapo Ajayi',
#  'Branislav Ivanović': 'Branislav Ivanovic',
#  'Filip Krovinović': 'Filip Krovinovic',
#  'Ahmed Hegazi': 'Ahmed El-Sayed Hegazi',
#  'Harvey Elliot': 'Harvey Elliott',
#  'Angeliño': 'Angelo Ogbonna',
#  'Thomas Doyle': 'Tommy Doyle',
#  'Diogo Dalot': 'José Diogo Dalot Teixeira',
#  'Pedro': 'Pedro Rodríguez Ledesma',
#  'Ricardo Pereira': 'Ricardo Domingos Barbosa Pereira',
#  'Gedson Fernandes': 'Gedson Carvalho Fernandes',
#  "Georges-Kévin N'Koudou": 'Georges-Kévin Nkoudou',
#  'Jonny Castro': 'Jonathan Castro Otto',
#  'Jesús Vallejo': 'Jesús Vallejo Lázaro',
#  'Bruno Jordão': 'Bruno André Cavaco Jordao',
#  'Mattéo Guendouzi': 'Matteo Guendouzi',
#  'Richairo Živković': 'Richairo Zivkovic',
#  'Danny Drinkwater': 'Daniel Drinkwater',
#  'Martin Dúbravka': 'Martin Dubravka',
#  'Yoshinori Mutō': 'Yoshinori Muto',
#  'Ki Sung-yueng': 'Sung-yueng Ki',
#  'Roberto': 'Roberto Jimenez Gago',
#  'Javier Hernández': 'Javier Hernández Balcázar',
#  'Frederic Guilbert': 'Frédéric Guilbert',
#  'Björn Engels': 'Bjorn Engels',
#  'Pepe Reina': 'José Reina',
#  'Jota': 'José Ignacio Peleteiro Romallo',
#  'Arnaut Groeneveld': 'Arnaut Danjuma Groeneveld',
#  'Étienne Capoue': 'Etienne Capoue',
#  'Kiko Femenía': 'Francisco Femenía Far',
#  'Ismaila Sarr': 'Ismaila Sarr',
#  'João Pedro': 'João Pedro Junqueira de Jesus',
#  'Max Aarons': 'Max Aarons',
#  'Emi Buendía': 'Emiliano Buendía Stati',
#  'Mario Vrančić': 'Mario Vrancic',
#  'Josip Drmić': 'Josip Drmic',
#  'Ralf Fährmann': 'Ralf Fahrmann',
#  'Danilo': 'Danilo Luiz da Silva',
#  'Petr Čech': 'Petr Cech',
#  'Idrissa Gana Gueye': 'Idrissa Gueye',
#  'Marko Arnautović': 'Marko Arnautovic',
#  'Xande Silva': 'Alexandre Nascimento Costa Silva',
#  'Julián Speroni': 'Julian Speroni',
#  'Kenedy': 'Robert Kenedy Nunes do Nascimento',
#  'Joselu': 'Jose Luis Mato Sanmartín',
#  'Asmir Begović': 'Asmir Begović',
#  'Kayne Ramsey': 'Kayne Ramsay',
#  'Bruno': 'Bruno Saltor Grau',
#  'Junior Hoilett': 'David Junior Hoilett',
#  'Greg Cunningham': 'Greg Cunninghamm',
#  'Jazz Richards': 'Ashley Darel Jazz Richards',
#  'Jean Seri': 'Jean Michael Seri',
#  'Fabricio': 'Fabricio Agosto Ramírez',
#  'Lazar Marković': 'Lazar Markovic',
#  'Mathias Jørgensen': 'Mathias Jorgensen',
#  'Steve Mounié': 'Steve Mounie',
#  'Jon Gorenc Stanković': 'Jon Gorenc Stankovic',
#  'Matty Daly': 'Matthew Daly',
#  'Yaya Touré': 'Gnegneri Yaya Touré',
#  'Brahim Díaz': 'Brahim Diaz',
#  'Zlatan Ibrahimović': 'Zlatan Ibrahimovic',
#  'Marko Grujić': 'Marko Grujic',
#  'Charly Musonda Jr.': 'Charly Musonda',
#  'Nikola Vlašić': 'Nikola Vlasic',
#  'Aleksandar Dragović': 'Aleksandar Dragovic',
#  'Eldin Jakupović': 'Eldin Jakupovic',
#  'Rob Elliot': 'Robert Elliot',
#  'Jesús Gámez': 'Jesús Gámez Duarte',
#  'Massadio Haïdara': 'Massadio Haidara',
#  'Lee Chung-yong': 'Chung-yong Lee',
#  'Freddie Ladapo': 'Olayinka Fredrick Oladotun Ladapo',
#  'João Mário': 'João Mário Naval Costa Eduardo',
#  'José Fonte': 'Jose Fonte',
#  'Younès Kaboul': 'Younes Kaboul',
#  'Izzy Brown': 'Isaiah Brown',
#  'Dušan Tadić': 'Dusan Tadic',
#  'Àngel Rangel': 'Angel Rangel',
#  'Badou Ndiaye': 'Papa Alioune Ndiaye',
#  'Jesé': 'Jesé Rodríguez Ruiz',
#  'Tom Edwards': 'Thomas Edwards',
#  'Kostas Stafylidis': 'Konstantinos Stafylidis',
#  'Lasse Sørensen': 'Lasse Sorenson',
#  'Bojan Krkić': 'Bojan Krkic',
#  'Allan Nyom': 'Allan-Roméo Nyom',
#  'Ahmed Elmohamady': 'Ahmed El Mohamady',
#  'Hélder Costa': 'Hélder Wander Sousa de Azevedo e Costa',
#  'Mohamed Elneny': 'Mohamed Naser El Sayed Elneny',
#  'Emile Smith-Rowe': 'Emile Smith Rowe',
#  'Ivan Cavaleiro': 'Ivan Ricardo Neves Abreu Cavaleiro',
#  'Bobby Reid': 'Bobby Decordova-Reid',
#  'Ahmed El-Sayed Hegazi': 'Ahmed El-Sayed Hegazy',
#  'Kiko Casilla': 'Francisco Casilla Cortés',
#  'Willian José': 'Willian José Da Silva',
#  'Kostas Tsimikas': 'Konstantinos Tsimikas',
#  'Okay Yokuşlu': 'Okay Yokuslu',
#  'Khanya Leshabela': 'Thakgalo Leshabela',
#  'Jaden Philogene Bidace': 'Jaden Philogene-Bidace',
#  'William Thomas Fish': 'William Fish',
#  'David Raya': 'David Raya Martin',
#  'Oghenekaro Etebo': 'Oghenekaro Peter Etebo',
#  'Ismaïla Sarr': 'Ismaila Sarr',
#  'Cucho': 'Juan Camilo Hernández Suárez',
#  'Enoch Mwepu': 'Enock Mwepu',
#  'Emiliano Buendía': 'Emiliano Buendía StatiJosé Malheiro de Sá',
#  'José Sá': 'José Malheiro de Sá',
#  'Francisco Trincão': 'Francisco Machado Mota de Castro Trincão',
#  'Valentino Livramento': 'Tino Livramento',
#  'Nuno Tavares': 'Nuno Varela Tavares',
#  'Jesuran Rak Sakyi': 'Jesurun Rak-Sakyi',
#  'Maximillian Aarons': 'Max Aarons',
#  'Josh Sargent': 'Joshua Sargent',
#  'Junior Firpo': 'Héctor Junior Firpo Adames',
#  'Imran Louza': 'Imrân Louza',
#  'Bryan': 'Bryan Gil Salvatierra',
#  'Kiernan Dewsbury Hall': 'Kiernan Dewsbury-Hall',
#  'Cristiano Ronaldo': 'Cristiano Ronaldo dos Santos Aveiro',
#  'Emerson': 'Emerson Aparecido Leite de Souza Junior',
#  'Mads Roerslev': 'Mads Roerslev Rasmussen',
#  'Odsonne Édouard': 'Odsonne Edouard',
#  'Hwang Hee-chan': 'Hee-Chan Hwang',
#  'Asmir Begovic': 'Asmir Begović',
#  'Caoimhín Kelleher': 'Caoimhin Kelleher',
#  'Lyanco': 'Lyanco Evangelista Silveira Neves Vojnovic',
#  'Przemysław Płacheta': 'Przemyslaw Placheta',
#  'James Mcatee': 'James McAtee',
#  'Jakob Sørensen': 'Jacob Sørensen',
#  'Alex Král': 'Alex Kral',
#  'Jon Rowe': 'Jonathan Rowe',
#  'Toti Gomes': 'Toti António Gomes',
#  'Philippe Coutinho': 'Philippe Coutinho Correia',
#  'Vitaliy Mykolenko': 'Vitalii Mykolenko',
#  'Samir Santos': 'Samir Caetano de Souza Santos'}

# %%
team_list = {}
team_list['Brighton'] = 'Brighton and Hove Albion'
team_list['Leeds United'] = 'Leeds'
team_list['Manchester Utd'] = 'Manchester United'
team_list['Newcastle Utd'] = 'Newcastle United'
team_list['Norwich City'] = 'Norwich'
team_list['Sheffield Utd'] = 'Sheffield United'
team_list['Tottenham'] = 'Tottenham Hotspur'
team_list['West Brom'] = 'West Bromwich Albion'
team_list['West Ham'] = 'West Ham United'
team_list['Wolves'] = 'Wolverhampton Wanderers'

# %%
df_enhanced = df_enhanced.loc[df_enhanced[df_enhanced['round'].str[-2:] != 'on'].index]

# %%
# replace non-matching names/teams and extract gw as integer
df_enhanced['alt_name'] = df_enhanced['player'].replace(match_list)
df_enhanced['squad'] = df_enhanced['squad'].replace(team_list)
df_enhanced['round'] = df_enhanced['round'].str[-2:].astype('int')

# %%
# remove duplicated (happens when players transferred within season)
df_enhanced = df_enhanced.drop_duplicates()

# %%
df_enhanced
# Out:
#          season           player        date            squad            comp  \
# 0     2021-2022     João Cancelo  2021-08-15  Manchester City  Premier League
# 1     2021-2022     João Cancelo  2021-08-21  Manchester City  Premier League
# 2     2021-2022     João Cancelo  2021-08-28  Manchester City  Premier League
# 3     2021-2022     João Cancelo  2021-09-11  Manchester City  Premier League
# 4     2021-2022     João Cancelo  2021-09-18  Manchester City  Premier League
# ...         ...              ...         ...              ...             ...
# 6269  2021-2022  Wayne Hennessey  2022-01-02          Burnley  Premier League
# 6270  2021-2022    Wout Weghorst  2022-02-05          Burnley  Premier League
# 6271  2021-2022    Wout Weghorst  2022-02-08          Burnley  Premier League
# 6272  2021-2022    Dale Stephens  2021-12-30          Burnley  Premier League
# 6273  2021-2022    Dale Stephens  2022-02-05          Burnley  Premier League
#
#       round shots_total shots_on_target touches pressures  ...   xa sca gca  \
# 0         1           3               0      87         4  ...  0.6   4   0
# 1         2           1               0      90        11  ...  0.0   1   0
# 2         3           1               1     118        11  ...  0.0   3   1
# 3         4           2               0      80        11  ...  0.1   2   1
# 4         5           2               0      95        10  ...  0.0   1   0
# ...     ...         ...             ...     ...       ...  ...  ...  ..  ..
# 6269     21           0               0      51         1  ...  0.0   0   0
# 6270     17           2               0      41        36  ...  0.0   2   0
# 6271     24           3               1      45        26  ...  0.4   2   2
# 6272     20           0               0      20         9  ...  0.0   0   0
# 6273     17           1               0      55        33  ...  0.0   2   0
#
#      passes_completed passes passes_pct carries dribbles_completed dribbles  \
# 0                  61     72       84.7      64                  3        5
# 1                  70     82       85.4      65                  1        1
# 2                  96    112       85.7      94                  2        2
# 3                  58     70       82.9      57                  2        2
# 4                  66     81       81.5      70                  1        2
# ...               ...    ...        ...     ...                ...      ...
# 6269               22     48       45.8      15                  0        0
# 6270               15     26       57.7      17                  1        3
# 6271               22     28       78.6      28                  3        3
# 6272               12     16       75.0       9                  0        0
# 6273               32     42       76.2      25                  0        0
#
#                        alt_name
# 0     João Pedro Cavaco Cancelo
# 1     João Pedro Cavaco Cancelo
# 2     João Pedro Cavaco Cancelo
# 3     João Pedro Cavaco Cancelo
# 4     João Pedro Cavaco Cancelo
# ...                         ...
# 6269            Wayne Hennessey
# 6270              Wout Weghorst
# 6271              Wout Weghorst
# 6272              Dale Stephens
# 6273              Dale Stephens
#
# [6162 rows x 25 columns]

# %%
# create date field in same format as enhanced data
df_latest['date'] = df_latest['kickoff_time'].str[:10]

# %%
# check if any names aren't matching
enhanced_players = df_enhanced[df_enhanced['date'].isin(df_latest['date'].unique())]['alt_name'].unique().tolist()
standard_players = df_latest['player'].unique().tolist()

unmatched_players = [x for x in enhanced_players if x not in standard_players]
unmatched_players
# Out:
# []

# %%
# check if any teams aren't matching
enhanced_teams = df_enhanced[df_enhanced['date'].isin(df_latest['date'].unique())]['squad'].unique().tolist()
standard_teams = df_latest['team'].unique().tolist()

unmatched_teams = [x for x in enhanced_teams if x not in standard_teams]
unmatched_teams
# Out:
# []

# %%
# any additional corrections
# match_list['Chiquinho'] = 'Francisco Jorge Tomás Oliveira'
# match_list['Josh Dasilva'] = 'Pelenda Joshua Dasilva'
# match_list['Bruno Guimarães'] = 'Bruno Guimarães Rodriguez Moura'
# match_list['Samir Santos'] = 'Samir Caetano de Souza Santos'
# match_list['Hwang Hee-chan'] = 'Hee-Chan Hwang'

# %%
# replace additional non-matching names
# df_enhanced['alt_name'] = df_enhanced['player'].replace(match_list)

# %%
# make sure there are no non matches after update
# enhanced_players =  df_enhanced[df_enhanced['round'] == last_gw]['alt_name'].unique().tolist()
# standard_players = df_latest['player'].unique().tolist()

# unmatched_players = [x for x in enhanced_players if x not in standard_players]
# unmatched_players

# %%
# if match list was updated then update the file
# json_file = json.dumps(match_list)
# f = open(path/"match_list.json","w")
# f.write(json_file)
# f.close()

# %%
# check there are no duplicates in the join fields for the enhanced data
assert(len(df_enhanced[df_enhanced.duplicated(subset=['alt_name', 'date'], keep=False)]) == 0)

# %%
df_latest[df_latest.duplicated(subset=['date','player','team'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [player, gw, position, minutes, team, opponent_team, relative_market_value_team, relative_market_value_opponent_team, was_home, total_points, assists, bonus, bps, clean_sheets, creativity, goals_conceded, goals_scored, ict_index, influence, own_goals, penalties_missed, penalties_saved, red_cards, saves, selected, team_a_score, team_h_score, threat, transfers_balance, transfers_in, transfers_out, yellow_cards, kickoff_time, season, play_proba, date]
# Index: []
#
# [0 rows x 36 columns]

# %%
# check there are no duplicates in the join fields for the standard data
assert(len(df_train[df_train.duplicated(subset=['date','player','team'])]) == 0)

# %%
# df_train[df_train.duplicated(subset=['date','player','team'])]

# %%
# join standard and enhanced dataframes
df_latest_further = df_latest.merge(df_enhanced.drop(['player', 'season', 'round'], axis=1), 
                                   left_on=['date', 'player', 'team'], 
                                   right_on=['date', 'alt_name', 'squad'], how='left')

# %%
# drop the alt name field and check the length of the standard
# dataframe has not increased
df_latest_further = df_latest_further.drop(['alt_name'], axis=1)
assert(len(df_latest_further) == len(df_latest_further))

# %%
# add crowds field
df_latest_further['crowds'] = 1

# %%
assert(sum(df_latest_further[df_latest_further['minutes'] > 0]['xg'].isnull()) == 0)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26372/2444589764.py in <module>
# ----> 1 assert(sum(df_latest_further[df_latest_further['minutes'] > 0]['xg'].isnull()) == 0)
#
# AssertionError:

# %%
df_latest_further[df_latest_further['minutes'] > 0][df_latest_further[df_latest_further['minutes'] > 0]['xg'].isnull()]
# Out:
#                         player  gw  position  minutes             team  \
# 165  Ederson Santana de Moraes  24         1       90  Manchester City
#
#     opponent_team  relative_market_value_team  \
# 165     Brentford                         NaN
#
#      relative_market_value_opponent_team  was_home  total_points  ...   xa  \
# 165                                  NaN      True             6  ...  NaN
#
#      sca  gca  passes_completed  passes  passes_pct  carries  \
# 165  NaN  NaN               NaN     NaN         NaN      NaN
#
#      dribbles_completed  dribbles  crowds
# 165                 NaN       NaN       1
#
# [1 rows x 57 columns]

# %%
df_enhanced
# Out:
#          season           player        date            squad            comp  \
# 0     2021-2022     João Cancelo  2021-08-15  Manchester City  Premier League
# 1     2021-2022     João Cancelo  2021-08-21  Manchester City  Premier League
# 2     2021-2022     João Cancelo  2021-08-28  Manchester City  Premier League
# 3     2021-2022     João Cancelo  2021-09-11  Manchester City  Premier League
# 4     2021-2022     João Cancelo  2021-09-18  Manchester City  Premier League
# ...         ...              ...         ...              ...             ...
# 6269  2021-2022  Wayne Hennessey  2022-01-02          Burnley  Premier League
# 6270  2021-2022    Wout Weghorst  2022-02-05          Burnley  Premier League
# 6271  2021-2022    Wout Weghorst  2022-02-08          Burnley  Premier League
# 6272  2021-2022    Dale Stephens  2021-12-30          Burnley  Premier League
# 6273  2021-2022    Dale Stephens  2022-02-05          Burnley  Premier League
#
#       round shots_total shots_on_target touches pressures  ...   xa sca gca  \
# 0         1           3               0      87         4  ...  0.6   4   0
# 1         2           1               0      90        11  ...  0.0   1   0
# 2         3           1               1     118        11  ...  0.0   3   1
# 3         4           2               0      80        11  ...  0.1   2   1
# 4         5           2               0      95        10  ...  0.0   1   0
# ...     ...         ...             ...     ...       ...  ...  ...  ..  ..
# 6269     21           0               0      51         1  ...  0.0   0   0
# 6270     17           2               0      41        36  ...  0.0   2   0
# 6271     24           3               1      45        26  ...  0.4   2   2
# 6272     20           0               0      20         9  ...  0.0   0   0
# 6273     17           1               0      55        33  ...  0.0   2   0
#
#      passes_completed passes passes_pct carries dribbles_completed dribbles  \
# 0                  61     72       84.7      64                  3        5
# 1                  70     82       85.4      65                  1        1
# 2                  96    112       85.7      94                  2        2
# 3                  58     70       82.9      57                  2        2
# 4                  66     81       81.5      70                  1        2
# ...               ...    ...        ...     ...                ...      ...
# 6269               22     48       45.8      15                  0        0
# 6270               15     26       57.7      17                  1        3
# 6271               22     28       78.6      28                  3        3
# 6272               12     16       75.0       9                  0        0
# 6273               32     42       76.2      25                  0        0
#
#                        alt_name
# 0     João Pedro Cavaco Cancelo
# 1     João Pedro Cavaco Cancelo
# 2     João Pedro Cavaco Cancelo
# 3     João Pedro Cavaco Cancelo
# 4     João Pedro Cavaco Cancelo
# ...                         ...
# 6269            Wayne Hennessey
# 6270              Wout Weghorst
# 6271              Wout Weghorst
# 6272              Dale Stephens
# 6273              Dale Stephens
#
# [6162 rows x 25 columns]

# %%
df_train_new = pd.concat([df_train, df_latest_further], ignore_index=True, axis=0, sort=False)

# %%
df_train_new[df_train_new['player'] == 'Harry Kane'].tail()
# Out:
#             player  gw  position  minutes               team   opponent_team  \
# 125801  Harry Kane  20         4       90  Tottenham Hotspur     Southampton
# 126346  Harry Kane  21         4       90  Tottenham Hotspur         Watford
# 127048  Harry Kane  22         4       90  Tottenham Hotspur  Leicester City
# 127815  Harry Kane  23         4       90  Tottenham Hotspur         Chelsea
# 128541  Harry Kane  24         4       90  Tottenham Hotspur     Southampton
#
#         relative_market_value_team  relative_market_value_opponent_team  \
# 125801                    1.463462                             0.563202
# 126346                    1.467118                             0.338504
# 127048                    1.466032                             1.169548
# 127815                         NaN                                  NaN
# 128541                         NaN                                  NaN
#
#         was_home  total_points  ...   xa   sca  gca  passes_completed  passes  \
# 125801     False             6  ...  0.1   3.0  0.0              17.0    24.0
# 126346     False             2  ...  0.0   3.0  0.0              24.0    33.0
# 127048     False            11  ...  0.4  11.0  2.0              25.0    36.0
# 127815     False             2  ...  0.2   2.0  0.0              13.0    21.0
# 128541      True             2  ...  0.5     4    1                18      30
#
#         passes_pct  carries  dribbles_completed  dribbles  crowds
# 125801        70.8     34.0                 2.0       2.0       1
# 126346        72.7     38.0                 0.0       1.0       1
# 127048        69.4     49.0                 4.0       4.0       1
# 127815        61.9     25.0                 2.0       2.0       1
# 128541        60.0       20                   2         2       1
#
# [5 rows x 59 columns]

# %%
df_train_new.tail(10)
# Out:
#                             player  gw  position  minutes  \
# 128949             Xherdan Shaqiri  24         3        0
# 128950                  Yan Valery  24         2        0
# 128951                  Yerry Mina  24         2       34
# 128952  Yerson Mosquera Valdelamar  24         2        0
# 128953                 Yoane Wissa  24         3       20
# 128954             Youri Tielemans  24         3       30
# 128955                    Zach Awe  24         2        0
# 128956                Zack Steffen  24         1        0
# 128957            Álvaro Fernández  24         1        0
# 128958              Çaglar Söyüncü  24         2        0
#
#                            team            opponent_team  \
# 128949                Liverpool           Leicester City
# 128950              Southampton        Tottenham Hotspur
# 128951                  Everton         Newcastle United
# 128952  Wolverhampton Wanderers                  Arsenal
# 128953                Brentford          Manchester City
# 128954           Leicester City                Liverpool
# 128955                  Arsenal  Wolverhampton Wanderers
# 128956          Manchester City                Brentford
# 128957                Brentford          Manchester City
# 128958           Leicester City                Liverpool
#
#         relative_market_value_team  relative_market_value_opponent_team  \
# 128949                         NaN                                  NaN
# 128950                         NaN                                  NaN
# 128951                         NaN                                  NaN
# 128952                         NaN                                  NaN
# 128953                         NaN                                  NaN
# 128954                         NaN                                  NaN
# 128955                         NaN                                  NaN
# 128956                         NaN                                  NaN
# 128957                         NaN                                  NaN
# 128958                         NaN                                  NaN
#
#         was_home  total_points  ...   xa  sca  gca  passes_completed  passes  \
# 128949      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 128950     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 128951     False             1  ...  0.0    0    0                20      24
# 128952      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 128953     False             1  ...  0.0    0    0                 1       2
# 128954     False             1  ...  0.0    0    0                11      16
# 128955     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 128956      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 128957     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 128958     False             0  ...  NaN  NaN  NaN               NaN     NaN
#
#         passes_pct  carries  dribbles_completed  dribbles  crowds
# 128949         NaN      NaN                 NaN       NaN       1
# 128950         NaN      NaN                 NaN       NaN       1
# 128951        83.3       17                   0         0       1
# 128952         NaN      NaN                 NaN       NaN       1
# 128953        50.0        1                   0         0       1
# 128954        68.8        9                   0         0       1
# 128955         NaN      NaN                 NaN       NaN       1
# 128956         NaN      NaN                 NaN       NaN       1
# 128957         NaN      NaN                 NaN       NaN       1
# 128958         NaN      NaN                 NaN       NaN       1
#
# [10 rows x 59 columns]

# %%
df_latest_further.shape
# Out:
# (635, 57)

# %%
df_train_new.shape
# Out:
# (128959, 59)

# %%
# save latest training set to csv
# overwrite existing one
df_train_new.to_csv(path/'train_v8.csv')

# %%
# get fixtures
fixtures = pd.read_csv(path/'2021-22/fixtures.csv')
team_dict = teams[['team_2122', 'team']].dropna().set_index('team_2122').to_dict()['team']

fixtures['home_team'] = fixtures['team_h'].replace(team_dict)
fixtures['away_team'] = fixtures['team_a'].replace(team_dict)
fixtures = fixtures[['home_team', 'away_team', 'kickoff_time', 'event']]
fixtures = fixtures.rename(columns={'event':'gw'})


# use these two lines if updating play_proba later in week
# current_gw = last_gw
# df_train_new = pd.read_csv(path/'train_v7.csv', index_col=0, dtype={'season':str,
#                                                                     'comp':str,
#                                                                     'squad':str})

# set starting gameweek (where are we right now in the season)
current_gw = last_gw + 1
fixtures = fixtures[fixtures['gw'] >= current_gw].sort_values(by=['gw'])
fixtures['match_no'] = np.arange(fixtures.shape[0])

# %%
fixtures.head(50)
# Out:
#                     home_team                 away_team          kickoff_time  \
# 237         Manchester United               Southampton  2022-02-12T12:30:00Z
# 238                 Brentford            Crystal Palace  2022-02-12T15:00:00Z
# 239                   Everton                     Leeds  2022-02-12T15:00:00Z
# 240                   Watford  Brighton and Hove Albion  2022-02-12T15:00:00Z
# 241                   Norwich           Manchester City  2022-02-12T17:30:00Z
# 242                   Burnley                 Liverpool  2022-02-13T14:00:00Z
# 243          Newcastle United               Aston Villa  2022-02-13T14:00:00Z
# 244         Tottenham Hotspur   Wolverhampton Wanderers  2022-02-13T14:00:00Z
# 245            Leicester City           West Ham United  2022-02-13T16:30:00Z
# 246         Manchester United  Brighton and Hove Albion  2022-02-15T20:15:00Z
# 260                   Arsenal   Wolverhampton Wanderers  2022-02-24T19:45:00Z
# 259                 Liverpool                     Leeds  2022-02-23T19:45:00Z
# 258                   Watford            Crystal Palace  2022-02-23T19:30:00Z
# 257                   Burnley         Tottenham Hotspur  2022-02-23T19:30:00Z
# 256   Wolverhampton Wanderers            Leicester City  2022-02-20T16:30:00Z
# 254           Manchester City         Tottenham Hotspur  2022-02-19T17:30:00Z
# 255                     Leeds         Manchester United  2022-02-20T14:00:00Z
# 252                 Liverpool                   Norwich  2022-02-19T15:00:00Z
# 251            Crystal Palace                   Chelsea  2022-02-19T15:00:00Z
# 250  Brighton and Hove Albion                   Burnley  2022-02-19T15:00:00Z
# 249               Aston Villa                   Watford  2022-02-19T15:00:00Z
# 248                   Arsenal                 Brentford  2022-02-19T15:00:00Z
# 247           West Ham United          Newcastle United  2022-02-19T12:30:00Z
# 253               Southampton                   Everton  2022-02-19T15:00:00Z
# 269                   Burnley            Leicester City  2022-03-01T19:45:00Z
# 268           West Ham United   Wolverhampton Wanderers  2022-02-27T14:00:00Z
# 267                   Everton           Manchester City  2022-02-26T17:30:00Z
# 266         Manchester United                   Watford  2022-02-26T15:00:00Z
# 264  Brighton and Hove Albion               Aston Villa  2022-02-26T15:00:00Z
# 263                 Brentford          Newcastle United  2022-02-26T15:00:00Z
# 262                     Leeds         Tottenham Hotspur  2022-02-26T12:30:00Z
# 261               Southampton                   Norwich  2022-02-25T20:00:00Z
# 265            Crystal Palace                   Burnley  2022-02-26T15:00:00Z
# 276                 Liverpool           West Ham United  2022-03-05T17:30:00Z
# 279         Tottenham Hotspur                   Everton  2022-03-07T20:00:00Z
# 278           Manchester City         Manchester United  2022-03-06T16:30:00Z
# 277                   Watford                   Arsenal  2022-03-06T14:00:00Z
# 275   Wolverhampton Wanderers            Crystal Palace  2022-03-05T15:00:00Z
# 270            Leicester City                     Leeds  2022-03-05T12:30:00Z
# 273          Newcastle United  Brighton and Hove Albion  2022-03-05T15:00:00Z
# 272                   Burnley                   Chelsea  2022-03-05T15:00:00Z
# 271               Aston Villa               Southampton  2022-03-05T15:00:00Z
# 274                   Norwich                 Brentford  2022-03-05T15:00:00Z
# 288                   Arsenal            Leicester City  2022-03-13T16:30:00Z
# 287           West Ham United               Aston Villa  2022-03-13T14:00:00Z
# 286                   Chelsea          Newcastle United  2022-03-13T14:00:00Z
# 285         Manchester United         Tottenham Hotspur  2022-03-12T17:30:00Z
# 289            Crystal Palace           Manchester City  2022-03-14T20:00:00Z
# 283                     Leeds                   Norwich  2022-03-12T15:00:00Z
# 282                   Everton   Wolverhampton Wanderers  2022-03-12T15:00:00Z
#
#        gw  match_no
# 237  25.0         0
# 238  25.0         1
# 239  25.0         2
# 240  25.0         3
# 241  25.0         4
# 242  25.0         5
# 243  25.0         6
# 244  25.0         7
# 245  25.0         8
# 246  25.0         9
# 260  26.0        10
# 259  26.0        11
# 258  26.0        12
# 257  26.0        13
# 256  26.0        14
# 254  26.0        15
# 255  26.0        16
# 252  26.0        17
# 251  26.0        18
# 250  26.0        19
# 249  26.0        20
# 248  26.0        21
# 247  26.0        22
# 253  26.0        23
# 269  27.0        24
# 268  27.0        25
# 267  27.0        26
# 266  27.0        27
# 264  27.0        28
# 263  27.0        29
# 262  27.0        30
# 261  27.0        31
# 265  27.0        32
# 276  28.0        33
# 279  28.0        34
# 278  28.0        35
# 277  28.0        36
# 275  28.0        37
# 270  28.0        38
# 273  28.0        39
# 272  28.0        40
# 271  28.0        41
# 274  28.0        42
# 288  29.0        43
# 287  29.0        44
# 286  29.0        45
# 285  29.0        46
# 289  29.0        47
# 283  29.0        48
# 282  29.0        49

# %%
# add universal team codes for home and away teams
fixtures = fixtures.merge(teams, left_on='home_team', right_on='team', how='left')
fixtures = fixtures.merge(teams, left_on='away_team', right_on='team', how='left')
fixtures = fixtures[['gw', 'match_no', 'home_team', 'away_team', 'kickoff_time', 'team_code_x', 'team_code_y']]
fixtures.rename(index=str,
                columns={'team_code_x':'home_team_code',
                         'team_code_y':'away_team_code'},
                inplace=True)

# %%
fixtures.head()
# Out:
#      gw  match_no          home_team                 away_team  \
# 0  25.0         0  Manchester United               Southampton
# 1  25.0         1          Brentford            Crystal Palace
# 2  25.0         2            Everton                     Leeds
# 3  25.0         3            Watford  Brighton and Hove Albion
# 4  25.0         4            Norwich           Manchester City
#
#            kickoff_time  home_team_code  away_team_code
# 0  2022-02-12T12:30:00Z               1              20
# 1  2022-02-12T15:00:00Z              94              31
# 2  2022-02-12T15:00:00Z              11               2
# 3  2022-02-12T15:00:00Z              57              36
# 4  2022-02-12T17:30:00Z              45              43

# %%
# all_players.replace(to_replace='None', value=1, inplace=True)

# %%
all_players[all_players['play_proba_2122'] == '0']
# Out:
#                      full_name play_proba_2122  position_2122  id_2122  \
# 1         Rúnar Alex Rúnarsson               0              1        2
# 2      Willian Borges Da Silva               0              3        3
# 3    Pierre-Emerick Aubameyang               0              4        4
# 7                   Pablo Marí               0              2        8
# 8              Héctor Bellerín               0              2        9
# ..                         ...             ...            ...      ...
# 695          Christian Marques               0              2      549
# 697              Louie Moulden               0              1      611
# 700  Bruno André Cavaco Jordão               0              3      661
# 702             Dion Sanderson               0              2      686
# 703                 Ryan Giles               0              3      687
#
#      cost_2122  team_2122 web_name_2122
# 1           40          3     Rúnarsson
# 2           63          3       Willian
# 3           96          3    Aubameyang
# 7           42          3          Marí
# 8           48          3      Bellerín
# ..         ...        ...           ...
# 695         40         39       Marques
# 697         40         39       Moulden
# 700         45         39        Jordão
# 702         40         39     Sanderson
# 703         45         39         Giles
#
# [193 rows x 7 columns]

# %%
# join home team to all players for current season
home_df = fixtures.merge(all_players, 
               left_on='home_team_code', 
               right_on='team_2122', 
               how='left')

# pull out the required fields and rename columns
home_df = home_df[['gw', 'match_no', 'home_team', 'away_team', 'kickoff_time', 
                   'full_name', 'position_2122', 'cost_2122', 'play_proba_2122', 
                   'web_name_2122']]
home_df.rename(index=str, 
               columns={'home_team':'team',
                        'away_team':'opponent_team',
                        'full_name':'player',
                        'position_2122':'position',
                        'cost_2122':'price',
                        'play_proba_2122':'play_proba',
                        'web_name_2122':'short_name'},
              inplace=True)

# add home flag
home_df['was_home'] = True

# %%
# join away team to all players for current season
away_df = fixtures.merge(all_players, 
               left_on='away_team_code', 
               right_on='team_2122', 
               how='left')

# pull out the required fields and rename columns
away_df = away_df[['gw',  'match_no', 'away_team', 'home_team', 'kickoff_time', 
                   'full_name', 'position_2122', 'cost_2122', 'play_proba_2122', 
                   'web_name_2122']]
away_df.rename(index=str, 
               columns={'away_team':'team',
                        'home_team':'opponent_team',
                        'full_name':'player',
                        'position_2122':'position',
                        'cost_2122':'price',
                        'play_proba_2122':'play_proba',
                        'web_name_2122':'short_name'},
              inplace=True)

# add home flag
away_df['was_home'] = False

# %%
# look at away players
away_df.head()
# Out:
#      gw  match_no         team      opponent_team          kickoff_time  \
# 0  25.0         0  Southampton  Manchester United  2022-02-12T12:30:00Z
# 1  25.0         0  Southampton  Manchester United  2022-02-12T12:30:00Z
# 2  25.0         0  Southampton  Manchester United  2022-02-12T12:30:00Z
# 3  25.0         0  Southampton  Manchester United  2022-02-12T12:30:00Z
# 4  25.0         0  Southampton  Manchester United  2022-02-12T12:30:00Z
#
#               player  position  price play_proba short_name  was_home
# 0       Theo Walcott         3     58        100    Walcott     False
# 1     Fraser Forster         1     44        100    Forster     False
# 2      Alex McCarthy         1     44          0   McCarthy     False
# 3  Oriol Romeu Vidal         3     45        100      Romeu     False
# 4     Nathan Redmond         3     59          0    Redmond     False

# %%
# look at home players
home_df.head()
# Out:
#      gw  match_no               team opponent_team          kickoff_time  \
# 0  25.0         0  Manchester United   Southampton  2022-02-12T12:30:00Z
# 1  25.0         0  Manchester United   Southampton  2022-02-12T12:30:00Z
# 2  25.0         0  Manchester United   Southampton  2022-02-12T12:30:00Z
# 3  25.0         0  Manchester United   Southampton  2022-02-12T12:30:00Z
# 4  25.0         0  Manchester United   Southampton  2022-02-12T12:30:00Z
#
#            player  position  price play_proba short_name  was_home
# 0  Edinson Cavani         4     84        100     Cavani      True
# 1    David de Gea         1     53       None     de Gea      True
# 2   Nemanja Matic         3     43         25      Matic      True
# 3      Paul Pogba         3     74        100      Pogba      True
# 4   Harry Maguire         2     54        100    Maguire      True

# %%
# # calculate average minutes over last 5 gameweeks
# # first get last 5 gameweeks in current season
# recent_mins = df_train_new[(df_train_new['gw'] >= current_gw - 5) & 
#                            (df_train_new['season'] == season_names[0])][['player', 'minutes', 'play_proba']]

# # recent_mins = df_train_new[((df_train_new['gw'] >= 40 - 5) & 
# #                            (df_train_new['season'] == '1920')) | 
# #                            ((df_train_new['gw'] >= 1) & 
# #                            (df_train_new['season'] == '2021'))][['player', 'minutes', 'play_proba']]

# # exclude weeks where the player had an injury designation (i.e. keep where play_proba is 1)
# recent_mins = recent_mins[recent_mins['play_proba'] == 1]

# len(recent_mins)

# # average for each player
# recent_mins = recent_mins.groupby(['player'])['minutes'].mean().to_dict()

# recent_mins

# %%
# concatenate home and away players
remaining_season_df = home_df.append(away_df).reset_index(drop=True)

# add home and away team market values
remaining_season_df = remaining_season_df.merge(teams_mv[teams_mv['season'] == '2122'],
                                                left_on='team', 
                                                right_on='name', 
                                                how='left').drop(['name', 'season'], axis=1)

remaining_season_df = remaining_season_df.merge(teams_mv[teams_mv['season'] == '2122'],
                                                left_on='opponent_team', 
                                                right_on='name', 
                                                how='left').drop(['name', 'season'], axis=1)

remaining_season_df.rename(index=str, 
                           columns={'relative_market_value_x':'relative_market_value_team',
                                    'relative_market_value_y':'relative_market_value_opponent_team'},
                           inplace=True)

# add season name
remaining_season_df['season'] = season_names[0]

# divide cost by 10 for actual cost
remaining_season_df['price'] = remaining_season_df['price']/10

# set availability probability
# 0 = 0% chance, 25 = 25% chance, etc
# 'None' or '100' = 100% chance
remaining_season_df.loc[remaining_season_df['play_proba'] == 'None', 'play_proba'] = 100
remaining_season_df['play_proba'] = remaining_season_df['play_proba'].astype('float') / 100

# cast position to integer
remaining_season_df['position'] = remaining_season_df['position'].astype(int)

# # add minutes based on last five fixtures
# remaining_season_df['minutes'] = remaining_season_df['player'].map(recent_mins)
# remaining_season_df['minutes'].fillna(0, inplace=True)

# # multiply minutes by play probability
# remaining_season_df['minutes'] = remaining_season_df['minutes'] * remaining_season_df['play_proba']

# %%
remaining_season_df.head(50)
# Out:
#       gw  match_no               team   opponent_team          kickoff_time  \
# 0   25.0         0  Manchester United     Southampton  2022-02-12T12:30:00Z
# 1   25.0         0  Manchester United     Southampton  2022-02-12T12:30:00Z
# 2   25.0         0  Manchester United     Southampton  2022-02-12T12:30:00Z
# 3   25.0         0  Manchester United     Southampton  2022-02-12T12:30:00Z
# 4   25.0         0  Manchester United     Southampton  2022-02-12T12:30:00Z
# 5   25.0         0  Manchester United     Southampton  2022-02-12T12:30:00Z
# 6   25.0         0  Manchester United     Southampton  2022-02-12T12:30:00Z
# 7   25.0         0  Manchester United     Southampton  2022-02-12T12:30:00Z
# 8   25.0         0  Manchester United     Southampton  2022-02-12T12:30:00Z
# 9   25.0         0  Manchester United     Southampton  2022-02-12T12:30:00Z
# 10  25.0         0  Manchester United     Southampton  2022-02-12T12:30:00Z
# 11  25.0         0  Manchester United     Southampton  2022-02-12T12:30:00Z
# 12  25.0         0  Manchester United     Southampton  2022-02-12T12:30:00Z
# 13  25.0         0  Manchester United     Southampton  2022-02-12T12:30:00Z
# 14  25.0         0  Manchester United     Southampton  2022-02-12T12:30:00Z
# 15  25.0         0  Manchester United     Southampton  2022-02-12T12:30:00Z
# 16  25.0         0  Manchester United     Southampton  2022-02-12T12:30:00Z
# 17  25.0         0  Manchester United     Southampton  2022-02-12T12:30:00Z
# 18  25.0         0  Manchester United     Southampton  2022-02-12T12:30:00Z
# 19  25.0         0  Manchester United     Southampton  2022-02-12T12:30:00Z
# 20  25.0         0  Manchester United     Southampton  2022-02-12T12:30:00Z
# 21  25.0         0  Manchester United     Southampton  2022-02-12T12:30:00Z
# 22  25.0         0  Manchester United     Southampton  2022-02-12T12:30:00Z
# 23  25.0         0  Manchester United     Southampton  2022-02-12T12:30:00Z
# 24  25.0         0  Manchester United     Southampton  2022-02-12T12:30:00Z
# 25  25.0         0  Manchester United     Southampton  2022-02-12T12:30:00Z
# 26  25.0         0  Manchester United     Southampton  2022-02-12T12:30:00Z
# 27  25.0         0  Manchester United     Southampton  2022-02-12T12:30:00Z
# 28  25.0         0  Manchester United     Southampton  2022-02-12T12:30:00Z
# 29  25.0         1          Brentford  Crystal Palace  2022-02-12T15:00:00Z
# 30  25.0         1          Brentford  Crystal Palace  2022-02-12T15:00:00Z
# 31  25.0         1          Brentford  Crystal Palace  2022-02-12T15:00:00Z
# 32  25.0         1          Brentford  Crystal Palace  2022-02-12T15:00:00Z
# 33  25.0         1          Brentford  Crystal Palace  2022-02-12T15:00:00Z
# 34  25.0         1          Brentford  Crystal Palace  2022-02-12T15:00:00Z
# 35  25.0         1          Brentford  Crystal Palace  2022-02-12T15:00:00Z
# 36  25.0         1          Brentford  Crystal Palace  2022-02-12T15:00:00Z
# 37  25.0         1          Brentford  Crystal Palace  2022-02-12T15:00:00Z
# 38  25.0         1          Brentford  Crystal Palace  2022-02-12T15:00:00Z
# 39  25.0         1          Brentford  Crystal Palace  2022-02-12T15:00:00Z
# 40  25.0         1          Brentford  Crystal Palace  2022-02-12T15:00:00Z
# 41  25.0         1          Brentford  Crystal Palace  2022-02-12T15:00:00Z
# 42  25.0         1          Brentford  Crystal Palace  2022-02-12T15:00:00Z
# 43  25.0         1          Brentford  Crystal Palace  2022-02-12T15:00:00Z
# 44  25.0         1          Brentford  Crystal Palace  2022-02-12T15:00:00Z
# 45  25.0         1          Brentford  Crystal Palace  2022-02-12T15:00:00Z
# 46  25.0         1          Brentford  Crystal Palace  2022-02-12T15:00:00Z
# 47  25.0         1          Brentford  Crystal Palace  2022-02-12T15:00:00Z
# 48  25.0         1          Brentford  Crystal Palace  2022-02-12T15:00:00Z
# 49  25.0         1          Brentford  Crystal Palace  2022-02-12T15:00:00Z
#
#                                  player  position  price  play_proba  \
# 0                        Edinson Cavani         4    8.4        1.00
# 1                          David de Gea         1    5.3        1.00
# 2                         Nemanja Matic         3    4.3        0.25
# 3                            Paul Pogba         3    7.4        1.00
# 4                         Harry Maguire         2    5.4        1.00
# 5   Frederico Rodrigues de Paula Santos         3    4.9        0.25
# 6                             Luke Shaw         2    5.0        1.00
# 7                         Jesse Lingard         3    6.7        1.00
# 8         Bruno Miguel Borges Fernandes         3   11.7        1.00
# 9                       Anthony Martial         4    7.6        0.00
# 10                  Alex Nicolao Telles         2    5.0        0.75
# 11                       Dean Henderson         1    4.7        1.00
# 12                      Marcus Rashford         3    9.4        1.00
# 13                        Axel Tuanzebe         2    4.4        0.00
# 14                      Victor Lindelöf         2    4.8        1.00
# 15                      Scott McTominay         3    5.4        1.00
# 16                          Eric Bailly         2    4.9        0.25
# 17                    Aaron Wan-Bissaka         2    5.1        1.00
# 18                      Mason Greenwood         3    7.1        0.00
# 19                            Juan Mata         3    4.7        1.00
# 20                         Jadon Sancho         3    8.9        1.00
# 21                           Tom Heaton         1    3.9        1.00
# 22            José Diogo Dalot Teixeira         2    4.6        1.00
# 23                      Andreas Pereira         3    5.0        0.00
# 24                       Anthony Elanga         3    4.8        1.00
# 25                       Raphaël Varane         2    5.5        1.00
# 26  Cristiano Ronaldo dos Santos Aveiro         4   12.5        1.00
# 27                           Phil Jones         2    4.5        1.00
# 28                          Amad Diallo         3    5.0        0.00
# 29                       Pontus Jansson         2    4.5        1.00
# 30                   Christian Nørgaard         3    5.0        1.00
# 31                           Ivan Toney         4    6.6        0.50
# 32                    Tariqe Fosu-Henry         3    5.1        0.00
# 33                    David Raya Martin         1    4.3        1.00
# 34                          Sergi Canós         3    5.5        1.00
# 35               Pelenda Joshua Dasilva         3    5.3        1.00
# 36                           Rico Henry         2    4.5        1.00
# 37                        Vitaly Janelt         3    5.0        0.75
# 38                        Saman Ghoddos         3    5.3        1.00
# 39                       Mathias Jensen         3    4.9        1.00
# 40                        Charlie Goode         2    3.9        0.00
# 41                         Marcus Forss         4    5.3        0.00
# 42              Mads Roerslev Rasmussen         2    4.3        1.00
# 43                   Mads Bech Sørensen         2    4.3        1.00
# 44                        Ethan Pinnock         2    4.5        1.00
# 45                      Ellery Balcombe         1    4.0        0.00
# 46                         Jan Zamburek         3    4.4        0.00
# 47                    Patrik Gunnarsson         1    3.9        0.00
# 48                     Halil Dervişoğlu         4    5.4        0.00
# 49                         Bryan Mbeumo         3    5.3        1.00
#
#      short_name  was_home  relative_market_value_team  \
# 0        Cavani      True                         NaN
# 1        de Gea      True                         NaN
# 2         Matic      True                         NaN
# 3         Pogba      True                         NaN
# 4       Maguire      True                         NaN
# 5          Fred      True                         NaN
# 6          Shaw      True                         NaN
# 7       Lingard      True                         NaN
# 8     Fernandes      True                         NaN
# 9       Martial      True                         NaN
# 10       Telles      True                         NaN
# 11    Henderson      True                         NaN
# 12     Rashford      True                         NaN
# 13     Tuanzebe      True                         NaN
# 14     Lindelöf      True                         NaN
# 15    McTominay      True                         NaN
# 16       Bailly      True                         NaN
# 17  Wan-Bissaka      True                         NaN
# 18    Greenwood      True                         NaN
# 19         Mata      True                         NaN
# 20       Sancho      True                         NaN
# 21       Heaton      True                         NaN
# 22        Dalot      True                         NaN
# 23      Pereira      True                         NaN
# 24       Elanga      True                         NaN
# 25       Varane      True                         NaN
# 26      Ronaldo      True                         NaN
# 27        Jones      True                         NaN
# 28       Diallo      True                         NaN
# 29      Jansson      True                         NaN
# 30     Nørgaard      True                         NaN
# 31        Toney      True                         NaN
# 32         Fosu      True                         NaN
# 33         Raya      True                         NaN
# 34        Canós      True                         NaN
# 35      Dasilva      True                         NaN
# 36        Henry      True                         NaN
# 37       Janelt      True                         NaN
# 38      Ghoddos      True                         NaN
# 39       Jensen      True                         NaN
# 40        Goode      True                         NaN
# 41        Forss      True                         NaN
# 42     Roerslev      True                         NaN
# 43     Sørensen      True                         NaN
# 44      Pinnock      True                         NaN
# 45     Balcombe      True                         NaN
# 46     Zamburek      True                         NaN
# 47   Gunnarsson      True                         NaN
# 48   Dervişoğlu      True                         NaN
# 49       Mbeumo      True                         NaN
#
#     relative_market_value_opponent_team season
# 0                                   NaN   2122
# 1                                   NaN   2122
# 2                                   NaN   2122
# 3                                   NaN   2122
# 4                                   NaN   2122
# 5                                   NaN   2122
# 6                                   NaN   2122
# 7                                   NaN   2122
# 8                                   NaN   2122
# 9                                   NaN   2122
# 10                                  NaN   2122
# 11                                  NaN   2122
# 12                                  NaN   2122
# 13                                  NaN   2122
# 14                                  NaN   2122
# 15                                  NaN   2122
# 16                                  NaN   2122
# 17                                  NaN   2122
# 18                                  NaN   2122
# 19                                  NaN   2122
# 20                                  NaN   2122
# 21                                  NaN   2122
# 22                                  NaN   2122
# 23                                  NaN   2122
# 24                                  NaN   2122
# 25                                  NaN   2122
# 26                                  NaN   2122
# 27                                  NaN   2122
# 28                                  NaN   2122
# 29                                  NaN   2122
# 30                                  NaN   2122
# 31                                  NaN   2122
# 32                                  NaN   2122
# 33                                  NaN   2122
# 34                                  NaN   2122
# 35                                  NaN   2122
# 36                                  NaN   2122
# 37                                  NaN   2122
# 38                                  NaN   2122
# 39                                  NaN   2122
# 40                                  NaN   2122
# 41                                  NaN   2122
# 42                                  NaN   2122
# 43                                  NaN   2122
# 44                                  NaN   2122
# 45                                  NaN   2122
# 46                                  NaN   2122
# 47                                  NaN   2122
# 48                                  NaN   2122
# 49                                  NaN   2122

# %%
# save latest prediction set to csv
remaining_season_df.to_csv(path/'remaining_season.csv')
