# %%
# import required libriaries
from pathlib import Path
from helpers import *

# %%
# path to data directory
path = Path('/home/jupyter/fpl-prediction/data')

# %%
# read in latest training set
df_train = pd.read_csv(path/'train.csv', index_col=0, dtype={'season':str})

# path to current season
season_paths = [path/'2019-20']

# name for current season
season_names = ['1920']

# team codes
teams = pd.read_csv(path/'teams.csv')

# latest remaining season dataset, for latest week's play_proba values
remaining_season = pd.read_csv(path/'remaining_season.csv', index_col=0)

# create players dataset
all_players = build_players(path, season_paths, season_names, teams)

# 2019-20 market value
# table was in slightly different position for 2019-20 season
# should check that 2019-20 season values remain the same once season starts
teams_mv = build_season_mv('1920', 11, range(13,33))

# %%
df_train.head()
# Out:
#                player  gw  position  minutes             team  \
# 0     Aaron_Cresswell   1         2        0  West Ham United
# 1        Aaron_Lennon   1         3       15          Everton
# 2        Aaron_Ramsey   1         3       60          Arsenal
# 3  Abdoulaye_Doucouré   1         3        0          Watford
# 4   Abdul Rahman_Baba   1         2        0          Chelsea
#
#        opponent_team  relative_market_value_team  \
# 0            Chelsea                    0.895471
# 1  Tottenham Hotspur                    1.057509
# 2          Liverpool                    1.944129
# 3        Southampton                    0.704200
# 4    West Ham United                    2.243698
#
#    relative_market_value_opponent_team  was_home  total_points season
# 0                             2.243698     False             0   1617
# 1                             1.433690      True             1   1617
# 2                             1.465860      True             2   1617
# 3                             0.796805     False             0   1617
# 4                             0.895471      True             0   1617

# %%
# find the latest gameweek
last_gw = df_train['gw'][df_train['season'] == '1920'].max()

if np.isnan(last_gw): 
    last_gw = 1 
else: 
    last_gw = last_gw + 1
    
last_gw
# Out:
# 1

# %%
# build training set for latest gameweek
df_latest = build_season(season_paths[0], season_names[0], all_players, teams, teams_mv, [last_gw])

# %%
df_latest
# Out:
#                                player  gw  position  minutes  \
# 0                     Aaron_Cresswell   1         2       90
# 1                        Aaron_Lennon   1         3        6
# 2                          Aaron_Mooy   1         3        0
# 3                      Aaron_Ramsdale   1         1       90
# 4                   Aaron_Wan-Bissaka   1         2       90
# 5                  Abdoulaye_Doucouré   1         3       90
# 6                        Adama_Traoré   1         3        0
# 7                        Adam_Lallana   1         3        0
# 8                         Adam_Masina   1         2        0
# 9                          Adam_Smith   1         2       90
# 10                       Adam_Webster   1         2        0
# 11                    Ademola_Lookman   1         3        0
# 12                    Adrian_Mariappa   1         2        0
# 13     Adrián_San Miguel del Castillo   1         1       51
# 14                  Ahmed_El Mohamady   1         2       90
# 15             Ainsley_Maitland-Niles   1         2       90
# 16                       Albian_Ajeti   1         4        0
# 17                   Alexander_Tettey   1         3        0
# 18   Alexandre Nascimento_Costa Silva   1         4        0
# 19                Alexandre_Lacazette   1         4        0
# 20                     Alexis_Sánchez   1         3        0
# 21                         Alex_Iwobi   1         3        0
# 22                      Alex_McCarthy   1         1        0
# 23            Alex_Oxlade-Chamberlain   1         3        0
# 24                Alireza_Jahanbakhsh   1         3        0
# 25              Alisson_Ramses Becker   1         1       38
# 26                Allan_Saint-Maximin   1         3       23
# 27                Andreas_Christensen   1         2       90
# 28                    Andreas_Pereira   1         3       73
# 512                   Chelsea         Manchester United
# 513   Wolverhampton Wanderers            Leicester City
# 514                   Chelsea         Manchester United
# 515                   Watford  Brighton and Hove Albion
# 516   Wolverhampton Wanderers            Leicester City
# 517           West Ham United           Manchester City
# 518                 Liverpool                   Norwich
# 519               Southampton                   Burnley
# 520                   Everton            Crystal Palace
# 521          Newcastle United                   Arsenal
# 522            Leicester City   Wolverhampton Wanderers
# 523  Brighton and Hove Albion                   Watford
# 524            Leicester City   Wolverhampton Wanderers
# 525               Aston Villa         Tottenham Hotspur
#
#      relative_market_value_team  relative_market_value_opponent_team  \
# 0                      0.739196                             2.727025
# 1                      0.441799                             0.624210
# 2                      0.476156                             0.555819
# 3                      0.687124                             0.150631
# 4                      1.679697                             1.798870
# 5                      0.555819                             0.476156
# 6                      0.673382                             0.886283
# 7                      2.297572                             0.198300
# 8                      0.555819                             0.476156
# 9                      0.687124                             0.150631
# 10                     0.476156                             0.555819
# 11                     1.125166                             0.495374
# 12                     0.555819                             0.476156
# 13                     2.297572                             0.198300
# 14                     0.338194                             2.113981
# 15                     1.448866                             0.542356
# 16                     0.739196                             2.727025
# 17                     0.198300                             2.297572
# 18                     0.739196                             2.727025
# 19                     1.448866                             0.542356
# 20                     1.679697                             1.798870
# 21                     1.125166                             0.495374
# 22                     0.624210                             0.441799
# 23                     2.297572                             0.198300
# 24                     0.476156                             0.555819
# 25                     2.297572                             0.198300
# 26                     0.542356                             1.448866
# 27                     1.798870                             1.679697
# 28                     1.679697                             1.798870
# 29                     2.297572                             0.198300
# ..                          ...                                  ...
# 496                    0.555819                             0.476156
# 497                    2.113981                             0.338194
# 498                    0.624210                             0.441799
# 499                    0.338194                             2.113981
# 500                    0.495374                             1.125166
# 501                    1.679697                             1.798870
# 502                    2.113981                             0.338194
# 503                    2.113981                             0.338194
# 504                    2.297572                             0.198300
# 505                    0.495374                             1.125166
# 506                    0.495374                             1.125166
# 507                    0.624210                             0.441799
# 508                    0.338194                             2.113981
# 509                    0.886283                             0.673382
# 510                    0.886283                             0.673382
# 511                    0.495374                             1.125166
# 512                    1.798870                             1.679697
# 513                    0.673382                             0.886283
# 514                    1.798870                             1.679697
# 515                    0.555819                             0.476156
# 516                    0.673382                             0.886283
# 517                    0.739196                             2.727025
# 518                    2.297572                             0.198300
# 519                    0.624210                             0.441799
# 520                    1.125166                             0.495374
# 521                    0.542356                             1.448866
# 522                    0.886283                             0.673382
# 523                    0.476156                             0.555819
# 524                    0.886283                             0.673382
# 525                    0.338194                             2.113981
#
#      was_home  total_points season
# 0        True             0   1920
# 1        True             1   1920
# 2       False             0   1920
# 3        True             2   1920
# 4        True             8   1920
# 5        True             0   1920
# 6       False             0   1920
# 7        True             0   1920
# 8        True             0   1920
# 9        True             1   1920
# 10      False             0   1920
# 11      False             0   1920
# 12       True             0   1920
# 13       True             1   1920
# 14      False             1   1920
# 15      False            12   1920
# 16       True             0   1920
# 17      False             0   1920
# 18       True             0   1920
# 19      False             0   1920
# 20       True             0   1920
# 21      False             0   1920
# 22      False             0   1920
# 23       True             0   1920
# 24      False             0   1920
# 25       True             1   1920
# 26       True             1   1920
# 27      False             0   1920
# 28       True             6   1920
# 29       True             2   1920
# ..        ...           ...    ...
# 496      True             2   1920
# 497      True             0   1920
# 498     False             0   1920
# 499     False             6   1920
# 500      True             6   1920
# 501      True             5   1920
# 502      True             0   1920
# 503      True             0   1920
# 504      True             8   1920
# 505      True             0   1920
# 506      True             0   1920
# 507     False             0   1920
# 508     False             2   1920
# 509      True             0   1920
# 510      True             3   1920
# 511      True             1   1920
# 512     False             0   1920
# 513     False             9   1920
# 514     False             0   1920
# 515      True             2   1920
# 516     False             0   1920
# 517      True             0   1920
# 518      True             0   1920
# 519     False             1   1920
# 520     False             9   1920
# 521      True             0   1920
# 522      True             3   1920
# 523     False             0   1920
# 524      True             6   1920
# 525     False             0   1920
#
# [526 rows x 11 columns]

# %%
df_latest.shape
# Out:
# (526, 11)

# %%
last_play_proba = remaining_season[remaining_season['gw'] == 1][['player', 'play_proba']]

# %%
last_play_proba.head()
# Out:
# Empty DataFrame
# Columns: [player, play_proba]
# Index: []

# %%
# add latest week's play_proba for each player
df_latest = df_latest.merge(last_play_proba, on='player', how='left')

# %%
df_latest
# Out:
#                                player  gw  position  minutes  \
# 0                     Aaron_Cresswell   1         2       90
# 1                        Aaron_Lennon   1         3        6
# 2                          Aaron_Mooy   1         3        0
# 3                      Aaron_Ramsdale   1         1       90
# 4                   Aaron_Wan-Bissaka   1         2       90
# 5                  Abdoulaye_Doucouré   1         3       90
# 6                        Adama_Traoré   1         3        0
# 7                        Adam_Lallana   1         3        0
# 8                         Adam_Masina   1         2        0
# 9                          Adam_Smith   1         2       90
# 10                       Adam_Webster   1         2        0
# 11                    Ademola_Lookman   1         3        0
# 12                    Adrian_Mariappa   1         2        0
# 13     Adrián_San Miguel del Castillo   1         1       51
# 14                  Ahmed_El Mohamady   1         2       90
# 15             Ainsley_Maitland-Niles   1         2       90
# 16                       Albian_Ajeti   1         4        0
# 17                   Alexander_Tettey   1         3        0
# 18   Alexandre Nascimento_Costa Silva   1         4        0
# 19                Alexandre_Lacazette   1         4        0
# 20                     Alexis_Sánchez   1         3        0
# 21                         Alex_Iwobi   1         3        0
# 22                      Alex_McCarthy   1         1        0
# 23            Alex_Oxlade-Chamberlain   1         3        0
# 24                Alireza_Jahanbakhsh   1         3        0
# 25              Alisson_Ramses Becker   1         1       38
# 26                Allan_Saint-Maximin   1         3       23
# 27                Andreas_Christensen   1         2       90
# 28                    Andreas_Pereira   1         3       73
# 29                   Andrew_Robertson   1         2       90
# ..                                ...  ..       ...      ...
# 496                       Troy_Deeney   1         4       90
# 497                      Troy_Parrott   1         4        0
# 498                    Tyreke_Johnson   1         3        0
# 499                      Tyrone_Mings   1         2       90
# 500                    Vicente_Guaita   1         1       90
# 501                   Victor_Lindelöf   1         2       90
# 502                    Victor_Wanyama   1         3        0
# 503                   Vincent_Janssen   1         4        0
# 504                   Virgil_van Dijk   1         2       90
# 505                   Víctor_Camarasa   1         3        0
# 506                   Wayne_Hennessey   1         1        0
# 507                      Wesley_Hoedt   1         2        0
# 502      True             0   1920        0.75
# 503      True             0   1920        0.00
# 504      True             8   1920        1.00
# 505      True             0   1920        1.00
# 506      True             0   1920        1.00
# 507     False             0   1920        1.00
# 508     False             2   1920        1.00
# 509      True             0   1920        1.00
# 510      True             3   1920        1.00
# 511      True             1   1920        1.00
# 512     False             0   1920        0.75
# 513     False             9   1920        1.00
# 514     False             0   1920        1.00
# 515      True             2   1920        1.00
# 516     False             0   1920        0.00
# 517      True             0   1920        1.00
# 518      True             0   1920        1.00
# 519     False             1   1920        1.00
# 520     False             9   1920        1.00
# 521      True             0   1920        1.00
# 522      True             3   1920        1.00
# 523     False             0   1920        0.00
# 524      True             6   1920        1.00
# 525     False             0   1920        1.00
#
# [526 rows x 12 columns]

# %%
df_train_new = pd.concat([df_train, df_latest], ignore_index=True, axis=0)

# %%
# save latest training set to csv
# overwrite existing one
df_train_new.to_csv(path/'train.csv')

# %%
## now need to create the prediction set
# start by reading fixtures.csv
# set starting gameweek (where are we right now in the season)
current_gw = last_gw + 1
fixtures = pd.read_csv(path/'fixtures.csv')
fixtures = fixtures[fixtures['gw'] >= current_gw]

# %%
fixtures.head(10)
# Out:
#                    home_team          away_team  gw
# 10                   Arsenal            Burnley   2
# 11               Aston Villa        Bournemouth   2
# 12  Brighton and Hove Albion    West Ham United   2
# 13                   Everton            Watford   2
# 14                   Norwich   Newcastle United   2
# 15               Southampton          Liverpool   2
# 16           Manchester City  Tottenham Hotspur   2
# 17          Sheffield United     Crystal Palace   2
# 18                   Chelsea     Leicester City   2
# 19   Wolverhampton Wanderers  Manchester United   2

# %%
# add team codes for home and away teams
fixtures = fixtures.merge(teams, left_on='home_team', right_on='team', how='left')
fixtures = fixtures.merge(teams, left_on='away_team', right_on='team', how='left')
fixtures = fixtures[['gw', 'home_team', 'away_team', 'team_code_x', 'team_code_y']]
fixtures.rename(index=str,
                columns={'team_code_x':'home_team_code',
                         'team_code_y':'away_team_code'},
                inplace=True)

# %%
fixtures.head()
# Out:
#    gw                 home_team         away_team  home_team_code  \
# 0   2                   Arsenal           Burnley               3
# 1   2               Aston Villa       Bournemouth               7
# 2   2  Brighton and Hove Albion   West Ham United              36
# 3   2                   Everton           Watford              11
# 4   2                   Norwich  Newcastle United              45
#
#    away_team_code
# 0              90
# 1              91
# 2              21
# 3              57
# 4               4

# %%
# join home team to all players for current season
home_df = fixtures.merge(all_players, 
               left_on='home_team_code', 
               right_on='team_1920', 
               how='left')

# pull out the required fields and rename columns
home_df = home_df[['gw', 'home_team', 'away_team', 'full_name', 'position_1920', 'cost_1920', 'play_proba_1920']]
home_df.rename(index=str, 
               columns={'home_team':'team',
                        'away_team':'opponent_team',
                        'full_name':'player',
                        'position_1920':'position',
                        'cost_1920':'price',
                        'play_proba_1920':'play_proba'},
              inplace=True)

# add home flag
home_df['was_home'] = True

# %%
# join away team to all players for current season
away_df = fixtures.merge(all_players, 
               left_on='away_team_code', 
               right_on='team_1920', 
               how='left')

# pull out the required fields and rename columns
away_df = away_df[['gw',  'away_team', 'home_team', 'full_name', 'position_1920', 'cost_1920', 'play_proba_1920']]
away_df.rename(index=str, 
               columns={'away_team':'team',
                        'home_team':'opponent_team',
                        'full_name':'player',
                        'position_1920':'position',
                        'cost_1920':'price',
                        'play_proba_1920':'play_proba'},
              inplace=True)

# add home flag
away_df['was_home'] = False

# %%
# look at away players
away_df.head()
# Out:
#    gw     team opponent_team           player  position  price play_proba  \
# 0   2  Burnley       Arsenal          Ben_Mee         2     50       None
# 1   2  Burnley       Arsenal  James_Tarkowski         2     50        100
# 2   2  Burnley       Arsenal   Matthew_Lowton         2     45       None
# 3   2  Burnley       Arsenal    Phil_Bardsley         2     45       None
# 4   2  Burnley       Arsenal   Charlie_Taylor         2     45       None
#
#    was_home
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False

# %%
# look at home players
home_df.head()
# Out:
#    gw     team opponent_team                     player  position  price  \
# 0   2  Arsenal       Burnley           Shkodran_Mustafi         2     55
# 1   2  Arsenal       Burnley            Héctor_Bellerín         2     55
# 2   2  Arsenal       Burnley             Sead_Kolasinac         2     55
# 3   2  Arsenal       Burnley     Ainsley_Maitland-Niles         2     50
# 4   2  Arsenal       Burnley  Sokratis_Papastathopoulos         2     50
#
#   play_proba  was_home
# 0       None      True
# 1          0      True
# 2         25      True
# 3       None      True
# 4       None      True

# %%
# concatenate home and away players
remaining_season_df = home_df.append(away_df).reset_index(drop=True)

# add home and away team market values
remaining_season_df = remaining_season_df.merge(teams_mv[teams_mv['season'] == '1920'],
                                                left_on='team', 
                                                right_on='name', 
                                                how='left').drop(['name', 'season'], axis=1)

remaining_season_df = remaining_season_df.merge(teams_mv[teams_mv['season'] == '1920'],
                                                left_on='opponent_team', 
                                                right_on='name', 
                                                how='left').drop(['name', 'season'], axis=1)

remaining_season_df.rename(index=str, 
                           columns={'relative_market_value_x':'relative_market_value_team',
                                    'relative_market_value_y':'relative_market_value_opponent_team'},
                           inplace=True)

# add season name
remaining_season_df['season'] = '1920'

# divide cost by 10 for actual cost
remaining_season_df['price'] = remaining_season_df['price']/10

# set availability probability
# 0 = 0% chance, 25 = 25% chance, etc
# 'None' or '100' = 100% chance
remaining_season_df.loc[remaining_season_df['play_proba'] == 'None', 'play_proba'] = 100
remaining_season_df['play_proba'] = remaining_season_df['play_proba'].astype('float') / 100

# set minutes equal to 90 multiplied by their play probabiliby for all players, for now
remaining_season_df['minutes'] = 90 * remaining_season_df['play_proba']

# cast position to integer
remaining_season_df['position'] = remaining_season_df['position'].astype(int)

# %%
remaining_season_df.head()
# Out:
#    gw     team opponent_team                     player  position  price  \
# 0   2  Arsenal       Burnley           Shkodran_Mustafi         2    5.5
# 1   2  Arsenal       Burnley            Héctor_Bellerín         2    5.5
# 2   2  Arsenal       Burnley             Sead_Kolasinac         2    5.5
# 3   2  Arsenal       Burnley     Ainsley_Maitland-Niles         2    5.0
# 4   2  Arsenal       Burnley  Sokratis_Papastathopoulos         2    5.0
#
#    play_proba  was_home  relative_market_value_team  \
# 0        1.00      True                    1.448866
# 1        0.00      True                    1.448866
# 2        0.25      True                    1.448866
# 3        1.00      True                    1.448866
# 4        1.00      True                    1.448866
#
#    relative_market_value_opponent_team season  minutes
# 0                             0.441799   1920     90.0
# 1                             0.441799   1920      0.0
# 2                             0.441799   1920     22.5
# 3                             0.441799   1920     90.0
# 4                             0.441799   1920     90.0

# %%
# save latest prediction set to csv
remaining_season_df.to_csv(path/'remaining_season.csv')
