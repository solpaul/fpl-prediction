# %%
# import required libriaries
from pathlib import Path
import json

from fpl_predictor.util import *

# %%
# path to data directory
#path = Path('/home/jupyter/fpl-prediction/data')
path = Path('./fpl_predictor/data')

# %%
# read in latest training set
df_train = pd.read_csv(path/'train_v8.csv', index_col=0, 
                       dtype={'season':str,
                              'comp':str,
                              'squad':str})

# path to current season
season_paths = [path/'2021-22']

# name for current season
season_names = ['2122']

# team codes
teams = pd.read_csv(path/'teams.csv')

# latest remaining season dataset, for latest week's play_proba values
remaining_season = pd.read_csv(path/'remaining_season.csv', index_col=0)

# create players dataset
all_players = build_players(path, season_paths, season_names, teams)

# 2019-20 market value
# table was in slightly different position for 2019-20 season
# should check that 2019-20 season values remain the same once season starts
teams_mv = build_season_mv('2122', 11, range(13,33))

# %%
# all_players#[all_players['full_name'] == 'Ben Davies']

# %%
df_train.tail(50)
# Out:
#                             player  gw  position  minutes  \
# 123200               Thomas Partey  14         3       90
# 123201            Timothy Castagne  14         2       90
# 123202                 Timo Werner  14         4        0
# 123203                    Tim Krul  14         1       90
# 123204             Tino Livramento  14         2       90
# 123205                  Tobi Omole  14         2        0
# 123206           Toby Alderweireld  14         2        0
# 123207               Todd Cantwell  14         3        0
# 123208                Tomas Soucek  14         3       90
# 123209                 Tommy Doyle  14         3        0
# 123210               Tom Cleverley  14         3       84
# 123211                  Tom Davies  14         3        0
# 123212                  Tom Heaton  14         1        0
# 123213      Trent Alexander-Arnold  14         2       90
# 123214             Trevoh Chalobah  14         2       59
# 123215                 Troy Deeney  14         4        0
# 123216                Tyler Morton  14         3        0
# 123217               Tyler Onyango  14         3        0
# 123218               Tyler Roberts  14         3       90
# 123219             Tyrick Mitchell  14         2       90
# 123220                Tyrone Mings  14         2       90
# 123221              Vicente Guaita  14         1       90
# 123222             Victor Lindelöf  14         2       90
# 123223            Viljami Sinisalo  14         1        0
# 123224             Virgil van Dijk  14         2       90
# 123225               Vitaly Janelt  14         3       69
# 123226             Vladimir Coufal  14         2       90
# 123227             Wayne Hennessey  14         1        0
# 123228               Wesley Fofana  14         2        0
# 123229               Wesley Moraes  14         4        0
# 123230               Wilfred Ndidi  14         3       90
# 123231               Wilfried Zaha  14         3       90
# 123232              William Saliba  14         2        0
# 123233           William Smallbone  14         3        0
# 123234        William Troost-Ekong  14         2       90
# 123235     Willian Borges Da Silva  14         3        0
# 123236                  Willy Boly  14         2        0
# 123237                 Will Hughes  14         3       10
# 123238                 Will Norris  14         1        0
# 123239                Winston Reid  14         2        0
# 123240             Xherdan Shaqiri  14         3        0
# 123241                  Yan Valery  14         2        0
# 123242                  Yerry Mina  14         2        0
# 123243  Yerson Mosquera Valdelamar  14         2        0
# 123244                 Yoane Wissa  14         3       20
# 123245             Youri Tielemans  14         3        0
# 123246               Yves Bissouma  14         3       90
# 123247                Zack Steffen  14         1        0
# 123248            Álvaro Fernández  14         1       90
# 123249              Çaglar Söyüncü  14         2       90
#
#                             team             opponent_team  \
# 123200                   Arsenal         Manchester United
# 123201            Leicester City               Southampton
# 123202                   Chelsea                   Watford
# 123203                   Norwich          Newcastle United
# 123238                    0.320000                             0.845919
# 123239                    0.780179                             0.566001
# 123240                    1.908328                             0.944253
# 123241                    0.562037                             1.207103
# 123242                    0.944253                             1.908328
# 123243                    0.845919                             0.320000
# 123244                    0.440358                             1.535582
# 123245                    1.207103                             0.562037
# 123246                    0.566001                             0.780179
# 123247                    2.378527                             0.909787
# 123248                    0.440358                             1.535582
# 123249                    1.207103                             0.562037
#
#         was_home  total_points  ...   xa  sca  gca  passes_completed  passes  \
# 123200     False             2  ...  0.0  4.0  1.0              48.0    58.0
# 123201     False             1  ...  0.0  0.0  0.0              35.0    51.0
# 123202     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 123203     False             2  ...  0.0  0.0  0.0              19.0    21.0
# 123204      True             1  ...  0.0  0.0  0.0              30.0    42.0
# 123205      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 123206      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 123207     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 123208      True             9  ...  0.0  2.0  0.0              15.0    22.0
# 123209     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 123210      True             1  ...  0.0  2.0  0.0              36.0    50.0
# 123211      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 123212      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 123213     False             2  ...  0.3  2.0  0.0              68.0    84.0
# 123214     False             1  ...  0.0  0.0  0.0              25.0    31.0
# 123215      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 123216     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 123217      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 123218      True             2  ...  0.0  2.0  0.0              11.0    16.0
# 123219     False             2  ...  0.0  0.0  0.0              24.0    40.0
# 123220      True             1  ...  0.0  1.0  0.0              32.0    39.0
# 123221     False             2  ...  0.0  0.0  0.0              26.0    37.0
# 123222      True             1  ...  0.0  0.0  0.0              40.0    43.0
# 123223      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 123224     False             1  ...  0.0  1.0  0.0              60.0    68.0
# 123225     False             2  ...  0.0  1.0  0.0              23.0    35.0
# 123226      True             2  ...  0.1  3.0  0.0              29.0    35.0
# 123227     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 123228     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 123229      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 123230     False             4  ...  0.0  1.0  1.0              38.0    49.0
# 123231     False             2  ...  0.5  3.0  0.0              24.0    35.0
# 123232     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 123233      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 123234      True             0  ...  0.0  0.0  0.0              15.0    24.0
# 123235     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 123236      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 123237     False             1  ...  0.0  1.0  0.0               3.0     5.0
# 123238     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 123239      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 123240     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 123241      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 123242      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 123243      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 123244     False             1  ...  0.0  0.0  0.0               3.0     3.0
# 123245     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 123246     False             2  ...  0.1  1.0  0.0              63.0    65.0
# 123247     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 123248     False             2  ...  0.0  0.0  0.0              27.0    36.0
# 123249     False             1  ...  0.0  0.0  0.0              56.0    65.0
#
#         passes_pct  carries  dribbles_completed  dribbles  crowds
# 123200        82.8     52.0                 0.0       1.0       1
# 123201        68.6     28.0                 0.0       0.0       1
# 123202         NaN      NaN                 NaN       NaN       1
# 123203        90.5      9.0                 0.0       0.0       1
# 123204        71.4     22.0                 0.0       0.0       1
# 123205         NaN      NaN                 NaN       NaN       1
# 123206         NaN      NaN                 NaN       NaN       1
# 123207         NaN      NaN                 NaN       NaN       1
# 123208        68.2     10.0                 0.0       0.0       1
# 123209         NaN      NaN                 NaN       NaN       1
# 123210        72.0     27.0                 0.0       0.0       1
# 123211         NaN      NaN                 NaN       NaN       1
# 123212         NaN      NaN                 NaN       NaN       1
# 123213        81.0     42.0                 0.0       0.0       1
# 123214        80.6     20.0                 1.0       1.0       1
# 123215         NaN      NaN                 NaN       NaN       1
# 123216         NaN      NaN                 NaN       NaN       1
# 123217         NaN      NaN                 NaN       NaN       1
# 123218        68.8     17.0                 0.0       3.0       1
# 123219        60.0     22.0                 1.0       1.0       1
# 123220        82.1     23.0                 0.0       0.0       1
# 123221        70.3     19.0                 0.0       0.0       1
# 123222        93.0     29.0                 0.0       0.0       1
# 123223         NaN      NaN                 NaN       NaN       1
# 123224        88.2     40.0                 0.0       0.0       1
# 123225        65.7     25.0                 0.0       0.0       1
# 123226        82.9     20.0                 1.0       1.0       1
# 123227         NaN      NaN                 NaN       NaN       1
# 123228         NaN      NaN                 NaN       NaN       1
# 123229         NaN      NaN                 NaN       NaN       1
# 123230        77.6     38.0                 1.0       1.0       1
# 123231        68.6     40.0                 2.0       6.0       1
# 123232         NaN      NaN                 NaN       NaN       1
# 123233         NaN      NaN                 NaN       NaN       1
# 123234        62.5     10.0                 0.0       0.0       1
# 123235         NaN      NaN                 NaN       NaN       1
# 123236         NaN      NaN                 NaN       NaN       1
# 123237        60.0      4.0                 0.0       0.0       1
# 123238         NaN      NaN                 NaN       NaN       1
# 123239         NaN      NaN                 NaN       NaN       1
# 123240         NaN      NaN                 NaN       NaN       1
# 123241         NaN      NaN                 NaN       NaN       1
# 123242         NaN      NaN                 NaN       NaN       1
# 123243         NaN      NaN                 NaN       NaN       1
# 123244       100.0      4.0                 0.0       0.0       1
# 123245         NaN      NaN                 NaN       NaN       1
# 123246        96.9     63.0                 4.0       4.0       1
# 123247         NaN      NaN                 NaN       NaN       1
# 123248        75.0     23.0                 0.0       0.0       1
# 123249        86.2     39.0                 0.0       0.0       1
#
# [50 rows x 59 columns]

# %%
# find the latest gameweek
last_gw = df_train['gw'][df_train['season'] == season_names[0]].max()

if np.isnan(last_gw): 
    last_gw = 1 
else: 
    last_gw = last_gw + 1
    
last_gw
# Out:
# 15

# %%
# build training set for latest gameweek
df_latest = build_season(season_paths[0], season_names[0], all_players, teams, teams_mv, [last_gw])

# %%
df_latest.drop_duplicates(inplace=True)

# %%
df_latest.head(50)
# Out:
#                             player  gw  position  minutes  \
# 0                   Aaron Connolly  15         4       35
# 1                  Aaron Cresswell  15         2        0
# 2                     Aaron Lennon  15         3        0
# 3                   Aaron Ramsdale  15         1       90
# 4                     Aaron Ramsey  15         3        0
# 5                Aaron Wan-Bissaka  15         2        0
# 6               Abdoulaye Doucouré  15         3       90
# 7                     Adama Traoré  15         3       87
# 8                   Adam Armstrong  15         4        9
# 9                     Adam Forshaw  15         3       90
# 10                       Adam Idah  15         4       68
# 11                    Adam Lallana  15         3        0
# 12                     Adam Masina  15         2        0
# 13                    Adam Webster  15         2        0
# 14          Adedapo Awokoya-Mebude  15         4        0
# 15                 Ademola Lookman  15         3       64
# 16  Adrián San Miguel del Castillo  15         1        0
# 17          Ainsley Maitland-Niles  15         3        0
# 18            Albert Sambi Lokonga  15         3        0
# 19             Alex Nicolao Telles  15         2       90
# 20             Alexandre Lacazette  15         4       84
# 21             Alexis Mac Allister  15         3        0
# 22                      Alex Iwobi  15         3        3
# 23                       Alex Kral  15         3        0
# 2                     0.319991                             0.540439     False
# 3                     1.240984                             0.944227     False
# 4                     0.909762                             1.207069      True
# 5                     2.006827                             0.549359      True
# 6                     0.944227                             1.240984      True
# 7                     0.845896                             1.908275      True
# 8                     0.562572                             0.565986      True
# 9                     0.569730                             0.440346      True
# 10                    0.410615                             1.535539     False
# 11                    0.565986                             0.562572     False
# 12                    0.320432                             2.378462      True
# 13                    0.565986                             0.562572     False
# 14                    0.320432                             2.378462      True
# 15                    1.207069                             0.909762     False
# 16                    1.908275                             0.845896     False
# 17                    1.240984                             0.944227     False
# 18                    1.240984                             0.944227     False
# 19                    2.006827                             0.549359      True
# 20                    1.240984                             0.944227     False
# 21                    0.565986                             0.562572     False
# 22                    0.944227                             1.240984      True
# 23                    0.780157                             1.963332      True
# 24                    0.562572                             0.565986      True
# 25                    1.908275                             0.845896     False
# 26                    0.565986                             0.562572     False
# 27                    1.908275                             0.845896     False
# 28                    0.944227                             1.240984      True
# 29                    0.540439                             0.319991      True
# 30                    0.780157                             1.963332      True
# 31                    2.006827                             0.549359      True
# 32                    0.565986                             0.562572     False
# 33                    1.963332                             0.780157     False
# 34                    2.006827                             0.549359      True
# 35                    0.845896                             1.908275      True
# 36                    0.410615                             1.535539     False
# 37                    1.908275                             0.845896     False
# 38                    0.320432                             2.378462      True
# 39                    0.780157                             1.963332      True
# 40                    0.944227                             1.240984      True
# 41                    0.944227                             1.240984      True
# 42                    0.944227                             1.240984      True
# 43                    0.780157                             1.963332      True
# 44                    0.410615                             1.535539     False
# 45                    2.006827                             0.549359      True
# 46                    0.944227                             1.240984      True
# 47                    2.006827                             0.549359      True
# 48                    1.963332                             0.780157     False
# 49                    0.909762                             1.207069      True
#
#     total_points  ...  selected  team_a_score  team_h_score  threat  \
# 0              1  ...      9181             1             1    10.0
# 1              0  ...    924326             2             3     0.0
# 2              0  ...      1368             0             1     0.0
# 3              2  ...   1222798             1             2     0.0
# 4              0  ...     15819             1             2     0.0
# 5              0  ...    338785             0             1     0.0
# 6              2  ...    140254             1             2    21.0
# 7              3  ...    131362             1             0     4.0
# 8              1  ...    350063             1             1     0.0
# 9              2  ...      2924             2             2     2.0
# 10             2  ...     38204             0             3     4.0
# 11             0  ...     16783             1             1     0.0
# 12             0  ...      5965             3             1     0.0
# 13             0  ...     15538             1             1     0.0
# 14             0  ...      7486             3             1     0.0
# 15             2  ...      8788             1             2     6.0
# 16             0  ...     17718             1             0     0.0
# 17             0  ...      5052             1             2     0.0
# 18             0  ...     15088             1             2     0.0
# 19             6  ...     22009             0             1     4.0
# 20             2  ...     93739             1             2     2.0
# 21             0  ...     31502             1             1     0.0
# 22             1  ...     15099             1             2    17.0
# 23             0  ...     13273             2             3     0.0
# 24             3  ...    438635             1             1     0.0
# 25             1  ...     12973             1             0     2.0
# 26             0  ...       108             1             1     0.0
# 27             6  ...    669681             1             0     0.0
# 28             2  ...    474857             1             2     0.0
# 29             2  ...   1556602             0             1    47.0
# 30             0  ...     62105             2             3     0.0
# 31             0  ...        44             0             1     0.0
# 32             0  ...     27217             1             1     0.0
# 20  2021-12-06T20:00:00Z    2122
# 21  2021-12-04T15:00:00Z    2122
# 22  2021-12-06T20:00:00Z    2122
# 23  2021-12-04T12:30:00Z    2122
# 24  2021-12-04T15:00:00Z    2122
# 25  2021-12-04T15:00:00Z    2122
# 26  2021-12-04T15:00:00Z    2122
# 27  2021-12-04T15:00:00Z    2122
# 28  2021-12-06T20:00:00Z    2122
# 29  2021-12-04T15:00:00Z    2122
# 30  2021-12-04T12:30:00Z    2122
# 31  2021-12-05T14:00:00Z    2122
# 32  2021-12-04T15:00:00Z    2122
# 33  2021-12-04T12:30:00Z    2122
# 34  2021-12-05T14:00:00Z    2122
# 35  2021-12-04T15:00:00Z    2122
# 36  2021-12-05T14:00:00Z    2122
# 37  2021-12-04T15:00:00Z    2122
# 38  2021-12-04T17:30:00Z    2122
# 39  2021-12-04T12:30:00Z    2122
# 40  2021-12-06T20:00:00Z    2122
# 41  2021-12-06T20:00:00Z    2122
# 42  2021-12-06T20:00:00Z    2122
# 43  2021-12-04T12:30:00Z    2122
# 44  2021-12-05T14:00:00Z    2122
# 45  2021-12-05T14:00:00Z    2122
# 46  2021-12-06T20:00:00Z    2122
# 47  2021-12-05T14:00:00Z    2122
# 48  2021-12-04T12:30:00Z    2122
# 49  2021-12-05T16:30:00Z    2122
#
# [50 rows x 34 columns]

# %%
df_latest.shape
# Out:
# (640, 34)

# %%
last_play_proba = remaining_season[remaining_season['gw'] == last_gw][['player', 'team', 'play_proba']]

# %%
last_play_proba.head()
# Out:
#              player             team  play_proba
# 0        Kurt Zouma  West Ham United         1.0
# 1        Mark Noble  West Ham United         1.0
# 2   Darren Randolph  West Ham United         1.0
# 3  Lukasz Fabianski  West Ham United         1.0
# 4    Angelo Ogbonna  West Ham United         0.0

# %%
# add latest week's play_proba for each player
df_latest = df_latest.merge(last_play_proba, on=['player', 'team'], how='left')

# %%
df_latest.drop_duplicates(inplace=True)

# %%
df_train.drop_duplicates(inplace=True)

# %%
if last_gw==1:
    df_latest['relative_market_value_team_season'] = df_latest['relative_market_value_team']
    df_latest['relative_market_value_opponent_team_season'] = df_latest['relative_market_value_opponent_team']

# %%
# for when you're doing the season value properly
# relative_market_value_season = train_df[train_df['season'] == '2021'][['team', 'relative_market_value_team']].groupby(['team']).first()
# relative_market_value_season = relative_market_value_season.rename(columns={'relative_market_value_team': 'season_value'})
# relative_market_value_season

# %%
# now get futher stats from fbref
# standard stats
features = ['squad', 'comp', 'round', 'shots_total', 'shots_on_target', 'touches', 'pressures',
            'tackles', 'interceptions', 'blocks', 'xg', 'npxg', 'xa', 'sca', 
            'gca', 'passes_completed', 'passes', 'passes_pct',  'carries', 
            'dribbles_completed', 'dribbles']

# %%
# url for the premier league
url_base = 'https://fbref.com'
pl_history_page = '/en/comps/9/history/Premier-League-Seasons'
url = url_base + pl_history_page

# scrape the history table to get latest season
pl_history_table = get_table(url)
pl_history_urls = get_urls(['season'], 'season', pl_history_table, url_base)
season_urls = pl_history_urls[0:1]

df_enhanced = get_stats(features, season_urls, url_base)
# Out:
# 2021-2022
# https://fbref.com/en/comps/9/Premier-League-Stats
# Manchester City
# https://fbref.com/en/squads/b8fd03ef/Manchester-City-St
://fbref.com/en/squads/b2b47a98/Newcastle-United-Stats
# Allan Saint-Maximin
# Matt Ritchie
# Jamaal Lascelles
# Callum Wilson
# Joe Willock
# Ciaran Clark
# Isaac Hayden
# Joelinton
# Miguel Almirón
# Javier Manquillo
# Sean Longstaff
# Karl Darlow
# Jonjo Shelvey
# Fabian Schär
# Jacob Murphy
# Federico Fernández
# Emil Krafth
# Freddie Woodman
# Ryan Fraser
# Martin Dúbravka
# Jamal Lewis
# Jeff Hendrick
# Dwight Gayle
# Norwich City
# https://fbref.com/en/squads/1c781004/Norwich-City-Stats
# Max Aarons
# Tim Krul
# Teemu Pukki
# Grant Hanley
# Kenny McLean
# Ben Gibson
# Pierre Lees-Melou
# Brandon Williams
# Mathias Normann
# Milot Rashica
# Josh Sargent
# Billy Gilmour
# Ozan Kabak
# Dimitris Giannoulis
# Lukas Rupp
# Andrew Omobamidele
# Todd Cantwell
# Kieran Dowell
# Christos Tzolis
# Adam Idah
# Bali Mumba
# Jakob Sørensen
# Przemysław Płacheta

# %%
# get the player name matching dictionary
with open(path/'match_list.json') as f:
  match_list = json.load(f)

match_list
# Out:
# {'Fabinho': 'Fabio Henrique Tavares',
#  'Alisson': 'Alisson Ramses Becker',
#  'Joël Matip': 'Joel Matip',
#  'Joe Gomez': 'Joseph Gomez',
#  'Naby Keïta': 'Naby Keita',
#  'Adrián': 'Adrián San Miguel del Castillo',
#  'Thiago Alcántara': 'Thiago Alcántara do Nascimento',
#  'Allan': 'Allan Marques Loureiro',
#  'Richarlison': 'Richarlison de Andrade',
#  'Gylfi Sigurðsson': 'Gylfi Sigurdsson',
#  'Séamus Coleman': 'Seamus Coleman',
#  'André Gomes': 'André Filipe Tavares Gomes',
#  'Bernard': 'Bernard Anício Caldeira Duarte',
#  'Çağlar Söyüncü': 'Çaglar Söyüncü',
#  'Bruno Fernandes': 'Bruno Miguel Borges Fernandes',
#  'Fred': 'Frederico Rodrigues de Paula Santos',
#  'Nemanja Matić': 'Nemanja Matic',
#  'Alex Telles': 'Alex Nicolao Telles',
#  'Pierre Højbjerg': 'Pierre-Emile Højbjerg',
#  'Son Heung-min': 'Heung-Min Son',
#  'Lucas Moura': 'Lucas Rodrigues Moura da Silva',
#  'Érik Lamela': 'Erik Lamela',
#  'Dele Alli': 'Bamidele Alli',
#  'Carlos Vinícius': 'Carlos Vinicius Alves Morais',
#  'Ederson': 'Ederson Santana de Moraes',
#  'Rodri': 'Rodrigo Hernandez',
#  'Rúben Dias': 'Rúben Santos Gato Alves Dias',
#  'João Cancelo': 'João Pedro Cavaco Cancelo',
#  'İlkay Gündoğan': 'Ilkay Gündogan',
#  'Gabriel Jesus': 'Gabriel Fernando de Jesus',
#  'Ferrán Torres': 'Ferran Torres',
#  'Bernardo Silva': 'Bernardo Mota Veiga de Carvalho e Silva',
#  'Fernandinho': 'Fernando Luiz Rosa',
#  'Eric García': 'Eric Garcia',
#  'Matty Cash': 'Matthew Cash',
#  'Douglas Luiz': 'Douglas Luiz Soares de Paulo',
#  'Ezri Konsa': 'Ezri Konsa Ngoyo',
#  'Trézéguet': 'Mahmoud Ahmed Ibrahim Hassan',
#  'Ben Chilwell': 'Benjamin Chilwell',
#  'Thiago Silva': 'Thiago Emiliano da Silva',
#  'Mateo Kovačić': 'Mateo Kovacic',
#  'Jorginho': 'Jorge Luiz Frello Filho',
#  'Emerson Palmieri': 'Emerson Palmieri dos Santos',
#  'Oriol Romeu': 'Oriol Romeu Vidal',
#  'Dan Nlundulu': "Daniel N'Lundulu",
#  'Łukasz Fabiański': 'Lukasz Fabianski',
#  'Tomáš Souček': 'Tomas Soucek',
#  'Vladimír Coufal': 'Vladimir Coufal',
#  'Felipe Anderson': 'Felipe Anderson Pereira Gomes',
#  'Rui Patrício': 'Rui Pedro dos Santos Patrício',
#  'Pedro Neto': 'Pedro Lomba Neto',
#  'Daniel Podence': 'Daniel Castelo Podence',
#  'Nélson Semedo': 'Nélson Cabral Semedo',
#  'Rúben Neves': 'Rúben Diogo da Silva Neves',
#  'João Moutinho': 'João Filipe Iria Santos Moutinho',
#  'Rayan Aït Nouri': 'Rayan Ait Nouri',
#  'Fábio Silva': 'Fabio Silva',
#  'Rúben Vinagre': 'Rúben Gonçalo Silva Nascimento Vinagre',
#  'Vitinha': 'Vitor Ferreira',
#  'Rodrigo': 'Rodrigo Moreno',
#  'Pablo Hernández': 'Pablo Hernández Domínguez',
#  'Ian Carlo Poveda': 'Ian Carlo Poveda-Ocampo',
#  'Joelinton': 'Joelinton Cássio Apolinário de Lira',
#  'Luka Milivojević': 'Luka Milivojevic',
#  'Jaïro Riedewald': 'Jairo Riedewald',
#  'Gabriel Dos Santos': 'Gabriel Magalhães',
#  'Willian': 'Willian Borges Da Silva',
#  'Dani Ceballos': 'Daniel Ceballos Fernández',
#  'David Luiz': 'David Luiz Moreira Marinho',
#  'Eddie Nketiah': 'Edward Nketiah',
#  'Joe Willock': 'Joseph Willock',
#  'Sead Kolašinac': 'Sead Kolasinac',
#  'Martinelli': 'Gabriel Teodoro Martinelli Silva',
#  'Solly March': 'Solomon March',
#  'Bernardo': 'Bernardo Fernandes da Silva Junior',
#  'Jóhann Berg Guðmundsson': 'Johann Berg Gudmundsson',
#  'Matěj Vydra': 'Matej Vydra',
#  'Andre-Frank Zambo Anguissa': 'André-Frank Zambo Anguissa',
#  'Semi Ajayi': 'Oluwasemilogo Adesewo Ibidapo Ajayi',
#  'Branislav Ivanović': 'Branislav Ivanovic',
#  'Filip Krovinović': 'Filip Krovinovic',
#  'Ahmed Hegazi': 'Ahmed El-Sayed Hegazi',
#  'Harvey Elliot': 'Harvey Elliott',
#  'Angeliño': 'Angelo Ogbonna',
#  'Thomas Doyle': 'Tommy Doyle',
#  'Diogo Dalot': 'José Diogo Dalot Teixeira',
#  'Pedro': 'Pedro Rodríguez Ledesma',
#  'Ricardo Pereira': 'Ricardo Domingos Barbosa Pereira',
#  'Gedson Fernandes': 'Gedson Carvalho Fernandes',
#  "Georges-Kévin N'Koudou": 'Georges-Kévin Nkoudou',
#  'Jonny Castro': 'Jonathan Castro Otto',
#  'Jesús Vallejo': 'Jesús Vallejo Lázaro',
#  'Bruno Jordão': 'Bruno André Cavaco Jordao',
#  'Mattéo Guendouzi': 'Matteo Guendouzi',
#  'Richairo Živković': 'Richairo Zivkovic',
#  'Danny Drinkwater': 'Daniel Drinkwater',
#  'Martin Dúbravka': 'Martin Dubravka',
#  'Yoshinori Mutō': 'Yoshinori Muto',
#  'Ki Sung-yueng': 'Sung-yueng Ki',
#  'Roberto': 'Roberto Jimenez Gago',
#  'Javier Hernández': 'Javier Hernández Balcázar',
#  'Frederic Guilbert': 'Frédéric Guilbert',
#  'Björn Engels': 'Bjorn Engels',
#  'Pepe Reina': 'José Reina',
#  'Jota': 'José Ignacio Peleteiro Romallo',
#  'Arnaut Groeneveld': 'Arnaut Danjuma Groeneveld',
#  'Étienne Capoue': 'Etienne Capoue',
#  'Kiko Femenía': 'Francisco Femenía Far',
#  'Ismaila Sarr': 'Ismaila Sarr',
#  'João Pedro': 'João Pedro Junqueira de Jesus',
#  'Max Aarons': 'Max Aarons',
#  'Emi Buendía': 'Emiliano Buendía Stati',
#  'Mario Vrančić': 'Mario Vrancic',
#  'Josip Drmić': 'Josip Drmic',
#  'Ralf Fährmann': 'Ralf Fahrmann',
#  'Danilo': 'Danilo Luiz da Silva',
#  'Petr Čech': 'Petr Cech',
#  'Idrissa Gana Gueye': 'Idrissa Gueye',
#  'Marko Arnautović': 'Marko Arnautovic',
#  'Xande Silva': 'Alexandre Nascimento Costa Silva',
#  'Julián Speroni': 'Julian Speroni',
#  'Kenedy': 'Robert Kenedy Nunes do Nascimento',
#  'Joselu': 'Jose Luis Mato Sanmartín',
#  'Asmir Begović': 'Asmir Begović',
#  'Kayne Ramsey': 'Kayne Ramsay',
#  'Bruno': 'Bruno Saltor Grau',
#  'Junior Hoilett': 'David Junior Hoilett',
#  'Greg Cunningham': 'Greg Cunninghamm',
#  'Jazz Richards': 'Ashley Darel Jazz Richards',
#  'Jean Seri': 'Jean Michael Seri',
#  'Fabricio': 'Fabricio Agosto Ramírez',
#  'Lazar Marković': 'Lazar Markovic',
#  'Mathias Jørgensen': 'Mathias Jorgensen',
#  'Steve Mounié': 'Steve Mounie',
#  'Jon Gorenc Stanković': 'Jon Gorenc Stankovic',
#  'Matty Daly': 'Matthew Daly',
#  'Yaya Touré': 'Gnegneri Yaya Touré',
#  'Brahim Díaz': 'Brahim Diaz',
#  'Zlatan Ibrahimović': 'Zlatan Ibrahimovic',
#  'Marko Grujić': 'Marko Grujic',
#  'Charly Musonda Jr.': 'Charly Musonda',
#  'Nikola Vlašić': 'Nikola Vlasic',
#  'Aleksandar Dragović': 'Aleksandar Dragovic',
#  'Eldin Jakupović': 'Eldin Jakupovic',
#  'Rob Elliot': 'Robert Elliot',
#  'Jesús Gámez': 'Jesús Gámez Duarte',
#  'Massadio Haïdara': 'Massadio Haidara',
#  'Lee Chung-yong': 'Chung-yong Lee',
#  'Freddie Ladapo': 'Olayinka Fredrick Oladotun Ladapo',
#  'João Mário': 'João Mário Naval Costa Eduardo',
#  'José Fonte': 'Jose Fonte',
#  'Younès Kaboul': 'Younes Kaboul',
#  'Izzy Brown': 'Isaiah Brown',
#  'Dušan Tadić': 'Dusan Tadic',
#  'Àngel Rangel': 'Angel Rangel',
#  'Badou Ndiaye': 'Papa Alioune Ndiaye',
#  'Jesé': 'Jesé Rodríguez Ruiz',
#  'Tom Edwards': 'Thomas Edwards',
#  'Kostas Stafylidis': 'Konstantinos Stafylidis',
#  'Lasse Sørensen': 'Lasse Sorenson',
#  'Bojan Krkić': 'Bojan Krkic',
#  'Allan Nyom': 'Allan-Roméo Nyom',
#  'Ahmed Elmohamady': 'Ahmed El Mohamady',
#  'Hélder Costa': 'Hélder Wander Sousa de Azevedo e Costa',
#  'Mohamed Elneny': 'Mohamed Naser El Sayed Elneny',
#  'Emile Smith-Rowe': 'Emile Smith Rowe',
#  'Ivan Cavaleiro': 'Ivan Ricardo Neves Abreu Cavaleiro',
#  'Bobby Reid': 'Bobby Decordova-Reid',
#  'Ahmed El-Sayed Hegazi': 'Ahmed El-Sayed Hegazy',
#  'Kiko Casilla': 'Francisco Casilla Cortés',
#  'Willian José': 'Willian José Da Silva',
#  'Kostas Tsimikas': 'Konstantinos Tsimikas',
#  'Okay Yokuşlu': 'Okay Yokuslu',
#  'Khanya Leshabela': 'Thakgalo Leshabela',
#  'Jaden Philogene Bidace': 'Jaden Philogene-Bidace',
#  'William Thomas Fish': 'William Fish',
#  'David Raya': 'David Raya Martin',
#  'Oghenekaro Etebo': 'Oghenekaro Peter Etebo',
#  'Ismaïla Sarr': 'Ismaila Sarr',
#  'Cucho': 'Juan Camilo Hernández Suárez',
#  'Enoch Mwepu': 'Enock Mwepu',
#  'Emiliano Buendía': 'Emiliano Buendía StatiJosé Malheiro de Sá',
#  'José Sá': 'José Malheiro de Sá',
#  'Francisco Trincão': 'Francisco Machado Mota de Castro Trincão',
#  'Valentino Livramento': 'Tino Livramento',
#  'Nuno Tavares': 'Nuno Varela Tavares',
#  'Jesuran Rak Sakyi': 'Jesurun Rak-Sakyi',
#  'Maximillian Aarons': 'Max Aarons',
#  'Josh Sargent': 'Joshua Sargent',
#  'Junior Firpo': 'Héctor Junior Firpo Adames',
#  'Imran Louza': 'Imrân Louza',
#  'Bryan': 'Bryan Gil Salvatierra',
#  'Kiernan Dewsbury Hall': 'Kiernan Dewsbury-Hall',
#  'Cristiano Ronaldo': 'Cristiano Ronaldo dos Santos Aveiro',
#  'Emerson': 'Emerson Aparecido Leite de Souza Junior',
#  'Mads Roerslev': 'Mads Roerslev Rasmussen',
#  'Odsonne Édouard': 'Odsonne Edouard',
#  'Hwang Hee-chan': 'Hee-Chan Hwang',
#  'Asmir Begovic': 'Asmir Begović',
#  'Caoimhín Kelleher': 'Caoimhin Kelleher',
#  'Lyanco': 'Lyanco Evangelista Silveira Neves Vojnovic',
#  'Przemysław Płacheta': 'Przemyslaw Placheta',
#  'James Mcatee': 'James McAtee'}

# %%
team_list = {}
team_list['Brighton'] = 'Brighton and Hove Albion'
team_list['Leeds United'] = 'Leeds'
team_list['Manchester Utd'] = 'Manchester United'
team_list['Newcastle Utd'] = 'Newcastle United'
team_list['Norwich City'] = 'Norwich'
team_list['Sheffield Utd'] = 'Sheffield United'
team_list['Tottenham'] = 'Tottenham Hotspur'
team_list['West Brom'] = 'West Bromwich Albion'
team_list['West Ham'] = 'West Ham United'
team_list['Wolves'] = 'Wolverhampton Wanderers'

# %%
# replace non-matching names/teams and extract gw as integer
df_enhanced['alt_name'] = df_enhanced['player'].replace(match_list)
df_enhanced['squad'] = df_enhanced['squad'].replace(team_list)
df_enhanced['round'] = df_enhanced['round'].str[-2:].astype('int')

# %%
# remove duplicated (happens when players transferred within season)
df_enhanced = df_enhanced.drop_duplicates()

# %%
df_enhanced
# Out:
#          season               player        date            squad  \
# 0     2021-2022         João Cancelo  2021-08-15  Manchester City
# 1     2021-2022         João Cancelo  2021-08-21  Manchester City
# 2     2021-2022         João Cancelo  2021-08-28  Manchester City
# 3     2021-2022         João Cancelo  2021-09-11  Manchester City
# 4     2021-2022         João Cancelo  2021-09-18  Manchester City
# ...         ...                  ...         ...              ...
# 4130  2021-2022            Adam Idah  2021-11-30          Norwich
# 4131  2021-2022            Adam Idah  2021-12-05          Norwich
# 4132  2021-2022           Bali Mumba  2021-08-21          Norwich
# 4133  2021-2022       Jakob Sørensen  2021-12-05          Norwich
# 4134  2021-2022  Przemysław Płacheta  2021-10-31          Norwich
#
#                 comp  round shots_total shots_on_target touches pressures  \
# 0     Premier League      1           3               0      87         4
# 1     Premier League      2           1               0      90        11
# 2     Premier League      3           1               1     118        11
# 3     Premier League      4           2               0      80        11
# 4     Premier League      5           2               0      95        10
# ...              ...    ...         ...             ...     ...       ...
# 4130  Premier League     14           1               0      10         2
# 4131  Premier League     15           1               0      23        12
# 4132  Premier League      2           0               0      19        12
# 4133  Premier League     15           0               0      10         4
# 4134  Premier League     10           0               0       4         3
#
#       ...   xa sca gca passes_completed passes passes_pct carries  \
# 0     ...  0.6   4   0               61     72       84.7      64
# 1     ...  0.0   1   0               70     82       85.4      65
# 2     ...  0.0   3   1               96    112       85.7      94
# 3     ...  0.1   2   1               58     70       82.9      57
# 4     ...  0.0   1   0               66     81       81.5      70
# ...   ...  ...  ..  ..              ...    ...        ...     ...
# 4130  ...  0.0   0   0                4      6       66.7       8
# 4131  ...  0.2   1   0                9     13       69.2      18
# 4132  ...  0.0   0   0                7     10       70.0       9
# 4133  ...  0.0   0   0                7      9       77.8       9
# 4134  ...  0.0   0   0                2      2      100.0       3
#
#      dribbles_completed dribbles                   alt_name
# 0                     3        5  João Pedro Cavaco Cancelo
# 1                     1        1  João Pedro Cavaco Cancelo
# 2                     2        2  João Pedro Cavaco Cancelo
# 3                     2        2  João Pedro Cavaco Cancelo
# 4                     1        2  João Pedro Cavaco Cancelo
# ...                 ...      ...                        ...
# 4130                  0        0                  Adam Idah
# 4131                  0        0                  Adam Idah
# 4132                  0        1                 Bali Mumba
# 4133                  1        1             Jakob Sørensen
# 4134                  0        0        Przemyslaw Placheta
#
# [4121 rows x 25 columns]

# %%
# create date field in same format as enhanced data
df_latest['date'] = df_latest['kickoff_time'].str[:10]

# %%
# check if any names aren't matching
enhanced_players = df_enhanced[df_enhanced['date'].isin(df_latest['date'].unique())]['alt_name'].unique().tolist()
standard_players = df_latest['player'].unique().tolist()

unmatched_players = [x for x in enhanced_players if x not in standard_players]
unmatched_players
# Out:
# ['Jakob Sørensen']

# %%
# check if any teams aren't matching
enhanced_teams = df_enhanced[df_enhanced['date'].isin(df_latest['date'].unique())]['squad'].unique().tolist()
standard_teams = df_latest['team'].unique().tolist()

unmatched_teams = [x for x in enhanced_teams if x not in standard_teams]
unmatched_teams
# Out:
# []

# %%
# any additional corrections
# match_list['Jakob Sørensen'] = 'Jacob Sørensen'
# match_list['Przemysław Płacheta'] = 'Przemyslaw Placheta'
# match_list['Mads Roerslev'] = 'Mads Roerslev Rasmussen'
# match_list['Odsonne Édouard'] = 'Odsonne Edouard'
# match_list['Hwang Hee-chan'] = 'Hee-Chan Hwang'

# %%
# replace additional non-matching names
# df_enhanced['alt_name'] = df_enhanced['player'].replace(match_list)

# %%
# make sure there are no non matches after update
# enhanced_players =  df_enhanced[df_enhanced['round'] == last_gw]['alt_name'].unique().tolist()
# standard_players = df_latest['player'].unique().tolist()

# unmatched_players = [x for x in enhanced_players if x not in standard_players]
# unmatched_players
# Out:
# []

# %%
# if match list was updated then update the file
# json_file = json.dumps(match_list)
# f = open(path/"match_list.json","w")
# f.write(json_file)
# f.close()

# %%
# check there are no duplicates in the join fields for the enhanced data
assert(len(df_enhanced[df_enhanced.duplicated(subset=['alt_name', 'date'], keep=False)]) == 0)

# %%
df_latest[df_latest.duplicated(subset=['date','player','team'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [player, gw, position, minutes, team, opponent_team, relative_market_value_team, relative_market_value_opponent_team, was_home, total_points, assists, bonus, bps, clean_sheets, creativity, goals_conceded, goals_scored, ict_index, influence, own_goals, penalties_missed, penalties_saved, red_cards, saves, selected, team_a_score, team_h_score, threat, transfers_balance, transfers_in, transfers_out, yellow_cards, kickoff_time, season, play_proba, date]
# Index: []
#
# [0 rows x 36 columns]

# %%
# check there are no duplicates in the join fields for the standard data
assert(len(df_train[df_train.duplicated(subset=['date','player','team'])]) == 0)

# %%
# df_train[df_train.duplicated(subset=['date','player','team'])]

# %%
# join standard and enhanced dataframes
df_latest_further = df_latest.merge(df_enhanced.drop(['player', 'season', 'round'], axis=1), 
                                   left_on=['date', 'player', 'team'], 
                                   right_on=['date', 'alt_name', 'squad'], how='left')

# %%
# drop the alt name field and check the length of the standard
# dataframe has not increased
df_latest_further = df_latest_further.drop(['alt_name'], axis=1)
assert(len(df_latest_further) == len(df_latest_further))

# %%
# add crowds field
df_latest_further['crowds'] = 1

# %%
assert(sum(df_latest_further[df_latest_further['minutes'] > 0]['xg'].isnull()) == 0)

# %%
df_latest_further[df_latest_further['minutes'] > 0][df_latest_further[df_latest_further['minutes'] > 0]['xg'].isnull()]
# Out:
# Empty DataFrame
# Columns: [player, gw, position, minutes, team, opponent_team, relative_market_value_team, relative_market_value_opponent_team, was_home, total_points, assists, bonus, bps, clean_sheets, creativity, goals_conceded, goals_scored, ict_index, influence, own_goals, penalties_missed, penalties_saved, red_cards, saves, selected, team_a_score, team_h_score, threat, transfers_balance, transfers_in, transfers_out, yellow_cards, kickoff_time, season, play_proba, date, squad, comp, shots_total, shots_on_target, touches, pressures, tackles, interceptions, blocks, xg, npxg, xa, sca, gca, passes_completed, passes, passes_pct, carries, dribbles_completed, dribbles, crowds]
# Index: []
#
# [0 rows x 57 columns]

# %%
df_train_new = pd.concat([df_train, df_latest_further], ignore_index=True, axis=0, sort=False)

# %%
df_train_new[df_train_new['player'] == 'Harry Kane'].tail()
# Out:
#             player  gw  position  minutes               team  \
# 120381  Harry Kane  10         4       90  Tottenham Hotspur
# 121004  Harry Kane  11         4       90  Tottenham Hotspur
# 121926  Harry Kane  12         4       90  Tottenham Hotspur
# 122835  Harry Kane  14         4       90  Tottenham Hotspur
# 123471  Harry Kane  15         4       90  Tottenham Hotspur
#
#             opponent_team  relative_market_value_team  \
# 120381  Manchester United                    1.535124
# 121004            Everton                    1.535073
# 121926              Leeds                    1.535073
# 122835          Brentford                    1.535582
# 123471            Norwich                    1.535539
#
#         relative_market_value_opponent_team  was_home  total_points  ...   xa  \
# 120381                             2.007004      True             2  ...  0.0
# 121004                             0.944279     False             2  ...  0.3
# 121926                             0.569761      True             2  ...  0.0
# 122835                             0.440358      True             2  ...  0.5
# 123471                             0.410615      True             2  ...  0.1
#
#         sca  gca  passes_completed  passes  passes_pct  carries  \
# 120381  0.0  0.0              15.0    26.0        57.7     17.0
# 121004  3.0  0.0              26.0    35.0        74.3     32.0
# 121926  2.0  1.0              20.0    24.0        83.3     32.0
# 122835  6.0  1.0              22.0    31.0        71.0     31.0
# 123471    2    1                13      21        61.9       22
#
#         dribbles_completed  dribbles  crowds
# 120381                 0.0       0.0       1
# 121004                 1.0       2.0       1
# 121926                 3.0       6.0       1
# 122835                 2.0       3.0       1
# 123471                   2         4       1
#
# [5 rows x 59 columns]

# %%
df_train_new.tail(7)
# Out:
#                             player  gw  position  minutes  \
# 123883  Yerson Mosquera Valdelamar  15         2        0
# 123884                 Yoane Wissa  15         3       18
# 123885             Youri Tielemans  15         3        0
# 123886               Yves Bissouma  15         3       90
# 123887                Zack Steffen  15         1        0
# 123888            Álvaro Fernández  15         1       90
# 123889              Çaglar Söyüncü  15         2       90
#
#                             team opponent_team  relative_market_value_team  \
# 123883   Wolverhampton Wanderers     Liverpool                    0.845896
# 123884                 Brentford         Leeds                    0.440346
# 123885            Leicester City   Aston Villa                    1.207069
# 123886  Brighton and Hove Albion   Southampton                    0.565986
# 123887           Manchester City       Watford                    2.378462
# 123888                 Brentford         Leeds                    0.440346
# 123889            Leicester City   Aston Villa                    1.207069
#
#         relative_market_value_opponent_team  was_home  total_points  ...   xa  \
# 123883                             1.908275      True             0  ...  NaN
# 123884                             0.569730     False             1  ...  0.0
# 123885                             0.909762     False             0  ...  NaN
# 123886                             0.562572     False             1  ...  0.0
# 123887                             0.320432     False             0  ...  NaN
# 123888                             0.569730     False             2  ...  0.0
# 123889                             0.909762     False             1  ...  0.0
#
#         sca  gca  passes_completed  passes  passes_pct  carries  \
# 123883  NaN  NaN               NaN     NaN         NaN      NaN
# 123884    1    0                 5       9        55.6        7
# 123885  NaN  NaN               NaN     NaN         NaN      NaN
# 123886    3    0                41      47        87.2       41
# 123887  NaN  NaN               NaN     NaN         NaN      NaN
# 123888    0    0                22      34        64.7       19
# 123889    1    0                67      75        89.3       56
#
#         dribbles_completed  dribbles  crowds
# 123883                 NaN       NaN       1
# 123884                   2         2       1
# 123885                 NaN       NaN       1
# 123886                   2         2       1
# 123887                 NaN       NaN       1
# 123888                   0         0       1
# 123889                   0         0       1
#
# [7 rows x 59 columns]

# %%
df_latest_further.shape
# Out:
# (640, 57)

# %%
df_train_new.shape
# Out:
# (123890, 59)

# %%
# save latest training set to csv
# overwrite existing one
df_train_new.to_csv(path/'train_v8.csv')

# %%
# get fixtures
fixtures = pd.read_csv(path/'2021-22/fixtures.csv')
team_dict = teams[['team_2122', 'team']].dropna().set_index('team_2122').to_dict()['team']

fixtures['home_team'] = fixtures['team_h'].replace(team_dict)
fixtures['away_team'] = fixtures['team_a'].replace(team_dict)
fixtures = fixtures[['home_team', 'away_team', 'kickoff_time', 'event']]
fixtures = fixtures.rename(columns={'event':'gw'})


# use these two lines if updating play_proba later in week
# current_gw = last_gw
# df_train_new = pd.read_csv(path/'train_v7.csv', index_col=0, dtype={'season':str,
#                                                                     'comp':str,
#                                                                     'squad':str})

# set starting gameweek (where are we right now in the season)
current_gw = last_gw + 1
fixtures = fixtures[fixtures['gw'] >= current_gw].sort_values(by=['gw'])
fixtures['match_no'] = np.arange(fixtures.shape[0])

# %%
fixtures.head(50)
# Out:
#                     home_team                 away_team          kickoff_time  \
# 152                 Brentford                   Watford  2021-12-10T20:00:00Z
# 153           Manchester City   Wolverhampton Wanderers  2021-12-11T12:30:00Z
# 154                   Arsenal               Southampton  2021-12-11T15:00:00Z
# 155                   Chelsea                     Leeds  2021-12-11T15:00:00Z
# 156                 Liverpool               Aston Villa  2021-12-11T15:00:00Z
# 157                   Norwich         Manchester United  2021-12-11T17:30:00Z
# 158  Brighton and Hove Albion         Tottenham Hotspur  2021-12-12T14:00:00Z
# 159                   Burnley           West Ham United  2021-12-12T14:00:00Z
# 160            Leicester City          Newcastle United  2021-12-12T14:00:00Z
# 161            Crystal Palace                   Everton  2021-12-12T16:30:00Z
# 171                 Liverpool          Newcastle United  2021-12-16T20:00:00Z
# 170                   Chelsea                   Everton  2021-12-16T19:45:00Z
# 169            Leicester City         Tottenham Hotspur  2021-12-16T19:30:00Z
# 168                   Arsenal           West Ham United  2021-12-15T20:00:00Z
# 167            Crystal Palace               Southampton  2021-12-15T19:30:00Z
# 163                   Norwich               Aston Villa  2021-12-14T19:45:00Z
# 165  Brighton and Hove Albion   Wolverhampton Wanderers  2021-12-15T19:30:00Z
# 164           Manchester City                     Leeds  2021-12-14T20:00:00Z
# 162                 Brentford         Manchester United  2021-12-14T19:30:00Z
# 166                   Burnley                   Watford  2021-12-15T19:30:00Z
# 179   Wolverhampton Wanderers                   Chelsea  2021-12-19T14:00:00Z
# 181         Tottenham Hotspur                 Liverpool  2021-12-19T16:30:00Z
# 180          Newcastle United           Manchester City  2021-12-19T14:15:00Z
# 177                     Leeds                   Arsenal  2021-12-18T17:30:00Z
# 178                   Everton            Leicester City  2021-12-19T12:00:00Z
# 175                   Watford            Crystal Palace  2021-12-18T15:00:00Z
# 176           West Ham United                   Norwich  2021-12-18T15:00:00Z
# 174               Southampton                 Brentford  2021-12-18T15:00:00Z
# 173               Aston Villa                   Burnley  2021-12-18T15:00:00Z
# 172         Manchester United  Brighton and Hove Albion  2021-12-18T12:30:00Z
# 190  Brighton and Hove Albion                 Brentford  2021-12-26T20:00:00Z
# 189               Aston Villa                   Chelsea  2021-12-26T17:30:00Z
# 188           West Ham United               Southampton  2021-12-26T15:00:00Z
# 187         Tottenham Hotspur            Crystal Palace  2021-12-26T15:00:00Z
# 191          Newcastle United         Manchester United  2021-12-27T20:00:00Z
# 185           Manchester City            Leicester City  2021-12-26T15:00:00Z
# 184                   Burnley                   Everton  2021-12-26T15:00:00Z
# 183   Wolverhampton Wanderers                   Watford  2021-12-26T12:30:00Z
# 182                 Liverpool                     Leeds  2021-12-26T12:30:00Z
# 186                   Norwich                   Arsenal  2021-12-26T15:00:00Z
# 201         Manchester United                   Burnley  2021-12-30T20:15:00Z
# 200                   Everton          Newcastle United  2021-12-30T19:30:00Z
# 199                 Brentford           Manchester City  2021-12-29T20:15:00Z
# 198                   Chelsea  Brighton and Hove Albion  2021-12-29T19:30:00Z
# 197            Leicester City                 Liverpool  2021-12-28T20:00:00Z
# 196                     Leeds               Aston Villa  2021-12-28T17:30:00Z
# 194               Southampton         Tottenham Hotspur  2021-12-28T15:00:00Z
# 193            Crystal Palace                   Norwich  2021-12-28T15:00:00Z
# 192                   Arsenal   Wolverhampton Wanderers  2021-12-28T12:30:00Z
# 195                   Watford           West Ham United  2021-12-28T15:00:00Z
#
#        gw  match_no
# 152  16.0         0
# 153  16.0         1
# 154  16.0         2
# 155  16.0         3
# 156  16.0         4
# 157  16.0         5
# 158  16.0         6
# 159  16.0         7
# 160  16.0         8
# 161  16.0         9
# 171  17.0        10
# 170  17.0        11
# 169  17.0        12
# 168  17.0        13
# 167  17.0        14
# 163  17.0        15
# 165  17.0        16
# 164  17.0        17
# 162  17.0        18
# 166  17.0        19
# 179  18.0        20
# 181  18.0        21
# 180  18.0        22
# 177  18.0        23
# 178  18.0        24
# 175  18.0        25
# 176  18.0        26
# 174  18.0        27
# 173  18.0        28
# 172  18.0        29
# 190  19.0        30
# 189  19.0        31
# 188  19.0        32
# 187  19.0        33
# 191  19.0        34
# 185  19.0        35
# 184  19.0        36
# 183  19.0        37
# 182  19.0        38
# 186  19.0        39
# 201  20.0        40
# 200  20.0        41
# 199  20.0        42
# 198  20.0        43
# 197  20.0        44
# 196  20.0        45
# 194  20.0        46
# 193  20.0        47
# 192  20.0        48
# 195  20.0        49

# %%
# add universal team codes for home and away teams
fixtures = fixtures.merge(teams, left_on='home_team', right_on='team', how='left')
fixtures = fixtures.merge(teams, left_on='away_team', right_on='team', how='left')
fixtures = fixtures[['gw', 'match_no', 'home_team', 'away_team', 'kickoff_time', 'team_code_x', 'team_code_y']]
fixtures.rename(index=str,
                columns={'team_code_x':'home_team_code',
                         'team_code_y':'away_team_code'},
                inplace=True)

# %%
fixtures.head()
# Out:
#      gw  match_no        home_team                away_team  \
# 0  16.0         0        Brentford                  Watford
# 1  16.0         1  Manchester City  Wolverhampton Wanderers
# 2  16.0         2          Arsenal              Southampton
# 3  16.0         3          Chelsea                    Leeds
# 4  16.0         4        Liverpool              Aston Villa
#
#            kickoff_time  home_team_code  away_team_code
# 0  2021-12-10T20:00:00Z              94              57
# 1  2021-12-11T12:30:00Z              43              39
# 2  2021-12-11T15:00:00Z               3              20
# 3  2021-12-11T15:00:00Z               8               2
# 4  2021-12-11T15:00:00Z              14               7

# %%
# all_players.replace(to_replace='None', value=1, inplace=True)

# %%
all_players[all_players['play_proba_2122'] == '0']
# Out:
#                       full_name play_proba_2122  position_2122  id_2122  \
# 1          Rúnar Alex Rúnarsson               0              1        2
# 2       Willian Borges Da Silva               0              3        3
# 8               Héctor Bellerín               0              2        9
# 10               Sead Kolasinac               0              2       11
# 17               Lucas Torreira               0              3       18
# ..                          ...             ...            ...      ...
# 624               Owen Otasowie               0              3      442
# 626         Andreas Söndergaard               0              1      444
# 628  Yerson Mosquera Valdelamar               0              2      446
# 633             Patrick Cutrone               0              4      523
# 636           Christian Marques               0              2      549
#
#      cost_2122  team_2122 web_name_2122
# 1           40          3     Rúnarsson
# 2           63          3       Willian
# 8           48          3      Bellerín
# 10          43          3     Kolasinac
# 17          45          3      Torreira
# ..         ...        ...           ...
# 624         45         39      Otasowie
# 626         40         39   Söndergaard
# 628         45         39      Mosquera
# 633         50         39       Cutrone
# 636         40         39       Marques
#
# [145 rows x 7 columns]

# %%
# join home team to all players for current season
home_df = fixtures.merge(all_players, 
               left_on='home_team_code', 
               right_on='team_2122', 
               how='left')

# pull out the required fields and rename columns
home_df = home_df[['gw', 'match_no', 'home_team', 'away_team', 'kickoff_time', 
                   'full_name', 'position_2122', 'cost_2122', 'play_proba_2122', 
                   'web_name_2122']]
home_df.rename(index=str, 
               columns={'home_team':'team',
                        'away_team':'opponent_team',
                        'full_name':'player',
                        'position_2122':'position',
                        'cost_2122':'price',
                        'play_proba_2122':'play_proba',
                        'web_name_2122':'short_name'},
              inplace=True)

# add home flag
home_df['was_home'] = True

# %%
# join away team to all players for current season
away_df = fixtures.merge(all_players, 
               left_on='away_team_code', 
               right_on='team_2122', 
               how='left')

# pull out the required fields and rename columns
away_df = away_df[['gw',  'match_no', 'away_team', 'home_team', 'kickoff_time', 
                   'full_name', 'position_2122', 'cost_2122', 'play_proba_2122', 
                   'web_name_2122']]
away_df.rename(index=str, 
               columns={'away_team':'team',
                        'home_team':'opponent_team',
                        'full_name':'player',
                        'position_2122':'position',
                        'cost_2122':'price',
                        'play_proba_2122':'play_proba',
                        'web_name_2122':'short_name'},
              inplace=True)

# add home flag
away_df['was_home'] = False

# %%
# look at away players
away_df.head()
# Out:
#      gw  match_no     team opponent_team          kickoff_time  \
# 0  16.0         0  Watford     Brentford  2021-12-10T20:00:00Z
# 1  16.0         0  Watford     Brentford  2021-12-10T20:00:00Z
# 2  16.0         0  Watford     Brentford  2021-12-10T20:00:00Z
# 3  16.0         0  Watford     Brentford  2021-12-10T20:00:00Z
# 4  16.0         0  Watford     Brentford  2021-12-10T20:00:00Z
#
#            player  position  price play_proba short_name  was_home
# 0  Moussa Sissoko         3     45       None    Sissoko     False
# 1      Ben Foster         1     41          0     Foster     False
# 2      Danny Rose         2     42        100       Rose     False
# 3     Dan Gosling         3     47        100    Gosling     False
# 4  Craig Cathcart         2     43        100   Cathcart     False

# %%
# look at home players
home_df.head()
# Out:
#      gw  match_no       team opponent_team          kickoff_time  \
# 0  16.0         0  Brentford       Watford  2021-12-10T20:00:00Z
# 1  16.0         0  Brentford       Watford  2021-12-10T20:00:00Z
# 2  16.0         0  Brentford       Watford  2021-12-10T20:00:00Z
# 3  16.0         0  Brentford       Watford  2021-12-10T20:00:00Z
# 4  16.0         0  Brentford       Watford  2021-12-10T20:00:00Z
#
#                player  position  price play_proba short_name  was_home
# 0      Pontus Jansson         2     46       None    Jansson      True
# 1  Christian Nørgaard         3     50        100   Nørgaard      True
# 2          Ivan Toney         4     67          0      Toney      True
# 3   Tariqe Fosu-Henry         3     51          0       Fosu      True
# 4   David Raya Martin         1     44          0       Raya      True

# %%
# # calculate average minutes over last 5 gameweeks
# # first get last 5 gameweeks in current season
# recent_mins = df_train_new[(df_train_new['gw'] >= current_gw - 5) & 
#                            (df_train_new['season'] == season_names[0])][['player', 'minutes', 'play_proba']]

# # recent_mins = df_train_new[((df_train_new['gw'] >= 40 - 5) & 
# #                            (df_train_new['season'] == '1920')) | 
# #                            ((df_train_new['gw'] >= 1) & 
# #                            (df_train_new['season'] == '2021'))][['player', 'minutes', 'play_proba']]

# # exclude weeks where the player had an injury designation (i.e. keep where play_proba is 1)
# recent_mins = recent_mins[recent_mins['play_proba'] == 1]

# len(recent_mins)

# # average for each player
# recent_mins = recent_mins.groupby(['player'])['minutes'].mean().to_dict()

# recent_mins

# %%
# concatenate home and away players
remaining_season_df = home_df.append(away_df).reset_index(drop=True)

# add home and away team market values
remaining_season_df = remaining_season_df.merge(teams_mv[teams_mv['season'] == '2122'],
                                                left_on='team', 
                                                right_on='name', 
                                                how='left').drop(['name', 'season'], axis=1)

remaining_season_df = remaining_season_df.merge(teams_mv[teams_mv['season'] == '2122'],
                                                left_on='opponent_team', 
                                                right_on='name', 
                                                how='left').drop(['name', 'season'], axis=1)

remaining_season_df.rename(index=str, 
                           columns={'relative_market_value_x':'relative_market_value_team',
                                    'relative_market_value_y':'relative_market_value_opponent_team'},
                           inplace=True)

# add season name
remaining_season_df['season'] = season_names[0]

# divide cost by 10 for actual cost
remaining_season_df['price'] = remaining_season_df['price']/10

# set availability probability
# 0 = 0% chance, 25 = 25% chance, etc
# 'None' or '100' = 100% chance
remaining_season_df.loc[remaining_season_df['play_proba'] == 'None', 'play_proba'] = 100
remaining_season_df['play_proba'] = remaining_season_df['play_proba'].astype('float') / 100

# cast position to integer
remaining_season_df['position'] = remaining_season_df['position'].astype(int)

# # add minutes based on last five fixtures
# remaining_season_df['minutes'] = remaining_season_df['player'].map(recent_mins)
# remaining_season_df['minutes'].fillna(0, inplace=True)

# # multiply minutes by play probability
# remaining_season_df['minutes'] = remaining_season_df['minutes'] * remaining_season_df['play_proba']

# %%
remaining_season_df.head(50)
# Out:
#       gw  match_no             team            opponent_team  \
# 0   16.0         0        Brentford                  Watford
# 1   16.0         0        Brentford                  Watford
# 2   16.0         0        Brentford                  Watford
# 3   16.0         0        Brentford                  Watford
# 4   16.0         0        Brentford                  Watford
# 5   16.0         0        Brentford                  Watford
# 6   16.0         0        Brentford                  Watford
# 17    4.4        1.00       Zamburek      True                    0.440346
# 18    3.9        0.00     Gunnarsson      True                    0.440346
# 19    5.4        0.00     Dervişoğlu      True                    0.440346
# 20    5.5        1.00         Mbeumo      True                    0.440346
# 21    4.4        1.00       Bidstrup      True                    0.440346
# 22    4.9        1.00         Onyeka      True                    0.440346
# 23    4.4        0.00           Ajer      True                    0.440346
# 24    4.4        1.00       Thompson      True                    0.440346
# 25    4.9        1.00       Baptiste      True                    0.440346
# 26    5.9        1.00          Wissa      True                    0.440346
# 27    4.5        1.00      Fernández      True                    0.440346
# 28    4.0        1.00        Stevens      True                    0.440346
# 29    4.5        0.00          Zanka      True                    0.440346
# 30    4.5        1.00        Maghoma      True                    0.440346
# 31    4.0        1.00            Cox      True                    0.440346
# 32    4.5        1.00       Haygarth      True                    0.440346
# 33    4.5        1.00  Young-Coombes      True                    0.440346
# 34    7.6        1.00       Grealish      True                    2.378462
# 35    5.5        1.00         Walker      True                    2.378462
# 36    7.3        1.00       Gündogan      True                    2.378462
# 37   11.8        1.00      De Bruyne      True                    2.378462
# 38    5.3        1.00         Stones      True                    2.378462
# 39    5.3        0.00          Mendy      True                    2.378462
# 40    8.6        1.00         Mahrez      True                    2.378462
# 41   10.6        1.00       Sterling      True                    2.378462
# 42    6.8        1.00        Cancelo      True                    2.378462
# 43    6.0        1.00        Ederson      True                    2.378462
# 44    4.8        0.75            Aké      True                    2.378462
# 45    5.5        1.00        Laporte      True                    2.378462
# 46    4.5        1.00        Steffen      True                    2.378462
# 47    7.6        1.00       Bernardo      True                    2.378462
# 48    6.0        1.00           Dias      True                    2.378462
# 49    8.7        0.75          Jesus      True                    2.378462
#
#     relative_market_value_opponent_team season
# 0                              0.320432   2122
# 1                              0.320432   2122
# 2                              0.320432   2122
# 3                              0.320432   2122
# 4                              0.320432   2122
# 5                              0.320432   2122
# 6                              0.320432   2122
# 7                              0.320432   2122
# 8                              0.320432   2122
# 9                              0.320432   2122
# 10                             0.320432   2122
# 11                             0.320432   2122
# 12                             0.320432   2122
# 13                             0.320432   2122
# 14                             0.320432   2122
# 15                             0.320432   2122
# 16                             0.320432   2122
# 17                             0.320432   2122
# 18                             0.320432   2122
# 19                             0.320432   2122
# 20                             0.320432   2122
# 21                             0.320432   2122
# 22                             0.320432   2122
# 23                             0.320432   2122
# 24                             0.320432   2122
# 25                             0.320432   2122
# 26                             0.320432   2122
# 27                             0.320432   2122
# 28                             0.320432   2122
# 29                             0.320432   2122
# 30                             0.320432   2122
# 31                             0.320432   2122
# 32                             0.320432   2122
# 33                             0.320432   2122
# 34                             0.845896   2122
# 35                             0.845896   2122
# 36                             0.845896   2122
# 37                             0.845896   2122
# 38                             0.845896   2122
# 39                             0.845896   2122
# 40                             0.845896   2122
# 41                             0.845896   2122
# 42                             0.845896   2122
# 43                             0.845896   2122
# 44                             0.845896   2122
# 45                             0.845896   2122
# 46                             0.845896   2122
# 47                             0.845896   2122
# 48                             0.845896   2122
# 49                             0.845896   2122

# %%
# save latest prediction set to csv
remaining_season_df.to_csv(path/'remaining_season.csv')
