# %%
# import required libriaries
from pathlib import Path
import json

from fpl_predictor.util import *

# %%
# path to data directory
#path = Path('/home/jupyter/fpl-prediction/data')
path = Path('./fpl_predictor/data')

# %%
# read in latest training set
df_train = pd.read_csv(path/'train_v8.csv', index_col=0, 
                       dtype={'season':str,
                              'comp':str,
                              'squad':str})

# path to current season
season_paths = [path/'2021-22']

# name for current season
season_names = ['2122']

# team codes
teams = pd.read_csv(path/'teams.csv')

# latest remaining season dataset, for latest week's play_proba values
remaining_season = pd.read_csv(path/'remaining_season.csv', index_col=0)

# create players dataset
all_players = build_players(path, season_paths, season_names, teams)

# 2019-20 market value
# table was in slightly different position for 2019-20 season
# should check that 2019-20 season values remain the same once season starts
teams_mv = build_season_mv('2122', 11, range(13,33))

# %%
# all_players#[all_players['full_name'] == 'Ben Davies']

# %%
df_train.tail(50)
# Out:
#                                 player  gw  position  minutes  \
# 126056               Tariqe Fosu-Henry  20         3        0
# 126057                   Tariq Lamptey  20         2       65
# 126058                 Taylor Richards  20         3        0
# 126059                     Teemu Pukki  20         4        0
# 126060                    Theo Walcott  20         3        0
# 126061  Thiago Alcántara do Nascimento  20         3        0
# 126062        Thiago Emiliano da Silva  20         2        0
# 126063                   Thierry Small  20         2        0
# 126064           Thomas Dickson-Peters  20         4        0
# 126065                Timothy Castagne  20         2       90
# 126066                     Timo Werner  20         4        0
# 126067                        Tim Krul  20         1        0
# 126068                 Tino Livramento  20         2        0
# 126069                      Tobi Omole  20         2        0
# 126070               Toby Alderweireld  20         2        0
# 126071                   Todd Cantwell  20         3        0
# 126072                    Tomas Soucek  20         3       90
# 126073                     Tommy Doyle  20         3        0
# 126074                   Tom Cleverley  20         3        0
# 126075                      Tom Heaton  20         1        0
# 126076          Trent Alexander-Arnold  20         2       90
# 126077                 Trevoh Chalobah  20         2       45
# 126078                     Troy Deeney  20         4        0
# 126079                    Tyler Morton  20         3        0
# 126080                 Tyrick Mitchell  20         2       90
# 126081                  Vicente Guaita  20         1       90
# 126082                 Victor Lindelöf  20         2        0
# 126083                Vincent Angelini  20         1        0
# 126084                 Virgil van Dijk  20         2       90
# 126085                   Vitaly Janelt  20         3        0
# 126086                 Vladimir Coufal  20         2       90
# 126087           Vontae Daley-Campbell  20         2        0
# 126088                 Wayne Hennessey  20         1       90
# 126089                   Wesley Fofana  20         2        0
# 126090                   Wilfred Ndidi  20         3       90
# 126091                   Wilfried Zaha  20         3        0
# 126092               William Smallbone  20         3        0
# 126093            William Troost-Ekong  20         2        0
# 126094                 Willy Caballero  20         1        0
# 126095                     Will Hughes  20         3       72
# 126096                     Will Norris  20         1        0
# 126097                    Winston Reid  20         2        0
# 126098                 Xherdan Shaqiri  20         3        0
# 126099                      Yan Valery  20         2       90
# 126100                     Yoane Wissa  20         3       68
# 126101                 Youri Tielemans  20         3       34
# 126102                   Yves Bissouma  20         3       90
# 126103                    Zack Steffen  20         1        0
# 126104                Álvaro Fernández  20         1       90
# 126105                  Çaglar Söyüncü  20         2        0
#
#                             team             opponent_team  \
# 126056                 Brentford           Manchester City
# 126092                    0.563202                             1.463462
# 126093                    0.308959                             0.797993
# 126094                    0.563202                             1.463462
# 126095                    0.545912                             0.401897
# 126096                    0.298039                             1.968535
# 126097                    0.797993                             0.308959
# 126098                    1.958866                             1.173500
# 126099                    0.563202                             1.463462
# 126100                    0.481299                             2.366110
# 126101                    1.173500                             1.958866
# 126102                    0.572189                             1.998680
# 126103                    2.366110                             0.481299
# 126104                    0.481299                             2.366110
# 126105                    1.173500                             1.958866
#
#         was_home  total_points  ...   xa  sca  gca  passes_completed  passes  \
# 126056      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 126057     False             2  ...  0.0  2.0  0.0              16.0    21.0
# 126058     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 126059     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 126060      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 126061     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 126062      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 126063      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 126064     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 126065      True             7  ...  0.1  1.0  0.0              29.0    40.0
# 126066      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 126067     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 126068      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 126069     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 126070     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 126071     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 126072     False             9  ...  0.0  1.0  0.0              43.0    54.0
# 126073     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 126074      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 126075      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 126076     False             2  ...  0.2  4.0  0.0              79.0   105.0
# 126077      True             1  ...  0.0  0.0  0.0              13.0    13.0
# 126078      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 126079     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 126080      True             8  ...  0.1  4.0  2.0              45.0    59.0
# 126081      True             6  ...  0.0  0.0  0.0              22.0    23.0
# 126082      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 126083      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 126084     False             2  ...  0.0  1.0  0.0              53.0    65.0
# 126085      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 126086     False             2  ...  0.0  2.0  1.0              38.0    56.0
# 126087      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 126088     False             2  ...  0.1  3.0  0.0              18.0    32.0
# 126089      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 126090      True             3  ...  0.0  1.0  0.0              33.0    38.0
# 126091      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 126092      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 126093      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 126094      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 126095      True             6  ...  0.1  6.0  1.0              22.0    38.0
# 126096     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 126097     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 126098     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 126099      True             2  ...  0.0  0.0  0.0              19.0    26.0
# 126100      True             2  ...  0.0  1.0  0.0               7.0     8.0
# 126101      True             1  ...  0.0  0.0  0.0              16.0    23.0
# 126102     False             1  ...  0.1  3.0  0.0              40.0    46.0
# 126103     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 126104      True             2  ...  0.0  0.0  0.0              21.0    43.0
# 126105      True             0  ...  NaN  NaN  NaN               NaN     NaN
#
#         passes_pct  carries  dribbles_completed  dribbles  crowds
# 126056         NaN      NaN                 NaN       NaN       1
# 126057        76.2     21.0                 1.0       1.0       1
# 126058         NaN      NaN                 NaN       NaN       1
# 126059         NaN      NaN                 NaN       NaN       1
# 126060         NaN      NaN                 NaN       NaN       1
# 126061         NaN      NaN                 NaN       NaN       1
# 126062         NaN      NaN                 NaN       NaN       1
# 126063         NaN      NaN                 NaN       NaN       1
# 126064         NaN      NaN                 NaN       NaN       1
# 126065        72.5     18.0                 0.0       1.0       1
# 126066         NaN      NaN                 NaN       NaN       1
# 126067         NaN      NaN                 NaN       NaN       1
# 126068         NaN      NaN                 NaN       NaN       1
# 126069         NaN      NaN                 NaN       NaN       1
# 126070         NaN      NaN                 NaN       NaN       1
# 126071         NaN      NaN                 NaN       NaN       1
# 126072        79.6     33.0                 0.0       0.0       1
# 126073         NaN      NaN                 NaN       NaN       1
# 126074         NaN      NaN                 NaN       NaN       1
# 126075         NaN      NaN                 NaN       NaN       1
# 126076        75.2     60.0                 0.0       0.0       1
# 126077       100.0      9.0                 0.0       0.0       1
# 126078         NaN      NaN                 NaN       NaN       1
# 126079         NaN      NaN                 NaN       NaN       1
# 126080        76.3     36.0                 0.0       0.0       1
# 126081        95.7     17.0                 0.0       0.0       1
# 126082         NaN      NaN                 NaN       NaN       1
# 126083         NaN      NaN                 NaN       NaN       1
# 126084        81.5     40.0                 0.0       0.0       1
# 126085         NaN      NaN                 NaN       NaN       1
# 126086        67.9     33.0                 1.0       2.0       1
# 126087         NaN      NaN                 NaN       NaN       1
# 126088        56.3     11.0                 0.0       0.0       1
# 126089         NaN      NaN                 NaN       NaN       1
# 126090        86.8     31.0                 0.0       0.0       1
# 126091         NaN      NaN                 NaN       NaN       1
# 126092         NaN      NaN                 NaN       NaN       1
# 126093         NaN      NaN                 NaN       NaN       1
# 126094         NaN      NaN                 NaN       NaN       1
# 126095        57.9     19.0                 0.0       0.0       1
# 126096         NaN      NaN                 NaN       NaN       1
# 126097         NaN      NaN                 NaN       NaN       1
# 126098         NaN      NaN                 NaN       NaN       1
# 126099        73.1     21.0                 0.0       0.0       1
# 126100        87.5      8.0                 0.0       0.0       1
# 126101        69.6     18.0                 1.0       1.0       1
# 126102        87.0     53.0                 2.0       2.0       1
# 126103         NaN      NaN                 NaN       NaN       1
# 126104        48.8     20.0                 0.0       0.0       1
# 126105         NaN      NaN                 NaN       NaN       1
#
# [50 rows x 59 columns]

# %%
# find the latest gameweek
last_gw = df_train['gw'][df_train['season'] == season_names[0]].max()

if np.isnan(last_gw): 
    last_gw = 1 
else: 
    last_gw = last_gw + 1
    
last_gw
# Out:
# 21

# %%
# build training set for latest gameweek
df_latest = build_season(season_paths[0], season_names[0], all_players, teams, teams_mv, [last_gw])

# %%
df_latest.drop_duplicates(inplace=True)

# %%
df_latest.head(50)
# Out:
#                             player  gw  position  minutes  \
# 0                   Aaron Connolly  21         4        0
# 1                  Aaron Cresswell  21         2        0
# 2                  Aaron Cresswell  21         2       90
# 3                     Aaron Lennon  21         3       79
# 4                   Aaron Ramsdale  21         1       90
# 5                     Aaron Ramsey  21         3        0
# 6                Aaron Wan-Bissaka  21         2       83
# 7               Abdoulaye Doucouré  21         3       90
# 8                     Adama Traoré  21         3       24
# 9                   Adam Armstrong  21         4       12
# 10                    Adam Forshaw  21         3       90
# 11                       Adam Idah  21         4       74
# 12                    Adam Lallana  21         3       60
# 13                     Adam Masina  21         2       90
# 14                    Adam Webster  21         2       90
# 15          Adedapo Awokoya-Mebude  21         4        0
# 16  Adrián San Miguel del Castillo  21         1        0
# 17          Ainsley Maitland-Niles  21         3        0
# 18                   Ajibola Alese  21         2        0
# 19                   Ajibola Alese  21         2        0
# 20            Albert Sambi Lokonga  21         3        0
# 21             Alex Nicolao Telles  21         2        0
# 22             Alexandre Lacazette  21         4       70
# 23             Alexis Mac Allister  21         3       90
# 24                      Alex Iwobi  21         3        0
# 25                       Alex Kral  21         3        0
# 26                       Alex Kral  21         3        0
# 27                   Alex McCarthy  21         1        0
# 28         Alex Oxlade-Chamberlain  21         3       21
# 29             Alireza Jahanbakhsh  21         3        0
# 30           Alisson Ramses Becker  21         1        0
# 10                    0.603658                             0.284745      True
# 11                    0.399895                             0.798993     False
# 12                    0.560833                             0.919725     False
# 13                    0.338504                             1.467118      True
# 14                    0.560833                             0.919725     False
# 15                    0.338504                             1.467118      True
# 16                    1.961320                             2.001185     False
# 17                    1.243764                             2.259960      True
# 18                    0.798993                             0.546596     False
# 19                    0.798993                             0.399895      True
# 20                    1.243764                             2.259960      True
# 21                    1.971002                             0.835099      True
# 22                    1.243764                             2.259960      True
# 23                    0.560833                             0.919725     False
# 24                    0.919725                             0.560833      True
# 25                    0.798993                             0.546596     False
# 26                    0.798993                             0.399895      True
# 27                    0.562086                             0.483496      True
# 28                    1.961320                             2.001185     False
# 29                    0.560833                             0.919725     False
# 30                    1.961320                             2.001185     False
# 31                    0.919725                             0.560833      True
# 32                    0.798993                             0.546596     False
# 33                    0.798993                             0.399895      True
# 34                    1.971002                             0.835099      True
# 35                    0.560833                             0.919725     False
# 36                    2.001185                             1.961320      True
# 37                    1.971002                             0.835099      True
# 38                    0.835099                             1.971002     False
# 39                    0.399895                             0.798993     False
# 40                    1.961320                             2.001185     False
# 41                    0.338504                             1.467118      True
# 42                    0.798993                             0.546596     False
# 43                    0.798993                             0.399895      True
# 44                    0.919725                             0.560833      True
# 45                    0.919725                             0.560833      True
# 46                    0.919725                             0.560833      True
# 47                    0.798993                             0.546596     False
# 48                    0.798993                             0.399895      True
# 49                    0.399895                             0.798993     False
#
#     total_points  ...  selected  team_a_score  team_h_score  threat  \
# 0              0  ...     10194             3             2     0.0
# 1              0  ...    587753             3             2     0.0
# 2              6  ...    587753             0             2     8.0
# 3              2  ...      2754             1             3     2.0
# 4              1  ...   1555083             2             1     0.0
# 5              0  ...     21409             1             2     0.0
# 6              2  ...    306175             1             0     2.0
# 7              2  ...    177465             3             2    22.0
# 8              1  ...    120629             1             0     2.0
# 9              1  ...    164684             1             4    17.0
# 10             2  ...      3483             1             3     0.0
# 11             2  ...     40422             0             2    35.0
# 12             2  ...     14860             3             2     8.0
# 13             2  ...      5384             1             0     0.0
# 14             0  ...     14140             3             2     0.0
# 15             0  ...      6911             1             0     0.0
# 16             0  ...     16344             2             2     0.0
# 17             0  ...      4763             2             1     0.0
# 18             0  ...      1103             3             2     0.0
# 19             0  ...      1103             0             2     0.0
# 20             0  ...     11396             2             1     0.0
# 21             0  ...     82473             1             0     0.0
# 22             2  ...    371882             2             1    12.0
# 23            15  ...     29183             3             2    34.0
# 24             0  ...     17715             3             2     0.0
# 25             0  ...     11319             3             2     0.0
# 26             0  ...     11319             0             2     0.0
# 27             0  ...    173169             1             4     0.0
# 28             1  ...     13621             2             2     0.0
# 29             0  ...       102             3             2     0.0
# 30             0  ...    662706             2             2     0.0
# 31             5  ...    344443             3             2    11.0
# 32             0  ...     61938             3             2     0.0
# 33             0  ...     61938             0             2     0.0
# 34             0  ...       360             1             0     0.0
# 35             0  ...     24805             3             2     0.0
# 36             0  ...    145565             2             2     0.0
# 37             0  ...       782             1             0     0.0
# 38             0  ...     87524             1             0     0.0
# 39             0  ...    263029             0             2     0.0
# 28  2022-01-02T16:30:00Z    2122
# 29  2022-01-02T14:00:00Z    2122
# 30  2022-01-02T16:30:00Z    2122
# 31  2022-01-02T14:00:00Z    2122
# 32  2022-01-01T17:30:00Z    2122
# 33  2022-01-12T19:45:00Z    2122
# 34  2022-01-03T17:30:00Z    2122
# 35  2022-01-02T14:00:00Z    2122
# 36  2022-01-02T16:30:00Z    2122
# 37  2022-01-03T17:30:00Z    2122
# 38  2022-01-03T17:30:00Z    2122
# 39  2022-01-12T19:45:00Z    2122
# 40  2022-01-02T16:30:00Z    2122
# 41  2022-01-01T15:00:00Z    2122
# 42  2022-01-01T17:30:00Z    2122
# 43  2022-01-12T19:45:00Z    2122
# 44  2022-01-02T14:00:00Z    2122
# 45  2022-01-02T14:00:00Z    2122
# 46  2022-01-02T14:00:00Z    2122
# 47  2022-01-01T17:30:00Z    2122
# 48  2022-01-12T19:45:00Z    2122
# 49  2022-01-12T19:45:00Z    2122
#
# [50 rows x 34 columns]

# %%
df_latest.shape
# Out:
# (686, 34)

# %%
last_play_proba = remaining_season[remaining_season['gw'] == last_gw][['player', 'team', 'play_proba']]

# %%
last_play_proba.head()
# Out:
#                       player     team  play_proba
# 0                 Bernd Leno  Arsenal        1.00
# 1       Rúnar Alex Rúnarsson  Arsenal        0.00
# 2    Willian Borges Da Silva  Arsenal        0.00
# 3  Pierre-Emerick Aubameyang  Arsenal        0.00
# 4              Cédric Soares  Arsenal        0.25

# %%
# add latest week's play_proba for each player
df_latest = df_latest.merge(last_play_proba, on=['player', 'team'], how='left')

# %%
df_latest.drop_duplicates(inplace=True)

# %%
df_train.drop_duplicates(inplace=True)

# %%
if last_gw==1:
    df_latest['relative_market_value_team_season'] = df_latest['relative_market_value_team']
    df_latest['relative_market_value_opponent_team_season'] = df_latest['relative_market_value_opponent_team']

# %%
# for when you're doing the season value properly
# relative_market_value_season = train_df[train_df['season'] == '2021'][['team', 'relative_market_value_team']].groupby(['team']).first()
# relative_market_value_season = relative_market_value_season.rename(columns={'relative_market_value_team': 'season_value'})
# relative_market_value_season

# %%
# now get futher stats from fbref
# standard stats
features = ['squad', 'comp', 'round', 'shots_total', 'shots_on_target', 'touches', 'pressures',
            'tackles', 'interceptions', 'blocks', 'xg', 'npxg', 'xa', 'sca', 
            'gca', 'passes_completed', 'passes', 'passes_pct',  'carries', 
            'dribbles_completed', 'dribbles']

# %%
# url for the premier league
url_base = 'https://fbref.com'
pl_history_page = '/en/comps/9/history/Premier-League-Seasons'
url = url_base + pl_history_page

# scrape the history table to get latest season
pl_history_table = get_table(url)
pl_history_urls = get_urls(['season'], 'season', pl_history_table, url_base)
season_urls = pl_history_urls[0:1]

df_enhanced = get_stats(features, season_urls, url_base)
# Out:
# 2021-2022
# https://fbref.com/en/comps/9/Premier-League-Stats
# Manchester City
# https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats
# Ederson
# João Cancelo
# Bernardo Silva
# Rúben Dias
# Rodri
# Aymeric Laporte
# Gabriel Jesus
# Jack Grealish
# İlkay Gündoğan
# Kyle Walker
# Raheem Sterling
# Kevin De Bruyne
# Phil Foden
# Riyad Mahrez
# Nathan Aké
# Fernandinho
# Oleksandr Zinchenko
# John Stones
# Ferrán Torres
# Cole Palmer
# Zack Steffen
# Benjamin Mendy
# James Mcatee
# Chelsea
# https://fbref.com/en/squads/cff3d9bb/Chelsea-St
://fbref.com/en/squads/b2b47a98/Newcastle-United-Stats
# Allan Saint-Maximin
# Jamaal Lascelles
# Matt Ritchie
# Callum Wilson
# Joelinton
# Joe Willock
# Javier Manquillo
# Isaac Hayden
# Ciaran Clark
# Miguel Almirón
# Sean Longstaff
# Jonjo Shelvey
# Fabian Schär
# Karl Darlow
# Jacob Murphy
# Martin Dúbravka
# Ryan Fraser
# Emil Krafth
# Federico Fernández
# Freddie Woodman
# Jamal Lewis
# Jeff Hendrick
# Dwight Gayle
# Norwich City
# https://fbref.com/en/squads/1c781004/Norwich-City-Stats
# Max Aarons
# Teemu Pukki
# Kenny McLean
# Tim Krul
# Ben Gibson
# Grant Hanley
# Brandon Williams
# Pierre Lees-Melou
# Billy Gilmour
# Josh Sargent
# Milot Rashica
# Ozan Kabak
# Mathias Normann
# Dimitris Giannoulis
# Lukas Rupp
# Todd Cantwell
# Przemysław Płacheta
# Andrew Omobamidele
# Kieran Dowell
# Adam Idah
# Christos Tzolis
# Jakob Sørensen
# Angus Gunn
# Sam Byram
# Bali Mumba
# Jon Rowe

# %%
# get the player name matching dictionary
with open(path/'match_list.json') as f:
  match_list = json.load(f)

match_list
# Out:
# {'Fabinho': 'Fabio Henrique Tavares',
#  'Alisson': 'Alisson Ramses Becker',
#  'Joël Matip': 'Joel Matip',
#  'Joe Gomez': 'Joseph Gomez',
#  'Naby Keïta': 'Naby Keita',
#  'Adrián': 'Adrián San Miguel del Castillo',
#  'Thiago Alcántara': 'Thiago Alcántara do Nascimento',
#  'Allan': 'Allan Marques Loureiro',
#  'Richarlison': 'Richarlison de Andrade',
#  'Gylfi Sigurðsson': 'Gylfi Sigurdsson',
#  'Séamus Coleman': 'Seamus Coleman',
#  'André Gomes': 'André Filipe Tavares Gomes',
#  'Bernard': 'Bernard Anício Caldeira Duarte',
#  'Çağlar Söyüncü': 'Çaglar Söyüncü',
#  'Bruno Fernandes': 'Bruno Miguel Borges Fernandes',
#  'Fred': 'Frederico Rodrigues de Paula Santos',
#  'Nemanja Matić': 'Nemanja Matic',
#  'Alex Telles': 'Alex Nicolao Telles',
#  'Pierre Højbjerg': 'Pierre-Emile Højbjerg',
#  'Son Heung-min': 'Heung-Min Son',
#  'Lucas Moura': 'Lucas Rodrigues Moura da Silva',
#  'Érik Lamela': 'Erik Lamela',
#  'Dele Alli': 'Bamidele Alli',
#  'Carlos Vinícius': 'Carlos Vinicius Alves Morais',
#  'Ederson': 'Ederson Santana de Moraes',
#  'Rodri': 'Rodrigo Hernandez',
#  'Rúben Dias': 'Rúben Santos Gato Alves Dias',
#  'João Cancelo': 'João Pedro Cavaco Cancelo',
#  'İlkay Gündoğan': 'Ilkay Gündogan',
#  'Gabriel Jesus': 'Gabriel Fernando de Jesus',
#  'Ferrán Torres': 'Ferran Torres',
#  'Bernardo Silva': 'Bernardo Mota Veiga de Carvalho e Silva',
#  'Fernandinho': 'Fernando Luiz Rosa',
#  'Eric García': 'Eric Garcia',
#  'Matty Cash': 'Matthew Cash',
#  'Douglas Luiz': 'Douglas Luiz Soares de Paulo',
#  'Ezri Konsa': 'Ezri Konsa Ngoyo',
#  'Trézéguet': 'Mahmoud Ahmed Ibrahim Hassan',
#  'Ben Chilwell': 'Benjamin Chilwell',
#  'Thiago Silva': 'Thiago Emiliano da Silva',
#  'Mateo Kovačić': 'Mateo Kovacic',
#  'Jorginho': 'Jorge Luiz Frello Filho',
#  'Emerson Palmieri': 'Emerson Palmieri dos Santos',
#  'Oriol Romeu': 'Oriol Romeu Vidal',
#  'Dan Nlundulu': "Daniel N'Lundulu",
#  'Łukasz Fabiański': 'Lukasz Fabianski',
#  'Tomáš Souček': 'Tomas Soucek',
#  'Vladimír Coufal': 'Vladimir Coufal',
#  'Felipe Anderson': 'Felipe Anderson Pereira Gomes',
#  'Rui Patrício': 'Rui Pedro dos Santos Patrício',
#  'Pedro Neto': 'Pedro Lomba Neto',
#  'Daniel Podence': 'Daniel Castelo Podence',
#  'Nélson Semedo': 'Nélson Cabral Semedo',
#  'Rúben Neves': 'Rúben Diogo da Silva Neves',
#  'João Moutinho': 'João Filipe Iria Santos Moutinho',
#  'Rayan Aït Nouri': 'Rayan Ait Nouri',
#  'Fábio Silva': 'Fabio Silva',
#  'Rúben Vinagre': 'Rúben Gonçalo Silva Nascimento Vinagre',
#  'Vitinha': 'Vitor Ferreira',
#  'Rodrigo': 'Rodrigo Moreno',
#  'Pablo Hernández': 'Pablo Hernández Domínguez',
#  'Ian Carlo Poveda': 'Ian Carlo Poveda-Ocampo',
#  'Joelinton': 'Joelinton Cássio Apolinário de Lira',
#  'Luka Milivojević': 'Luka Milivojevic',
#  'Jaïro Riedewald': 'Jairo Riedewald',
#  'Gabriel Dos Santos': 'Gabriel Magalhães',
#  'Willian': 'Willian Borges Da Silva',
#  'Dani Ceballos': 'Daniel Ceballos Fernández',
#  'David Luiz': 'David Luiz Moreira Marinho',
#  'Eddie Nketiah': 'Edward Nketiah',
#  'Joe Willock': 'Joseph Willock',
#  'Sead Kolašinac': 'Sead Kolasinac',
#  'Martinelli': 'Gabriel Teodoro Martinelli Silva',
#  'Solly March': 'Solomon March',
#  'Bernardo': 'Bernardo Fernandes da Silva Junior',
#  'Jóhann Berg Guðmundsson': 'Johann Berg Gudmundsson',
#  'Matěj Vydra': 'Matej Vydra',
#  'Andre-Frank Zambo Anguissa': 'André-Frank Zambo Anguissa',
#  'Semi Ajayi': 'Oluwasemilogo Adesewo Ibidapo Ajayi',
#  'Branislav Ivanović': 'Branislav Ivanovic',
#  'Filip Krovinović': 'Filip Krovinovic',
#  'Ahmed Hegazi': 'Ahmed El-Sayed Hegazi',
#  'Harvey Elliot': 'Harvey Elliott',
#  'Angeliño': 'Angelo Ogbonna',
#  'Thomas Doyle': 'Tommy Doyle',
#  'Diogo Dalot': 'José Diogo Dalot Teixeira',
#  'Pedro': 'Pedro Rodríguez Ledesma',
#  'Ricardo Pereira': 'Ricardo Domingos Barbosa Pereira',
#  'Gedson Fernandes': 'Gedson Carvalho Fernandes',
#  "Georges-Kévin N'Koudou": 'Georges-Kévin Nkoudou',
#  'Jonny Castro': 'Jonathan Castro Otto',
#  'Jesús Vallejo': 'Jesús Vallejo Lázaro',
#  'Bruno Jordão': 'Bruno André Cavaco Jordao',
#  'Mattéo Guendouzi': 'Matteo Guendouzi',
#  'Richairo Živković': 'Richairo Zivkovic',
#  'Danny Drinkwater': 'Daniel Drinkwater',
#  'Martin Dúbravka': 'Martin Dubravka',
#  'Yoshinori Mutō': 'Yoshinori Muto',
#  'Ki Sung-yueng': 'Sung-yueng Ki',
#  'Roberto': 'Roberto Jimenez Gago',
#  'Javier Hernández': 'Javier Hernández Balcázar',
#  'Frederic Guilbert': 'Frédéric Guilbert',
#  'Björn Engels': 'Bjorn Engels',
#  'Pepe Reina': 'José Reina',
#  'Jota': 'José Ignacio Peleteiro Romallo',
#  'Arnaut Groeneveld': 'Arnaut Danjuma Groeneveld',
#  'Étienne Capoue': 'Etienne Capoue',
#  'Kiko Femenía': 'Francisco Femenía Far',
#  'Ismaila Sarr': 'Ismaila Sarr',
#  'João Pedro': 'João Pedro Junqueira de Jesus',
#  'Max Aarons': 'Max Aarons',
#  'Emi Buendía': 'Emiliano Buendía Stati',
#  'Mario Vrančić': 'Mario Vrancic',
#  'Josip Drmić': 'Josip Drmic',
#  'Ralf Fährmann': 'Ralf Fahrmann',
#  'Danilo': 'Danilo Luiz da Silva',
#  'Petr Čech': 'Petr Cech',
#  'Idrissa Gana Gueye': 'Idrissa Gueye',
#  'Marko Arnautović': 'Marko Arnautovic',
#  'Xande Silva': 'Alexandre Nascimento Costa Silva',
#  'Julián Speroni': 'Julian Speroni',
#  'Kenedy': 'Robert Kenedy Nunes do Nascimento',
#  'Joselu': 'Jose Luis Mato Sanmartín',
#  'Asmir Begović': 'Asmir Begović',
#  'Kayne Ramsey': 'Kayne Ramsay',
#  'Bruno': 'Bruno Saltor Grau',
#  'Junior Hoilett': 'David Junior Hoilett',
#  'Greg Cunningham': 'Greg Cunninghamm',
#  'Jazz Richards': 'Ashley Darel Jazz Richards',
#  'Jean Seri': 'Jean Michael Seri',
#  'Fabricio': 'Fabricio Agosto Ramírez',
#  'Lazar Marković': 'Lazar Markovic',
#  'Mathias Jørgensen': 'Mathias Jorgensen',
#  'Steve Mounié': 'Steve Mounie',
#  'Jon Gorenc Stanković': 'Jon Gorenc Stankovic',
#  'Matty Daly': 'Matthew Daly',
#  'Yaya Touré': 'Gnegneri Yaya Touré',
#  'Brahim Díaz': 'Brahim Diaz',
#  'Zlatan Ibrahimović': 'Zlatan Ibrahimovic',
#  'Marko Grujić': 'Marko Grujic',
#  'Charly Musonda Jr.': 'Charly Musonda',
#  'Nikola Vlašić': 'Nikola Vlasic',
#  'Aleksandar Dragović': 'Aleksandar Dragovic',
#  'Eldin Jakupović': 'Eldin Jakupovic',
#  'Rob Elliot': 'Robert Elliot',
#  'Jesús Gámez': 'Jesús Gámez Duarte',
#  'Massadio Haïdara': 'Massadio Haidara',
#  'Lee Chung-yong': 'Chung-yong Lee',
#  'Freddie Ladapo': 'Olayinka Fredrick Oladotun Ladapo',
#  'João Mário': 'João Mário Naval Costa Eduardo',
#  'José Fonte': 'Jose Fonte',
#  'Younès Kaboul': 'Younes Kaboul',
#  'Izzy Brown': 'Isaiah Brown',
#  'Dušan Tadić': 'Dusan Tadic',
#  'Àngel Rangel': 'Angel Rangel',
#  'Badou Ndiaye': 'Papa Alioune Ndiaye',
#  'Jesé': 'Jesé Rodríguez Ruiz',
#  'Tom Edwards': 'Thomas Edwards',
#  'Kostas Stafylidis': 'Konstantinos Stafylidis',
#  'Lasse Sørensen': 'Lasse Sorenson',
#  'Bojan Krkić': 'Bojan Krkic',
#  'Allan Nyom': 'Allan-Roméo Nyom',
#  'Ahmed Elmohamady': 'Ahmed El Mohamady',
#  'Hélder Costa': 'Hélder Wander Sousa de Azevedo e Costa',
#  'Mohamed Elneny': 'Mohamed Naser El Sayed Elneny',
#  'Emile Smith-Rowe': 'Emile Smith Rowe',
#  'Ivan Cavaleiro': 'Ivan Ricardo Neves Abreu Cavaleiro',
#  'Bobby Reid': 'Bobby Decordova-Reid',
#  'Ahmed El-Sayed Hegazi': 'Ahmed El-Sayed Hegazy',
#  'Kiko Casilla': 'Francisco Casilla Cortés',
#  'Willian José': 'Willian José Da Silva',
#  'Kostas Tsimikas': 'Konstantinos Tsimikas',
#  'Okay Yokuşlu': 'Okay Yokuslu',
#  'Khanya Leshabela': 'Thakgalo Leshabela',
#  'Jaden Philogene Bidace': 'Jaden Philogene-Bidace',
#  'William Thomas Fish': 'William Fish',
#  'David Raya': 'David Raya Martin',
#  'Oghenekaro Etebo': 'Oghenekaro Peter Etebo',
#  'Ismaïla Sarr': 'Ismaila Sarr',
#  'Cucho': 'Juan Camilo Hernández Suárez',
#  'Enoch Mwepu': 'Enock Mwepu',
#  'Emiliano Buendía': 'Emiliano Buendía StatiJosé Malheiro de Sá',
#  'José Sá': 'José Malheiro de Sá',
#  'Francisco Trincão': 'Francisco Machado Mota de Castro Trincão',
#  'Valentino Livramento': 'Tino Livramento',
#  'Nuno Tavares': 'Nuno Varela Tavares',
#  'Jesuran Rak Sakyi': 'Jesurun Rak-Sakyi',
#  'Maximillian Aarons': 'Max Aarons',
#  'Josh Sargent': 'Joshua Sargent',
#  'Junior Firpo': 'Héctor Junior Firpo Adames',
#  'Imran Louza': 'Imrân Louza',
#  'Bryan': 'Bryan Gil Salvatierra',
#  'Kiernan Dewsbury Hall': 'Kiernan Dewsbury-Hall',
#  'Cristiano Ronaldo': 'Cristiano Ronaldo dos Santos Aveiro',
#  'Emerson': 'Emerson Aparecido Leite de Souza Junior',
#  'Mads Roerslev': 'Mads Roerslev Rasmussen',
#  'Odsonne Édouard': 'Odsonne Edouard',
#  'Hwang Hee-chan': 'Hee-Chan Hwang',
#  'Asmir Begovic': 'Asmir Begović',
#  'Caoimhín Kelleher': 'Caoimhin Kelleher',
#  'Lyanco': 'Lyanco Evangelista Silveira Neves Vojnovic',
#  'Przemysław Płacheta': 'Przemyslaw Placheta',
#  'James Mcatee': 'James McAtee',
#  'Jakob Sørensen': 'Jacob Sørensen',
#  'Alex Král': 'Alex Kral',
#  'Jon Rowe': 'Jonathan Rowe'}

# %%
team_list = {}
team_list['Brighton'] = 'Brighton and Hove Albion'
team_list['Leeds United'] = 'Leeds'
team_list['Manchester Utd'] = 'Manchester United'
team_list['Newcastle Utd'] = 'Newcastle United'
team_list['Norwich City'] = 'Norwich'
team_list['Sheffield Utd'] = 'Sheffield United'
team_list['Tottenham'] = 'Tottenham Hotspur'
team_list['West Brom'] = 'West Bromwich Albion'
team_list['West Ham'] = 'West Ham United'
team_list['Wolves'] = 'Wolverhampton Wanderers'

# %%
# replace non-matching names/teams and extract gw as integer
df_enhanced['alt_name'] = df_enhanced['player'].replace(match_list)
df_enhanced['squad'] = df_enhanced['squad'].replace(team_list)
df_enhanced['round'] = df_enhanced['round'].str[-2:].astype('int')

# %%
# remove duplicated (happens when players transferred within season)
df_enhanced = df_enhanced.drop_duplicates()

# %%
df_enhanced
# Out:
#          season      player        date            squad            comp  \
# 0     2021-2022     Ederson  2021-08-15  Manchester City  Premier League
# 1     2021-2022     Ederson  2021-08-21  Manchester City  Premier League
# 2     2021-2022     Ederson  2021-08-28  Manchester City  Premier League
# 3     2021-2022     Ederson  2021-09-11  Manchester City  Premier League
# 4     2021-2022     Ederson  2021-09-18  Manchester City  Premier League
# ...         ...         ...         ...              ...             ...
# 5349  2021-2022   Sam Byram  2021-12-14          Norwich  Premier League
# 5350  2021-2022   Sam Byram  2021-12-28          Norwich  Premier League
# 5351  2021-2022  Bali Mumba  2021-08-21          Norwich  Premier League
# 5352  2021-2022    Jon Rowe  2021-12-28          Norwich  Premier League
# 5353  2021-2022    Jon Rowe  2022-01-12          Norwich  Premier League
#
#       round shots_total shots_on_target touches pressures  ...   xa sca gca  \
# 0         1           0               0      22         0  ...  0.0   2   0
# 1         2           0               0      14         0  ...  0.0   0   0
# 2         3           0               0      37         0  ...  0.0   0   0
# 3         4           0               0      26         0  ...  0.0   0   0
# 4         5           0               0      40         0  ...  0.0   0   0
# ...     ...         ...             ...     ...       ...  ...  ...  ..  ..
# 5349     17           0               0      25         9  ...  0.0   0   0
# 5350     20           1               0      62        13  ...  0.0   3   0
# 5351      2           0               0      19        12  ...  0.0   0   0
# 5352     20           0               0       9         5  ...  0.1   1   0
# 5353     18           0               0       6         4  ...  0.0   1   0
#
#      passes_completed passes passes_pct carries dribbles_completed dribbles  \
# 0                  20     22       90.9      10                  0        0
# 1                  12     12      100.0       6                  0        0
# 2                  31     37       83.8      25                  0        0
# 3                  22     24       91.7      10                  0        0
# 4                  39     39      100.0      28                  0        0
# ...               ...    ...        ...     ...                ...      ...
# 5349               15     21       71.4      12                  0        0
# 5350               30     43       69.8      32                  0        0
# 5351                7     10       70.0       9                  0        1
# 5352                3      5       60.0       7                  0        1
# 5353                1      2       50.0       3                  1        1
#
#                        alt_name
# 0     Ederson Santana de Moraes
# 1     Ederson Santana de Moraes
# 2     Ederson Santana de Moraes
# 3     Ederson Santana de Moraes
# 4     Ederson Santana de Moraes
# ...                         ...
# 5349                  Sam Byram
# 5350                  Sam Byram
# 5351                 Bali Mumba
# 5352              Jonathan Rowe
# 5353              Jonathan Rowe
#
# [5337 rows x 25 columns]

# %%
# create date field in same format as enhanced data
df_latest['date'] = df_latest['kickoff_time'].str[:10]

# %%
# check if any names aren't matching
enhanced_players = df_enhanced[df_enhanced['date'].isin(df_latest['date'].unique())]['alt_name'].unique().tolist()
standard_players = df_latest['player'].unique().tolist()

unmatched_players = [x for x in enhanced_players if x not in standard_players]
unmatched_players
# Out:
# []

# %%
# check if any teams aren't matching
enhanced_teams = df_enhanced[df_enhanced['date'].isin(df_latest['date'].unique())]['squad'].unique().tolist()
standard_teams = df_latest['team'].unique().tolist()

unmatched_teams = [x for x in enhanced_teams if x not in standard_teams]
unmatched_teams
# Out:
# []

# %%
# any additional corrections
# match_list['Alex Král'] = 'Alex Kral'
# match_list['Jon Rowe'] = 'Jonathan Rowe'
# match_list['Mads Roerslev'] = 'Mads Roerslev Rasmussen'
# match_list['Odsonne Édouard'] = 'Odsonne Edouard'
# match_list['Hwang Hee-chan'] = 'Hee-Chan Hwang'

# %%
# replace additional non-matching names
# df_enhanced['alt_name'] = df_enhanced['player'].replace(match_list)

# %%
# make sure there are no non matches after update
# enhanced_players =  df_enhanced[df_enhanced['round'] == last_gw]['alt_name'].unique().tolist()
# standard_players = df_latest['player'].unique().tolist()

# unmatched_players = [x for x in enhanced_players if x not in standard_players]
# unmatched_players

# %%
# if match list was updated then update the file
# json_file = json.dumps(match_list)
# f = open(path/"match_list.json","w")
# f.write(json_file)
# f.close()

# %%
# check there are no duplicates in the join fields for the enhanced data
assert(len(df_enhanced[df_enhanced.duplicated(subset=['alt_name', 'date'], keep=False)]) == 0)

# %%
df_latest[df_latest.duplicated(subset=['date','player','team'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [player, gw, position, minutes, team, opponent_team, relative_market_value_team, relative_market_value_opponent_team, was_home, total_points, assists, bonus, bps, clean_sheets, creativity, goals_conceded, goals_scored, ict_index, influence, own_goals, penalties_missed, penalties_saved, red_cards, saves, selected, team_a_score, team_h_score, threat, transfers_balance, transfers_in, transfers_out, yellow_cards, kickoff_time, season, play_proba, date]
# Index: []
#
# [0 rows x 36 columns]

# %%
# check there are no duplicates in the join fields for the standard data
assert(len(df_train[df_train.duplicated(subset=['date','player','team'])]) == 0)

# %%
# df_train[df_train.duplicated(subset=['date','player','team'])]

# %%
# join standard and enhanced dataframes
df_latest_further = df_latest.merge(df_enhanced.drop(['player', 'season', 'round'], axis=1), 
                                   left_on=['date', 'player', 'team'], 
                                   right_on=['date', 'alt_name', 'squad'], how='left')

# %%
# drop the alt name field and check the length of the standard
# dataframe has not increased
df_latest_further = df_latest_further.drop(['alt_name'], axis=1)
assert(len(df_latest_further) == len(df_latest_further))

# %%
# add crowds field
df_latest_further['crowds'] = 1

# %%
assert(sum(df_latest_further[df_latest_further['minutes'] > 0]['xg'].isnull()) == 0)

# %%
df_latest_further[df_latest_further['minutes'] > 0][df_latest_further[df_latest_further['minutes'] > 0]['xg'].isnull()]
# Out:
# Empty DataFrame
# Columns: [player, gw, position, minutes, team, opponent_team, relative_market_value_team, relative_market_value_opponent_team, was_home, total_points, assists, bonus, bps, clean_sheets, creativity, goals_conceded, goals_scored, ict_index, influence, own_goals, penalties_missed, penalties_saved, red_cards, saves, selected, team_a_score, team_h_score, threat, transfers_balance, transfers_in, transfers_out, yellow_cards, kickoff_time, season, play_proba, date, squad, comp, shots_total, shots_on_target, touches, pressures, tackles, interceptions, blocks, xg, npxg, xa, sca, gca, passes_completed, passes, passes_pct, carries, dribbles_completed, dribbles, crowds]
# Index: []
#
# [0 rows x 57 columns]

# %%
df_enhanced
# Out:
#          season      player        date            squad            comp  \
# 0     2021-2022     Ederson  2021-08-15  Manchester City  Premier League
# 1     2021-2022     Ederson  2021-08-21  Manchester City  Premier League
# 2     2021-2022     Ederson  2021-08-28  Manchester City  Premier League
# 3     2021-2022     Ederson  2021-09-11  Manchester City  Premier League
# 4     2021-2022     Ederson  2021-09-18  Manchester City  Premier League
# ...         ...         ...         ...              ...             ...
# 5349  2021-2022   Sam Byram  2021-12-14          Norwich  Premier League
# 5350  2021-2022   Sam Byram  2021-12-28          Norwich  Premier League
# 5351  2021-2022  Bali Mumba  2021-08-21          Norwich  Premier League
# 5352  2021-2022    Jon Rowe  2021-12-28          Norwich  Premier League
# 5353  2021-2022    Jon Rowe  2022-01-12          Norwich  Premier League
#
#       round shots_total shots_on_target touches pressures  ...   xa sca gca  \
# 0         1           0               0      22         0  ...  0.0   2   0
# 1         2           0               0      14         0  ...  0.0   0   0
# 2         3           0               0      37         0  ...  0.0   0   0
# 3         4           0               0      26         0  ...  0.0   0   0
# 4         5           0               0      40         0  ...  0.0   0   0
# ...     ...         ...             ...     ...       ...  ...  ...  ..  ..
# 5349     17           0               0      25         9  ...  0.0   0   0
# 5350     20           1               0      62        13  ...  0.0   3   0
# 5351      2           0               0      19        12  ...  0.0   0   0
# 5352     20           0               0       9         5  ...  0.1   1   0
# 5353     18           0               0       6         4  ...  0.0   1   0
#
#      passes_completed passes passes_pct carries dribbles_completed dribbles  \
# 0                  20     22       90.9      10                  0        0
# 1                  12     12      100.0       6                  0        0
# 2                  31     37       83.8      25                  0        0
# 3                  22     24       91.7      10                  0        0
# 4                  39     39      100.0      28                  0        0
# ...               ...    ...        ...     ...                ...      ...
# 5349               15     21       71.4      12                  0        0
# 5350               30     43       69.8      32                  0        0
# 5351                7     10       70.0       9                  0        1
# 5352                3      5       60.0       7                  0        1
# 5353                1      2       50.0       3                  1        1
#
#                        alt_name
# 0     Ederson Santana de Moraes
# 1     Ederson Santana de Moraes
# 2     Ederson Santana de Moraes
# 3     Ederson Santana de Moraes
# 4     Ederson Santana de Moraes
# ...                         ...
# 5349                  Sam Byram
# 5350                  Sam Byram
# 5351                 Bali Mumba
# 5352              Jonathan Rowe
# 5353              Jonathan Rowe
#
# [5337 rows x 25 columns]

# %%
df_train_new = pd.concat([df_train, df_latest_further], ignore_index=True, axis=0, sort=False)

# %%
df_train_new[df_train_new['player'] == 'Harry Kane'].tail()
# Out:
#             player  gw  position  minutes               team   opponent_team  \
# 123471  Harry Kane  15         4       90  Tottenham Hotspur         Norwich
# 125020  Harry Kane  18         4       90  Tottenham Hotspur       Liverpool
# 125561  Harry Kane  19         4       63  Tottenham Hotspur  Crystal Palace
# 125801  Harry Kane  20         4       90  Tottenham Hotspur     Southampton
# 126346  Harry Kane  21         4       90  Tottenham Hotspur         Watford
#
#         relative_market_value_team  relative_market_value_opponent_team  \
# 123471                    1.535539                             0.410615
# 125020                    1.463462                             1.958866
# 125561                    1.463462                             0.545912
# 125801                    1.463462                             0.563202
# 126346                    1.467118                             0.338504
#
#         was_home  total_points  ...   xa  sca  gca  passes_completed  passes  \
# 123471      True             2  ...  0.1  2.0  1.0              13.0    21.0
# 125020      True             6  ...  0.2  2.0  0.0              10.0    18.0
# 125561      True             6  ...  0.0  1.0  1.0              17.0    19.0
# 125801     False             6  ...  0.1  3.0  0.0              17.0    24.0
# 126346     False             2  ...  0.0    3    0                24      33
#
#         passes_pct  carries  dribbles_completed  dribbles  crowds
# 123471        61.9     22.0                 2.0       4.0       1
# 125020        55.6     20.0                 3.0       3.0       1
# 125561        89.5     23.0                 1.0       1.0       1
# 125801        70.8     34.0                 2.0       2.0       1
# 126346        72.7       38                   0         1       1
#
# [5 rows x 59 columns]

# %%
df_train_new.tail(10)
# Out:
#                             player  gw  position  minutes  \
# 126782             Xherdan Shaqiri  21         3        0
# 126783                  Yan Valery  21         2        0
# 126784                  Yerry Mina  21         2        0
# 126785  Yerson Mosquera Valdelamar  21         2        0
# 126786                 Yoane Wissa  21         3       90
# 126787                 Yoane Wissa  21         3       34
# 126788               Yves Bissouma  21         3       90
# 126789                Zack Steffen  21         1        0
# 126790            Álvaro Fernández  21         1       90
# 126791            Álvaro Fernández  21         1       90
#
#                             team             opponent_team  \
# 126782                 Liverpool                   Chelsea
# 126783               Southampton                 Brentford
# 126784                   Everton  Brighton and Hove Albion
# 126785   Wolverhampton Wanderers         Manchester United
# 126786                 Brentford               Aston Villa
# 126787                 Brentford               Southampton
# 126788  Brighton and Hove Albion                   Everton
# 126789           Manchester City                   Arsenal
# 126790                 Brentford               Aston Villa
# 126791                 Brentford               Southampton
#
#         relative_market_value_team  relative_market_value_opponent_team  \
# 126782                    1.961320                             2.001185
# 126783                    0.562086                             0.483496
# 126784                    0.919725                             0.560833
# 126785                    0.835099                             1.971002
# 126786                    0.483496                             1.028042
# 126787                    0.483496                             0.562086
# 126788                    0.560833                             0.919725
# 126789                    2.259960                             1.243764
# 126790                    0.483496                             1.028042
# 126791                    0.483496                             0.562086
#
#         was_home  total_points  ...   xa  sca  gca  passes_completed  passes  \
# 126782     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 126783      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 126784      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 126785     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 126786      True             8  ...  0.0    0    0                11      15
# 126787     False             1  ...  0.0    0    0                 4       6
# 126788     False             2  ...  0.0    1    0                39      47
# 126789     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 126790      True             3  ...  0.0    0    0                24      36
# 126791     False            -1  ...  0.0    0    0                30      43
#
#         passes_pct  carries  dribbles_completed  dribbles  crowds
# 126782         NaN      NaN                 NaN       NaN       1
# 126783         NaN      NaN                 NaN       NaN       1
# 126784         NaN      NaN                 NaN       NaN       1
# 126785         NaN      NaN                 NaN       NaN       1
# 126786        73.3       13                   0         0       1
# 126787        66.7        5                   1         1       1
# 126788        83.0       41                   2         3       1
# 126789         NaN      NaN                 NaN       NaN       1
# 126790        66.7       20                   0         0       1
# 126791        69.8       21                   0         0       1
#
# [10 rows x 59 columns]

# %%
df_latest_further.shape
# Out:
# (686, 57)

# %%
df_train_new.shape
# Out:
# (126792, 59)

# %%
# save latest training set to csv
# overwrite existing one
df_train_new.to_csv(path/'train_v8.csv')

# %%
# get fixtures
fixtures = pd.read_csv(path/'2021-22/fixtures.csv')
team_dict = teams[['team_2122', 'team']].dropna().set_index('team_2122').to_dict()['team']

fixtures['home_team'] = fixtures['team_h'].replace(team_dict)
fixtures['away_team'] = fixtures['team_a'].replace(team_dict)
fixtures = fixtures[['home_team', 'away_team', 'kickoff_time', 'event']]
fixtures = fixtures.rename(columns={'event':'gw'})


# use these two lines if updating play_proba later in week
# current_gw = last_gw
# df_train_new = pd.read_csv(path/'train_v7.csv', index_col=0, dtype={'season':str,
#                                                                     'comp':str,
#                                                                     'squad':str})

# set starting gameweek (where are we right now in the season)
current_gw = last_gw + 1
fixtures = fixtures[fixtures['gw'] >= current_gw].sort_values(by=['gw'])
fixtures['match_no'] = np.arange(fixtures.shape[0])

# %%
fixtures.head(50)
# Out:
#                     home_team                 away_team          kickoff_time  \
# 209  Brighton and Hove Albion            Crystal Palace  2022-01-14T20:00:00Z
# 222                 Brentford         Manchester United  2022-01-19T20:00:00Z
# 221            Leicester City         Tottenham Hotspur  2022-01-19T19:30:00Z
# 220  Brighton and Hove Albion                   Chelsea  2022-01-18T20:00:00Z
# 219                   Burnley                   Watford  2022-01-18T19:30:00Z
# 218         Tottenham Hotspur                   Arsenal  2022-01-16T16:30:00Z
# 216                 Liverpool                 Brentford  2022-01-16T14:00:00Z
# 217           West Ham United                     Leeds  2022-01-16T14:00:00Z
# 214   Wolverhampton Wanderers               Southampton  2022-01-15T15:00:00Z
# 213                   Norwich                   Everton  2022-01-15T15:00:00Z
# 212          Newcastle United                   Watford  2022-01-15T15:00:00Z
# 211                   Burnley            Leicester City  2022-01-15T15:00:00Z
# 210           Manchester City                   Chelsea  2022-01-15T12:30:00Z
# 215               Aston Villa         Manchester United  2022-01-15T17:30:00Z
# 229                   Arsenal                   Burnley  2022-01-23T14:00:00Z
# 231            Leicester City  Brighton and Hove Albion  2022-01-23T14:00:00Z
# 230            Crystal Palace                 Liverpool  2022-01-23T14:00:00Z
# 228               Southampton           Manchester City  2022-01-22T17:30:00Z
# 232                   Chelsea         Tottenham Hotspur  2022-01-23T16:30:00Z
# 226                     Leeds          Newcastle United  2022-01-22T15:00:00Z
# 225                 Brentford   Wolverhampton Wanderers  2022-01-22T15:00:00Z
# 224                   Everton               Aston Villa  2022-01-22T12:30:00Z
# 223                   Watford                   Norwich  2022-01-21T20:00:00Z
# 227         Manchester United           West Ham United  2022-01-22T15:00:00Z
# 240                 Liverpool            Leicester City  2022-02-10T19:45:00Z
# 239               Aston Villa                     Leeds  2022-02-09T20:00:00Z
# 238         Tottenham Hotspur               Southampton  2022-02-09T19:45:00Z
# 237                   Norwich            Crystal Palace  2022-02-09T19:45:00Z
# 241   Wolverhampton Wanderers                   Arsenal  2022-02-10T19:45:00Z
# 235                   Burnley         Manchester United  2022-02-08T20:00:00Z
# 234           West Ham United                   Watford  2022-02-08T19:45:00Z
# 233          Newcastle United                   Everton  2022-02-08T19:45:00Z
# 236           Manchester City                 Brentford  2022-02-09T19:45:00Z
# 250            Leicester City           West Ham United  2022-02-13T16:30:00Z
# 249         Tottenham Hotspur   Wolverhampton Wanderers  2022-02-13T14:00:00Z
# 248          Newcastle United               Aston Villa  2022-02-13T14:00:00Z
# 247                   Burnley                 Liverpool  2022-02-13T14:00:00Z
# 246                   Norwich           Manchester City  2022-02-12T17:30:00Z
# 244                   Everton                     Leeds  2022-02-12T15:00:00Z
# 243                 Brentford            Crystal Palace  2022-02-12T15:00:00Z
# 242         Manchester United               Southampton  2022-02-12T12:30:00Z
# 245                   Watford  Brighton and Hove Albion  2022-02-12T15:00:00Z
# 257               Southampton                   Everton  2022-02-19T15:00:00Z
# 260   Wolverhampton Wanderers            Leicester City  2022-02-20T16:30:00Z
# 259                     Leeds         Manchester United  2022-02-20T14:00:00Z
# 258           Manchester City         Tottenham Hotspur  2022-02-19T17:30:00Z
# 256                 Liverpool                   Norwich  2022-02-19T15:00:00Z
# 251           West Ham United          Newcastle United  2022-02-19T12:30:00Z
# 254  Brighton and Hove Albion                   Burnley  2022-02-19T15:00:00Z
# 252                   Arsenal                 Brentford  2022-02-19T15:00:00Z
#
#        gw  match_no
# 209  22.0         0
# 222  22.0         1
# 221  22.0         2
# 220  22.0         3
# 219  22.0         4
# 218  22.0         5
# 216  22.0         6
# 217  22.0         7
# 214  22.0         8
# 213  22.0         9
# 212  22.0        10
# 211  22.0        11
# 210  22.0        12
# 215  22.0        13
# 229  23.0        14
# 231  23.0        15
# 230  23.0        16
# 228  23.0        17
# 232  23.0        18
# 226  23.0        19
# 225  23.0        20
# 224  23.0        21
# 223  23.0        22
# 227  23.0        23
# 240  24.0        24
# 239  24.0        25
# 238  24.0        26
# 237  24.0        27
# 241  24.0        28
# 235  24.0        29
# 234  24.0        30
# 233  24.0        31
# 236  24.0        32
# 250  25.0        33
# 249  25.0        34
# 248  25.0        35
# 247  25.0        36
# 246  25.0        37
# 244  25.0        38
# 243  25.0        39
# 242  25.0        40
# 245  25.0        41
# 257  26.0        42
# 260  26.0        43
# 259  26.0        44
# 258  26.0        45
# 256  26.0        46
# 251  26.0        47
# 254  26.0        48
# 252  26.0        49

# %%
# add universal team codes for home and away teams
fixtures = fixtures.merge(teams, left_on='home_team', right_on='team', how='left')
fixtures = fixtures.merge(teams, left_on='away_team', right_on='team', how='left')
fixtures = fixtures[['gw', 'match_no', 'home_team', 'away_team', 'kickoff_time', 'team_code_x', 'team_code_y']]
fixtures.rename(index=str,
                columns={'team_code_x':'home_team_code',
                         'team_code_y':'away_team_code'},
                inplace=True)

# %%
fixtures.head()
# Out:
#      gw  match_no                 home_team          away_team  \
# 0  22.0         0  Brighton and Hove Albion     Crystal Palace
# 1  22.0         1                 Brentford  Manchester United
# 2  22.0         2            Leicester City  Tottenham Hotspur
# 3  22.0         3  Brighton and Hove Albion            Chelsea
# 4  22.0         4                   Burnley            Watford
#
#            kickoff_time  home_team_code  away_team_code
# 0  2022-01-14T20:00:00Z              36              31
# 1  2022-01-19T20:00:00Z              94               1
# 2  2022-01-19T19:30:00Z              13               6
# 3  2022-01-18T20:00:00Z              36               8
# 4  2022-01-18T19:30:00Z              90              57

# %%
# all_players.replace(to_replace='None', value=1, inplace=True)

# %%
all_players[all_players['play_proba_2122'] == '0']
# Out:
#                          full_name play_proba_2122  position_2122  id_2122  \
# 1             Rúnar Alex Rúnarsson               0              1        2
# 2          Willian Borges Da Silva               0              3        3
# 3        Pierre-Emerick Aubameyang               0              4        4
# 8                  Héctor Bellerín               0              2        9
# 11   Mohamed Naser El Sayed Elneny               0              3       12
# ..                             ...             ...            ...      ...
# 665                  Owen Otasowie               0              3      442
# 669     Yerson Mosquera Valdelamar               0              2      446
# 674                Patrick Cutrone               0              4      523
# 677              Christian Marques               0              2      549
# 678                 Hee-Chan Hwang               0              4      583
#
#      cost_2122  team_2122 web_name_2122
# 1           40          3     Rúnarsson
# 2           63          3       Willian
# 3           96          3    Aubameyang
# 8           48          3      Bellerín
# 11          44          3        Elneny
# ..         ...        ...           ...
# 665         45         39      Otasowie
# 669         44         39      Mosquera
# 674         50         39       Cutrone
# 677         40         39       Marques
# 678         54         39         Hwang
#
# [181 rows x 7 columns]

# %%
# join home team to all players for current season
home_df = fixtures.merge(all_players, 
               left_on='home_team_code', 
               right_on='team_2122', 
               how='left')

# pull out the required fields and rename columns
home_df = home_df[['gw', 'match_no', 'home_team', 'away_team', 'kickoff_time', 
                   'full_name', 'position_2122', 'cost_2122', 'play_proba_2122', 
                   'web_name_2122']]
home_df.rename(index=str, 
               columns={'home_team':'team',
                        'away_team':'opponent_team',
                        'full_name':'player',
                        'position_2122':'position',
                        'cost_2122':'price',
                        'play_proba_2122':'play_proba',
                        'web_name_2122':'short_name'},
              inplace=True)

# add home flag
home_df['was_home'] = True

# %%
# join away team to all players for current season
away_df = fixtures.merge(all_players, 
               left_on='away_team_code', 
               right_on='team_2122', 
               how='left')

# pull out the required fields and rename columns
away_df = away_df[['gw',  'match_no', 'away_team', 'home_team', 'kickoff_time', 
                   'full_name', 'position_2122', 'cost_2122', 'play_proba_2122', 
                   'web_name_2122']]
away_df.rename(index=str, 
               columns={'away_team':'team',
                        'home_team':'opponent_team',
                        'full_name':'player',
                        'position_2122':'position',
                        'cost_2122':'price',
                        'play_proba_2122':'play_proba',
                        'web_name_2122':'short_name'},
              inplace=True)

# add home flag
away_df['was_home'] = False

# %%
# look at away players
away_df.head()
# Out:
#      gw  match_no            team             opponent_team  \
# 0  22.0         0  Crystal Palace  Brighton and Hove Albion
# 1  22.0         0  Crystal Palace  Brighton and Hove Albion
# 2  22.0         0  Crystal Palace  Brighton and Hove Albion
# 3  22.0         0  Crystal Palace  Brighton and Hove Albion
# 4  22.0         0  Crystal Palace  Brighton and Hove Albion
#
#            kickoff_time             player  position  price play_proba  \
# 0  2022-01-14T20:00:00Z    Conor Gallagher         3     61        100
# 1  2022-01-14T20:00:00Z     Vicente Guaita         1     46       None
# 2  2022-01-14T20:00:00Z      James Tomkins         2     43          0
# 3  2022-01-14T20:00:00Z     James McArthur         3     43          0
# 4  2022-01-14T20:00:00Z  Christian Benteke         4     62       None
#
#   short_name  was_home
# 0  Gallagher     False
# 1     Guaita     False
# 2    Tomkins     False
# 3   McArthur     False
# 4    Benteke     False

# %%
# look at home players
home_df.head()
# Out:
#      gw  match_no                      team   opponent_team  \
# 0  22.0         0  Brighton and Hove Albion  Crystal Palace
# 1  22.0         0  Brighton and Hove Albion  Crystal Palace
# 2  22.0         0  Brighton and Hove Albion  Crystal Palace
# 3  22.0         0  Brighton and Hove Albion  Crystal Palace
# 4  22.0         0  Brighton and Hove Albion  Crystal Palace
#
#            kickoff_time        player  position  price play_proba short_name  \
# 0  2022-01-14T20:00:00Z  Adam Lallana         3     53        100    Lallana
# 1  2022-01-14T20:00:00Z  Jason Steele         1     40       None     Steele
# 2  2022-01-14T20:00:00Z   Pascal Groß         3     57        100       Groß
# 3  2022-01-14T20:00:00Z   Shane Duffy         2     41        100      Duffy
# 4  2022-01-14T20:00:00Z  Davy Pröpper         3     45          0    Pröpper
#
#    was_home
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True

# %%
# # calculate average minutes over last 5 gameweeks
# # first get last 5 gameweeks in current season
# recent_mins = df_train_new[(df_train_new['gw'] >= current_gw - 5) & 
#                            (df_train_new['season'] == season_names[0])][['player', 'minutes', 'play_proba']]

# # recent_mins = df_train_new[((df_train_new['gw'] >= 40 - 5) & 
# #                            (df_train_new['season'] == '1920')) | 
# #                            ((df_train_new['gw'] >= 1) & 
# #                            (df_train_new['season'] == '2021'))][['player', 'minutes', 'play_proba']]

# # exclude weeks where the player had an injury designation (i.e. keep where play_proba is 1)
# recent_mins = recent_mins[recent_mins['play_proba'] == 1]

# len(recent_mins)

# # average for each player
# recent_mins = recent_mins.groupby(['player'])['minutes'].mean().to_dict()

# recent_mins

# %%
# concatenate home and away players
remaining_season_df = home_df.append(away_df).reset_index(drop=True)

# add home and away team market values
remaining_season_df = remaining_season_df.merge(teams_mv[teams_mv['season'] == '2122'],
                                                left_on='team', 
                                                right_on='name', 
                                                how='left').drop(['name', 'season'], axis=1)

remaining_season_df = remaining_season_df.merge(teams_mv[teams_mv['season'] == '2122'],
                                                left_on='opponent_team', 
                                                right_on='name', 
                                                how='left').drop(['name', 'season'], axis=1)

remaining_season_df.rename(index=str, 
                           columns={'relative_market_value_x':'relative_market_value_team',
                                    'relative_market_value_y':'relative_market_value_opponent_team'},
                           inplace=True)

# add season name
remaining_season_df['season'] = season_names[0]

# divide cost by 10 for actual cost
remaining_season_df['price'] = remaining_season_df['price']/10

# set availability probability
# 0 = 0% chance, 25 = 25% chance, etc
# 'None' or '100' = 100% chance
remaining_season_df.loc[remaining_season_df['play_proba'] == 'None', 'play_proba'] = 100
remaining_season_df['play_proba'] = remaining_season_df['play_proba'].astype('float') / 100

# cast position to integer
remaining_season_df['position'] = remaining_season_df['position'].astype(int)

# # add minutes based on last five fixtures
# remaining_season_df['minutes'] = remaining_season_df['player'].map(recent_mins)
# remaining_season_df['minutes'].fillna(0, inplace=True)

# # multiply minutes by play probability
# remaining_season_df['minutes'] = remaining_season_df['minutes'] * remaining_season_df['play_proba']

# %%
remaining_season_df.head(50)
# Out:
#       gw  match_no                      team      opponent_team  \
# 0   22.0         0  Brighton and Hove Albion     Crystal Palace
# 1   22.0         0  Brighton and Hove Albion     Crystal Palace
# 2   22.0         0  Brighton and Hove Albion     Crystal Palace
# 3   22.0         0  Brighton and Hove Albion     Crystal Palace
# 4   22.0         0  Brighton and Hove Albion     Crystal Palace
# 5   22.0         0  Brighton and Hove Albion     Crystal Palace
# 6   22.0         0  Brighton and Hove Albion     Crystal Palace
# 7   22.0         0  Brighton and Hove Albion     Crystal Palace
# 8   22.0         0  Brighton and Hove Albion     Crystal Palace
# 9   22.0         0  Brighton and Hove Albion     Crystal Palace
# 10        1.00        Maupay      True                    0.560833
# 11        1.00      Trossard      True                    0.560833
# 12        0.00          Ryan      True                    0.560833
# 13        0.00   Jahanbakhsh      True                    0.560833
# 14        0.00      Bernardo      True                    0.560833
# 15        1.00       Sánchez      True                    0.560833
# 16        0.00      Bissouma      True                    0.560833
# 17        1.00       Lamptey      True                    0.560833
# 18        0.00      Connolly      True                    0.560833
# 19        1.00        Alzate      True                    0.560833
# 20        1.00  Mac Allister      True                    0.560833
# 21        1.00         Moder      True                    0.560833
# 22        1.00       Welbeck      True                    0.560833
# 23        0.00         Mwepu      True                    0.560833
# 24        1.00      Scherpen      True                    0.560833
# 25        0.00        Andone      True                    0.560833
# 26        0.00        Zeqiri      True                    0.560833
# 27        0.00     Karbownik      True                    0.560833
# 28        0.00      Richards      True                    0.560833
# 29        0.00       Caicedo      True                    0.560833
# 30        1.00       Roberts      True                    0.560833
# 31        1.00     Cucurella      True                    0.560833
# 32        0.00       Locadia      True                    0.560833
# 33        0.00     Sarmiento      True                    0.560833
# 34        1.00         Turns      True                    0.560833
# 35        1.00       Leonard      True                    0.560833
# 36        1.00      Ferguson      True                    0.560833
# 37        1.00       Jansson      True                    0.483496
# 38        1.00      Nørgaard      True                    0.483496
# 39        1.00         Toney      True                    0.483496
# 40        0.00          Fosu      True                    0.483496
# 41        0.00          Raya      True                    0.483496
# 42        0.75         Canós      True                    0.483496
# 43        0.00       Dasilva      True                    0.483496
# 44        0.75         Henry      True                    0.483496
# 45        1.00        Janelt      True                    0.483496
# 46        1.00       Ghoddos      True                    0.483496
# 47        1.00        Jensen      True                    0.483496
# 48        0.00         Goode      True                    0.483496
# 49        1.00         Forss      True                    0.483496
#
#     relative_market_value_opponent_team season
# 0                              0.546596   2122
# 1                              0.546596   2122
# 2                              0.546596   2122
# 3                              0.546596   2122
# 4                              0.546596   2122
# 5                              0.546596   2122
# 6                              0.546596   2122
# 7                              0.546596   2122
# 8                              0.546596   2122
# 9                              0.546596   2122
# 10                             0.546596   2122
# 11                             0.546596   2122
# 12                             0.546596   2122
# 13                             0.546596   2122
# 14                             0.546596   2122
# 15                             0.546596   2122
# 16                             0.546596   2122
# 17                             0.546596   2122
# 18                             0.546596   2122
# 19                             0.546596   2122
# 20                             0.546596   2122
# 21                             0.546596   2122
# 22                             0.546596   2122
# 23                             0.546596   2122
# 24                             0.546596   2122
# 25                             0.546596   2122
# 26                             0.546596   2122
# 27                             0.546596   2122
# 28                             0.546596   2122
# 29                             0.546596   2122
# 30                             0.546596   2122
# 31                             0.546596   2122
# 32                             0.546596   2122
# 33                             0.546596   2122
# 34                             0.546596   2122
# 35                             0.546596   2122
# 36                             0.546596   2122
# 37                             1.971002   2122
# 38                             1.971002   2122
# 39                             1.971002   2122
# 40                             1.971002   2122
# 41                             1.971002   2122
# 42                             1.971002   2122
# 43                             1.971002   2122
# 44                             1.971002   2122
# 45                             1.971002   2122
# 46                             1.971002   2122
# 47                             1.971002   2122
# 48                             1.971002   2122
# 49                             1.971002   2122

# %%
# save latest prediction set to csv
remaining_season_df.to_csv(path/'remaining_season.csv')
