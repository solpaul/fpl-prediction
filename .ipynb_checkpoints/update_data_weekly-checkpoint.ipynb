# %%
# import required libriaries
from pathlib import Path
import json

from fpl_predictor.util import *

# %%
# path to data directory
#path = Path('/home/jupyter/fpl-prediction/data')
path = Path('./fpl_predictor/data')

# %%
# read in latest training set
df_train = pd.read_csv(path/'train_v8.csv', index_col=0, 
                       dtype={'season':str,
                              'comp':str,
                              'squad':str})

# path to current season
season_paths = [path/'2021-22']

# name for current season
season_names = ['2122']

# team codes
teams = pd.read_csv(path/'teams.csv')

# latest remaining season dataset, for latest week's play_proba values
remaining_season = pd.read_csv(path/'remaining_season.csv', index_col=0)

# create players dataset
all_players = build_players(path, season_paths, season_names, teams)

# 2019-20 market value
# table was in slightly different position for 2019-20 season
# should check that 2019-20 season values remain the same once season starts
teams_mv = build_season_mv('2122', 11, range(13,33))

# %%
# all_players#[all_players['full_name'] == 'Ben Davies']

# %%
# df_train = df_train.iloc[:-686]

# %%
# find the latest gameweek
last_gw = df_train['gw'][df_train['season'] == season_names[0]].max()

if np.isnan(last_gw): 
    last_gw = 1 
else: 
    last_gw = last_gw + 1
    
last_gw
# Out:
# 22

# %%
# build training set for latest gameweek
df_latest = build_season(season_paths[0], season_names[0], all_players, teams, teams_mv, [last_gw])

# %%
df_latest.drop_duplicates(inplace=True)

# %%
# df_latest[df_latest['player'] == 'Chris Wood']
# lucas digne
# chris wood

# %%
last_play_proba = remaining_season[remaining_season['gw'] == last_gw][['player', 'team', 'play_proba']]

# %%
last_play_proba.head()
# Out:
#          player                      team  play_proba
# 0  Adam Lallana  Brighton and Hove Albion         1.0
# 1  Jason Steele  Brighton and Hove Albion         1.0
# 2   Pascal Groß  Brighton and Hove Albion         1.0
# 3   Shane Duffy  Brighton and Hove Albion         1.0
# 4  Davy Pröpper  Brighton and Hove Albion         0.0

# %%
# add latest week's play_proba for each player
df_latest = df_latest.merge(last_play_proba, on=['player', 'team'], how='left')

# %%
df_latest.drop_duplicates(inplace=True)

# %%
df_train.drop_duplicates(inplace=True)

# %%
if last_gw==1:
    df_latest['relative_market_value_team_season'] = df_latest['relative_market_value_team']
    df_latest['relative_market_value_opponent_team_season'] = df_latest['relative_market_value_opponent_team']

# %%
# for when you're doing the season value properly
# relative_market_value_season = train_df[train_df['season'] == '2021'][['team', 'relative_market_value_team']].groupby(['team']).first()
# relative_market_value_season = relative_market_value_season.rename(columns={'relative_market_value_team': 'season_value'})
# relative_market_value_season

# %%
# now get futher stats from fbref
# standard stats
features = ['squad', 'comp', 'round', 'shots_total', 'shots_on_target', 'touches', 'pressures',
            'tackles', 'interceptions', 'blocks', 'xg', 'npxg', 'xa', 'sca', 
            'gca', 'passes_completed', 'passes', 'passes_pct',  'carries', 
            'dribbles_completed', 'dribbles']

# %%
# url for the premier league
url_base = 'https://fbref.com'
pl_history_page = '/en/comps/9/history/Premier-League-Seasons'
url = url_base + pl_history_page

# scrape the history table to get latest season
pl_history_table = get_table(url)
pl_history_urls = get_urls(['season'], 'season', pl_history_table, url_base)
season_urls = pl_history_urls[0:1]

df_enhanced = get_stats(features, season_urls, url_base)
# Out:
# 2021-2022
# https://fbref.com/en/comps/9/Premier-League-Stats
# Manchester City
# https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats
# Ederson
# João Cancelo
# Bernardo Silva
# Rúben Dias
# Rodri
# Aymeric Laporte
# Gabriel Jesus
# Jack Grealish
# Kyle Walker
# Raheem Sterling
# İlkay Gündoğan
# Phil Foden
# Kevin De Bruyne
# Riyad Mahrez
# Nathan Aké
# Fernandinho
# Oleksandr Zinchenko
# John Stones
# Ferrán Torres
# Cole Palmer
# Zack Steffen
# Benjamin Mendy
# James Mcatee
# Liverpool
# https://fbref.com/en/squads/822bd0ba/Liverpool-Stats
# Mohamed Salah
# Sadio Mané
# Alisson
# Virgil van Dijk
# Trent Alexander-Arnold
# Jordan Henderson
# Diogo Jota
# Joël Matip
# Andrew Robertson
# Fabinho
# Thiago Alcántara
# Alex Oxlade-Chamberlain
# Ibrahima Konaté
# James Milner
# Kostas Tsimikas
# Naby Keïta
# Roberto Firmino
# Curtis Jones
# Harvey Elliott
# Caoimhín Kelleher
# Tyler Morton
# Takumi Minamino
# Divock Origi
# Joe Gomez
# Kaide Gordon
# Neco Williams
# Chelsea
# https://fbref.com/en/squads/cff3d9bb/Chelsea-Stats
# Antonio Rüdiger
# Edouard Mendy
# Thiago Silva
# Jorginho
# Marcos Alonso
# Mason Mount
# César Azpilicueta
# Reece James
# Kai Havertz
# Mateo Kovačić
# Andreas Christensen
# N'Golo Kanté
# Trevoh Chalobah
# Romelu Lukaku
# Callum Hudson-Odoi
# Christian Pulisic
# Hakim Ziyech
# Ruben Loftus-Cheek
# Timo Werner
# Ben Chilwell
# Kepa Arrizabalaga
# Malang Sarr
# Saúl Ñíguez
# Ross Barkley
# Emerson Palmieri
# West Ham
# https://fbref.com/en/squads/7c21e445/West-Ham-United-Stats
# Łukasz Fabiański
# Declan Rice
# Jarrod Bowen
# Michail Antonio
# Tomáš Souček
# Pablo Fornals
# Saïd Benrahma
# Vladimír Coufal
# Craig Dawson
# Aaron Cresswell
# Kurt Zouma
# Angelo Ogbonna
# Ben Johnson
# Issa Diop
# Manuel Lanzini
# Arthur Masuaku
# Nikola Vlašić
# Mark Noble
# Andriy Yarmolenko
# Harrison Ashby
# Sonny Perkins
# Ryan Fredericks
# Alex Král
# Tottenham
# https://fbref.com/en/squads/361ca564/Tottenham-Hotspur-Stats
# Hugo Lloris
# Pierre Højbjerg
# Eric Dier
# Harry Kane
# Son Heung-min
# Sergio Reguilón
# Lucas Moura
# Oliver Skipp
# Emerson
# Davinson Sánchez
# Ben Davies
# Japhet Tanganga
# Dele Alli
# Cristian Romero
# Tanguy Ndombele
# Harry Winks
# Steven Bergwijn
# Giovani Lo Celso
# Ryan Sessegnon
# Matt Doherty
# Bryan
# Joe Rodon
# Arsenal
# https://fbref.com/en/squads/18bb7c10/Arsenal-Stats
# Ben White
# Bukayo Saka
# Aaron Ramsdale
# Gabriel Dos Santos
# Takehiro Tomiyasu
# Thomas Partey
# Martin Ødegaard
# Kieran Tierney
# Emile Smith Rowe
# Pierre-Emerick Aubameyang
# Alexandre Lacazette
# Granit Xhaka
# Albert Sambi Lokonga
# Martinelli
# Nuno Tavares
# Nicolas Pépé
# Rob Holding
# Bernd Leno
# Ainsley Maitland-Niles
# Cédric Soares
# Pablo Marí
# Calum Chambers
# Mohamed Elneny
# Sead Kolašinac
# Folarin Balogun
# Eddie Nketiah
# Reiss Nelson
# Manchester Utd
# https://fbref.com/en/squads/19538871/Manchester-United-Stats
# David de Gea
# Bruno Fernandes
# Harry Maguire
# Scott McTominay
# Fred
# Cristiano Ronaldo
# Aaron Wan-Bissaka
# Mason Greenwood
# Victor Lindelöf
# Luke Shaw
# Jadon Sancho
# Raphaël Varane
# Nemanja Matić
# Alex Telles
# Paul Pogba
# Marcus Rashford
# Diogo Dalot
# Edinson Cavani
# Eric Bailly
# Anthony Martial
# Anthony Elanga
# Daniel James
# Phil Jones
# Jesse Lingard
# Donny van de Beek
# Wolves
# https://fbref.com/en/squads/8cec06e1/Wolverhampton-Wanderers-Stats
# José Sá
# Max Kilman
# Conor Coady
# João Moutinho
# Romain Saïss
# Nélson Semedo
# Raúl Jiménez
# Rúben Neves
# Francisco Trincão
# Hwang Hee-chan
# Fernando Marçal
# Adama Traoré
# Rayan Aït Nouri
# Leander Dendoncker
# Daniel Podence
# Ki-Jana Hoever
# Toti Gomes
# Fábio Silva
# Morgan Gibbs-White
# Luke Cundle
# Brighton
# https://fbref.com/en/squads/d07537b9/Brighton-and-Hove-Albion-Stats
# Robert Sánchez
# Leandro Trossard
# Marc Cucurella
# Neal Maupay
# Joël Veltman
# Adam Lallana
# Lewis Dunk
# Yves Bissouma
# Jakub Moder
# Shane Duffy
# Pascal Groß
# Dan Burn
# Adam Webster
# Solly March
# Tariq Lamptey
# Alexis Mac Allister
# Enock Mwepu
# Danny Welbeck
# Steven Alzate
# Aaron Connolly
# Jason Steele
# Jeremy Sarmiento
# Taylor Richards
# Jürgen Locadia
# Leicester City
# https://fbref.com/en/squads/a2d435b3/Leicester-City-Stats
# Kasper Schmeichel
# Çağlar Söyüncü
# Jamie Vardy
# James Maddison
# Youri Tielemans
# Wilfred Ndidi
# Harvey Barnes
# Timothy Castagne
# Luke Thomas
# Boubakary Soumaré
# Ademola Lookman
# Daniel Amartey
# Jonny Evans
# Ricardo Pereira
# Kelechi Iheanacho
# Jannik Vestergaard
# Kiernan Dewsbury Hall
# Marc Albrighton
# Ryan Bertrand
# Patson Daka
# Hamza Choudhury
# Ayoze Pérez
# James Justin
# Kasey McAteer
# Crystal Palace
# https://fbref.com/en/squads/47c64c55/Crystal-Palace-Stats
# Tyrick Mitchell
# Marc Guéhi
# Joel Ward
# Vicente Guaita
# Conor Gallagher
# Wilfried Zaha
# Jordan Ayew
# Joachim Andersen
# Cheikhou Kouyaté
# Odsonne Édouard
# Christian Benteke
# James McArthur
# Jeffrey Schlupp
# Luka Milivojević
# James Tomkins
# Will Hughes
# Michael Olise
# Jack Butland
# Jean-Philippe Mateta
# Jaïro Riedewald
# Eberechi Eze
# Nathaniel Clyne
# Jesuran Rak Sakyi
# Nathan Ferguson
# Southampton
# https://fbref.com/en/squads/33c895d4/Southampton-Stats
# Mohammed Salisu
# James Ward-Prowse
# Oriol Romeu
# Valentino Livramento
# Alex McCarthy
# Jan Bednarek
# Nathan Redmond
# Adam Armstrong
# Kyle Walker-Peters
# Che Adams
# Mohamed Elyounoussi
# Armando Broja
# Romain Perraud
# Ibrahima Diallo
# Nathan Tella
# Jack Stephens
# Lyanco
# Moussa Djenepo
# Theo Walcott
# Fraser Forster
# Stuart Armstrong
# Willy Caballero
# Shane Long
# Yan Valery
# William Smallbone
# Aston Villa
# https://fbref.com/en/squads/8602292d/Aston-Villa-Stats
# Matty Cash
# Emiliano Martínez
# Ezri Konsa
# Tyrone Mings
# John McGinn
# Matt Targett
# Ollie Watkins
# Douglas Luiz
# Jacob Ramsey
# Emi Buendía
# Danny Ings
# Marvelous Nakamba
# Ashley Young
# Axel Tuanzebe
# Leon Bailey
# Kortney Hause
# Anwar El Ghazi
# Morgan Sanson
# Bertrand Traoré
# Carney Chukwuemeka
# Lucas Digne
# Jed Steer
# Cameron Archer
# Philippe Coutinho
# Keinan Davis
# Trézéguet
# Jaden Philogene Bidace
# Wesley Moraes
# Brentford
# https://fbref.com/en/squads/cd051869/Brentford-Stats
# Pontus Jansson
# Christian Nørgaard
# Ethan Pinnock
# Ivan Toney
# Bryan Mbeumo
# Sergi Canós
# Rico Henry
# Vitaly Janelt
# Álvaro Fernández
# Frank Onyeka
# Mathias Jensen
# David Raya
# Shandon Baptiste
# Mads Roerslev
# Kristoffer Ajer
# Mathias Jørgensen
# Charlie Goode
# Mads Bech Sørensen
# Yoane Wissa
# Saman Ghoddos
# Dominic Thompson
# Marcus Forss
# Jonas Lössl
# Mads Bidstrup
# Finley Stevens
# Leeds United
# https://fbref.com/en/squads/5bfb9659/Leeds-United-Stats
# Illan Meslier
# Stuart Dallas
# Raphael Dias Belloli
# Liam Cooper
# Jack Harrison
# Diego Llorente
# Daniel James
# Mateusz Klich
# Kalvin Phillips
# Luke Ayling
# Junior Firpo
# Rodrigo
# Pascal Struijk
# Adam Forshaw
# Tyler Roberts
# Jamie Shackleton
# Patrick Bamford
# Robin Koch
# Joe Gelhardt
# Cody Drameh
# Charlie Cresswell
# Crysencio Summerville
# Leo Fuhr Hjelde
# Lewis Bate
# Hélder Costa
# Sam Greenwood
# Liam McCarron
# Stuart McKinstry
# Everton
# https://fbref.com/en/squads/d3fd31cc/Everton-Stats
# Michael Keane
# Jordan Pickford
# Demarai Gray
# Allan
# Ben Godfrey
# Abdoulaye Doucouré
# Séamus Coleman
# Andros Townsend
# Lucas Digne
# Richarlison
# Anthony Gordon
# Salomón Rondón
# Alex Iwobi
# Mason Holgate
# Yerry Mina
# Dominic Calvert-Lewin
# André Gomes
# Fabian Delph
# Jonjoe Kenny
# Tom Davies
# Asmir Begović
# Jarrad Branthwaite
# Vitaliy Mykolenko
# Jean-Philippe Gbamin
# Ellis Simms
# Lewis Dobbin
# Cenk Tosun
# Tyler Onyango
# Moise Kean
# Watford
# https://fbref.com/en/squads/2abfe087/Watford-Stats
# Moussa Sissoko
# Craig Cathcart
# Emmanuel Dennis
# Joshua King
# William Troost-Ekong
# Juraj Kucka
# Ismaila Sarr
# Kiko Femenía
# Adam Masina
# Daniel Bachmann
# Ben Foster
# Tom Cleverley
# Danny Rose
# Cucho
# Imran Louza
# Jeremy Ngakia
# Francisco Sierralta
# João Pedro
# Oghenekaro Etebo
# Ozan Tufan
# Ken Sema
# Christian Kabasele
# Nicolas Nkoulou
# Hassane Kamara
# Edo Kayembe
# Samir Santos
# Ashley Fletcher
# Troy Deeney
# Dan Gosling
# Norwich City
# https://fbref.com/en/squads/1c781004/Norwich-City-Stats
# Max Aarons
# Teemu Pukki
# Tim Krul
# Kenny McLean
# Ben Gibson
# Grant Hanley
# Brandon Williams
# Pierre Lees-Melou
# Billy Gilmour
# Josh Sargent
# Milot Rashica
# Ozan Kabak
# Mathias Normann
# Dimitris Giannoulis
# Lukas Rupp
# Todd Cantwell
# Przemysław Płacheta
# Adam Idah
# Andrew Omobamidele
# Kieran Dowell
# Jakob Sørensen
# Christos Tzolis
# Angus Gunn
# Sam Byram
# Bali Mumba
# Jon Rowe
# Newcastle Utd
# https://fbref.com/en/squads/b2b47a98/Newcastle-United-Stats
# Allan Saint-Maximin
# Jamaal Lascelles
# Matt Ritchie
# Joelinton
# Callum Wilson
# Joe Willock
# Javier Manquillo
# Isaac Hayden
# Ciaran Clark
# Miguel Almirón
# Sean Longstaff
# Jonjo Shelvey
# Fabian Schär
# Karl Darlow
# Martin Dúbravka
# Ryan Fraser
# Jacob Murphy
# Emil Krafth
# Federico Fernández
# Freddie Woodman
# Jamal Lewis
# Paul Dummett
# Kieran Trippier
# Chris Wood
# Jeff Hendrick
# Dwight Gayle
# Burnley
# https://fbref.com/en/squads/943e8050/Burnley-Stats
# Matthew Lowton
# Dwight McNeil
# Chris Wood
# James Tarkowski
# Charlie Taylor
# Nick Pope
# Ashley Westwood
# Josh Brownhill
# Ben Mee
# Jóhann Berg Guðmundsson
# Jack Cork
# Maxwel Cornet
# Nathan Collins
# Ashley Barnes
# Aaron Lennon
# Jay Rodriguez
# Matěj Vydra
# Wayne Hennessey
# Erik Pieters
# Dale Stephens
# Connor Roberts

# %%
# get the player name matching dictionary
with open(path/'match_list.json') as f:
  match_list = json.load(f)

match_list
# Out:
# {'Fabinho': 'Fabio Henrique Tavares',
#  'Alisson': 'Alisson Ramses Becker',
#  'Joël Matip': 'Joel Matip',
#  'Joe Gomez': 'Joseph Gomez',
#  'Naby Keïta': 'Naby Keita',
#  'Adrián': 'Adrián San Miguel del Castillo',
#  'Thiago Alcántara': 'Thiago Alcántara do Nascimento',
#  'Allan': 'Allan Marques Loureiro',
#  'Richarlison': 'Richarlison de Andrade',
#  'Gylfi Sigurðsson': 'Gylfi Sigurdsson',
#  'Séamus Coleman': 'Seamus Coleman',
#  'André Gomes': 'André Filipe Tavares Gomes',
#  'Bernard': 'Bernard Anício Caldeira Duarte',
#  'Çağlar Söyüncü': 'Çaglar Söyüncü',
#  'Bruno Fernandes': 'Bruno Miguel Borges Fernandes',
#  'Fred': 'Frederico Rodrigues de Paula Santos',
#  'Nemanja Matić': 'Nemanja Matic',
#  'Alex Telles': 'Alex Nicolao Telles',
#  'Pierre Højbjerg': 'Pierre-Emile Højbjerg',
#  'Son Heung-min': 'Heung-Min Son',
#  'Lucas Moura': 'Lucas Rodrigues Moura da Silva',
#  'Érik Lamela': 'Erik Lamela',
#  'Dele Alli': 'Bamidele Alli',
#  'Carlos Vinícius': 'Carlos Vinicius Alves Morais',
#  'Ederson': 'Ederson Santana de Moraes',
#  'Rodri': 'Rodrigo Hernandez',
#  'Rúben Dias': 'Rúben Santos Gato Alves Dias',
#  'João Cancelo': 'João Pedro Cavaco Cancelo',
#  'İlkay Gündoğan': 'Ilkay Gündogan',
#  'Gabriel Jesus': 'Gabriel Fernando de Jesus',
#  'Ferrán Torres': 'Ferran Torres',
#  'Bernardo Silva': 'Bernardo Mota Veiga de Carvalho e Silva',
#  'Fernandinho': 'Fernando Luiz Rosa',
#  'Eric García': 'Eric Garcia',
#  'Matty Cash': 'Matthew Cash',
#  'Douglas Luiz': 'Douglas Luiz Soares de Paulo',
#  'Ezri Konsa': 'Ezri Konsa Ngoyo',
#  'Trézéguet': 'Mahmoud Ahmed Ibrahim Hassan',
#  'Ben Chilwell': 'Benjamin Chilwell',
#  'Thiago Silva': 'Thiago Emiliano da Silva',
#  'Mateo Kovačić': 'Mateo Kovacic',
#  'Jorginho': 'Jorge Luiz Frello Filho',
#  'Emerson Palmieri': 'Emerson Palmieri dos Santos',
#  'Oriol Romeu': 'Oriol Romeu Vidal',
#  'Dan Nlundulu': "Daniel N'Lundulu",
#  'Łukasz Fabiański': 'Lukasz Fabianski',
#  'Tomáš Souček': 'Tomas Soucek',
#  'Vladimír Coufal': 'Vladimir Coufal',
#  'Felipe Anderson': 'Felipe Anderson Pereira Gomes',
#  'Rui Patrício': 'Rui Pedro dos Santos Patrício',
#  'Pedro Neto': 'Pedro Lomba Neto',
#  'Daniel Podence': 'Daniel Castelo Podence',
#  'Nélson Semedo': 'Nélson Cabral Semedo',
#  'Rúben Neves': 'Rúben Diogo da Silva Neves',
#  'João Moutinho': 'João Filipe Iria Santos Moutinho',
#  'Rayan Aït Nouri': 'Rayan Ait Nouri',
#  'Fábio Silva': 'Fabio Silva',
#  'Rúben Vinagre': 'Rúben Gonçalo Silva Nascimento Vinagre',
#  'Vitinha': 'Vitor Ferreira',
#  'Rodrigo': 'Rodrigo Moreno',
#  'Pablo Hernández': 'Pablo Hernández Domínguez',
#  'Ian Carlo Poveda': 'Ian Carlo Poveda-Ocampo',
#  'Joelinton': 'Joelinton Cássio Apolinário de Lira',
#  'Luka Milivojević': 'Luka Milivojevic',
#  'Jaïro Riedewald': 'Jairo Riedewald',
#  'Gabriel Dos Santos': 'Gabriel Magalhães',
#  'Willian': 'Willian Borges Da Silva',
#  'Dani Ceballos': 'Daniel Ceballos Fernández',
#  'David Luiz': 'David Luiz Moreira Marinho',
#  'Eddie Nketiah': 'Edward Nketiah',
#  'Joe Willock': 'Joseph Willock',
#  'Sead Kolašinac': 'Sead Kolasinac',
#  'Martinelli': 'Gabriel Teodoro Martinelli Silva',
#  'Solly March': 'Solomon March',
#  'Bernardo': 'Bernardo Fernandes da Silva Junior',
#  'Jóhann Berg Guðmundsson': 'Johann Berg Gudmundsson',
#  'Matěj Vydra': 'Matej Vydra',
#  'Andre-Frank Zambo Anguissa': 'André-Frank Zambo Anguissa',
#  'Semi Ajayi': 'Oluwasemilogo Adesewo Ibidapo Ajayi',
#  'Branislav Ivanović': 'Branislav Ivanovic',
#  'Filip Krovinović': 'Filip Krovinovic',
#  'Ahmed Hegazi': 'Ahmed El-Sayed Hegazi',
#  'Harvey Elliot': 'Harvey Elliott',
#  'Angeliño': 'Angelo Ogbonna',
#  'Thomas Doyle': 'Tommy Doyle',
#  'Diogo Dalot': 'José Diogo Dalot Teixeira',
#  'Pedro': 'Pedro Rodríguez Ledesma',
#  'Ricardo Pereira': 'Ricardo Domingos Barbosa Pereira',
#  'Gedson Fernandes': 'Gedson Carvalho Fernandes',
#  "Georges-Kévin N'Koudou": 'Georges-Kévin Nkoudou',
#  'Jonny Castro': 'Jonathan Castro Otto',
#  'Jesús Vallejo': 'Jesús Vallejo Lázaro',
#  'Bruno Jordão': 'Bruno André Cavaco Jordao',
#  'Mattéo Guendouzi': 'Matteo Guendouzi',
#  'Richairo Živković': 'Richairo Zivkovic',
#  'Danny Drinkwater': 'Daniel Drinkwater',
#  'Martin Dúbravka': 'Martin Dubravka',
#  'Yoshinori Mutō': 'Yoshinori Muto',
#  'Ki Sung-yueng': 'Sung-yueng Ki',
#  'Roberto': 'Roberto Jimenez Gago',
#  'Javier Hernández': 'Javier Hernández Balcázar',
#  'Frederic Guilbert': 'Frédéric Guilbert',
#  'Björn Engels': 'Bjorn Engels',
#  'Pepe Reina': 'José Reina',
#  'Jota': 'José Ignacio Peleteiro Romallo',
#  'Arnaut Groeneveld': 'Arnaut Danjuma Groeneveld',
#  'Étienne Capoue': 'Etienne Capoue',
#  'Kiko Femenía': 'Francisco Femenía Far',
#  'Ismaila Sarr': 'Ismaila Sarr',
#  'João Pedro': 'João Pedro Junqueira de Jesus',
#  'Max Aarons': 'Max Aarons',
#  'Emi Buendía': 'Emiliano Buendía Stati',
#  'Mario Vrančić': 'Mario Vrancic',
#  'Josip Drmić': 'Josip Drmic',
#  'Ralf Fährmann': 'Ralf Fahrmann',
#  'Danilo': 'Danilo Luiz da Silva',
#  'Petr Čech': 'Petr Cech',
#  'Idrissa Gana Gueye': 'Idrissa Gueye',
#  'Marko Arnautović': 'Marko Arnautovic',
#  'Xande Silva': 'Alexandre Nascimento Costa Silva',
#  'Julián Speroni': 'Julian Speroni',
#  'Kenedy': 'Robert Kenedy Nunes do Nascimento',
#  'Joselu': 'Jose Luis Mato Sanmartín',
#  'Asmir Begović': 'Asmir Begović',
#  'Kayne Ramsey': 'Kayne Ramsay',
#  'Bruno': 'Bruno Saltor Grau',
#  'Junior Hoilett': 'David Junior Hoilett',
#  'Greg Cunningham': 'Greg Cunninghamm',
#  'Jazz Richards': 'Ashley Darel Jazz Richards',
#  'Jean Seri': 'Jean Michael Seri',
#  'Fabricio': 'Fabricio Agosto Ramírez',
#  'Lazar Marković': 'Lazar Markovic',
#  'Mathias Jørgensen': 'Mathias Jorgensen',
#  'Steve Mounié': 'Steve Mounie',
#  'Jon Gorenc Stanković': 'Jon Gorenc Stankovic',
#  'Matty Daly': 'Matthew Daly',
#  'Yaya Touré': 'Gnegneri Yaya Touré',
#  'Brahim Díaz': 'Brahim Diaz',
#  'Zlatan Ibrahimović': 'Zlatan Ibrahimovic',
#  'Marko Grujić': 'Marko Grujic',
#  'Charly Musonda Jr.': 'Charly Musonda',
#  'Nikola Vlašić': 'Nikola Vlasic',
#  'Aleksandar Dragović': 'Aleksandar Dragovic',
#  'Eldin Jakupović': 'Eldin Jakupovic',
#  'Rob Elliot': 'Robert Elliot',
#  'Jesús Gámez': 'Jesús Gámez Duarte',
#  'Massadio Haïdara': 'Massadio Haidara',
#  'Lee Chung-yong': 'Chung-yong Lee',
#  'Freddie Ladapo': 'Olayinka Fredrick Oladotun Ladapo',
#  'João Mário': 'João Mário Naval Costa Eduardo',
#  'José Fonte': 'Jose Fonte',
#  'Younès Kaboul': 'Younes Kaboul',
#  'Izzy Brown': 'Isaiah Brown',
#  'Dušan Tadić': 'Dusan Tadic',
#  'Àngel Rangel': 'Angel Rangel',
#  'Badou Ndiaye': 'Papa Alioune Ndiaye',
#  'Jesé': 'Jesé Rodríguez Ruiz',
#  'Tom Edwards': 'Thomas Edwards',
#  'Kostas Stafylidis': 'Konstantinos Stafylidis',
#  'Lasse Sørensen': 'Lasse Sorenson',
#  'Bojan Krkić': 'Bojan Krkic',
#  'Allan Nyom': 'Allan-Roméo Nyom',
#  'Ahmed Elmohamady': 'Ahmed El Mohamady',
#  'Hélder Costa': 'Hélder Wander Sousa de Azevedo e Costa',
#  'Mohamed Elneny': 'Mohamed Naser El Sayed Elneny',
#  'Emile Smith-Rowe': 'Emile Smith Rowe',
#  'Ivan Cavaleiro': 'Ivan Ricardo Neves Abreu Cavaleiro',
#  'Bobby Reid': 'Bobby Decordova-Reid',
#  'Ahmed El-Sayed Hegazi': 'Ahmed El-Sayed Hegazy',
#  'Kiko Casilla': 'Francisco Casilla Cortés',
#  'Willian José': 'Willian José Da Silva',
#  'Kostas Tsimikas': 'Konstantinos Tsimikas',
#  'Okay Yokuşlu': 'Okay Yokuslu',
#  'Khanya Leshabela': 'Thakgalo Leshabela',
#  'Jaden Philogene Bidace': 'Jaden Philogene-Bidace',
#  'William Thomas Fish': 'William Fish',
#  'David Raya': 'David Raya Martin',
#  'Oghenekaro Etebo': 'Oghenekaro Peter Etebo',
#  'Ismaïla Sarr': 'Ismaila Sarr',
#  'Cucho': 'Juan Camilo Hernández Suárez',
#  'Enoch Mwepu': 'Enock Mwepu',
#  'Emiliano Buendía': 'Emiliano Buendía StatiJosé Malheiro de Sá',
#  'José Sá': 'José Malheiro de Sá',
#  'Francisco Trincão': 'Francisco Machado Mota de Castro Trincão',
#  'Valentino Livramento': 'Tino Livramento',
#  'Nuno Tavares': 'Nuno Varela Tavares',
#  'Jesuran Rak Sakyi': 'Jesurun Rak-Sakyi',
#  'Maximillian Aarons': 'Max Aarons',
#  'Josh Sargent': 'Joshua Sargent',
#  'Junior Firpo': 'Héctor Junior Firpo Adames',
#  'Imran Louza': 'Imrân Louza',
#  'Bryan': 'Bryan Gil Salvatierra',
#  'Kiernan Dewsbury Hall': 'Kiernan Dewsbury-Hall',
#  'Cristiano Ronaldo': 'Cristiano Ronaldo dos Santos Aveiro',
#  'Emerson': 'Emerson Aparecido Leite de Souza Junior',
#  'Mads Roerslev': 'Mads Roerslev Rasmussen',
#  'Odsonne Édouard': 'Odsonne Edouard',
#  'Hwang Hee-chan': 'Hee-Chan Hwang',
#  'Asmir Begovic': 'Asmir Begović',
#  'Caoimhín Kelleher': 'Caoimhin Kelleher',
#  'Lyanco': 'Lyanco Evangelista Silveira Neves Vojnovic',
#  'Przemysław Płacheta': 'Przemyslaw Placheta',
#  'James Mcatee': 'James McAtee',
#  'Jakob Sørensen': 'Jacob Sørensen',
#  'Alex Král': 'Alex Kral',
#  'Jon Rowe': 'Jonathan Rowe'}

# %%
team_list = {}
team_list['Brighton'] = 'Brighton and Hove Albion'
team_list['Leeds United'] = 'Leeds'
team_list['Manchester Utd'] = 'Manchester United'
team_list['Newcastle Utd'] = 'Newcastle United'
team_list['Norwich City'] = 'Norwich'
team_list['Sheffield Utd'] = 'Sheffield United'
team_list['Tottenham'] = 'Tottenham Hotspur'
team_list['West Brom'] = 'West Bromwich Albion'
team_list['West Ham'] = 'West Ham United'
team_list['Wolves'] = 'Wolverhampton Wanderers'

# %%
# replace non-matching names/teams and extract gw as integer
df_enhanced['alt_name'] = df_enhanced['player'].replace(match_list)
df_enhanced['squad'] = df_enhanced['squad'].replace(team_list)
df_enhanced['round'] = df_enhanced['round'].str[-2:].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_34052/561780417.py in <module>
#       2 df_enhanced['alt_name'] = df_enhanced['player'].replace(match_list)
#       3 df_enhanced['squad'] = df_enhanced['squad'].replace(team_list)
# ----> 4 df_enhanced['round'] = df_enhanced['round'].str[-2:].astype('int')
#
# ~\anaconda3\envs\fplenv\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\anaconda3\envs\fplenv\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ~\anaconda3\envs\fplenv\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# ~\anaconda3\envs\fplenv\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     589         values = self.values
#     590
# --> 591         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     592
#     593         new_values = maybe_coerce_values(new_values)
#
# ~\anaconda3\envs\fplenv\lib\site-packages\pandas\core\dtypes\cast.py in astype_array_safe(values, dtype, copy, errors)
#    1307
#    1308     try:
# -> 1309         new_values = astype_array(values, dtype, copy=copy)
#    1310     except (ValueError, TypeError):
#    1311         # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\anaconda3\envs\fplenv\lib\site-packages\pandas\core\dtypes\cast.py in astype_array(values, dtype, copy)
#    1255
#    1256     else:
# -> 1257         values = astype_nansafe(values, dtype, copy=copy)
#    1258
#    1259     # in pandas we don't store numpy str dtypes, so convert to object
#
# ~\anaconda3\envs\fplenv\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1172         # work around NumPy brokenness, #1987
#    1173         if np.issubdtype(dtype.type, np.integer):
# -> 1174             return lib.astype_intsafe(arr, dtype)
#    1175
#    1176         # if we have a datetime/timedelta array of objects
#
# ~\anaconda3\envs\fplenv\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: 'on'

# %%
df_enhanced['round'] = df_enhanced['round'].str[-2:].astype('int')

# %%
# remove duplicated (happens when players transferred within season)
df_enhanced = df_enhanced.drop_duplicates()

# %%
df_enhanced
# Out:
#          season          player        date            squad            comp  \
# 0     2021-2022         Ederson  2021-08-15  Manchester City  Premier League
# 1     2021-2022         Ederson  2021-08-21  Manchester City  Premier League
# 2     2021-2022         Ederson  2021-08-28  Manchester City  Premier League
# 3     2021-2022         Ederson  2021-09-11  Manchester City  Premier League
# 4     2021-2022         Ederson  2021-09-18  Manchester City  Premier League
# ...         ...             ...         ...              ...             ...
# 5702  2021-2022    Erik Pieters  2021-10-16          Burnley  Premier League
# 5703  2021-2022    Erik Pieters  2021-11-06          Burnley  Premier League
# 5704  2021-2022    Erik Pieters  2021-12-30          Burnley  Premier League
# 5705  2021-2022   Dale Stephens  2021-12-30          Burnley  Premier League
# 5706  2021-2022  Connor Roberts  2021-12-04          Burnley  Premier League
#
#       round shots_total shots_on_target touches pressures  ...   xa sca gca  \
# 0         1           0               0      22         0  ...  0.0   2   0
# 1         2           0               0      14         0  ...  0.0   0   0
# 2         3           0               0      37         0  ...  0.0   0   0
# 3         4           0               0      26         0  ...  0.0   0   0
# 4         5           0               0      40         0  ...  0.0   0   0
# ...     ...         ...             ...     ...       ...  ...  ...  ..  ..
# 5702      8           0               0      52        24  ...  0.0   0   0
# 5703     11           0               0       3         3  ...  0.0   0   0
# 5704     20           0               0       8         4  ...  0.0   0   0
# 5705     20           0               0      20         9  ...  0.0   0   0
# 5706     15           0               0      14         2  ...  0.0   0   0
#
#      passes_completed passes passes_pct carries dribbles_completed dribbles  \
# 0                  20     22       90.9      10                  0        0
# 1                  12     12      100.0       6                  0        0
# 2                  31     37       83.8      25                  0        0
# 3                  22     24       91.7      10                  0        0
# 4                  39     39      100.0      28                  0        0
# ...               ...    ...        ...     ...                ...      ...
# 5702               29     37       78.4      22                  0        1
# 5703                1      2       50.0       2                  0        0
# 5704                2      3       66.7       4                  0        0
# 5705               12     16       75.0       9                  0        0
# 5706                6      7       85.7       5                  0        0
#
#                        alt_name
# 0     Ederson Santana de Moraes
# 1     Ederson Santana de Moraes
# 2     Ederson Santana de Moraes
# 3     Ederson Santana de Moraes
# 4     Ederson Santana de Moraes
# ...                         ...
# 5702               Erik Pieters
# 5703               Erik Pieters
# 5704               Erik Pieters
# 5705              Dale Stephens
# 5706             Connor Roberts
#
# [5642 rows x 25 columns]

# %%
# create date field in same format as enhanced data
df_latest['date'] = df_latest['kickoff_time'].str[:10]

# %%
# check if any names aren't matching
enhanced_players = df_enhanced[df_enhanced['date'].isin(df_latest['date'].unique())]['alt_name'].unique().tolist()
standard_players = df_latest['player'].unique().tolist()

unmatched_players = [x for x in enhanced_players if x not in standard_players]
unmatched_players
# Out:
# ['Toti Gomes', 'Philippe Coutinho', 'Vitaliy Mykolenko', 'Samir Santos']

# %%
# check if any teams aren't matching
enhanced_teams = df_enhanced[df_enhanced['date'].isin(df_latest['date'].unique())]['squad'].unique().tolist()
standard_teams = df_latest['team'].unique().tolist()

unmatched_teams = [x for x in enhanced_teams if x not in standard_teams]
unmatched_teams
# Out:
# []

# %%
# any additional corrections
# match_list['Toti Gomes'] = 'Toti António Gomes'
# match_list['Philippe Coutinho'] = 'Philippe Coutinho Correia'
# match_list['Vitaliy Mykolenko'] = 'Vitalii Mykolenko'
# match_list['Samir Santos'] = 'Samir Caetano de Souza Santos'
# match_list['Hwang Hee-chan'] = 'Hee-Chan Hwang'

# %%
# replace additional non-matching names
# df_enhanced['alt_name'] = df_enhanced['player'].replace(match_list)

# %%
# make sure there are no non matches after update
# enhanced_players =  df_enhanced[df_enhanced['round'] == last_gw]['alt_name'].unique().tolist()
# standard_players = df_latest['player'].unique().tolist()

# unmatched_players = [x for x in enhanced_players if x not in standard_players]
# unmatched_players
# Out:
# []

# %%
# if match list was updated then update the file
# json_file = json.dumps(match_list)
# f = open(path/"match_list.json","w")
# f.write(json_file)
# f.close()

# %%
# check there are no duplicates in the join fields for the enhanced data
assert(len(df_enhanced[df_enhanced.duplicated(subset=['alt_name', 'date'], keep=False)]) == 0)

# %%
df_latest[df_latest.duplicated(subset=['date','player','team'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [player, gw, position, minutes, team, opponent_team, relative_market_value_team, relative_market_value_opponent_team, was_home, total_points, assists, bonus, bps, clean_sheets, creativity, goals_conceded, goals_scored, ict_index, influence, own_goals, penalties_missed, penalties_saved, red_cards, saves, selected, team_a_score, team_h_score, threat, transfers_balance, transfers_in, transfers_out, yellow_cards, kickoff_time, season, play_proba, date]
# Index: []
#
# [0 rows x 36 columns]

# %%
# check there are no duplicates in the join fields for the standard data
assert(len(df_train[df_train.duplicated(subset=['date','player','team'])]) == 0)

# %%
# df_train[df_train.duplicated(subset=['date','player','team'])]

# %%
# join standard and enhanced dataframes
df_latest_further = df_latest.merge(df_enhanced.drop(['player', 'season', 'round'], axis=1), 
                                   left_on=['date', 'player', 'team'], 
                                   right_on=['date', 'alt_name', 'squad'], how='left')

# %%
# drop the alt name field and check the length of the standard
# dataframe has not increased
df_latest_further = df_latest_further.drop(['alt_name'], axis=1)
assert(len(df_latest_further) == len(df_latest_further))

# %%
# add crowds field
df_latest_further['crowds'] = 1

# %%
assert(sum(df_latest_further[df_latest_further['minutes'] > 0]['xg'].isnull()) == 0)

# %%
df_latest_further[df_latest_further['minutes'] > 0][df_latest_further[df_latest_further['minutes'] > 0]['xg'].isnull()]
# Out:
# Empty DataFrame
# Columns: [player, gw, position, minutes, team, opponent_team, relative_market_value_team, relative_market_value_opponent_team, was_home, total_points, assists, bonus, bps, clean_sheets, creativity, goals_conceded, goals_scored, ict_index, influence, own_goals, penalties_missed, penalties_saved, red_cards, saves, selected, team_a_score, team_h_score, threat, transfers_balance, transfers_in, transfers_out, yellow_cards, kickoff_time, season, play_proba, date, squad, comp, shots_total, shots_on_target, touches, pressures, tackles, interceptions, blocks, xg, npxg, xa, sca, gca, passes_completed, passes, passes_pct, carries, dribbles_completed, dribbles, crowds]
# Index: []
#
# [0 rows x 57 columns]

# %%
df_enhanced
# Out:
#          season          player        date            squad            comp  \
# 0     2021-2022         Ederson  2021-08-15  Manchester City  Premier League
# 1     2021-2022         Ederson  2021-08-21  Manchester City  Premier League
# 2     2021-2022         Ederson  2021-08-28  Manchester City  Premier League
# 3     2021-2022         Ederson  2021-09-11  Manchester City  Premier League
# 4     2021-2022         Ederson  2021-09-18  Manchester City  Premier League
# ...         ...             ...         ...              ...             ...
# 5702  2021-2022    Erik Pieters  2021-10-16          Burnley  Premier League
# 5703  2021-2022    Erik Pieters  2021-11-06          Burnley  Premier League
# 5704  2021-2022    Erik Pieters  2021-12-30          Burnley  Premier League
# 5705  2021-2022   Dale Stephens  2021-12-30          Burnley  Premier League
# 5706  2021-2022  Connor Roberts  2021-12-04          Burnley  Premier League
#
#       round shots_total shots_on_target touches pressures  ...   xa sca gca  \
# 0         1           0               0      22         0  ...  0.0   2   0
# 1         2           0               0      14         0  ...  0.0   0   0
# 2         3           0               0      37         0  ...  0.0   0   0
# 3         4           0               0      26         0  ...  0.0   0   0
# 4         5           0               0      40         0  ...  0.0   0   0
# ...     ...         ...             ...     ...       ...  ...  ...  ..  ..
# 5702      8           0               0      52        24  ...  0.0   0   0
# 5703     11           0               0       3         3  ...  0.0   0   0
# 5704     20           0               0       8         4  ...  0.0   0   0
# 5705     20           0               0      20         9  ...  0.0   0   0
# 5706     15           0               0      14         2  ...  0.0   0   0
#
#      passes_completed passes passes_pct carries dribbles_completed dribbles  \
# 0                  20     22       90.9      10                  0        0
# 1                  12     12      100.0       6                  0        0
# 2                  31     37       83.8      25                  0        0
# 3                  22     24       91.7      10                  0        0
# 4                  39     39      100.0      28                  0        0
# ...               ...    ...        ...     ...                ...      ...
# 5702               29     37       78.4      22                  0        1
# 5703                1      2       50.0       2                  0        0
# 5704                2      3       66.7       4                  0        0
# 5705               12     16       75.0       9                  0        0
# 5706                6      7       85.7       5                  0        0
#
#                        alt_name
# 0     Ederson Santana de Moraes
# 1     Ederson Santana de Moraes
# 2     Ederson Santana de Moraes
# 3     Ederson Santana de Moraes
# 4     Ederson Santana de Moraes
# ...                         ...
# 5702               Erik Pieters
# 5703               Erik Pieters
# 5704               Erik Pieters
# 5705              Dale Stephens
# 5706             Connor Roberts
#
# [5642 rows x 25 columns]

# %%
df_train_new = pd.concat([df_train, df_latest_further], ignore_index=True, axis=0, sort=False)

# %%
df_train_new[df_train_new['player'] == 'Harry Kane'].tail()
# Out:
#             player  gw  position  minutes               team   opponent_team  \
# 125020  Harry Kane  18         4       90  Tottenham Hotspur       Liverpool
# 125561  Harry Kane  19         4       63  Tottenham Hotspur  Crystal Palace
# 125801  Harry Kane  20         4       90  Tottenham Hotspur     Southampton
# 126346  Harry Kane  21         4       90  Tottenham Hotspur         Watford
# 127048  Harry Kane  22         4       90  Tottenham Hotspur  Leicester City
#
#         relative_market_value_team  relative_market_value_opponent_team  \
# 125020                    1.463462                             1.958866
# 125561                    1.463462                             0.545912
# 125801                    1.463462                             0.563202
# 126346                    1.467118                             0.338504
# 127048                    1.466032                             1.169548
#
#         was_home  total_points  ...  gca  passes_completed  passes  \
# 125020      True             6  ...  0.0              10.0    18.0
# 125561      True             6  ...  1.0              17.0    19.0
# 125801     False             6  ...  0.0              17.0    24.0
# 126346     False             2  ...  0.0              24.0    33.0
# 127048     False            11  ...    2                25      36
#
#         passes_pct  carries  dribbles_completed  dribbles  crowds  \
# 125020        55.6     20.0                 3.0       3.0       1
# 125561        89.5     23.0                 1.0       1.0       1
# 125801        70.8     34.0                 2.0       2.0       1
# 126346        72.7     38.0                 0.0       1.0       1
# 127048        69.4       49                   4         4       1
#
#         play_proba_x  play_proba_y
# 125020           NaN           NaN
# 125561           NaN           NaN
# 125801           NaN           NaN
# 126346           NaN           NaN
# 127048           NaN           NaN
#
# [5 rows x 61 columns]

# %%
df_train_new.tail(10)
# Out:
#                             player  gw  position  minutes  \
# 127541  Yerson Mosquera Valdelamar  22         2        0
# 127542                 Yoane Wissa  22         3       22
# 127543                 Yoane Wissa  22         3       23
# 127544             Youri Tielemans  22         3       90
# 127545               Yves Bissouma  22         3        0
# 127546               Yves Bissouma  22         3        0
# 127547                Zack Steffen  22         1        0
# 127548            Álvaro Fernández  22         1       90
# 127549            Álvaro Fernández  22         1        0
# 127550              Çaglar Söyüncü  22         2       90
#
#                             team      opponent_team  \
# 127541   Wolverhampton Wanderers        Southampton
# 127542                 Brentford          Liverpool
# 127543                 Brentford  Manchester United
# 127544            Leicester City  Tottenham Hotspur
# 127545  Brighton and Hove Albion     Crystal Palace
# 127546  Brighton and Hove Albion            Chelsea
# 127547           Manchester City            Chelsea
# 127548                 Brentford          Liverpool
# 127549                 Brentford  Manchester United
# 127550            Leicester City  Tottenham Hotspur
#
#         relative_market_value_team  relative_market_value_opponent_team  \
# 127541                    0.836530                             0.561670
# 127542                    0.481090                             1.968974
# 127543                    0.481090                             1.978649
# 127544                    1.169548                             1.466032
# 127545                    0.560418                             0.546191
# 127546                    0.560418                             2.009947
# 127547                    2.258288                             2.009947
# 127548                    0.481090                             1.968974
# 127549                    0.481090                             1.978649
# 127550                    1.169548                             1.466032
#
#         was_home  total_points  ...  gca  passes_completed  passes  \
# 127541      True             0  ...  NaN               NaN     NaN
# 127542     False             1  ...    0                 3       4
# 127543      True             1  ...    0                13      15
# 127544      True             2  ...    0                56      61
# 127545      True             0  ...  NaN               NaN     NaN
# 127546      True             0  ...  NaN               NaN     NaN
# 127547      True             0  ...  NaN               NaN     NaN
# 127548     False             4  ...    0                20      48
# 127549      True             0  ...  NaN               NaN     NaN
# 127550      True             1  ...    0                62      69
#
#         passes_pct  carries  dribbles_completed  dribbles  crowds  \
# 127541         NaN      NaN                 NaN       NaN       1
# 127542        75.0        1                   0         0       1
# 127543        86.7       14                   0         0       1
# 127544        91.8       54                   1         1       1
# 127545         NaN      NaN                 NaN       NaN       1
# 127546         NaN      NaN                 NaN       NaN       1
# 127547         NaN      NaN                 NaN       NaN       1
# 127548        41.7       20                   0         0       1
# 127549         NaN      NaN                 NaN       NaN       1
# 127550        89.9       56                   0         0       1
#
#         play_proba_x  play_proba_y
# 127541           NaN           NaN
# 127542           NaN           NaN
# 127543           NaN           NaN
# 127544           NaN           NaN
# 127545           NaN           NaN
# 127546           NaN           NaN
# 127547           NaN           NaN
# 127548           NaN           NaN
# 127549           NaN           NaN
# 127550           NaN           NaN
#
# [10 rows x 61 columns]

# %%
df_latest_further.shape
# Out:
# (759, 57)

# %%
df_train_new.shape
# Out:
# (127551, 61)

# %%
# save latest training set to csv
# overwrite existing one
df_train_new.to_csv(path/'train_v8.csv')

# %%
# get fixtures
fixtures = pd.read_csv(path/'2021-22/fixtures.csv')
team_dict = teams[['team_2122', 'team']].dropna().set_index('team_2122').to_dict()['team']

fixtures['home_team'] = fixtures['team_h'].replace(team_dict)
fixtures['away_team'] = fixtures['team_a'].replace(team_dict)
fixtures = fixtures[['home_team', 'away_team', 'kickoff_time', 'event']]
fixtures = fixtures.rename(columns={'event':'gw'})


# use these two lines if updating play_proba later in week
# current_gw = last_gw
# df_train_new = pd.read_csv(path/'train_v7.csv', index_col=0, dtype={'season':str,
#                                                                     'comp':str,
#                                                                     'squad':str})

# set starting gameweek (where are we right now in the season)
current_gw = last_gw + 1
fixtures = fixtures[fixtures['gw'] >= current_gw].sort_values(by=['gw'])
fixtures['match_no'] = np.arange(fixtures.shape[0])

# %%
fixtures.head(50)
# Out:
#                     home_team                 away_team          kickoff_time  \
# 223                   Watford                   Norwich  2022-01-21T20:00:00Z
# 224                   Everton               Aston Villa  2022-01-22T12:30:00Z
# 225                 Brentford   Wolverhampton Wanderers  2022-01-22T15:00:00Z
# 226                     Leeds          Newcastle United  2022-01-22T15:00:00Z
# 227         Manchester United           West Ham United  2022-01-22T15:00:00Z
# 228               Southampton           Manchester City  2022-01-22T17:30:00Z
# 229                   Arsenal                   Burnley  2022-01-23T14:00:00Z
# 230            Crystal Palace                 Liverpool  2022-01-23T14:00:00Z
# 231            Leicester City  Brighton and Hove Albion  2022-01-23T14:00:00Z
# 232                   Chelsea         Tottenham Hotspur  2022-01-23T16:30:00Z
# 233                   Burnley                   Watford  2022-02-05T18:00:00Z
# 242   Wolverhampton Wanderers                   Arsenal  2022-02-10T19:45:00Z
# 241                 Liverpool            Leicester City  2022-02-10T19:45:00Z
# 240               Aston Villa                     Leeds  2022-02-09T20:00:00Z
# 239         Tottenham Hotspur               Southampton  2022-02-09T19:45:00Z
# 234          Newcastle United                   Everton  2022-02-08T19:45:00Z
# 237           Manchester City                 Brentford  2022-02-09T19:45:00Z
# 236                   Burnley         Manchester United  2022-02-08T20:00:00Z
# 235           West Ham United                   Watford  2022-02-08T19:45:00Z
# 238                   Norwich            Crystal Palace  2022-02-09T19:45:00Z
# 249          Newcastle United               Aston Villa  2022-02-13T14:00:00Z
# 251            Leicester City           West Ham United  2022-02-13T16:30:00Z
# 250         Tottenham Hotspur   Wolverhampton Wanderers  2022-02-13T14:00:00Z
# 248                   Burnley                 Liverpool  2022-02-13T14:00:00Z
# 244                 Brentford            Crystal Palace  2022-02-12T15:00:00Z
# 246                   Watford  Brighton and Hove Albion  2022-02-12T15:00:00Z
# 245                   Everton                     Leeds  2022-02-12T15:00:00Z
# 243         Manchester United               Southampton  2022-02-12T12:30:00Z
# 247                   Norwich           Manchester City  2022-02-12T17:30:00Z
# 261   Wolverhampton Wanderers            Leicester City  2022-02-20T16:30:00Z
# 260                     Leeds         Manchester United  2022-02-20T14:00:00Z
# 259           Manchester City         Tottenham Hotspur  2022-02-19T17:30:00Z
# 258               Southampton                   Everton  2022-02-19T15:00:00Z
# 257                 Liverpool                   Norwich  2022-02-19T15:00:00Z
# 256            Crystal Palace                   Chelsea  2022-02-19T15:00:00Z
# 254               Aston Villa                   Watford  2022-02-19T15:00:00Z
# 253                   Arsenal                 Brentford  2022-02-19T15:00:00Z
# 252           West Ham United          Newcastle United  2022-02-19T12:30:00Z
# 255  Brighton and Hove Albion                   Burnley  2022-02-19T15:00:00Z
# 267         Manchester United                   Watford  2022-02-26T15:00:00Z
# 269                   Everton           Manchester City  2022-02-26T17:30:00Z
# 268           West Ham United   Wolverhampton Wanderers  2022-02-26T15:00:00Z
# 266            Crystal Palace                   Burnley  2022-02-26T15:00:00Z
# 263                     Leeds         Tottenham Hotspur  2022-02-26T12:30:00Z
# 264                 Brentford          Newcastle United  2022-02-26T15:00:00Z
# 262               Southampton                   Norwich  2022-02-25T20:00:00Z
# 265  Brighton and Hove Albion               Aston Villa  2022-02-26T15:00:00Z
# 270               Aston Villa               Southampton  2022-03-05T15:00:00Z
# 271                   Burnley                   Chelsea  2022-03-05T15:00:00Z
# 272            Leicester City                     Leeds  2022-03-05T15:00:00Z
#
#        gw  match_no
# 223  23.0         0
# 224  23.0         1
# 225  23.0         2
# 226  23.0         3
# 227  23.0         4
# 228  23.0         5
# 229  23.0         6
# 230  23.0         7
# 231  23.0         8
# 232  23.0         9
# 233  23.0        10
# 242  24.0        11
# 241  24.0        12
# 240  24.0        13
# 239  24.0        14
# 234  24.0        15
# 237  24.0        16
# 236  24.0        17
# 235  24.0        18
# 238  24.0        19
# 249  25.0        20
# 251  25.0        21
# 250  25.0        22
# 248  25.0        23
# 244  25.0        24
# 246  25.0        25
# 245  25.0        26
# 243  25.0        27
# 247  25.0        28
# 261  26.0        29
# 260  26.0        30
# 259  26.0        31
# 258  26.0        32
# 257  26.0        33
# 256  26.0        34
# 254  26.0        35
# 253  26.0        36
# 252  26.0        37
# 255  26.0        38
# 267  27.0        39
# 269  27.0        40
# 268  27.0        41
# 266  27.0        42
# 263  27.0        43
# 264  27.0        44
# 262  27.0        45
# 265  27.0        46
# 270  28.0        47
# 271  28.0        48
# 272  28.0        49

# %%
# add universal team codes for home and away teams
fixtures = fixtures.merge(teams, left_on='home_team', right_on='team', how='left')
fixtures = fixtures.merge(teams, left_on='away_team', right_on='team', how='left')
fixtures = fixtures[['gw', 'match_no', 'home_team', 'away_team', 'kickoff_time', 'team_code_x', 'team_code_y']]
fixtures.rename(index=str,
                columns={'team_code_x':'home_team_code',
                         'team_code_y':'away_team_code'},
                inplace=True)

# %%
fixtures.head()
# Out:
#      gw  match_no          home_team                away_team  \
# 0  23.0         0            Watford                  Norwich
# 1  23.0         1            Everton              Aston Villa
# 2  23.0         2          Brentford  Wolverhampton Wanderers
# 3  23.0         3              Leeds         Newcastle United
# 4  23.0         4  Manchester United          West Ham United
#
#            kickoff_time  home_team_code  away_team_code
# 0  2022-01-21T20:00:00Z              57              45
# 1  2022-01-22T12:30:00Z              11               7
# 2  2022-01-22T15:00:00Z              94              39
# 3  2022-01-22T15:00:00Z               2               4
# 4  2022-01-22T15:00:00Z               1              21

# %%
# all_players.replace(to_replace='None', value=1, inplace=True)

# %%
all_players[all_players['play_proba_2122'] == '0']
# Out:
#                       full_name play_proba_2122  position_2122  id_2122  \
# 1          Rúnar Alex Rúnarsson               0              1        2
# 2       Willian Borges Da Silva               0              3        3
# 3     Pierre-Emerick Aubameyang               0              4        4
# 6                  Granit Xhaka               0              3        7
# 7                    Pablo Marí               0              2        8
# ..                          ...             ...            ...      ...
# 669               Owen Otasowie               0              3      442
# 673  Yerson Mosquera Valdelamar               0              2      446
# 678             Patrick Cutrone               0              4      523
# 681           Christian Marques               0              2      549
# 682              Hee-Chan Hwang               0              4      583
#
#      cost_2122  team_2122 web_name_2122
# 1           40          3     Rúnarsson
# 2           63          3       Willian
# 3           96          3    Aubameyang
# 6           48          3         Xhaka
# 7           42          3          Marí
# ..         ...        ...           ...
# 669         45         39      Otasowie
# 673         44         39      Mosquera
# 678         50         39       Cutrone
# 681         40         39       Marques
# 682         54         39         Hwang
#
# [190 rows x 7 columns]

# %%
# join home team to all players for current season
home_df = fixtures.merge(all_players, 
               left_on='home_team_code', 
               right_on='team_2122', 
               how='left')

# pull out the required fields and rename columns
home_df = home_df[['gw', 'match_no', 'home_team', 'away_team', 'kickoff_time', 
                   'full_name', 'position_2122', 'cost_2122', 'play_proba_2122', 
                   'web_name_2122']]
home_df.rename(index=str, 
               columns={'home_team':'team',
                        'away_team':'opponent_team',
                        'full_name':'player',
                        'position_2122':'position',
                        'cost_2122':'price',
                        'play_proba_2122':'play_proba',
                        'web_name_2122':'short_name'},
              inplace=True)

# add home flag
home_df['was_home'] = True

# %%
# join away team to all players for current season
away_df = fixtures.merge(all_players, 
               left_on='away_team_code', 
               right_on='team_2122', 
               how='left')

# pull out the required fields and rename columns
away_df = away_df[['gw',  'match_no', 'away_team', 'home_team', 'kickoff_time', 
                   'full_name', 'position_2122', 'cost_2122', 'play_proba_2122', 
                   'web_name_2122']]
away_df.rename(index=str, 
               columns={'away_team':'team',
                        'home_team':'opponent_team',
                        'full_name':'player',
                        'position_2122':'position',
                        'cost_2122':'price',
                        'play_proba_2122':'play_proba',
                        'web_name_2122':'short_name'},
              inplace=True)

# add home flag
away_df['was_home'] = False

# %%
# look at away players
away_df.head()
# Out:
#      gw  match_no     team opponent_team          kickoff_time  \
# 0  23.0         0  Norwich       Watford  2022-01-21T20:00:00Z
# 1  23.0         0  Norwich       Watford  2022-01-21T20:00:00Z
# 2  23.0         0  Norwich       Watford  2022-01-21T20:00:00Z
# 3  23.0         0  Norwich       Watford  2022-01-21T20:00:00Z
# 4  23.0         0  Norwich       Watford  2022-01-21T20:00:00Z
#
#              player  position  price play_proba short_name  was_home
# 0     Billy Gilmour         3     43          0    Gilmour     False
# 1  Brandon Williams         2     39        100   Williams     False
# 2  Michael McGovern         1     39       None   McGovern     False
# 3          Tim Krul         1     45          0       Krul     False
# 4       Teemu Pukki         4     58        100      Pukki     False

# %%
# look at home players
home_df.head()
# Out:
#      gw  match_no     team opponent_team          kickoff_time  \
# 0  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 1  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 2  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 3  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 4  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
#
#            player  position  price play_proba short_name  was_home
# 0  Moussa Sissoko         3     44       None    Sissoko      True
# 1      Ben Foster         1     41        100     Foster      True
# 2      Danny Rose         2     42        100       Rose      True
# 3     Dan Gosling         3     47        100    Gosling      True
# 4  Craig Cathcart         2     43        100   Cathcart      True

# %%
# # calculate average minutes over last 5 gameweeks
# # first get last 5 gameweeks in current season
# recent_mins = df_train_new[(df_train_new['gw'] >= current_gw - 5) & 
#                            (df_train_new['season'] == season_names[0])][['player', 'minutes', 'play_proba']]

# # recent_mins = df_train_new[((df_train_new['gw'] >= 40 - 5) & 
# #                            (df_train_new['season'] == '1920')) | 
# #                            ((df_train_new['gw'] >= 1) & 
# #                            (df_train_new['season'] == '2021'))][['player', 'minutes', 'play_proba']]

# # exclude weeks where the player had an injury designation (i.e. keep where play_proba is 1)
# recent_mins = recent_mins[recent_mins['play_proba'] == 1]

# len(recent_mins)

# # average for each player
# recent_mins = recent_mins.groupby(['player'])['minutes'].mean().to_dict()

# recent_mins

# %%
# concatenate home and away players
remaining_season_df = home_df.append(away_df).reset_index(drop=True)

# add home and away team market values
remaining_season_df = remaining_season_df.merge(teams_mv[teams_mv['season'] == '2122'],
                                                left_on='team', 
                                                right_on='name', 
                                                how='left').drop(['name', 'season'], axis=1)

remaining_season_df = remaining_season_df.merge(teams_mv[teams_mv['season'] == '2122'],
                                                left_on='opponent_team', 
                                                right_on='name', 
                                                how='left').drop(['name', 'season'], axis=1)

remaining_season_df.rename(index=str, 
                           columns={'relative_market_value_x':'relative_market_value_team',
                                    'relative_market_value_y':'relative_market_value_opponent_team'},
                           inplace=True)

# add season name
remaining_season_df['season'] = season_names[0]

# divide cost by 10 for actual cost
remaining_season_df['price'] = remaining_season_df['price']/10

# set availability probability
# 0 = 0% chance, 25 = 25% chance, etc
# 'None' or '100' = 100% chance
remaining_season_df.loc[remaining_season_df['play_proba'] == 'None', 'play_proba'] = 100
remaining_season_df['play_proba'] = remaining_season_df['play_proba'].astype('float') / 100

# cast position to integer
remaining_season_df['position'] = remaining_season_df['position'].astype(int)

# # add minutes based on last five fixtures
# remaining_season_df['minutes'] = remaining_season_df['player'].map(recent_mins)
# remaining_season_df['minutes'].fillna(0, inplace=True)

# # multiply minutes by play probability
# remaining_season_df['minutes'] = remaining_season_df['minutes'] * remaining_season_df['play_proba']

# %%
remaining_season_df.head(50)
# Out:
#       gw  match_no     team opponent_team          kickoff_time  \
# 0   23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 1   23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 2   23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 3   23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 4   23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 5   23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 6   23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 7   23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 8   23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 9   23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 10  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 11  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 12  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 13  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 14  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 15  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 16  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 17  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 18  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 19  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 20  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 21  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 22  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 23  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 24  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 25  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 26  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 27  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 28  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 29  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 30  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 31  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 32  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 33  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 34  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 35  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 36  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 37  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 38  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 39  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 40  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 41  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 42  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 43  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 44  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 45  23.0         0  Watford       Norwich  2022-01-21T20:00:00Z
# 46  23.0         1  Everton   Aston Villa  2022-01-22T12:30:00Z
# 47  23.0         1  Everton   Aston Villa  2022-01-22T12:30:00Z
# 48  23.0         1  Everton   Aston Villa  2022-01-22T12:30:00Z
# 49  23.0         1  Everton   Aston Villa  2022-01-22T12:30:00Z
#
#                            player  position  price  play_proba    short_name  \
# 0                  Moussa Sissoko         3    4.4         1.0       Sissoko
# 1                      Ben Foster         1    4.1         1.0        Foster
# 2                      Danny Rose         2    4.2         1.0          Rose
# 3                     Dan Gosling         3    4.7         1.0       Gosling
# 4                  Craig Cathcart         2    4.3         1.0      Cathcart
# 5                     Troy Deeney         4    5.4         0.0        Deeney
# 6                   Tom Cleverley         3    4.8         1.0     Cleverley
# 7           Francisco Femenía Far         2    4.3         1.0       Femenía
# 8                      Andre Gray         4    5.4         0.0          Gray
# 9              Christian Kabasele         2    4.3         1.0      Kabasele
# 10             Nathaniel Chalobah         3    5.0         0.0      Chalobah
# 11           William Troost-Ekong         2    4.3         0.0  Troost-Ekong
# 12                   Stipe Perica         4    4.5         0.0        Perica
# 13                Daniel Bachmann         1    4.3         1.0      Bachmann
# 14                    Adam Masina         2    4.3         0.0        Masina
# 15                       Ken Sema         3    5.2         1.0          Sema
# 16            Philip Zinckernagel         3    5.5         0.0  Zinckernagel
# 17            Isaac Success Ajayi         4    5.0         0.0       Success
# 18         Ayotomiwa Dele-Bashiru         3    4.5         0.0  Dele-Bashiru
# 19                Ashley Fletcher         4    4.8         1.0      Fletcher
# 20            Francisco Sierralta         2    4.3         1.0     Sierralta
# 21                 Domingos Quina         3    4.5         0.0         Quina
# 22                   Marc Navarro         2    4.0         0.0       Navarro
# 23                   Ismaila Sarr         3    5.8         0.0          Sarr
# 24                  Jeremy Ngakia         2    4.3         1.0        Ngakia
# 25                     Ben Wilmot         2    4.5         0.0        Wilmot
# 26                  Joseph Hungbo         3    4.5         0.0        Hungbo
# 27                    Imrân Louza         3    5.2         0.0         Louza
# 28  João Pedro Junqueira de Jesus         4    5.4         1.0    João Pedro
# 29                    Kwadwo Baah         3    4.3         0.0          Baah
# 30                Emmanuel Dennis         4    6.1         1.0        Dennis
# 31                Matthew Pollock         2    4.0         0.0       Pollock
# 32         Oghenekaro Peter Etebo         3    4.3         0.0         Etebo
# 33                    Joshua King         4    5.8         1.0          King
# 34         Adedapo Awokoya-Mebude         4    4.5         0.0        Mebude
# 35   Juan Camilo Hernández Suárez         4    5.0         1.0         Cucho
# 36                    Juraj Kucka         3    5.5         1.0         Kucka
# 37                     Ozan Tufan         3    5.0         1.0         Tufan
# 38                  Robert Elliot         1    4.0         1.0        Elliot
# 39                Nicolas Nkoulou         2    4.4         0.0       Nkoulou
# 40                   James Morris         2    4.0         1.0        Morris
# 41               Vincent Angelini         1    4.0         1.0      Angelini
# 42                   Kamil Conteh         3    4.5         1.0        Conteh
# 43                 Hassane Kamara         2    4.5         1.0        Kamara
# 44  Samir Caetano de Souza Santos         2    4.5         1.0         Samir
# 45                    Edo Kayembe         3    5.0         1.0       Kayembe
# 46                 Anwar El Ghazi         3    5.6         0.0      El Ghazi
# 47                   Fabian Delph         3    4.3         0.0         Delph
# 48               Gylfi Sigurdsson         3    6.7         0.0    Sigurdsson
# 49                 Seamus Coleman         2    4.9         1.0       Coleman
#
#     was_home  relative_market_value_team  relative_market_value_opponent_team  \
# 0       True                    0.339392                             0.399599
# 1       True                    0.339392                             0.399599
# 2       True                    0.339392                             0.399599
# 3       True                    0.339392                             0.399599
# 4       True                    0.339392                             0.399599
# 5       True                    0.339392                             0.399599
# 6       True                    0.339392                             0.399599
# 7       True                    0.339392                             0.399599
# 8       True                    0.339392                             0.399599
# 9       True                    0.339392                             0.399599
# 10      True                    0.339392                             0.399599
# 11      True                    0.339392                             0.399599
# 12      True                    0.339392                             0.399599
# 13      True                    0.339392                             0.399599
# 14      True                    0.339392                             0.399599
# 15      True                    0.339392                             0.399599
# 16      True                    0.339392                             0.399599
# 17      True                    0.339392                             0.399599
# 18      True                    0.339392                             0.399599
# 19      True                    0.339392                             0.399599
# 20      True                    0.339392                             0.399599
# 21      True                    0.339392                             0.399599
# 22      True                    0.339392                             0.399599
# 23      True                    0.339392                             0.399599
# 24      True                    0.339392                             0.399599
# 25      True                    0.339392                             0.399599
# 26      True                    0.339392                             0.399599
# 27      True                    0.339392                             0.399599
# 28      True                    0.339392                             0.399599
# 29      True                    0.339392                             0.399599
# 30      True                    0.339392                             0.399599
# 31      True                    0.339392                             0.399599
# 32      True                    0.339392                             0.399599
# 33      True                    0.339392                             0.399599
# 34      True                    0.339392                             0.399599
# 35      True                    0.339392                             0.399599
# 36      True                    0.339392                             0.399599
# 37      True                    0.339392                             0.399599
# 38      True                    0.339392                             0.399599
# 39      True                    0.339392                             0.399599
# 40      True                    0.339392                             0.399599
# 41      True                    0.339392                             0.399599
# 42      True                    0.339392                             0.399599
# 43      True                    0.339392                             0.399599
# 44      True                    0.339392                             0.399599
# 45      True                    0.339392                             0.399599
# 46      True                    0.941807                             1.007933
# 47      True                    0.941807                             1.007933
# 48      True                    0.941807                             1.007933
# 49      True                    0.941807                             1.007933
#
#    season
# 0    2122
# 1    2122
# 2    2122
# 3    2122
# 4    2122
# 5    2122
# 6    2122
# 7    2122
# 8    2122
# 9    2122
# 10   2122
# 11   2122
# 12   2122
# 13   2122
# 14   2122
# 15   2122
# 16   2122
# 17   2122
# 18   2122
# 19   2122
# 20   2122
# 21   2122
# 22   2122
# 23   2122
# 24   2122
# 25   2122
# 26   2122
# 27   2122
# 28   2122
# 29   2122
# 30   2122
# 31   2122
# 32   2122
# 33   2122
# 34   2122
# 35   2122
# 36   2122
# 37   2122
# 38   2122
# 39   2122
# 40   2122
# 41   2122
# 42   2122
# 43   2122
# 44   2122
# 45   2122
# 46   2122
# 47   2122
# 48   2122
# 49   2122

# %%
# save latest prediction set to csv
remaining_season_df.to_csv(path/'remaining_season.csv')
