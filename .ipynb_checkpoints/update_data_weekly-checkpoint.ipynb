# %%
# import required libriaries
from pathlib import Path
import json

from fpl_predictor.util import *

# %%
# path to data directory
#path = Path('/home/jupyter/fpl-prediction/data')
path = Path('./fpl_predictor/data')

# %%
# read in latest training set
df_train = pd.read_csv(path/'train_v8.csv', index_col=0, 
                       dtype={'season':str,
                              'comp':str,
                              'squad':str})

# path to current season
season_paths = [path/'2021-22']

# name for current season
season_names = ['2122']

# team codes
teams = pd.read_csv(path/'teams.csv')

# latest remaining season dataset, for latest week's play_proba values
remaining_season = pd.read_csv(path/'remaining_season.csv', index_col=0)

# create players dataset
all_players = build_players(path, season_paths, season_names, teams)

# 2019-20 market value
# table was in slightly different position for 2019-20 season
# should check that 2019-20 season values remain the same once season starts
teams_mv = build_season_mv('2122', 11, range(13,33))

# %%
# all_players#[all_players['full_name'] == 'Ben Davies']

# %%
# df_train = df_train.iloc[:-686]

# %%
# find the latest gameweek
last_gw = df_train['gw'][df_train['season'] == season_names[0]].max()

if np.isnan(last_gw): 
    last_gw = 1 
else: 
    last_gw = last_gw + 1
    
last_gw
# Out:
# 34

# %%
# build training set for latest gameweek
df_latest = build_season(season_paths[0], season_names[0], all_players, teams, teams_mv, [last_gw])

# %%
df_latest.drop_duplicates(inplace=True)

# %%
# df_latest[df_latest['player'] == 'Chris Wood']
# lucas digne
# chris wood

# %%
last_play_proba = remaining_season[remaining_season['gw'] == last_gw][['player', 'team', 'play_proba']]

# %%
last_play_proba.head()
# Out:
#                       player     team  play_proba
# 0                 Bernd Leno  Arsenal         1.0
# 1       Rúnar Alex Rúnarsson  Arsenal         0.0
# 2    Willian Borges Da Silva  Arsenal         0.0
# 3  Pierre-Emerick Aubameyang  Arsenal         0.0
# 4              Cédric Soares  Arsenal         1.0

# %%
# add latest week's play_proba for each player
df_latest = df_latest.merge(last_play_proba, on=['player', 'team'], how='left')

# %%
df_latest.drop_duplicates(inplace=True)

# %%
df_train.drop_duplicates(inplace=True)

# %%
if last_gw==1:
    df_latest['relative_market_value_team_season'] = df_latest['relative_market_value_team']
    df_latest['relative_market_value_opponent_team_season'] = df_latest['relative_market_value_opponent_team']

# %%
# for when you're doing the season value properly
# relative_market_value_season = train_df[train_df['season'] == '2021'][['team', 'relative_market_value_team']].groupby(['team']).first()
# relative_market_value_season = relative_market_value_season.rename(columns={'relative_market_value_team': 'season_value'})
# relative_market_value_season

# %%
# now get futher stats from fbref
# standard stats
features = ['squad', 'comp', 'round', 'shots_total', 'shots_on_target', 'touches', 'pressures',
            'tackles', 'interceptions', 'blocks', 'xg', 'npxg', 'xa', 'sca', 
            'gca', 'passes_completed', 'passes', 'passes_pct',  'carries', 
            'dribbles_completed', 'dribbles']

# %%
# url for the premier league
url_base = 'https://fbref.com'
pl_history_page = '/en/comps/9/history/Premier-League-Seasons'
url = url_base + pl_history_page

# scrape the history table to get latest season
pl_history_table = get_table(url)
pl_history_urls = get_urls(['season'], 'season', pl_history_table, url_base)
season_urls = pl_history_urls[0:1]

df_enhanced = get_stats(features, season_urls, url_base)
# Out:
# 2021-2022
# https://fbref.com/en/comps/9/Premier-League-Stats
# Manchester City
# https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats
# Ederson
# João Cancelo
# Bernardo Silva
# Rodri
# Aymeric Laporte
# Rúben Dias
# Phil Foden
# Kevin De Bruyne
# Raheem Sterling
# Kyle Walker
# Jack Grealish
# İlkay Gündoğan
# Gabriel Jesus
# Riyad Mahrez
# John Stones
# Nathan Aké
# Oleksandr Zinchenko
# Fernandinho
# Ferrán Torres
# Cole Palmer
# Zack Steffen
# Benjamin Mendy
# James Mcatee
# Liam Delap
# Kayky Chagas
# Liverpool
# https://fbref.com/en/squads/822bd0ba/Liverpool-Stats
# Alisson
# Virgil van Dijk
# Mohamed Salah
# Trent Alexander-Arnold
# Sadio Mané
# Joël Matip
# Andrew Robertson
# Jordan Henderson
# Fabinho
# Diogo Jota
# Thiago Alcántara
# Naby Keïta
# Roberto Firmino
# Alex Oxlade-Chamberlain
# Ibrahima Konaté
# Curtis Jones
# Kostas Tsimikas
# James Milner
# Luis Díaz
# Harvey Elliott
# Joe Gomez
# Caoimhín Kelleher
# Tyler Morton
# Divock Origi
# Takumi Minamino
# Kaide Gordon
# Neco Williams
# Chelsea
# https://fbref.com/en/squads/cff3d9bb/Chelsea-Stats
# Edouard Mendy
# Antonio Rüdiger
# Thiago Silva
# Mason Mount
# Jorginho
# Marcos Alonso
# César Azpilicueta
# Kai Havertz
# N'Golo Kanté
# Reece James
# Andreas Christensen
# Trevoh Chalobah
# Mateo Kovačić
# Romelu Lukaku
# Timo Werner
# Hakim Ziyech
# Ruben Loftus-Cheek
# Callum Hudson-Odoi
# Christian Pulisic
# Ben Chilwell
# Malang Sarr
# Kepa Arrizabalaga
# Saúl Ñíguez
# Ross Barkley
# Emerson Palmieri
# Arsenal
# https://fbref.com/en/squads/18bb7c10/Arsenal-Stats
# Ben White
# Bukayo Saka
# Gabriel Dos Santos
# Aaron Ramsdale
# Martin Ødegaard
# Thomas Partey
# Kieran Tierney
# Granit Xhaka
# Emile Smith Rowe
# Alexandre Lacazette
# Martinelli
# Takehiro Tomiyasu
# Cédric Soares
# Albert Sambi Lokonga
# Pierre-Emerick Aubameyang
# Nuno Tavares
# Nicolas Pépé
# Rob Holding
# Bernd Leno
# Eddie Nketiah
# Mohamed Elneny
# Ainsley Maitland-Niles
# Pablo Marí
# Calum Chambers
# Sead Kolašinac
# Folarin Balogun
# Reiss Nelson
# Tottenham
# https://fbref.com/en/squads/361ca564/Tottenham-Hotspur-Stats
# Hugo Lloris
# Harry Kane
# Pierre Højbjerg
# Eric Dier
# Son Heung-min
# Ben Davies
# Sergio Reguilón
# Emerson
# Cristian Romero
# Lucas Moura
# Oliver Skipp
# Davinson Sánchez
# Dejan Kulusevski
# Rodrigo Bentancur
# Japhet Tanganga
# Harry Winks
# Matt Doherty
# Dele Alli
# Ryan Sessegnon
# Tanguy Ndombele
# Steven Bergwijn
# Giovani Lo Celso
# Bryan
# Joe Rodon
# Dane Scarlett
# Manchester Utd
# https://fbref.com/en/squads/19538871/Manchester-United-Stats
# David de Gea
# Bruno Fernandes
# Harry Maguire
# Cristiano Ronaldo
# Scott McTominay
# Victor Lindelöf
# Fred
# Jadon Sancho
# Aaron Wan-Bissaka
# Luke Shaw
# Raphaël Varane
# Diogo Dalot
# Paul Pogba
# Mason Greenwood
# Alex Telles
# Nemanja Matić
# Marcus Rashford
# Anthony Elanga
# Edinson Cavani
# Eric Bailly
# Jesse Lingard
# Anthony Martial
# Phil Jones
# Daniel James
# Donny van de Beek
# Juan Mata
# Hannibal Mejbri
# Alejandro Garnacho
# West Ham
# https://fbref.com/en/squads/7c21e445/West-Ham-United-Stats
# Łukasz Fabiański
# Tomáš Souček
# Declan Rice
# Michail Antonio
# Jarrod Bowen
# Pablo Fornals
# Craig Dawson
# Backing off 0.0 seconds afters 1 tries calling function <function get_table at 0x000001B60479E948> with args ('https://fbref.com/en/players/3e9e06cb/matchlogs/2021-2022/summary/Craig-Dawson-Match-Logs',) and kwargs {}
# Backing off 0.1 seconds afters 2 tries calling function <function get_table at 0x000001B60479E948> with args ('https://fbref.com/en/players/3e9e06cb/matchlogs/2021-2022/summary/Craig-Dawson-Match-Logs',) and kwargs {}
# Backing off 0.3 seconds afters 3 tries calling function <function get_table at 0x000001B60479E948> with args ('https://fbref.com/en/players/3e9e06cb/matchlogs/2021-2022/summary/Craig-Dawson-Match-Logs',) and kwargs {}
# Backing off 5.6 seconds afters 4 tries calling function <function get_table at 0x000001B60479E948> with args ('https://fbref.com/en/players/3e9e06cb/matchlogs/2021-2022/summary/Craig-Dawson-Match-Logs',) and kwargs {}
# Aaron Cresswell
# Saïd Benrahma
# Vladimír Coufal
# Kurt Zouma
# Ben Johnson
# Manuel Lanzini
# Angelo Ogbonna
# Issa Diop
# Arthur Masuaku
# Nikola Vlašić
# Ryan Fredericks
# Mark Noble
# Andriy Yarmolenko
# Alphonse Areola
# Harrison Ashby
# Sonny Perkins
# Daniel Chesters
# Alex Král
# Wolves
# https://fbref.com/en/squads/8cec06e1/Wolverhampton-Wanderers-Stats
# José Sá
# Conor Coady
# Max Kilman
# Romain Saïss
# João Moutinho
# Rúben Neves
# Raúl Jiménez
# Nélson Semedo
# Hwang Hee-chan
# Leander Dendoncker
# Fernando Marçal
# Francisco Trincão
# Daniel Podence
# Rayan Aït Nouri
# Adama Traoré
# Jonny Castro
# Fábio Silva
# Willy Boly
# Ki-Jana Hoever
# Toti Gomes
# Luke Cundle
# Pedro Neto
# Chiquinho
# Chem Campbell
# Morgan Gibbs-White
# Newcastle Utd
# https://fbref.com/en/squads/b2b47a98/Newcastle-United-Stats
# Allan Saint-Maximin
# Joelinton
# Fabian Schär
# Joe Willock
# Martin Dúbravka
# Jonjo Shelvey
# Jamaal Lascelles
# Ryan Fraser
# Emil Krafth
# Miguel Almirón
# Javier Manquillo
# Matt Ritchie
# Chris Wood
# Callum Wilson
# Jacob Murphy
# Sean Longstaff
# Dan Burn
# Matt Targett
# Ciaran Clark
# Isaac Hayden
# Karl Darlow
# Bruno Guimarães
# Federico Fernández
# Freddie Woodman
# Kieran Trippier
# Jamal Lewis
# Paul Dummett
# Jeff Hendrick
# Dwight Gayle
# Leicester City
# https://fbref.com/en/squads/a2d435b3/Leicester-City-Stats
# Kasper Schmeichel
# Çağlar Söyüncü
# Youri Tielemans
# James Maddison
# Harvey Barnes
# Luke Thomas
# Daniel Amartey
# Kiernan Dewsbury Hall
# Wilfred Ndidi
# Timothy Castagne
# Jamie Vardy
# Ademola Lookman
# Ricardo Pereira
# Boubakary Soumaré
# Patson Daka
# Jonny Evans
# Kelechi Iheanacho
# Marc Albrighton
# James Justin
# Nampalys Mendy
# Jannik Vestergaard
# Ryan Bertrand
# Hamza Choudhury
# Ayoze Pérez
# Wesley Fofana
# Kasey McAteer
# Brighton
# https://fbref.com/en/squads/d07537b9/Brighton-and-Hove-Albion-Stats
# Robert Sánchez
# Marc Cucurella
# Leandro Trossard
# Joël Veltman
# Neal Maupay
# Lewis Dunk
# Yves Bissouma
# Pascal Groß
# Jakub Moder
# Alexis Mac Allister
# Adam Lallana
# Tariq Lamptey
# Shane Duffy
# Adam Webster
# Solly March
# Dan Burn
# Danny Welbeck
# Enock Mwepu
# Steven Alzate
# Moisés Caicedo
# Aaron Connolly
# Jason Steele
# Jeremy Sarmiento
# Taylor Richards
# Evan Ferguson
# Jürgen Locadia
# Brentford
# https://fbref.com/en/squads/cd051869/Brentford-Stats
# Pontus Jansson
# Christian Nørgaard
# Ethan Pinnock
# Backing off 0.0 seconds afters 1 tries calling function <function get_table at 0x000001B60479E948> with args ('https://fbref.com/en/players/e541326e/matchlogs/2021-2022/summary/Ethan-Pinnock-Match-Logs',) and kwargs {}
# Backing off 0.6 seconds afters 2 tries calling function <function get_table at 0x000001B60479E948> with args ('https://fbref.com/en/players/e541326e/matchlogs/2021-2022/summary/Ethan-Pinnock-Match-Logs',) and kwargs {}
# Backing off 1.1 seconds afters 3 tries calling function <function get_table at 0x000001B60479E948> with args ('https://fbref.com/en/players/e541326e/matchlogs/2021-2022/summary/Ethan-Pinnock-Match-Logs',) and kwargs {}
# Backing off 5.2 seconds afters 4 tries calling function <function get_table at 0x000001B60479E948> with args ('https://fbref.com/en/players/e541326e/matchlogs/2021-2022/summary/Ethan-Pinnock-Match-Logs',) and kwargs {}
# Bryan Mbeumo
# Rico Henry
# Ivan Toney
# Vitaly Janelt
# Sergi Canós
# David Raya
# Kristoffer Ajer
# Mathias Jensen
# Álvaro Fernández
# Frank Onyeka
# Mads Roerslev
# Yoane Wissa
# Shandon Baptiste
# Christian Eriksen
# Mathias Jørgensen
# Mads Bech Sørensen
# Saman Ghoddos
# Charlie Goode
# Jonas Lössl
# Josh Dasilva
# Dominic Thompson
# Marcus Forss
# Mads Bidstrup
# Tariqe Fosu
# Finley Stevens
# Southampton
# https://fbref.com/en/squads/33c895d4/Southampton-Stats
# James Ward-Prowse
# Oriol Romeu
# Mohammed Salisu
# Jan Bednarek
# Kyle Walker-Peters
# Valentino Livramento
# Che Adams
# Mohamed Elyounoussi
# Armando Broja
# Fraser Forster
# Nathan Redmond
# Romain Perraud
# Alex McCarthy
# Adam Armstrong
# Stuart Armstrong
# Ibrahima Diallo
# Nathan Tella
# Lyanco
# Jack Stephens
# Moussa Djenepo
# Theo Walcott
# Yan Valery
# Shane Long
# Willy Caballero
# William Smallbone
# Crystal Palace
# https://fbref.com/en/squads/47c64c55/Crystal-Palace-Stats
# Marc Guéhi
# Tyrick Mitchell
# Conor Gallagher
# Vicente Guaita
# Joachim Andersen
# Wilfried Zaha
# Joel Ward
# Cheikhou Kouyaté
# Jordan Ayew
# Jeffrey Schlupp
# Odsonne Édouard
# James McArthur
# Christian Benteke
# Michael Olise
# Jean-Philippe Mateta
# Nathaniel Clyne
# Will Hughes
# Luka Milivojević
# James Tomkins
# Jack Butland
# Eberechi Eze
# Jaïro Riedewald
# Jesuran Rak Sakyi
# Nathan Ferguson
# Aston Villa
# https://fbref.com/en/squads/8602292d/Aston-Villa-Stats
# Matty Cash
# Emiliano Martínez
# Tyrone Mings
# John McGinn
# Ollie Watkins
# Ezri Konsa
# Douglas Luiz
# Jacob Ramsey
# Danny Ings
# Emi Buendía
# Matt Targett
# Philippe Coutinho
# Ashley Young
# Lucas Digne
# Marvelous Nakamba
# Leon Bailey
# Axel Tuanzebe
# Calum Chambers
# Kortney Hause
# Anwar El Ghazi
# Morgan Sanson
# Carney Chukwuemeka
# Bertrand Traoré
# Jed Steer
# Cameron Archer
# Tim Iroegbunam
# Keinan Davis
# Trézéguet
# Jaden Philogene Bidace
# Wesley Moraes
# Leeds United
# https://fbref.com/en/squads/5bfb9659/Leeds-United-Stats
# Illan Meslier
# Stuart Dallas
# Raphael Dias Belloli
# Jack Harrison
# Daniel James
# Luke Ayling
# Diego Llorente
# Rodrigo
# Mateusz Klich
# Pascal Struijk
# Liam Cooper
# Adam Forshaw
# Junior Firpo
# Kalvin Phillips
# Robin Koch
# Tyler Roberts
# Jamie Shackleton
# Patrick Bamford
# Joe Gelhardt
# Charlie Cresswell
# Cody Drameh
# Leo Fuhr Hjelde
# Sam Greenwood
# Crysencio Summerville
# Lewis Bate
# Kristoffer Klaesson
# Hélder Costa
# Liam McCarron
# Stuart McKinstry
# Burnley
# https://fbref.com/en/squads/943e8050/Burnley-Stats
# Nick Pope
# James Tarkowski
# Dwight McNeil
# Josh Brownhill
# Ashley Westwood
# Charlie Taylor
# Ben Mee
# Matthew Lowton
# Maxwel Cornet
# Chris Wood
# Aaron Lennon
# Wout Weghorst
# Jack Cork
# Connor Roberts
# Jay Rodriguez
# Nathan Collins
# Backing off 0.0 seconds afters 1 tries calling function <function get_table at 0x000001B60479E948> with args ('https://fbref.com/en/players/a8c19eb8/matchlogs/2021-2022/summary/Nathan-Collins-Match-Logs',) and kwargs {}
# Backing off 0.0 seconds afters 2 tries calling function <function get_table at 0x000001B60479E948> with args ('https://fbref.com/en/players/a8c19eb8/matchlogs/2021-2022/summary/Nathan-Collins-Match-Logs',) and kwargs {}
# Backing off 0.9 seconds afters 3 tries calling function <function get_table at 0x000001B60479E948> with args ('https://fbref.com/en/players/a8c19eb8/matchlogs/2021-2022/summary/Nathan-Collins-Match-Logs',) and kwargs {}
# Backing off 5.1 seconds afters 4 tries calling function <function get_table at 0x000001B60479E948> with args ('https://fbref.com/en/players/a8c19eb8/matchlogs/2021-2022/summary/Nathan-Collins-Match-Logs',) and kwargs {}
# Backing off 14.6 seconds afters 5 tries calling function <function get_table at 0x000001B60479E948> with args ('https://fbref.com/en/players/a8c19eb8/matchlogs/2021-2022/summary/Nathan-Collins-Match-Logs',) and kwargs {}
# Backing off 24.3 seconds afters 6 tries calling function <function get_table at 0x000001B60479E948> with args ('https://fbref.com/en/players/a8c19eb8/matchlogs/2021-2022/summary/Nathan-Collins-Match-Logs',) and kwargs {}
# Backing off 53.8 seconds afters 7 tries calling function <function get_table at 0x000001B60479E948> with args ('https://fbref.com/en/players/a8c19eb8/matchlogs/2021-2022/summary/Nathan-Collins-Match-Logs',) and kwargs {}
# Jóhann Berg Guðmundsson
# Erik Pieters
# Matěj Vydra
# Ashley Barnes
# Wayne Hennessey
# Dale Stephens
# Kevin Long
# Everton
# https://fbref.com/en/squads/d3fd31cc/Everton-Stats
# Jordan Pickford
# Michael Keane
# Séamus Coleman
# Allan
# Demarai Gray
# Richarlison
# Abdoulaye Doucouré
# Ben Godfrey
# Anthony Gordon
# Mason Holgate
# Andros Townsend
# Alex Iwobi
# Lucas Digne
# Dominic Calvert-Lewin
# Jonjoe Kenny
# Yerry Mina
# Salomón Rondón
# Vitaliy Mykolenko
# André Gomes
# Donny van de Beek
# Fabian Delph
# Jarrad Branthwaite
# Asmir Begović
# Tom Davies
# Jean-Philippe Gbamin
# Ellis Simms
# Dele Alli
# Lewis Dobbin
# Tyler Onyango
# Anwar El Ghazi
# Cenk Tosun
# Moise Kean
# Watford
# https://fbref.com/en/squads/2abfe087/Watford-Stats
# Moussa Sissoko
# Emmanuel Dennis
# Craig Cathcart
# Joshua King
# Kiko Femenía
# Ben Foster
# Juraj Kucka
# Ismaila Sarr
# Tom Cleverley
# Imran Louza
# William Troost-Ekong
# Hassane Kamara
# Samir Santos
# João Pedro
# Cucho
# Daniel Bachmann
# Adam Masina
# Christian Kabasele
# Jeremy Ngakia
# Danny Rose
# Edo Kayembe
# Francisco Sierralta
# Ken Sema
# Oghenekaro Etebo
# Ozan Tufan
# Nicolas Nkoulou
# Samuel Kalu
# Ashley Fletcher
# Troy Deeney
# Dan Gosling
# Norwich City
# https://fbref.com/en/squads/1c781004/Norwich-City-Stats
# Teemu Pukki
# Kenny McLean
# Grant Hanley
# Max Aarons
# Ben Gibson
# Tim Krul
# Pierre Lees-Melou
# Milot Rashica
# Brandon Williams
# Josh Sargent
# Billy Gilmour
# Mathias Normann
# Ozan Kabak
# Dimitris Giannoulis
# Angus Gunn
# Kieran Dowell
# Sam Byram
# Adam Idah
# Lukas Rupp
# Przemysław Płacheta
# Todd Cantwell
# Andrew Omobamidele
# Jakob Sørensen
# Christos Tzolis
# Christoph Zimmermann
# Jon Rowe
# Bali Mumba

# %%
# get the player name matching dictionary
with open(path/'match_list.json') as f:
  match_list = json.load(f)

match_list
# Out:
# {'Fabinho': 'Fabio Henrique Tavares',
#  'Alisson': 'Alisson Ramses Becker',
#  'Joël Matip': 'Joel Matip',
#  'Joe Gomez': 'Joseph Gomez',
#  'Naby Keïta': 'Naby Keita',
#  'Adrián': 'Adrián San Miguel del Castillo',
#  'Thiago Alcántara': 'Thiago Alcántara do Nascimento',
#  'Allan': 'Allan Marques Loureiro',
#  'Richarlison': 'Richarlison de Andrade',
#  'Gylfi Sigurðsson': 'Gylfi Sigurdsson',
#  'Séamus Coleman': 'Seamus Coleman',
#  'André Gomes': 'André Filipe Tavares Gomes',
#  'Bernard': 'Bernard Anício Caldeira Duarte',
#  'Çağlar Söyüncü': 'Çaglar Söyüncü',
#  'Bruno Fernandes': 'Bruno Miguel Borges Fernandes',
#  'Fred': 'Frederico Rodrigues de Paula Santos',
#  'Nemanja Matić': 'Nemanja Matic',
#  'Alex Telles': 'Alex Nicolao Telles',
#  'Pierre Højbjerg': 'Pierre-Emile Højbjerg',
#  'Son Heung-min': 'Heung-Min Son',
#  'Lucas Moura': 'Lucas Rodrigues Moura da Silva',
#  'Érik Lamela': 'Erik Lamela',
#  'Dele Alli': 'Bamidele Alli',
#  'Carlos Vinícius': 'Carlos Vinicius Alves Morais',
#  'Ederson': 'Ederson Santana de Moraes',
#  'Rodri': 'Rodrigo Hernandez',
#  'Rúben Dias': 'Rúben Santos Gato Alves Dias',
#  'João Cancelo': 'João Pedro Cavaco Cancelo',
#  'İlkay Gündoğan': 'Ilkay Gündogan',
#  'Gabriel Jesus': 'Gabriel Fernando de Jesus',
#  'Ferrán Torres': 'Ferran Torres',
#  'Bernardo Silva': 'Bernardo Mota Veiga de Carvalho e Silva',
#  'Fernandinho': 'Fernando Luiz Rosa',
#  'Eric García': 'Eric Garcia',
#  'Matty Cash': 'Matthew Cash',
#  'Douglas Luiz': 'Douglas Luiz Soares de Paulo',
#  'Ezri Konsa': 'Ezri Konsa Ngoyo',
#  'Trézéguet': 'Mahmoud Ahmed Ibrahim Hassan',
#  'Ben Chilwell': 'Benjamin Chilwell',
#  'Thiago Silva': 'Thiago Emiliano da Silva',
#  'Mateo Kovačić': 'Mateo Kovacic',
#  'Jorginho': 'Jorge Luiz Frello Filho',
#  'Emerson Palmieri': 'Emerson Palmieri dos Santos',
#  'Oriol Romeu': 'Oriol Romeu Vidal',
#  'Dan Nlundulu': "Daniel N'Lundulu",
#  'Łukasz Fabiański': 'Lukasz Fabianski',
#  'Tomáš Souček': 'Tomas Soucek',
#  'Vladimír Coufal': 'Vladimir Coufal',
#  'Felipe Anderson': 'Felipe Anderson Pereira Gomes',
#  'Rui Patrício': 'Rui Pedro dos Santos Patrício',
#  'Pedro Neto': 'Pedro Lomba Neto',
#  'Daniel Podence': 'Daniel Castelo Podence',
#  'Nélson Semedo': 'Nélson Cabral Semedo',
#  'Rúben Neves': 'Rúben Diogo da Silva Neves',
#  'João Moutinho': 'João Filipe Iria Santos Moutinho',
#  'Rayan Aït Nouri': 'Rayan Ait Nouri',
#  'Fábio Silva': 'Fabio Silva',
#  'Rúben Vinagre': 'Rúben Gonçalo Silva Nascimento Vinagre',
#  'Vitinha': 'Vitor Ferreira',
#  'Rodrigo': 'Rodrigo Moreno',
#  'Pablo Hernández': 'Pablo Hernández Domínguez',
#  'Ian Carlo Poveda': 'Ian Carlo Poveda-Ocampo',
#  'Joelinton': 'Joelinton Cássio Apolinário de Lira',
#  'Luka Milivojević': 'Luka Milivojevic',
#  'Jaïro Riedewald': 'Jairo Riedewald',
#  'Gabriel Dos Santos': 'Gabriel Magalhães',
#  'Willian': 'Willian Borges Da Silva',
#  'Dani Ceballos': 'Daniel Ceballos Fernández',
#  'David Luiz': 'David Luiz Moreira Marinho',
#  'Eddie Nketiah': 'Edward Nketiah',
#  'Joe Willock': 'Joseph Willock',
#  'Sead Kolašinac': 'Sead Kolasinac',
#  'Martinelli': 'Gabriel Teodoro Martinelli Silva',
#  'Solly March': 'Solomon March',
#  'Bernardo': 'Bernardo Fernandes da Silva Junior',
#  'Jóhann Berg Guðmundsson': 'Johann Berg Gudmundsson',
#  'Matěj Vydra': 'Matej Vydra',
#  'Andre-Frank Zambo Anguissa': 'André-Frank Zambo Anguissa',
#  'Semi Ajayi': 'Oluwasemilogo Adesewo Ibidapo Ajayi',
#  'Branislav Ivanović': 'Branislav Ivanovic',
#  'Filip Krovinović': 'Filip Krovinovic',
#  'Ahmed Hegazi': 'Ahmed El-Sayed Hegazi',
#  'Harvey Elliot': 'Harvey Elliott',
#  'Angeliño': 'Angelo Ogbonna',
#  'Thomas Doyle': 'Tommy Doyle',
#  'Diogo Dalot': 'José Diogo Dalot Teixeira',
#  'Pedro': 'Pedro Rodríguez Ledesma',
#  'Ricardo Pereira': 'Ricardo Domingos Barbosa Pereira',
#  'Gedson Fernandes': 'Gedson Carvalho Fernandes',
#  "Georges-Kévin N'Koudou": 'Georges-Kévin Nkoudou',
#  'Jonny Castro': 'Jonathan Castro Otto',
#  'Jesús Vallejo': 'Jesús Vallejo Lázaro',
#  'Bruno Jordão': 'Bruno André Cavaco Jordao',
#  'Mattéo Guendouzi': 'Matteo Guendouzi',
#  'Richairo Živković': 'Richairo Zivkovic',
#  'Danny Drinkwater': 'Daniel Drinkwater',
#  'Martin Dúbravka': 'Martin Dubravka',
#  'Yoshinori Mutō': 'Yoshinori Muto',
#  'Ki Sung-yueng': 'Sung-yueng Ki',
#  'Roberto': 'Roberto Jimenez Gago',
#  'Javier Hernández': 'Javier Hernández Balcázar',
#  'Frederic Guilbert': 'Frédéric Guilbert',
#  'Björn Engels': 'Bjorn Engels',
#  'Pepe Reina': 'José Reina',
#  'Jota': 'José Ignacio Peleteiro Romallo',
#  'Arnaut Groeneveld': 'Arnaut Danjuma Groeneveld',
#  'Étienne Capoue': 'Etienne Capoue',
#  'Kiko Femenía': 'Francisco Femenía Far',
#  'Ismaila Sarr': 'Ismaila Sarr',
#  'João Pedro': 'João Pedro Junqueira de Jesus',
#  'Max Aarons': 'Max Aarons',
#  'Emi Buendía': 'Emiliano Buendía Stati',
#  'Mario Vrančić': 'Mario Vrancic',
#  'Josip Drmić': 'Josip Drmic',
#  'Ralf Fährmann': 'Ralf Fahrmann',
#  'Danilo': 'Danilo Luiz da Silva',
#  'Petr Čech': 'Petr Cech',
#  'Idrissa Gana Gueye': 'Idrissa Gueye',
#  'Marko Arnautović': 'Marko Arnautovic',
#  'Xande Silva': 'Alexandre Nascimento Costa Silva',
#  'Julián Speroni': 'Julian Speroni',
#  'Kenedy': 'Robert Kenedy Nunes do Nascimento',
#  'Joselu': 'Jose Luis Mato Sanmartín',
#  'Asmir Begović': 'Asmir Begović',
#  'Kayne Ramsey': 'Kayne Ramsay',
#  'Bruno': 'Bruno Saltor Grau',
#  'Junior Hoilett': 'David Junior Hoilett',
#  'Greg Cunningham': 'Greg Cunninghamm',
#  'Jazz Richards': 'Ashley Darel Jazz Richards',
#  'Jean Seri': 'Jean Michael Seri',
#  'Fabricio': 'Fabricio Agosto Ramírez',
#  'Lazar Marković': 'Lazar Markovic',
#  'Mathias Jørgensen': 'Mathias Jorgensen',
#  'Steve Mounié': 'Steve Mounie',
#  'Jon Gorenc Stanković': 'Jon Gorenc Stankovic',
#  'Matty Daly': 'Matthew Daly',
#  'Yaya Touré': 'Gnegneri Yaya Touré',
#  'Brahim Díaz': 'Brahim Diaz',
#  'Zlatan Ibrahimović': 'Zlatan Ibrahimovic',
#  'Marko Grujić': 'Marko Grujic',
#  'Charly Musonda Jr.': 'Charly Musonda',
#  'Nikola Vlašić': 'Nikola Vlasic',
#  'Aleksandar Dragović': 'Aleksandar Dragovic',
#  'Eldin Jakupović': 'Eldin Jakupovic',
#  'Rob Elliot': 'Robert Elliot',
#  'Jesús Gámez': 'Jesús Gámez Duarte',
#  'Massadio Haïdara': 'Massadio Haidara',
#  'Lee Chung-yong': 'Chung-yong Lee',
#  'Freddie Ladapo': 'Olayinka Fredrick Oladotun Ladapo',
#  'João Mário': 'João Mário Naval Costa Eduardo',
#  'José Fonte': 'Jose Fonte',
#  'Younès Kaboul': 'Younes Kaboul',
#  'Izzy Brown': 'Isaiah Brown',
#  'Dušan Tadić': 'Dusan Tadic',
#  'Àngel Rangel': 'Angel Rangel',
#  'Badou Ndiaye': 'Papa Alioune Ndiaye',
#  'Jesé': 'Jesé Rodríguez Ruiz',
#  'Tom Edwards': 'Thomas Edwards',
#  'Kostas Stafylidis': 'Konstantinos Stafylidis',
#  'Lasse Sørensen': 'Lasse Sorenson',
#  'Bojan Krkić': 'Bojan Krkic',
#  'Allan Nyom': 'Allan-Roméo Nyom',
#  'Ahmed Elmohamady': 'Ahmed El Mohamady',
#  'Hélder Costa': 'Hélder Wander Sousa de Azevedo e Costa',
#  'Mohamed Elneny': 'Mohamed Naser El Sayed Elneny',
#  'Emile Smith-Rowe': 'Emile Smith Rowe',
#  'Ivan Cavaleiro': 'Ivan Ricardo Neves Abreu Cavaleiro',
#  'Bobby Reid': 'Bobby Decordova-Reid',
#  'Ahmed El-Sayed Hegazi': 'Ahmed El-Sayed Hegazy',
#  'Kiko Casilla': 'Francisco Casilla Cortés',
#  'Willian José': 'Willian José Da Silva',
#  'Kostas Tsimikas': 'Konstantinos Tsimikas',
#  'Okay Yokuşlu': 'Okay Yokuslu',
#  'Khanya Leshabela': 'Thakgalo Leshabela',
#  'Jaden Philogene Bidace': 'Jaden Philogene-Bidace',
#  'William Thomas Fish': 'William Fish',
#  'David Raya': 'David Raya Martin',
#  'Oghenekaro Etebo': 'Oghenekaro Peter Etebo',
#  'Ismaïla Sarr': 'Ismaila Sarr',
#  'Cucho': 'Juan Camilo Hernández Suárez',
#  'Enoch Mwepu': 'Enock Mwepu',
#  'Emiliano Buendía': 'Emiliano Buendía StatiJosé Malheiro de Sá',
#  'José Sá': 'José Malheiro de Sá',
#  'Francisco Trincão': 'Francisco Machado Mota de Castro Trincão',
#  'Valentino Livramento': 'Tino Livramento',
#  'Nuno Tavares': 'Nuno Varela Tavares',
#  'Jesuran Rak Sakyi': 'Jesurun Rak-Sakyi',
#  'Maximillian Aarons': 'Max Aarons',
#  'Josh Sargent': 'Joshua Sargent',
#  'Junior Firpo': 'Héctor Junior Firpo Adames',
#  'Imran Louza': 'Imrân Louza',
#  'Bryan': 'Bryan Gil Salvatierra',
#  'Kiernan Dewsbury Hall': 'Kiernan Dewsbury-Hall',
#  'Cristiano Ronaldo': 'Cristiano Ronaldo dos Santos Aveiro',
#  'Emerson': 'Emerson Aparecido Leite de Souza Junior',
#  'Mads Roerslev': 'Mads Roerslev Rasmussen',
#  'Odsonne Édouard': 'Odsonne Edouard',
#  'Hwang Hee-chan': 'Hee-Chan Hwang',
#  'Asmir Begovic': 'Asmir Begović',
#  'Caoimhín Kelleher': 'Caoimhin Kelleher',
#  'Lyanco': 'Lyanco Evangelista Silveira Neves Vojnovic',
#  'Przemysław Płacheta': 'Przemyslaw Placheta',
#  'James Mcatee': 'James McAtee',
#  'Jakob Sørensen': 'Jacob Sørensen',
#  'Alex Král': 'Alex Kral',
#  'Jon Rowe': 'Jonathan Rowe',
#  'Toti Gomes': 'Toti António Gomes',
#  'Philippe Coutinho': 'Philippe Coutinho Correia',
#  'Vitaliy Mykolenko': 'Vitalii Mykolenko',
#  'Samir Santos': 'Samir Caetano de Souza Santos',
#  'Chiquinho': 'Francisco Jorge Tomás Oliveira',
#  'Josh Dasilva': 'Pelenda Joshua Dasilva',
#  'Bruno Guimarães': 'Bruno Guimarães Rodriguez Moura',
#  'Kayky Chagas': 'Kayky da Silva Chagas',
#  'Tariqe Fosu': 'Tariqe Fosu-Henry'}

# %%
team_list = {}
team_list['Brighton'] = 'Brighton and Hove Albion'
team_list['Leeds United'] = 'Leeds'
team_list['Manchester Utd'] = 'Manchester United'
team_list['Newcastle Utd'] = 'Newcastle United'
team_list['Norwich City'] = 'Norwich'
team_list['Sheffield Utd'] = 'Sheffield United'
team_list['Tottenham'] = 'Tottenham Hotspur'
team_list['West Brom'] = 'West Bromwich Albion'
team_list['West Ham'] = 'West Ham United'
team_list['Wolves'] = 'Wolverhampton Wanderers'

# %%
df_enhanced = df_enhanced.loc[df_enhanced[df_enhanced['round'].str[-2:] != 'on'].index]
df_enhanced = df_enhanced.loc[df_enhanced[df_enhanced['squad'] != 'CSKA Moscow'].index]

# %%
# replace non-matching names/teams and extract gw as integer
df_enhanced['alt_name'] = df_enhanced['player'].replace(match_list)
df_enhanced['squad'] = df_enhanced['squad'].replace(team_list)
df_enhanced['round'] = df_enhanced['round'].str[-2:].astype('int')

# %%
# remove duplicated (happens when players transferred within season)
df_enhanced = df_enhanced.drop_duplicates()

# %%
df_enhanced
# Out:
#          season      player        date            squad            comp  \
# 0     2021-2022     Ederson  2021-08-15  Manchester City  Premier League
# 1     2021-2022     Ederson  2021-08-21  Manchester City  Premier League
# 2     2021-2022     Ederson  2021-08-28  Manchester City  Premier League
# 3     2021-2022     Ederson  2021-09-11  Manchester City  Premier League
# 4     2021-2022     Ederson  2021-09-18  Manchester City  Premier League
# ...         ...         ...         ...              ...             ...
# 9376  2021-2022    Jon Rowe  2022-03-13          Norwich  Premier League
# 9377  2021-2022    Jon Rowe  2022-04-02          Norwich  Premier League
# 9378  2021-2022    Jon Rowe  2022-04-16          Norwich  Premier League
# 9379  2021-2022    Jon Rowe  2022-04-23          Norwich  Premier League
# 9380  2021-2022  Bali Mumba  2021-08-21          Norwich  Premier League
#
#       round shots_total shots_on_target touches pressures  ...   xa sca gca  \
# 0         1           0               0      22         0  ...  0.0   2   0
# 1         2           0               0      14         0  ...  0.0   0   0
# 2         3           0               0      37         0  ...  0.0   0   0
# 3         4           0               0      26         0  ...  0.0   0   0
# 4         5           0               0      40         0  ...  0.0   0   0
# ...     ...         ...             ...     ...       ...  ...  ...  ..  ..
# 9376     29           2               1      15         6  ...  0.0   0   0
# 9377     31           0               0       8         6  ...  0.0   0   0
# 9378     33           0               0       6         4  ...  0.0   0   0
# 9379     34           1               1      19        11  ...  0.1   1   0
# 9380      2           0               0      19        12  ...  0.0   0   0
#
#      passes_completed passes passes_pct carries dribbles_completed dribbles  \
# 0                  20     22       90.9      10                  0        0
# 1                  12     12      100.0       6                  0        0
# 2                  31     37       83.8      25                  0        0
# 3                  22     24       91.7      10                  0        0
# 4                  39     39      100.0      28                  0        0
# ...               ...    ...        ...     ...                ...      ...
# 9376                6      9       66.7      13                  2        3
# 9377                1      4       25.0       6                  0        0
# 9378                2      3       66.7       5                  0        1
# 9379               11     13       84.6      14                  1        1
# 9380                7     10       70.0       9                  0        1
#
#                        alt_name
# 0     Ederson Santana de Moraes
# 1     Ederson Santana de Moraes
# 2     Ederson Santana de Moraes
# 3     Ederson Santana de Moraes
# 4     Ederson Santana de Moraes
# ...                         ...
# 9376              Jonathan Rowe
# 9377              Jonathan Rowe
# 9378              Jonathan Rowe
# 9379              Jonathan Rowe
# 9380                 Bali Mumba
#
# [9163 rows x 25 columns]

# %%
# create date field in same format as enhanced data
df_latest['date'] = df_latest['kickoff_time'].str[:10]

# %%
# check if any names aren't matching
enhanced_players = df_enhanced[df_enhanced['date'].isin(df_latest['date'].unique())]['alt_name'].unique().tolist()
standard_players = df_latest['player'].unique().tolist()

unmatched_players = [x for x in enhanced_players if x not in standard_players]
unmatched_players
# Out:
# []

# %%
# check if any teams aren't matching
enhanced_teams = df_enhanced[df_enhanced['date'].isin(df_latest['date'].unique())]['squad'].unique().tolist()
standard_teams = df_latest['team'].unique().tolist()

unmatched_teams = [x for x in enhanced_teams if x not in standard_teams]
unmatched_teams
# Out:
# []

# %%
# any additional corrections
# match_list['Alejandro Garnacho'] = 'Alejandro Garnacho Ferreyra'
# match_list['Josh Dasilva'] = 'Pelenda Joshua Dasilva'
# match_list['Bruno Guimarães'] = 'Bruno Guimarães Rodriguez Moura'
# match_list['Samir Santos'] = 'Samir Caetano de Souza Santos'
# match_list['Hwang Hee-chan'] = 'Hee-Chan Hwang'

# match_list['Sadio Man�'] = 'Sadio Mané'
# match_list['Jo�l Matip'] = 'Joel Matip'
# match_list['Thiago Alc�ntara'] = 'Thiago Alcántara do Nascimento'
# match_list['Naby Ke�ta'] = 'Naby Keita'
# match_list['Luis D�az'] = 'Luis Díaz'
# match_list['Jos� S�'] = 'José Malheiro de Sá'
# match_list['Romain Sa�ss'] = 'Romain Saïss'
# match_list['N�lson Semedo'] = 'Nélson Cabral Semedo'
# match_list['Ra�l Jim�nez'] = 'Raúl Jiménez'
# match_list['Jo�o Moutinho'] = 'João Filipe Iria Santos Moutinho'
# match_list['R�ben Neves'] = 'Rúben Diogo da Silva Neves'
# match_list['Rayan A�t Nouri'] = 'Rayan Ait Nouri'
# match_list['Fernando Mar�al'] = 'Fernando Marçal'
# match_list['Emiliano Mart�nez'] = 'Emiliano Martínez'
# match_list['Emi Buend�a'] = 'Emiliano Buendía Stati'
# match_list['Fabian Sch�r'] = 'Fabian Schär'
# match_list['Martin D�bravka'] = 'Martin Dubravka'
# match_list['Miguel Almir�n'] = 'Miguel Almirón'
# match_list['Bruno Guimar�es'] = 'Bruno Guimarães Rodriguez Moura'
# match_list['Kiko Femen�a'] = 'Francisco Femenía Far'

# %%
# replace additional non-matching names
# df_enhanced['alt_name'] = df_enhanced['player'].replace(match_list)

# %%
# make sure there are no non matches after update
# enhanced_teams = df_enhanced[df_enhanced['date'].isin(df_latest['date'].unique())]['squad'].unique().tolist()
# standard_teams = df_latest['team'].unique().tolist()

# unmatched_teams = [x for x in enhanced_teams if x not in standard_teams]
# unmatched_teams

# %%
# if match list was updated then update the file
# json_file = json.dumps(match_list)
# f = open(path/"match_list.json","w")
# f.write(json_file)
# f.close()

# %%
# check there are no duplicates in the join fields for the enhanced data
assert(len(df_enhanced[df_enhanced.duplicated(subset=['alt_name', 'date'], keep=False)]) == 0)

# %%
df_latest[df_latest.duplicated(subset=['date','player','team'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [player, gw, position, minutes, team, opponent_team, relative_market_value_team, relative_market_value_opponent_team, was_home, total_points, assists, bonus, bps, clean_sheets, creativity, goals_conceded, goals_scored, ict_index, influence, own_goals, penalties_missed, penalties_saved, red_cards, saves, selected, team_a_score, team_h_score, threat, transfers_balance, transfers_in, transfers_out, yellow_cards, kickoff_time, season, play_proba, date]
# Index: []
#
# [0 rows x 36 columns]

# %%
# check there are no duplicates in the join fields for the standard data
assert(len(df_train[df_train.duplicated(subset=['date','player','team'])]) == 0)

# %%
# df_train[df_train.duplicated(subset=['date','player','team'])]

# %%
# join standard and enhanced dataframes
df_latest_further = df_latest.merge(df_enhanced.drop(['player', 'season', 'round'], axis=1), 
                                   left_on=['date', 'player', 'team'], 
                                   right_on=['date', 'alt_name', 'squad'], how='left')

# %%
# drop the alt name field and check the length of the standard
# dataframe has not increased
df_latest_further = df_latest_further.drop(['alt_name'], axis=1)
assert(len(df_latest_further) == len(df_latest_further))

# %%
# add crowds field
df_latest_further['crowds'] = 1

# %%
assert(sum(df_latest_further[df_latest_further['minutes'] > 0]['xg'].isnull()) == 0)

# %%
df_latest_further[df_latest_further['minutes'] > 0][df_latest_further[df_latest_further['minutes'] > 0]['xg'].isnull()]
# Out:
# Empty DataFrame
# Columns: [player, gw, position, minutes, team, opponent_team, relative_market_value_team, relative_market_value_opponent_team, was_home, total_points, assists, bonus, bps, clean_sheets, creativity, goals_conceded, goals_scored, ict_index, influence, own_goals, penalties_missed, penalties_saved, red_cards, saves, selected, team_a_score, team_h_score, threat, transfers_balance, transfers_in, transfers_out, yellow_cards, kickoff_time, season, play_proba, date, squad, comp, shots_total, shots_on_target, touches, pressures, tackles, interceptions, blocks, xg, npxg, xa, sca, gca, passes_completed, passes, passes_pct, carries, dribbles_completed, dribbles, crowds]
# Index: []
#
# [0 rows x 57 columns]

# %%
df_enhanced
# Out:
#          season      player        date            squad            comp  \
# 0     2021-2022     Ederson  2021-08-15  Manchester City  Premier League
# 1     2021-2022     Ederson  2021-08-21  Manchester City  Premier League
# 2     2021-2022     Ederson  2021-08-28  Manchester City  Premier League
# 3     2021-2022     Ederson  2021-09-11  Manchester City  Premier League
# 4     2021-2022     Ederson  2021-09-18  Manchester City  Premier League
# ...         ...         ...         ...              ...             ...
# 9376  2021-2022    Jon Rowe  2022-03-13          Norwich  Premier League
# 9377  2021-2022    Jon Rowe  2022-04-02          Norwich  Premier League
# 9378  2021-2022    Jon Rowe  2022-04-16          Norwich  Premier League
# 9379  2021-2022    Jon Rowe  2022-04-23          Norwich  Premier League
# 9380  2021-2022  Bali Mumba  2021-08-21          Norwich  Premier League
#
#       round shots_total shots_on_target touches pressures  ...   xa sca gca  \
# 0         1           0               0      22         0  ...  0.0   2   0
# 1         2           0               0      14         0  ...  0.0   0   0
# 2         3           0               0      37         0  ...  0.0   0   0
# 3         4           0               0      26         0  ...  0.0   0   0
# 4         5           0               0      40         0  ...  0.0   0   0
# ...     ...         ...             ...     ...       ...  ...  ...  ..  ..
# 9376     29           2               1      15         6  ...  0.0   0   0
# 9377     31           0               0       8         6  ...  0.0   0   0
# 9378     33           0               0       6         4  ...  0.0   0   0
# 9379     34           1               1      19        11  ...  0.1   1   0
# 9380      2           0               0      19        12  ...  0.0   0   0
#
#      passes_completed passes passes_pct carries dribbles_completed dribbles  \
# 0                  20     22       90.9      10                  0        0
# 1                  12     12      100.0       6                  0        0
# 2                  31     37       83.8      25                  0        0
# 3                  22     24       91.7      10                  0        0
# 4                  39     39      100.0      28                  0        0
# ...               ...    ...        ...     ...                ...      ...
# 9376                6      9       66.7      13                  2        3
# 9377                1      4       25.0       6                  0        0
# 9378                2      3       66.7       5                  0        1
# 9379               11     13       84.6      14                  1        1
# 9380                7     10       70.0       9                  0        1
#
#                        alt_name
# 0     Ederson Santana de Moraes
# 1     Ederson Santana de Moraes
# 2     Ederson Santana de Moraes
# 3     Ederson Santana de Moraes
# 4     Ederson Santana de Moraes
# ...                         ...
# 9376              Jonathan Rowe
# 9377              Jonathan Rowe
# 9378              Jonathan Rowe
# 9379              Jonathan Rowe
# 9380                 Bali Mumba
#
# [9163 rows x 25 columns]

# %%
df_train_new = pd.concat([df_train, df_latest_further], ignore_index=True, axis=0, sort=False)

# %%
df_train_new[df_train_new['player'] == 'Harry Kane'].tail()
# Out:
#             player  gw  position  minutes               team  \
# 133347  Harry Kane  30         4       90  Tottenham Hotspur
# 133813  Harry Kane  31         4       90  Tottenham Hotspur
# 134575  Harry Kane  32         4       90  Tottenham Hotspur
# 135348  Harry Kane  33         4       90  Tottenham Hotspur
# 136179  Harry Kane  34         4       90  Tottenham Hotspur
#
#                    opponent_team  relative_market_value_team  \
# 133347           West Ham United                         NaN
# 133813          Newcastle United                         NaN
# 134575               Aston Villa                         NaN
# 135348  Brighton and Hove Albion                         NaN
# 136179                 Brentford                         NaN
#
#         relative_market_value_opponent_team  was_home  total_points  ...   xa  \
# 133347                                  NaN      True            13  ...  0.7
# 133813                                  NaN      True             4  ...  0.9
# 134575                                  NaN     False            10  ...  0.6
# 135348                                  NaN      True             2  ...  0.3
# 136179                                  NaN     False             2  ...  0.0
#
#         sca  gca  passes_completed  passes  passes_pct  carries  \
# 133347  6.0  2.0              26.0    42.0        61.9     47.0
# 133813  7.0  2.0              16.0    25.0        64.0     27.0
# 134575  5.0  3.0              15.0    18.0        83.3     24.0
# 135348  2.0  0.0              12.0    18.0        66.7     18.0
# 136179    1    0                10      15        66.7       17
#
#         dribbles_completed  dribbles  crowds
# 133347                 3.0       3.0       1
# 133813                 1.0       2.0       1
# 134575                 3.0       6.0       1
# 135348                 1.0       1.0       1
# 136179                   0         2       1
#
# [5 rows x 59 columns]

# %%
df_train_new.tail(10)
# Out:
#                   player  gw  position  minutes                      team  \
# 136691       Yoane Wissa  34         3       12                 Brentford
# 136692   Youri Tielemans  34         3       85            Leicester City
# 136693     Yves Bissouma  34         3        0  Brighton and Hove Albion
# 136694          Zach Awe  34         2        0                   Arsenal
# 136695      Zack Steffen  34         1        0           Manchester City
# 136696       Zak Swanson  34         2        0                   Arsenal
# 136697  Álvaro Fernández  34         1        0                 Brentford
# 136698  Álvaro Fernández  34         2        0         Manchester United
# 136699  Álvaro Fernández  34         2        0         Manchester United
# 136700    Çaglar Söyüncü  34         2       90            Leicester City
#
#             opponent_team  relative_market_value_team  \
# 136691  Tottenham Hotspur                         NaN
# 136692        Aston Villa                         NaN
# 136693        Southampton                         NaN
# 136694  Manchester United                         NaN
# 136695            Watford                         NaN
# 136696  Manchester United                         NaN
# 136697  Tottenham Hotspur                         NaN
# 136698            Arsenal                         NaN
# 136699            Chelsea                         NaN
# 136700        Aston Villa                         NaN
#
#         relative_market_value_opponent_team  was_home  total_points  ...   xa  \
# 136691                                  NaN      True             1  ...  0.0
# 136692                                  NaN      True             3  ...  0.0
# 136693                                  NaN      True             0  ...  NaN
# 136694                                  NaN      True             0  ...  NaN
# 136695                                  NaN      True             0  ...  NaN
# 136696                                  NaN      True             0  ...  NaN
# 136697                                  NaN      True             0  ...  NaN
# 136698                                  NaN     False             0  ...  NaN
# 136699                                  NaN      True             0  ...  NaN
# 136700                                  NaN      True             9  ...  0.0
#
#         sca  gca  passes_completed  passes  passes_pct  carries  \
# 136691    0    0                 3       4        75.0        1
# 136692    1    0                44      49        89.8       39
# 136693  NaN  NaN               NaN     NaN         NaN      NaN
# 136694  NaN  NaN               NaN     NaN         NaN      NaN
# 136695  NaN  NaN               NaN     NaN         NaN      NaN
# 136696  NaN  NaN               NaN     NaN         NaN      NaN
# 136697  NaN  NaN               NaN     NaN         NaN      NaN
# 136698  NaN  NaN               NaN     NaN         NaN      NaN
# 136699  NaN  NaN               NaN     NaN         NaN      NaN
# 136700    0    0                73      79        92.4       62
#
#         dribbles_completed  dribbles  crowds
# 136691                   0         0       1
# 136692                   0         0       1
# 136693                 NaN       NaN       1
# 136694                 NaN       NaN       1
# 136695                 NaN       NaN       1
# 136696                 NaN       NaN       1
# 136697                 NaN       NaN       1
# 136698                 NaN       NaN       1
# 136699                 NaN       NaN       1
# 136700                   0         0       1
#
# [10 rows x 59 columns]

# %%
df_latest_further.shape
# Out:
# (794, 57)

# %%
df_train_new.shape
# Out:
# (136701, 59)

# %%
# save latest training set to csv
# overwrite existing one
df_train_new.to_csv(path/'train_v8.csv')

# %%
# get fixtures
fixtures = pd.read_csv(path/'2021-22/fixtures.csv')
team_dict = teams[['team_2122', 'team']].dropna().set_index('team_2122').to_dict()['team']

fixtures['home_team'] = fixtures['team_h'].replace(team_dict)
fixtures['away_team'] = fixtures['team_a'].replace(team_dict)
fixtures = fixtures[['home_team', 'away_team', 'kickoff_time', 'event']]
fixtures = fixtures.rename(columns={'event':'gw'})


# use these two lines if updating play_proba later in week
# current_gw = last_gw
# df_train_new = pd.read_csv(path/'train_v7.csv', index_col=0, dtype={'season':str,
#                                                                     'comp':str,
#                                                                     'squad':str})

# set starting gameweek (where are we right now in the season)
current_gw = last_gw + 1
fixtures = fixtures[fixtures['gw'] >= current_gw].sort_values(by=['gw'])
fixtures['match_no'] = np.arange(fixtures.shape[0])

# %%
fixtures.head(50)
# Out:
#                     home_team                 away_team          kickoff_time  \
# 332          Newcastle United                 Liverpool  2022-04-30T11:30:00Z
# 341         Manchester United                 Brentford  2022-05-02T19:00:00Z
# 339         Tottenham Hotspur            Leicester City  2022-05-01T13:00:00Z
# 338                   Everton                   Chelsea  2022-05-01T13:00:00Z
# 337                     Leeds           Manchester City  2022-04-30T16:30:00Z
# 340           West Ham United                   Arsenal  2022-05-01T15:30:00Z
# 335                   Watford                   Burnley  2022-04-30T14:00:00Z
# 334               Southampton            Crystal Palace  2022-04-30T14:00:00Z
# 333               Aston Villa                   Norwich  2022-04-30T14:00:00Z
# 336   Wolverhampton Wanderers  Brighton and Hove Albion  2022-04-30T14:00:00Z
# 351           Manchester City          Newcastle United  2022-05-08T15:30:00Z
# 357         Tottenham Hotspur                   Arsenal  2022-05-12T18:45:00Z
# 356   Wolverhampton Wanderers           Manchester City  2022-05-11T19:15:00Z
# 354            Leicester City                   Norwich  2022-05-11T18:45:00Z
# 353                     Leeds                   Chelsea  2022-05-11T18:30:00Z
# 352               Aston Villa                 Liverpool  2022-05-10T19:00:00Z
# 350                   Norwich           West Ham United  2022-05-08T13:00:00Z
# 355                   Watford                   Everton  2022-05-11T18:45:00Z
# 348                   Arsenal                     Leeds  2022-05-08T13:00:00Z
# 347                 Liverpool         Tottenham Hotspur  2022-05-07T18:45:00Z
# 346  Brighton and Hove Albion         Manchester United  2022-05-07T16:30:00Z
# 345            Crystal Palace                   Watford  2022-05-07T14:00:00Z
# 344                   Chelsea   Wolverhampton Wanderers  2022-05-07T14:00:00Z
# 343                   Burnley               Aston Villa  2022-05-07T14:00:00Z
# 342                 Brentford               Southampton  2022-05-07T14:00:00Z
# 349            Leicester City                   Everton  2022-05-08T13:00:00Z
# 369                   Chelsea            Leicester City  2022-05-19T19:00:00Z
# 368               Aston Villa                   Burnley  2022-05-19T19:00:00Z
# 367                   Everton            Crystal Palace  2022-05-19T18:45:00Z
# 366               Southampton                 Liverpool  2022-05-17T18:45:00Z
# 365          Newcastle United                   Arsenal  2022-05-16T19:00:00Z
# 364           West Ham United           Manchester City  2022-05-15T15:30:00Z
# 362                   Watford            Leicester City  2022-05-15T13:00:00Z
# 361                     Leeds  Brighton and Hove Albion  2022-05-15T13:00:00Z
# 360                   Everton                 Brentford  2022-05-15T13:00:00Z
# 359               Aston Villa            Crystal Palace  2022-05-15T13:00:00Z
# 358         Tottenham Hotspur                   Burnley  2022-05-15T11:00:00Z
# 363   Wolverhampton Wanderers                   Norwich  2022-05-15T13:00:00Z
# 378           Manchester City               Aston Villa  2022-05-22T15:00:00Z
# 370                   Arsenal                   Everton  2022-05-22T15:00:00Z
# 371                 Brentford                     Leeds  2022-05-22T15:00:00Z
# 372  Brighton and Hove Albion           West Ham United  2022-05-22T15:00:00Z
# 373                   Burnley          Newcastle United  2022-05-22T15:00:00Z
# 374                   Chelsea                   Watford  2022-05-22T15:00:00Z
# 375            Crystal Palace         Manchester United  2022-05-22T15:00:00Z
# 376            Leicester City               Southampton  2022-05-22T15:00:00Z
# 377                 Liverpool   Wolverhampton Wanderers  2022-05-22T15:00:00Z
# 379                   Norwich         Tottenham Hotspur  2022-05-22T15:00:00Z
#
#      gw  match_no
# 332  35         0
# 341  35         1
# 339  35         2
# 338  35         3
# 337  35         4
# 340  35         5
# 335  35         6
# 334  35         7
# 333  35         8
# 336  35         9
# 351  36        10
# 357  36        11
# 356  36        12
# 354  36        13
# 353  36        14
# 352  36        15
# 350  36        16
# 355  36        17
# 348  36        18
# 347  36        19
# 346  36        20
# 345  36        21
# 344  36        22
# 343  36        23
# 342  36        24
# 349  36        25
# 369  37        26
# 368  37        27
# 367  37        28
# 366  37        29
# 365  37        30
# 364  37        31
# 362  37        32
# 361  37        33
# 360  37        34
# 359  37        35
# 358  37        36
# 363  37        37
# 378  38        38
# 370  38        39
# 371  38        40
# 372  38        41
# 373  38        42
# 374  38        43
# 375  38        44
# 376  38        45
# 377  38        46
# 379  38        47

# %%
# add universal team codes for home and away teams
fixtures = fixtures.merge(teams, left_on='home_team', right_on='team', how='left')
fixtures = fixtures.merge(teams, left_on='away_team', right_on='team', how='left')
fixtures = fixtures[['gw', 'match_no', 'home_team', 'away_team', 'kickoff_time', 'team_code_x', 'team_code_y']]
fixtures.rename(index=str,
                columns={'team_code_x':'home_team_code',
                         'team_code_y':'away_team_code'},
                inplace=True)

# %%
fixtures.head()
# Out:
#    gw  match_no          home_team        away_team          kickoff_time  \
# 0  35         0   Newcastle United        Liverpool  2022-04-30T11:30:00Z
# 1  35         1  Manchester United        Brentford  2022-05-02T19:00:00Z
# 2  35         2  Tottenham Hotspur   Leicester City  2022-05-01T13:00:00Z
# 3  35         3            Everton          Chelsea  2022-05-01T13:00:00Z
# 4  35         4              Leeds  Manchester City  2022-04-30T16:30:00Z
#
#    home_team_code  away_team_code
# 0               4              14
# 1               1              94
# 2               6              13
# 3              11               8
# 4               2              43

# %%
# all_players.replace(to_replace='None', value=1, inplace=True)

# %%
all_players[all_players['play_proba_2122'] == '0']
# Out:
#                      full_name play_proba_2122  position_2122  id_2122  \
# 1         Rúnar Alex Rúnarsson               0              1        2
# 2      Willian Borges Da Silva               0              3        3
# 3    Pierre-Emerick Aubameyang               0              4        4
# 7                   Pablo Marí               0              2        8
# 8              Héctor Bellerín               0              2        9
# ..                         ...             ...            ...      ...
# 718          Christian Marques               0              2      549
# 720              Louie Moulden               0              1      611
# 723  Bruno André Cavaco Jordão               0              3      661
# 725             Dion Sanderson               0              2      686
# 726                 Ryan Giles               0              3      687
#
#      cost_2122  team_2122 web_name_2122
# 1           40          3     Rúnarsson
# 2           63          3       Willian
# 3           96          3    Aubameyang
# 7           42          3          Marí
# 8           48          3      Bellerín
# ..         ...        ...           ...
# 718         40         39       Marques
# 720         40         39       Moulden
# 723         45         39        Jordão
# 725         40         39     Sanderson
# 726         45         39         Giles
#
# [192 rows x 7 columns]

# %%
# join home team to all players for current season
home_df = fixtures.merge(all_players, 
               left_on='home_team_code', 
               right_on='team_2122', 
               how='left')

# pull out the required fields and rename columns
home_df = home_df[['gw', 'match_no', 'home_team', 'away_team', 'kickoff_time', 
                   'full_name', 'position_2122', 'cost_2122', 'play_proba_2122', 
                   'web_name_2122']]
home_df.rename(index=str, 
               columns={'home_team':'team',
                        'away_team':'opponent_team',
                        'full_name':'player',
                        'position_2122':'position',
                        'cost_2122':'price',
                        'play_proba_2122':'play_proba',
                        'web_name_2122':'short_name'},
              inplace=True)

# add home flag
home_df['was_home'] = True

# %%
# join away team to all players for current season
away_df = fixtures.merge(all_players, 
               left_on='away_team_code', 
               right_on='team_2122', 
               how='left')

# pull out the required fields and rename columns
away_df = away_df[['gw',  'match_no', 'away_team', 'home_team', 'kickoff_time', 
                   'full_name', 'position_2122', 'cost_2122', 'play_proba_2122', 
                   'web_name_2122']]
away_df.rename(index=str, 
               columns={'away_team':'team',
                        'home_team':'opponent_team',
                        'full_name':'player',
                        'position_2122':'position',
                        'cost_2122':'price',
                        'play_proba_2122':'play_proba',
                        'web_name_2122':'short_name'},
              inplace=True)

# add home flag
away_df['was_home'] = False

# %%
# look at away players
away_df.head()
# Out:
#    gw  match_no       team     opponent_team          kickoff_time  \
# 0  35         0  Liverpool  Newcastle United  2022-04-30T11:30:00Z
# 1  35         0  Liverpool  Newcastle United  2022-04-30T11:30:00Z
# 2  35         0  Liverpool  Newcastle United  2022-04-30T11:30:00Z
# 3  35         0  Liverpool  Newcastle United  2022-04-30T11:30:00Z
# 4  35         0  Liverpool  Newcastle United  2022-04-30T11:30:00Z
#
#                            player  position  price play_proba short_name  \
# 0                    James Milner         3     49        100     Milner
# 1                Jordan Henderson         3     49        100  Henderson
# 2  Adrián San Miguel del Castillo         1     43        100     Adrián
# 3                      Joel Matip         2     51        100      Matip
# 4  Thiago Alcántara do Nascimento         3     53        100     Thiago
#
#    was_home
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False

# %%
# look at home players
home_df.head()
# Out:
#    gw  match_no              team opponent_team          kickoff_time  \
# 0  35         0  Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 1  35         0  Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 2  35         0  Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 3  35         0  Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 4  35         0  Newcastle United     Liverpool  2022-04-30T11:30:00Z
#
#            player  position  price play_proba short_name  was_home
# 0  Joseph Willock         3     55        100    Willock      True
# 1    Matt Targett         2     47        100    Targett      True
# 2        Dan Burn         2     44        100       Burn      True
# 3      Chris Wood         4     67        100       Wood      True
# 4   Jonjo Shelvey         3     53        100    Shelvey      True

# %%
# # calculate average minutes over last 5 gameweeks
# # first get last 5 gameweeks in current season
# recent_mins = df_train_new[(df_train_new['gw'] >= current_gw - 5) & 
#                            (df_train_new['season'] == season_names[0])][['player', 'minutes', 'play_proba']]

# # recent_mins = df_train_new[((df_train_new['gw'] >= 40 - 5) & 
# #                            (df_train_new['season'] == '1920')) | 
# #                            ((df_train_new['gw'] >= 1) & 
# #                            (df_train_new['season'] == '2021'))][['player', 'minutes', 'play_proba']]

# # exclude weeks where the player had an injury designation (i.e. keep where play_proba is 1)
# recent_mins = recent_mins[recent_mins['play_proba'] == 1]

# len(recent_mins)

# # average for each player
# recent_mins = recent_mins.groupby(['player'])['minutes'].mean().to_dict()

# recent_mins

# %%
# concatenate home and away players
remaining_season_df = home_df.append(away_df).reset_index(drop=True)

# add home and away team market values
remaining_season_df = remaining_season_df.merge(teams_mv[teams_mv['season'] == '2122'],
                                                left_on='team', 
                                                right_on='name', 
                                                how='left').drop(['name', 'season'], axis=1)

remaining_season_df = remaining_season_df.merge(teams_mv[teams_mv['season'] == '2122'],
                                                left_on='opponent_team', 
                                                right_on='name', 
                                                how='left').drop(['name', 'season'], axis=1)

remaining_season_df.rename(index=str, 
                           columns={'relative_market_value_x':'relative_market_value_team',
                                    'relative_market_value_y':'relative_market_value_opponent_team'},
                           inplace=True)

# add season name
remaining_season_df['season'] = season_names[0]

# divide cost by 10 for actual cost
remaining_season_df['price'] = remaining_season_df['price']/10

# set availability probability
# 0 = 0% chance, 25 = 25% chance, etc
# 'None' or '100' = 100% chance
remaining_season_df.loc[remaining_season_df['play_proba'] == 'None', 'play_proba'] = 100
remaining_season_df['play_proba'] = remaining_season_df['play_proba'].astype('float') / 100

# cast position to integer
remaining_season_df['position'] = remaining_season_df['position'].astype(int)

# # add minutes based on last five fixtures
# remaining_season_df['minutes'] = remaining_season_df['player'].map(recent_mins)
# remaining_season_df['minutes'].fillna(0, inplace=True)

# # multiply minutes by play probability
# remaining_season_df['minutes'] = remaining_season_df['minutes'] * remaining_season_df['play_proba']

# %%
remaining_season_df.head(50)
# Out:
#     gw  match_no               team opponent_team          kickoff_time  \
# 0   35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 1   35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 2   35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 3   35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 4   35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 5   35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 6   35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 7   35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 8   35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 9   35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 10  35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 11  35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 12  35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 13  35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 14  35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 15  35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 16  35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 17  35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 18  35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 19  35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 20  35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 21  35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 22  35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 23  35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 24  35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 25  35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 26  35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 27  35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 28  35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 29  35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 30  35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 31  35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 32  35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 33  35         0   Newcastle United     Liverpool  2022-04-30T11:30:00Z
# 34  35         1  Manchester United     Brentford  2022-05-02T19:00:00Z
# 35  35         1  Manchester United     Brentford  2022-05-02T19:00:00Z
# 36  35         1  Manchester United     Brentford  2022-05-02T19:00:00Z
# 37  35         1  Manchester United     Brentford  2022-05-02T19:00:00Z
# 38  35         1  Manchester United     Brentford  2022-05-02T19:00:00Z
# 39  35         1  Manchester United     Brentford  2022-05-02T19:00:00Z
# 40  35         1  Manchester United     Brentford  2022-05-02T19:00:00Z
# 41  35         1  Manchester United     Brentford  2022-05-02T19:00:00Z
# 42  35         1  Manchester United     Brentford  2022-05-02T19:00:00Z
# 43  35         1  Manchester United     Brentford  2022-05-02T19:00:00Z
# 44  35         1  Manchester United     Brentford  2022-05-02T19:00:00Z
# 45  35         1  Manchester United     Brentford  2022-05-02T19:00:00Z
# 46  35         1  Manchester United     Brentford  2022-05-02T19:00:00Z
# 47  35         1  Manchester United     Brentford  2022-05-02T19:00:00Z
# 48  35         1  Manchester United     Brentford  2022-05-02T19:00:00Z
# 49  35         1  Manchester United     Brentford  2022-05-02T19:00:00Z
#
#                                  player  position  price  play_proba  \
# 0                        Joseph Willock         3    5.5        1.00
# 1                          Matt Targett         2    4.7        1.00
# 2                              Dan Burn         2    4.4        1.00
# 3                            Chris Wood         4    6.7        1.00
# 4                         Jonjo Shelvey         3    5.3        1.00
# 5                          Matt Ritchie         2    4.9        1.00
# 6                          Ciaran Clark         2    4.4        0.00
# 7                           Karl Darlow         1    4.5        1.00
# 8                       Martin Dubravka         1    4.5        1.00
# 9                         Callum Wilson         4    7.1        0.25
# 10                        Jeff Hendrick         3    4.8        0.00
# 11                          Ryan Fraser         3    5.2        0.00
# 12                     Jamaal Lascelles         2    4.4        1.00
# 13                         Dwight Gayle         4    5.2        1.00
# 14                         Paul Dummett         2    4.5        1.00
# 15                     Javier Manquillo         2    3.9        1.00
# 16                          Emil Krafth         2    4.3        1.00
# 17                         Jacob Murphy         3    4.7        1.00
# 18                         Fabian Schär         2    4.4        1.00
# 19                         Isaac Hayden         3    4.5        0.00
# 20                  Allan Saint-Maximin         4    6.8        1.00
# 21                       Miguel Almirón         3    5.0        1.00
# 22                       Sean Longstaff         3    4.3        1.00
# 23  Joelinton Cássio Apolinário de Lira         4    5.8        1.00
# 24                          Jamal Lewis         2    4.2        0.00
# 25                    Matthew Longstaff         3    4.5        0.00
# 26                   Federico Fernández         2    4.3        1.00
# 27                      Freddie Woodman         1    4.3        0.00
# 28                       Mark Gillespie         1    3.9        1.00
# 29                            Joe White         3    4.4        0.00
# 30                      Elliot Anderson         3    4.5        0.00
# 31                      Kieran Trippier         2    4.9        0.25
# 32      Bruno Guimarães Rodriguez Moura         3    5.0        1.00
# 33                       Lucas De Bolle         3    4.4        1.00
# 34                     Álvaro Fernández         2    4.0        1.00
# 35                       Edinson Cavani         4    8.4        0.75
# 36                         David de Gea         1    5.1        1.00
# 37                        Nemanja Matic         3    4.3        1.00
# 38                           Paul Pogba         3    7.4        0.00
# 39                        Harry Maguire         2    5.4        0.75
# 40  Frederico Rodrigues de Paula Santos         3    4.9        0.75
# 41                            Luke Shaw         2    5.0        0.00
# 42                        Jesse Lingard         3    6.7        0.75
# 43        Bruno Miguel Borges Fernandes         3   11.6        1.00
# 44                      Anthony Martial         4    7.6        0.00
# 45                  Alex Nicolao Telles         2    5.1        1.00
# 46                       Dean Henderson         1    4.7        1.00
# 47                      Marcus Rashford         3    9.4        1.00
# 48                        Axel Tuanzebe         2    4.4        0.00
# 49                      Victor Lindelöf         2    4.8        1.00
#
#           short_name  was_home  relative_market_value_team  \
# 0            Willock      True                         NaN
# 1            Targett      True                         NaN
# 2               Burn      True                         NaN
# 3               Wood      True                         NaN
# 4            Shelvey      True                         NaN
# 5            Ritchie      True                         NaN
# 6              Clark      True                         NaN
# 7             Darlow      True                         NaN
# 8           Dubravka      True                         NaN
# 9             Wilson      True                         NaN
# 10          Hendrick      True                         NaN
# 11            Fraser      True                         NaN
# 12         Lascelles      True                         NaN
# 13             Gayle      True                         NaN
# 14           Dummett      True                         NaN
# 15         Manquillo      True                         NaN
# 16            Krafth      True                         NaN
# 17            Murphy      True                         NaN
# 18             Schär      True                         NaN
# 19            Hayden      True                         NaN
# 20     Saint-Maximin      True                         NaN
# 21           Almirón      True                         NaN
# 22       S.Longstaff      True                         NaN
# 23         Joelinton      True                         NaN
# 24             Lewis      True                         NaN
# 25       M.Longstaff      True                         NaN
# 26         Fernández      True                         NaN
# 27           Woodman      True                         NaN
# 28         Gillespie      True                         NaN
# 29             White      True                         NaN
# 30          Anderson      True                         NaN
# 31          Trippier      True                         NaN
# 32   Bruno Guimarães      True                         NaN
# 33          De Bolle      True                         NaN
# 34  Álvaro Fernández      True                         NaN
# 35            Cavani      True                         NaN
# 36            de Gea      True                         NaN
# 37             Matic      True                         NaN
# 38             Pogba      True                         NaN
# 39           Maguire      True                         NaN
# 40              Fred      True                         NaN
# 41              Shaw      True                         NaN
# 42           Lingard      True                         NaN
# 43         Fernandes      True                         NaN
# 44           Martial      True                         NaN
# 45            Telles      True                         NaN
# 46         Henderson      True                         NaN
# 47          Rashford      True                         NaN
# 48          Tuanzebe      True                         NaN
# 49          Lindelöf      True                         NaN
#
#     relative_market_value_opponent_team season
# 0                                   NaN   2122
# 1                                   NaN   2122
# 2                                   NaN   2122
# 3                                   NaN   2122
# 4                                   NaN   2122
# 5                                   NaN   2122
# 6                                   NaN   2122
# 7                                   NaN   2122
# 8                                   NaN   2122
# 9                                   NaN   2122
# 10                                  NaN   2122
# 11                                  NaN   2122
# 12                                  NaN   2122
# 13                                  NaN   2122
# 14                                  NaN   2122
# 15                                  NaN   2122
# 16                                  NaN   2122
# 17                                  NaN   2122
# 18                                  NaN   2122
# 19                                  NaN   2122
# 20                                  NaN   2122
# 21                                  NaN   2122
# 22                                  NaN   2122
# 23                                  NaN   2122
# 24                                  NaN   2122
# 25                                  NaN   2122
# 26                                  NaN   2122
# 27                                  NaN   2122
# 28                                  NaN   2122
# 29                                  NaN   2122
# 30                                  NaN   2122
# 31                                  NaN   2122
# 32                                  NaN   2122
# 33                                  NaN   2122
# 34                                  NaN   2122
# 35                                  NaN   2122
# 36                                  NaN   2122
# 37                                  NaN   2122
# 38                                  NaN   2122
# 39                                  NaN   2122
# 40                                  NaN   2122
# 41                                  NaN   2122
# 42                                  NaN   2122
# 43                                  NaN   2122
# 44                                  NaN   2122
# 45                                  NaN   2122
# 46                                  NaN   2122
# 47                                  NaN   2122
# 48                                  NaN   2122
# 49                                  NaN   2122

# %%
# save latest prediction set to csv
remaining_season_df.to_csv(path/'remaining_season.csv')
