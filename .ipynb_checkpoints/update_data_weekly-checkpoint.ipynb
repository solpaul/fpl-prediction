# %%
# import required libriaries
from pathlib import Path
import json

from fpl_predictor.util import *

# %%
# path to data directory
#path = Path('/home/jupyter/fpl-prediction/data')
path = Path('./fpl_predictor/data')

# %%
# read in latest training set
df_train = pd.read_csv(path/'train_v8.csv', index_col=0, 
                       dtype={'season':str,
                              'comp':str,
                              'squad':str})

# path to current season
season_paths = [path/'2021-22']

# name for current season
season_names = ['2122']

# team codes
teams = pd.read_csv(path/'teams.csv')

# latest remaining season dataset, for latest week's play_proba values
remaining_season = pd.read_csv(path/'remaining_season.csv', index_col=0)

# create players dataset
all_players = build_players(path, season_paths, season_names, teams)

# 2019-20 market value
# table was in slightly different position for 2019-20 season
# should check that 2019-20 season values remain the same once season starts
teams_mv = build_season_mv('2122', 11, range(13,33))

# %%
# all_players#[all_players['full_name'] == 'Ben Davies']

# %%
df_train.tail(50)
# Out:
#                                 player  gw  position  minutes  \
# 117047  Thiago Alcántara do Nascimento   4         3       90
# 117048        Thiago Emiliano da Silva   4         2       90
# 117049                   Thomas Partey   4         3       28
# 117050                Timothy Castagne   4         2       90
# 117051                     Timo Werner   4         4        8
# 117052                        Tim Krul   4         1       90
# 117053                 Tino Livramento   4         2       90
# 117054                      Tobi Omole   4         2        0
# 117055               Toby Alderweireld   4         2        0
# 117056                   Todd Cantwell   4         3       28
# 117057                    Tomas Soucek   4         3       90
# 117058                     Tommy Doyle   4         3        0
# 117059                   Tom Cleverley   4         3        0
# 117060                      Tom Davies   4         3        0
# 117061                      Tom Heaton   4         1        0
# 117062          Trent Alexander-Arnold   4         2       90
# 117063                 Trevoh Chalobah   4         2       90
# 117064                     Troy Deeney   4         4        0
# 117065                   Tyler Roberts   4         3       45
# 117066                 Tyrick Mitchell   4         2       90
# 117067                    Tyrone Mings   4         2       90
# 117068                  Vicente Guaita   4         1       90
# 117069                 Victor Lindelöf   4         2        0
# 117070                Viljami Sinisalo   4         1        0
# 117071                 Virgil van Dijk   4         2       90
# 117072                   Vitaly Janelt   4         3       67
# 117073                 Vladimir Coufal   4         2       90
# 117074                 Wayne Hennessey   4         1        0
# 117075                   Wesley Fofana   4         2        0
# 117076                   Wesley Moraes   4         4        0
# 117077                   Wilfred Ndidi   4         3       90
# 117078                   Wilfried Zaha   4         3       90
# 117079                  William Saliba   4         2        0
# 117080               William Smallbone   4         3        0
# 117081            William Troost-Ekong   4         2       90
# 117082         Willian Borges Da Silva   4         3        0
# 117083                      Willy Boly   4         2        0
# 117084                     Will Hughes   4         3        0
# 117085                     Will Norris   4         1        0
# 117086                    Winston Reid   4         2        0
# 117087                 Xherdan Shaqiri   4         3        0
# 117088                      Yan Valery   4         2        0
# 117089                      Yerry Mina   4         2       90
# 117090      Yerson Mosquera Valdelamar   4         2        0
# 117091                     Yoane Wissa   4         3        0
# 117092                 Youri Tielemans   4         3       90
# 117093                   Yves Bissouma   4         3       90
# 117094                    Zack Steffen   4         1        0
# 117095                Álvaro Fernández   4         1        0
# 117096                  Çaglar Söyüncü   4         2       90
#
#                             team             opponent_team  \
# 117047                 Liverpool                     Leeds
# 117080                    0.535859                             0.787799
# 117081                    0.295355                             0.868522
# 117082                    1.218063                             0.420937
# 117083                    0.868522                             0.295355
# 117084                    0.531751                             1.547840
# 117085                    0.322670                             1.025416
# 117086                    0.787799                             0.535859
# 117087                    1.953121                             0.556956
# 117088                    0.535859                             0.787799
# 117089                    1.025416                             0.322670
# 117090                    0.868522                             0.295355
# 117091                    0.369638                             0.550960
# 117092                    1.221616                             2.309546
# 117093                    0.550960                             0.369638
# 117094                    2.309546                             1.221616
# 117095                    0.369638                             0.550960
# 117096                    1.221616                             2.309546
#
#         was_home  total_points  ...   xa   sca  gca  passes_completed  passes  \
# 117047     False             7  ...  0.3   3.0  1.0              58.0    61.0
# 117048      True             6  ...  0.1   1.0  0.0              58.0    66.0
# 117049      True             0  ...  0.0   0.0  0.0              10.0    11.0
# 117050      True             2  ...  0.0   2.0  0.0              26.0    30.0
# 117051      True             1  ...  0.0   0.0  0.0               1.0     1.0
# 117052     False             3  ...  0.0   1.0  0.0              30.0    50.0
# 117053      True             6  ...  0.1   2.0  0.0              35.0    42.0
# 117054     False             0  ...  NaN   NaN  NaN               NaN     NaN
# 117055     False             0  ...  NaN   NaN  NaN               NaN     NaN
# 117056     False             1  ...  0.0   0.0  0.0               9.0    15.0
# 117057     False             3  ...  0.0   0.0  0.0              53.0    63.0
# 117058     False             0  ...  NaN   NaN  NaN               NaN     NaN
# 117059      True             0  ...  NaN   NaN  NaN               NaN     NaN
# 117060      True             0  ...  NaN   NaN  NaN               NaN     NaN
# 117061      True             0  ...  NaN   NaN  NaN               NaN     NaN
# 117062     False            12  ...  0.6   7.0  1.0              45.0    63.0
# 117063      True             6  ...  0.0   0.0  0.0              36.0    45.0
# 117064      True             0  ...  NaN   NaN  NaN               NaN     NaN
# 117065      True             1  ...  0.0   1.0  0.0              11.0    14.0
# 117066      True             6  ...  0.1   1.0  0.0              55.0    78.0
# 117067     False             0  ...  0.0   2.0  0.0              32.0    44.0
# 117068      True             6  ...  0.0   0.0  0.0              14.0    14.0
# 117069      True             0  ...  NaN   NaN  NaN               NaN     NaN
# 117070     False             0  ...  NaN   NaN  NaN               NaN     NaN
# 117071     False             6  ...  0.0   2.0  0.0              52.0    56.0
# 117072      True             3  ...  0.0   3.0  0.0              23.0    25.0
# 117073     False             6  ...  0.0   1.0  0.0              34.0    47.0
# 117074     False             0  ...  NaN   NaN  NaN               NaN     NaN
# 117075      True             0  ...  NaN   NaN  NaN               NaN     NaN
# 117076     False             0  ...  NaN   NaN  NaN               NaN     NaN
# 117077      True             2  ...  0.0   1.0  0.0              32.0    38.0
# 117078      True            12  ...  0.5  10.0  3.0              34.0    42.0
# 117079      True             0  ...  NaN   NaN  NaN               NaN     NaN
# 117080      True             0  ...  NaN   NaN  NaN               NaN     NaN
# 117081      True             1  ...  0.0   0.0  0.0              50.0    55.0
# 117082      True             0  ...  NaN   NaN  NaN               NaN     NaN
# 117083     False             0  ...  NaN   NaN  NaN               NaN     NaN
# 117084      True             0  ...  NaN   NaN  NaN               NaN     NaN
# 117085     False             0  ...  NaN   NaN  NaN               NaN     NaN
# 117086     False             0  ...  NaN   NaN  NaN               NaN     NaN
# 117087     False             0  ...  NaN   NaN  NaN               NaN     NaN
# 117088      True             0  ...  NaN   NaN  NaN               NaN     NaN
# 117089      True             2  ...  0.0   0.0  0.0              30.0    39.0
# 117090     False             0  ...  NaN   NaN  NaN               NaN     NaN
# 117091      True             0  ...  NaN   NaN  NaN               NaN     NaN
# 117092      True             2  ...  0.0   0.0  0.0              35.0    42.0
# 117093     False             3  ...  0.0   0.0  0.0              52.0    64.0
# 117094     False             0  ...  NaN   NaN  NaN               NaN     NaN
# 117095      True             0  ...  NaN   NaN  NaN               NaN     NaN
# 117096      True             1  ...  0.0   0.0  0.0              53.0    62.0
#
#         passes_pct  carries  dribbles_completed  dribbles  crowds
# 117047        95.1     47.0                 0.0       0.0       1
# 117048        87.9     46.0                 0.0       0.0       1
# 117049        90.9      8.0                 0.0       0.0       1
# 117050        86.7     22.0                 0.0       0.0       1
# 117051       100.0      1.0                 0.0       0.0       1
# 117052        60.0     24.0                 0.0       0.0       1
# 117053        83.3     37.0                 1.0       2.0       1
# 117054         NaN      NaN                 NaN       NaN       1
# 117055         NaN      NaN                 NaN       NaN       1
# 117056        60.0     12.0                 0.0       0.0       1
# 117057        84.1     48.0                 0.0       0.0       1
# 117058         NaN      NaN                 NaN       NaN       1
# 117059         NaN      NaN                 NaN       NaN       1
# 117060         NaN      NaN                 NaN       NaN       1
# 117061         NaN      NaN                 NaN       NaN       1
# 117062        71.4     35.0                 1.0       2.0       1
# 117063        80.0     34.0                 1.0       1.0       1
# 117064         NaN      NaN                 NaN       NaN       1
# 117065        78.6     13.0                 0.0       0.0       1
# 117066        70.5     62.0                 2.0       3.0       1
# 117067        72.7     33.0                 0.0       0.0       1
# 117068       100.0      8.0                 0.0       0.0       1
# 117069         NaN      NaN                 NaN       NaN       1
# 117070         NaN      NaN                 NaN       NaN       1
# 117071        92.9     39.0                 0.0       0.0       1
# 117072        92.0     20.0                 1.0       1.0       1
# 117073        72.3     27.0                 1.0       2.0       1
# 117074         NaN      NaN                 NaN       NaN       1
# 117075         NaN      NaN                 NaN       NaN       1
# 117076         NaN      NaN                 NaN       NaN       1
# 117077        84.2     26.0                 0.0       0.0       1
# 117078        81.0     64.0                 7.0      13.0       1
# 117079         NaN      NaN                 NaN       NaN       1
# 117080         NaN      NaN                 NaN       NaN       1
# 117081        90.9     38.0                 0.0       0.0       1
# 117082         NaN      NaN                 NaN       NaN       1
# 117083         NaN      NaN                 NaN       NaN       1
# 117084         NaN      NaN                 NaN       NaN       1
# 117085         NaN      NaN                 NaN       NaN       1
# 117086         NaN      NaN                 NaN       NaN       1
# 117087         NaN      NaN                 NaN       NaN       1
# 117088         NaN      NaN                 NaN       NaN       1
# 117089        76.9     24.0                 0.0       0.0       1
# 117090         NaN      NaN                 NaN       NaN       1
# 117091         NaN      NaN                 NaN       NaN       1
# 117092        83.3     32.0                 0.0       0.0       1
# 117093        81.3     53.0                 2.0       3.0       1
# 117094         NaN      NaN                 NaN       NaN       1
# 117095         NaN      NaN                 NaN       NaN       1
# 117096        85.5     46.0                 0.0       0.0       1
#
# [50 rows x 59 columns]

# %%
# find the latest gameweek
last_gw = df_train['gw'][df_train['season'] == season_names[0]].max()

if np.isnan(last_gw): 
    last_gw = 1 
else: 
    last_gw = last_gw + 1
    
last_gw
# Out:
# 5

# %%
# build training set for latest gameweek
df_latest = build_season(season_paths[0], season_names[0], all_players, teams, teams_mv, [last_gw])

# %%
df_latest.drop_duplicates(inplace=True)

# %%
df_latest.head(50)
# Out:
#                             player  gw  position  minutes  \
# 0                   Aaron Connolly   5         4        0
# 1                  Aaron Cresswell   5         2       90
# 30           West Ham United         Manchester United
# 31  Brighton and Hove Albion            Leicester City
# 32                   Chelsea         Tottenham Hotspur
# 33         Manchester United           West Ham United
# 34   Wolverhampton Wanderers                 Brentford
# 35                   Norwich                   Watford
# 36                 Liverpool            Crystal Palace
# 37                   Watford                   Norwich
# 38           West Ham United         Manchester United
# 39                   Everton               Aston Villa
# 40                   Everton               Aston Villa
# 41                   Everton               Aston Villa
# 42           West Ham United         Manchester United
# 43                   Norwich                   Watford
# 44         Manchester United           West Ham United
# 45                   Everton               Aston Villa
# 46         Manchester United           West Ham United
# 47                   Chelsea         Tottenham Hotspur
# 48               Aston Villa                   Everton
# 49               Southampton           Manchester City
#
#     relative_market_value_team  relative_market_value_opponent_team  was_home  \
# 0                     0.552039                             1.224008      True
# 1                     0.786004                             2.085443      True
# 2                     0.323302                             1.220448      True
# 3                     1.220448                             0.323302     False
# 4                     0.908494                             0.965122      True
# 5                     2.085443                             0.786004     False
# 6                     0.965122                             0.908494     False
# 7                     0.870223                             0.370362      True
# 8                     0.536908                             2.336319     False
# 9                     0.562274                             0.537131     False
# 10                    0.421761                             0.295934      True
# 11                    0.552039                             1.224008      True
# 12                    0.295934                             0.421761     False
# 13                    0.552039                             1.224008      True
# 14                    0.295934                             0.421761     False
# 15                    1.224008                             0.552039     False
# 16                    1.956945                             0.532792      True
# 17                    1.220448                             0.323302     False
# 18                    1.220448                             0.323302     False
# 19                    2.085443                             0.786004     False
# 20                    1.220448                             0.323302     False
# 21                    0.552039                             1.224008      True
# 22                    0.965122                             0.908494     False
# 23                    0.786004                             2.085443      True
# 24                    0.536908                             2.336319     False
# 25                    1.956945                             0.532792      True
# 26                    0.552039                             1.224008      True
# 27                    1.956945                             0.532792      True
# 28                    0.965122                             0.908494     False
# 29                    0.537131                             0.562274      True
# 30                    0.786004                             2.085443      True
# 31                    0.552039                             1.224008      True
# 32                    1.963620                             1.550871     False
# 33                    2.085443                             0.786004     False
# 34                    0.870223                             0.370362      True
# 35                    0.421761                             0.295934      True
# 36                    1.956945                             0.532792      True
# 37                    0.295934                             0.421761     False
# 38                    0.786004                             2.085443      True
# 39                    0.965122                             0.908494     False
# 40                    0.965122                             0.908494     False
# 41                    0.965122                             0.908494     False
# 42                    0.786004                             2.085443      True
# 43                    0.421761                             0.295934      True
# 44                    2.085443                             0.786004     False
# 45                    0.965122                             0.908494     False
# 46                    2.085443                             0.786004     False
# 47                    1.963620                             1.550871     False
# 48                    0.908494                             0.965122      True
# 49                    0.536908                             2.336319     False
#
#     total_points  ...  selected  team_a_score  team_h_score  threat  \
# 0              0  ...      9659             1             2     0.0
# 1              1  ...   1265797             2             1     0.0
# 2              0  ...       859             1             0     0.0
# 3              9  ...     77277             1             0     0.0
# 4              0  ...     16181             0             3     0.0
# 5              2  ...    542701             2             1    21.0
# 6              2  ...    237412             0             3     0.0
# 7              2  ...    369081             2             0    25.0
# 8              2  ...    249612             0             0    71.0
# 9              0  ...      1246             1             1     0.0
# 10             1  ...     34179             3             1     0.0
#             kickoff_time  season
# 0   2021-09-19T13:00:00Z    2122
# 1   2021-09-19T13:00:00Z    2122
# 2   2021-09-18T14:00:00Z    2122
# 3   2021-09-18T14:00:00Z    2122
# 4   2021-09-18T16:30:00Z    2122
# 5   2021-09-19T13:00:00Z    2122
# 6   2021-09-18T16:30:00Z    2122
# 7   2021-09-18T11:30:00Z    2122
# 8   2021-09-18T14:00:00Z    2122
# 9   2021-09-17T19:00:00Z    2122
# 10  2021-09-18T14:00:00Z    2122
# 11  2021-09-19T13:00:00Z    2122
# 12  2021-09-18T14:00:00Z    2122
# 13  2021-09-19T13:00:00Z    2122
# 14  2021-09-18T14:00:00Z    2122
# 15  2021-09-19T13:00:00Z    2122
# 16  2021-09-18T14:00:00Z    2122
# 17  2021-09-18T14:00:00Z    2122
# 18  2021-09-18T14:00:00Z    2122
# 19  2021-09-19T13:00:00Z    2122
# 20  2021-09-18T14:00:00Z    2122
# 21  2021-09-19T13:00:00Z    2122
# 22  2021-09-18T16:30:00Z    2122
# 23  2021-09-19T13:00:00Z    2122
# 24  2021-09-18T14:00:00Z    2122
# 25  2021-09-18T14:00:00Z    2122
# 26  2021-09-19T13:00:00Z    2122
# 27  2021-09-18T14:00:00Z    2122
# 28  2021-09-18T16:30:00Z    2122
# 29  2021-09-17T19:00:00Z    2122
# 30  2021-09-19T13:00:00Z    2122
# 31  2021-09-19T13:00:00Z    2122
# 32  2021-09-19T15:30:00Z    2122
# 33  2021-09-19T13:00:00Z    2122
# 34  2021-09-18T11:30:00Z    2122
# 35  2021-09-18T14:00:00Z    2122
# 36  2021-09-18T14:00:00Z    2122
# 37  2021-09-18T14:00:00Z    2122
# 38  2021-09-19T13:00:00Z    2122
# 39  2021-09-18T16:30:00Z    2122
# 40  2021-09-18T16:30:00Z    2122
# 41  2021-09-18T16:30:00Z    2122
# 42  2021-09-19T13:00:00Z    2122
# 43  2021-09-18T14:00:00Z    2122
# 44  2021-09-19T13:00:00Z    2122
# 45  2021-09-18T16:30:00Z    2122
# 46  2021-09-19T13:00:00Z    2122
# 47  2021-09-19T15:30:00Z    2122
# 48  2021-09-18T16:30:00Z    2122
# 49  2021-09-18T14:00:00Z    2122
#
# [50 rows x 34 columns]

# %%
df_latest.shape
# Out:
# (606, 34)

# %%
last_play_proba = remaining_season[remaining_season['gw'] == last_gw][['player', 'team', 'play_proba']]

# %%
last_play_proba.head()
# Out:
#            player              team  play_proba
# 0  Joseph Willock  Newcastle United         1.0
# 1   Jonjo Shelvey  Newcastle United         0.0
# 2    Matt Ritchie  Newcastle United         1.0
# 3    Ciaran Clark  Newcastle United         1.0
# 4     Karl Darlow  Newcastle United         1.0

# %%
# add latest week's play_proba for each player
df_latest = df_latest.merge(last_play_proba, on=['player', 'team'], how='left')

# %%
df_latest.drop_duplicates(inplace=True)

# %%
df_train.drop_duplicates(inplace=True)

# %%
if last_gw==1:
    df_latest['relative_market_value_team_season'] = df_latest['relative_market_value_team']
    df_latest['relative_market_value_opponent_team_season'] = df_latest['relative_market_value_opponent_team']

# %%
# for when you're doing the season value properly
# relative_market_value_season = train_df[train_df['season'] == '2021'][['team', 'relative_market_value_team']].groupby(['team']).first()
# relative_market_value_season = relative_market_value_season.rename(columns={'relative_market_value_team': 'season_value'})
# relative_market_value_season

# %%
# now get futher stats from fbref
# standard stats
features = ['squad', 'comp', 'round', 'shots_total', 'shots_on_target', 'touches', 'pressures',
            'tackles', 'interceptions', 'blocks', 'xg', 'npxg', 'xa', 'sca', 
            'gca', 'passes_completed', 'passes', 'passes_pct',  'carries', 
            'dribbles_completed', 'dribbles']

# %%
# url for the premier league
url_base = 'https://fbref.com'
pl_history_page = '/en/comps/9/history/Premier-League-Seasons'
url = url_base + pl_history_page

# scrape the history table to get latest season
pl_history_table = get_table(url)
pl_history_urls = get_urls(['season'], 'season', pl_history_table, url_base)
season_urls = pl_history_urls[0:1]

df_enhanced = get_stats(features, season_urls, url_base)
# Out:
# 2021-2022
# https://fbref.com/en/comps/9/Premier-League-Stats
# Chelsea
# https://fbref.com/en/squads/cff3d9bb/Chelsea-Stats
# Antonio Rüdiger
# Marcos Alonso
# Jorginho
# Mateo Kovačić
# César Azpilicueta
# Andreas Christensen
# Romelu Lukaku
# Edouard Mendy
# Mason Mount
# Kai Havertz
# Thiago Silva
# Trevoh Chalobah
# Reece James
# Timo Werner
# N'Golo Kanté
# Hakim Ziyech
# Kepa Arrizabalaga
# Callum Hudson-Odoi
# Christian Pulisic
# Saúl Ñíguez
# Emerson Palmieri
# Liverpool
# https://fbref.com/en/squads/822bd0ba/Liverpool-Stats
# Alisson
# Virgil van Dijk
# Sadio Mané
# Mohamed Salah
# Trent Alexander-Arnold
# Joël Matip
# Diogo Jota
# Fabinho
# Jordan Henderson
# Kostas Tsimikas
# Harvey Elliott
# Naby Keïta
# James Milner
# Thiago Alcántara
# Andrew Robertson
# Ibrahima Konaté
# Roberto Firmino
# Alex Oxlade-Chamberlain
# Curtis Jones
# Divock Origi
# Joe Gomez
# Manchester Utd
# https://fbref.com/en/squads/19538871/Manchester-United-Stats
# David de Gea
# Harry Maguire
# Luke Shaw
# Aaron Wan-Bissaka
# Bruno Fernandes
# Mason Greenwood
# Paul Pogba
# Fred
# Raphaël Varane
# Jadon Sancho
# Nemanja Matić
# Victor Lindelöf
# Cristiano Ronaldo
# Scott McTominay
# Daniel James
# Anthony Martial
# Jesse Lingard
# Edinson Cavani
# Donny van de Beek
# Diogo Dalot
# Brighton
# https://fbref.com/en/squads/d07537b9/Brighton-and-Hove-Albion-Stats
# Shane Duffy
# Lewis Dunk
# Robert Sánchez
# Yves Bissouma
# Leandro Trossard
# Neal Maupay
# Adam Lallana
# Adam Webster
# Pascal Groß
# Solly March
# Joël Veltman
# Alexis Mac Allister
# Marc Cucurella
# Danny Welbeck
# Jakub Moder
# Enock Mwepu
# Steven Alzate
# Aaron Connolly
# Dan Burn
# Taylor Richards
# Manchester City
# https://fbref.com/en/squads/b8fd03ef/Manchester-City-St
# https://fbref.com/en/squads/943e8050/Burnley-Stats
# Matthew Lowton
# Ben Mee
# Nick Pope
# James Tarkowski
# Charlie Taylor
# Dwight McNeil
# Chris Wood
# Jóhann Berg Guðmundsson
# Josh Brownhill
# Ashley Westwood
# Ashley Barnes
# Jack Cork
# Jay Rodriguez
# Matěj Vydra
# Aaron Lennon
# Maxwel Cornet
# Erik Pieters
# Norwich City
# https://fbref.com/en/squads/1c781004/Norwich-City-Stats
# Max Aarons
# Grant Hanley
# Tim Krul
# Teemu Pukki
# Milot Rashica
# Billy Gilmour
# Pierre Lees-Melou
# Todd Cantwell
# Kenny McLean
# Ben Gibson
# Brandon Williams
# Lukas Rupp
# Dimitris Giannoulis
# Josh Sargent
# Ozan Kabak
# Andrew Omobamidele
# Christos Tzolis
# Mathias Normann
# Kieran Dowell
# Bali Mumba
# Adam Idah

# %%
# get the player name matching dictionary
with open(path/'match_list.json') as f:
  match_list = json.load(f)

match_list
# Out:
# {'Fabinho': 'Fabio Henrique Tavares',
#  'Alisson': 'Alisson Ramses Becker',
#  'Joël Matip': 'Joel Matip',
#  'Joe Gomez': 'Joseph Gomez',
#  'Naby Keïta': 'Naby Keita',
#  'Adrián': 'Adrián San Miguel del Castillo',
#  'Thiago Alcántara': 'Thiago Alcántara do Nascimento',
#  'Allan': 'Allan Marques Loureiro',
#  'Richarlison': 'Richarlison de Andrade',
#  'Gylfi Sigurðsson': 'Gylfi Sigurdsson',
#  'Séamus Coleman': 'Seamus Coleman',
#  'André Gomes': 'André Filipe Tavares Gomes',
#  'Bernard': 'Bernard Anício Caldeira Duarte',
#  'Çağlar Söyüncü': 'Çaglar Söyüncü',
#  'Bruno Fernandes': 'Bruno Miguel Borges Fernandes',
#  'Fred': 'Frederico Rodrigues de Paula Santos',
#  'Nemanja Matić': 'Nemanja Matic',
#  'Alex Telles': 'Alex Nicolao Telles',
#  'Pierre Højbjerg': 'Pierre-Emile Højbjerg',
#  'Son Heung-min': 'Heung-Min Son',
#  'Lucas Moura': 'Lucas Rodrigues Moura da Silva',
#  'Érik Lamela': 'Erik Lamela',
#  'Dele Alli': 'Bamidele Alli',
#  'Carlos Vinícius': 'Carlos Vinicius Alves Morais',
#  'Ederson': 'Ederson Santana de Moraes',
#  'Rodri': 'Rodrigo Hernandez',
#  'Rúben Dias': 'Rúben Santos Gato Alves Dias',
#  'João Cancelo': 'João Pedro Cavaco Cancelo',
#  'İlkay Gündoğan': 'Ilkay Gündogan',
#  'Gabriel Jesus': 'Gabriel Fernando de Jesus',
#  'Ferrán Torres': 'Ferran Torres',
#  'Bernardo Silva': 'Bernardo Mota Veiga de Carvalho e Silva',
#  'Fernandinho': 'Fernando Luiz Rosa',
#  'Eric García': 'Eric Garcia',
#  'Matty Cash': 'Matthew Cash',
#  'Douglas Luiz': 'Douglas Luiz Soares de Paulo',
#  'Ezri Konsa': 'Ezri Konsa Ngoyo',
#  'Trézéguet': 'Mahmoud Ahmed Ibrahim Hassan',
#  'Ben Chilwell': 'Benjamin Chilwell',
#  'Thiago Silva': 'Thiago Emiliano da Silva',
#  'Mateo Kovačić': 'Mateo Kovacic',
#  'Jorginho': 'Jorge Luiz Frello Filho',
#  'Emerson Palmieri': 'Emerson Palmieri dos Santos',
#  'Oriol Romeu': 'Oriol Romeu Vidal',
#  'Dan Nlundulu': "Daniel N'Lundulu",
#  'Łukasz Fabiański': 'Lukasz Fabianski',
#  'Tomáš Souček': 'Tomas Soucek',
#  'Vladimír Coufal': 'Vladimir Coufal',
#  'Felipe Anderson': 'Felipe Anderson Pereira Gomes',
#  'Rui Patrício': 'Rui Pedro dos Santos Patrício',
#  'Pedro Neto': 'Pedro Lomba Neto',
#  'Daniel Podence': 'Daniel Castelo Podence',
#  'Nélson Semedo': 'Nélson Cabral Semedo',
#  'Rúben Neves': 'Rúben Diogo da Silva Neves',
#  'João Moutinho': 'João Filipe Iria Santos Moutinho',
#  'Rayan Aït Nouri': 'Rayan Ait Nouri',
#  'Fábio Silva': 'Fabio Silva',
#  'Rúben Vinagre': 'Rúben Gonçalo Silva Nascimento Vinagre',
#  'Vitinha': 'Vitor Ferreira',
#  'Rodrigo': 'Rodrigo Moreno',
#  'Pablo Hernández': 'Pablo Hernández Domínguez',
#  'Ian Carlo Poveda': 'Ian Carlo Poveda-Ocampo',
#  'Joelinton': 'Joelinton Cássio Apolinário de Lira',
#  'Luka Milivojević': 'Luka Milivojevic',
#  'Jaïro Riedewald': 'Jairo Riedewald',
#  'Gabriel Dos Santos': 'Gabriel Magalhães',
#  'Willian': 'Willian Borges Da Silva',
#  'Dani Ceballos': 'Daniel Ceballos Fernández',
#  'David Luiz': 'David Luiz Moreira Marinho',
#  'Eddie Nketiah': 'Edward Nketiah',
#  'Joe Willock': 'Joseph Willock',
#  'Sead Kolašinac': 'Sead Kolasinac',
#  'Martinelli': 'Gabriel Teodoro Martinelli Silva',
#  'Solly March': 'Solomon March',
#  'Bernardo': 'Bernardo Fernandes da Silva Junior',
#  'Jóhann Berg Guðmundsson': 'Johann Berg Gudmundsson',
#  'Matěj Vydra': 'Matej Vydra',
#  'Andre-Frank Zambo Anguissa': 'André-Frank Zambo Anguissa',
#  'Semi Ajayi': 'Oluwasemilogo Adesewo Ibidapo Ajayi',
#  'Branislav Ivanović': 'Branislav Ivanovic',
#  'Filip Krovinović': 'Filip Krovinovic',
#  'Ahmed Hegazi': 'Ahmed El-Sayed Hegazi',
#  'Harvey Elliot': 'Harvey Elliott',
#  'Angeliño': 'Angelo Ogbonna',
#  'Thomas Doyle': 'Tommy Doyle',
#  'Diogo Dalot': 'José Diogo Dalot Teixeira',
#  'Pedro': 'Pedro Rodríguez Ledesma',
#  'Ricardo Pereira': 'Ricardo Domingos Barbosa Pereira',
#  'Gedson Fernandes': 'Gedson Carvalho Fernandes',
#  "Georges-Kévin N'Koudou": 'Georges-Kévin Nkoudou',
#  'Jonny Castro': 'Jonathan Castro Otto',
#  'Jesús Vallejo': 'Jesús Vallejo Lázaro',
#  'Bruno Jordão': 'Bruno André Cavaco Jordao',
#  'Mattéo Guendouzi': 'Matteo Guendouzi',
#  'Richairo Živković': 'Richairo Zivkovic',
#  'Danny Drinkwater': 'Daniel Drinkwater',
#  'Martin Dúbravka': 'Martin Dubravka',
#  'Yoshinori Mutō': 'Yoshinori Muto',
#  'Ki Sung-yueng': 'Sung-yueng Ki',
#  'Roberto': 'Roberto Jimenez Gago',
#  'Javier Hernández': 'Javier Hernández Balcázar',
#  'Frederic Guilbert': 'Frédéric Guilbert',
#  'Björn Engels': 'Bjorn Engels',
#  'Pepe Reina': 'José Reina',
#  'Jota': 'José Ignacio Peleteiro Romallo',
#  'Arnaut Groeneveld': 'Arnaut Danjuma Groeneveld',
#  'Étienne Capoue': 'Etienne Capoue',
#  'Kiko Femenía': 'Francisco Femenía Far',
#  'Ismaila Sarr': 'Ismaila Sarr',
#  'João Pedro': 'João Pedro Junqueira de Jesus',
#  'Max Aarons': 'Max Aarons',
#  'Emi Buendía': 'Emiliano Buendía Stati',
#  'Mario Vrančić': 'Mario Vrancic',
#  'Josip Drmić': 'Josip Drmic',
#  'Ralf Fährmann': 'Ralf Fahrmann',
#  'Danilo': 'Danilo Luiz da Silva',
#  'Petr Čech': 'Petr Cech',
#  'Idrissa Gana Gueye': 'Idrissa Gueye',
#  'Marko Arnautović': 'Marko Arnautovic',
#  'Xande Silva': 'Alexandre Nascimento Costa Silva',
#  'Julián Speroni': 'Julian Speroni',
#  'Kenedy': 'Robert Kenedy Nunes do Nascimento',
#  'Joselu': 'Jose Luis Mato Sanmartín',
#  'Asmir Begović': 'Asmir Begovic',
#  'Kayne Ramsey': 'Kayne Ramsay',
#  'Bruno': 'Bruno Saltor Grau',
#  'Junior Hoilett': 'David Junior Hoilett',
#  'Greg Cunningham': 'Greg Cunninghamm',
#  'Jazz Richards': 'Ashley Darel Jazz Richards',
#  'Jean Seri': 'Jean Michael Seri',
#  'Fabricio': 'Fabricio Agosto Ramírez',
#  'Lazar Marković': 'Lazar Markovic',
#  'Mathias Jørgensen': 'Mathias Jorgensen',
#  'Steve Mounié': 'Steve Mounie',
#  'Jon Gorenc Stanković': 'Jon Gorenc Stankovic',
#  'Matty Daly': 'Matthew Daly',
#  'Yaya Touré': 'Gnegneri Yaya Touré',
#  'Brahim Díaz': 'Brahim Diaz',
#  'Zlatan Ibrahimović': 'Zlatan Ibrahimovic',
#  'Marko Grujić': 'Marko Grujic',
#  'Charly Musonda Jr.': 'Charly Musonda',
#  'Nikola Vlašić': 'Nikola Vlasic',
#  'Aleksandar Dragović': 'Aleksandar Dragovic',
#  'Eldin Jakupović': 'Eldin Jakupovic',
#  'Rob Elliot': 'Robert Elliot',
#  'Jesús Gámez': 'Jesús Gámez Duarte',
#  'Massadio Haïdara': 'Massadio Haidara',
#  'Lee Chung-yong': 'Chung-yong Lee',
#  'Freddie Ladapo': 'Olayinka Fredrick Oladotun Ladapo',
#  'João Mário': 'João Mário Naval Costa Eduardo',
#  'José Fonte': 'Jose Fonte',
#  'Younès Kaboul': 'Younes Kaboul',
#  'Izzy Brown': 'Isaiah Brown',
#  'Dušan Tadić': 'Dusan Tadic',
#  'Àngel Rangel': 'Angel Rangel',
#  'Badou Ndiaye': 'Papa Alioune Ndiaye',
#  'Jesé': 'Jesé Rodríguez Ruiz',
#  'Tom Edwards': 'Thomas Edwards',
#  'Kostas Stafylidis': 'Konstantinos Stafylidis',
#  'Lasse Sørensen': 'Lasse Sorenson',
#  'Bojan Krkić': 'Bojan Krkic',
#  'Allan Nyom': 'Allan-Roméo Nyom',
#  'Ahmed Elmohamady': 'Ahmed El Mohamady',
#  'Hélder Costa': 'Hélder Wander Sousa de Azevedo e Costa',
#  'Mohamed Elneny': 'Mohamed Naser El Sayed Elneny',
#  'Emile Smith-Rowe': 'Emile Smith Rowe',
#  'Ivan Cavaleiro': 'Ivan Ricardo Neves Abreu Cavaleiro',
#  'Bobby Reid': 'Bobby Decordova-Reid',
#  'Ahmed El-Sayed Hegazi': 'Ahmed El-Sayed Hegazy',
#  'Kiko Casilla': 'Francisco Casilla Cortés',
#  'Willian José': 'Willian José Da Silva',
#  'Kostas Tsimikas': 'Konstantinos Tsimikas',
#  'Okay Yokuşlu': 'Okay Yokuslu',
#  'Khanya Leshabela': 'Thakgalo Leshabela',
#  'Jaden Philogene Bidace': 'Jaden Philogene-Bidace',
#  'William Thomas Fish': 'William Fish',
#  'David Raya': 'David Raya Martin',
#  'Oghenekaro Etebo': 'Oghenekaro Peter Etebo',
#  'Ismaïla Sarr': 'Ismaila Sarr',
#  'Cucho': 'Juan Camilo Hernández Suárez',
#  'Enoch Mwepu': 'Enock Mwepu',
#  'Emiliano Buendía': 'Emiliano Buendía StatiJosé Malheiro de Sá',
#  'José Sá': 'José Malheiro de Sá',
#  'Francisco Trincão': 'Francisco Machado Mota de Castro Trincão',
#  'Valentino Livramento': 'Tino Livramento',
#  'Nuno Tavares': 'Nuno Varela Tavares',
#  'Jesuran Rak Sakyi': 'Jesurun Rak-Sakyi',
#  'Maximillian Aarons': 'Max Aarons',
#  'Josh Sargent': 'Joshua Sargent',
#  'Junior Firpo': 'Héctor Junior Firpo Adames',
#  'Imran Louza': 'Imrân Louza',
#  'Bryan': 'Bryan Gil Salvatierra',
#  'Kiernan Dewsbury Hall': 'Kiernan Dewsbury-Hall',
#  'Cristiano Ronaldo': 'Cristiano Ronaldo dos Santos Aveiro',
#  'Emerson': 'Emerson Aparecido Leite de Souza Junior',
#  'Mads Roerslev': 'Mads Roerslev Rasmussen',
#  'Odsonne Édouard': 'Odsonne Edouard',
#  'Hwang Hee-chan': 'Hee-Chan Hwang'}

# %%
team_list = {}
team_list['Brighton'] = 'Brighton and Hove Albion'
team_list['Leeds United'] = 'Leeds'
team_list['Manchester Utd'] = 'Manchester United'
team_list['Newcastle Utd'] = 'Newcastle United'
team_list['Norwich City'] = 'Norwich'
team_list['Sheffield Utd'] = 'Sheffield United'
team_list['Tottenham'] = 'Tottenham Hotspur'
team_list['West Brom'] = 'West Bromwich Albion'
team_list['West Ham'] = 'West Ham United'
team_list['Wolves'] = 'Wolverhampton Wanderers'

# %%
# replace non-matching names/teams and extract gw as integer
df_enhanced['alt_name'] = df_enhanced['player'].replace(match_list)
df_enhanced['squad'] = df_enhanced['squad'].replace(team_list)
df_enhanced['round'] = df_enhanced['round'].str[-2:].astype('int')

# %%
# remove duplicated (happens when players transferred within season)
df_enhanced = df_enhanced.drop_duplicates()

# %%
df_enhanced
# Out:
#          season           player        date    squad            comp  round  \
# 0     2021-2022  Antonio Rüdiger  2021-08-14  Chelsea  Premier League      1
# 1     2021-2022  Antonio Rüdiger  2021-08-22  Chelsea  Premier League      2
# 2     2021-2022  Antonio Rüdiger  2021-08-28  Chelsea  Premier League      3
# 3     2021-2022  Antonio Rüdiger  2021-09-11  Chelsea  Premier League      4
# 4     2021-2022  Antonio Rüdiger  2021-09-19  Chelsea  Premier League      5
# ...         ...              ...         ...      ...             ...    ...
# 1390  2021-2022       Bali Mumba  2021-08-21  Norwich  Premier League      2
# 1391  2021-2022        Adam Idah  2021-08-14  Norwich  Premier League      1
# 1392  2021-2022        Adam Idah  2021-08-28  Norwich  Premier League      3
# 1393  2021-2022        Adam Idah  2021-09-11  Norwich  Premier League      4
# 1394  2021-2022        Adam Idah  2021-09-18  Norwich  Premier League      5
#
#      shots_total shots_on_target touches pressures  ...   xa sca gca  \
# 0              0               0      94         8  ...  0.0   0   0
# 1              0               0      71         6  ...  0.0   0   0
# 2              0               0      44         6  ...  0.0   0   0
# 3              2               0      54         5  ...  0.0   1   0
# 4              2               2      61         5  ...  0.1   5   1
# ...          ...             ...     ...       ...  ...  ...  ..  ..
# 1390           0               0      19        12  ...  0.0   0   0
# 1391           1               1       6         5  ...  0.0   0   0
# 1392           1               0       6         2  ...  0.0   0   0
# 1393           0               0       3         2  ...  0.2   1   0
# 1394           0               0       3         0  ...  0.0   0   0
#
#      passes_completed passes passes_pct carries dribbles_completed dribbles  \
# 0                  77     84       91.7      77                  0        0
# 1                  56     66       84.8      50                  0        0
# 2                  19     30       63.3      17                  0        0
# 3                  38     43       88.4      27                  0        0
# 4                  48     53       90.6      41                  0        0
# ...               ...    ...        ...     ...                ...      ...
# 1390                7     10       70.0       9                  0        1
# 1391                3      5       60.0       2                  0        0
# 1392                4      4      100.0       5                  0        1
# 1393                1      2       50.0       2                  0        0
# 1394                2      3       66.7       3                  1        1
#
#              alt_name
# 0     Antonio Rüdiger
# 1     Antonio Rüdiger
# 2     Antonio Rüdiger
# 3     Antonio Rüdiger
# 4     Antonio Rüdiger
# ...               ...
# 1390       Bali Mumba
# 1391        Adam Idah
# 1392        Adam Idah
# 1393        Adam Idah
# 1394        Adam Idah
#
# [1391 rows x 25 columns]

# %%
# create date field in same format as enhanced data
df_latest['date'] = df_latest['kickoff_time'].str[:10]

# %%
# check if any names aren't matching
enhanced_players = df_enhanced[df_enhanced['date'].isin(df_latest['date'].unique())]['alt_name'].unique().tolist()
standard_players = df_latest['player'].unique().tolist()

unmatched_players = [x for x in enhanced_players if x not in standard_players]
unmatched_players
# Out:
# ['Asmir Begovic']

# %%
# check if any teams aren't matching
enhanced_teams = df_enhanced[df_enhanced['date'].isin(df_latest['date'].unique())]['squad'].unique().tolist()
standard_teams = df_latest['team'].unique().tolist()

unmatched_teams = [x for x in enhanced_teams if x not in standard_teams]
unmatched_teams
# Out:
# []

# %%
# any additional corrections
# match_list['Asmir Begović'] = 'Asmir Begović'
# match_list['Emerson'] = 'Emerson Aparecido Leite de Souza Junior'
# match_list['Mads Roerslev'] = 'Mads Roerslev Rasmussen'
# match_list['Odsonne Édouard'] = 'Odsonne Edouard'
# match_list['Hwang Hee-chan'] = 'Hee-Chan Hwang'

# %%
# replace additional non-matching names
# df_enhanced['alt_name'] = df_enhanced['player'].replace(match_list)

# %%
# make sure there are no non matches after update
# enhanced_players =  df_enhanced[df_enhanced['round'] == last_gw]['alt_name'].unique().tolist()
# standard_players = df_latest['player'].unique().tolist()

# unmatched_players = [x for x in enhanced_players if x not in standard_players]
# unmatched_players
# Out:
# []

# %%
# if match list was updated then update the file
# json_file = json.dumps(match_list)
# f = open(path/"match_list.json","w")
# f.write(json_file)
# f.close()

# %%
# check there are no duplicates in the join fields for the enhanced data
assert(len(df_enhanced[df_enhanced.duplicated(subset=['alt_name', 'date'], keep=False)]) == 0)

# %%
df_latest[df_latest.duplicated(subset=['date','player','team'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [player, gw, position, minutes, team, opponent_team, relative_market_value_team, relative_market_value_opponent_team, was_home, total_points, assists, bonus, bps, clean_sheets, creativity, goals_conceded, goals_scored, ict_index, influence, own_goals, penalties_missed, penalties_saved, red_cards, saves, selected, team_a_score, team_h_score, threat, transfers_balance, transfers_in, transfers_out, yellow_cards, kickoff_time, season, play_proba, date]
# Index: []
#
# [0 rows x 36 columns]

# %%
# check there are no duplicates in the join fields for the standard data
assert(len(df_train[df_train.duplicated(subset=['date','player','team'])]) == 0)

# %%
# df_train[df_train.duplicated(subset=['date','player','team'])]

# %%
# join standard and enhanced dataframes
df_latest_further = df_latest.merge(df_enhanced.drop(['player', 'season', 'round'], axis=1), 
                                   left_on=['date', 'player', 'team'], 
                                   right_on=['date', 'alt_name', 'squad'], how='left')

# %%
# drop the alt name field and check the length of the standard
# dataframe has not increased
df_latest_further = df_latest_further.drop(['alt_name'], axis=1)
assert(len(df_latest_further) == len(df_latest_further))

# %%
# add crowds field
df_latest_further['crowds'] = 1

# %%
assert(sum(df_latest_further[df_latest_further['minutes'] > 0]['xg'].isnull()) == 0)

# %%
# df_latest_further[df_latest_further['minutes'] > 0][df_latest_further[df_latest_further['minutes'] > 0]['xg'].isnull()]

# %%
df_train_new = pd.concat([df_train, df_latest_further], ignore_index=True, axis=0, sort=False)

# %%
df_train_new[df_train_new['player'] == 'Harry Kane'].tail()
# Out:
#             player  gw  position  minutes               team  \
# 114999  Harry Kane   1         4        0  Tottenham Hotspur
# 115556  Harry Kane   2         4       18  Tottenham Hotspur
# 116128  Harry Kane   3         4       90  Tottenham Hotspur
# 116711  Harry Kane   4         4       90  Tottenham Hotspur
# 117311  Harry Kane   5         4       90  Tottenham Hotspur
#
#                   opponent_team  relative_market_value_team  \
# 114999          Manchester City                    1.560569
# 115556  Wolverhampton Wanderers                    1.558729
# 116128                  Watford                    1.537334
# 116711           Crystal Palace                    1.547840
# 117311                  Chelsea                    1.550871
#
#         relative_market_value_opponent_team  was_home  total_points  ...   xa  \
# 114999                             2.349720      True             0  ...  NaN
# 115556                             0.858519     False             0  ...  0.1
# 116128                             0.295470      True             1  ...  0.3
# 116711                             0.531751     False             2  ...    0
# 117311                             1.963620      True             2  ...  0.0
#
#         sca  gca  passes_completed  passes  passes_pct  carries  \
# 114999  NaN  NaN               NaN     NaN         NaN      NaN
# 115556    2    0                 7      10          70        7
# 116128    3    0                21      26        80.8       30
# 116711    1    0                16      23        69.6       26
# 117311    1    0                24      31        77.4       29
#
#         dribbles_completed  dribbles  crowds
# 114999                 NaN       NaN       1
# 115556                   0         0       1
# 116128                   2         3       1
# 116711                   2         3       1
# 117311                   1         2       1
#
# [5 rows x 59 columns]

# %%
df_train_new.tail(7)
# Out:
#                             player  gw  position  minutes  \
# 117696  Yerson Mosquera Valdelamar   5         2        0
# 117697                 Yoane Wissa   5         3        0
# 117698             Youri Tielemans   5         3       90
# 117699               Yves Bissouma   5         3       78
# 117700                Zack Steffen   5         1        0
# 117701            Álvaro Fernández   5         1        0
# 117702              Çaglar Söyüncü   5         2       90
#
#                             team             opponent_team  \
# 117696   Wolverhampton Wanderers                 Brentford
# 117697                 Brentford   Wolverhampton Wanderers
# 117698            Leicester City  Brighton and Hove Albion
# 117699  Brighton and Hove Albion            Leicester City
# 117700           Manchester City               Southampton
# 117701                 Brentford   Wolverhampton Wanderers
# 117702            Leicester City  Brighton and Hove Albion
#
#         relative_market_value_team  relative_market_value_opponent_team  \
# 117696                    0.870223                             0.370362
# 117697                    0.370362                             0.870223
# 117698                    1.224008                             0.552039
# 117699                    0.552039                             1.224008
# 117700                    2.336319                             0.536908
# 117701                    0.370362                             0.870223
# 117702                    1.224008                             0.552039
#
#         was_home  total_points  ...   xa  sca  gca  passes_completed  passes  \
# 117696      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 117697     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 117698     False             5  ...  0.9    4    1                55      67
# 117699      True             2  ...  0.0    0    0                19      23
# 117700      True             0  ...  NaN  NaN  NaN               NaN     NaN
# 117701     False             0  ...  NaN  NaN  NaN               NaN     NaN
# 117702     False             1  ...  0.0    0    0                60      67
#
#         passes_pct  carries  dribbles_completed  dribbles  crowds
# 117696         NaN      NaN                 NaN       NaN       1
# 117697         NaN      NaN                 NaN       NaN       1
# 117698        82.1       60                   0         1       1
# 117699        82.6       13                   0         0       1
# 117700         NaN      NaN                 NaN       NaN       1
# 117701         NaN      NaN                 NaN       NaN       1
# 117702        89.6       52                   0         0       1
#
# [7 rows x 59 columns]

# %%
df_latest_further.shape
# Out:
# (606, 57)

# %%
df_train_new.shape
# Out:
# (117703, 59)

# %%
# save latest training set to csv
# overwrite existing one
df_train_new.to_csv(path/'train_v8.csv')

# %%
# get fixtures
fixtures = pd.read_csv(path/'2021-22/fixtures.csv')
team_dict = teams[['team_2122', 'team']].dropna().set_index('team_2122').to_dict()['team']

fixtures['home_team'] = fixtures['team_h'].replace(team_dict)
fixtures['away_team'] = fixtures['team_a'].replace(team_dict)
fixtures = fixtures[['home_team', 'away_team', 'kickoff_time', 'event']]
fixtures = fixtures.rename(columns={'event':'gw'})


# use these two lines if updating play_proba later in week
# current_gw = last_gw
# df_train_new = pd.read_csv(path/'train_v7.csv', index_col=0, dtype={'season':str,
#                                                                     'comp':str,
#                                                                     'squad':str})

# set starting gameweek (where are we right now in the season)
current_gw = last_gw + 1
# 95                   Watford               Southampton  2021-10-30T14:00:00Z
# 92                 Liverpool  Brighton and Hove Albion  2021-10-30T14:00:00Z
# 93           Manchester City            Crystal Palace  2021-10-30T14:00:00Z
# 90            Leicester City                   Arsenal  2021-10-30T11:30:00Z
# 94          Newcastle United                   Chelsea  2021-10-30T14:00:00Z
# 91                   Burnley                 Brentford  2021-10-30T14:00:00Z
#
#     gw  match_no
# 50   6         0
# 51   6         1
# 52   6         2
# 53   6         3
# 54   6         4
# 55   6         5
# 56   6         6
# 57   6         7
# 58   6         8
# 59   6         9
# 69   7        10
# 68   7        11
# 67   7        12
# 66   7        13
# 65   7        14
# 62   7        15
# 63   7        16
# 61   7        17
# 60   7        18
# 64   7        19
# 76   8        20
# 79   8        21
# 78   8        22
# 77   8        23
# 75   8        24
# 72   8        25
# 73   8        26
# 71   8        27
# 70   8        28
# 74   8        29
# 89   9        30
# 88   9        31
# 87   9        32
# 86   9        33
# 85   9        34
# 83   9        35
# 82   9        36
# 81   9        37
# 80   9        38
# 84   9        39
# 96  10        40
# 99  10        41
# 98  10        42
# 97  10        43
# 95  10        44
# 92  10        45
# 93  10        46
# 90  10        47
# 94  10        48
# 91  10        49

# %%
# add universal team codes for home and away teams
fixtures = fixtures.merge(teams, left_on='home_team', right_on='team', how='left')
fixtures = fixtures.merge(teams, left_on='away_team', right_on='team', how='left')
fixtures = fixtures[['gw', 'match_no', 'home_team', 'away_team', 'kickoff_time', 'team_code_x', 'team_code_y']]
fixtures.rename(index=str,
                columns={'team_code_x':'home_team_code',
                         'team_code_y':'away_team_code'},
                inplace=True)

# %%
fixtures.head()
# Out:
#    gw  match_no          home_team        away_team          kickoff_time  \
# 0   6         0            Chelsea  Manchester City  2021-09-25T11:30:00Z
# 1   6         1  Manchester United      Aston Villa  2021-09-25T11:30:00Z
# 2   6         2            Everton          Norwich  2021-09-25T14:00:00Z
# 3   6         3              Leeds  West Ham United  2021-09-25T14:00:00Z
# 4   6         4     Leicester City          Burnley  2021-09-25T14:00:00Z
#
#    home_team_code  away_team_code
# 0               8              43
# 1               1               7
# 2              11              45
# 3               2              21
# 4              13              90

# %%
# all_players.replace(to_replace='None', value=1, inplace=True)

# %%
all_players[all_players['play_proba_2122'] == '0']
# Out:
#                       full_name play_proba_2122  position_2122  id_2122  \
# 1          Rúnar Alex Rúnarsson               0              1        2
# 2       Willian Borges Da Silva               0              3        3
# 8               Héctor Bellerín               0              2        9
# 17               Lucas Torreira               0              3       18
# 22      Konstantinos Mavropanos               0              2       24
# ..                          ...             ...            ...      ...
# 594         Andreas Söndergaard               0              1      444
# 596  Yerson Mosquera Valdelamar               0              2      446
# 599             Rayan Ait Nouri               0              2      470
# 601             Patrick Cutrone               0              4      523
# 604           Christian Marques               0              2      549
#
#      cost_2122  team_2122 web_name_2122
# 1           40          3     Rúnarsson
# 2           63          3       Willian
# 8           48          3      Bellerín
# 17          45          3      Torreira
# 22          45          3    Mavropanos
# ..         ...        ...           ...
# 594         40         39   Söndergaard
# 596         45         39      Mosquera
# 599         43         39     Ait Nouri
# 601         50         39       Cutrone
# 604         40         39       Marques
#
# [132 rows x 7 columns]

# %%
# join home team to all players for current season
home_df = fixtures.merge(all_players, 
               left_on='home_team_code', 
               right_on='team_2122', 
               how='left')

# pull out the required fields and rename columns
home_df = home_df[['gw', 'match_no', 'home_team', 'away_team', 'kickoff_time', 
                   'full_name', 'position_2122', 'cost_2122', 'play_proba_2122', 
                   'web_name_2122']]
home_df.rename(index=str, 
               columns={'home_team':'team',
                        'away_team':'opponent_team',
                        'full_name':'player',
                        'position_2122':'position',
                        'cost_2122':'price',
                        'play_proba_2122':'play_proba',
                        'web_name_2122':'short_name'},
              inplace=True)

# add home flag
home_df['was_home'] = True

# %%
# join away team to all players for current season
away_df = fixtures.merge(all_players, 
               left_on='away_team_code', 
               right_on='team_2122', 
               how='left')

# pull out the required fields and rename columns
away_df = away_df[['gw',  'match_no', 'away_team', 'home_team', 'kickoff_time', 
                   'full_name', 'position_2122', 'cost_2122', 'play_proba_2122', 
                   'web_name_2122']]
away_df.rename(index=str, 
               columns={'away_team':'team',
                        'home_team':'opponent_team',
                        'full_name':'player',
                        'position_2122':'position',
                        'cost_2122':'price',
                        'play_proba_2122':'play_proba',
                        'web_name_2122':'short_name'},
              inplace=True)

# add home flag
away_df['was_home'] = False

# %%
# look at away players
away_df.head()
# Out:
#    gw  match_no             team opponent_team          kickoff_time  \
# 0   6         0  Manchester City       Chelsea  2021-09-25T11:30:00Z
# 1   6         0  Manchester City       Chelsea  2021-09-25T11:30:00Z
# 2   6         0  Manchester City       Chelsea  2021-09-25T11:30:00Z
# 3   6         0  Manchester City       Chelsea  2021-09-25T11:30:00Z
# 4   6         0  Manchester City       Chelsea  2021-09-25T11:30:00Z
#
#             player  position  price play_proba short_name  was_home
# 0    Jack Grealish         3     80       None   Grealish     False
# 1      Kyle Walker         2     55       None     Walker     False
# 2   Ilkay Gündogan         3     73         50   Gündogan     False
# 3  Kevin De Bruyne         3    119        100  De Bruyne     False
# 4      John Stones         2     53         75     Stones     False

# %%
# look at home players
home_df.head()
# Out:
#    gw  match_no     team    opponent_team          kickoff_time  \
# 0   6         0  Chelsea  Manchester City  2021-09-25T11:30:00Z
# 1   6         0  Chelsea  Manchester City  2021-09-25T11:30:00Z
# 2   6         0  Chelsea  Manchester City  2021-09-25T11:30:00Z
# 3   6         0  Chelsea  Manchester City  2021-09-25T11:30:00Z
# 4   6         0  Chelsea  Manchester City  2021-09-25T11:30:00Z
#
#                      player  position  price play_proba    short_name  \
# 0         César Azpilicueta         2     60       None   Azpilicueta
# 1            Olivier Giroud         4     65          0        Giroud
# 2  Thiago Emiliano da Silva         2     54       None  Thiago Silva
# 3             Marcos Alonso         2     58       None        Alonso
# 4   Jorge Luiz Frello Filho         3     59       None      Jorginho
#
#    was_home
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True

# %%
# # calculate average minutes over last 5 gameweeks
# # first get last 5 gameweeks in current season
# recent_mins = df_train_new[(df_train_new['gw'] >= current_gw - 5) & 
#                            (df_train_new['season'] == season_names[0])][['player', 'minutes', 'play_proba']]

# # recent_mins = df_train_new[((df_train_new['gw'] >= 40 - 5) & 
# #                            (df_train_new['season'] == '1920')) | 
# #                            ((df_train_new['gw'] >= 1) & 
# #                            (df_train_new['season'] == '2021'))][['player', 'minutes', 'play_proba']]

# # exclude weeks where the player had an injury designation (i.e. keep where play_proba is 1)
# recent_mins = recent_mins[recent_mins['play_proba'] == 1]

# len(recent_mins)

# # average for each player
# recent_mins = recent_mins.groupby(['player'])['minutes'].mean().to_dict()

# recent_mins

# %%
# concatenate home and away players
remaining_season_df = home_df.append(away_df).reset_index(drop=True)

# add home and away team market values
remaining_season_df = remaining_season_df.merge(teams_mv[teams_mv['season'] == '2122'],
                                                left_on='team', 
                                                right_on='name', 
                                                how='left').drop(['name', 'season'], axis=1)

remaining_season_df = remaining_season_df.merge(teams_mv[teams_mv['season'] == '2122'],
                                                left_on='opponent_team', 
                                                right_on='name', 
                                                how='left').drop(['name', 'season'], axis=1)

remaining_season_df.rename(index=str, 
                           columns={'relative_market_value_x':'relative_market_value_team',
                                    'relative_market_value_y':'relative_market_value_opponent_team'},
                           inplace=True)

# add season name
remaining_season_df['season'] = season_names[0]

# divide cost by 10 for actual cost
remaining_season_df['price'] = remaining_season_df['price']/10

# set availability probability
# 0 = 0% chance, 25 = 25% chance, etc
# 'None' or '100' = 100% chance
remaining_season_df.loc[remaining_season_df['play_proba'] == 'None', 'play_proba'] = 100
remaining_season_df['play_proba'] = remaining_season_df['play_proba'].astype('float') / 100

# cast position to integer
remaining_season_df['position'] = remaining_season_df['position'].astype(int)

# # add minutes based on last five fixtures
# remaining_season_df['minutes'] = remaining_season_df['player'].map(recent_mins)
# remaining_season_df['minutes'].fillna(0, inplace=True)

# # multiply minutes by play probability
# remaining_season_df['minutes'] = remaining_season_df['minutes'] * remaining_season_df['play_proba']

# %%
remaining_season_df.head(50)
# Out:
#     gw  match_no               team    opponent_team          kickoff_time  \
# 0    6         0            Chelsea  Manchester City  2021-09-25T11:30:00Z
# 1    6         0            Chelsea  Manchester City  2021-09-25T11:30:00Z
# 2    6         0            Chelsea  Manchester City  2021-09-25T11:30:00Z
# 3    6         0            Chelsea  Manchester City  2021-09-25T11:30:00Z
# 4    6         0            Chelsea  Manchester City  2021-09-25T11:30:00Z
# 5    6         0            Chelsea  Manchester City  2021-09-25T11:30:00Z
# 6    6         0            Chelsea  Manchester City  2021-09-25T11:30:00Z
# 7    6         0            Chelsea  Manchester City  2021-09-25T11:30:00Z
# 8    6         0            Chelsea  Manchester City  2021-09-25T11:30:00Z
# 9    6         0            Chelsea  Manchester City  2021-09-25T11:30:00Z
# 10   6         0            Chelsea  Manchester City  2021-09-25T11:30:00Z
# 11   6         0            Chelsea  Manchester City  2021-09-25T11:30:00Z
# 12   6         0            Chelsea  Manchester City  2021-09-25T11:30:00Z
# 13   6         0            Chelsea  Manchester City  2021-09-25T11:30:00Z
# 14   6         0            Chelsea  Manchester City  2021-09-25T11:30:00Z
# 15   6         0            Chelsea  Manchester City  2021-09-25T11:30:00Z
# 16   6         0            Chelsea  Manchester City  2021-09-25T11:30:00Z
# 17   6         0            Chelsea  Manchester City  2021-09-25T11:30:00Z
# 18   6         0            Chelsea  Manchester City  2021-09-25T11:30:00Z
# 19   6         0            Chelsea  Manchester City  2021-09-25T11:30:00Z
# 20   6         0            Chelsea  Manchester City  2021-09-25T11:30:00Z
# 21   6         0            Chelsea  Manchester City  2021-09-25T11:30:00Z
# 22   6         0            Chelsea  Manchester City  2021-09-25T11:30:00Z
# 23   6         0            Chelsea  Manchester City  2021-09-25T11:30:00Z
# 24   6         0            Chelsea  Manchester City  2021-09-25T11:30:00Z
# 25   6         0            Chelsea  Manchester City  2021-09-25T11:30:00Z
# 26   6         0            Chelsea  Manchester City  2021-09-25T11:30:00Z
# 27   6         0            Chelsea  Manchester City  2021-09-25T11:30:00Z
# 28   6         0            Chelsea  Manchester City  2021-09-25T11:30:00Z
# 29   6         0            Chelsea  Manchester City  2021-09-25T11:30:00Z
# 30   6         1  Manchester United      Aston Villa  2021-09-25T11:30:00Z
# 31   6         1  Manchester United      Aston Villa  2021-09-25T11:30:00Z
# 32   6         1  Manchester United      Aston Villa  2021-09-25T11:30:00Z
# 33   6         1  Manchester United      Aston Villa  2021-09-25T11:30:00Z
# 34   6         1  Manchester United      Aston Villa  2021-09-25T11:30:00Z
# 35   6         1  Manchester United      Aston Villa  2021-09-25T11:30:00Z
# 36   6         1  Manchester United      Aston Villa  2021-09-25T11:30:00Z
# 37   6         1  Manchester United      Aston Villa  2021-09-25T11:30:00Z
# 38   6         1  Manchester United      Aston Villa  2021-09-25T11:30:00Z
# 39   6         1  Manchester United      Aston Villa  2021-09-25T11:30:00Z
# 40   6         1  Manchester United      Aston Villa  2021-09-25T11:30:00Z
# 41   6         1  Manchester United      Aston Villa  2021-09-25T11:30:00Z
# 42   6         1  Manchester United      Aston Villa  2021-09-25T11:30:00Z
# 43   6         1  Manchester United      Aston Villa  2021-09-25T11:30:00Z
# 44   6         1  Manchester United      Aston Villa  2021-09-25T11:30:00Z
