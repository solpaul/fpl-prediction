# %%
# import required libriaries
from pathlib import Path
import json

from fpl_predictor.util import *

# %%
# path to data directory
#path = Path('/home/jupyter/fpl-prediction/data')
path = Path('./fpl_predictor/data')

# %%
# read in latest training set
df_train = pd.read_csv(path/'train_v8.csv', index_col=0, 
                       dtype={'season':str,
                              'comp':str,
                              'squad':str})

# path to current season
season_paths = [path/'2021-22']

# name for current season
season_names = ['2122']

# team codes
teams = pd.read_csv(path/'teams.csv')

# latest remaining season dataset, for latest week's play_proba values
remaining_season = pd.read_csv(path/'remaining_season.csv', index_col=0)

# create players dataset
all_players = build_players(path, season_paths, season_names, teams)

# 2019-20 market value
# table was in slightly different position for 2019-20 season
# should check that 2019-20 season values remain the same once season starts
teams_mv = build_season_mv('2122', 11, range(13,33))

# %%
# all_players#[all_players['full_name'] == 'Ben Davies']

# %%
df_train.tail(50)
# Out:
#                                 player  gw  position  minutes  \
# 117653  Thiago Alcántara do Nascimento   5         3       61
# 117654        Thiago Emiliano da Silva   5         2       90
# 117655                   Thomas Partey   5         3       74
# 117656                Timothy Castagne   5         2       22
# 117657                     Timo Werner   5         4       20
# 117658                        Tim Krul   5         1       90
# 117659                 Tino Livramento   5         2       85
# 117660                      Tobi Omole   5         2        0
# 117661               Toby Alderweireld   5         2        0
# 117662                   Todd Cantwell   5         3       20
# 117663                    Tomas Soucek   5         3       90
# 117664                     Tommy Doyle   5         3        0
# 117665                   Tom Cleverley   5         3       81
# 117666                      Tom Davies   5         3        9
# 117667                      Tom Heaton   5         1        0
# 117668          Trent Alexander-Arnold   5         2        0
# 117669                 Trevoh Chalobah   5         2        0
# 117670                     Troy Deeney   5         4        0
# 117671                   Tyler Roberts   5         3       29
# 117672                 Tyrick Mitchell   5         2       90
# 117673                    Tyrone Mings   5         2       90
# 117674                  Vicente Guaita   5         1       90
# 117675                 Victor Lindelöf   5         2        0
# 117676                Viljami Sinisalo   5         1        0
# 117677                 Virgil van Dijk   5         2       90
# 117678                   Vitaly Janelt   5         3       90
# 117679                 Vladimir Coufal   5         2       90
# 117680                 Wayne Hennessey   5         1        0
# 117681                   Wesley Fofana   5         2        0
# 117682                   Wesley Moraes   5         4        0
# 117683                   Wilfred Ndidi   5         3       90
# 117684                   Wilfried Zaha   5         3       90
# 117685                  William Saliba   5         2        0
# 117686               William Smallbone   5         3        0
# 117687            William Troost-Ekong   5         2       90
# 117688         Willian Borges Da Silva   5         3        0
# 117689                      Willy Boly   5         2        0
# 117690                     Will Hughes   5         3        0
# 117691                     Will Norris   5         1        0
# 117692                    Winston Reid   5         2        0
# 117693                 Xherdan Shaqiri   5         3        0
# 117694                      Yan Valery   5         2        0
# 117695                      Yerry Mina   5         2       90
# 117696      Yerson Mosquera Valdelamar   5         2        0
# 117697                     Yoane Wissa   5         3        0
# 117698                 Youri Tielemans   5         3       90
# 117699                   Yves Bissouma   5         3       78
# 117700                    Zack Steffen   5         1        0
# 117701                Álvaro Fernández   5         1        0
# 117702                  Çaglar Söyüncü   5         2       90
#
#                             team             opponent_team  \
# 117661         NaN      NaN                 NaN       NaN       1
# 117662        84.6     10.0                 0.0       0.0       1
# 117663        86.4     31.0                 0.0       0.0       1
# 117664         NaN      NaN                 NaN       NaN       1
# 117665        68.1     29.0                 0.0       0.0       1
# 117666        77.8      6.0                 0.0       0.0       1
# 117667         NaN      NaN                 NaN       NaN       1
# 117668         NaN      NaN                 NaN       NaN       1
# 117669         NaN      NaN                 NaN       NaN       1
# 117670         NaN      NaN                 NaN       NaN       1
# 117671        64.7     18.0                 1.0       2.0       1
# 117672        65.6     35.0                 0.0       0.0       1
# 117673        79.7     40.0                 0.0       0.0       1
# 117674        72.0     10.0                 0.0       0.0       1
# 117675         NaN      NaN                 NaN       NaN       1
# 117676         NaN      NaN                 NaN       NaN       1
# 117677        93.0     31.0                 0.0       0.0       1
# 117678        81.5     24.0                 0.0       1.0       1
# 117679        70.0     37.0                 2.0       2.0       1
# 117680         NaN      NaN                 NaN       NaN       1
# 117681         NaN      NaN                 NaN       NaN       1
# 117682         NaN      NaN                 NaN       NaN       1
# 117683        82.5     48.0                 0.0       0.0       1
# 117684        66.7     38.0                 3.0       5.0       1
# 117685         NaN      NaN                 NaN       NaN       1
# 117686         NaN      NaN                 NaN       NaN       1
# 117687        82.1     32.0                 0.0       0.0       1
# 117688         NaN      NaN                 NaN       NaN       1
# 117689         NaN      NaN                 NaN       NaN       1
# 117690         NaN      NaN                 NaN       NaN       1
# 117691         NaN      NaN                 NaN       NaN       1
# 117692         NaN      NaN                 NaN       NaN       1
# 117693         NaN      NaN                 NaN       NaN       1
# 117694         NaN      NaN                 NaN       NaN       1
# 117695        72.0     17.0                 0.0       0.0       1
# 117696         NaN      NaN                 NaN       NaN       1
# 117697         NaN      NaN                 NaN       NaN       1
# 117698        82.1     60.0                 0.0       1.0       1
# 117699        82.6     13.0                 0.0       0.0       1
# 117700         NaN      NaN                 NaN       NaN       1
# 117701         NaN      NaN                 NaN       NaN       1
# 117702        89.6     52.0                 0.0       0.0       1
#
# [50 rows x 59 columns]

# %%
# find the latest gameweek
last_gw = df_train['gw'][df_train['season'] == season_names[0]].max()

if np.isnan(last_gw): 
    last_gw = 1 
else: 
    last_gw = last_gw + 1
    
last_gw
# Out:
# 6

# %%
# build training set for latest gameweek
df_latest = build_season(season_paths[0], season_names[0], all_players, teams, teams_mv, [last_gw])

# %%
df_latest.drop_duplicates(inplace=True)

# %%
df_latest.head(50)
# Out:
#                             player  gw  position  minutes  \
# 0                   Aaron Connolly   6         4       14
# 1                  Aaron Cresswell   6         2       90
# 2                     Aaron Lennon   6         3        3
# 3                   Aaron Ramsdale   6         1       90
# 4                     Aaron Ramsey   6         3        0
# 5                Aaron Wan-Bissaka   6         2       90
# 6               Abdoulaye Doucouré   6         3       90
# 7                     Adama Traoré   6         3       19
# 8                   Adam Armstrong   6         4       90
# 9                     Adam Forshaw   6         3        0
# 10                       Adam Idah   6         4        0
# 11                    Adam Lallana   6         3       90
# 12                     Adam Masina   6         2        0
# 13                    Adam Webster   6         2        0
# 42           West Ham United                    Leeds
# 43                   Norwich                  Everton
# 44         Manchester United              Aston Villa
# 45                   Everton                  Norwich
# 46         Manchester United              Aston Villa
# 47                   Chelsea          Manchester City
# 48               Aston Villa        Manchester United
# 49               Southampton  Wolverhampton Wanderers
#
#     relative_market_value_team  relative_market_value_opponent_team  was_home  \
# 0                     0.552100                             0.532851     False
# 1                     0.786092                             0.562337     False
# 2                     0.323338                             1.224145     False
# 3                     1.220584                             1.551043      True
# 4                     0.908595                             2.085675     False
# 5                     2.085675                             0.908595      True
# 6                     0.965229                             0.421808      True
# 7                     0.870320                             0.536968     False
# 8                     0.536968                             0.870320      True
# 9                     0.562337                             0.786092      True
# 10                    0.421808                             0.965229     False
# 11                    0.552100                             0.532851     False
# 12                    0.295967                             0.537191      True
# 13                    0.552100                             0.532851     False
# 14                    0.295967                             0.537191      True
# 15                    1.224145                             0.323338      True
# 16                    1.957163                             0.370403     False
# 17                    1.220584                             1.551043      True
# 18                    1.220584                             1.551043      True
# 19                    2.085675                             0.908595      True
# 20                    1.220584                             1.551043      True
# 21                    0.552100                             0.532851     False
# 22                    0.965229                             0.421808      True
# 23                    0.786092                             0.562337     False
# 24                    0.536968                             0.870320      True
# 25                    1.957163                             0.370403     False
# 26                    0.552100                             0.532851     False
# 27                    1.957163                             0.370403     False
# 28                    0.965229                             0.421808      True
# 29                    0.537191                             0.295967     False
# 30                    0.786092                             0.562337     False
# 31                    0.552100                             0.532851     False
# 32                    1.961613                             2.336579      True
# 33                    2.085675                             0.908595      True
# 34                    0.870320                             0.536968     False
# 35                    0.421808                             0.965229     False
# 36                    1.957163                             0.370403     False
# 37                    0.295967                             0.537191      True
# 38                    0.786092                             0.562337     False
# 39                    0.965229                             0.421808      True
# 40                    0.965229                             0.421808      True
# 41                    0.965229                             0.421808      True
# 42                    0.786092                             0.562337     False
# 43                    0.421808                             0.965229     False
# 44                    2.085675                             0.908595      True
# 45                    0.965229                             0.421808      True
# 46                    2.085675                             0.908595      True
# 47                    1.961613                             2.336579      True
# 48                    0.908595                             2.085675     False
# 49                    0.536968                             0.870320      True
#
#     total_points  ...  selected  team_a_score  team_h_score  threat  \
# 0              1  ...      9738             1             1     0.0
# 1              2  ...   1277017             2             1    11.0
# 2              1  ...       954             2             2     2.0
# 3              3  ...    139625             1             3     0.0
# 4              0  ...     16453             1             0     0.0
# 5              2  ...    512424             1             0     0.0
# 6             11  ...    277834             0             2    35.0
# 7              1  ...    334831             1             0     0.0
# 8              2  ...    250797             1             0    20.0
# 9              0  ...      1250             2             1     0.0
# 10             0  ...     35010             0             2     0.0
# 11             1  ...     17915             1             1    17.0
# 12             0  ...      8198             1             1     0.0
# 13             0  ...     25090             1             1     0.0
# 14             0  ...      9905             1             1     0.0
# 15             3  ...      4732             2             2    20.0
# 16             0  ...     19351             3             3     0.0
# 17             1  ...      4974             1             3     0.0
# 18             0  ...     15276             1             3     0.0
# 19             0  ...      1275             1             0     0.0
# 20             0  ...     83168             1             3     0.0
# 21             0  ...     42565             1             1     0.0
# 9   2021-09-25T14:00:00Z    2122
# 10  2021-09-25T14:00:00Z    2122
# 11  2021-09-27T19:00:00Z    2122
# 12  2021-09-25T14:00:00Z    2122
# 13  2021-09-27T19:00:00Z    2122
# 14  2021-09-25T14:00:00Z    2122
# 15  2021-09-25T14:00:00Z    2122
# 16  2021-09-25T16:30:00Z    2122
# 17  2021-09-26T15:30:00Z    2122
# 18  2021-09-26T15:30:00Z    2122
# 19  2021-09-25T11:30:00Z    2122
# 20  2021-09-26T15:30:00Z    2122
# 21  2021-09-27T19:00:00Z    2122
# 22  2021-09-25T14:00:00Z    2122
# 23  2021-09-25T14:00:00Z    2122
# 24  2021-09-26T13:00:00Z    2122
# 25  2021-09-25T16:30:00Z    2122
# 26  2021-09-27T19:00:00Z    2122
# 27  2021-09-25T16:30:00Z    2122
# 28  2021-09-25T14:00:00Z    2122
# 29  2021-09-25T14:00:00Z    2122
# 30  2021-09-25T14:00:00Z    2122
# 31  2021-09-27T19:00:00Z    2122
# 32  2021-09-25T11:30:00Z    2122
# 33  2021-09-25T11:30:00Z    2122
# 34  2021-09-26T13:00:00Z    2122
# 35  2021-09-25T14:00:00Z    2122
# 36  2021-09-25T16:30:00Z    2122
# 37  2021-09-25T14:00:00Z    2122
# 38  2021-09-25T14:00:00Z    2122
# 39  2021-09-25T14:00:00Z    2122
# 40  2021-09-25T14:00:00Z    2122
# 41  2021-09-25T14:00:00Z    2122
# 42  2021-09-25T14:00:00Z    2122
# 43  2021-09-25T14:00:00Z    2122
# 44  2021-09-25T11:30:00Z    2122
# 45  2021-09-25T14:00:00Z    2122
# 46  2021-09-25T11:30:00Z    2122
# 47  2021-09-25T11:30:00Z    2122
# 48  2021-09-25T11:30:00Z    2122
# 49  2021-09-26T13:00:00Z    2122
#
# [50 rows x 34 columns]

# %%
df_latest.shape
# Out:
# (611, 34)

# %%
last_play_proba = remaining_season[remaining_season['gw'] == last_gw][['player', 'team', 'play_proba']]

# %%
last_play_proba.head()
# Out:
#                      player     team  play_proba
# 0         César Azpilicueta  Chelsea         1.0
# 1            Olivier Giroud  Chelsea         0.0
# 2  Thiago Emiliano da Silva  Chelsea         1.0
# 3             Marcos Alonso  Chelsea         1.0
# 4   Jorge Luiz Frello Filho  Chelsea         1.0

# %%
# add latest week's play_proba for each player
df_latest = df_latest.merge(last_play_proba, on=['player', 'team'], how='left')

# %%
df_latest.drop_duplicates(inplace=True)

# %%
df_train.drop_duplicates(inplace=True)

# %%
if last_gw==1:
    df_latest['relative_market_value_team_season'] = df_latest['relative_market_value_team']
    df_latest['relative_market_value_opponent_team_season'] = df_latest['relative_market_value_opponent_team']

# %%
# for when you're doing the season value properly
# relative_market_value_season = train_df[train_df['season'] == '2021'][['team', 'relative_market_value_team']].groupby(['team']).first()
# relative_market_value_season = relative_market_value_season.rename(columns={'relative_market_value_team': 'season_value'})
# relative_market_value_season

# %%
# now get futher stats from fbref
# standard stats
features = ['squad', 'comp', 'round', 'shots_total', 'shots_on_target', 'touches', 'pressures',
            'tackles', 'interceptions', 'blocks', 'xg', 'npxg', 'xa', 'sca', 
            'gca', 'passes_completed', 'passes', 'passes_pct',  'carries', 
            'dribbles_completed', 'dribbles']

# %%
# url for the premier league
url_base = 'https://fbref.com'
pl_history_page = '/en/comps/9/history/Premier-League-Seasons'
url = url_base + pl_history_page

# scrape the history table to get latest season
pl_history_table = get_table(url)
pl_history_urls = get_urls(['season'], 'season', pl_history_table, url_base)
season_urls = pl_history_urls[0:1]

df_enhanced = get_stats(features, season_urls, url_base)
# Out:
# 2021-2022
# https://fbref.com/en/comps/9/Premier-League-Stats
# Liverpool
# https://fbref.com/en/squads/822bd0ba/Liverpool-Stats
# Alisson
# Virgil van Dijk
# Sadio Mané
# Mohamed Salah
# Trent Alexander-Arnold
# Joël Matip
# Diogo Jota
# Fabinho
# Jordan Henderson
# Kostas Tsimikas
# Andrew Robertson
# Harvey Elliott
# Naby Keïta
# James Milner
# Thiago Alcántara
# Roberto Firmino
# Ibrahima Konaté
# Curtis Jones
# Alex Oxlade-Chamberlain
# Divock Origi
# Joe Gomez
# Manchester City
# https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats
# João Cancelo
# Rúben Dias
# Ederson
# Jack Grealish
# İlkay Gündoğan
# Gabriel Jesus
# Kyle Walker
# Bernardo Silva
# Aymeric Laporte
# Rodri
# Ferrán Torres
# Raheem Sterling
# Nathan Aké
# Fernandinho
# Riyad Mahrez
# Kevin De Bruyne
# Phil Foden
# Benjamin Mendy
# Oleksandr Zinchenko
# Cole Palmer
# Chelsea
# https://fbref.com/en/squads/cff3d9bb/Chelsea-Stats
# Antonio Rüdiger
# Marcos Alonso
# Jorginho
# Mateo Kovačić
# César Azpilicueta
# Andreas Christensen
# Romelu Lukaku
# Edouard Mendy
# Kai Havertz
# Mason Mount
# Reece James
# Thiago Silva
# Timo Werner
# Trevoh Chalobah
# N'Golo Kanté
# Hakim Ziyech
# Kepa Arrizabalaga
# Callum Hudson-Odoi
# Christian Pulisic
# Saúl Ñíguez
# Ruben Loftus-Cheek
# Emerson Palmieri
# Manchester Utd
# https://fbref.com/en/squads/19538871/Manchester-United-Stats
# David de Gea
# Aaron Wan-Bissaka
# Bruno Fernandes
# Harry Maguire
# Mason Greenwood
# Paul Pogba
# Luke Shaw
# Fred
# Raphaël Varane
# Cristiano Ronaldo
# Scott McTominay
# Victor Lindelöf
# Jadon Sancho
# Nemanja Matić
# Daniel James
# Anthony Martial
# Diogo Dalot
# Jesse Lingard
# Edinson Cavani
# Donny van de Beek
# Everton
# https://fbref.com/en/squads/d3fd31cc/Everton-Stats
# Lucas Digne
# Abdoulaye Doucouré
# Michael Keane
# Allan
# Demarai Gray
# Jordan Pickford
# Andros Townsend
# Yerry Mina
# Séamus Coleman
# Richarlison
# Alex Iwobi
# Dominic Calvert-Lewin
# Ben Godfrey
# Mason Holgate
# Salomón Rondón
# Asmir Begović
# André Gomes
# Anthony Gordon
# Tom Davies
# Jonjoe Kenny
# Fabian Delph
# Lewis Dobbin
# Moise Kean
# Brighton
# https://fbref.com/en/squads/d07537b9/Brighton-and-Hove-Albion-St
# Ashley Westwood
# Jóhann Berg Guðmundsson
# Ashley Barnes
# Jack Cork
# Matěj Vydra
# Jay Rodriguez
# Maxwel Cornet
# Aaron Lennon
# Erik Pieters
# Norwich City
# https://fbref.com/en/squads/1c781004/Norwich-City-Stats
# Max Aarons
# Grant Hanley
# Tim Krul
# Teemu Pukki
# Pierre Lees-Melou
# Kenny McLean
# Milot Rashica
# Ben Gibson
# Brandon Williams
# Billy Gilmour
# Todd Cantwell
# Lukas Rupp
# Josh Sargent
# Ozan Kabak
# Dimitris Giannoulis
# Mathias Normann
# Christos Tzolis
# Andrew Omobamidele
# Kieran Dowell
# Bali Mumba
# Adam Idah

# %%
# get the player name matching dictionary
with open(path/'match_list.json') as f:
  match_list = json.load(f)

match_list
# Out:
# {'Fabinho': 'Fabio Henrique Tavares',
#  'Alisson': 'Alisson Ramses Becker',
#  'Joël Matip': 'Joel Matip',
#  'Joe Gomez': 'Joseph Gomez',
#  'Naby Keïta': 'Naby Keita',
#  'Adrián': 'Adrián San Miguel del Castillo',
#  'Thiago Alcántara': 'Thiago Alcántara do Nascimento',
#  'Allan': 'Allan Marques Loureiro',
#  'Richarlison': 'Richarlison de Andrade',
#  'Gylfi Sigurðsson': 'Gylfi Sigurdsson',
#  'Séamus Coleman': 'Seamus Coleman',
#  'André Gomes': 'André Filipe Tavares Gomes',
#  'Bernard': 'Bernard Anício Caldeira Duarte',
#  'Çağlar Söyüncü': 'Çaglar Söyüncü',
#  'Bruno Fernandes': 'Bruno Miguel Borges Fernandes',
#  'Fred': 'Frederico Rodrigues de Paula Santos',
#  'Nemanja Matić': 'Nemanja Matic',
#  'Alex Telles': 'Alex Nicolao Telles',
#  'Pierre Højbjerg': 'Pierre-Emile Højbjerg',
#  'Son Heung-min': 'Heung-Min Son',
#  'Lucas Moura': 'Lucas Rodrigues Moura da Silva',
#  'Érik Lamela': 'Erik Lamela',
#  'Dele Alli': 'Bamidele Alli',
#  'Carlos Vinícius': 'Carlos Vinicius Alves Morais',
#  'Ederson': 'Ederson Santana de Moraes',
#  'Rodri': 'Rodrigo Hernandez',
#  'Rúben Dias': 'Rúben Santos Gato Alves Dias',
#  'João Cancelo': 'João Pedro Cavaco Cancelo',
#  'İlkay Gündoğan': 'Ilkay Gündogan',
#  'Gabriel Jesus': 'Gabriel Fernando de Jesus',
#  'Ferrán Torres': 'Ferran Torres',
#  'Bernardo Silva': 'Bernardo Mota Veiga de Carvalho e Silva',
#  'Fernandinho': 'Fernando Luiz Rosa',
#  'Eric García': 'Eric Garcia',
#  'Matty Cash': 'Matthew Cash',
#  'Douglas Luiz': 'Douglas Luiz Soares de Paulo',
#  'Ezri Konsa': 'Ezri Konsa Ngoyo',
#  'Trézéguet': 'Mahmoud Ahmed Ibrahim Hassan',
#  'Ben Chilwell': 'Benjamin Chilwell',
#  'Thiago Silva': 'Thiago Emiliano da Silva',
#  'Mateo Kovačić': 'Mateo Kovacic',
#  'Jorginho': 'Jorge Luiz Frello Filho',
#  'Emerson Palmieri': 'Emerson Palmieri dos Santos',
#  'Oriol Romeu': 'Oriol Romeu Vidal',
#  'Dan Nlundulu': "Daniel N'Lundulu",
#  'Łukasz Fabiański': 'Lukasz Fabianski',
#  'Tomáš Souček': 'Tomas Soucek',
#  'Vladimír Coufal': 'Vladimir Coufal',
#  'Felipe Anderson': 'Felipe Anderson Pereira Gomes',
#  'Rui Patrício': 'Rui Pedro dos Santos Patrício',
#  'Pedro Neto': 'Pedro Lomba Neto',
#  'Daniel Podence': 'Daniel Castelo Podence',
#  'Nélson Semedo': 'Nélson Cabral Semedo',
#  'Rúben Neves': 'Rúben Diogo da Silva Neves',
#  'João Moutinho': 'João Filipe Iria Santos Moutinho',
#  'Rayan Aït Nouri': 'Rayan Ait Nouri',
#  'Fábio Silva': 'Fabio Silva',
#  'Rúben Vinagre': 'Rúben Gonçalo Silva Nascimento Vinagre',
#  'Vitinha': 'Vitor Ferreira',
#  'Rodrigo': 'Rodrigo Moreno',
#  'Pablo Hernández': 'Pablo Hernández Domínguez',
#  'Ian Carlo Poveda': 'Ian Carlo Poveda-Ocampo',
#  'Joelinton': 'Joelinton Cássio Apolinário de Lira',
#  'Luka Milivojević': 'Luka Milivojevic',
#  'Jaïro Riedewald': 'Jairo Riedewald',
#  'Gabriel Dos Santos': 'Gabriel Magalhães',
#  'Willian': 'Willian Borges Da Silva',
#  'Dani Ceballos': 'Daniel Ceballos Fernández',
#  'David Luiz': 'David Luiz Moreira Marinho',
#  'Eddie Nketiah': 'Edward Nketiah',
#  'Joe Willock': 'Joseph Willock',
#  'Sead Kolašinac': 'Sead Kolasinac',
#  'Martinelli': 'Gabriel Teodoro Martinelli Silva',
#  'Solly March': 'Solomon March',
#  'Bernardo': 'Bernardo Fernandes da Silva Junior',
#  'Jóhann Berg Guðmundsson': 'Johann Berg Gudmundsson',
#  'Matěj Vydra': 'Matej Vydra',
#  'Andre-Frank Zambo Anguissa': 'André-Frank Zambo Anguissa',
#  'Semi Ajayi': 'Oluwasemilogo Adesewo Ibidapo Ajayi',
#  'Branislav Ivanović': 'Branislav Ivanovic',
#  'Filip Krovinović': 'Filip Krovinovic',
#  'Ahmed Hegazi': 'Ahmed El-Sayed Hegazi',
#  'Harvey Elliot': 'Harvey Elliott',
#  'Angeliño': 'Angelo Ogbonna',
#  'Thomas Doyle': 'Tommy Doyle',
#  'Diogo Dalot': 'José Diogo Dalot Teixeira',
#  'Pedro': 'Pedro Rodríguez Ledesma',
#  'Ricardo Pereira': 'Ricardo Domingos Barbosa Pereira',
#  'Gedson Fernandes': 'Gedson Carvalho Fernandes',
#  "Georges-Kévin N'Koudou": 'Georges-Kévin Nkoudou',
#  'Jonny Castro': 'Jonathan Castro Otto',
#  'Jesús Vallejo': 'Jesús Vallejo Lázaro',
#  'Bruno Jordão': 'Bruno André Cavaco Jordao',
#  'Mattéo Guendouzi': 'Matteo Guendouzi',
#  'Richairo Živković': 'Richairo Zivkovic',
#  'Danny Drinkwater': 'Daniel Drinkwater',
#  'Martin Dúbravka': 'Martin Dubravka',
#  'Yoshinori Mutō': 'Yoshinori Muto',
#  'Ki Sung-yueng': 'Sung-yueng Ki',
#  'Roberto': 'Roberto Jimenez Gago',
#  'Javier Hernández': 'Javier Hernández Balcázar',
#  'Frederic Guilbert': 'Frédéric Guilbert',
#  'Björn Engels': 'Bjorn Engels',
#  'Pepe Reina': 'José Reina',
#  'Jota': 'José Ignacio Peleteiro Romallo',
#  'Arnaut Groeneveld': 'Arnaut Danjuma Groeneveld',
#  'Étienne Capoue': 'Etienne Capoue',
#  'Kiko Femenía': 'Francisco Femenía Far',
#  'Ismaila Sarr': 'Ismaila Sarr',
#  'João Pedro': 'João Pedro Junqueira de Jesus',
#  'Max Aarons': 'Max Aarons',
#  'Emi Buendía': 'Emiliano Buendía Stati',
#  'Mario Vrančić': 'Mario Vrancic',
#  'Josip Drmić': 'Josip Drmic',
#  'Ralf Fährmann': 'Ralf Fahrmann',
#  'Danilo': 'Danilo Luiz da Silva',
#  'Petr Čech': 'Petr Cech',
#  'Idrissa Gana Gueye': 'Idrissa Gueye',
#  'Marko Arnautović': 'Marko Arnautovic',
#  'Xande Silva': 'Alexandre Nascimento Costa Silva',
#  'Julián Speroni': 'Julian Speroni',
#  'Kenedy': 'Robert Kenedy Nunes do Nascimento',
#  'Joselu': 'Jose Luis Mato Sanmartín',
#  'Asmir Begović': 'Asmir Begović',
#  'Kayne Ramsey': 'Kayne Ramsay',
#  'Bruno': 'Bruno Saltor Grau',
#  'Junior Hoilett': 'David Junior Hoilett',
#  'Greg Cunningham': 'Greg Cunninghamm',
#  'Jazz Richards': 'Ashley Darel Jazz Richards',
#  'Jean Seri': 'Jean Michael Seri',
#  'Fabricio': 'Fabricio Agosto Ramírez',
#  'Lazar Marković': 'Lazar Markovic',
#  'Mathias Jørgensen': 'Mathias Jorgensen',
#  'Steve Mounié': 'Steve Mounie',
#  'Jon Gorenc Stanković': 'Jon Gorenc Stankovic',
#  'Matty Daly': 'Matthew Daly',
#  'Yaya Touré': 'Gnegneri Yaya Touré',
#  'Brahim Díaz': 'Brahim Diaz',
#  'Zlatan Ibrahimović': 'Zlatan Ibrahimovic',
#  'Marko Grujić': 'Marko Grujic',
#  'Charly Musonda Jr.': 'Charly Musonda',
#  'Nikola Vlašić': 'Nikola Vlasic',
#  'Aleksandar Dragović': 'Aleksandar Dragovic',
#  'Eldin Jakupović': 'Eldin Jakupovic',
#  'Rob Elliot': 'Robert Elliot',
#  'Jesús Gámez': 'Jesús Gámez Duarte',
#  'Massadio Haïdara': 'Massadio Haidara',
#  'Lee Chung-yong': 'Chung-yong Lee',
#  'Freddie Ladapo': 'Olayinka Fredrick Oladotun Ladapo',
#  'João Mário': 'João Mário Naval Costa Eduardo',
#  'José Fonte': 'Jose Fonte',
#  'Younès Kaboul': 'Younes Kaboul',
#  'Izzy Brown': 'Isaiah Brown',
#  'Dušan Tadić': 'Dusan Tadic',
#  'Àngel Rangel': 'Angel Rangel',
#  'Badou Ndiaye': 'Papa Alioune Ndiaye',
#  'Jesé': 'Jesé Rodríguez Ruiz',
#  'Tom Edwards': 'Thomas Edwards',
#  'Kostas Stafylidis': 'Konstantinos Stafylidis',
#  'Lasse Sørensen': 'Lasse Sorenson',
#  'Bojan Krkić': 'Bojan Krkic',
#  'Allan Nyom': 'Allan-Roméo Nyom',
#  'Ahmed Elmohamady': 'Ahmed El Mohamady',
#  'Hélder Costa': 'Hélder Wander Sousa de Azevedo e Costa',
#  'Mohamed Elneny': 'Mohamed Naser El Sayed Elneny',
#  'Emile Smith-Rowe': 'Emile Smith Rowe',
#  'Ivan Cavaleiro': 'Ivan Ricardo Neves Abreu Cavaleiro',
#  'Bobby Reid': 'Bobby Decordova-Reid',
#  'Ahmed El-Sayed Hegazi': 'Ahmed El-Sayed Hegazy',
#  'Kiko Casilla': 'Francisco Casilla Cortés',
#  'Willian José': 'Willian José Da Silva',
#  'Kostas Tsimikas': 'Konstantinos Tsimikas',
#  'Okay Yokuşlu': 'Okay Yokuslu',
#  'Khanya Leshabela': 'Thakgalo Leshabela',
#  'Jaden Philogene Bidace': 'Jaden Philogene-Bidace',
#  'William Thomas Fish': 'William Fish',
#  'David Raya': 'David Raya Martin',
#  'Oghenekaro Etebo': 'Oghenekaro Peter Etebo',
#  'Ismaïla Sarr': 'Ismaila Sarr',
#  'Cucho': 'Juan Camilo Hernández Suárez',
#  'Enoch Mwepu': 'Enock Mwepu',
#  'Emiliano Buendía': 'Emiliano Buendía StatiJosé Malheiro de Sá',
#  'José Sá': 'José Malheiro de Sá',
#  'Francisco Trincão': 'Francisco Machado Mota de Castro Trincão',
#  'Valentino Livramento': 'Tino Livramento',
#  'Nuno Tavares': 'Nuno Varela Tavares',
#  'Jesuran Rak Sakyi': 'Jesurun Rak-Sakyi',
#  'Maximillian Aarons': 'Max Aarons',
#  'Josh Sargent': 'Joshua Sargent',
#  'Junior Firpo': 'Héctor Junior Firpo Adames',
#  'Imran Louza': 'Imrân Louza',
#  'Bryan': 'Bryan Gil Salvatierra',
#  'Kiernan Dewsbury Hall': 'Kiernan Dewsbury-Hall',
#  'Cristiano Ronaldo': 'Cristiano Ronaldo dos Santos Aveiro',
#  'Emerson': 'Emerson Aparecido Leite de Souza Junior',
#  'Mads Roerslev': 'Mads Roerslev Rasmussen',
#  'Odsonne Édouard': 'Odsonne Edouard',
#  'Hwang Hee-chan': 'Hee-Chan Hwang',
#  'Asmir Begovic': 'Asmir Begović'}

# %%
team_list = {}
team_list['Brighton'] = 'Brighton and Hove Albion'
team_list['Leeds United'] = 'Leeds'
team_list['Manchester Utd'] = 'Manchester United'
team_list['Newcastle Utd'] = 'Newcastle United'
team_list['Norwich City'] = 'Norwich'
team_list['Sheffield Utd'] = 'Sheffield United'
team_list['Tottenham'] = 'Tottenham Hotspur'
team_list['West Brom'] = 'West Bromwich Albion'
team_list['West Ham'] = 'West Ham United'
team_list['Wolves'] = 'Wolverhampton Wanderers'

# %%
# replace non-matching names/teams and extract gw as integer
df_enhanced['alt_name'] = df_enhanced['player'].replace(match_list)
df_enhanced['squad'] = df_enhanced['squad'].replace(team_list)
df_enhanced['round'] = df_enhanced['round'].str[-2:].astype('int')

# %%
# remove duplicated (happens when players transferred within season)
df_enhanced = df_enhanced.drop_duplicates()

# %%
df_enhanced
# Out:
#          season      player        date      squad            comp  round  \
# 0     2021-2022     Alisson  2021-08-14  Liverpool  Premier League      1
# 1     2021-2022     Alisson  2021-08-21  Liverpool  Premier League      2
# 2     2021-2022     Alisson  2021-08-28  Liverpool  Premier League      3
# 3     2021-2022     Alisson  2021-09-12  Liverpool  Premier League      4
# 4     2021-2022     Alisson  2021-09-18  Liverpool  Premier League      5
# ...         ...         ...         ...        ...             ...    ...
# 1668  2021-2022  Bali Mumba  2021-08-21    Norwich  Premier League      2
# 1669  2021-2022   Adam Idah  2021-08-14    Norwich  Premier League      1
# 1670  2021-2022   Adam Idah  2021-08-28    Norwich  Premier League      3
# 1671  2021-2022   Adam Idah  2021-09-11    Norwich  Premier League      4
# 1672  2021-2022   Adam Idah  2021-09-18    Norwich  Premier League      5
#
#      shots_total shots_on_target touches pressures  ...   xa sca gca  \
# 0              0               0      33         0  ...  0.0   0   0
# 1              0               0      53         1  ...  0.0   0   0
# 2              0               0      26         0  ...  0.0   0   0
# 3              0               0      43         0  ...  0.0   0   0
# 4              0               0      36         0  ...  0.0   0   0
# ...          ...             ...     ...       ...  ...  ...  ..  ..
# 1668           0               0      19        12  ...  0.0   0   0
# 1669           1               1       6         5  ...  0.0   0   0
# 1670           1               0       6         2  ...  0.0   0   0
# 1671           0               0       3         2  ...  0.2   1   0
# 1672           0               0       3         0  ...  0.0   0   0
#
#      passes_completed passes passes_pct carries dribbles_completed dribbles  \
# 0                  27     30       90.0      17                  0        0
# 1                  38     46       82.6      28                  1        1
# 2                  21     23       91.3      15                  0        0
# 3                  37     41       90.2      27                  0        0
# 4                  22     28       78.6      13                  0        0
# ...               ...    ...        ...     ...                ...      ...
# 1668                7     10       70.0       9                  0        1
# 1669                3      5       60.0       2                  0        0
# 1670                4      4      100.0       5                  0        1
# 1671                1      2       50.0       2                  0        0
# 1672                2      3       66.7       3                  1        1
#
#                    alt_name
# 0     Alisson Ramses Becker
# 1     Alisson Ramses Becker
# 2     Alisson Ramses Becker
# 3     Alisson Ramses Becker
# 4     Alisson Ramses Becker
# ...                     ...
# 1668             Bali Mumba
# 1669              Adam Idah
# 1670              Adam Idah
# 1671              Adam Idah
# 1672              Adam Idah
#
# [1668 rows x 25 columns]

# %%
# create date field in same format as enhanced data
df_latest['date'] = df_latest['kickoff_time'].str[:10]

# %%
# check if any names aren't matching
enhanced_players = df_enhanced[df_enhanced['date'].isin(df_latest['date'].unique())]['alt_name'].unique().tolist()
standard_players = df_latest['player'].unique().tolist()

unmatched_players = [x for x in enhanced_players if x not in standard_players]
unmatched_players
# Out:
# []

# %%
# check if any teams aren't matching
enhanced_teams = df_enhanced[df_enhanced['date'].isin(df_latest['date'].unique())]['squad'].unique().tolist()
standard_teams = df_latest['team'].unique().tolist()

unmatched_teams = [x for x in enhanced_teams if x not in standard_teams]
unmatched_teams
# Out:
# []

# %%
# any additional corrections
# match_list['Asmir Begović'] = 'Asmir Begović'
# match_list['Emerson'] = 'Emerson Aparecido Leite de Souza Junior'
# match_list['Mads Roerslev'] = 'Mads Roerslev Rasmussen'
# match_list['Odsonne Édouard'] = 'Odsonne Edouard'
# match_list['Hwang Hee-chan'] = 'Hee-Chan Hwang'

# %%
# replace additional non-matching names
# df_enhanced['alt_name'] = df_enhanced['player'].replace(match_list)

# %%
# make sure there are no non matches after update
# enhanced_players =  df_enhanced[df_enhanced['round'] == last_gw]['alt_name'].unique().tolist()
# standard_players = df_latest['player'].unique().tolist()

# unmatched_players = [x for x in enhanced_players if x not in standard_players]
# unmatched_players

# %%
# if match list was updated then update the file
# json_file = json.dumps(match_list)
# f = open(path/"match_list.json","w")
# f.write(json_file)
# f.close()

# %%
# check there are no duplicates in the join fields for the enhanced data
assert(len(df_enhanced[df_enhanced.duplicated(subset=['alt_name', 'date'], keep=False)]) == 0)

# %%
df_latest[df_latest.duplicated(subset=['date','player','team'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [player, gw, position, minutes, team, opponent_team, relative_market_value_team, relative_market_value_opponent_team, was_home, total_points, assists, bonus, bps, clean_sheets, creativity, goals_conceded, goals_scored, ict_index, influence, own_goals, penalties_missed, penalties_saved, red_cards, saves, selected, team_a_score, team_h_score, threat, transfers_balance, transfers_in, transfers_out, yellow_cards, kickoff_time, season, play_proba, date]
# Index: []
#
# [0 rows x 36 columns]

# %%
# check there are no duplicates in the join fields for the standard data
assert(len(df_train[df_train.duplicated(subset=['date','player','team'])]) == 0)

# %%
# df_train[df_train.duplicated(subset=['date','player','team'])]

# %%
# join standard and enhanced dataframes
df_latest_further = df_latest.merge(df_enhanced.drop(['player', 'season', 'round'], axis=1), 
                                   left_on=['date', 'player', 'team'], 
                                   right_on=['date', 'alt_name', 'squad'], how='left')

# %%
# drop the alt name field and check the length of the standard
# dataframe has not increased
df_latest_further = df_latest_further.drop(['alt_name'], axis=1)
assert(len(df_latest_further) == len(df_latest_further))

# %%
# add crowds field
df_latest_further['crowds'] = 1

# %%
assert(sum(df_latest_further[df_latest_further['minutes'] > 0]['xg'].isnull()) == 0)

# %%
# df_latest_further[df_latest_further['minutes'] > 0][df_latest_further[df_latest_further['minutes'] > 0]['xg'].isnull()]

# %%
df_train_new = pd.concat([df_train, df_latest_further], ignore_index=True, axis=0, sort=False)

# %%
df_train_new[df_train_new['player'] == 'Harry Kane'].tail()
# Out:
#             player  gw  position  minutes               team  \
# 115556  Harry Kane   2         4       18  Tottenham Hotspur
# 116128  Harry Kane   3         4       90  Tottenham Hotspur
# 116711  Harry Kane   4         4       90  Tottenham Hotspur
# 117311  Harry Kane   5         4       90  Tottenham Hotspur
# 117918  Harry Kane   6         4       90  Tottenham Hotspur
#
#                   opponent_team  relative_market_value_team  \
# 115556  Wolverhampton Wanderers                    1.558729
# 116128                  Watford                    1.537334
# 116711           Crystal Palace                    1.547840
# 117311                  Chelsea                    1.550871
# 117918                  Arsenal                    1.551043
#
#         relative_market_value_opponent_team  was_home  total_points  ...   xa  \
# 115556                             0.858519     False             0  ...  0.1
# 116128                             0.295470      True             1  ...  0.3
# 116711                             0.531751     False             2  ...    0
# 117311                             1.963620      True             2  ...    0
# 117918                             1.220584     False             2  ...  0.0
#
#         sca  gca  passes_completed  passes  passes_pct  carries  \
# 115556    2    0                 7      10          70        7
# 116128    3    0                21      26        80.8       30
# 116711    1    0                16      23        69.6       26
# 117311    1    0                24      31        77.4       29
# 117918    0    0                10      13        76.9       12
#
#         dribbles_completed  dribbles  crowds
# 115556                   0         0       1
# 116128                   2         3       1
# 116711                   2         3       1
# 117311                   1         2       1
# 117918                   0         1       1
#
# [5 rows x 59 columns]

# %%
df_train_new.tail(7)
# Out:
#                             player  gw  position  minutes  \
# 118307  Yerson Mosquera Valdelamar   6         2        0
# 118308                 Yoane Wissa   6         3       12
# 118309             Youri Tielemans   6         3       90
# 118310               Yves Bissouma   6         3        0
# 118311                Zack Steffen   6         1        0
# 118312            Álvaro Fernández   6         1        0
# 118313              Çaglar Söyüncü   6         2       90
#
#                             team   opponent_team  relative_market_value_team  \
# 118307   Wolverhampton Wanderers     Southampton                    0.870320
# 118308                 Brentford       Liverpool                    0.370403
# 118309            Leicester City         Burnley                    1.224145
# 118310  Brighton and Hove Albion  Crystal Palace                    0.552100
# 118311           Manchester City         Chelsea                    2.336579
# 118312                 Brentford       Liverpool                    0.370403
# 118313            Leicester City         Burnley                    1.224145
#
#         relative_market_value_opponent_team  was_home  total_points  ...   xa  \
# 118307                             0.536968     False             0  ...  NaN
# 118308                             1.957163      True             6  ...  0.0
# 118309                             0.323338      True             7  ...  0.5
# 118310                             0.532851     False             0  ...  NaN
# 118311                             1.961613     False             0  ...  NaN
# 118312                             1.957163      True             0  ...  NaN
# 118313                             0.323338      True             1  ...  0.0
#
#         sca  gca  passes_completed  passes  passes_pct  carries  \
# 118307  NaN  NaN               NaN     NaN         NaN      NaN
# 118308    1    1                 1       3        33.3        3
# 118309    8    1                66      77        85.7       72
# 118310  NaN  NaN               NaN     NaN         NaN      NaN
# 118311  NaN  NaN               NaN     NaN         NaN      NaN
# 118312  NaN  NaN               NaN     NaN         NaN      NaN
# 118313    1    0                57      62        91.9       51
#
#         dribbles_completed  dribbles  crowds
# 118307                 NaN       NaN       1
# 118308                   0         0       1
# 118309                   1         1       1
# 118310                 NaN       NaN       1
# 118311                 NaN       NaN       1
# 118312                 NaN       NaN       1
# 118313                   0         1       1
#
# [7 rows x 59 columns]

# %%
df_latest_further.shape
# Out:
# (611, 57)

# %%
df_train_new.shape
# Out:
# (118314, 59)

# %%
# save latest training set to csv
# overwrite existing one
df_train_new.to_csv(path/'train_v8.csv')

# %%
# get fixtures
fixtures = pd.read_csv(path/'2021-22/fixtures.csv')
team_dict = teams[['team_2122', 'team']].dropna().set_index('team_2122').to_dict()['team']

fixtures['home_team'] = fixtures['team_h'].replace(team_dict)
fixtures['away_team'] = fixtures['team_a'].replace(team_dict)
fixtures = fixtures[['home_team', 'away_team', 'kickoff_time', 'event']]
fixtures = fixtures.rename(columns={'event':'gw'})


# use these two lines if updating play_proba later in week
# current_gw = last_gw
# df_train_new = pd.read_csv(path/'train_v7.csv', index_col=0, dtype={'season':str,
# 101         Manchester United           Manchester City  2021-11-06T12:30:00Z
# 102                 Brentford                   Norwich  2021-11-06T15:00:00Z
# 103                   Chelsea                   Burnley  2021-11-06T15:00:00Z
# 105  Brighton and Hove Albion          Newcastle United  2021-11-06T17:30:00Z
# 106                   Arsenal                   Watford  2021-11-07T14:00:00Z
# 107                   Everton         Tottenham Hotspur  2021-11-07T14:00:00Z
# 108                     Leeds            Leicester City  2021-11-07T14:00:00Z
# 109           West Ham United                 Liverpool  2021-11-07T16:30:00Z
# 104            Crystal Palace   Wolverhampton Wanderers  2021-11-06T15:00:00Z
#
#      gw  match_no
# 60    7         0
# 61    7         1
# 62    7         2
# 63    7         3
# 64    7         4
# 65    7         5
# 66    7         6
# 67    7         7
# 68    7         8
# 69    7         9
# 79    8        10
# 78    8        11
# 77    8        12
# 75    8        13
# 76    8        14
# 73    8        15
# 72    8        16
# 71    8        17
# 70    8        18
# 74    8        19
# 89    9        20
# 88    9        21
# 87    9        22
# 86    9        23
# 85    9        24
# 84    9        25
# 82    9        26
# 81    9        27
# 80    9        28
# 83    9        29
# 97   10        30
# 99   10        31
# 98   10        32
# 95   10        33
# 96   10        34
# 93   10        35
# 90   10        36
# 91   10        37
# 94   10        38
# 92   10        39
# 100  11        40
# 101  11        41
# 102  11        42
# 103  11        43
# 105  11        44
# 106  11        45
# 107  11        46
# 108  11        47
# 109  11        48
# 104  11        49

# %%
# add universal team codes for home and away teams
fixtures = fixtures.merge(teams, left_on='home_team', right_on='team', how='left')
fixtures = fixtures.merge(teams, left_on='away_team', right_on='team', how='left')
fixtures = fixtures[['gw', 'match_no', 'home_team', 'away_team', 'kickoff_time', 'team_code_x', 'team_code_y']]
fixtures.rename(index=str,
                columns={'team_code_x':'home_team_code',
                         'team_code_y':'away_team_code'},
                inplace=True)

# %%
fixtures.head()
# Out:
#    gw  match_no                home_team         away_team  \
# 0   7         0        Manchester United           Everton
# 1   7         1                  Burnley           Norwich
# 2   7         2                  Chelsea       Southampton
# 3   7         3                    Leeds           Watford
# 4   7         4  Wolverhampton Wanderers  Newcastle United
#
#            kickoff_time  home_team_code  away_team_code
# 0  2021-10-02T11:30:00Z               1              11
# 1  2021-10-02T14:00:00Z              90              45
# 2  2021-10-02T14:00:00Z               8              20
# 3  2021-10-02T14:00:00Z               2              57
# 4  2021-10-02T14:00:00Z              39               4

# %%
# all_players.replace(to_replace='None', value=1, inplace=True)

# %%
all_players[all_players['play_proba_2122'] == '0']
# Out:
#                       full_name play_proba_2122  position_2122  id_2122  \
# 1          Rúnar Alex Rúnarsson               0              1        2
# 2       Willian Borges Da Silva               0              3        3
# 6                  Granit Xhaka               0              3        7
# 8               Héctor Bellerín               0              2        9
# 17               Lucas Torreira               0              3       18
# ..                          ...             ...            ...      ...
# 596               Owen Otasowie               0              3      442
# 598         Andreas Söndergaard               0              1      444
# 600  Yerson Mosquera Valdelamar               0              2      446
# 605             Patrick Cutrone               0              4      523
# 608           Christian Marques               0              2      549
#
#      cost_2122  team_2122 web_name_2122
# 1           40          3     Rúnarsson
# 2           63          3       Willian
# 6           49          3         Xhaka
# 8           48          3      Bellerín
# 17          45          3      Torreira
# ..         ...        ...           ...
# 596         45         39      Otasowie
# 598         40         39   Söndergaard
# 600         45         39      Mosquera
# 605         50         39       Cutrone
# 608         40         39       Marques
#
# [133 rows x 7 columns]

# %%
# join home team to all players for current season
home_df = fixtures.merge(all_players, 
               left_on='home_team_code', 
               right_on='team_2122', 
               how='left')

# pull out the required fields and rename columns
home_df = home_df[['gw', 'match_no', 'home_team', 'away_team', 'kickoff_time', 
                   'full_name', 'position_2122', 'cost_2122', 'play_proba_2122', 
                   'web_name_2122']]
home_df.rename(index=str, 
               columns={'home_team':'team',
                        'away_team':'opponent_team',
                        'full_name':'player',
                        'position_2122':'position',
                        'cost_2122':'price',
                        'play_proba_2122':'play_proba',
                        'web_name_2122':'short_name'},
              inplace=True)

# add home flag
home_df['was_home'] = True

# %%
# join away team to all players for current season
away_df = fixtures.merge(all_players, 
               left_on='away_team_code', 
               right_on='team_2122', 
               how='left')

# pull out the required fields and rename columns
away_df = away_df[['gw',  'match_no', 'away_team', 'home_team', 'kickoff_time', 
                   'full_name', 'position_2122', 'cost_2122', 'play_proba_2122', 
                   'web_name_2122']]
away_df.rename(index=str, 
               columns={'away_team':'team',
                        'home_team':'opponent_team',
                        'full_name':'player',
                        'position_2122':'position',
                        'cost_2122':'price',
                        'play_proba_2122':'play_proba',
                        'web_name_2122':'short_name'},
              inplace=True)

# add home flag
away_df['was_home'] = False

# %%
# look at away players
away_df.head()
# Out:
#    gw  match_no     team      opponent_team          kickoff_time  \
# 0   7         0  Everton  Manchester United  2021-10-02T11:30:00Z
# 1   7         0  Everton  Manchester United  2021-10-02T11:30:00Z
# 2   7         0  Everton  Manchester United  2021-10-02T11:30:00Z
# 3   7         0  Everton  Manchester United  2021-10-02T11:30:00Z
# 4   7         0  Everton  Manchester United  2021-10-02T11:30:00Z
#
#                            player  position  price play_proba  short_name  \
# 0                    Fabian Delph         3     44          0       Delph
# 1                Gylfi Sigurdsson         3     68       None  Sigurdsson
# 2                  Seamus Coleman         2     49          0     Coleman
# 3                 James Rodríguez         3     69          0       James
# 4  Bernard Anício Caldeira Duarte         3     55          0     Bernard
#
#    was_home
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False

# %%
# look at home players
home_df.head()
# Out:
#    gw  match_no               team opponent_team          kickoff_time  \
# 0   7         0  Manchester United       Everton  2021-10-02T11:30:00Z
# 1   7         0  Manchester United       Everton  2021-10-02T11:30:00Z
# 2   7         0  Manchester United       Everton  2021-10-02T11:30:00Z
# 3   7         0  Manchester United       Everton  2021-10-02T11:30:00Z
# 4   7         0  Manchester United       Everton  2021-10-02T11:30:00Z
#
#            player  position  price play_proba short_name  was_home
# 0  Edinson Cavani         4     84        100     Cavani      True
# 1    David de Gea         1     50       None     de Gea      True
# 2   Nemanja Matic         3     45       None      Matic      True
# 3      Paul Pogba         3     78       None      Pogba      True
# 4   Harry Maguire         2     54          0    Maguire      True

# %%
# # calculate average minutes over last 5 gameweeks
# # first get last 5 gameweeks in current season
# recent_mins = df_train_new[(df_train_new['gw'] >= current_gw - 5) & 
#                            (df_train_new['season'] == season_names[0])][['player', 'minutes', 'play_proba']]

# # recent_mins = df_train_new[((df_train_new['gw'] >= 40 - 5) & 
# #                            (df_train_new['season'] == '1920')) | 
# #                            ((df_train_new['gw'] >= 1) & 
# #                            (df_train_new['season'] == '2021'))][['player', 'minutes', 'play_proba']]

# # exclude weeks where the player had an injury designation (i.e. keep where play_proba is 1)
# recent_mins = recent_mins[recent_mins['play_proba'] == 1]

# len(recent_mins)

# # average for each player
# recent_mins = recent_mins.groupby(['player'])['minutes'].mean().to_dict()

# recent_mins

# %%
# concatenate home and away players
remaining_season_df = home_df.append(away_df).reset_index(drop=True)

# add home and away team market values
remaining_season_df = remaining_season_df.merge(teams_mv[teams_mv['season'] == '2122'],
                                                left_on='team', 
                                                right_on='name', 
                                                how='left').drop(['name', 'season'], axis=1)

remaining_season_df = remaining_season_df.merge(teams_mv[teams_mv['season'] == '2122'],
                                                left_on='opponent_team', 
                                                right_on='name', 
                                                how='left').drop(['name', 'season'], axis=1)

remaining_season_df.rename(index=str, 
                           columns={'relative_market_value_x':'relative_market_value_team',
                                    'relative_market_value_y':'relative_market_value_opponent_team'},
                           inplace=True)

# add season name
remaining_season_df['season'] = season_names[0]

# divide cost by 10 for actual cost
remaining_season_df['price'] = remaining_season_df['price']/10

# set availability probability
# 0 = 0% chance, 25 = 25% chance, etc
# 'None' or '100' = 100% chance
remaining_season_df.loc[remaining_season_df['play_proba'] == 'None', 'play_proba'] = 100
remaining_season_df['play_proba'] = remaining_season_df['play_proba'].astype('float') / 100

# cast position to integer
remaining_season_df['position'] = remaining_season_df['position'].astype(int)

# # add minutes based on last five fixtures
# remaining_season_df['minutes'] = remaining_season_df['player'].map(recent_mins)
# remaining_season_df['minutes'].fillna(0, inplace=True)

# # multiply minutes by play probability
# remaining_season_df['minutes'] = remaining_season_df['minutes'] * remaining_season_df['play_proba']

# %%
remaining_season_df.head(50)
# Out:
#     gw  match_no               team opponent_team          kickoff_time  \
# 0    7         0  Manchester United       Everton  2021-10-02T11:30:00Z
# 1    7         0  Manchester United       Everton  2021-10-02T11:30:00Z
# 2    7         0  Manchester United       Everton  2021-10-02T11:30:00Z
# 3    7         0  Manchester United       Everton  2021-10-02T11:30:00Z
# 4    7         0  Manchester United       Everton  2021-10-02T11:30:00Z
# 5    7         0  Manchester United       Everton  2021-10-02T11:30:00Z
# 6    7         0  Manchester United       Everton  2021-10-02T11:30:00Z
# 7    7         0  Manchester United       Everton  2021-10-02T11:30:00Z
# 8    7         0  Manchester United       Everton  2021-10-02T11:30:00Z
# 9    7         0  Manchester United       Everton  2021-10-02T11:30:00Z
# 10   7         0  Manchester United       Everton  2021-10-02T11:30:00Z
# 11   7         0  Manchester United       Everton  2021-10-02T11:30:00Z
# 12   7         0  Manchester United       Everton  2021-10-02T11:30:00Z
# 13   7         0  Manchester United       Everton  2021-10-02T11:30:00Z
# 14   7         0  Manchester United       Everton  2021-10-02T11:30:00Z
# 15   7         0  Manchester United       Everton  2021-10-02T11:30:00Z
# 16   7         0  Manchester United       Everton  2021-10-02T11:30:00Z
# 17   7         0  Manchester United       Everton  2021-10-02T11:30:00Z
# 18   7         0  Manchester United       Everton  2021-10-02T11:30:00Z
# 19   7         0  Manchester United       Everton  2021-10-02T11:30:00Z
# 20   7         0  Manchester United       Everton  2021-10-02T11:30:00Z
# 21   7         0  Manchester United       Everton  2021-10-02T11:30:00Z
# 22   7         0  Manchester United       Everton  2021-10-02T11:30:00Z
# 23   7         0  Manchester United       Everton  2021-10-02T11:30:00Z
# 24   7         0  Manchester United       Everton  2021-10-02T11:30:00Z
# 25   7         0  Manchester United       Everton  2021-10-02T11:30:00Z
# 26   7         0  Manchester United       Everton  2021-10-02T11:30:00Z
# 27   7         1            Burnley       Norwich  2021-10-02T14:00:00Z
# 28   7         1            Burnley       Norwich  2021-10-02T14:00:00Z
# 29   7         1            Burnley       Norwich  2021-10-02T14:00:00Z
# 30   7         1            Burnley       Norwich  2021-10-02T14:00:00Z
# 31   7         1            Burnley       Norwich  2021-10-02T14:00:00Z
# 32   7         1            Burnley       Norwich  2021-10-02T14:00:00Z
# 33   7         1            Burnley       Norwich  2021-10-02T14:00:00Z
# 34   7         1            Burnley       Norwich  2021-10-02T14:00:00Z
# 35   7         1            Burnley       Norwich  2021-10-02T14:00:00Z
# 36   7         1            Burnley       Norwich  2021-10-02T14:00:00Z
# 37   7         1            Burnley       Norwich  2021-10-02T14:00:00Z
# 38   7         1            Burnley       Norwich  2021-10-02T14:00:00Z
# 39   7         1            Burnley       Norwich  2021-10-02T14:00:00Z
# 40   7         1            Burnley       Norwich  2021-10-02T14:00:00Z
# 41   7         1            Burnley       Norwich  2021-10-02T14:00:00Z
# 42   7         1            Burnley       Norwich  2021-10-02T14:00:00Z
# 2             Matic      True                    2.085675
# 3             Pogba      True                    2.085675
# 4           Maguire      True                    2.085675
# 5              Fred      True                    2.085675
# 6              Shaw      True                    2.085675
# 7           Lingard      True                    2.085675
# 8         Fernandes      True                    2.085675
# 9           Martial      True                    2.085675
# 10           Telles      True                    2.085675
# 11        Henderson      True                    2.085675
# 12         Rashford      True                    2.085675
# 13      van de Beek      True                    2.085675
# 14         Lindelöf      True                    2.085675
# 15        McTominay      True                    2.085675
# 16           Bailly      True                    2.085675
# 17      Wan-Bissaka      True                    2.085675
# 18        Greenwood      True                    2.085675
# 19             Mata      True                    2.085675
# 20           Sancho      True                    2.085675
# 21           Heaton      True                    2.085675
# 22            Dalot      True                    2.085675
# 23          Pereira      True                    2.085675
# 24           Elanga      True                    2.085675
# 25           Varane      True                    2.085675
# 26          Ronaldo      True                    2.085675
# 27        Tarkowski      True                    0.323338
# 28         Bardsley      True                    0.323338
# 29          Pieters      True                    0.323338
# 30             Cork      True                    0.323338
# 31         Stephens      True                    0.323338
# 32             Long      True                    0.323338
# 33        Rodriguez      True                    0.323338
# 34           Barnes      True                    0.323338
# 35              Mee      True                    0.323338
# 36         Westwood      True                    0.323338
# 37      Gudmundsson      True                    0.323338
# 38             Wood      True                    0.323338
# 39           Lowton      True                    0.323338
# 40            Vydra      True                    0.323338
# 41             Pope      True                    0.323338
# 42           Taylor      True                    0.323338
# 43           Norris      True                    0.323338
# 44        Brownhill      True                    0.323338
# 45           Benson      True                    0.323338
# 46  Peacock-Farrell      True                    0.323338
# 47           McNeil      True                    0.323338
# 48          Collins      True                    0.323338
# 49        Hennessey      True                    0.323338
#
#     relative_market_value_opponent_team season
# 0                              0.965229   2122
# 1                              0.965229   2122
# 2                              0.965229   2122
# 3                              0.965229   2122
# 4                              0.965229   2122
# 5                              0.965229   2122
# 6                              0.965229   2122
# 7                              0.965229   2122
# 8                              0.965229   2122
# 9                              0.965229   2122
# 10                             0.965229   2122
# 11                             0.965229   2122
# 12                             0.965229   2122
# 13                             0.965229   2122
# 14                             0.965229   2122
# 15                             0.965229   2122
# 16                             0.965229   2122
# 17                             0.965229   2122
# 18                             0.965229   2122
# 19                             0.965229   2122
# 20                             0.965229   2122
# 21                             0.965229   2122
# 22                             0.965229   2122
# 23                             0.965229   2122
# 24                             0.965229   2122
# 25                             0.965229   2122
# 26                             0.965229   2122
# 27                             0.421808   2122
# 28                             0.421808   2122
# 29                             0.421808   2122
# 30                             0.421808   2122
# 31                             0.421808   2122
# 32                             0.421808   2122
# 33                             0.421808   2122
# 34                             0.421808   2122
# 35                             0.421808   2122
# 36                             0.421808   2122
# 37                             0.421808   2122
# 38                             0.421808   2122
# 39                             0.421808   2122
# 40                             0.421808   2122
# 41                             0.421808   2122
# 42                             0.421808   2122
# 43                             0.421808   2122
# 44                             0.421808   2122
# 45                             0.421808   2122
# 46                             0.421808   2122
# 47                             0.421808   2122
# 48                             0.421808   2122
# 49                             0.421808   2122

# %%
# save latest prediction set to csv
remaining_season_df.to_csv(path/'remaining_season.csv')
